# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler
import pytz

# %%
s3 = boto3.client('s3')

training_bucket = "icarus-research-data"
training_prefix = 'training_datasets/expanded_1d_datasets/'

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

index = ["QQQ","SPY","IWM","TLT"]
test_lag = ["DAL","UAL","VZ","T","AAL","AMC"]
train_lag = ["AMC"]

bf_plus = ["AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","PLTR","BAC","AAPL","NFLX","ABNB","CRWD","SHOP","FB","CRM",
            "MSFT","F","V","MA","JNJ","DIS","JPM","INTC","ADBE","BA","CVX","MRNA","PFE","SNOW","NKE",'META',
            'C','TGT','MMM','SQ','PANW','DAL','CSCO','UBER','SBUX']
bfpidx = ["AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","PLTR","BAC","AAPL","NFLX","ABNB","CRWD","SHOP","FB","CRM",
            "MSFT","F","V","MA","JNJ","DIS","JPM","INTC","ADBE","BA","CVX","MRNA","PFE","SNOW","NKE",'META',
            'C','TGT','MMM','SQ','PANW','DAL','CSCO','UBER','SBUX','TSM',"QQQ","SPY","IWM","TLT"]
high_vol = ['ZM', 'UBER', 'TDOC', 'UAL', 'DAL', 'RCL', 'AMZN', 'ABNB', 'CRM',
       'F', 'ADBE', 'BA', 'META', 'TSLA', 'LCID', 'NIO', 'RIVN', 'COIN',
       'SQ', 'SHOP', 'DOCU', 'ROKU', 'TWLO', 'DDOG', 'ZS', 'NET', 'OKTA',
       'UPST', 'ETSY', 'PINS', 'FUTU', 'SE', 'BIDU', 'JD', 'BABA', 'RBLX',
       'AMD', 'NVDA', 'PYPL', 'PLTR', 'NFLX', 'CRWD', 'INTC', 'MRNA',
       'SNOW', 'SOFI', 'PANW']

low_vol = ['CMG', 'AXP', 'MMM', 'PEP', 'GE', 'MRK', 'HD', 'LOW', 'VZ', 'PG',
            'TSM', 'GOOG', 'GOOGL', 'BAC', 'AAPL', 'MSFT', 'V', 'MA', 'JNJ',
            'DIS', 'JPM', 'CVX', 'PFE', 'C', 'CAT', 'KO', 'MS', 'GS', 'IBM',
            'CSCO', 'WMT', 'WFC', 'TGT', 'COST', 'ORCL', 'SBUX', 'NKE', 'QQQ',
            'SPY', 'TLT', 'IWM']

goliath = ['QQQ','SPY','NVDA','IWM','TLT','AAPL','MSFT','GOOG','GOOGL','AMZN','META','FB']

# %%
def create_training_data_local(key_list, prefix, bucket_name,title, start_date, end_date):
    df_list = []
    hours = [10,11,12,13,14,15]
    start = start_date.split(' ')[0]
    end = end_date.split(' ')[0]
    # print(file_key)
    for key in key_list:
        for hour in hours:
            try:
                data = s3.get_object(Bucket=bucket_name, Key=f'{prefix}{key}/{hour}.csv')
                df = pd.read_csv(data.get("Body")) 
                df_list.append(df)
                df['hour'] = hour
            except:
                continue

    data = pd.concat(df_list)
    data.reset_index(drop=True, inplace=True)
    data['dt'] = pd.to_datetime(data['date'])
    data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek)
    data = data.round(3)
    data.replace([np.inf, -np.inf], 0, inplace=True)

    data.to_csv(f'/Users/charlesmiller/Documents/BF/{start}_{end}.csv', index=False)

    return data

def pull_training_data_local(end_date,start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/ALL_SYM/2018-01-01_2023-10-28.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data = data.loc[data['symbol'].isin(high_vol)]
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data


def pull_validation_data_local(end_date,start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/ALL_SYM/2018-01-01_2023-10-28.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data = data.loc[data['dt'] >= start_date]
    data = data.loc[data['symbol'].isin(high_vol)]
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data

# %%
def build_date_list(start_date, end_date):
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list


def build_validation_dates_local(deployment_date):
    end_date = deployment_date + timedelta(days=5)
    return end_date

# %%
def model_results_analyzer(predictions, y_validate):
    mse = mean_squared_error(y_validate, predictions)
    rmse = math.sqrt(mse)
    mae = mean_absolute_error(y_validate, predictions)
    r2 = r2_score(y_validate, predictions)
    print(f'MSE: {mse}')
    return mse, rmse, mae, r2

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    X = dataset[features]
    y = dataset[target_label]

    X_validate = validation_dataset[features]
    y_validate = validation_dataset[target_label]


    xgb_model = xgb.XGBRegressor(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='reg:squarederror',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    mse, rmse, mae, r2 = model_results_analyzer(predictions, y_validate)
    validation_dataset['forecast'] = predictions


    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    return mse, rmse, mae, r2, fi_list, validation_dataset


def train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset = dataset.round(3)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features]
    y = dataset[target_label]

    X_validate = validation_dataset[features]
    y_validate = validation_dataset[target_label]
    

    xgb_model = xgb.XGBRegressor(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='reg:squarederror',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    mse, rmse, mae, r2 = model_results_analyzer(predictions, y_validate)
    validation_dataset['forecast'] = predictions

    return mse, rmse, mae, r2, "fi_list", validation_dataset

# %%
def model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
    validation_end_date = build_validation_dates_local(deployment_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    mse, rmse, mae, r2, fi_list, validation_dataset = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_dataset.to_csv())
    return put_response

def model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,end_date,deployment_date,hyperparams):
    validation_end_date = build_validation_dates_local(deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    mse, rmse, mae, r2, fi_list, validation_dataset = train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    return mse

def model_runner_data(model_name, dataset_name, title, features, target_label, target_value,start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams):
    dates = build_date_list(start_date, end_date)
    key_list = build_query_keys(dates)
    dataset = create_training_data_local(key_list, 'fixed_alerts_full/new_features/big_fish/', 'inv-alerts', title, start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
    return dataset

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=10)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

# %%
model_name = 'BFP:TSSIM1_HIGHVOL_custHyp_2018'
dataset_name = 'TSSIM1_HIGHVOL_custHyp_2018'
title = 'BFP'
hyperparams = {'subsample': 0.6, 'num_round': 800, 'min_child_weight': 8, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
features = ['min_volume_vol_diff', 'daily_vol_diff', 'volume_vol_450M', 'threeD_stddev50', 'return_vol_15M', 'rsi', '15min_vol_diff_pct', 'return_vol_4H', 
             'volume_vol_30M', 'SPY_3D', 'SPY_diff', 'volume_vol_60M', 'SPY_5D', 'oneD_stddev50', 'rsi3', 'roc', 'adx', 'SPY_diff3', 'volume_vol_240M', 'hour_vol_diff', 
             'cmf', 'month', 'volume_vol_16H', 'daily_volume_vol_diff_pct', 'close_diff3', 'return_vol_240M', 'hour', 'return_vol_3D', 'volume_vol_4H', 'range_vol', 'volume_vol_8H', 
             'daily_vol_diff_pct30', 'volume_vol_15M', 'threeD_returns_close']
target_label = 'three_min'
target_value = -.025

dataset_start_date = datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')) 
dates_list = build_evaluation_period(datetime(2022,10,3,tzinfo=pytz.timezone('US/Eastern')), datetime(2023,10,14,tzinfo=pytz.timezone('US/Eastern')))

# date = dates_list[-1]
# response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
for date in dates_list:
    print(date)
    response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=dataset_start_date)
# Out:
# {'deployment_date': datetime.datetime(2022, 10, 3, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 9, 23, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.004777421637793425
# {'deployment_date': datetime.datetime(2022, 10, 10, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 9, 30, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0013133573279480058
# {'deployment_date': datetime.datetime(2022, 10, 17, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 10, 7, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.003605681200759565
# {'deployment_date': datetime.datetime(2022, 10, 24, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 10, 14, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0026241819475307845
# {'deployment_date': datetime.datetime(2022, 10, 31, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 10, 21, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.008057885845043938
# {'deployment_date': datetime.datetime(2022, 11, 7, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 10, 28, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0021074992316590497
# {'deployment_date': datetime.datetime(2022, 11, 14, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 11, 4, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.002334593937096983
# {'deployment_date': datetime.datetime(2022, 11, 21, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 11, 11, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0011556455648317663
# {'deployment_date': datetime.datetime(2022, 11, 28, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 11, 18, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.001979601231835167
# {'deployment_date': datetime.datetime(2022, 12, 5, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 11, 25, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0012543545334519318
# {'deployment_date': datetime.datetime(2022, 12, 12, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 12, 2, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0023663450530232535
# {'deployment_date': datetime.datetime(2022, 12, 19, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 12, 9, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.001157687988394735
# {'deployment_date': datetime.datetime(2022, 12, 26, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 12, 16, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.002567423583391052
# {'deployment_date': datetime.datetime(2023, 1, 2, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 12, 23, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0014859964782029907
# {'deployment_date': datetime.datetime(2023, 1, 9, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 12, 30, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.001192298236914897
# {'deployment_date': datetime.datetime(2023, 1, 16, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 1, 6, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0009134208801556496
# {'deployment_date': datetime.datetime(2023, 1, 23, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 1, 13, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0010088412060888633
# {'deployment_date': datetime.datetime(2023, 1, 30, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 1, 20, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0012499786637587642
# {'deployment_date': datetime.datetime(2023, 2, 6, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 1, 27, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0016236383443651494
# {'deployment_date': datetime.datetime(2023, 2, 13, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 2, 3, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0016223677416838964
# {'deployment_date': datetime.datetime(2023, 2, 20, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 2, 10, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0011724099063389502
# {'deployment_date': datetime.datetime(2023, 2, 27, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 2, 17, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0012806660200518623
# {'deployment_date': datetime.datetime(2023, 3, 6, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 2, 24, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0037441364523435835
# {'deployment_date': datetime.datetime(2023, 3, 13, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 3, 3, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0011117782044663446
# {'deployment_date': datetime.datetime(2023, 3, 20, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 3, 10, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0015561008565335847
# {'deployment_date': datetime.datetime(2023, 3, 27, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 3, 17, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0011821799981867154
# {'deployment_date': datetime.datetime(2023, 4, 3, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 3, 24, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0007096014995155298
# {'deployment_date': datetime.datetime(2023, 4, 10, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 3, 31, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0009410412626648426
# {'deployment_date': datetime.datetime(2023, 4, 17, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 4, 7, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0013880292647726288
# {'deployment_date': datetime.datetime(2023, 4, 24, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 4, 14, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.002499205861975023
# {'deployment_date': datetime.datetime(2023, 5, 1, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 4, 21, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0010444712706180394
# {'deployment_date': datetime.datetime(2023, 5, 8, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 4, 28, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.001399069219102948
# {'deployment_date': datetime.datetime(2023, 5, 15, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 5, 5, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0010613599246032375
# {'deployment_date': datetime.datetime(2023, 5, 22, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 5, 12, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0014187139660458861
# {'deployment_date': datetime.datetime(2023, 5, 29, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 5, 19, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0019632721018002616
# {'deployment_date': datetime.datetime(2023, 6, 5, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 5, 26, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0009422057209813944
# {'deployment_date': datetime.datetime(2023, 6, 12, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 6, 2, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0009779377009776983
# {'deployment_date': datetime.datetime(2023, 6, 19, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 6, 9, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0008434729912531235
# {'deployment_date': datetime.datetime(2023, 6, 26, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 6, 16, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.000776670009533354
# {'deployment_date': datetime.datetime(2023, 7, 3, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 6, 23, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0006873492165639186
# {'deployment_date': datetime.datetime(2023, 7, 10, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 6, 30, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0009636434132389432
# {'deployment_date': datetime.datetime(2023, 7, 17, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 7, 7, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0008078541301251623
# {'deployment_date': datetime.datetime(2023, 7, 24, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 7, 14, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0006945058823179561
# {'deployment_date': datetime.datetime(2023, 7, 31, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 7, 21, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.00426802233219581
# {'deployment_date': datetime.datetime(2023, 8, 7, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 7, 28, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0028655970641754485
# {'deployment_date': datetime.datetime(2023, 8, 14, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 8, 4, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.001104746195414105
# {'deployment_date': datetime.datetime(2023, 8, 21, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 8, 11, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.000696898235326907
# {'deployment_date': datetime.datetime(2023, 8, 28, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 8, 18, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0008319752852826461
# {'deployment_date': datetime.datetime(2023, 9, 4, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 8, 25, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0008120433379010747
# {'deployment_date': datetime.datetime(2023, 9, 11, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 9, 1, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.000980323762312623
# {'deployment_date': datetime.datetime(2023, 9, 18, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 9, 8, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0010961921826401837
# {'deployment_date': datetime.datetime(2023, 9, 25, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 9, 15, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0006861509989508982
# {'deployment_date': datetime.datetime(2023, 10, 2, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 9, 22, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0010762006154349
# {'deployment_date': datetime.datetime(2023, 10, 9, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 9, 29, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>)}
# MSE: 0.0011072904535577152

# %%
# data = pull_training_data_local(datetime(2023,9,23,tzinfo=pytz.timezone('US/Eastern')), datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')))

# %%
# data['three_max'].describe(percentiles=[.25,.4,.6,.9,.95,.99])

# %%
# def run_temporal_simulation(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date):
#     mse_list = []
    
#     hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
#     dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
#     # date = dates_list[-1]
#     # response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
#     for date in dates_list:
#         mse = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams)
#         mse_list.append(mse)

#     return mse_list

# %%
# number_of_simulations = 15
# now = datetime.now()
# title = 'BFP3d_reg'
# total_feature_list = ['hour','year','month','day_of_month',
#        'price7', 'price14', 'adjusted_volume', 'vol7', 'vol14',
#        'rsi', 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close',
#        'oneD_returns_close', 'range_vol', 'range_vol5MA', 'range_vol10MA',
#        'range_vol25MA', 'oneD_stddev50', 'threeD_stddev50', 'cmf',
#        'close_diff', 'close_diff3', 'close_diff5', 'v_diff_pct', 'adx',
#        'volume_10MA', 'volume_25MA', 'price_10MA', 'price_25MA',
#        'volume_10DDiff', 'volume_25DDiff', 'price_10DDiff', 'price_25DDiff',
#        'day_of_week','close_diff_deviation3','close_diff_deviation','roc_diff','range_vol_diff5',
#        'return_vol_240M', 'volume_vol_240M', 'return_vol_450M', 'volume_vol_450M', 'min_vol_diff', 'min_vol_diff_pct', 'min_volume_vol_diff', 
#        'min_volume_vol_diff_pct', 'return_vol_8H', 'return_vol_16H', 'volume_vol_8H', 'volume_vol_16H', 'hour_vol_diff', 'hour_vol_diff_pct', 'hour_volume_vol_diff', 
#        'hour_volume_vol_diff_pct', 'return_vol_5D', 'return_vol_10D', 'return_vol_30D', 'volume_vol_5D', 'volume_vol_10D', 'volume_vol_30D', 'daily_vol_diff', 'daily_vol_diff_pct',
#        'daily_vol_diff30', 'daily_vol_diff_pct30', 'daily_volume_vol_diff', 'daily_volume_vol_diff_pct', 'daily_volume_vol_diff30', 'daily_volume_vol_diff_pct30']
# testing_features = ['hour','month','day_of_month','price7', 
#        'rsi', 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close',
#        'oneD_returns_close', 'range_vol', 'oneD_stddev50', 'threeD_stddev50', 'cmf',
#        'close_diff', 'close_diff3', 'close_diff5', 'v_diff_pct', 'adx',
#        'price_10DDiff', 'price_25DDiff',
#        'day_of_week','close_diff_deviation3','close_diff_deviation','roc_diff','range_vol_diff5',
#         'return_vol_240M', 'volume_vol_240M', 'return_vol_450M', 'volume_vol_450M', 'min_vol_diff', 'min_vol_diff_pct', 'min_volume_vol_diff', 
#        'min_volume_vol_diff_pct', 'return_vol_8H', 'return_vol_16H', 'volume_vol_8H', 'volume_vol_16H', 'hour_vol_diff', 'hour_vol_diff_pct', 'hour_volume_vol_diff', 
#        'hour_volume_vol_diff_pct', 'return_vol_5D', 'return_vol_10D', 'return_vol_30D', 'volume_vol_5D', 'volume_vol_10D', 'volume_vol_30D', 'daily_vol_diff', 'daily_vol_diff_pct',
#        'daily_vol_diff30', 'daily_vol_diff_pct30', 'daily_volume_vol_diff', 'daily_volume_vol_diff_pct', 'daily_volume_vol_diff30', 'daily_volume_vol_diff_pct30', 'return_vol_15M',
#        'volume_vol_15M','return_vol_30M','volume_vol_30M','return_vol_60M','volume_vol_60M','15min_vol_diff_pct','return_vol_3D','volume_vol_3D','return_vol_4H','volume_vol_4H', 'SPY_diff',
#        'SPY_diff3', 'SPY_diff5', 'SPY_1D', 'SPY_3D', 'SPY_5D',]
# target_label = 'three_min'
# target_value = -.025
# results_array = []

# i = 0
# i = 0
# while i < number_of_simulations:
#        model_name = f"{title}_temporal_simulation_{i}"
#        print(model_name)
#        random_int = random.randint(24, 40)
#        features = random.sample(testing_features, random_int)
#        print(features)
#        mse_list = run_temporal_simulation(features, target_label, "target_value", dataset_start_date=datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')), evaluation_start_date=datetime(2022,10,24,tzinfo=pytz.timezone('US/Eastern')), evaluation_end_date=datetime(2023,10,2,tzinfo=pytz.timezone('US/Eastern')))        
#        mse = sum(mse_list)/len(mse_list)
#        print(mse)
#        print()
#        results_array.append({"model_name": model_name, "features": features, "mse_avg": mse, "num_features": random_int})
#        i += 1

# results_df = pd.DataFrame(results_array)
# results_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
