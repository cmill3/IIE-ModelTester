# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler
import pytz

# %%
s3 = boto3.client('s3')

training_bucket = "icarus-research-data"

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

weekly_expiries = ['SPY', 'IVV', 'QQQ', 'GLD', 'IWM', 'EFA', 'XLK', 'XLV', 'TLT', 'LQD', 'XLE', 'MMM', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 
                   'AAP', 'AFL', 'ALB', 'ALGN', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMD', 'AAL', 'AXP', 'AIG', 'ABC', 'AMGN', 'ADI', 'APA', 'AAPL', 'AMAT', 'ANET', 'T', 'ADSK', 'BAC', 'BBWI', 'BAX', 'BBY', 'BIIB', 
                   'BLK', 'BA', 'BKNG', 'BMY', 'AVGO', 'CZR', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CAT', 'CBOE', 'CNC', 'CF', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CI', 'CSCO', 'C', 'CLX', 'CME', 'KO', 'CMCSA', 'CMA', 'CAG', 
                   'COP', 'STZ', 'GLW', 'COST', 'CTRA', 'CSX', 'CVS', 'DHI', 'DHR', 'DE', 'DAL', 'DVN', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'DPZ', 'DOW', 'DD', 'EBAY', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'EOG', 'EQT', 
                   'ETSY', 'EXPE', 'XOM', 'FDX', 'FITB', 'FSLR', 'FI', 'F', 'FTNT', 'FOXA', 'FCX', 'GEHC', 'GNRC', 'GD', 'GE', 'GM', 'GILD', 'GS', 'HAL', 'HSY', 'HES', 'HD', 'HON', 'HRL', 'HPQ', 'HUM', 'HBAN', 'IBM', 'ILMN', 
                   'INTC', 'IP', 'INTU', 'ISRG', 'JNJ', 'JPM', 'JNPR', 'KEY', 'KMB', 'KMI', 'KLAC', 'KHC', 'KR', 'LRCX', 'LVS', 'LEN', 'LMT', 'LOW', 'MRO', 'MPC', 'MAR', 'MA', 'MTCH', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 
                   'MGM', 'MU', 'MSFT', 'MRNA', 'MDLZ', 'MS', 'MOS', 'NTAP', 'NFLX', 'NEM', 'NKE', 'NSC', 'NOC', 'NCLH', 'NUE', 'NVDA', 'NXPI', 'OXY', 'ON', 'ORCL', 'PARA', 'PYPL', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PXD', 'PNC', 
                   'PPG', 'PG', 'PHM', 'QCOM', 'RTX', 'REGN', 'ROST', 'RCL', 'SPGI', 'CRM', 'SLB', 'STX', 'NOW', 'SWKS', 'SEDG', 'SO', 'LUV', 'SBUX', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TGT', 'TSLA', 'TXN', 'TMO', 'TJX', 'TSCO', 'TFC', 
                   'TSN', 'USB', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'VLO', 'VZ', 'VRTX', 'VFC', 'V', 'WBA', 'WMT', 'WBD', 'WM', 'WFC', 'WDC', 'WHR', 'WMB', 'WYNN', 'ZION']
leveraged_etfs = ["TQQQ","SQQQ","SPXS","SPXL","SOXL","SOXS"]
high_vol = ['COIN','BILI','UPST','CVNA',"TQQQ","SQQQ","SPXS","SPXL","SOXL","SOXS","NIO","BABA","ROKU","RBLX","SE","SNAP","LCID",'RIVN',"BIDU","FUTU","TSLA","JD","HOOD","CHWY"]
expensive = ["CMG","NFLX","AVGO","BKNG","ABNB"]
indexes = ['QQQ','IWM','TLT','SPY','VXX']

# %%
def create_training_data_local(key_list, prefix, bucket_name, alert_type, start_date, end_date):
    df_list = []
    hours = [10,11,12,13,14,15]
    start = start_date.split(' ')[0]
    end = end_date.split(' ')[0]
    # print(file_key)
    for key in key_list:
        for hour in hours:
            try:
                data = s3.get_object(Bucket=bucket_name, Key=f'{prefix}{key}/{alert_type}/{hour}.csv')
                df = pd.read_csv(data.get("Body")) 
                df = df.tail(15)
                df_list.append(df)
                # df['hour'] = hour
            except:
                continue

    data = pd.concat(df_list)
    # data = data.loc[~data['symbol'].isin(index)]
    # data = data.loc[~data['symbol'].isin(laggards)]
    data.reset_index(drop=True, inplace=True)

    # data['date'] = pd.to_datetime(data['date'])
    # data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek)
    # data = data.round(3)
    data.replace([np.inf, -np.inf], 0, inplace=True)

    data.to_csv(f'/Users/charlesmiller/Documents/LOSE/{start}_{end}.csv', index=False)

    return data

def pull_training_data_local(end_date,start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/LOSE/2018-01-01_2023-12-23_trainTL15.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data = data.loc[~data['symbol'].isin(high_vol)]
    data = data.loc[~data['symbol'].isin(expensive)]
    data = data.loc[~data['symbol'].isin(leveraged_etfs)]
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data


def pull_validation_data_local(end_date,start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/LOSE/2018-01-01_2023-12-23_validationTL15.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[~data['symbol'].isin(high_vol)]
    data = data.loc[~data['symbol'].isin(expensive)]
    data = data.loc[~data['symbol'].isin(leveraged_etfs)]
    data = data.loc[data['dt'] <= end_date]
    data = data.loc[data['dt'] >= start_date]
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data

# %%
def build_date_list(start_date, end_date):
    print(start_date, end_date)
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_validation_dates_local(deployment_date):
    end_date = deployment_date + timedelta(days=5)
    return end_date

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] < target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] < target_value).astype(int)

    # dataset = dataset.round(3)
    # validation_dataset = validation_dataset.round(3)

    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']


    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    print(y.value_counts())
    predictions = xgb_model.predict(X_validate)
    probabilities = xgb_model.predict_proba(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,str(fi_list), predictions, probabilities


def train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] < target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] < target_value).astype(int)

    dataset = dataset.round(5)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']
    

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,"str(fi_list)", predictions, "probabilities"

# %%
def model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile,start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
    validation_end_date = build_validation_dates_local(deployment_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    target_value = dataset[target_label].quantile(target_percentile).round(3)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
    validation_dataset['probabilities'] = probabilities[:,1]
    validation_dataset['predictions'] = predictions
    validation_dataset['target_value'] = target_value
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    return response

def model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,end_date,deployment_date,hyperparams):
    validation_end_date = build_validation_dates_local(deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    return tp, fp, fn, tn 

def model_runner_data(start_date,end_date,):
    dates = build_date_list(start_date, end_date)
    key_list = build_query_keys(dates)
    print(key_list[-1])
    dataset = create_training_data_local(key_list, 'bf_alerts/', 'inv-alerts', 'losers', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
    return dataset

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=10),
            "dataset_start": datetime(2018,1,1)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

# %%
title = 'LOSERS_1d'
target_percentile = 0.45
model_name = f'{title}:TSSIM1_TL15-EXP_custHypTP{target_percentile}'
dataset_name = f'TSSIM1_TL15-EXP_custHypTP{target_percentile}'
hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
features = ['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 
            'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 
            'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 
            'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']

target_label = 'one_min'

dataset_start_date = datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')) 
dates_list = build_evaluation_period(datetime(2022,10,3), datetime(2023,12,23))

# date = dates_list[-1]
# print(date)
# response = model_runner_data(start_date=datetime(2018,1,1),end_date=datetime(2023,10,28))

# dataset = pull_training_data_local(start_date=datetime(2018,1,1),end_date=datetime(2023,10,28))
# print(dataset['one_min'].describe())

for date in dates_list:
    print(date)
    response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile,"dataset_start_date",date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])
# Out:
# {'deployment_date': datetime.datetime(2022, 10, 3, 0, 0), 'dataset_end': datetime.datetime(2022, 9, 23, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    58478
# 1    46254
# Name: count, dtype: int64
# 178 102 48 90
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2022-10-03', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 178, 'TPpct': Decimal('0'), 'FP': 102, 'FPpct': Decimal('0'), 'TN': 48, 'TNpct': Decimal('0'), 'FN': 90, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.7450980392156863'), 'evaluation_timeperiod': '2022-10-03_2022-10-07', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026665574}, {'daily_vol_diff_pct30': 0.026796289}, {'return_vol_450M': 0.18086036}, {'range_vol': 0.033822544}, {'roc5': 0.029100392}, {'range_vol_diff5': 0.025999548}, {'day_of_week': 0.033183344}, {'close_diff_deviation': 0.026832122}, {'SPY_diff3': 0.029175993}, {'price_10DDiff': 0.027279466}, {'SPY_1D': 0.03243959}, {'min_volume_vol_diff_pct': 0.022138828}, {'return_vol_240M': 0.04670905}, {'month': 0.0370623}, {'close_diff': 0.029212177}, {'roc': 0.027150638}, {'SPY_3D': 0.033834662}, {'hour_volume_vol_diff_pct': 0.024045682}, {'daily_vol_diff30': 0.02927746}, {'oneD_stddev50': 0.028024295}, {'SPY_diff5': 0.02942158}, {'threeD_stddev50': 0.02905564}, {'daily_volume_vol_diff_pct': 0.024282921}, {'roc_diff': 0.028220087}, {'price7': 0.02738839}, {'min_vol_diff': 0.024948446}, {'daily_volume_vol_diff_pct30': 0.025601674}, {'return_vol_10D': 0.034116875}, {'SPY_diff': 0.027354155}]"}
# {'deployment_date': datetime.datetime(2022, 10, 10, 0, 0), 'dataset_end': datetime.datetime(2022, 9, 30, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    58686
# 1    46490
# Name: count, dtype: int64
# 240 96 25 52
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2022-10-10', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 240, 'TPpct': Decimal('0'), 'FP': 96, 'FPpct': Decimal('0'), 'TN': 25, 'TNpct': Decimal('0'), 'FN': 52, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.5'), 'evaluation_timeperiod': '2022-10-10_2022-10-14', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026258936}, {'daily_vol_diff_pct30': 0.027098415}, {'return_vol_450M': 0.17065232}, {'range_vol': 0.032208264}, {'roc5': 0.030073892}, {'range_vol_diff5': 0.026909351}, {'day_of_week': 0.034070008}, {'close_diff_deviation': 0.027224643}, {'SPY_diff3': 0.028355896}, {'price_10DDiff': 0.02698472}, {'SPY_1D': 0.03268607}, {'min_volume_vol_diff_pct': 0.022536015}, {'return_vol_240M': 0.052508835}, {'month': 0.037578505}, {'close_diff': 0.030191576}, {'roc': 0.026879836}, {'SPY_3D': 0.03471483}, {'hour_volume_vol_diff_pct': 0.024469065}, {'daily_vol_diff30': 0.0292839}, {'oneD_stddev50': 0.02856999}, {'SPY_diff5': 0.029938351}, {'threeD_stddev50': 0.02916966}, {'daily_volume_vol_diff_pct': 0.02415943}, {'roc_diff': 0.027795825}, {'price7': 0.02778876}, {'min_vol_diff': 0.025128763}, {'daily_volume_vol_diff_pct30': 0.02527266}, {'return_vol_10D': 0.03295661}, {'SPY_diff': 0.02853487}]"}
# {'deployment_date': datetime.datetime(2022, 10, 17, 0, 0), 'dataset_end': datetime.datetime(2022, 10, 7, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    58873
# 1    46746
# Name: count, dtype: int64
# 96 142 115 60
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2022-10-17', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 96, 'TPpct': Decimal('0'), 'FP': 142, 'FPpct': Decimal('0'), 'TN': 115, 'TNpct': Decimal('0'), 'FN': 60, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.676056338028169'), 'evaluation_timeperiod': '2022-10-17_2022-10-21', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026287057}, {'daily_vol_diff_pct30': 0.02679784}, {'return_vol_450M': 0.17514925}, {'range_vol': 0.032777112}, {'roc5': 0.030067619}, {'range_vol_diff5': 0.026901167}, {'day_of_week': 0.03459126}, {'close_diff_deviation': 0.026883682}, {'SPY_diff3': 0.027900767}, {'price_10DDiff': 0.026804784}, {'SPY_1D': 0.033302095}, {'min_volume_vol_diff_pct': 0.02233682}, {'return_vol_240M': 0.051041156}, {'month': 0.036518894}, {'close_diff': 0.030796727}, {'roc': 0.027665665}, {'SPY_3D': 0.034418367}, {'hour_volume_vol_diff_pct': 0.024977714}, {'daily_vol_diff30': 0.02797374}, {'oneD_stddev50': 0.029411448}, {'SPY_diff5': 0.029735634}, {'threeD_stddev50': 0.027886346}, {'daily_volume_vol_diff_pct': 0.023819776}, {'roc_diff': 0.027988587}, {'price7': 0.027573602}, {'min_vol_diff': 0.025002839}, {'daily_volume_vol_diff_pct30': 0.02441481}, {'return_vol_10D': 0.033234246}, {'SPY_diff': 0.027741082}]"}
# {'deployment_date': datetime.datetime(2022, 10, 24, 0, 0), 'dataset_end': datetime.datetime(2022, 10, 14, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    58990
# 1    47064
# Name: count, dtype: int64
# 110 143 101 48
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2022-10-24', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 110, 'TPpct': Decimal('0'), 'FP': 143, 'FPpct': Decimal('0'), 'TN': 101, 'TNpct': Decimal('0'), 'FN': 48, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.7692307692307693'), 'evaluation_timeperiod': '2022-10-24_2022-10-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.027439587}, {'daily_vol_diff_pct30': 0.026500281}, {'return_vol_450M': 0.16897711}, {'range_vol': 0.032137554}, {'roc5': 0.029324576}, {'range_vol_diff5': 0.02703001}, {'day_of_week': 0.03394003}, {'close_diff_deviation': 0.027776338}, {'SPY_diff3': 0.029138684}, {'price_10DDiff': 0.027853474}, {'SPY_1D': 0.032969426}, {'min_volume_vol_diff_pct': 0.02203274}, {'return_vol_240M': 0.05307851}, {'month': 0.036831036}, {'close_diff': 0.031440333}, {'roc': 0.027882604}, {'SPY_3D': 0.03425724}, {'hour_volume_vol_diff_pct': 0.024953393}, {'daily_vol_diff30': 0.028573168}, {'oneD_stddev50': 0.027719151}, {'SPY_diff5': 0.029825995}, {'threeD_stddev50': 0.028364526}, {'daily_volume_vol_diff_pct': 0.023773385}, {'roc_diff': 0.028100407}, {'price7': 0.027567117}, {'min_vol_diff': 0.02527991}, {'daily_volume_vol_diff_pct30': 0.024973249}, {'return_vol_10D': 0.03466351}, {'SPY_diff': 0.027596774}]"}
# {'deployment_date': datetime.datetime(2022, 10, 31, 0, 0), 'dataset_end': datetime.datetime(2022, 10, 21, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    59260
# 1    47235
# Name: count, dtype: int64
# 120 67 81 123
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2022-10-31', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 120, 'TPpct': Decimal('0'), 'FP': 67, 'FPpct': Decimal('0'), 'TN': 81, 'TNpct': Decimal('0'), 'FN': 123, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.791044776119403'), 'evaluation_timeperiod': '2022-10-31_2022-11-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026799975}, {'daily_vol_diff_pct30': 0.027290545}, {'return_vol_450M': 0.17854606}, {'range_vol': 0.032293238}, {'roc5': 0.029570704}, {'range_vol_diff5': 0.025333475}, {'day_of_week': 0.034086198}, {'close_diff_deviation': 0.02727738}, {'SPY_diff3': 0.02895654}, {'price_10DDiff': 0.027774047}, {'SPY_1D': 0.033539303}, {'min_volume_vol_diff_pct': 0.022186875}, {'return_vol_240M': 0.04661894}, {'month': 0.03640139}, {'close_diff': 0.03157513}, {'roc': 0.027840938}, {'SPY_3D': 0.03490147}, {'hour_volume_vol_diff_pct': 0.024317205}, {'daily_vol_diff30': 0.027162204}, {'oneD_stddev50': 0.02827222}, {'SPY_diff5': 0.029517798}, {'threeD_stddev50': 0.029725557}, {'daily_volume_vol_diff_pct': 0.024135873}, {'roc_diff': 0.027735226}, {'price7': 0.0276812}, {'min_vol_diff': 0.024315529}, {'daily_volume_vol_diff_pct30': 0.025464958}, {'return_vol_10D': 0.03322639}, {'SPY_diff': 0.027453654}]"}
# {'deployment_date': datetime.datetime(2022, 11, 7, 0, 0), 'dataset_end': datetime.datetime(2022, 10, 28, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    59538
# 1    47388
# Name: count, dtype: int64
# 50 75 180 102
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2022-11-07', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 50, 'TPpct': Decimal('0'), 'FP': 75, 'FPpct': Decimal('0'), 'TN': 180, 'TNpct': Decimal('0'), 'FN': 102, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6666666666666666'), 'evaluation_timeperiod': '2022-11-07_2022-11-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026437297}, {'daily_vol_diff_pct30': 0.027285475}, {'return_vol_450M': 0.1738613}, {'range_vol': 0.03153922}, {'roc5': 0.028559988}, {'range_vol_diff5': 0.026858902}, {'day_of_week': 0.0336148}, {'close_diff_deviation': 0.026635548}, {'SPY_diff3': 0.028639635}, {'price_10DDiff': 0.027180947}, {'SPY_1D': 0.0336081}, {'min_volume_vol_diff_pct': 0.022496384}, {'return_vol_240M': 0.05782096}, {'month': 0.036690265}, {'close_diff': 0.03069191}, {'roc': 0.027483571}, {'SPY_3D': 0.034237463}, {'hour_volume_vol_diff_pct': 0.024490194}, {'daily_vol_diff30': 0.028089056}, {'oneD_stddev50': 0.02971729}, {'SPY_diff5': 0.029136077}, {'threeD_stddev50': 0.028174581}, {'daily_volume_vol_diff_pct': 0.023383984}, {'roc_diff': 0.026698813}, {'price7': 0.02708801}, {'min_vol_diff': 0.024973327}, {'daily_volume_vol_diff_pct30': 0.02569388}, {'return_vol_10D': 0.031969566}, {'SPY_diff': 0.02694351}]"}
# {'deployment_date': datetime.datetime(2022, 11, 14, 0, 0), 'dataset_end': datetime.datetime(2022, 11, 4, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    59730
# 1    47626
# Name: count, dtype: int64
# 167 44 65 149
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2022-11-14', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 167, 'TPpct': Decimal('0'), 'FP': 44, 'FPpct': Decimal('0'), 'TN': 65, 'TNpct': Decimal('0'), 'FN': 149, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.7954545454545454'), 'evaluation_timeperiod': '2022-11-14_2022-11-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026945736}, {'daily_vol_diff_pct30': 0.026167126}, {'return_vol_450M': 0.1667357}, {'range_vol': 0.032084394}, {'roc5': 0.02964369}, {'range_vol_diff5': 0.026419371}, {'day_of_week': 0.03307972}, {'close_diff_deviation': 0.026367579}, {'SPY_diff3': 0.02855648}, {'price_10DDiff': 0.027276527}, {'SPY_1D': 0.03372796}, {'min_volume_vol_diff_pct': 0.022762185}, {'return_vol_240M': 0.058382865}, {'month': 0.036240432}, {'close_diff': 0.029937694}, {'roc': 0.028337255}, {'SPY_3D': 0.034930885}, {'hour_volume_vol_diff_pct': 0.025203453}, {'daily_vol_diff30': 0.028717399}, {'oneD_stddev50': 0.029348344}, {'SPY_diff5': 0.029105067}, {'threeD_stddev50': 0.028027233}, {'daily_volume_vol_diff_pct': 0.024695396}, {'roc_diff': 0.027491406}, {'price7': 0.027414478}, {'min_vol_diff': 0.024586754}, {'daily_volume_vol_diff_pct30': 0.025375728}, {'return_vol_10D': 0.03307775}, {'SPY_diff': 0.029361432}]"}
# {'deployment_date': datetime.datetime(2022, 11, 21, 0, 0), 'dataset_end': datetime.datetime(2022, 11, 11, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    59955
# 1    47840
# Name: count, dtype: int64
# 45 66 159 58
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2022-11-21', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 45, 'TPpct': Decimal('0'), 'FP': 66, 'FPpct': Decimal('0'), 'TN': 159, 'TNpct': Decimal('0'), 'FN': 58, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6818181818181818'), 'evaluation_timeperiod': '2022-11-21_2022-11-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026408814}, {'daily_vol_diff_pct30': 0.027328108}, {'return_vol_450M': 0.17305714}, {'range_vol': 0.03261477}, {'roc5': 0.029241912}, {'range_vol_diff5': 0.026472049}, {'day_of_week': 0.033796076}, {'close_diff_deviation': 0.02577896}, {'SPY_diff3': 0.02947884}, {'price_10DDiff': 0.026588285}, {'SPY_1D': 0.03330649}, {'min_volume_vol_diff_pct': 0.022200707}, {'return_vol_240M': 0.055050366}, {'month': 0.03660417}, {'close_diff': 0.029609663}, {'roc': 0.027731579}, {'SPY_3D': 0.034963023}, {'hour_volume_vol_diff_pct': 0.024262412}, {'daily_vol_diff30': 0.027487347}, {'oneD_stddev50': 0.028843023}, {'SPY_diff5': 0.028856218}, {'threeD_stddev50': 0.028523471}, {'daily_volume_vol_diff_pct': 0.024421131}, {'roc_diff': 0.027904823}, {'price7': 0.027679533}, {'min_vol_diff': 0.024532178}, {'daily_volume_vol_diff_pct30': 0.024947334}, {'return_vol_10D': 0.03434835}, {'SPY_diff': 0.027963247}]"}
# {'deployment_date': datetime.datetime(2022, 11, 28, 0, 0), 'dataset_end': datetime.datetime(2022, 11, 18, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    60114
# 1    48110
# Name: count, dtype: int64
# 97 58 145 114
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2022-11-28', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 97, 'TPpct': Decimal('0'), 'FP': 58, 'FPpct': Decimal('0'), 'TN': 145, 'TNpct': Decimal('0'), 'FN': 114, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.6724137931034482'), 'evaluation_timeperiod': '2022-11-28_2022-12-02', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026952045}, {'daily_vol_diff_pct30': 0.027451651}, {'return_vol_450M': 0.1658874}, {'range_vol': 0.031877838}, {'roc5': 0.028061213}, {'range_vol_diff5': 0.026921427}, {'day_of_week': 0.03399169}, {'close_diff_deviation': 0.026938353}, {'SPY_diff3': 0.029175136}, {'price_10DDiff': 0.026322154}, {'SPY_1D': 0.03289095}, {'min_volume_vol_diff_pct': 0.02234318}, {'return_vol_240M': 0.06286507}, {'month': 0.03590417}, {'close_diff': 0.031818274}, {'roc': 0.02695187}, {'SPY_3D': 0.033368018}, {'hour_volume_vol_diff_pct': 0.02456637}, {'daily_vol_diff30': 0.02774297}, {'oneD_stddev50': 0.02841094}, {'SPY_diff5': 0.029301638}, {'threeD_stddev50': 0.0286862}, {'daily_volume_vol_diff_pct': 0.024649391}, {'roc_diff': 0.02763165}, {'price7': 0.027272316}, {'min_vol_diff': 0.02508001}, {'daily_volume_vol_diff_pct30': 0.025532182}, {'return_vol_10D': 0.033556152}, {'SPY_diff': 0.027849613}]"}
# {'deployment_date': datetime.datetime(2022, 12, 5, 0, 0), 'dataset_end': datetime.datetime(2022, 11, 25, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    60360
# 1    48213
# Name: count, dtype: int64
# 77 87 161 101
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2022-12-05', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 77, 'TPpct': Decimal('0'), 'FP': 87, 'FPpct': Decimal('0'), 'TN': 161, 'TNpct': Decimal('0'), 'FN': 101, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8850574712643678'), 'evaluation_timeperiod': '2022-12-05_2022-12-09', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026652321}, {'daily_vol_diff_pct30': 0.026576342}, {'return_vol_450M': 0.16430277}, {'range_vol': 0.03268877}, {'roc5': 0.028786814}, {'range_vol_diff5': 0.026614388}, {'day_of_week': 0.03518631}, {'close_diff_deviation': 0.026518399}, {'SPY_diff3': 0.028839868}, {'price_10DDiff': 0.027456041}, {'SPY_1D': 0.03393052}, {'min_volume_vol_diff_pct': 0.022723729}, {'return_vol_240M': 0.059741862}, {'month': 0.035821326}, {'close_diff': 0.030419586}, {'roc': 0.027441964}, {'SPY_3D': 0.03493503}, {'hour_volume_vol_diff_pct': 0.024563394}, {'daily_vol_diff30': 0.028077556}, {'oneD_stddev50': 0.027661223}, {'SPY_diff5': 0.029435175}, {'threeD_stddev50': 0.028027093}, {'daily_volume_vol_diff_pct': 0.024430089}, {'roc_diff': 0.028559074}, {'price7': 0.027841315}, {'min_vol_diff': 0.025053646}, {'daily_volume_vol_diff_pct30': 0.025518492}, {'return_vol_10D': 0.033616014}, {'SPY_diff': 0.028580936}]"}
# {'deployment_date': datetime.datetime(2022, 12, 12, 0, 0), 'dataset_end': datetime.datetime(2022, 12, 2, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    60595
# 1    48421
# Name: count, dtype: int64
# 180 57 88 90
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2022-12-12', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 180, 'TPpct': Decimal('0'), 'FP': 57, 'FPpct': Decimal('0'), 'TN': 88, 'TNpct': Decimal('0'), 'FN': 90, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.1578947368421053'), 'evaluation_timeperiod': '2022-12-12_2022-12-16', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026446061}, {'daily_vol_diff_pct30': 0.027037002}, {'return_vol_450M': 0.17524043}, {'range_vol': 0.031811524}, {'roc5': 0.028595502}, {'range_vol_diff5': 0.026162004}, {'day_of_week': 0.033776715}, {'close_diff_deviation': 0.02700044}, {'SPY_diff3': 0.02914247}, {'price_10DDiff': 0.026842542}, {'SPY_1D': 0.03243796}, {'min_volume_vol_diff_pct': 0.022651866}, {'return_vol_240M': 0.055393204}, {'month': 0.03659348}, {'close_diff': 0.030030832}, {'roc': 0.027112901}, {'SPY_3D': 0.03470127}, {'hour_volume_vol_diff_pct': 0.024843374}, {'daily_vol_diff30': 0.027786039}, {'oneD_stddev50': 0.028390512}, {'SPY_diff5': 0.029341927}, {'threeD_stddev50': 0.029037045}, {'daily_volume_vol_diff_pct': 0.024606083}, {'roc_diff': 0.027918879}, {'price7': 0.027459543}, {'min_vol_diff': 0.024202067}, {'daily_volume_vol_diff_pct30': 0.025042035}, {'return_vol_10D': 0.032491855}, {'SPY_diff': 0.027904522}]"}
# {'deployment_date': datetime.datetime(2022, 12, 19, 0, 0), 'dataset_end': datetime.datetime(2022, 12, 9, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    60806
# 1    48658
# Name: count, dtype: int64
# 98 97 93 118
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2022-12-19', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 98, 'TPpct': Decimal('0'), 'FP': 97, 'FPpct': Decimal('0'), 'TN': 93, 'TNpct': Decimal('0'), 'FN': 118, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0103092783505154'), 'evaluation_timeperiod': '2022-12-19_2022-12-23', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026685668}, {'daily_vol_diff_pct30': 0.026506307}, {'return_vol_450M': 0.17559531}, {'range_vol': 0.032457598}, {'roc5': 0.029469082}, {'range_vol_diff5': 0.026165156}, {'day_of_week': 0.03339185}, {'close_diff_deviation': 0.026628304}, {'SPY_diff3': 0.02899775}, {'price_10DDiff': 0.027298754}, {'SPY_1D': 0.032569196}, {'min_volume_vol_diff_pct': 0.022323756}, {'return_vol_240M': 0.055046037}, {'month': 0.036320094}, {'close_diff': 0.030332396}, {'roc': 0.028047984}, {'SPY_3D': 0.03400038}, {'hour_volume_vol_diff_pct': 0.024823382}, {'daily_vol_diff30': 0.027410757}, {'oneD_stddev50': 0.027773622}, {'SPY_diff5': 0.029645195}, {'threeD_stddev50': 0.02768926}, {'daily_volume_vol_diff_pct': 0.024273762}, {'roc_diff': 0.028641315}, {'price7': 0.027712421}, {'min_vol_diff': 0.024330005}, {'daily_volume_vol_diff_pct30': 0.024888184}, {'return_vol_10D': 0.032720182}, {'SPY_diff': 0.028256256}]"}
# {'deployment_date': datetime.datetime(2022, 12, 26, 0, 0), 'dataset_end': datetime.datetime(2022, 12, 16, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    60981
# 1    48921
# Name: count, dtype: int64
# 54 118 114 60
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2022-12-26', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 54, 'TPpct': Decimal('0'), 'FP': 118, 'FPpct': Decimal('0'), 'TN': 114, 'TNpct': Decimal('0'), 'FN': 60, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.4576271186440678'), 'evaluation_timeperiod': '2022-12-26_2022-12-30', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.027009182}, {'daily_vol_diff_pct30': 0.026440702}, {'return_vol_450M': 0.17452224}, {'range_vol': 0.03169226}, {'roc5': 0.028956385}, {'range_vol_diff5': 0.025259808}, {'day_of_week': 0.03420484}, {'close_diff_deviation': 0.027100878}, {'SPY_diff3': 0.027867582}, {'price_10DDiff': 0.02766225}, {'SPY_1D': 0.033323046}, {'min_volume_vol_diff_pct': 0.02268194}, {'return_vol_240M': 0.0555953}, {'month': 0.03614819}, {'close_diff': 0.030536408}, {'roc': 0.027883258}, {'SPY_3D': 0.0345396}, {'hour_volume_vol_diff_pct': 0.02440006}, {'daily_vol_diff30': 0.028435221}, {'oneD_stddev50': 0.028727984}, {'SPY_diff5': 0.029505847}, {'threeD_stddev50': 0.028212577}, {'daily_volume_vol_diff_pct': 0.024652017}, {'roc_diff': 0.028742086}, {'price7': 0.028151574}, {'min_vol_diff': 0.024112584}, {'daily_volume_vol_diff_pct30': 0.02507199}, {'return_vol_10D': 0.031655937}, {'SPY_diff': 0.026908293}]"}
# {'deployment_date': datetime.datetime(2023, 1, 2, 0, 0), 'dataset_end': datetime.datetime(2022, 12, 23, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    61213
# 1    49113
# Name: count, dtype: int64
# 76 93 95 55
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-01-02', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 76, 'TPpct': Decimal('0'), 'FP': 93, 'FPpct': Decimal('0'), 'TN': 95, 'TNpct': Decimal('0'), 'FN': 55, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8172043010752689'), 'evaluation_timeperiod': '2023-01-02_2023-01-06', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026481438}, {'daily_vol_diff_pct30': 0.027035227}, {'return_vol_450M': 0.18034175}, {'range_vol': 0.03292976}, {'roc5': 0.029787717}, {'range_vol_diff5': 0.026518967}, {'day_of_week': 0.03361398}, {'close_diff_deviation': 0.02689635}, {'SPY_diff3': 0.029297356}, {'price_10DDiff': 0.02841211}, {'SPY_1D': 0.03288163}, {'min_volume_vol_diff_pct': 0.022539593}, {'return_vol_240M': 0.045871288}, {'month': 0.035522226}, {'close_diff': 0.030297957}, {'roc': 0.027691228}, {'SPY_3D': 0.034053996}, {'hour_volume_vol_diff_pct': 0.024959985}, {'daily_vol_diff30': 0.028116813}, {'oneD_stddev50': 0.028571844}, {'SPY_diff5': 0.029802922}, {'threeD_stddev50': 0.028554864}, {'daily_volume_vol_diff_pct': 0.024264734}, {'roc_diff': 0.02857703}, {'price7': 0.028145473}, {'min_vol_diff': 0.024561472}, {'daily_volume_vol_diff_pct30': 0.024437336}, {'return_vol_10D': 0.031089626}, {'SPY_diff': 0.028745381}]"}
# {'deployment_date': datetime.datetime(2023, 1, 9, 0, 0), 'dataset_end': datetime.datetime(2022, 12, 30, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    61482
# 1    49191
# Name: count, dtype: int64
# 16 68 281 47
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-01-09', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 16, 'TPpct': Decimal('0'), 'FP': 68, 'FPpct': Decimal('0'), 'TN': 281, 'TNpct': Decimal('0'), 'FN': 47, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.23529411764705882'), 'evaluation_timeperiod': '2023-01-09_2023-01-13', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026857877}, {'daily_vol_diff_pct30': 0.02709754}, {'return_vol_450M': 0.17085241}, {'range_vol': 0.0332141}, {'roc5': 0.029255088}, {'range_vol_diff5': 0.026074564}, {'day_of_week': 0.03250717}, {'close_diff_deviation': 0.026726995}, {'SPY_diff3': 0.029276423}, {'price_10DDiff': 0.02785736}, {'SPY_1D': 0.032028336}, {'min_volume_vol_diff_pct': 0.022971787}, {'return_vol_240M': 0.053286612}, {'month': 0.035819862}, {'close_diff': 0.033269066}, {'roc': 0.027710166}, {'SPY_3D': 0.033496134}, {'hour_volume_vol_diff_pct': 0.025144096}, {'daily_vol_diff30': 0.028896283}, {'oneD_stddev50': 0.028601367}, {'SPY_diff5': 0.029304137}, {'threeD_stddev50': 0.029605588}, {'daily_volume_vol_diff_pct': 0.024258217}, {'roc_diff': 0.027953802}, {'price7': 0.027834656}, {'min_vol_diff': 0.025303239}, {'daily_volume_vol_diff_pct30': 0.024619007}, {'return_vol_10D': 0.032070413}, {'SPY_diff': 0.028107475}]"}
# {'deployment_date': datetime.datetime(2023, 1, 16, 0, 0), 'dataset_end': datetime.datetime(2023, 1, 6, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    61698
# 1    49329
# Name: count, dtype: int64
# 43 50 127 121
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-01-16', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 43, 'TPpct': Decimal('0'), 'FP': 50, 'FPpct': Decimal('0'), 'TN': 127, 'TNpct': Decimal('0'), 'FN': 121, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.86'), 'evaluation_timeperiod': '2023-01-16_2023-01-20', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026387889}, {'daily_vol_diff_pct30': 0.026579183}, {'return_vol_450M': 0.16899033}, {'range_vol': 0.032257497}, {'roc5': 0.028944284}, {'range_vol_diff5': 0.026320389}, {'day_of_week': 0.034402233}, {'close_diff_deviation': 0.027677901}, {'SPY_diff3': 0.030029263}, {'price_10DDiff': 0.027038991}, {'SPY_1D': 0.033601284}, {'min_volume_vol_diff_pct': 0.02269388}, {'return_vol_240M': 0.057374116}, {'month': 0.034828052}, {'close_diff': 0.030731795}, {'roc': 0.028088776}, {'SPY_3D': 0.034484155}, {'hour_volume_vol_diff_pct': 0.024932452}, {'daily_vol_diff30': 0.027400305}, {'oneD_stddev50': 0.028577473}, {'SPY_diff5': 0.028985439}, {'threeD_stddev50': 0.029409122}, {'daily_volume_vol_diff_pct': 0.024516685}, {'roc_diff': 0.028084535}, {'price7': 0.026802719}, {'min_vol_diff': 0.024993718}, {'daily_volume_vol_diff_pct30': 0.024595585}, {'return_vol_10D': 0.03192771}, {'SPY_diff': 0.02934432}]"}
# {'deployment_date': datetime.datetime(2023, 1, 23, 0, 0), 'dataset_end': datetime.datetime(2023, 1, 13, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    62057
# 1    49413
# Name: count, dtype: int64
# 29 40 185 164
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-01-23', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 29, 'TPpct': Decimal('0'), 'FP': 40, 'FPpct': Decimal('0'), 'TN': 185, 'TNpct': Decimal('0'), 'FN': 164, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.725'), 'evaluation_timeperiod': '2023-01-23_2023-01-27', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026880953}, {'daily_vol_diff_pct30': 0.026920682}, {'return_vol_450M': 0.17622711}, {'range_vol': 0.03351811}, {'roc5': 0.029339807}, {'range_vol_diff5': 0.026619826}, {'day_of_week': 0.034259327}, {'close_diff_deviation': 0.02685069}, {'SPY_diff3': 0.028367573}, {'price_10DDiff': 0.028047528}, {'SPY_1D': 0.03401844}, {'min_volume_vol_diff_pct': 0.022501655}, {'return_vol_240M': 0.049817387}, {'month': 0.03514509}, {'close_diff': 0.030800235}, {'roc': 0.027685683}, {'SPY_3D': 0.034035593}, {'hour_volume_vol_diff_pct': 0.024759078}, {'daily_vol_diff30': 0.027825404}, {'oneD_stddev50': 0.028083805}, {'SPY_diff5': 0.029196152}, {'threeD_stddev50': 0.029257929}, {'daily_volume_vol_diff_pct': 0.024583079}, {'roc_diff': 0.028587135}, {'price7': 0.02830425}, {'min_vol_diff': 0.024545288}, {'daily_volume_vol_diff_pct30': 0.024420416}, {'return_vol_10D': 0.031113496}, {'SPY_diff': 0.02828825}]"}
# {'deployment_date': datetime.datetime(2023, 1, 30, 0, 0), 'dataset_end': datetime.datetime(2023, 1, 20, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    62237
# 1    49590
# Name: count, dtype: int64
# 62 37 206 108
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-01-30', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 62, 'TPpct': Decimal('0'), 'FP': 37, 'FPpct': Decimal('0'), 'TN': 206, 'TNpct': Decimal('0'), 'FN': 108, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.6756756756756757'), 'evaluation_timeperiod': '2023-01-30_2023-02-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026773557}, {'daily_vol_diff_pct30': 0.027806258}, {'return_vol_450M': 0.17220579}, {'range_vol': 0.0329376}, {'roc5': 0.029567884}, {'range_vol_diff5': 0.025764517}, {'day_of_week': 0.03485821}, {'close_diff_deviation': 0.027293218}, {'SPY_diff3': 0.028388396}, {'price_10DDiff': 0.02835399}, {'SPY_1D': 0.033393573}, {'min_volume_vol_diff_pct': 0.023009166}, {'return_vol_240M': 0.051835135}, {'month': 0.03582581}, {'close_diff': 0.029676856}, {'roc': 0.026865369}, {'SPY_3D': 0.034169786}, {'hour_volume_vol_diff_pct': 0.025135776}, {'daily_vol_diff30': 0.027421333}, {'oneD_stddev50': 0.029637907}, {'SPY_diff5': 0.02951567}, {'threeD_stddev50': 0.02855727}, {'daily_volume_vol_diff_pct': 0.024657875}, {'roc_diff': 0.028321749}, {'price7': 0.028779821}, {'min_vol_diff': 0.02432995}, {'daily_volume_vol_diff_pct30': 0.025570715}, {'return_vol_10D': 0.031592734}, {'SPY_diff': 0.027754214}]"}
# {'deployment_date': datetime.datetime(2023, 2, 6, 0, 0), 'dataset_end': datetime.datetime(2023, 1, 27, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    62510
# 1    49760
# Name: count, dtype: int64
# 116 92 112 83
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-02-06', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 116, 'TPpct': Decimal('0'), 'FP': 92, 'FPpct': Decimal('0'), 'TN': 112, 'TNpct': Decimal('0'), 'FN': 83, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.2608695652173914'), 'evaluation_timeperiod': '2023-02-06_2023-02-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.025821384}, {'daily_vol_diff_pct30': 0.026474193}, {'return_vol_450M': 0.18658291}, {'range_vol': 0.031788826}, {'roc5': 0.028117714}, {'range_vol_diff5': 0.025593814}, {'day_of_week': 0.032947637}, {'close_diff_deviation': 0.027753051}, {'SPY_diff3': 0.029267715}, {'price_10DDiff': 0.026809726}, {'SPY_1D': 0.03271141}, {'min_volume_vol_diff_pct': 0.02275679}, {'return_vol_240M': 0.05278191}, {'month': 0.03633837}, {'close_diff': 0.029120669}, {'roc': 0.027007302}, {'SPY_3D': 0.033824295}, {'hour_volume_vol_diff_pct': 0.024206445}, {'daily_vol_diff30': 0.027996436}, {'oneD_stddev50': 0.027637538}, {'SPY_diff5': 0.029132672}, {'threeD_stddev50': 0.028304162}, {'daily_volume_vol_diff_pct': 0.024208464}, {'roc_diff': 0.027575089}, {'price7': 0.026707511}, {'min_vol_diff': 0.023952357}, {'daily_volume_vol_diff_pct30': 0.024831153}, {'return_vol_10D': 0.031222118}, {'SPY_diff': 0.028528478}]"}
# {'deployment_date': datetime.datetime(2023, 2, 13, 0, 0), 'dataset_end': datetime.datetime(2023, 2, 3, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    62731
# 1    49986
# Name: count, dtype: int64
# 74 82 152 127
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-02-13', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 74, 'TPpct': Decimal('0'), 'FP': 82, 'FPpct': Decimal('0'), 'TN': 152, 'TNpct': Decimal('0'), 'FN': 127, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.9024390243902439'), 'evaluation_timeperiod': '2023-02-13_2023-02-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026727147}, {'daily_vol_diff_pct30': 0.027276833}, {'return_vol_450M': 0.1691587}, {'range_vol': 0.033342667}, {'roc5': 0.029530881}, {'range_vol_diff5': 0.026310714}, {'day_of_week': 0.03535675}, {'close_diff_deviation': 0.02823132}, {'SPY_diff3': 0.029363109}, {'price_10DDiff': 0.02870567}, {'SPY_1D': 0.033402476}, {'min_volume_vol_diff_pct': 0.022538621}, {'return_vol_240M': 0.04888902}, {'month': 0.035752002}, {'close_diff': 0.030013712}, {'roc': 0.027792701}, {'SPY_3D': 0.034594975}, {'hour_volume_vol_diff_pct': 0.02476011}, {'daily_vol_diff30': 0.028589534}, {'oneD_stddev50': 0.028909337}, {'SPY_diff5': 0.029974153}, {'threeD_stddev50': 0.028628657}, {'daily_volume_vol_diff_pct': 0.024451064}, {'roc_diff': 0.029211817}, {'price7': 0.027356159}, {'min_vol_diff': 0.024939053}, {'daily_volume_vol_diff_pct30': 0.025561556}, {'return_vol_10D': 0.03173669}, {'SPY_diff': 0.028894503}]"}
# {'deployment_date': datetime.datetime(2023, 2, 20, 0, 0), 'dataset_end': datetime.datetime(2023, 2, 10, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    62983
# 1    50168
# Name: count, dtype: int64
# 76 130 58 60
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-02-20', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 76, 'TPpct': Decimal('0'), 'FP': 130, 'FPpct': Decimal('0'), 'TN': 58, 'TNpct': Decimal('0'), 'FN': 60, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5846153846153846'), 'evaluation_timeperiod': '2023-02-20_2023-02-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.017+one_min', 'feature_importances': "[{'adx': 0.026467493}, {'daily_vol_diff_pct30': 0.02766807}, {'return_vol_450M': 0.18366906}, {'range_vol': 0.032114763}, {'roc5': 0.02886524}, {'range_vol_diff5': 0.025742305}, {'day_of_week': 0.03416003}, {'close_diff_deviation': 0.02686007}, {'SPY_diff3': 0.029279722}, {'price_10DDiff': 0.027849384}, {'SPY_1D': 0.03262955}, {'min_volume_vol_diff_pct': 0.0227611}, {'return_vol_240M': 0.04509257}, {'month': 0.035792217}, {'close_diff': 0.02926927}, {'roc': 0.02806679}, {'SPY_3D': 0.03526917}, {'hour_volume_vol_diff_pct': 0.024800895}, {'daily_vol_diff30': 0.028388107}, {'oneD_stddev50': 0.026975393}, {'SPY_diff5': 0.0295042}, {'threeD_stddev50': 0.02854689}, {'daily_volume_vol_diff_pct': 0.024984721}, {'roc_diff': 0.02771634}, {'price7': 0.027277306}, {'min_vol_diff': 0.0249569}, {'daily_volume_vol_diff_pct30': 0.024453007}, {'return_vol_10D': 0.031948607}, {'SPY_diff': 0.028890934}]"}
# {'deployment_date': datetime.datetime(2023, 2, 27, 0, 0), 'dataset_end': datetime.datetime(2023, 2, 17, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    63213
# 1    50388
# Name: count, dtype: int64
# 21 44 267 94
# ...
# {'deployment_date': datetime.datetime(2023, 11, 6, 0, 0), 'dataset_end': datetime.datetime(2023, 10, 27, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    69535
# 1    59339
# Name: count, dtype: int64
# 37 39 259 103
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-11-06', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 37, 'TPpct': Decimal('0'), 'FP': 39, 'FPpct': Decimal('0'), 'TN': 259, 'TNpct': Decimal('0'), 'FN': 103, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.9487179487179487'), 'evaluation_timeperiod': '2023-11-06_2023-11-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.016+one_min', 'feature_importances': "[{'adx': 0.025870826}, {'daily_vol_diff_pct30': 0.026417017}, {'return_vol_450M': 0.1743239}, {'range_vol': 0.03293672}, {'roc5': 0.028611992}, {'range_vol_diff5': 0.025675826}, {'day_of_week': 0.034801602}, {'close_diff_deviation': 0.026638817}, {'SPY_diff3': 0.029431386}, {'price_10DDiff': 0.02807299}, {'SPY_1D': 0.03220653}, {'min_volume_vol_diff_pct': 0.022392692}, {'return_vol_240M': 0.05158563}, {'month': 0.037070226}, {'close_diff': 0.030268524}, {'roc': 0.02797708}, {'SPY_3D': 0.03363822}, {'hour_volume_vol_diff_pct': 0.025830265}, {'daily_vol_diff30': 0.029123139}, {'oneD_stddev50': 0.029307155}, {'SPY_diff5': 0.030284828}, {'threeD_stddev50': 0.027884582}, {'daily_volume_vol_diff_pct': 0.024333742}, {'roc_diff': 0.027466416}, {'price7': 0.027711669}, {'min_vol_diff': 0.024587285}, {'daily_volume_vol_diff_pct30': 0.025076423}, {'return_vol_10D': 0.032602765}, {'SPY_diff': 0.02787188}]"}
# {'deployment_date': datetime.datetime(2023, 11, 13, 0, 0), 'dataset_end': datetime.datetime(2023, 11, 3, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    69877
# 1    59440
# Name: count, dtype: int64
# 15 31 306 53
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-11-13', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 15, 'TPpct': Decimal('0'), 'FP': 31, 'FPpct': Decimal('0'), 'TN': 306, 'TNpct': Decimal('0'), 'FN': 53, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.4838709677419355'), 'evaluation_timeperiod': '2023-11-13_2023-11-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.016+one_min', 'feature_importances': "[{'adx': 0.02610713}, {'daily_vol_diff_pct30': 0.027603228}, {'return_vol_450M': 0.17974451}, {'range_vol': 0.030884283}, {'roc5': 0.028890638}, {'range_vol_diff5': 0.026101187}, {'day_of_week': 0.0356765}, {'close_diff_deviation': 0.026535958}, {'SPY_diff3': 0.028399326}, {'price_10DDiff': 0.02820423}, {'SPY_1D': 0.032392718}, {'min_volume_vol_diff_pct': 0.02285862}, {'return_vol_240M': 0.048686076}, {'month': 0.036257133}, {'close_diff': 0.030068958}, {'roc': 0.027141225}, {'SPY_3D': 0.034246843}, {'hour_volume_vol_diff_pct': 0.02514824}, {'daily_vol_diff30': 0.028848583}, {'oneD_stddev50': 0.02877382}, {'SPY_diff5': 0.030298784}, {'threeD_stddev50': 0.027934864}, {'daily_volume_vol_diff_pct': 0.024248328}, {'roc_diff': 0.028041534}, {'price7': 0.026587164}, {'min_vol_diff': 0.025230255}, {'daily_volume_vol_diff_pct30': 0.024659334}, {'return_vol_10D': 0.03216101}, {'SPY_diff': 0.028269472}]"}
# {'deployment_date': datetime.datetime(2023, 11, 20, 0, 0), 'dataset_end': datetime.datetime(2023, 11, 10, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    70139
# 1    59624
# Name: count, dtype: int64
# 4 23 248 61
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-11-20', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 4, 'TPpct': Decimal('0'), 'FP': 23, 'FPpct': Decimal('0'), 'TN': 248, 'TNpct': Decimal('0'), 'FN': 61, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.17391304347826086'), 'evaluation_timeperiod': '2023-11-20_2023-11-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.016+one_min', 'feature_importances': "[{'adx': 0.026870677}, {'daily_vol_diff_pct30': 0.027044034}, {'return_vol_450M': 0.16886467}, {'range_vol': 0.032225553}, {'roc5': 0.028725741}, {'range_vol_diff5': 0.025467506}, {'day_of_week': 0.03506078}, {'close_diff_deviation': 0.026909683}, {'SPY_diff3': 0.028494421}, {'price_10DDiff': 0.028373446}, {'SPY_1D': 0.033003267}, {'min_volume_vol_diff_pct': 0.022325132}, {'return_vol_240M': 0.054877058}, {'month': 0.036347706}, {'close_diff': 0.029627994}, {'roc': 0.02732918}, {'SPY_3D': 0.03430039}, {'hour_volume_vol_diff_pct': 0.02573713}, {'daily_vol_diff30': 0.028979838}, {'oneD_stddev50': 0.02908182}, {'SPY_diff5': 0.03020923}, {'threeD_stddev50': 0.028984448}, {'daily_volume_vol_diff_pct': 0.024575394}, {'roc_diff': 0.028181575}, {'price7': 0.027260654}, {'min_vol_diff': 0.02582991}, {'daily_volume_vol_diff_pct30': 0.025027992}, {'return_vol_10D': 0.03221335}, {'SPY_diff': 0.028071353}]"}
# {'deployment_date': datetime.datetime(2023, 11, 27, 0, 0), 'dataset_end': datetime.datetime(2023, 11, 17, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    70473
# 1    59722
# Name: count, dtype: int64
# 25 38 223 116
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-11-27', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 25, 'TPpct': Decimal('0'), 'FP': 38, 'FPpct': Decimal('0'), 'TN': 223, 'TNpct': Decimal('0'), 'FN': 116, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6578947368421053'), 'evaluation_timeperiod': '2023-11-27_2023-12-01', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.016+one_min', 'feature_importances': "[{'adx': 0.027257225}, {'daily_vol_diff_pct30': 0.027239291}, {'return_vol_450M': 0.1614522}, {'range_vol': 0.03238547}, {'roc5': 0.028968686}, {'range_vol_diff5': 0.026799945}, {'day_of_week': 0.0348472}, {'close_diff_deviation': 0.026838012}, {'SPY_diff3': 0.029523881}, {'price_10DDiff': 0.027261704}, {'SPY_1D': 0.033645142}, {'min_volume_vol_diff_pct': 0.023896744}, {'return_vol_240M': 0.053107727}, {'month': 0.03641901}, {'close_diff': 0.030275496}, {'roc': 0.028545065}, {'SPY_3D': 0.03536355}, {'hour_volume_vol_diff_pct': 0.025065294}, {'daily_vol_diff30': 0.028488968}, {'oneD_stddev50': 0.030205056}, {'SPY_diff5': 0.029719131}, {'threeD_stddev50': 0.029035399}, {'daily_volume_vol_diff_pct': 0.024650898}, {'roc_diff': 0.028339922}, {'price7': 0.027830552}, {'min_vol_diff': 0.025338385}, {'daily_volume_vol_diff_pct30': 0.026075892}, {'return_vol_10D': 0.03288946}, {'SPY_diff': 0.028534519}]"}
# {'deployment_date': datetime.datetime(2023, 12, 4, 0, 0), 'dataset_end': datetime.datetime(2023, 11, 24, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    70773
# 1    59770
# Name: count, dtype: int64
# 18 24 309 67
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-12-04', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 18, 'TPpct': Decimal('0'), 'FP': 24, 'FPpct': Decimal('0'), 'TN': 309, 'TNpct': Decimal('0'), 'FN': 67, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.75'), 'evaluation_timeperiod': '2023-12-04_2023-12-08', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.016+one_min', 'feature_importances': "[{'adx': 0.026257852}, {'daily_vol_diff_pct30': 0.026417183}, {'return_vol_450M': 0.1714091}, {'range_vol': 0.031734373}, {'roc5': 0.027551776}, {'range_vol_diff5': 0.026441209}, {'day_of_week': 0.034433357}, {'close_diff_deviation': 0.02637214}, {'SPY_diff3': 0.029303176}, {'price_10DDiff': 0.02810775}, {'SPY_1D': 0.032771483}, {'min_volume_vol_diff_pct': 0.022712884}, {'return_vol_240M': 0.053277116}, {'month': 0.037209377}, {'close_diff': 0.030777419}, {'roc': 0.028002702}, {'SPY_3D': 0.033854373}, {'hour_volume_vol_diff_pct': 0.025252938}, {'daily_vol_diff30': 0.0289219}, {'oneD_stddev50': 0.02968415}, {'SPY_diff5': 0.030433988}, {'threeD_stddev50': 0.027659992}, {'daily_volume_vol_diff_pct': 0.025031198}, {'roc_diff': 0.028195478}, {'price7': 0.027648816}, {'min_vol_diff': 0.025368938}, {'daily_volume_vol_diff_pct30': 0.024923954}, {'return_vol_10D': 0.03227627}, {'SPY_diff': 0.02796902}]"}
# {'deployment_date': datetime.datetime(2023, 12, 11, 0, 0), 'dataset_end': datetime.datetime(2023, 12, 1, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    71053
# 1    59924
# Name: count, dtype: int64
# 36 68 244 89
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-12-11', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 36, 'TPpct': Decimal('0'), 'FP': 68, 'FPpct': Decimal('0'), 'TN': 244, 'TNpct': Decimal('0'), 'FN': 89, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5294117647058824'), 'evaluation_timeperiod': '2023-12-11_2023-12-15', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.016+one_min', 'feature_importances': "[{'adx': 0.026577095}, {'daily_vol_diff_pct30': 0.028079137}, {'return_vol_450M': 0.16901815}, {'range_vol': 0.03225709}, {'roc5': 0.028787553}, {'range_vol_diff5': 0.026718048}, {'day_of_week': 0.0343679}, {'close_diff_deviation': 0.026909336}, {'SPY_diff3': 0.028917436}, {'price_10DDiff': 0.027233781}, {'SPY_1D': 0.032275345}, {'min_volume_vol_diff_pct': 0.022710288}, {'return_vol_240M': 0.052540403}, {'month': 0.03647725}, {'close_diff': 0.030616738}, {'roc': 0.027342517}, {'SPY_3D': 0.034150526}, {'hour_volume_vol_diff_pct': 0.025596045}, {'daily_vol_diff30': 0.028308641}, {'oneD_stddev50': 0.028880393}, {'SPY_diff5': 0.03054367}, {'threeD_stddev50': 0.029069075}, {'daily_volume_vol_diff_pct': 0.025683781}, {'roc_diff': 0.028290696}, {'price7': 0.027936852}, {'min_vol_diff': 0.025544059}, {'daily_volume_vol_diff_pct30': 0.024686078}, {'return_vol_10D': 0.03223939}, {'SPY_diff': 0.02824262}]"}
# {'deployment_date': datetime.datetime(2023, 12, 18, 0, 0), 'dataset_end': datetime.datetime(2023, 12, 8, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    71359
# 1    60061
# Name: count, dtype: int64
# 20 38 261 100
# {'model_name': 'LOSERS_1d:TSSIM1_TL15-EXP_custHypTP0.45', 'deployment_date': '2023-12-18', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_TL15-EXP_custHypTP0.45', 'TP': 20, 'TPpct': Decimal('0'), 'FP': 38, 'FPpct': Decimal('0'), 'TN': 261, 'TNpct': Decimal('0'), 'FN': 100, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5263157894736842'), 'evaluation_timeperiod': '2023-12-18_2023-12-22', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['adx', 'daily_vol_diff_pct30', 'return_vol_450M', 'range_vol', 'roc5', 'range_vol_diff5', 'day_of_week', 'close_diff_deviation', 'SPY_diff3', 'price_10DDiff', 'SPY_1D', 'min_volume_vol_diff_pct', 'return_vol_240M', 'month', 'close_diff', 'roc', 'SPY_3D', 'hour_volume_vol_diff_pct', 'daily_vol_diff30', 'oneD_stddev50', 'SPY_diff5', 'threeD_stddev50', 'daily_volume_vol_diff_pct', 'roc_diff', 'price7', 'min_vol_diff', 'daily_volume_vol_diff_pct30', 'return_vol_10D', 'SPY_diff']"}, 'target': '-0.016+one_min', 'feature_importances': "[{'adx': 0.026590765}, {'daily_vol_diff_pct30': 0.027074099}, {'return_vol_450M': 0.1701787}, {'range_vol': 0.032246783}, {'roc5': 0.02846865}, {'range_vol_diff5': 0.026372777}, {'day_of_week': 0.034570906}, {'close_diff_deviation': 0.026317764}, {'SPY_diff3': 0.028796734}, {'price_10DDiff': 0.027578177}, {'SPY_1D': 0.033467986}, {'min_volume_vol_diff_pct': 0.022818305}, {'return_vol_240M': 0.05263582}, {'month': 0.037132304}, {'close_diff': 0.030569555}, {'roc': 0.02770162}, {'SPY_3D': 0.03455356}, {'hour_volume_vol_diff_pct': 0.025815317}, {'daily_vol_diff30': 0.028362125}, {'oneD_stddev50': 0.028592506}, {'SPY_diff5': 0.029998923}, {'threeD_stddev50': 0.027979478}, {'daily_volume_vol_diff_pct': 0.024766186}, {'roc_diff': 0.028772857}, {'price7': 0.027579408}, {'min_vol_diff': 0.024956334}, {'daily_volume_vol_diff_pct30': 0.025403647}, {'return_vol_10D': 0.032240946}, {'SPY_diff': 0.028457781}]"}

# %%
# def convert_timestamp_est(timestamp):
#     # Create a naive datetime object from the UNIX timestamp
#     dt_naive = datetime.utcfromtimestamp(timestamp)
#     # Convert the naive datetime object to a timezone-aware one (UTC)
#     dt_utc = pytz.utc.localize(dt_naive)
#     # Convert the UTC datetime to EST
#     dt_est = dt_utc.astimezone(pytz.timezone('US/Eastern'))
    
#     return dt_est


# data = pd.read_csv(f'/Users/charlesmiller/Documents/GAIN/2018-01-01_2023-10-28.csv')
# data['date'] = data['date'].astype(str)
# data['date'] = data['date'].apply(lambda x: x.split(" ")[0])
# data = data.drop(data[data['date'] == 'nan'].index)
# # data.drop('date',axis=1,inplace=True)
# # data['date'] = data['t'].apply(lambda x: convert_timestamp_est(x))
# # data.drop(['one_pct','three_pct','Unnamed: 0.2', "Unnamed: 0","Unnamed: 0.1", "date_x","date_y",'vw_x', 'n_x', 'return_vol_240M_x', 'volume_vol_240M_x', 'return_vol_450M_x', 'volume_vol_450M_x', 'min_vol_diff_x', 'min_vol_diff_pct_x', 'min_volume_vol_diff_x', 'min_volume_vol_diff_pct_x', 'return_vol_8H_x', 'return_vol_16H_x', 'volume_vol_8H_x', 'volume_vol_16H_x', 'hour_vol_diff_x', 'hour_vol_diff_pct_x', 'hour_volume_vol_diff_x', 'hour_volume_vol_diff_pct_x', 'return_vol_5D_x', 'return_vol_10D_x', 'return_vol_30D_x', 'volume_vol_5D_x', 'volume_vol_10D_x', 'volume_vol_30D_x', 'daily_vol_diff_x', 'daily_vol_diff_pct_x', 'daily_vol_diff30_x', 'daily_vol_diff_pct30_x', 'daily_volume_vol_diff_x', 'daily_volume_vol_diff_pct_x', 'daily_volume_vol_diff30_x', 'daily_volume_vol_diff_pct30_x', 'vw_y', 'n_y', 'return_vol_240M_y', 'volume_vol_240M_y', 'return_vol_450M_y', 'volume_vol_450M_y', 'min_vol_diff_y', 'min_vol_diff_pct_y', 'min_volume_vol_diff_y', 'min_volume_vol_diff_pct_y', 'return_vol_8H_y', 'return_vol_16H_y', 'volume_vol_8H_y', 'volume_vol_16H_y', 'hour_vol_diff_y', 'hour_vol_diff_pct_y', 'hour_volume_vol_diff_y', 'hour_volume_vol_diff_pct_y', 'return_vol_5D_y', 'return_vol_10D_y', 'return_vol_30D_y', 'volume_vol_5D_y', 'volume_vol_10D_y', 'volume_vol_30D_y', 'daily_vol_diff_y', 'daily_vol_diff_pct_y', 'daily_vol_diff30_y', 'daily_vol_diff_pct30_y', 'daily_volume_vol_diff_y', 'daily_volume_vol_diff_pct_y', 'daily_volume_vol_diff30_y', 'daily_volume_vol_diff_pct30_y'], axis=1, inplace=True)
# data['roc_diff'] = data['roc'] - data['roc5']
# data['range_vol_diff5'] = (data['range_vol'] - data['range_vol5MA'])
# data['close_diff_deviation3'] = abs(data['close_diff3'])/(data['threeD_stddev50']*100)
# data['close_diff_deviation'] = abs(data['close_diff'])/(data['oneD_stddev50']*100)
# data.dropna(subset=['date'], inplace=True)
# data['date'] = data['date'].apply(lambda x: datetime.strptime(x,"%Y-%m-%d"))
# data['day_of_week'] = data['date'].apply(lambda x: x.dayofweek).astype(int)
# data['day_of_month'] = data['date'].apply(lambda x: x.day).astype(int)
# data['month'] = data['date'].apply(lambda x: x.month).astype(int)
# data['year'] = data['date'].apply(lambda x: x.year).astype(int)
# data.replace([np.inf, -np.inf], 0, inplace=True)
# data.to_csv(f'/Users/charlesmiller/Documents/GAIN/2018-01-01_2023-10-28.csv', index=False)

# %%
# def run_temporal_simulation(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date):
#     tp_avg_list = []
#     gross_accuracy_list = []
#     # fn_list = []
#     # tn_list = []
    
#     hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
#     dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
#     for date in dates_list:
#         tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams)
#         tp_avg_list.append(tp)
#         gross_accuracy_list.append((tp-fp))

#     return tp_avg_list, gross_accuracy_list

# %%
# number_of_simulations = 200
# now = datetime.now()
# title = 'LOSERS_1d'
# # total_feature_list = ['hour','year','month','day_of_month',
# #        'price7', 'price14', 'adjusted_volume', 'vol7', 'vol14',
# #        'rsi', 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close',
# #        'oneD_returns_close', 'range_vol', 'range_vol5MA', 'range_vol10MA',
# #        'range_vol25MA', 'oneD_stddev50', 'threeD_stddev50', 'cmf',
# #        'close_diff', 'close_diff3', 'close_diff5', 'v_diff_pct', 'adx',
# #        'volume_10MA', 'volume_25MA', 'price_10MA', 'price_25MA',
# #        'volume_10DDiff', 'volume_25DDiff', 'price_10DDiff', 'price_25DDiff',
# #        'day_of_week','close_diff_deviation3','close_diff_deviation','roc_diff','range_vol_diff5',
# #        'return_vol_240M', 'volume_vol_240M', 'return_vol_450M', 'volume_vol_450M', 'min_vol_diff', 'min_vol_diff_pct', 'min_volume_vol_diff', 
# #        'min_volume_vol_diff_pct', 'return_vol_8H', 'return_vol_16H', 'volume_vol_8H', 'volume_vol_16H', 'hour_vol_diff', 'hour_vol_diff_pct', 'hour_volume_vol_diff', 
# #        'hour_volume_vol_diff_pct', 'return_vol_5D', 'return_vol_10D', 'return_vol_30D', 'volume_vol_5D', 'volume_vol_10D', 'volume_vol_30D', 'daily_vol_diff', 'daily_vol_diff_pct',
# #        'daily_vol_diff30', 'daily_vol_diff_pct30', 'daily_volume_vol_diff', 'daily_volume_vol_diff_pct', 'daily_volume_vol_diff30', 'daily_volume_vol_diff_pct30']
# testing_features = ['hour', 'day_of_week','month','daily_vol_diff30', 'hour_volume_vol_diff', 'roc_diff', 
# 'range_vol', 'volume_vol_8H','close_diff3', 'close_diff5',
# 'range_vol_diff5', 'SPY_diff', 'SPY_diff3','SPY_diff5','rsi5','roc5',
# 'return_vol_10D', 'return_vol_8H', 'return_vol_16H', 'return_vol_450M', 'adx', 
# 'rsi','roc','rsi3','roc3','daily_vol_diff', 'SPY_1D','SPY_3D', 'SPY_5D','min_vol_diff', 'return_vol_240M', 
# 'price_25DDiff', 'price_10DDiff','daily_vol_diff_pct30','threeD_stddev50',
# 'price7', 'daily_vol_diff_pct', 'oneD_stddev50', 'volume_vol_16H','min_volume_vol_diff_pct',
# 'close_diff_deviation','close_diff','daily_volume_vol_diff_pct','hour_volume_vol_diff_pct','daily_volume_vol_diff_pct30']

# target_label = 'one_min'
# target_value = -.015
# results_array = []

# i = 0
# while i < number_of_simulations:
#        model_name = f"{title}_temporal_simulation_{i}"
#        print(model_name)
#        random_int = random.randint(20, 35)
#        features = random.sample(testing_features, random_int)
#        print(features)
#        tp_avg_list, gross_accuracy_list = run_temporal_simulation(features, target_label, target_value, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2022,10,3), evaluation_end_date=datetime(2023,10,2))        
#        tp_avg = sum(tp_avg_list)/len(tp_avg_list)
#        gross_accuracy = sum(gross_accuracy_list)/len(gross_accuracy_list)
#        print(tp_avg, gross_accuracy)
#        print()
#        results_array.append({"model_name": model_name, "features": features, "tp_avg": tp_avg, "gross_accuracy": gross_accuracy,"num_features": random_int})
#        i += 1

# results_df = pd.DataFrame(results_array)
# results_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
