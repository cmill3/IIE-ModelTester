# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler
import pytz
from helpers.constants import *
import warnings 
warnings.filterwarnings('ignore')

# %%
s3 = boto3.client('s3')

training_bucket = "icarus-research-data"
training_prefix = 'training_datasets/expanded_1d_datasets/'

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

weekly_expiries = ['SPY', 'IVV', 'QQQ', 'GLD', 'IWM', 'EFA', 'XLK', 'XLV', 'TLT', 'LQD', 'XLE', 'TQQQ', 'SQQQ', 'SPXS', 'SPXL', 'SOXL', 'SOXS', 'MMM', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 
                   'AAP', 'AFL', 'ALB', 'ALGN', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMD', 'AAL', 'AXP', 'AIG', 'ABC', 'AMGN', 'ADI', 'APA', 'AAPL', 'AMAT', 'ANET', 'T', 'ADSK', 'BAC', 'BBWI', 'BAX', 'BBY', 'BIIB', 
                   'BLK', 'BA', 'BKNG', 'BMY', 'AVGO', 'CZR', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CAT', 'CBOE', 'CNC', 'CF', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CI', 'CSCO', 'C', 'CLX', 'CME', 'KO', 'CMCSA', 'CMA', 'CAG', 
                   'COP', 'STZ', 'GLW', 'COST', 'CTRA', 'CSX', 'CVS', 'DHI', 'DHR', 'DE', 'DAL', 'DVN', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'DPZ', 'DOW', 'DD', 'EBAY', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'EOG', 'EQT', 
                   'ETSY', 'EXPE', 'XOM', 'FDX', 'FITB', 'FSLR', 'FI', 'F', 'FTNT', 'FOXA', 'FCX', 'GEHC', 'GNRC', 'GD', 'GE', 'GM', 'GILD', 'GS', 'HAL', 'HSY', 'HES', 'HD', 'HON', 'HRL', 'HPQ', 'HUM', 'HBAN', 'IBM', 'ILMN', 
                   'INTC', 'IP', 'INTU', 'ISRG', 'JNJ', 'JPM', 'JNPR', 'KEY', 'KMB', 'KMI', 'KLAC', 'KHC', 'KR', 'LRCX', 'LVS', 'LEN', 'LMT', 'LOW', 'MRO', 'MPC', 'MAR', 'MA', 'MTCH', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 
                   'MGM', 'MU', 'MSFT', 'MRNA', 'MDLZ', 'MS', 'MOS', 'NTAP', 'NFLX', 'NEM', 'NKE', 'NSC', 'NOC', 'NCLH', 'NUE', 'NVDA', 'NXPI', 'OXY', 'ON', 'ORCL', 'PARA', 'PYPL', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PXD', 'PNC', 
                   'PPG', 'PG', 'PHM', 'QCOM', 'RTX', 'REGN', 'ROST', 'RCL', 'SPGI', 'CRM', 'SLB', 'STX', 'NOW', 'SWKS', 'SEDG', 'SO', 'LUV', 'SBUX', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TGT', 'TSLA', 'TXN', 'TMO', 'TJX', 'TSCO', 'TFC', 
                   'TSN', 'USB', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'VLO', 'VZ', 'VRTX', 'VFC', 'V', 'WBA', 'WMT', 'WBD', 'WM', 'WFC', 'WDC', 'WHR', 'WMB', 'WYNN', 'ZION']

leveraged_etfs = ["TQQQ","SQQQ","SPXS","SPXL","SOXL","SOXS"]
high_vol = ['COIN','BILI','UPST','CVNA',"TQQQ","SQQQ","SPXS","SPXL","SOXL","SOXS","NIO","BABA","ROKU","RBLX","SE","SNAP","LCID",'RIVN',"BIDU","FUTU","TSLA","JD","HOOD","CHWY"]
expensive = ["CMG","NFLX","AVGO","BKNG","ABNB"]
indexes = ['QQQ','IWM','TLT','VXX','SPY']

# %%
def create_training_data_local(key_list, prefix, bucket_name, alert_type, start_date, end_date):
    df_list = []
    hours = [10,11,12,13,14,15]
    start = start_date.split(' ')[0]
    end = end_date.split(' ')[0]
    for key in key_list:
        for hour in hours:
            try:
                data = s3.get_object(Bucket=bucket_name, Key=f'{prefix}{key}/{alert_type}/{hour}.csv')
                df = pd.read_csv(data.get("Body")) 
                df = df.loc[df['symbol'].isin(WEEKLY_EXP)]
                df = df.loc[~df['symbol'].isin(high_vol)]
                df = df.iloc[:10]
                df_list.append(df)
                # df['hour'] = hour
            except:
                continue

    data = pd.concat(df_list)
    data.reset_index(drop=True, inplace=True)
    data.replace([np.inf, -np.inf], 0, inplace=True)
    data.to_csv(f'/Users/charlesmiller/Documents/model_tester_data/GAIN/{start}_{end}_trainTL10.csv', index=False)
    return data

def create_validation_data_local(key_list, prefix, bucket_name, alert_type, start_date, end_date):
    df_list = []
    hours = [10,11,12,13,14,15]
    start = start_date.split(' ')[0]
    end = end_date.split(' ')[0]
    for key in key_list:
        for hour in hours:
            try:
                data = s3.get_object(Bucket=bucket_name, Key=f'{prefix}{key}/{alert_type}/{hour}.csv')
                df = pd.read_csv(data.get("Body")) 
                df = df.loc[df['symbol'].isin(TRADING_SYMBOLS)]
                df = df.loc[~df['symbol'].isin(high_vol)]
                df = df.iloc[:6]
                df_list.append(df)
                # df['hour'] = hour
            except:
                continue

    data = pd.concat(df_list)
    data.reset_index(drop=True, inplace=True)
    data.replace([np.inf, -np.inf], 0, inplace=True)
    data.to_csv(f'/Users/charlesmiller/Documents/model_tester_data/GAIN/{start}_{end}_validationTR6.csv', index=False)
    return data

def pull_training_data_local(end_date,start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/LOSE/2018-01-01_2023-12-23_trainTL8.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data


def pull_validation_data_local(end_date,start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/LOSE/2018-01-01_2023-12-23_trainTL15.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data = data.loc[data['dt'] >= start_date]
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data

# %%
def build_date_list(start_date, end_date):
    print(start_date, end_date)
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_validation_dates_local(deployment_date):
    end_date = deployment_date + timedelta(days=5)
    return end_date

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] > target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] > target_value).astype(int)

    # dataset = dataset.round(3)
    # validation_dataset = validation_dataset.round(3)

    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']


    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    print(y.value_counts())
    predictions = xgb_model.predict(X_validate)
    probabilities = xgb_model.predict_proba(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,str(fi_list), predictions, probabilities


def train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] > target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] > target_value).astype(int)

    dataset = dataset.round(5)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']
    

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,"str(fi_list)", predictions, "probabilities"

# %%
def model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile, start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
    validation_end_date = build_validation_dates_local(deployment_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    # dates_list = pull_gmm_labels(deployment_date)
    # rm_dataset = dataset.loc[dataset['dt'].isin(dates_list)]
    target_value = dataset[target_label].quantile(target_percentile).round(3)
    # print(target_value)
    # print(len(rm_dataset)/len(dataset))
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
    validation_dataset['probabilities'] = probabilities[:,1]
    validation_dataset['predictions'] = predictions
    validation_dataset['target_value'] = target_value
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    return "response"

def model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,end_date,deployment_date,hyperparams):
    validation_end_date = build_validation_dates_local(deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    return tp, fp, fn, tn 

def model_runner_data(start_date,end_date):
    dates = build_date_list(start_date, end_date)
    key_list = build_query_keys(dates)
    print(key_list[-1])
    train_data = create_training_data_local(key_list, 'full_alerts/weekly_exp_alerts/', 'inv-alerts', 'gainers', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
    # val_data = create_validation_data_local(key_list, 'full_alerts/trading_symbols_alerts/', 'inv-alerts', 'gainers', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
    return "train_data", "val_data"

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=10),
            "dataset_start": datetime(2018,1,1)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

def pull_gmm_labels(date):
    date_str = date.strftime('%Y-%m-%d')
    data_20d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm20d_labels_RM2/{date_str}.csv')
    data_10d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm10d_labels_RM2/{date_str}.csv')
    data_3d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm3d_labels_RM2/{date_str}.csv')

    data_20d = pd.read_csv(data_20d.get("Body"))
    data_10d = pd.read_csv(data_10d.get("Body"))
    data_3d = pd.read_csv(data_3d.get("Body"))

    data_20d['dt'] = pd.to_datetime(data_20d['date'])
    data_10d['dt'] = pd.to_datetime(data_10d['date'])
    data_3d['dt'] = pd.to_datetime(data_3d['date'])

    label_20d = data_20d['labels'].iloc[-1]
    label_10d = data_10d['labels'].iloc[-1]
    label_3d = data_3d['labels'].iloc[-1]

    dates_20d = data_20d['dt'].loc[data_20d['labels'] == label_20d].tolist()
    dates_10d = data_10d['dt'].loc[data_10d['labels'] == label_10d].tolist()
    dates_3d = data_3d['dt'].loc[data_3d['labels'] == label_3d].tolist()

    combined_list = list(set(dates_20d  + dates_3d))
    return dates_20d

# %%
target_percentile = 0.5
model_name = f'LOSERSC:TSSIM1_CDVOLTL15_custHypTP{target_percentile}'
# model_name = 'GAIN:TSSIM1_TL15_custHypP3'
dataset_name = f'LOSERSC:TSSIM1_CDVOLTL15_custHypTP{target_percentile}'
title = 'LOSERSC'
hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
features = ['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 
            'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 
            'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']
target_label = 'three_max_vol'

dataset_start_date = datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')) 
dates_list = build_evaluation_period(datetime(2022,1,3), datetime(2023,12,23))

# date = dates_list[-1]
# print(date)
# response = model_runner_data(start_date=datetime(2018,1,1),end_date=datetime(2023,12,23))

# dataset = pull_training_data_local(start_date=datetime(2018,1,1),end_date=datetime(2023,10,28))
# print(dataset['three_max'].describe())

for date in dates_list:
    print(date)
    response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile,"dataset_start_date",date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])
# Out:
# {'deployment_date': datetime.datetime(2022, 1, 3, 0, 0), 'dataset_end': datetime.datetime(2021, 12, 24, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    24387
# 1    23717
# Name: count, dtype: int64
# 130 198 85 37
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-01-03', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 130, 'TPpct': Decimal('0'), 'FP': 198, 'FPpct': Decimal('0'), 'TN': 85, 'TNpct': Decimal('0'), 'FN': 37, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6565656565656566'), 'evaluation_timeperiod': '2022-01-03_2022-01-07', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.67+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.04279689}, {'rsi': 0.039267804}, {'close_diff': 0.03984321}, {'daily_volume_vol_diff_pct30': 0.035711206}, {'range_vol_diff5': 0.03640102}, {'SPY_diff': 0.03445536}, {'threeD_stddev50': 0.040967807}, {'close_diff3': 0.036574293}, {'min_volume_vol_diff_pct': 0.029884413}, {'month': 0.043678988}, {'return_vol_240M': 0.04526878}, {'range_vol': 0.03947039}, {'rsi5': 0.036878638}, {'roc': 0.037179556}, {'SPY_3D': 0.039821126}, {'roc5': 0.038651336}, {'roc_diff': 0.050557632}, {'price_25DDiff': 0.039774798}, {'daily_volume_vol_diff_pct': 0.033986222}, {'price_10DDiff': 0.036457308}, {'SPY_1D': 0.039853066}, {'hour_volume_vol_diff': 0.034099635}, {'hour_volume_vol_diff_pct': 0.03519279}, {'return_vol_10D': 0.072236486}, {'SPY_5D': 0.040991228}]"}
# {'deployment_date': datetime.datetime(2022, 1, 10, 0, 0), 'dataset_end': datetime.datetime(2021, 12, 31, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    24502
# 1    23842
# Name: count, dtype: int64
# 118 193 99 40
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-01-10', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 118, 'TPpct': Decimal('0'), 'FP': 193, 'FPpct': Decimal('0'), 'TN': 99, 'TNpct': Decimal('0'), 'FN': 40, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6113989637305699'), 'evaluation_timeperiod': '2022-01-10_2022-01-14', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.667+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.043459002}, {'rsi': 0.03840129}, {'close_diff': 0.040818024}, {'daily_volume_vol_diff_pct30': 0.034242596}, {'range_vol_diff5': 0.036037188}, {'SPY_diff': 0.033980727}, {'threeD_stddev50': 0.04115709}, {'close_diff3': 0.03777483}, {'min_volume_vol_diff_pct': 0.031192817}, {'month': 0.043176334}, {'return_vol_240M': 0.044203766}, {'range_vol': 0.04043266}, {'rsi5': 0.03757471}, {'roc': 0.037810363}, {'SPY_3D': 0.039435793}, {'roc5': 0.037209723}, {'roc_diff': 0.049172245}, {'price_25DDiff': 0.040815603}, {'daily_volume_vol_diff_pct': 0.033986233}, {'price_10DDiff': 0.036069334}, {'SPY_1D': 0.040762395}, {'hour_volume_vol_diff': 0.03433991}, {'hour_volume_vol_diff_pct': 0.034934238}, {'return_vol_10D': 0.07151981}, {'SPY_5D': 0.041493285}]"}
# {'deployment_date': datetime.datetime(2022, 1, 17, 0, 0), 'dataset_end': datetime.datetime(2022, 1, 7, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    24620
# 1    23964
# Name: count, dtype: int64
# 50 243 57 10
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-01-17', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 50, 'TPpct': Decimal('0'), 'FP': 243, 'FPpct': Decimal('0'), 'TN': 57, 'TNpct': Decimal('0'), 'FN': 10, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.205761316872428'), 'evaluation_timeperiod': '2022-01-17_2022-01-21', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.664+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.043926373}, {'rsi': 0.038078357}, {'close_diff': 0.041678037}, {'daily_volume_vol_diff_pct30': 0.03576838}, {'range_vol_diff5': 0.036555145}, {'SPY_diff': 0.034435004}, {'threeD_stddev50': 0.04195172}, {'close_diff3': 0.036130734}, {'min_volume_vol_diff_pct': 0.030691367}, {'month': 0.04491806}, {'return_vol_240M': 0.04179709}, {'range_vol': 0.03941343}, {'rsi5': 0.037802156}, {'roc': 0.038323525}, {'SPY_3D': 0.03932335}, {'roc5': 0.03674888}, {'roc_diff': 0.050905097}, {'price_25DDiff': 0.039983775}, {'daily_volume_vol_diff_pct': 0.033607278}, {'price_10DDiff': 0.037798215}, {'SPY_1D': 0.03960693}, {'hour_volume_vol_diff': 0.033627365}, {'hour_volume_vol_diff_pct': 0.0354998}, {'return_vol_10D': 0.06900442}, {'SPY_5D': 0.042425483}]"}
# {'deployment_date': datetime.datetime(2022, 1, 24, 0, 0), 'dataset_end': datetime.datetime(2022, 1, 14, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    24738
# 1    24086
# Name: count, dtype: int64
# 309 45 24 72
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-01-24', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 309, 'TPpct': Decimal('0'), 'FP': 45, 'FPpct': Decimal('0'), 'TN': 24, 'TNpct': Decimal('0'), 'FN': 72, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('6.866666666666666'), 'evaluation_timeperiod': '2022-01-24_2022-01-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.661+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.044583086}, {'rsi': 0.03839743}, {'close_diff': 0.039477974}, {'daily_volume_vol_diff_pct30': 0.03490189}, {'range_vol_diff5': 0.03558787}, {'SPY_diff': 0.03377616}, {'threeD_stddev50': 0.040777616}, {'close_diff3': 0.037978686}, {'min_volume_vol_diff_pct': 0.03147209}, {'month': 0.04284265}, {'return_vol_240M': 0.044260297}, {'range_vol': 0.038930554}, {'rsi5': 0.03665919}, {'roc': 0.038701113}, {'SPY_3D': 0.040804196}, {'roc5': 0.03713268}, {'roc_diff': 0.051526118}, {'price_25DDiff': 0.039570574}, {'daily_volume_vol_diff_pct': 0.03304123}, {'price_10DDiff': 0.03819079}, {'SPY_1D': 0.039974853}, {'hour_volume_vol_diff': 0.035464127}, {'hour_volume_vol_diff_pct': 0.035484724}, {'return_vol_10D': 0.06803149}, {'SPY_5D': 0.04243267}]"}
# {'deployment_date': datetime.datetime(2022, 1, 31, 0, 0), 'dataset_end': datetime.datetime(2022, 1, 21, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    24833
# 1    24183
# Name: count, dtype: int64
# 123 86 152 89
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-01-31', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 123, 'TPpct': Decimal('0'), 'FP': 86, 'FPpct': Decimal('0'), 'TN': 152, 'TNpct': Decimal('0'), 'FN': 89, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.430232558139535'), 'evaluation_timeperiod': '2022-01-31_2022-02-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.655+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.043665342}, {'rsi': 0.03893899}, {'close_diff': 0.03807624}, {'daily_volume_vol_diff_pct30': 0.034819853}, {'range_vol_diff5': 0.036591865}, {'SPY_diff': 0.033576358}, {'threeD_stddev50': 0.041921254}, {'close_diff3': 0.037367847}, {'min_volume_vol_diff_pct': 0.031196699}, {'month': 0.04075799}, {'return_vol_240M': 0.043535877}, {'range_vol': 0.040419225}, {'rsi5': 0.03714747}, {'roc': 0.039675087}, {'SPY_3D': 0.040132307}, {'roc5': 0.038015265}, {'roc_diff': 0.05027263}, {'price_25DDiff': 0.040672775}, {'daily_volume_vol_diff_pct': 0.034243323}, {'price_10DDiff': 0.0356005}, {'SPY_1D': 0.04032609}, {'hour_volume_vol_diff': 0.034011662}, {'hour_volume_vol_diff_pct': 0.03545054}, {'return_vol_10D': 0.07094094}, {'SPY_5D': 0.04264393}]"}
# {'deployment_date': datetime.datetime(2022, 2, 7, 0, 0), 'dataset_end': datetime.datetime(2022, 1, 28, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    24957
# 1    24299
# Name: count, dtype: int64
# 63 65 235 87
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-02-07', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 63, 'TPpct': Decimal('0'), 'FP': 65, 'FPpct': Decimal('0'), 'TN': 235, 'TNpct': Decimal('0'), 'FN': 87, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.9692307692307692'), 'evaluation_timeperiod': '2022-02-07_2022-02-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.663+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.044485994}, {'rsi': 0.03924609}, {'close_diff': 0.03978961}, {'daily_volume_vol_diff_pct30': 0.035422064}, {'range_vol_diff5': 0.035626438}, {'SPY_diff': 0.0346945}, {'threeD_stddev50': 0.0407035}, {'close_diff3': 0.03623626}, {'min_volume_vol_diff_pct': 0.031699628}, {'month': 0.043138817}, {'return_vol_240M': 0.043890677}, {'range_vol': 0.04066067}, {'rsi5': 0.03691107}, {'roc': 0.039029744}, {'SPY_3D': 0.038607612}, {'roc5': 0.036341514}, {'roc_diff': 0.04994451}, {'price_25DDiff': 0.038928118}, {'daily_volume_vol_diff_pct': 0.035176426}, {'price_10DDiff': 0.037633557}, {'SPY_1D': 0.039754257}, {'hour_volume_vol_diff': 0.034247667}, {'hour_volume_vol_diff_pct': 0.035188816}, {'return_vol_10D': 0.07055281}, {'SPY_5D': 0.042089626}]"}
# {'deployment_date': datetime.datetime(2022, 2, 14, 0, 0), 'dataset_end': datetime.datetime(2022, 2, 4, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    25084
# 1    24412
# Name: count, dtype: int64
# 60 159 212 19
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-02-14', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 60, 'TPpct': Decimal('0'), 'FP': 159, 'FPpct': Decimal('0'), 'TN': 212, 'TNpct': Decimal('0'), 'FN': 19, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.37735849056603776'), 'evaluation_timeperiod': '2022-02-14_2022-02-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.664+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.042316224}, {'rsi': 0.03829288}, {'close_diff': 0.04019685}, {'daily_volume_vol_diff_pct30': 0.034507502}, {'range_vol_diff5': 0.036585797}, {'SPY_diff': 0.035194483}, {'threeD_stddev50': 0.040871687}, {'close_diff3': 0.036337405}, {'min_volume_vol_diff_pct': 0.031489108}, {'month': 0.043305792}, {'return_vol_240M': 0.04496046}, {'range_vol': 0.03923039}, {'rsi5': 0.0383945}, {'roc': 0.0375927}, {'SPY_3D': 0.039873198}, {'roc5': 0.03774056}, {'roc_diff': 0.04868402}, {'price_25DDiff': 0.03962641}, {'daily_volume_vol_diff_pct': 0.034084387}, {'price_10DDiff': 0.03728405}, {'SPY_1D': 0.040278338}, {'hour_volume_vol_diff': 0.0338461}, {'hour_volume_vol_diff_pct': 0.035910565}, {'return_vol_10D': 0.070973694}, {'SPY_5D': 0.042422898}]"}
# {'deployment_date': datetime.datetime(2022, 2, 21, 0, 0), 'dataset_end': datetime.datetime(2022, 2, 11, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    25197
# 1    24539
# Name: count, dtype: int64
# 151 67 71 71
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-02-21', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 151, 'TPpct': Decimal('0'), 'FP': 67, 'FPpct': Decimal('0'), 'TN': 71, 'TNpct': Decimal('0'), 'FN': 71, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.253731343283582'), 'evaluation_timeperiod': '2022-02-21_2022-02-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.66+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.04386456}, {'rsi': 0.03944096}, {'close_diff': 0.03762789}, {'daily_volume_vol_diff_pct30': 0.036648802}, {'range_vol_diff5': 0.036563758}, {'SPY_diff': 0.033848118}, {'threeD_stddev50': 0.042335}, {'close_diff3': 0.036737338}, {'min_volume_vol_diff_pct': 0.031227594}, {'month': 0.04254527}, {'return_vol_240M': 0.0430583}, {'range_vol': 0.041065168}, {'rsi5': 0.035916895}, {'roc': 0.040081672}, {'SPY_3D': 0.039666306}, {'roc5': 0.038150307}, {'roc_diff': 0.050082285}, {'price_25DDiff': 0.04135979}, {'daily_volume_vol_diff_pct': 0.03314279}, {'price_10DDiff': 0.036432195}, {'SPY_1D': 0.04060854}, {'hour_volume_vol_diff': 0.03306993}, {'hour_volume_vol_diff_pct': 0.03470774}, {'return_vol_10D': 0.07013875}, {'SPY_5D': 0.041679952}]"}
# {'deployment_date': datetime.datetime(2022, 2, 28, 0, 0), 'dataset_end': datetime.datetime(2022, 2, 18, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    25318
# 1    24658
# Name: count, dtype: int64
# 40 151 229 30
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-02-28', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 40, 'TPpct': Decimal('0'), 'FP': 151, 'FPpct': Decimal('0'), 'TN': 229, 'TNpct': Decimal('0'), 'FN': 30, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.26490066225165565'), 'evaluation_timeperiod': '2022-02-28_2022-03-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.654+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.042984802}, {'rsi': 0.039774567}, {'close_diff': 0.03904631}, {'daily_volume_vol_diff_pct30': 0.03451789}, {'range_vol_diff5': 0.03626019}, {'SPY_diff': 0.03430644}, {'threeD_stddev50': 0.04042985}, {'close_diff3': 0.036752693}, {'min_volume_vol_diff_pct': 0.030731102}, {'month': 0.04321308}, {'return_vol_240M': 0.043291386}, {'range_vol': 0.04008056}, {'rsi5': 0.038306113}, {'roc': 0.039406057}, {'SPY_3D': 0.040611904}, {'roc5': 0.04016535}, {'roc_diff': 0.05011915}, {'price_25DDiff': 0.039524667}, {'daily_volume_vol_diff_pct': 0.03377502}, {'price_10DDiff': 0.036476757}, {'SPY_1D': 0.03880563}, {'hour_volume_vol_diff': 0.034499623}, {'hour_volume_vol_diff_pct': 0.03507834}, {'return_vol_10D': 0.07052329}, {'SPY_5D': 0.041319236}]"}
# {'deployment_date': datetime.datetime(2022, 3, 7, 0, 0), 'dataset_end': datetime.datetime(2022, 2, 25, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    25412
# 1    24756
# Name: count, dtype: int64
# 130 59 125 136
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-03-07', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 130, 'TPpct': Decimal('0'), 'FP': 59, 'FPpct': Decimal('0'), 'TN': 125, 'TNpct': Decimal('0'), 'FN': 136, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.2033898305084745'), 'evaluation_timeperiod': '2022-03-07_2022-03-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.656+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.04207937}, {'rsi': 0.037949562}, {'close_diff': 0.039341453}, {'daily_volume_vol_diff_pct30': 0.035504185}, {'range_vol_diff5': 0.03617295}, {'SPY_diff': 0.03531166}, {'threeD_stddev50': 0.04127133}, {'close_diff3': 0.037516877}, {'min_volume_vol_diff_pct': 0.029788988}, {'month': 0.042277556}, {'return_vol_240M': 0.04565228}, {'range_vol': 0.039136145}, {'rsi5': 0.036432415}, {'roc': 0.03991675}, {'SPY_3D': 0.038410228}, {'roc5': 0.037641175}, {'roc_diff': 0.050863985}, {'price_25DDiff': 0.039060734}, {'daily_volume_vol_diff_pct': 0.034185782}, {'price_10DDiff': 0.037075184}, {'SPY_1D': 0.042045444}, {'hour_volume_vol_diff': 0.033896435}, {'hour_volume_vol_diff_pct': 0.033314835}, {'return_vol_10D': 0.07282859}, {'SPY_5D': 0.04232606}]"}
# {'deployment_date': datetime.datetime(2022, 3, 14, 0, 0), 'dataset_end': datetime.datetime(2022, 3, 4, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    25529
# 1    24879
# Name: count, dtype: int64
# 87 31 105 227
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-03-14', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 87, 'TPpct': Decimal('0'), 'FP': 31, 'FPpct': Decimal('0'), 'TN': 105, 'TNpct': Decimal('0'), 'FN': 227, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.806451612903226'), 'evaluation_timeperiod': '2022-03-14_2022-03-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.649+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.04241274}, {'rsi': 0.040351383}, {'close_diff': 0.039152976}, {'daily_volume_vol_diff_pct30': 0.03384757}, {'range_vol_diff5': 0.036955927}, {'SPY_diff': 0.033852205}, {'threeD_stddev50': 0.041982237}, {'close_diff3': 0.036987793}, {'min_volume_vol_diff_pct': 0.030559875}, {'month': 0.04162854}, {'return_vol_240M': 0.04330099}, {'range_vol': 0.03932238}, {'rsi5': 0.036796495}, {'roc': 0.03858547}, {'SPY_3D': 0.038643513}, {'roc5': 0.038037937}, {'roc_diff': 0.050011586}, {'price_25DDiff': 0.04086039}, {'daily_volume_vol_diff_pct': 0.0347042}, {'price_10DDiff': 0.036434423}, {'SPY_1D': 0.04084903}, {'hour_volume_vol_diff': 0.035805453}, {'hour_volume_vol_diff_pct': 0.03397059}, {'return_vol_10D': 0.072036415}, {'SPY_5D': 0.04290988}]"}
# {'deployment_date': datetime.datetime(2022, 3, 21, 0, 0), 'dataset_end': datetime.datetime(2022, 3, 11, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    25652
# 1    24996
# Name: count, dtype: int64
# 41 68 153 188
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-03-21', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 41, 'TPpct': Decimal('0'), 'FP': 68, 'FPpct': Decimal('0'), 'TN': 153, 'TNpct': Decimal('0'), 'FN': 188, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6029411764705882'), 'evaluation_timeperiod': '2022-03-21_2022-03-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.651+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.042048223}, {'rsi': 0.03980194}, {'close_diff': 0.037709687}, {'daily_volume_vol_diff_pct30': 0.035218105}, {'range_vol_diff5': 0.03670857}, {'SPY_diff': 0.033883985}, {'threeD_stddev50': 0.041721262}, {'close_diff3': 0.037796523}, {'min_volume_vol_diff_pct': 0.031106286}, {'month': 0.042976767}, {'return_vol_240M': 0.045477893}, {'range_vol': 0.03959134}, {'rsi5': 0.037129328}, {'roc': 0.039285682}, {'SPY_3D': 0.04009891}, {'roc5': 0.037835896}, {'roc_diff': 0.05067522}, {'price_25DDiff': 0.03930987}, {'daily_volume_vol_diff_pct': 0.033520482}, {'price_10DDiff': 0.038035963}, {'SPY_1D': 0.03995632}, {'hour_volume_vol_diff': 0.034735024}, {'hour_volume_vol_diff_pct': 0.03313685}, {'return_vol_10D': 0.07170059}, {'SPY_5D': 0.04053918}]"}
# {'deployment_date': datetime.datetime(2022, 3, 28, 0, 0), 'dataset_end': datetime.datetime(2022, 3, 18, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    25771
# 1    25117
# Name: count, dtype: int64
# 77 122 188 63
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-03-28', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 77, 'TPpct': Decimal('0'), 'FP': 122, 'FPpct': Decimal('0'), 'TN': 188, 'TNpct': Decimal('0'), 'FN': 63, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6311475409836066'), 'evaluation_timeperiod': '2022-03-28_2022-04-01', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.655+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.04462509}, {'rsi': 0.039130047}, {'close_diff': 0.037920818}, {'daily_volume_vol_diff_pct30': 0.03516506}, {'range_vol_diff5': 0.03638063}, {'SPY_diff': 0.03384398}, {'threeD_stddev50': 0.041593667}, {'close_diff3': 0.03702322}, {'min_volume_vol_diff_pct': 0.029950198}, {'month': 0.04326309}, {'return_vol_240M': 0.044545427}, {'range_vol': 0.040704124}, {'rsi5': 0.0382301}, {'roc': 0.038210817}, {'SPY_3D': 0.0396801}, {'roc5': 0.038658287}, {'roc_diff': 0.050325193}, {'price_25DDiff': 0.03937018}, {'daily_volume_vol_diff_pct': 0.034339093}, {'price_10DDiff': 0.03592961}, {'SPY_1D': 0.0410756}, {'hour_volume_vol_diff': 0.03431547}, {'hour_volume_vol_diff_pct': 0.033077095}, {'return_vol_10D': 0.0703899}, {'SPY_5D': 0.042253256}]"}
# {'deployment_date': datetime.datetime(2022, 4, 4, 0, 0), 'dataset_end': datetime.datetime(2022, 3, 25, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    25889
# 1    25239
# Name: count, dtype: int64
# 146 165 114 25
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-04-04', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 146, 'TPpct': Decimal('0'), 'FP': 165, 'FPpct': Decimal('0'), 'TN': 114, 'TNpct': Decimal('0'), 'FN': 25, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8848484848484849'), 'evaluation_timeperiod': '2022-04-04_2022-04-08', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.655+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.0417506}, {'rsi': 0.039033547}, {'close_diff': 0.04009274}, {'daily_volume_vol_diff_pct30': 0.034859076}, {'range_vol_diff5': 0.037081033}, {'SPY_diff': 0.033509374}, {'threeD_stddev50': 0.042032402}, {'close_diff3': 0.036942698}, {'min_volume_vol_diff_pct': 0.030840108}, {'month': 0.04286634}, {'return_vol_240M': 0.04477836}, {'range_vol': 0.03996189}, {'rsi5': 0.038024165}, {'roc': 0.038816094}, {'SPY_3D': 0.037980236}, {'roc5': 0.037565965}, {'roc_diff': 0.051060725}, {'price_25DDiff': 0.040651754}, {'daily_volume_vol_diff_pct': 0.032892797}, {'price_10DDiff': 0.03661735}, {'SPY_1D': 0.04094018}, {'hour_volume_vol_diff': 0.034583464}, {'hour_volume_vol_diff_pct': 0.034588777}, {'return_vol_10D': 0.07030632}, {'SPY_5D': 0.04222407}]"}
# {'deployment_date': datetime.datetime(2022, 4, 11, 0, 0), 'dataset_end': datetime.datetime(2022, 4, 1, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    26010
# 1    25358
# Name: count, dtype: int64
# 89 125 111 35
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-04-11', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 89, 'TPpct': Decimal('0'), 'FP': 125, 'FPpct': Decimal('0'), 'TN': 111, 'TNpct': Decimal('0'), 'FN': 35, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.712'), 'evaluation_timeperiod': '2022-04-11_2022-04-15', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.652+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.043099027}, {'rsi': 0.038207337}, {'close_diff': 0.039904352}, {'daily_volume_vol_diff_pct30': 0.03554274}, {'range_vol_diff5': 0.03670798}, {'SPY_diff': 0.034203332}, {'threeD_stddev50': 0.04122248}, {'close_diff3': 0.037269633}, {'min_volume_vol_diff_pct': 0.03201863}, {'month': 0.043411262}, {'return_vol_240M': 0.045256622}, {'range_vol': 0.03906105}, {'rsi5': 0.037913825}, {'roc': 0.038964678}, {'SPY_3D': 0.0388581}, {'roc5': 0.038925882}, {'roc_diff': 0.05003852}, {'price_25DDiff': 0.03855537}, {'daily_volume_vol_diff_pct': 0.035523616}, {'price_10DDiff': 0.03719699}, {'SPY_1D': 0.039760407}, {'hour_volume_vol_diff': 0.034650914}, {'hour_volume_vol_diff_pct': 0.03335257}, {'return_vol_10D': 0.06871625}, {'SPY_5D': 0.04163837}]"}
# {'deployment_date': datetime.datetime(2022, 4, 18, 0, 0), 'dataset_end': datetime.datetime(2022, 4, 8, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    26135
# 1    25473
# Name: count, dtype: int64
# 67 168 166 49
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-04-18', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 67, 'TPpct': Decimal('0'), 'FP': 168, 'FPpct': Decimal('0'), 'TN': 166, 'TNpct': Decimal('0'), 'FN': 49, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.39880952380952384'), 'evaluation_timeperiod': '2022-04-18_2022-04-22', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.65+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.04018495}, {'rsi': 0.03921495}, {'close_diff': 0.03965873}, {'daily_volume_vol_diff_pct30': 0.03569065}, {'range_vol_diff5': 0.035400666}, {'SPY_diff': 0.033393875}, {'threeD_stddev50': 0.042088397}, {'close_diff3': 0.03864155}, {'min_volume_vol_diff_pct': 0.031230478}, {'month': 0.04228321}, {'return_vol_240M': 0.04714444}, {'range_vol': 0.039771028}, {'rsi5': 0.037091594}, {'roc': 0.03881909}, {'SPY_3D': 0.039333254}, {'roc5': 0.038750395}, {'roc_diff': 0.04866247}, {'price_25DDiff': 0.039523803}, {'daily_volume_vol_diff_pct': 0.03335841}, {'price_10DDiff': 0.038167924}, {'SPY_1D': 0.039222486}, {'hour_volume_vol_diff': 0.03497306}, {'hour_volume_vol_diff_pct': 0.035822794}, {'return_vol_10D': 0.06899233}, {'SPY_5D': 0.042579446}]"}
# {'deployment_date': datetime.datetime(2022, 4, 25, 0, 0), 'dataset_end': datetime.datetime(2022, 4, 15, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    26238
# 1    25562
# Name: count, dtype: int64
# 140 97 132 81
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-04-25', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 140, 'TPpct': Decimal('0'), 'FP': 97, 'FPpct': Decimal('0'), 'TN': 132, 'TNpct': Decimal('0'), 'FN': 81, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.443298969072165'), 'evaluation_timeperiod': '2022-04-25_2022-04-29', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.649+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.042348303}, {'rsi': 0.039957926}, {'close_diff': 0.039036695}, {'daily_volume_vol_diff_pct30': 0.03528223}, {'range_vol_diff5': 0.035378948}, {'SPY_diff': 0.033562906}, {'threeD_stddev50': 0.041699987}, {'close_diff3': 0.036808986}, {'min_volume_vol_diff_pct': 0.030022679}, {'month': 0.04313106}, {'return_vol_240M': 0.04367867}, {'range_vol': 0.038873404}, {'rsi5': 0.038005944}, {'roc': 0.03748531}, {'SPY_3D': 0.039631642}, {'roc5': 0.038532488}, {'roc_diff': 0.049975954}, {'price_25DDiff': 0.039958894}, {'daily_volume_vol_diff_pct': 0.03633906}, {'price_10DDiff': 0.038268097}, {'SPY_1D': 0.04011146}, {'hour_volume_vol_diff': 0.03525466}, {'hour_volume_vol_diff_pct': 0.035668712}, {'return_vol_10D': 0.068706706}, {'SPY_5D': 0.04227919}]"}
# {'deployment_date': datetime.datetime(2022, 5, 2, 0, 0), 'dataset_end': datetime.datetime(2022, 4, 22, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    26370
# 1    25670
# Name: count, dtype: int64
# 82 120 191 57
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-05-02', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 82, 'TPpct': Decimal('0'), 'FP': 120, 'FPpct': Decimal('0'), 'TN': 191, 'TNpct': Decimal('0'), 'FN': 57, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6833333333333333'), 'evaluation_timeperiod': '2022-05-02_2022-05-06', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.645+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.04317}, {'rsi': 0.037626583}, {'close_diff': 0.03886766}, {'daily_volume_vol_diff_pct30': 0.03418122}, {'range_vol_diff5': 0.036895394}, {'SPY_diff': 0.033761524}, {'threeD_stddev50': 0.04140418}, {'close_diff3': 0.036760736}, {'min_volume_vol_diff_pct': 0.03071604}, {'month': 0.0422495}, {'return_vol_240M': 0.045547467}, {'range_vol': 0.040377397}, {'rsi5': 0.037683006}, {'roc': 0.0401474}, {'SPY_3D': 0.040060878}, {'roc5': 0.03779954}, {'roc_diff': 0.051350646}, {'price_25DDiff': 0.039172918}, {'daily_volume_vol_diff_pct': 0.035494756}, {'price_10DDiff': 0.037007596}, {'SPY_1D': 0.039591204}, {'hour_volume_vol_diff': 0.03477689}, {'hour_volume_vol_diff_pct': 0.03320419}, {'return_vol_10D': 0.07142095}, {'SPY_5D': 0.040732395}]"}
# {'deployment_date': datetime.datetime(2022, 5, 9, 0, 0), 'dataset_end': datetime.datetime(2022, 4, 29, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    26493
# 1    25787
# Name: count, dtype: int64
# 170 118 100 62
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-05-09', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 170, 'TPpct': Decimal('0'), 'FP': 118, 'FPpct': Decimal('0'), 'TN': 100, 'TNpct': Decimal('0'), 'FN': 62, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.4406779661016949'), 'evaluation_timeperiod': '2022-05-09_2022-05-13', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.645+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.041257177}, {'rsi': 0.038417768}, {'close_diff': 0.040349483}, {'daily_volume_vol_diff_pct30': 0.03624763}, {'range_vol_diff5': 0.037150066}, {'SPY_diff': 0.03434564}, {'threeD_stddev50': 0.042048886}, {'close_diff3': 0.036775205}, {'min_volume_vol_diff_pct': 0.031096388}, {'month': 0.042399563}, {'return_vol_240M': 0.045280464}, {'range_vol': 0.039457306}, {'rsi5': 0.03702207}, {'roc': 0.039439626}, {'SPY_3D': 0.03984116}, {'roc5': 0.037428387}, {'roc_diff': 0.050346885}, {'price_25DDiff': 0.040241804}, {'daily_volume_vol_diff_pct': 0.034921814}, {'price_10DDiff': 0.037913002}, {'SPY_1D': 0.040755633}, {'hour_volume_vol_diff': 0.032413956}, {'hour_volume_vol_diff_pct': 0.0330781}, {'return_vol_10D': 0.070417896}, {'SPY_5D': 0.041354075}]"}
# {'deployment_date': datetime.datetime(2022, 5, 16, 0, 0), 'dataset_end': datetime.datetime(2022, 5, 6, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    26615
# 1    25905
# Name: count, dtype: int64
# 93 61 231 65
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-05-16', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 93, 'TPpct': Decimal('0'), 'FP': 61, 'FPpct': Decimal('0'), 'TN': 231, 'TNpct': Decimal('0'), 'FN': 65, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.5245901639344261'), 'evaluation_timeperiod': '2022-05-16_2022-05-20', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.641+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.04364375}, {'rsi': 0.038896192}, {'close_diff': 0.039841447}, {'daily_volume_vol_diff_pct30': 0.034215067}, {'range_vol_diff5': 0.036487255}, {'SPY_diff': 0.034563616}, {'threeD_stddev50': 0.04150511}, {'close_diff3': 0.037114978}, {'min_volume_vol_diff_pct': 0.030703658}, {'month': 0.04297761}, {'return_vol_240M': 0.04669058}, {'range_vol': 0.039824717}, {'rsi5': 0.038104985}, {'roc': 0.039596356}, {'SPY_3D': 0.037966657}, {'roc5': 0.036698006}, {'roc_diff': 0.050658777}, {'price_25DDiff': 0.040552426}, {'daily_volume_vol_diff_pct': 0.033090148}, {'price_10DDiff': 0.036838688}, {'SPY_1D': 0.03818692}, {'hour_volume_vol_diff': 0.035952188}, {'hour_volume_vol_diff_pct': 0.03397758}, {'return_vol_10D': 0.070049405}, {'SPY_5D': 0.04186388}]"}
# {'deployment_date': datetime.datetime(2022, 5, 23, 0, 0), 'dataset_end': datetime.datetime(2022, 5, 13, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    26740
# 1    26020
# Name: count, dtype: int64
# 108 36 141 165
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-05-23', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 108, 'TPpct': Decimal('0'), 'FP': 36, 'FPpct': Decimal('0'), 'TN': 141, 'TNpct': Decimal('0'), 'FN': 165, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.0'), 'evaluation_timeperiod': '2022-05-23_2022-05-27', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.643+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.042400293}, {'rsi': 0.039602865}, {'close_diff': 0.03894281}, {'daily_volume_vol_diff_pct30': 0.035069127}, {'range_vol_diff5': 0.03649696}, {'SPY_diff': 0.034636673}, {'threeD_stddev50': 0.04140575}, {'close_diff3': 0.03705325}, {'min_volume_vol_diff_pct': 0.029351145}, {'month': 0.042916168}, {'return_vol_240M': 0.044800494}, {'range_vol': 0.039000608}, {'rsi5': 0.03773568}, {'roc': 0.038609557}, {'SPY_3D': 0.039982058}, {'roc5': 0.037530992}, {'roc_diff': 0.050191972}, {'price_25DDiff': 0.040855464}, {'daily_volume_vol_diff_pct': 0.033918355}, {'price_10DDiff': 0.038065493}, {'SPY_1D': 0.03947084}, {'hour_volume_vol_diff': 0.03525476}, {'hour_volume_vol_diff_pct': 0.03484437}, {'return_vol_10D': 0.07050051}, {'SPY_5D': 0.041363835}]"}
# {'deployment_date': datetime.datetime(2022, 5, 30, 0, 0), 'dataset_end': datetime.datetime(2022, 5, 20, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    26858
# 1    26142
# Name: count, dtype: int64
# 41 87 154 78
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-05-30', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 41, 'TPpct': Decimal('0'), 'FP': 87, 'FPpct': Decimal('0'), 'TN': 154, 'TNpct': Decimal('0'), 'FN': 78, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.47126436781609193'), 'evaluation_timeperiod': '2022-05-30_2022-06-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.64+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.04199538}, {'rsi': 0.038360205}, {'close_diff': 0.039959185}, {'daily_volume_vol_diff_pct30': 0.035308566}, {'range_vol_diff5': 0.03648634}, {'SPY_diff': 0.03266566}, {'threeD_stddev50': 0.04122727}, {'close_diff3': 0.037575558}, {'min_volume_vol_diff_pct': 0.030616777}, {'month': 0.042033713}, {'return_vol_240M': 0.04523263}, {'range_vol': 0.039422356}, {'rsi5': 0.038683455}, {'roc': 0.040127173}, {'SPY_3D': 0.039233062}, {'roc5': 0.03913551}, {'roc_diff': 0.05063359}, {'price_25DDiff': 0.040510945}, {'daily_volume_vol_diff_pct': 0.03245953}, {'price_10DDiff': 0.03736625}, {'SPY_1D': 0.04034776}, {'hour_volume_vol_diff': 0.033824157}, {'hour_volume_vol_diff_pct': 0.034468826}, {'return_vol_10D': 0.07074655}, {'SPY_5D': 0.041579522}]"}
# {'deployment_date': datetime.datetime(2022, 6, 6, 0, 0), 'dataset_end': datetime.datetime(2022, 5, 27, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    26972
# 1    26268
# Name: count, dtype: int64
# 12 183 220 35
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2022-06-06', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 12, 'TPpct': Decimal('0'), 'FP': 183, 'FPpct': Decimal('0'), 'TN': 220, 'TNpct': Decimal('0'), 'FN': 35, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.06557377049180328'), 'evaluation_timeperiod': '2022-06-06_2022-06-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.642+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.041527644}, {'rsi': 0.03796037}, {'close_diff': 0.039960437}, {'daily_volume_vol_diff_pct30': 0.03622844}, {'range_vol_diff5': 0.037077438}, {'SPY_diff': 0.033782743}, {'threeD_stddev50': 0.041147616}, {'close_diff3': 0.03796561}, {'min_volume_vol_diff_pct': 0.030722689}, {'month': 0.04351027}, {'return_vol_240M': 0.04627806}, {'range_vol': 0.038868513}, {'rsi5': 0.03726762}, {'roc': 0.038938228}, {'SPY_3D': 0.03864909}, {'roc5': 0.037760045}, {'roc_diff': 0.049934782}, {'price_25DDiff': 0.040284973}, {'daily_volume_vol_diff_pct': 0.03435668}, {'price_10DDiff': 0.036938794}, {'SPY_1D': 0.04057824}, {'hour_volume_vol_diff': 0.034844987}, {'hour_volume_vol_diff_pct': 0.033610415}, {'return_vol_10D': 0.06983466}, {'SPY_5D': 0.04197166}]"}
# {'deployment_date': datetime.datetime(2022, 6, 13, 0, 0), 'dataset_end': datetime.datetime(2022, 6, 3, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    27071
# 1    26361
# Name: count, dtype: int64
# 99 143 123 85
# ...
# {'deployment_date': datetime.datetime(2023, 11, 6, 0, 0), 'dataset_end': datetime.datetime(2023, 10, 27, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    35553
# 1    34775
# Name: count, dtype: int64
# 125 81 100 144
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2023-11-06', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 125, 'TPpct': Decimal('0'), 'FP': 81, 'FPpct': Decimal('0'), 'TN': 100, 'TNpct': Decimal('0'), 'FN': 144, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.5432098765432098'), 'evaluation_timeperiod': '2023-11-06_2023-11-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.622+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.043593682}, {'rsi': 0.039535664}, {'close_diff': 0.03690867}, {'daily_volume_vol_diff_pct30': 0.03556956}, {'range_vol_diff5': 0.03591673}, {'SPY_diff': 0.034637857}, {'threeD_stddev50': 0.041417807}, {'close_diff3': 0.035754487}, {'min_volume_vol_diff_pct': 0.030223154}, {'month': 0.043911964}, {'return_vol_240M': 0.044090558}, {'range_vol': 0.040778212}, {'rsi5': 0.040283617}, {'roc': 0.039108057}, {'SPY_3D': 0.039756544}, {'roc5': 0.038179666}, {'roc_diff': 0.046976354}, {'price_25DDiff': 0.04030737}, {'daily_volume_vol_diff_pct': 0.034186434}, {'price_10DDiff': 0.03571774}, {'SPY_1D': 0.04087564}, {'hour_volume_vol_diff': 0.034083743}, {'hour_volume_vol_diff_pct': 0.03413585}, {'return_vol_10D': 0.07311835}, {'SPY_5D': 0.040932354}]"}
# {'deployment_date': datetime.datetime(2023, 11, 13, 0, 0), 'dataset_end': datetime.datetime(2023, 11, 3, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    35677
# 1    34891
# Name: count, dtype: int64
# 105 35 145 165
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2023-11-13', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 105, 'TPpct': Decimal('0'), 'FP': 35, 'FPpct': Decimal('0'), 'TN': 145, 'TNpct': Decimal('0'), 'FN': 165, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.0'), 'evaluation_timeperiod': '2023-11-13_2023-11-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.627+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.0435985}, {'rsi': 0.039733853}, {'close_diff': 0.03708695}, {'daily_volume_vol_diff_pct30': 0.0359304}, {'range_vol_diff5': 0.035459235}, {'SPY_diff': 0.033133384}, {'threeD_stddev50': 0.040549777}, {'close_diff3': 0.036519904}, {'min_volume_vol_diff_pct': 0.02996539}, {'month': 0.04335986}, {'return_vol_240M': 0.045804385}, {'range_vol': 0.041781817}, {'rsi5': 0.040593434}, {'roc': 0.040196653}, {'SPY_3D': 0.039212823}, {'roc5': 0.036859132}, {'roc_diff': 0.047279883}, {'price_25DDiff': 0.040238425}, {'daily_volume_vol_diff_pct': 0.03467734}, {'price_10DDiff': 0.038208816}, {'SPY_1D': 0.03999005}, {'hour_volume_vol_diff': 0.033842474}, {'hour_volume_vol_diff_pct': 0.035909895}, {'return_vol_10D': 0.06961565}, {'SPY_5D': 0.040451966}]"}
# {'deployment_date': datetime.datetime(2023, 11, 20, 0, 0), 'dataset_end': datetime.datetime(2023, 11, 10, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    35786
# 1    35022
# Name: count, dtype: int64
# 59 85 159 57
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2023-11-20', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 59, 'TPpct': Decimal('0'), 'FP': 85, 'FPpct': Decimal('0'), 'TN': 159, 'TNpct': Decimal('0'), 'FN': 57, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6941176470588235'), 'evaluation_timeperiod': '2023-11-20_2023-11-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.628+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.043446958}, {'rsi': 0.039709717}, {'close_diff': 0.03680802}, {'daily_volume_vol_diff_pct30': 0.035724305}, {'range_vol_diff5': 0.035943314}, {'SPY_diff': 0.03487511}, {'threeD_stddev50': 0.03997497}, {'close_diff3': 0.035560638}, {'min_volume_vol_diff_pct': 0.029086886}, {'month': 0.045680482}, {'return_vol_240M': 0.04700647}, {'range_vol': 0.041352563}, {'rsi5': 0.039884426}, {'roc': 0.038414173}, {'SPY_3D': 0.039038863}, {'roc5': 0.037933514}, {'roc_diff': 0.047348324}, {'price_25DDiff': 0.040087353}, {'daily_volume_vol_diff_pct': 0.034076974}, {'price_10DDiff': 0.037637837}, {'SPY_1D': 0.041055176}, {'hour_volume_vol_diff': 0.033336468}, {'hour_volume_vol_diff_pct': 0.03565972}, {'return_vol_10D': 0.07026804}, {'SPY_5D': 0.040089708}]"}
# {'deployment_date': datetime.datetime(2023, 11, 27, 0, 0), 'dataset_end': datetime.datetime(2023, 11, 17, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    35923
# 1    35125
# Name: count, dtype: int64
# 200 116 61 73
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2023-11-27', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 200, 'TPpct': Decimal('0'), 'FP': 116, 'FPpct': Decimal('0'), 'TN': 61, 'TNpct': Decimal('0'), 'FN': 73, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.7241379310344827'), 'evaluation_timeperiod': '2023-11-27_2023-12-01', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.631+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.04325749}, {'rsi': 0.039501216}, {'close_diff': 0.037470102}, {'daily_volume_vol_diff_pct30': 0.0360991}, {'range_vol_diff5': 0.037070893}, {'SPY_diff': 0.0340989}, {'threeD_stddev50': 0.04173242}, {'close_diff3': 0.034808245}, {'min_volume_vol_diff_pct': 0.029557504}, {'month': 0.044139944}, {'return_vol_240M': 0.04765326}, {'range_vol': 0.040541146}, {'rsi5': 0.039018095}, {'roc': 0.039414834}, {'SPY_3D': 0.03994927}, {'roc5': 0.037123725}, {'roc_diff': 0.047076903}, {'price_25DDiff': 0.03917828}, {'daily_volume_vol_diff_pct': 0.034383133}, {'price_10DDiff': 0.03603723}, {'SPY_1D': 0.04177816}, {'hour_volume_vol_diff': 0.03403819}, {'hour_volume_vol_diff_pct': 0.035751812}, {'return_vol_10D': 0.0689211}, {'SPY_5D': 0.04139904}]"}
# {'deployment_date': datetime.datetime(2023, 12, 4, 0, 0), 'dataset_end': datetime.datetime(2023, 11, 24, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    36012
# 1    35228
# Name: count, dtype: int64
# 168 43 87 152
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2023-12-04', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 168, 'TPpct': Decimal('0'), 'FP': 43, 'FPpct': Decimal('0'), 'TN': 87, 'TNpct': Decimal('0'), 'FN': 152, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.9069767441860463'), 'evaluation_timeperiod': '2023-12-04_2023-12-08', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.629+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.043065365}, {'rsi': 0.039429095}, {'close_diff': 0.037144102}, {'daily_volume_vol_diff_pct30': 0.036275707}, {'range_vol_diff5': 0.037076555}, {'SPY_diff': 0.03314894}, {'threeD_stddev50': 0.040640067}, {'close_diff3': 0.03460032}, {'min_volume_vol_diff_pct': 0.028937714}, {'month': 0.045032717}, {'return_vol_240M': 0.04748704}, {'range_vol': 0.040371403}, {'rsi5': 0.040467676}, {'roc': 0.03886363}, {'SPY_3D': 0.038880214}, {'roc5': 0.03799782}, {'roc_diff': 0.047393173}, {'price_25DDiff': 0.040374517}, {'daily_volume_vol_diff_pct': 0.03361747}, {'price_10DDiff': 0.038910527}, {'SPY_1D': 0.04043406}, {'hour_volume_vol_diff': 0.034520745}, {'hour_volume_vol_diff_pct': 0.03416215}, {'return_vol_10D': 0.070211746}, {'SPY_5D': 0.040957253}]"}
# {'deployment_date': datetime.datetime(2023, 12, 11, 0, 0), 'dataset_end': datetime.datetime(2023, 12, 1, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    36132
# 1    35348
# Name: count, dtype: int64
# 103 12 80 255
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2023-12-11', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 103, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 80, 'TNpct': Decimal('0'), 'FN': 255, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('8.583333333333334'), 'evaluation_timeperiod': '2023-12-11_2023-12-15', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.63+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.043508325}, {'rsi': 0.039054453}, {'close_diff': 0.035335798}, {'daily_volume_vol_diff_pct30': 0.035288934}, {'range_vol_diff5': 0.036813}, {'SPY_diff': 0.034677036}, {'threeD_stddev50': 0.040837158}, {'close_diff3': 0.03645857}, {'min_volume_vol_diff_pct': 0.030590462}, {'month': 0.043722734}, {'return_vol_240M': 0.04715612}, {'range_vol': 0.04108196}, {'rsi5': 0.038170192}, {'roc': 0.03938613}, {'SPY_3D': 0.038412597}, {'roc5': 0.03659967}, {'roc_diff': 0.048362758}, {'price_25DDiff': 0.040786736}, {'daily_volume_vol_diff_pct': 0.034108154}, {'price_10DDiff': 0.037202764}, {'SPY_1D': 0.041602634}, {'hour_volume_vol_diff': 0.03491047}, {'hour_volume_vol_diff_pct': 0.034563247}, {'return_vol_10D': 0.0715147}, {'SPY_5D': 0.039855335}]"}
# {'deployment_date': datetime.datetime(2023, 12, 18, 0, 0), 'dataset_end': datetime.datetime(2023, 12, 8, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    36250
# 1    35470
# Name: count, dtype: int64
# 45 63 274 68
# {'model_name': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'deployment_date': '2023-12-18', 'algorithm_type': 'xgboost', 'dataset': 'LOSERSC:TSSIM1_CDVOLTL15_custHypTP0.5', 'TP': 45, 'TPpct': Decimal('0'), 'FP': 63, 'FPpct': Decimal('0'), 'TN': 274, 'TNpct': Decimal('0'), 'FN': 68, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.7142857142857143'), 'evaluation_timeperiod': '2023-12-18_2023-12-22', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['oneD_stddev50', 'rsi', 'close_diff', 'daily_volume_vol_diff_pct30', 'range_vol_diff5', 'SPY_diff', 'threeD_stddev50', 'close_diff3', 'min_volume_vol_diff_pct', 'month', 'return_vol_240M', 'range_vol', 'rsi5', 'roc', 'SPY_3D', 'roc5', 'roc_diff', 'price_25DDiff', 'daily_volume_vol_diff_pct', 'price_10DDiff', 'SPY_1D', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_10D', 'SPY_5D']"}, 'target': '1.631+three_max_vol', 'feature_importances': "[{'oneD_stddev50': 0.042853538}, {'rsi': 0.039424896}, {'close_diff': 0.03656036}, {'daily_volume_vol_diff_pct30': 0.035306122}, {'range_vol_diff5': 0.036653306}, {'SPY_diff': 0.03412106}, {'threeD_stddev50': 0.039953843}, {'close_diff3': 0.035684504}, {'min_volume_vol_diff_pct': 0.03024512}, {'month': 0.044728134}, {'return_vol_240M': 0.046008456}, {'range_vol': 0.041861925}, {'rsi5': 0.0396981}, {'roc': 0.03931687}, {'SPY_3D': 0.039741017}, {'roc5': 0.03812269}, {'roc_diff': 0.0469826}, {'price_25DDiff': 0.040198874}, {'daily_volume_vol_diff_pct': 0.034025796}, {'price_10DDiff': 0.037561443}, {'SPY_1D': 0.040635083}, {'hour_volume_vol_diff': 0.035806064}, {'hour_volume_vol_diff_pct': 0.034975193}, {'return_vol_10D': 0.07047348}, {'SPY_5D': 0.03906151}]"}

# %%
# def convert_timestamp_est(timestamp):
#     # Create a naive datetime object from the UNIX timestamp
#     dt_naive = datetime.utcfromtimestamp(timestamp)
#     # Convert the naive datetime object to a timezone-aware one (UTC)
#     dt_utc = pytz.utc.localize(dt_naive)
#     # Convert the UTC datetime to EST
#     dt_est = dt_utc.astimezone(pytz.timezone('US/Eastern'))
    
#     return dt_est


# data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/GAIN/2018-01-01_2023-12-23_trainTL10.csv')
# data['date'] = data['date'].astype(str)
# data['date'] = data['date'].apply(lambda x: x.split(" ")[0])
# data = data.drop(data[data['date'] == 'nan'].index)
# # data.drop('date',axis=1,inplace=True)
# # data['date'] = data['t'].apply(lambda x: convert_timestamp_est(x))
# # data.drop(['one_pct','three_pct','Unnamed: 0.2', "Unnamed: 0","Unnamed: 0.1", "date_x","date_y",'vw_x', 'n_x', 'return_vol_240M_x', 'volume_vol_240M_x', 'return_vol_450M_x', 'volume_vol_450M_x', 'min_vol_diff_x', 'min_vol_diff_pct_x', 'min_volume_vol_diff_x', 'min_volume_vol_diff_pct_x', 'return_vol_8H_x', 'return_vol_16H_x', 'volume_vol_8H_x', 'volume_vol_16H_x', 'hour_vol_diff_x', 'hour_vol_diff_pct_x', 'hour_volume_vol_diff_x', 'hour_volume_vol_diff_pct_x', 'return_vol_5D_x', 'return_vol_10D_x', 'return_vol_30D_x', 'volume_vol_5D_x', 'volume_vol_10D_x', 'volume_vol_30D_x', 'daily_vol_diff_x', 'daily_vol_diff_pct_x', 'daily_vol_diff30_x', 'daily_vol_diff_pct30_x', 'daily_volume_vol_diff_x', 'daily_volume_vol_diff_pct_x', 'daily_volume_vol_diff30_x', 'daily_volume_vol_diff_pct30_x', 'vw_y', 'n_y', 'return_vol_240M_y', 'volume_vol_240M_y', 'return_vol_450M_y', 'volume_vol_450M_y', 'min_vol_diff_y', 'min_vol_diff_pct_y', 'min_volume_vol_diff_y', 'min_volume_vol_diff_pct_y', 'return_vol_8H_y', 'return_vol_16H_y', 'volume_vol_8H_y', 'volume_vol_16H_y', 'hour_vol_diff_y', 'hour_vol_diff_pct_y', 'hour_volume_vol_diff_y', 'hour_volume_vol_diff_pct_y', 'return_vol_5D_y', 'return_vol_10D_y', 'return_vol_30D_y', 'volume_vol_5D_y', 'volume_vol_10D_y', 'volume_vol_30D_y', 'daily_vol_diff_y', 'daily_vol_diff_pct_y', 'daily_vol_diff30_y', 'daily_vol_diff_pct30_y', 'daily_volume_vol_diff_y', 'daily_volume_vol_diff_pct_y', 'daily_volume_vol_diff30_y', 'daily_volume_vol_diff_pct30_y'], axis=1, inplace=True)
# data['roc_diff'] = data['roc'] - data['roc5'] 
# data['range_vol_diff5'] = (data['range_vol'] - data['range_vol5MA'])
# data['close_diff_deviation3'] = abs(data['close_diff3'])/(data['threeD_stddev50']*100)
# data['close_diff_deviation'] = abs(data['close_diff'])/(data['oneD_stddev50']*100)
# data.dropna(subset=['date'], inplace=True)
# data['date'] = data['date'].apply(lambda x: datetime.strptime(x,"%Y-%m-%d"))
# data['day_of_week'] = data['date'].apply(lambda x: x.dayofweek).astype(int)
# data['day_of_month'] = data['date'].apply(lambda x: x.day).astype(int)
# data['month'] = data['date'].apply(lambda x: x.month).astype(int)
# data['year'] = data['date'].apply(lambda x: x.year).astype(int)
# data.replace([np.inf, -np.inf], 0, inplace=True)
# data.to_csv(f'/Users/charlesmiller/Documents/model_tester_data/GAIN/2018-01-01_2023-12-23_trainTL10.csv', index=False)

# %%
# def run_temporal_simulation(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date):
#     tp_avg_list = []
#     gross_accuracy_list = []
#     # fn_list = []
#     # tn_list = []
    
#     hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
#     dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
#     for date in dates_list:
#         tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams)
#         tp_avg_list.append(tp)
#         gross_accuracy_list.append((tp-fp))

#     return tp_avg_list, gross_accuracy_list

# %%
# number_of_simulations = 200
# now = datetime.now()
# title = 'GAIN'
# # total_feature_list = ['hour','year','month','day_of_month',
# #        'price7', 'price14', 'adjusted_volume', 'vol7', 'vol14',
# #        'rsi', 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close',
# #        'oneD_returns_close', 'range_vol', 'range_vol5MA', 'range_vol10MA',
# #        'range_vol25MA', 'oneD_stddev50', 'threeD_stddev50', 'cmf',
# #        'close_diff', 'close_diff3', 'close_diff5', 'v_diff_pct', 'adx',
# #        'volume_10MA', 'volume_25MA', 'price_10MA', 'price_25MA',
# #        'volume_10DDiff', 'volume_25DDiff', 'price_10DDiff', 'price_25DDiff',
# #        'day_of_week','close_diff_deviation3','close_diff_deviation','roc_diff','range_vol_diff5',
# #        'return_vol_240M', 'volume_vol_240M', 'return_vol_450M', 'volume_vol_450M', 'min_vol_diff', 'min_vol_diff_pct', 'min_volume_vol_diff', 
# #        'min_volume_vol_diff_pct', 'return_vol_8H', 'return_vol_16H', 'volume_vol_8H', 'volume_vol_16H', 'hour_vol_diff', 'hour_vol_diff_pct', 'hour_volume_vol_diff', 
# #        'hour_volume_vol_diff_pct', 'return_vol_5D', 'return_vol_10D', 'return_vol_30D', 'volume_vol_5D', 'volume_vol_10D', 'volume_vol_30D', 'daily_vol_diff', 'daily_vol_diff_pct',
# #        'daily_vol_diff30', 'daily_vol_diff_pct30', 'daily_volume_vol_diff', 'daily_volume_vol_diff_pct', 'daily_volume_vol_diff30', 'daily_volume_vol_diff_pct30']
# testing_features = ['hour', 'day_of_week','month','daily_vol_diff30', 'hour_volume_vol_diff', 'roc_diff', 
# 'range_vol', 'volume_vol_8H','close_diff3', 'close_diff5',
# 'range_vol_diff5', 'SPY_diff', 'SPY_diff3','SPY_diff5','rsi5','roc5',
# 'return_vol_10D', 'return_vol_8H', 'return_vol_16H', 'return_vol_450M', 'adx', 
# 'rsi','roc','rsi3','roc3','daily_vol_diff', 'SPY_1D','SPY_3D', 'SPY_5D','min_vol_diff', 'return_vol_240M', 
# 'price_25DDiff', 'price_10DDiff','daily_vol_diff_pct30','threeD_stddev50',
# 'price7', 'daily_vol_diff_pct', 'oneD_stddev50', 'volume_vol_16H','min_volume_vol_diff_pct',
# 'close_diff_deviation','close_diff','daily_volume_vol_diff_pct','hour_volume_vol_diff_pct','daily_volume_vol_diff_pct30']

# target_label = 'three_max'
# target_value = .03
# results_array = []

# i = 0
# while i < number_of_simulations:
#        model_name = f"{title}_temporal_simulation_{i}"
#        print(model_name)
#        random_int = random.randint(20, 35)
#        features = random.sample(testing_features, random_int)
#        print(features)
#        tp_avg_list, gross_accuracy_list = run_temporal_simulation(features, target_label, target_value, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2022,10,3), evaluation_end_date=datetime(2023,10,2))        
#        tp_avg = sum(tp_avg_list)/len(tp_avg_list)
#        gross_accuracy = sum(gross_accuracy_list)/len(gross_accuracy_list)
#        print(tp_avg, gross_accuracy)
#        print()
#        results_array.append({"model_name": model_name, "features": features, "tp_avg": tp_avg, "gross_accuracy": gross_accuracy,"num_features": random_int})
#        i += 1

# results_df = pd.DataFrame(results_array)
# results_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
