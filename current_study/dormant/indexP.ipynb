# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler
import pytz

# %%
s3 = boto3.client('s3')

training_bucket = "icarus-research-data"
training_prefix = 'training_datasets/expanded_1d_datasets/'

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

# %%
def create_training_data_local(key_list, prefix, bucket_name,title, start_date, end_date):
    df_list = []
    hours = [10,11,12,13,14,15]
    start = start_date.split(' ')[0]
    end = end_date.split(' ')[0]
    # print(file_key)
    for key in key_list:
        for hour in hours:
            try:
                data = s3.get_object(Bucket=bucket_name, Key=f'{prefix}{key}/{hour}.csv')
                df = pd.read_csv(data.get("Body")) 
                df_list.append(df)
                df['hour'] = hour
            except:
                continue

    data = pd.concat(df_list)
    data.reset_index(drop=True, inplace=True)
    data['dt'] = pd.to_datetime(data['date'])
    data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek)
    data = data.round(3)
    data.replace([np.inf, -np.inf], 0, inplace=True)

    data.to_csv(f'/Users/charlesmiller/Documents/INDEX/{start}_{end}.csv', index=False)

    return data

# %%
def pull_training_data_local(end_date,start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/INDEX/2018-01-01_2023-10-28.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data


def pull_validation_data_local(end_date,start_date):
    start_str = start_date.strftime('%Y-%m-%d %H:%M:%S%z').split(' ')[0]
    end_str = end_date.strftime('%Y-%m-%d %H:%M:%S%z').split(' ')[0]
    start_dt = datetime.strptime(start_str, '%Y-%m-%d')
    end_dt = datetime.strptime(end_str, '%Y-%m-%d')
    data = pd.read_csv(f'/Users/charlesmiller/Documents/INDEX/2018-01-01_2023-10-28.csv')
    data['dt'] = pd.to_datetime(data['date'])
    print(data['dt'])
    data = data.loc[data['dt'] <= end_dt]
    data = data.loc[data['dt'] >= start_dt]
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data

# %%
def build_date_list(start_date, end_date):
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_validation_dates_local(deployment_date):
    end_date = deployment_date + timedelta(days=5)
    return end_date

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] < target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] < target_value).astype(int)

    scaler = StandardScaler()
    
    X = dataset[features]
    y = dataset['label']

    print(y.value_counts())
    X_validate = validation_dataset[features]
    y_validate = validation_dataset['label']

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    probabilities = xgb_model.predict_proba(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, str(fi_list), predictions, probabilities

def train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] > target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] > target_value).astype(int)

    dataset = dataset.round(3)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features]
    y = dataset['label']

    X_validate = validation_dataset[features]
    y_validate = validation_dataset['label']

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,"str(fi_list)", predictions, "probabilities"

# %%
def model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
    # dates = build_date_list(start_date, end_date)
    # key_list = build_query_keys(dates)
    validation_end_date = build_validation_dates_local(deployment_date)
    # validation_keys = build_query_keys_validation(deployment_date)
    # validation_dataset = create_validation_data(validation_keys, 'fixed_alerts_full/new_features/big_fish_stable/', 'inv-alerts')
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    # else:
    #     dataset = create_training_data_v2(key_list, 'fixed_alerts_full/new_features/big_fish/', 'inv-alerts')
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
    validation_dataset['probabilities'] = probabilities[:,1]
    validation_dataset['predictions'] = predictions
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    return response

def model_runner_data(model_name, dataset_name, title, features, target_label, target_value,start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams):
    dates = build_date_list(start_date, end_date)
    key_list = build_query_keys(dates)
    dataset = create_training_data_local(key_list, 'fixed_alerts_full/new_features/indexes/', 'inv-alerts', title, start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
    return dataset


def model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,end_date,deployment_date,hyperparams):
    validation_end_date = build_validation_dates_local(deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    return tp, fp, fn, tn

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=10),
            "dataset_start": datetime(2020,1,1)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

# %%
#ma_cont_classifier_EXPvDiff_HistData
#ma_cont_classifier_EXPvDiff_HistData_NOVAL
#ma_cont_classifier_EXPvDiffDYNTUN_HistData_NOVAL
#'ma_cont_classifier_EXPvDiffDYNTUN_HistData_NOVAL

model_name = 'INDEXP:TSSIM1_best231110_custHypP15_2018'
dataset_name = 'TSSIM1_best231110_custHypP15_2018'
title = 'INDEXP_3D'
hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
features = ['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']
target_label = 'three_min'
target_value = -.015

dataset_start_date = datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')) 
dates_list = build_evaluation_period(datetime(2022,10,3,tzinfo=pytz.timezone('US/Eastern')), datetime(2023,10,14,tzinfo=pytz.timezone('US/Eastern')))

# date = dates_list[-1]
# response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
for date in dates_list:
    response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])
# Out:
# label
# 0    12479
# 1     8545
# Name: count, dtype: int64
# 3 11 29 29
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2022-10-24', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 3, 'TPpct': Decimal('0'), 'FP': 11, 'FPpct': Decimal('0'), 'TN': 29, 'TNpct': Decimal('0'), 'FN': 29, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.2727272727272727'), 'evaluation_timeperiod': '2022-10-24_2022-10-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.100711815}, {'price_25MA': 0.08286102}, {'range_vol5MA': 0.19382513}, {'close_diff_deviation3': 0.06607933}, {'range_vol25MA': 0.09265914}, {'adx': 0.07923362}, {'close_diff5': 0.073348954}, {'threeD_stddev50': 0.09199886}, {'oneD_returns_close': 0.07131239}, {'oneD_stddev50': 0.08252992}, {'range_vol_diff5': 0.06543982}]"}
# label
# 0    12522
# 1     8592
# Name: count, dtype: int64
# 23 27 1 39
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2022-10-31', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 23, 'TPpct': Decimal('0'), 'FP': 27, 'FPpct': Decimal('0'), 'TN': 1, 'TNpct': Decimal('0'), 'FN': 39, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8518518518518519'), 'evaluation_timeperiod': '2022-10-31_2022-11-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.0969876}, {'price_25MA': 0.08266302}, {'range_vol5MA': 0.19885355}, {'close_diff_deviation3': 0.067305945}, {'range_vol25MA': 0.08889904}, {'adx': 0.07514267}, {'close_diff5': 0.07476162}, {'threeD_stddev50': 0.093837224}, {'oneD_returns_close': 0.072035104}, {'oneD_stddev50': 0.07996916}, {'range_vol_diff5': 0.06954514}]"}
# label
# 0    12580
# 1     8606
# Name: count, dtype: int64
# 16 32 27 15
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2022-11-07', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 16, 'TPpct': Decimal('0'), 'FP': 32, 'FPpct': Decimal('0'), 'TN': 27, 'TNpct': Decimal('0'), 'FN': 15, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5'), 'evaluation_timeperiod': '2022-11-07_2022-11-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.10654411}, {'price_25MA': 0.0814859}, {'range_vol5MA': 0.19769059}, {'close_diff_deviation3': 0.06610904}, {'range_vol25MA': 0.09103891}, {'adx': 0.075861305}, {'close_diff5': 0.07393584}, {'threeD_stddev50': 0.08836644}, {'oneD_returns_close': 0.074066006}, {'oneD_stddev50': 0.080832064}, {'range_vol_diff5': 0.06406973}]"}
# label
# 0    12596
# 1     8680
# Name: count, dtype: int64
# 38 21 15 16
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2022-11-14', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 38, 'TPpct': Decimal('0'), 'FP': 21, 'FPpct': Decimal('0'), 'TN': 15, 'TNpct': Decimal('0'), 'FN': 16, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.8095238095238095'), 'evaluation_timeperiod': '2022-11-14_2022-11-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09709217}, {'price_25MA': 0.08273988}, {'range_vol5MA': 0.20347053}, {'close_diff_deviation3': 0.06974859}, {'range_vol25MA': 0.08611472}, {'adx': 0.073343694}, {'close_diff5': 0.071533136}, {'threeD_stddev50': 0.09099206}, {'oneD_returns_close': 0.07698281}, {'oneD_stddev50': 0.08508551}, {'range_vol_diff5': 0.06289692}]"}
# label
# 0    12653
# 1     8713
# Name: count, dtype: int64
# 18 15 25 8
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2022-11-21', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 18, 'TPpct': Decimal('0'), 'FP': 15, 'FPpct': Decimal('0'), 'TN': 25, 'TNpct': Decimal('0'), 'FN': 8, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.2'), 'evaluation_timeperiod': '2022-11-21_2022-11-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09693074}, {'price_25MA': 0.083717756}, {'range_vol5MA': 0.20841236}, {'close_diff_deviation3': 0.06481378}, {'range_vol25MA': 0.08238209}, {'adx': 0.0743809}, {'close_diff5': 0.07451448}, {'threeD_stddev50': 0.094832435}, {'oneD_returns_close': 0.075718924}, {'oneD_stddev50': 0.08336625}, {'range_vol_diff5': 0.0609302}]"}
# label
# 0    12687
# 1     8769
# Name: count, dtype: int64
# 30 36 10 14
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2022-11-28', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 30, 'TPpct': Decimal('0'), 'FP': 36, 'FPpct': Decimal('0'), 'TN': 10, 'TNpct': Decimal('0'), 'FN': 14, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8333333333333334'), 'evaluation_timeperiod': '2022-11-28_2022-12-02', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09815793}, {'price_25MA': 0.082019456}, {'range_vol5MA': 0.20794863}, {'close_diff_deviation3': 0.068503805}, {'range_vol25MA': 0.08733384}, {'adx': 0.07560891}, {'close_diff5': 0.07274985}, {'threeD_stddev50': 0.09624755}, {'oneD_returns_close': 0.07303291}, {'oneD_stddev50': 0.07750427}, {'range_vol_diff5': 0.060892772}]"}
# label
# 0    12743
# 1     8785
# Name: count, dtype: int64
# 23 40 24 3
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2022-12-05', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 23, 'TPpct': Decimal('0'), 'FP': 40, 'FPpct': Decimal('0'), 'TN': 24, 'TNpct': Decimal('0'), 'FN': 3, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.575'), 'evaluation_timeperiod': '2022-12-05_2022-12-09', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.0958112}, {'price_25MA': 0.08161775}, {'range_vol5MA': 0.21140744}, {'close_diff_deviation3': 0.0644471}, {'range_vol25MA': 0.08516285}, {'adx': 0.07605286}, {'close_diff5': 0.07140708}, {'threeD_stddev50': 0.09335982}, {'oneD_returns_close': 0.07564244}, {'oneD_stddev50': 0.082263775}, {'range_vol_diff5': 0.06282771}]"}
# label
# 0    12789
# 1     8823
# Name: count, dtype: int64
# 54 10 0 26
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2022-12-12', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 54, 'TPpct': Decimal('0'), 'FP': 10, 'FPpct': Decimal('0'), 'TN': 0, 'TNpct': Decimal('0'), 'FN': 26, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('5.4'), 'evaluation_timeperiod': '2022-12-12_2022-12-16', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09844356}, {'price_25MA': 0.08512128}, {'range_vol5MA': 0.2129555}, {'close_diff_deviation3': 0.06475376}, {'range_vol25MA': 0.08549297}, {'adx': 0.07381245}, {'close_diff5': 0.071809724}, {'threeD_stddev50': 0.09016799}, {'oneD_returns_close': 0.07166724}, {'oneD_stddev50': 0.08125785}, {'range_vol_diff5': 0.0645178}]"}
# label
# 0    12835
# 1     8867
# Name: count, dtype: int64
# 49 36 0 5
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2022-12-19', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 49, 'TPpct': Decimal('0'), 'FP': 36, 'FPpct': Decimal('0'), 'TN': 0, 'TNpct': Decimal('0'), 'FN': 5, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.3611111111111112'), 'evaluation_timeperiod': '2022-12-19_2022-12-23', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09397959}, {'price_25MA': 0.085384704}, {'range_vol5MA': 0.2062396}, {'close_diff_deviation3': 0.066911705}, {'range_vol25MA': 0.08369334}, {'adx': 0.0745563}, {'close_diff5': 0.07418238}, {'threeD_stddev50': 0.0955942}, {'oneD_returns_close': 0.07272192}, {'oneD_stddev50': 0.08331671}, {'range_vol_diff5': 0.063419476}]"}
# label
# 0    12853
# 1     8939
# Name: count, dtype: int64
# 10 38 10 14
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2022-12-26', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 10, 'TPpct': Decimal('0'), 'FP': 38, 'FPpct': Decimal('0'), 'TN': 10, 'TNpct': Decimal('0'), 'FN': 14, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.2631578947368421'), 'evaluation_timeperiod': '2022-12-26_2022-12-30', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09419792}, {'price_25MA': 0.08537866}, {'range_vol5MA': 0.20918933}, {'close_diff_deviation3': 0.06406162}, {'range_vol25MA': 0.08129418}, {'adx': 0.07521086}, {'close_diff5': 0.07610391}, {'threeD_stddev50': 0.09339228}, {'oneD_returns_close': 0.074757114}, {'oneD_stddev50': 0.086021565}, {'range_vol_diff5': 0.060392562}]"}
# label
# 0    12893
# 1     8989
# Name: count, dtype: int64
# 2 24 31 15
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-01-02', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 2, 'TPpct': Decimal('0'), 'FP': 24, 'FPpct': Decimal('0'), 'TN': 31, 'TNpct': Decimal('0'), 'FN': 15, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.08333333333333333'), 'evaluation_timeperiod': '2023-01-02_2023-01-06', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09667373}, {'price_25MA': 0.083606556}, {'range_vol5MA': 0.21124244}, {'close_diff_deviation3': 0.06561944}, {'range_vol25MA': 0.08832025}, {'adx': 0.07180286}, {'close_diff5': 0.07195589}, {'threeD_stddev50': 0.09218515}, {'oneD_returns_close': 0.071622945}, {'oneD_stddev50': 0.08283938}, {'range_vol_diff5': 0.06413135}]"}
# label
# 0    12929
# 1     9025
# Name: count, dtype: int64
# 4 14 67 5
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-01-09', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 4, 'TPpct': Decimal('0'), 'FP': 14, 'FPpct': Decimal('0'), 'TN': 67, 'TNpct': Decimal('0'), 'FN': 5, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.2857142857142857'), 'evaluation_timeperiod': '2023-01-09_2023-01-13', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09681598}, {'price_25MA': 0.08658888}, {'range_vol5MA': 0.20283791}, {'close_diff_deviation3': 0.065534815}, {'range_vol25MA': 0.08466114}, {'adx': 0.0755643}, {'close_diff5': 0.07542758}, {'threeD_stddev50': 0.08951244}, {'oneD_returns_close': 0.075089976}, {'oneD_stddev50': 0.08615729}, {'range_vol_diff5': 0.061809633}]"}
# label
# 0    12984
# 1     9042
# Name: count, dtype: int64
# 19 10 27 16
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-01-16', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 19, 'TPpct': Decimal('0'), 'FP': 10, 'FPpct': Decimal('0'), 'TN': 27, 'TNpct': Decimal('0'), 'FN': 16, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.9'), 'evaluation_timeperiod': '2023-01-16_2023-01-20', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.093828045}, {'price_25MA': 0.081986465}, {'range_vol5MA': 0.21284276}, {'close_diff_deviation3': 0.06543143}, {'range_vol25MA': 0.08252783}, {'adx': 0.07391221}, {'close_diff5': 0.07608105}, {'threeD_stddev50': 0.08967874}, {'oneD_returns_close': 0.07522892}, {'oneD_stddev50': 0.08255315}, {'range_vol_diff5': 0.06592944}]"}
# label
# 0    13068
# 1     9048
# Name: count, dtype: int64
# 19 9 46 16
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-01-23', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 19, 'TPpct': Decimal('0'), 'FP': 9, 'FPpct': Decimal('0'), 'TN': 46, 'TNpct': Decimal('0'), 'FN': 16, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.111111111111111'), 'evaluation_timeperiod': '2023-01-23_2023-01-27', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09443479}, {'price_25MA': 0.085110195}, {'range_vol5MA': 0.21112067}, {'close_diff_deviation3': 0.06795339}, {'range_vol25MA': 0.08324936}, {'adx': 0.075863}, {'close_diff5': 0.073549315}, {'threeD_stddev50': 0.09355792}, {'oneD_returns_close': 0.07075704}, {'oneD_stddev50': 0.08115066}, {'range_vol_diff5': 0.063253656}]"}
# label
# 0    13102
# 1     9086
# Name: count, dtype: int64
# 18 11 49 12
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-01-30', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 18, 'TPpct': Decimal('0'), 'FP': 11, 'FPpct': Decimal('0'), 'TN': 49, 'TNpct': Decimal('0'), 'FN': 12, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.6363636363636365'), 'evaluation_timeperiod': '2023-01-30_2023-02-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.0964126}, {'price_25MA': 0.0863211}, {'range_vol5MA': 0.20930076}, {'close_diff_deviation3': 0.06397676}, {'range_vol25MA': 0.08430414}, {'adx': 0.07590033}, {'close_diff5': 0.07294979}, {'threeD_stddev50': 0.0923811}, {'oneD_returns_close': 0.07816059}, {'oneD_stddev50': 0.07719579}, {'range_vol_diff5': 0.063097075}]"}
# label
# 0    13163
# 1     9115
# Name: count, dtype: int64
# 21 21 19 29
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-02-06', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 21, 'TPpct': Decimal('0'), 'FP': 21, 'FPpct': Decimal('0'), 'TN': 19, 'TNpct': Decimal('0'), 'FN': 29, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0'), 'evaluation_timeperiod': '2023-02-06_2023-02-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09833907}, {'price_25MA': 0.08590182}, {'range_vol5MA': 0.20430695}, {'close_diff_deviation3': 0.068092816}, {'range_vol25MA': 0.08273136}, {'adx': 0.0761577}, {'close_diff5': 0.07259622}, {'threeD_stddev50': 0.09411786}, {'oneD_returns_close': 0.07366943}, {'oneD_stddev50': 0.08163466}, {'range_vol_diff5': 0.06245201}]"}
# label
# 0    13231
# 1     9137
# Name: count, dtype: int64
# 20 24 8 38
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-02-13', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 20, 'TPpct': Decimal('0'), 'FP': 24, 'FPpct': Decimal('0'), 'TN': 8, 'TNpct': Decimal('0'), 'FN': 38, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8333333333333334'), 'evaluation_timeperiod': '2023-02-13_2023-02-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.0971723}, {'price_25MA': 0.08547627}, {'range_vol5MA': 0.20340611}, {'close_diff_deviation3': 0.067645095}, {'range_vol25MA': 0.079766355}, {'adx': 0.07463793}, {'close_diff5': 0.07642766}, {'threeD_stddev50': 0.09732848}, {'oneD_returns_close': 0.075286835}, {'oneD_stddev50': 0.08118577}, {'range_vol_diff5': 0.06166718}]"}
# label
# 0    13257
# 1     9201
# Name: count, dtype: int64
# 17 37 11 7
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-02-20', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 17, 'TPpct': Decimal('0'), 'FP': 37, 'FPpct': Decimal('0'), 'TN': 11, 'TNpct': Decimal('0'), 'FN': 7, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.4594594594594595'), 'evaluation_timeperiod': '2023-02-20_2023-02-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.100364424}, {'price_25MA': 0.08293556}, {'range_vol5MA': 0.19857706}, {'close_diff_deviation3': 0.06836138}, {'range_vol25MA': 0.08284621}, {'adx': 0.075616136}, {'close_diff5': 0.07487625}, {'threeD_stddev50': 0.09253948}, {'oneD_returns_close': 0.07232876}, {'oneD_stddev50': 0.0864773}, {'range_vol_diff5': 0.06507751}]"}
# label
# 0    13307
# 1     9241
# Name: count, dtype: int64
# 16 43 12 19
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-02-27', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 16, 'TPpct': Decimal('0'), 'FP': 43, 'FPpct': Decimal('0'), 'TN': 12, 'TNpct': Decimal('0'), 'FN': 19, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.37209302325581395'), 'evaluation_timeperiod': '2023-02-27_2023-03-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.095055155}, {'price_25MA': 0.08428692}, {'range_vol5MA': 0.20173028}, {'close_diff_deviation3': 0.06707191}, {'range_vol25MA': 0.0843887}, {'adx': 0.07536371}, {'close_diff5': 0.07272264}, {'threeD_stddev50': 0.09559266}, {'oneD_returns_close': 0.076869026}, {'oneD_stddev50': 0.084369816}, {'range_vol_diff5': 0.062549174}]"}
# label
# 0    13337
# 1     9283
# Name: count, dtype: int64
# 56 3 0 31
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-03-06', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 56, 'TPpct': Decimal('0'), 'FP': 3, 'FPpct': Decimal('0'), 'TN': 0, 'TNpct': Decimal('0'), 'FN': 31, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('18.666666666666668'), 'evaluation_timeperiod': '2023-03-06_2023-03-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09286782}, {'price_25MA': 0.08393356}, {'range_vol5MA': 0.21056482}, {'close_diff_deviation3': 0.0654814}, {'range_vol25MA': 0.08325442}, {'adx': 0.07550164}, {'close_diff5': 0.074242994}, {'threeD_stddev50': 0.088939264}, {'oneD_returns_close': 0.07522758}, {'oneD_stddev50': 0.08750303}, {'range_vol_diff5': 0.062483437}]"}
# label
# 0    13401
# 1     9309
# Name: count, dtype: int64
# 22 25 39 4
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-03-13', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 22, 'TPpct': Decimal('0'), 'FP': 25, 'FPpct': Decimal('0'), 'TN': 39, 'TNpct': Decimal('0'), 'FN': 4, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.88'), 'evaluation_timeperiod': '2023-03-13_2023-03-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09286692}, {'price_25MA': 0.085010864}, {'range_vol5MA': 0.2151565}, {'close_diff_deviation3': 0.0644956}, {'range_vol25MA': 0.09036626}, {'adx': 0.07520356}, {'close_diff5': 0.07093125}, {'threeD_stddev50': 0.09017348}, {'oneD_returns_close': 0.06999869}, {'oneD_stddev50': 0.08396991}, {'range_vol_diff5': 0.061826922}]"}
# label
# 0    13410
# 1     9390
# Name: count, dtype: int64
# 32 23 18 17
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-03-20', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 32, 'TPpct': Decimal('0'), 'FP': 23, 'FPpct': Decimal('0'), 'TN': 18, 'TNpct': Decimal('0'), 'FN': 17, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.391304347826087'), 'evaluation_timeperiod': '2023-03-20_2023-03-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09451929}, {'price_25MA': 0.08348379}, {'range_vol5MA': 0.211788}, {'close_diff_deviation3': 0.063649245}, {'range_vol25MA': 0.08641346}, {'adx': 0.07431885}, {'close_diff5': 0.07285438}, {'threeD_stddev50': 0.09179764}, {'oneD_returns_close': 0.07506483}, {'oneD_stddev50': 0.0837441}, {'range_vol_diff5': 0.062366504}]"}
# label
# 0    13461
# 1     9429
# Name: count, dtype: int64
# 2 16 61 11
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-03-27', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 2, 'TPpct': Decimal('0'), 'FP': 16, 'FPpct': Decimal('0'), 'TN': 61, 'TNpct': Decimal('0'), 'FN': 11, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.125'), 'evaluation_timeperiod': '2023-03-27_2023-03-31', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.092622556}, {'price_25MA': 0.086034596}, {'range_vol5MA': 0.21136785}, {'close_diff_deviation3': 0.06427592}, {'range_vol25MA': 0.0822855}, {'adx': 0.07654793}, {'close_diff5': 0.07290106}, {'threeD_stddev50': 0.09500294}, {'oneD_returns_close': 0.07347656}, {'oneD_stddev50': 0.08505792}, {'range_vol_diff5': 0.06042714}]"}
# label
# 0    13501
# 1     9479
# Name: count, dtype: int64
# 12 11 41 8
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-04-03', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 12, 'TPpct': Decimal('0'), 'FP': 11, 'FPpct': Decimal('0'), 'TN': 41, 'TNpct': Decimal('0'), 'FN': 8, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0909090909090908'), 'evaluation_timeperiod': '2023-04-03_2023-04-07', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.098750085}, {'price_25MA': 0.08453323}, {'range_vol5MA': 0.20316954}, {'close_diff_deviation3': 0.06452873}, {'range_vol25MA': 0.08391467}, {'adx': 0.07493699}, {'close_diff5': 0.07505531}, {'threeD_stddev50': 0.092662714}, {'oneD_returns_close': 0.07303243}, {'oneD_stddev50': 0.085730545}, {'range_vol_diff5': 0.06368575}]"}
# label
# 0    13586
# 1     9484
# Name: count, dtype: int64
# 2 20 66 2
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-04-10', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 2, 'TPpct': Decimal('0'), 'FP': 20, 'FPpct': Decimal('0'), 'TN': 66, 'TNpct': Decimal('0'), 'FN': 2, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.1'), 'evaluation_timeperiod': '2023-04-10_2023-04-14', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09280491}, {'price_25MA': 0.086621165}, {'range_vol5MA': 0.20215718}, {'close_diff_deviation3': 0.06612681}, {'range_vol25MA': 0.08619113}, {'adx': 0.077055514}, {'close_diff5': 0.072081245}, {'threeD_stddev50': 0.09071839}, {'oneD_returns_close': 0.07932604}, {'oneD_stddev50': 0.08586553}, {'range_vol_diff5': 0.061052047}]"}
# label
# 0    13647
# 1     9513
# Name: count, dtype: int64
# 11 10 43 26
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-04-17', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 11, 'TPpct': Decimal('0'), 'FP': 10, 'FPpct': Decimal('0'), 'TN': 43, 'TNpct': Decimal('0'), 'FN': 26, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.1'), 'evaluation_timeperiod': '2023-04-17_2023-04-21', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09383305}, {'price_25MA': 0.08468047}, {'range_vol5MA': 0.21783012}, {'close_diff_deviation3': 0.06575697}, {'range_vol25MA': 0.08205736}, {'adx': 0.07466961}, {'close_diff5': 0.06937597}, {'threeD_stddev50': 0.092543654}, {'oneD_returns_close': 0.07551166}, {'oneD_stddev50': 0.0814794}, {'range_vol_diff5': 0.06226175}]"}
# label
# 0    13716
# 1     9516
# Name: count, dtype: int64
# 2 0 55 33
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-04-24', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 2, 'TPpct': Decimal('0'), 'FP': 0, 'FPpct': Decimal('0'), 'TN': 55, 'TNpct': Decimal('0'), 'FN': 33, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0'), 'evaluation_timeperiod': '2023-04-24_2023-04-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09375822}, {'price_25MA': 0.085651495}, {'range_vol5MA': 0.2114548}, {'close_diff_deviation3': 0.063028574}, {'range_vol25MA': 0.08315772}, {'adx': 0.07496532}, {'close_diff5': 0.073798925}, {'threeD_stddev50': 0.09653935}, {'oneD_returns_close': 0.06991576}, {'oneD_stddev50': 0.08330208}, {'range_vol_diff5': 0.064427786}]"}
# label
# 0    13785
# 1     9537
# Name: count, dtype: int64
# 4 14 29 43
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-05-01', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 4, 'TPpct': Decimal('0'), 'FP': 14, 'FPpct': Decimal('0'), 'TN': 29, 'TNpct': Decimal('0'), 'FN': 43, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.2857142857142857'), 'evaluation_timeperiod': '2023-05-01_2023-05-05', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.096821986}, {'price_25MA': 0.08830688}, {'range_vol5MA': 0.1966636}, {'close_diff_deviation3': 0.0667301}, {'range_vol25MA': 0.08198143}, {'adx': 0.07837604}, {'close_diff5': 0.07386779}, {'threeD_stddev50': 0.09387703}, {'oneD_returns_close': 0.073705405}, {'oneD_stddev50': 0.08420686}, {'range_vol_diff5': 0.06546292}]"}
# label
# 0    13833
# 1     9579
# Name: count, dtype: int64
# 0 12 77 1
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-05-08', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 77, 'TNpct': Decimal('0'), 'FN': 1, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.0'), 'evaluation_timeperiod': '2023-05-08_2023-05-12', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09616711}, {'price_25MA': 0.08534203}, {'range_vol5MA': 0.21075173}, {'close_diff_deviation3': 0.06780123}, {'range_vol25MA': 0.08267316}, {'adx': 0.07460565}, {'close_diff5': 0.07370936}, {'threeD_stddev50': 0.08652859}, {'oneD_returns_close': 0.07564186}, {'oneD_stddev50': 0.0854289}, {'range_vol_diff5': 0.061350238}]"}
# label
# 0    13871
# 1     9631
# Name: count, dtype: int64
# 1 4 71 14
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-05-15', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 1, 'TPpct': Decimal('0'), 'FP': 4, 'FPpct': Decimal('0'), 'TN': 71, 'TNpct': Decimal('0'), 'FN': 14, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.25'), 'evaluation_timeperiod': '2023-05-15_2023-05-19', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09241825}, {'price_25MA': 0.08597955}, {'range_vol5MA': 0.19770516}, {'close_diff_deviation3': 0.06751824}, {'range_vol25MA': 0.08382243}, {'adx': 0.07632702}, {'close_diff5': 0.07376182}, {'threeD_stddev50': 0.091528796}, {'oneD_returns_close': 0.073933646}, {'oneD_stddev50': 0.092061415}, {'range_vol_diff5': 0.0649436}]"}
# label
# 0    13955
# 1     9637
# Name: count, dtype: int64
# 0 6 49 35
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-05-22', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 49, 'TNpct': Decimal('0'), 'FN': 35, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.0'), 'evaluation_timeperiod': '2023-05-22_2023-05-26', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09062274}, {'price_25MA': 0.08733223}, {'range_vol5MA': 0.19976752}, {'close_diff_deviation3': 0.06731692}, {'range_vol25MA': 0.08362049}, {'adx': 0.07616306}, {'close_diff5': 0.07318372}, {'threeD_stddev50': 0.0931197}, {'oneD_returns_close': 0.07572536}, {'oneD_stddev50': 0.08626747}, {'range_vol_diff5': 0.066880785}]"}
# label
# 0    14043
# 1     9639
# Name: count, dtype: int64
# 5 12 48 7
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-05-29', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 5, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 48, 'TNpct': Decimal('0'), 'FN': 7, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.4166666666666667'), 'evaluation_timeperiod': '2023-05-29_2023-06-02', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09580067}, {'price_25MA': 0.08344595}, {'range_vol5MA': 0.19404687}, {'close_diff_deviation3': 0.06790134}, {'range_vol25MA': 0.08612392}, {'adx': 0.07847258}, {'close_diff5': 0.07350607}, {'threeD_stddev50': 0.093001634}, {'oneD_returns_close': 0.077455945}, {'oneD_stddev50': 0.08670286}, {'range_vol_diff5': 0.0635421}]"}
# label
# 0    14089
# 1     9683
# Name: count, dtype: int64
# 12 7 69 2
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-06-05', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 12, 'TPpct': Decimal('0'), 'FP': 7, 'FPpct': Decimal('0'), 'TN': 69, 'TNpct': Decimal('0'), 'FN': 2, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.7142857142857142'), 'evaluation_timeperiod': '2023-06-05_2023-06-09', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09231172}, {'price_25MA': 0.08571912}, {'range_vol5MA': 0.21526855}, {'close_diff_deviation3': 0.06761302}, {'range_vol25MA': 0.08325555}, {'adx': 0.07435863}, {'close_diff5': 0.07365552}, {'threeD_stddev50': 0.09271864}, {'oneD_returns_close': 0.070863225}, {'oneD_stddev50': 0.08251278}, {'range_vol_diff5': 0.06172325}]"}
# label
# 0    14152
# 1     9692
# Name: count, dtype: int64
# 11 4 60 15
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-06-12', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 11, 'TPpct': Decimal('0'), 'FP': 4, 'FPpct': Decimal('0'), 'TN': 60, 'TNpct': Decimal('0'), 'FN': 15, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.75'), 'evaluation_timeperiod': '2023-06-12_2023-06-16', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.091369644}, {'price_25MA': 0.08824659}, {'range_vol5MA': 0.19948798}, {'close_diff_deviation3': 0.06890691}, {'range_vol25MA': 0.08725424}, {'adx': 0.07678508}, {'close_diff5': 0.07020706}, {'threeD_stddev50': 0.09633927}, {'oneD_returns_close': 0.071213946}, {'oneD_stddev50': 0.0892453}, {'range_vol_diff5': 0.06094398}]"}
# label
# 0    14221
# 1     9713
# Name: count, dtype: int64
# 7 14 28 23
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-06-19', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 7, 'TPpct': Decimal('0'), 'FP': 14, 'FPpct': Decimal('0'), 'TN': 28, 'TNpct': Decimal('0'), 'FN': 23, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5'), 'evaluation_timeperiod': '2023-06-19_2023-06-23', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09458504}, {'price_25MA': 0.0851036}, {'range_vol5MA': 0.19889967}, {'close_diff_deviation3': 0.06583946}, {'range_vol25MA': 0.086241156}, {'adx': 0.07962295}, {'close_diff5': 0.072075516}, {'threeD_stddev50': 0.09420029}, {'oneD_returns_close': 0.07665505}, {'oneD_stddev50': 0.084530525}, {'range_vol_diff5': 0.062246785}]"}
# label
# 0    14297
# 1     9727
# Name: count, dtype: int64
# 0 9 80 1
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-06-26', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 9, 'FPpct': Decimal('0'), 'TN': 80, 'TNpct': Decimal('0'), 'FN': 1, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.0'), 'evaluation_timeperiod': '2023-06-26_2023-06-30', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.094882704}, {'price_25MA': 0.08499567}, {'range_vol5MA': 0.20219356}, {'close_diff_deviation3': 0.06781114}, {'range_vol25MA': 0.087173104}, {'adx': 0.07412769}, {'close_diff5': 0.0705723}, {'threeD_stddev50': 0.09429074}, {'oneD_returns_close': 0.0711417}, {'oneD_stddev50': 0.08612337}, {'range_vol_diff5': 0.06668806}]"}
# label
# 0    14329
# 1     9767
# Name: count, dtype: int64
# 9 12 35 10
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-07-03', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 9, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 35, 'TNpct': Decimal('0'), 'FN': 10, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.75'), 'evaluation_timeperiod': '2023-07-03_2023-07-07', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09727919}, {'price_25MA': 0.08452002}, {'range_vol5MA': 0.20015153}, {'close_diff_deviation3': 0.06713709}, {'range_vol25MA': 0.08920082}, {'adx': 0.077003404}, {'close_diff5': 0.071026415}, {'threeD_stddev50': 0.09240028}, {'oneD_returns_close': 0.072494484}, {'oneD_stddev50': 0.08515549}, {'range_vol_diff5': 0.06363122}]"}
# label
# 0    14416
# 1     9770
# Name: count, dtype: int64
# 4 24 62 0
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-07-10', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 4, 'TPpct': Decimal('0'), 'FP': 24, 'FPpct': Decimal('0'), 'TN': 62, 'TNpct': Decimal('0'), 'FN': 0, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.16666666666666666'), 'evaluation_timeperiod': '2023-07-10_2023-07-14', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09491544}, {'price_25MA': 0.086492}, {'range_vol5MA': 0.20382974}, {'close_diff_deviation3': 0.06726875}, {'range_vol25MA': 0.083716415}, {'adx': 0.0767892}, {'close_diff5': 0.07238682}, {'threeD_stddev50': 0.09407814}, {'oneD_returns_close': 0.074165046}, {'oneD_stddev50': 0.086494945}, {'range_vol_diff5': 0.05986347}]"}
# label
# 0    14465
# 1     9787
# Name: count, dtype: int64
# 0 3 70 17
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-07-17', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 3, 'FPpct': Decimal('0'), 'TN': 70, 'TNpct': Decimal('0'), 'FN': 17, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.0'), 'evaluation_timeperiod': '2023-07-17_2023-07-21', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09764321}, {'price_25MA': 0.08589623}, {'range_vol5MA': 0.20812069}, {'close_diff_deviation3': 0.06463275}, {'range_vol25MA': 0.082941145}, {'adx': 0.076193646}, {'close_diff5': 0.07068545}, {'threeD_stddev50': 0.091040656}, {'oneD_returns_close': 0.07312691}, {'oneD_stddev50': 0.08393151}, {'range_vol_diff5': 0.065787785}]"}
# label
# 0    14549
# 1     9793
# Name: count, dtype: int64
# 4 20 51 15
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-07-24', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 4, 'TPpct': Decimal('0'), 'FP': 20, 'FPpct': Decimal('0'), 'TN': 51, 'TNpct': Decimal('0'), 'FN': 15, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.2'), 'evaluation_timeperiod': '2023-07-24_2023-07-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.096368454}, {'price_25MA': 0.0837335}, {'range_vol5MA': 0.19883983}, {'close_diff_deviation3': 0.06692743}, {'range_vol25MA': 0.08530795}, {'adx': 0.07589431}, {'close_diff5': 0.07271455}, {'threeD_stddev50': 0.09442339}, {'oneD_returns_close': 0.07509567}, {'oneD_stddev50': 0.084554896}, {'range_vol_diff5': 0.06614004}]"}
# label
# 0    14622
# 1     9810
# Name: count, dtype: int64
# 9 14 19 48
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-07-31', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 9, 'TPpct': Decimal('0'), 'FP': 14, 'FPpct': Decimal('0'), 'TN': 19, 'TNpct': Decimal('0'), 'FN': 48, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6428571428571429'), 'evaluation_timeperiod': '2023-07-31_2023-08-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09598197}, {'price_25MA': 0.086655155}, {'range_vol5MA': 0.2010251}, {'close_diff_deviation3': 0.066907994}, {'range_vol25MA': 0.08248077}, {'adx': 0.07508499}, {'close_diff5': 0.07153174}, {'threeD_stddev50': 0.0927794}, {'oneD_returns_close': 0.072649986}, {'oneD_stddev50': 0.08848535}, {'range_vol_diff5': 0.06641756}]"}
# label
# 0    14703
# 1     9819
# Name: count, dtype: int64
# 18 34 23 15
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-08-07', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 18, 'TPpct': Decimal('0'), 'FP': 34, 'FPpct': Decimal('0'), 'TN': 23, 'TNpct': Decimal('0'), 'FN': 15, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5294117647058824'), 'evaluation_timeperiod': '2023-08-07_2023-08-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09418147}, {'price_25MA': 0.08748687}, {'range_vol5MA': 0.1993441}, {'close_diff_deviation3': 0.06525707}, {'range_vol25MA': 0.08632961}, {'adx': 0.07788692}, {'close_diff5': 0.07292052}, {'threeD_stddev50': 0.09340405}, {'oneD_returns_close': 0.072739534}, {'oneD_stddev50': 0.09009912}, {'range_vol_diff5': 0.060350746}]"}
# label
# 0    14738
# 1     9874
# Name: count, dtype: int64
# 45 15 9 21
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-08-14', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 45, 'TPpct': Decimal('0'), 'FP': 15, 'FPpct': Decimal('0'), 'TN': 9, 'TNpct': Decimal('0'), 'FN': 21, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.0'), 'evaluation_timeperiod': '2023-08-14_2023-08-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09413142}, {'price_25MA': 0.08555841}, {'range_vol5MA': 0.18989418}, {'close_diff_deviation3': 0.066075616}, {'range_vol25MA': 0.08651926}, {'adx': 0.076332055}, {'close_diff5': 0.07217756}, {'threeD_stddev50': 0.096202046}, {'oneD_returns_close': 0.0765155}, {'oneD_stddev50': 0.09190181}, {'range_vol_diff5': 0.06469217}]"}
# label
# 0    14789
# 1     9913
# Name: count, dtype: int64
# 6 30 36 18
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-08-21', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 6, 'TPpct': Decimal('0'), 'FP': 30, 'FPpct': Decimal('0'), 'TN': 36, 'TNpct': Decimal('0'), 'FN': 18, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.2'), 'evaluation_timeperiod': '2023-08-21_2023-08-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.0896767}, {'price_25MA': 0.08540512}, {'range_vol5MA': 0.20575944}, {'close_diff_deviation3': 0.065607846}, {'range_vol25MA': 0.08576613}, {'adx': 0.075977884}, {'close_diff5': 0.07427384}, {'threeD_stddev50': 0.09369671}, {'oneD_returns_close': 0.07364586}, {'oneD_stddev50': 0.08532644}, {'range_vol_diff5': 0.06486408}]"}
# label
# 0    14807
# 1     9985
# Name: count, dtype: int64
# 2 18 62 8
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-08-28', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 2, 'TPpct': Decimal('0'), 'FP': 18, 'FPpct': Decimal('0'), 'TN': 62, 'TNpct': Decimal('0'), 'FN': 8, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.1111111111111111'), 'evaluation_timeperiod': '2023-08-28_2023-09-01', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09698521}, {'price_25MA': 0.086093195}, {'range_vol5MA': 0.19499938}, {'close_diff_deviation3': 0.06654779}, {'range_vol25MA': 0.08637635}, {'adx': 0.07695396}, {'close_diff5': 0.07096667}, {'threeD_stddev50': 0.09504588}, {'oneD_returns_close': 0.073200926}, {'oneD_stddev50': 0.091159984}, {'range_vol_diff5': 0.061670672}]"}
# label
# 0    14873
# 1    10009
# Name: count, dtype: int64
# 0 0 53 19
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-09-04', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 0, 'FPpct': Decimal('0'), 'TN': 53, 'TNpct': Decimal('0'), 'FN': 19, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0'), 'evaluation_timeperiod': '2023-09-04_2023-09-08', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09227695}, {'price_25MA': 0.08743416}, {'range_vol5MA': 0.20500149}, {'close_diff_deviation3': 0.066707335}, {'range_vol25MA': 0.08543508}, {'adx': 0.0772042}, {'close_diff5': 0.070582084}, {'threeD_stddev50': 0.098095976}, {'oneD_returns_close': 0.07218542}, {'oneD_stddev50': 0.08228157}, {'range_vol_diff5': 0.06279577}]"}
# label
# 0    14961
# 1    10011
# Name: count, dtype: int64
# 0 0 50 22
# {'model_name': 'IndexP:TSSIM1_custHypP15_2018', 'deployment_date': '2023-09-11', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 0, 'FPpct': Decimal('0'), 'TN': 50, 'TNpct': Decimal('0'), 'FN': 22, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0'), 'evaluation_timeperiod': '2023-09-11_2023-09-15', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.015+three_min', 'feature_importances': "[{'price7': 0.09524127}, {'price_25MA': 0.0856402}, {'range_vol5MA': 0.20427456}, {'close_diff_deviation3': 0.06524072}, {'range_vol25MA': 0.08368045}, {'adx': 0.0745117}, {'close_diff5': 0.07323783}, {'threeD_stddev50': 0.09489014}, {'oneD_returns_close': 0.07332807}, {'oneD_stddev50': 0.08528028}, {'range_vol_diff5': 0.064674824}]"}
# label
# 0    15006
# 1    10038
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 19
#      16 # date = dates_list[-1]
#      17 # response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
#      18 for date in dates_list:
# ---> 19     response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])
#
# Cell In[9], line 13, in model_runner_v2(model_name, dataset_name, title, features, target_label, target_value, start_date, end_date, deployment_date, feature_str, hyperparams_str, hyperparams, local_data, dataset_start_date)
#      11 dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
#      12 validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
# ---> 13 tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
#      14 response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
#      15 validation_dataset['probabilities'] = probabilities[:,1]
#
# Cell In[8], line 19, in train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
#      17 predictions = xgb_model.predict(X_validate)
#      18 probabilities = xgb_model.predict_proba(X_validate)
# ---> 19 tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)
#      21 fi = xgb_model.feature_importances_
#      22 fi_list = []
#
# Cell In[6], line 4, in model_results_analyzer(predictions, y_validate, target_value)
#       2 result_list = []
#       3 counter = 0
# ----> 4 predictions_series = pd.Series(predictions,name='prediction_values')
#       5 for x in predictions:
#       6     if x == 1:
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/pandas/core/series.py:509, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     507         data = data.copy()
#     508 else:
# --> 509     data = sanitize_array(data, index, dtype, copy)
#     511     manager = get_option("mode.data_manager")
#     512     if manager == "block":
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/pandas/core/construction.py:607, in sanitize_array(data, index, dtype, copy, allow_2d)
#     604             subarr = cast(np.ndarray, subarr)
#     605             subarr = maybe_infer_to_datetimelike(subarr)
# --> 607 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     609 if isinstance(subarr, np.ndarray):
#     610     # at this point we should have dtype be None or subarr.dtype == dtype
#     611     dtype = cast(np.dtype, dtype)
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/pandas/core/construction.py:666, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     664     if allow_2d:
#     665         return result
# --> 666     raise ValueError(
#     667         f"Data must be 1-dimensional, got ndarray of shape {data.shape} instead"
#     668     )
#     669 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     670     # i.e. PandasDtype("O")
#     672     result = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#
# ValueError: Data must be 1-dimensional, got ndarray of shape (0, 0) instead

# %%
# def run_temporal_simulation(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date):
#     tp_avg_list = []
#     gross_accuracy_list = []
#     # fn_list = []
#     # tn_list = []
    
#     hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
#     dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
#     # date = dates_list[-1]
#     # response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
#     for date in dates_list:
#         tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams)
#         tp_avg_list.append(tp)
#         gross_accuracy_list.append((tp-fp))

#     return tp_avg_list, gross_accuracy_list

# %%
# number_of_simulations = 60
# now = datetime.now()
# title = 'INDEXP_3d'
# total_feature_list = ['hour','year','month','day_of_month',
#        'price7', 'price14', 'adjusted_volume', 'vol7', 'vol14',
#        'rsi', 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close',
#        'oneD_returns_close', 'range_vol', 'range_vol5MA', 'range_vol10MA',
#        'range_vol25MA', 'oneD_stddev50', 'threeD_stddev50', 'cmf',
#        'close_diff', 'close_diff3', 'close_diff5', 'v_diff_pct', 'adx',
#        'volume_10MA', 'volume_25MA', 'price_10MA', 'price_25MA',
#        'volume_10DDiff', 'volume_25DDiff', 'price_10DDiff', 'price_25DDiff',
#        'day_of_week','close_diff_deviation3','close_diff_deviation','roc_diff','range_vol_diff5']

# target_label = 'three_min'
# target_value = -.015
# results_array = []

# i = 0
# while i < number_of_simulations:
#        model_name = f"{title}_temporal_simulation_{i}"
#        print(model_name)
#        random_int = random.randint(8, 24)
#        features = random.sample(total_feature_list, random_int)
#        tp_avg_list, gross_accuracy_list = run_temporal_simulation(features, target_label, target_value, dataset_start_date=datetime(2018,10,1), evaluation_start_date=datetime(2022,10,24), evaluation_end_date=datetime(2023,8,11)) 
#        tp_avg = sum(tp_avg_list)/len(tp_avg_list)
#        gross_accuracy = sum(gross_accuracy_list)/len(gross_accuracy_list)
#        print(tp_avg, gross_accuracy)
#        print()
#        results_array.append({"model_name": model_name, "features": features, "tp_avg": tp_avg, "gross_accuracy": gross_accuracy,"num_features": random_int})
#        i += 1

# results_df = pd.DataFrame(results_array)
# results_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
