# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler
import pytz

# %%
s3 = boto3.client('s3')

training_bucket = "icarus-research-data"
training_prefix = 'training_datasets/expanded_1d_datasets/'

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

index = ["QQQ","SPY","IWM","TLT"]
test_lag = ["DAL","UAL","VZ","T","AAL","AMC"]
train_lag = ["AMC"]

# %%
def create_training_data_local(key_list, prefix, bucket_name, start_date, end_date):
    df_list = []
    hours = [10,11,12,13,14,15]
    start = start_date.split(' ')[0]
    end = end_date.split(' ')[0]
    # print(file_key)
    for key in key_list:
        print(key)
        for hour in hours:
            try:
                data = s3.get_object(Bucket=bucket_name, Key=f'{prefix}{key}/{hour}.csv')
                df = pd.read_csv(data.get("Body")) 
                df_list.append(df)
                df['hour'] = hour
            except:
                continue

    data = pd.concat(df_list)
    data.reset_index(drop=True, inplace=True)
    data['dt'] = pd.to_datetime(data['date'])
    data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek)
    data = data.round(3)
    data.replace([np.inf, -np.inf], 0, inplace=True)

    data.to_csv(f'/Users/charlesmiller/Documents/BF/{start}_{end}.csv', index=False)

    return data

def pull_training_data_local(end_date,start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/SF/2018-01-01_2023-10-12.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    # data = data.loc[data['dt'] >= start_date]
    data = data.loc[~data['symbol'].isin(index)]
    data = data.loc[~data['symbol'].isin(train_lag)]
    data['roc_diff'] = data['roc'] - data['roc5']
    data['range_vol_diff5'] = (data['range_vol'] - data['range_vol5MA'])
    data['close_diff_deviation3'] = abs(data['close_diff3'])/(data['threeD_stddev50']*100)
    data['close_diff_deviation'] = abs(data['close_diff'])/(data['oneD_stddev50']*100)
    data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek).astype(int)
    data['day_of_month'] = data['dt'].apply(lambda x: x.day).astype(int)
    data['month'] = data['dt'].apply(lambda x: x.month).astype(int)
    data['year'] = data['dt'].apply(lambda x: x.year).astype(int)
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data


def pull_validation_data_local(end_date,start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/SF/2018-01-01_2023-10-12.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data = data.loc[data['dt'] >= start_date]
    data = data.loc[~data['symbol'].isin(index)]
    data = data.loc[~data['symbol'].isin(test_lag)]
    data['roc_diff'] = data['roc'] - data['roc5']
    data['range_vol_diff5'] = (data['range_vol'] - data['range_vol5MA'])
    data['close_diff_deviation3'] = abs(data['close_diff3'])/(data['threeD_stddev50']*100)
    data['close_diff_deviation'] = abs(data['close_diff'])/(data['oneD_stddev50']*100)
    data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek).astype(int)
    data['day_of_month'] = data['dt'].apply(lambda x: x.day).astype(int)
    data['month'] = data['dt'].apply(lambda x: x.month).astype(int)
    data['year'] = data['dt'].apply(lambda x: x.year).astype(int)
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data

# %%
def build_date_list(start_date, end_date):
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_validation_dates_local(deployment_date):
    end_date = deployment_date + timedelta(days=5)
    return end_date

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] > target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] > target_value).astype(int)

    dataset = dataset.round(3)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features]
    y = dataset['label']

    X_validate = validation_dataset[features]
    y_validate = validation_dataset['label']

    print(y.value_counts())
    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    probabilities = xgb_model.predict_proba(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,str(fi_list), predictions, probabilities


def train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] > target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] > target_value).astype(int)

    dataset = dataset.round(3)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features]
    y = dataset['label']

    X_validate = validation_dataset[features]
    y_validate = validation_dataset['label']

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,"str(fi_list)", predictions, "probabilities"

# %%
def model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
    # dates = build_date_list(start_date, end_date)
    # key_list = build_query_keys(dates)
    validation_end_date = build_validation_dates_local(deployment_date)
    # validation_keys = build_query_keys_validation(deployment_date)
    # validation_dataset = create_validation_data(validation_keys, 'fixed_alerts_full/new_features/big_fish_stable/', 'inv-alerts')
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    # else:
    #     dataset = create_training_data_v2(key_list, 'fixed_alerts_full/new_features/big_fish/', 'inv-alerts')
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
    validation_dataset['probabilities'] = probabilities[:,1]
    validation_dataset['predictions'] = predictions
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    return response

def model_runner_data(start_date,end_date,):
    dates = build_date_list(start_date, end_date)
    key_list = build_query_keys(dates)
    print(key_list[-1])
    dataset = create_training_data_local(key_list, 'sf/vol/', 'inv-alerts', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
    return dataset


def model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,end_date,deployment_date,hyperparams):
    validation_end_date = build_validation_dates_local(deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    return tp, fp, fn, tn

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=10),
            "dataset_start": datetime(2020,1,1)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

# %%
#ma_cont_classifier_EXPvDiff_HistData
#ma_cont_classifier_EXPvDiff_HistData_NOVAL
#ma_cont_classifier_EXPvDiffDYNTUN_HistData_NOVAL
#ma_cont_classifier_EXPvDiffDYNTUN_HistData_NOVAL
model_name = 'SFC:3D_TSSIM1_expVol_custHyP15_2018'
dataset_name = '3D_TSSIM1_expVol_custHypP15_2018'
title = 'SFC_3D'
hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
features = ['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 
            'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 
            'volume_10MA',"SPY_diff","SPY_1D"]
target_label = 'three_max'
target_value = .045
dataset_start_date = datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')) 

dates_list = build_evaluation_period(datetime(2022,10,24,tzinfo=pytz.timezone('US/Eastern')), datetime(2023,10,20,tzinfo=pytz.timezone('US/Eastern')))
# date = dates_list[-1]
# response = model_runner_data(start_date=dataset_start_date,end_date=datetime(2023,10,12,tzinfo=pytz.timezone('US/Eastern')))
for date in dates_list:
    print(date)
    response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,"dataset_start_date",date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])
# Out:
# {'deployment_date': datetime.datetime(2022, 10, 24, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 10, 14, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    220433
# 1    113426
# Name: count, dtype: int64
# 362 350 939 539
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-10-24', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 362, 'TPpct': Decimal('0'), 'FP': 350, 'FPpct': Decimal('0'), 'TN': 939, 'TNpct': Decimal('0'), 'FN': 539, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0342857142857143'), 'evaluation_timeperiod': '2022-10-24_2022-10-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.020181825}, {'vol7': 0.020548012}, {'daily_volume_vol_diff30': 0.025274927}, {'price_10DDiff': 0.02855466}, {'close_diff3': 0.024306985}, {'return_vol_30D': 0.0515007}, {'hour_vol_diff_pct': 0.018359577}, {'v_diff_pct': 0.018817931}, {'month': 0.036595087}, {'hour_volume_vol_diff': 0.019330371}, {'rsi5': 0.02737007}, {'range_vol_diff5': 0.021231666}, {'daily_vol_diff30': 0.028895732}, {'rsi': 0.030017423}, {'roc_diff': 0.027566502}, {'range_vol5MA': 0.3338944}, {'price_25MA': 0.031344894}, {'year': 0.038198847}, {'min_vol_diff': 0.018547013}, {'return_vol_5D': 0.025215402}, {'daily_vol_diff': 0.025544103}, {'price14': 0.02743265}, {'adx': 0.028159926}, {'volume_10MA': 0.023254339}, {'SPY_diff': 0.01961337}, {'SPY_1D': 0.030243523}]"}
# {'deployment_date': datetime.datetime(2022, 10, 31, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 10, 21, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    221692
# 1    114687
# Name: count, dtype: int64
# 344 602 859 385
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-10-31', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 344, 'TPpct': Decimal('0'), 'FP': 602, 'FPpct': Decimal('0'), 'TN': 859, 'TNpct': Decimal('0'), 'FN': 385, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5714285714285714'), 'evaluation_timeperiod': '2022-10-31_2022-11-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.019316737}, {'vol7': 0.020516548}, {'daily_volume_vol_diff30': 0.025437089}, {'price_10DDiff': 0.02801472}, {'close_diff3': 0.023876805}, {'return_vol_30D': 0.05624311}, {'hour_vol_diff_pct': 0.01791142}, {'v_diff_pct': 0.019472888}, {'month': 0.036191404}, {'hour_volume_vol_diff': 0.018983344}, {'rsi5': 0.026932636}, {'range_vol_diff5': 0.021241967}, {'daily_vol_diff30': 0.029925017}, {'rsi': 0.028238151}, {'roc_diff': 0.027384842}, {'range_vol5MA': 0.32833794}, {'price_25MA': 0.03185326}, {'year': 0.038312066}, {'min_vol_diff': 0.020474654}, {'return_vol_5D': 0.025751894}, {'daily_vol_diff': 0.025466887}, {'price14': 0.027966628}, {'adx': 0.027944027}, {'volume_10MA': 0.023209233}, {'SPY_diff': 0.020152776}, {'SPY_1D': 0.030843949}]"}
# {'deployment_date': datetime.datetime(2022, 11, 7, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 10, 28, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    222981
# 1    115918
# Name: count, dtype: int64
# 854 213 364 759
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-11-07', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 854, 'TPpct': Decimal('0'), 'FP': 213, 'FPpct': Decimal('0'), 'TN': 364, 'TNpct': Decimal('0'), 'FN': 759, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('4.009389671361502'), 'evaluation_timeperiod': '2022-11-07_2022-11-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.019178702}, {'vol7': 0.0208444}, {'daily_volume_vol_diff30': 0.024784032}, {'price_10DDiff': 0.028881477}, {'close_diff3': 0.025033126}, {'return_vol_30D': 0.054534893}, {'hour_vol_diff_pct': 0.018386103}, {'v_diff_pct': 0.019521765}, {'month': 0.037159584}, {'hour_volume_vol_diff': 0.019612927}, {'rsi5': 0.026488932}, {'range_vol_diff5': 0.022142008}, {'daily_vol_diff30': 0.027659327}, {'rsi': 0.029103363}, {'roc_diff': 0.02739126}, {'range_vol5MA': 0.32843038}, {'price_25MA': 0.03265761}, {'year': 0.038900625}, {'min_vol_diff': 0.01715213}, {'return_vol_5D': 0.025536349}, {'daily_vol_diff': 0.02564366}, {'price14': 0.028261531}, {'adx': 0.028597038}, {'volume_10MA': 0.023663491}, {'SPY_diff': 0.019866683}, {'SPY_1D': 0.030568562}]"}
# {'deployment_date': datetime.datetime(2022, 11, 14, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 11, 4, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    224872
# 1    116547
# Name: count, dtype: int64
# 188 667 998 337
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-11-14', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 188, 'TPpct': Decimal('0'), 'FP': 667, 'FPpct': Decimal('0'), 'TN': 998, 'TNpct': Decimal('0'), 'FN': 337, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.2818590704647676'), 'evaluation_timeperiod': '2022-11-14_2022-11-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.018457262}, {'vol7': 0.02004418}, {'daily_volume_vol_diff30': 0.024961226}, {'price_10DDiff': 0.027917571}, {'close_diff3': 0.024336353}, {'return_vol_30D': 0.048767604}, {'hour_vol_diff_pct': 0.01837633}, {'v_diff_pct': 0.019900436}, {'month': 0.035996065}, {'hour_volume_vol_diff': 0.0188946}, {'rsi5': 0.026006985}, {'range_vol_diff5': 0.022606121}, {'daily_vol_diff30': 0.027757049}, {'rsi': 0.02882319}, {'roc_diff': 0.028069522}, {'range_vol5MA': 0.3359542}, {'price_25MA': 0.031662885}, {'year': 0.038590867}, {'min_vol_diff': 0.019855864}, {'return_vol_5D': 0.02555413}, {'daily_vol_diff': 0.025680168}, {'price14': 0.027728744}, {'adx': 0.028433772}, {'volume_10MA': 0.023738246}, {'SPY_diff': 0.020299483}, {'SPY_1D': 0.031587165}]"}
# {'deployment_date': datetime.datetime(2022, 11, 21, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 11, 11, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    225693
# 1    118246
# Name: count, dtype: int64
# 494 443 1023 159
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-11-21', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 494, 'TPpct': Decimal('0'), 'FP': 443, 'FPpct': Decimal('0'), 'TN': 1023, 'TNpct': Decimal('0'), 'FN': 159, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.1151241534988714'), 'evaluation_timeperiod': '2022-11-21_2022-11-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.01982706}, {'vol7': 0.020078612}, {'daily_volume_vol_diff30': 0.025127012}, {'price_10DDiff': 0.029283186}, {'close_diff3': 0.024778401}, {'return_vol_30D': 0.055388886}, {'hour_vol_diff_pct': 0.017693132}, {'v_diff_pct': 0.019720633}, {'month': 0.036478538}, {'hour_volume_vol_diff': 0.01938444}, {'rsi5': 0.027043827}, {'range_vol_diff5': 0.02128096}, {'daily_vol_diff30': 0.027961}, {'rsi': 0.029832436}, {'roc_diff': 0.027821744}, {'range_vol5MA': 0.32898974}, {'price_25MA': 0.032425415}, {'year': 0.03912265}, {'min_vol_diff': 0.01579509}, {'return_vol_5D': 0.025053693}, {'daily_vol_diff': 0.026510075}, {'price14': 0.027847888}, {'adx': 0.028999038}, {'volume_10MA': 0.023324238}, {'SPY_diff': 0.019894032}, {'SPY_1D': 0.030338246}]"}
# {'deployment_date': datetime.datetime(2022, 11, 28, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 11, 18, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    227474
# 1    118985
# Name: count, dtype: int64
# 416 110 1007 657
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-11-28', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 416, 'TPpct': Decimal('0'), 'FP': 110, 'FPpct': Decimal('0'), 'TN': 1007, 'TNpct': Decimal('0'), 'FN': 657, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.7818181818181817'), 'evaluation_timeperiod': '2022-11-28_2022-12-02', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.019402022}, {'vol7': 0.02123946}, {'daily_volume_vol_diff30': 0.025551507}, {'price_10DDiff': 0.029727865}, {'close_diff3': 0.024452573}, {'return_vol_30D': 0.04723389}, {'hour_vol_diff_pct': 0.018131737}, {'v_diff_pct': 0.018924175}, {'month': 0.036134228}, {'hour_volume_vol_diff': 0.01881106}, {'rsi5': 0.025902765}, {'range_vol_diff5': 0.022105543}, {'daily_vol_diff30': 0.027866386}, {'rsi': 0.028467786}, {'roc_diff': 0.027700568}, {'range_vol5MA': 0.3393232}, {'price_25MA': 0.03178546}, {'year': 0.039621573}, {'min_vol_diff': 0.016088672}, {'return_vol_5D': 0.025880424}, {'daily_vol_diff': 0.02466382}, {'price14': 0.027444081}, {'adx': 0.028077452}, {'volume_10MA': 0.02372161}, {'SPY_diff': 0.020539785}, {'SPY_1D': 0.031202368}]"}
# {'deployment_date': datetime.datetime(2022, 12, 5, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 11, 25, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    228970
# 1    119505
# Name: count, dtype: int64
# 340 339 983 528
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-12-05', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 340, 'TPpct': Decimal('0'), 'FP': 339, 'FPpct': Decimal('0'), 'TN': 983, 'TNpct': Decimal('0'), 'FN': 528, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0029498525073746'), 'evaluation_timeperiod': '2022-12-05_2022-12-09', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.019455304}, {'vol7': 0.021312311}, {'daily_volume_vol_diff30': 0.02542798}, {'price_10DDiff': 0.030231455}, {'close_diff3': 0.024864497}, {'return_vol_30D': 0.0476024}, {'hour_vol_diff_pct': 0.018898612}, {'v_diff_pct': 0.019573718}, {'month': 0.03712416}, {'hour_volume_vol_diff': 0.019130094}, {'rsi5': 0.02592912}, {'range_vol_diff5': 0.02220556}, {'daily_vol_diff30': 0.027610011}, {'rsi': 0.02960752}, {'roc_diff': 0.028116588}, {'range_vol5MA': 0.32955694}, {'price_25MA': 0.031625096}, {'year': 0.04010656}, {'min_vol_diff': 0.022972966}, {'return_vol_5D': 0.023016239}, {'daily_vol_diff': 0.024964489}, {'price14': 0.028256625}, {'adx': 0.028786188}, {'volume_10MA': 0.022782182}, {'SPY_diff': 0.020209983}, {'SPY_1D': 0.030633373}]"}
# {'deployment_date': datetime.datetime(2022, 12, 12, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 12, 2, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    230741
# 1    120730
# Name: count, dtype: int64
# 230 575 1181 204
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-12-12', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 230, 'TPpct': Decimal('0'), 'FP': 575, 'FPpct': Decimal('0'), 'TN': 1181, 'TNpct': Decimal('0'), 'FN': 204, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.4'), 'evaluation_timeperiod': '2022-12-12_2022-12-16', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.
), 'evaluation_timeperiod': '2023-01-23_2023-01-27', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.019545566}, {'vol7': 0.02036029}, {'daily_volume_vol_diff30': 0.025386713}, {'price_10DDiff': 0.030277168}, {'close_diff3': 0.02437113}, {'return_vol_30D': 0.050052196}, {'hour_vol_diff_pct': 0.017369319}, {'v_diff_pct': 0.018972285}, {'month': 0.03739076}, {'hour_volume_vol_diff': 0.021504488}, {'rsi5': 0.025301823}, {'range_vol_diff5': 0.021248488}, {'daily_vol_diff30': 0.027023315}, {'rsi': 0.029181886}, {'roc_diff': 0.027679345}, {'range_vol5MA': 0.33634967}, {'price_25MA': 0.03166951}, {'year': 0.042697437}, {'min_vol_diff': 0.013952564}, {'return_vol_5D': 0.024208229}, {'daily_vol_diff': 0.026336256}, {'price14': 0.027441729}, {'adx': 0.028256396}, {'volume_10MA': 0.021955606}, {'SPY_diff': 0.020194387}, {'SPY_1D': 0.03127356}]"}
# {'deployment_date': datetime.datetime(2023, 1, 30, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 1, 20, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    240743
# 1    126595
# Name: count, dtype: int64
# 593 301 328 301
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-01-30', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 593, 'TPpct': Decimal('0'), 'FP': 301, 'FPpct': Decimal('0'), 'TN': 328, 'TNpct': Decimal('0'), 'FN': 301, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.9700996677740863'), 'evaluation_timeperiod': '2023-01-30_2023-02-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.018314494}, {'vol7': 0.020492923}, {'daily_volume_vol_diff30': 0.024735741}, {'price_10DDiff': 0.02913892}, {'close_diff3': 0.02355567}, {'return_vol_30D': 0.05086013}, {'hour_vol_diff_pct': 0.017958883}, {'v_diff_pct': 0.01889258}, {'month': 0.036990967}, {'hour_volume_vol_diff': 0.021422237}, {'rsi5': 0.025220904}, {'range_vol_diff5': 0.021283275}, {'daily_vol_diff30': 0.026769143}, {'rsi': 0.02951897}, {'roc_diff': 0.027880391}, {'range_vol5MA': 0.3313987}, {'price_25MA': 0.03136838}, {'year': 0.04168764}, {'min_vol_diff': 0.023494083}, {'return_vol_5D': 0.024464741}, {'daily_vol_diff': 0.026393518}, {'price14': 0.027302515}, {'adx': 0.027757062}, {'volume_10MA': 0.022316128}, {'SPY_diff': 0.019621082}, {'SPY_1D': 0.031160867}]"}
# {'deployment_date': datetime.datetime(2023, 2, 6, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 1, 27, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    241665
# 1    127642
# Name: count, dtype: int64
# 419 538 459 84
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-02-06', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 419, 'TPpct': Decimal('0'), 'FP': 538, 'FPpct': Decimal('0'), 'TN': 459, 'TNpct': Decimal('0'), 'FN': 84, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.7788104089219331'), 'evaluation_timeperiod': '2023-02-06_2023-02-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.019216282}, {'vol7': 0.02005905}, {'daily_volume_vol_diff30': 0.025131958}, {'price_10DDiff': 0.02857956}, {'close_diff3': 0.02500038}, {'return_vol_30D': 0.052365623}, {'hour_vol_diff_pct': 0.017756356}, {'v_diff_pct': 0.019022075}, {'month': 0.037612416}, {'hour_volume_vol_diff': 0.021588746}, {'rsi5': 0.026125109}, {'range_vol_diff5': 0.021529408}, {'daily_vol_diff30': 0.026748404}, {'rsi': 0.028812477}, {'roc_diff': 0.027179124}, {'range_vol5MA': 0.3317307}, {'price_25MA': 0.03199848}, {'year': 0.042564202}, {'min_vol_diff': 0.01981423}, {'return_vol_5D': 0.02391805}, {'daily_vol_diff': 0.025668072}, {'price14': 0.027015854}, {'adx': 0.027204009}, {'volume_10MA': 0.022562394}, {'SPY_diff': 0.01943742}, {'SPY_1D': 0.031359643}]"}
# {'deployment_date': datetime.datetime(2023, 2, 13, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 2, 3, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    242290
# 1    128754
# Name: count, dtype: int64
# 500 658 457 23
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-02-13', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 500, 'TPpct': Decimal('0'), 'FP': 658, 'FPpct': Decimal('0'), 'TN': 457, 'TNpct': Decimal('0'), 'FN': 23, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.7598784194528876'), 'evaluation_timeperiod': '2023-02-13_2023-02-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.018424382}, {'vol7': 0.020123037}, {'daily_volume_vol_diff30': 0.024001595}, {'price_10DDiff': 0.028366918}, {'close_diff3': 0.024480851}, {'return_vol_30D': 0.052758954}, {'hour_vol_diff_pct': 0.017636308}, {'v_diff_pct': 0.01810295}, {'month': 0.03740847}, {'hour_volume_vol_diff': 0.02094531}, {'rsi5': 0.026120406}, {'range_vol_diff5': 0.020699363}, {'daily_vol_diff30': 0.026616946}, {'rsi': 0.029301217}, {'roc_diff': 0.027331874}, {'range_vol5MA': 0.336156}, {'price_25MA': 0.031207485}, {'year': 0.042938735}, {'min_vol_diff': 0.020414948}, {'return_vol_5D': 0.024384396}, {'daily_vol_diff': 0.024305526}, {'price14': 0.027268277}, {'adx': 0.027375253}, {'volume_10MA': 0.022874597}, {'SPY_diff': 0.019725567}, {'SPY_1D': 0.031030525}]"}
# {'deployment_date': datetime.datetime(2023, 2, 20, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 2, 10, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    243589
# 1    129105
# Name: count, dtype: int64
# 131 157 719 193
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-02-20', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 131, 'TPpct': Decimal('0'), 'FP': 157, 'FPpct': Decimal('0'), 'TN': 719, 'TNpct': Decimal('0'), 'FN': 193, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8343949044585988'), 'evaluation_timeperiod': '2023-02-20_2023-02-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.018998682}, {'vol7': 0.019378785}, {'daily_volume_vol_diff30': 0.024746962}, {'price_10DDiff': 0.028807903}, {'close_diff3': 0.023463273}, {'return_vol_30D': 0.050990596}, {'hour_vol_diff_pct': 0.017045178}, {'v_diff_pct': 0.018153368}, {'month': 0.03782776}, {'hour_volume_vol_diff': 0.022099907}, {'rsi5': 0.025653973}, {'range_vol_diff5': 0.021003837}, {'daily_vol_diff30': 0.027412646}, {'rsi': 0.029365826}, {'roc_diff': 0.02740109}, {'range_vol5MA': 0.3448798}, {'price_25MA': 0.030798418}, {'year': 0.041729935}, {'min_vol_diff': 0.01618536}, {'return_vol_5D': 0.02365987}, {'daily_vol_diff': 0.025422959}, {'price14': 0.027116535}, {'adx': 0.027313935}, {'volume_10MA': 0.021483988}, {'SPY_diff': 0.01813078}, {'SPY_1D': 0.03092868}]"}
# {'deployment_date': datetime.datetime(2023, 2, 27, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 2, 17, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    244526
# 1    129818
# Name: count, dtype: int64
# 357 142 617 384
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-02-27', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 357, 'TPpct': Decimal('0'), 'FP': 142, 'FPpct': Decimal('0'), 'TN': 617, 'TNpct': Decimal('0'), 'FN': 384, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.5140845070422535'), 'evaluation_timeperiod': '2023-02-27_2023-03-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.019316867}, {'vol7': 0.020162905}, {'daily_volume_vol_diff30': 0.02447902}, {'price_10DDiff': 0.029095963}, {'close_diff3': 0.024354458}, {'return_vol_30D': 0.051273823}, {'hour_vol_diff_pct': 0.017714571}, {'v_diff_pct': 0.018048473}, {'month': 0.03816508}, {'hour_volume_vol_diff': 0.020618057}, {'rsi5': 0.025858646}, {'range_vol_diff5': 0.020613952}, {'daily_vol_diff30': 0.027410524}, {'rsi': 0.028598668}, {'roc_diff': 0.027036231}, {'range_vol5MA': 0.3388659}, {'price_25MA': 0.031245708}, {'year': 0.039977174}, {'min_vol_diff': 0.020729475}, {'return_vol_5D': 0.024472417}, {'daily_vol_diff': 0.025403822}, {'price14': 0.027101701}, {'adx': 0.027222773}, {'volume_10MA': 0.02288057}, {'SPY_diff': 0.018789176}, {'SPY_1D': 0.030563975}]"}
# {'deployment_date': datetime.datetime(2023, 3, 6, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 2, 24, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    245768
# 1    130070
# Name: count, dtype: int64
# 103 117 1087 193
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-03-06', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 103, 'TPpct': Decimal('0'), 'FP': 117, 'FPpct': Decimal('0'), 'TN': 1087, 'TNpct': Decimal('0'), 'FN': 193, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8803418803418803'), 'evaluation_timeperiod': '2023-03-06_2023-03-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.018354898}, {'vol7': 0.020179555}, {'daily_volume_vol_diff30': 0.024663284}, {'price_10DDiff': 0.028553007}, {'close_diff3': 0.023465114}, {'return_vol_30D': 0.050723113}, {'hour_vol_diff_pct': 0.016859299}, {'v_diff_pct': 0.01916086}, {'month': 0.038916517}, {'hour_volume_vol_diff': 0.02203556}, {'rsi5': 0.025515197}, {'range_vol_diff5': 0.02074895}, {'daily_vol_diff30': 0.027654478}, {'rsi': 0.028293507}, {'roc_diff': 0.028558115}, {'range_vol5MA': 0.33662102}, {'price_25MA': 0.030875945}, {'year': 0.040687528}, {'min_vol_diff': 0.019234002}, {'return_vol_5D': 0.024759226}, {'daily_vol_diff': 0.026385741}, {'price14': 0.02708498}, {'adx': 0.027605051}, {'volume_10MA': 0.022584379}, {'SPY_diff': 0.019259669}, {'SPY_1D': 0.031221054}]"}
# {'deployment_date': datetime.datetime(2023, 3, 13, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 3, 3, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    246606
# 1    130882
# Name: count, dtype: int64
# 655 387 345 113
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-03-13', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 655, 'TPpct': Decimal('0'), 'FP': 387, 'FPpct': Decimal('0'), 'TN': 345, 'TNpct': Decimal('0'), 'FN': 113, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.6925064599483204'), 'evaluation_timeperiod': '2023-03-13_2023-03-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.01798126}, {'vol7': 0.018490063}, {'daily_volume_vol_diff30': 0.025113434}, {'price_10DDiff': 0.028298855}, {'close_diff3': 0.02374777}, {'return_vol_30D': 0.047459878}, {'hour_vol_diff_pct': 0.017411835}, {'v_diff_pct': 0.018843403}, {'month': 0.03964623}, {'hour_volume_vol_diff': 0.021213051}, {'rsi5': 0.024937287}, {'range_vol_diff5': 0.021262346}, {'daily_vol_diff30': 0.028249236}, {'rsi': 0.02962045}, {'roc_diff': 0.0275199}, {'range_vol5MA': 0.33998334}, {'price_25MA': 0.030870588}, {'year': 0.040587742}, {'min_vol_diff': 0.019295035}, {'return_vol_5D': 0.024781754}, {'daily_vol_diff': 0.025672093}, {'price14': 0.026827069}, {'adx': 0.02760691}, {'volume_10MA': 0.022596454}, {'SPY_diff': 0.019162316}, {'SPY_1D': 0.032821715}]"}
# {'deployment_date': datetime.datetime(2023, 3, 20, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 3, 10, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    248005
# 1    131133
# Name: count, dtype: int64
# 99 137 836 428
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-03-20', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 99, 'TPpct': Decimal('0'), 'FP': 137, 'FPpct': Decimal('0'), 'TN': 836, 'TNpct': Decimal('0'), 'FN': 428, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.7226277372262774'), 'evaluation_timeperiod': '2023-03-20_2023-03-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.01970295}, {'vol7': 0.020237513}, {'daily_volume_vol_diff30': 0.025187152}, {'price_10DDiff': 0.029896278}, {'close_diff3': 0.024858734}, {'return_vol_30D': 0.048648532}, {'hour_vol_diff_pct': 0.017461317}, {'v_diff_pct': 0.02021106}, {'month': 0.03967071}, {'hour_volume_vol_diff': 0.020519314}, {'rsi5': 0.025795927}, {'range_vol_diff5': 0.02059048}, {'daily_vol_diff30': 0.028257957}, {'rsi': 0.029081725}, {'roc_diff': 0.028771678}, {'range_vol5MA': 0.3341776}, {'price_25MA': 0.031770956}, {'year': 0.040057313}, {'min_vol_diff': 0.015635964}, {'return_vol_5D': 0.023914287}, {'daily_vol_diff': 0.026359534}, {'price14': 0.02767253}, {'adx': 0.02836407}, {'volume_10MA': 0.022068657}, {'SPY_diff': 0.01937826}, {'SPY_1D': 0.031709477}]"}
# {'deployment_date': datetime.datetime(2023, 3, 27, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 3, 17, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    248929
# 1    131859
# Name: count, dtype: int64
# 193 112 671 524
# ...
# {'deployment_date': datetime.datetime(2023, 9, 18, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 9, 8, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    275678
# 1    144800
# Name: count, dtype: int64
# 12 62 1308 142
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-09-18', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 12, 'TPpct': Decimal('0'), 'FP': 62, 'FPpct': Decimal('0'), 'TN': 1308, 'TNpct': Decimal('0'), 'FN': 142, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.1935483870967742'), 'evaluation_timeperiod': '2023-09-18_2023-09-22', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.018270029}, {'vol7': 0.019175416}, {'daily_volume_vol_diff30': 0.025407242}, {'price_10DDiff': 0.02792126}, {'close_diff3': 0.022145698}, {'return_vol_30D': 0.04815273}, {'hour_vol_diff_pct': 0.017178724}, {'v_diff_pct': 0.018918017}, {'month': 0.039284233}, {'hour_volume_vol_diff': 0.021162327}, {'rsi5': 0.024463648}, {'range_vol_diff5': 0.019854391}, {'daily_vol_diff30': 0.026818225}, {'rsi': 0.028104382}, {'roc_diff': 0.026602052}, {'range_vol5MA': 0.35260147}, {'price_25MA': 0.030333461}, {'year': 0.038412705}, {'min_vol_diff': 0.021240655}, {'return_vol_5D': 0.02320974}, {'daily_vol_diff': 0.02527376}, {'price14': 0.027412338}, {'adx': 0.02737814}, {'volume_10MA': 0.022007149}, {'SPY_diff': 0.018614655}, {'SPY_1D': 0.030057529}]"}
# {'deployment_date': datetime.datetime(2023, 9, 25, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 9, 15, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    277066
# 1    145062
# Name: count, dtype: int64
# 95 61 947 427
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-09-25', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 95, 'TPpct': Decimal('0'), 'FP': 61, 'FPpct': Decimal('0'), 'TN': 947, 'TNpct': Decimal('0'), 'FN': 427, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.5573770491803278'), 'evaluation_timeperiod': '2023-09-25_2023-09-29', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.018611494}, {'vol7': 0.019184573}, {'daily_volume_vol_diff30': 0.025380723}, {'price_10DDiff': 0.027815599}, {'close_diff3': 0.023816384}, {'return_vol_30D': 0.05432984}, {'hour_vol_diff_pct': 0.017569609}, {'v_diff_pct': 0.018644461}, {'month': 0.040218875}, {'hour_volume_vol_diff': 0.021209033}, {'rsi5': 0.025142357}, {'range_vol_diff5': 0.021123424}, {'daily_vol_diff30': 0.027582683}, {'rsi': 0.029814653}, {'roc_diff': 0.028029636}, {'range_vol5MA': 0.33403954}, {'price_25MA': 0.031017229}, {'year': 0.040071983}, {'min_vol_diff': 0.020168388}, {'return_vol_5D': 0.024160422}, {'daily_vol_diff': 0.026269233}, {'price14': 0.02634076}, {'adx': 0.02802413}, {'volume_10MA': 0.022554714}, {'SPY_diff': 0.018433658}, {'SPY_1D': 0.030446662}]"}
# {'deployment_date': datetime.datetime(2023, 10, 2, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 9, 22, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    278630
# 1    145166
# Name: count, dtype: int64
# 130 48 819 533
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-10-02', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 130, 'TPpct': Decimal('0'), 'FP': 48, 'FPpct': Decimal('0'), 'TN': 819, 'TNpct': Decimal('0'), 'FN': 533, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.7083333333333335'), 'evaluation_timeperiod': '2023-10-02_2023-10-06', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.018532103}, {'vol7': 0.019152816}, {'daily_volume_vol_diff30': 0.02489815}, {'price_10DDiff': 0.027927425}, {'close_diff3': 0.023885356}, {'return_vol_30D': 0.053117823}, {'hour_vol_diff_pct': 0.016975485}, {'v_diff_pct': 0.019155355}, {'month': 0.039922036}, {'hour_volume_vol_diff': 0.020052552}, {'rsi5': 0.02488042}, {'range_vol_diff5': 0.020459732}, {'daily_vol_diff30': 0.026983079}, {'rsi': 0.029043997}, {'roc_diff': 0.02698411}, {'range_vol5MA': 0.34446377}, {'price_25MA': 0.030984137}, {'year': 0.041209213}, {'min_vol_diff': 0.018567245}, {'return_vol_5D': 0.023839844}, {'daily_vol_diff': 0.02412099}, {'price14': 0.027508663}, {'adx': 0.026950235}, {'volume_10MA': 0.02172164}, {'SPY_diff': 0.018616633}, {'SPY_1D': 0.030047253}]"}
# {'deployment_date': datetime.datetime(2023, 10, 9, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 9, 29, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    279741
# 1    145735
# Name: count, dtype: int64
# 29 20 679 190
# {'model_name': 'SFC:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-10-09', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 29, 'TPpct': Decimal('0'), 'FP': 20, 'FPpct': Decimal('0'), 'TN': 679, 'TNpct': Decimal('0'), 'FN': 190, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.45'), 'evaluation_timeperiod': '2023-10-09_2023-10-13', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '0.045+three_max', 'feature_importances': "[{'close_diff_deviation': 0.01820361}, {'vol7': 0.018758098}, {'daily_volume_vol_diff30': 0.024598204}, {'price_10DDiff': 0.027427388}, {'close_diff3': 0.023089206}, {'return_vol_30D': 0.05162363}, {'hour_vol_diff_pct': 0.016993785}, {'v_diff_pct': 0.018247275}, {'month': 0.0380849}, {'hour_volume_vol_diff': 0.021181665}, {'rsi5': 0.024493437}, {'range_vol_diff5': 0.019809134}, {'daily_vol_diff30': 0.027323369}, {'rsi': 0.029006079}, {'roc_diff': 0.026591456}, {'range_vol5MA': 0.35296044}, {'price_25MA': 0.030434983}, {'year': 0.040089242}, {'min_vol_diff': 0.019917233}, {'return_vol_5D': 0.02339582}, {'daily_vol_diff': 0.024816044}, {'price14': 0.026259858}, {'adx': 0.026653724}, {'volume_10MA': 0.02155781}, {'SPY_diff': 0.01840458}, {'SPY_1D': 0.030079087}]"}
# {'deployment_date': datetime.datetime(2023, 10, 16, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 10, 6, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    280888
# 1    146268
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a> for date in dates_list:
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=19'>20</a>     print(date)
# ---> <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=20'>21</a>     response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,"dataset_start_date",date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])
#
# /Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=10'>11</a> dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
# ---> <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=12'>13</a> tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=13'>14</a> response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=14'>15</a> validation_dataset['probabilities'] = probabilities[:,1]
#
# /Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a> predictions = xgb_model.predict(X_validate)
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=19'>20</a> probabilities = xgb_model.predict_proba(X_validate)
# ---> <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=20'>21</a> tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=22'>23</a> fi = xgb_model.feature_importances_
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=23'>24</a> fi_list = []
#
# /Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb Cell 10 line 4
#       <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> result_list = []
#       <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> counter = 0
# ----> <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> predictions_series = pd.Series(predictions,name='prediction_values')
#       <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> for x in predictions:
#       <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfC_3d.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a>     if x == 1:
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/pandas/core/series.py:509, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     507         data = data.copy()
#     508 else:
# --> 509     data = sanitize_array(data, index, dtype, copy)
#     511     manager = get_option("mode.data_manager")
#     512     if manager == "block":
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/pandas/core/construction.py:607, in sanitize_array(data, index, dtype, copy, allow_2d)
#     604             subarr = cast(np.ndarray, subarr)
#     605             subarr = maybe_infer_to_datetimelike(subarr)
# --> 607 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     609 if isinstance(subarr, np.ndarray):
#     610     # at this point we should have dtype be None or subarr.dtype == dtype
#     611     dtype = cast(np.dtype, dtype)
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/pandas/core/construction.py:666, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     664     if allow_2d:
#     665         return result
# --> 666     raise ValueError(
#     667         f"Data must be 1-dimensional, got ndarray of shape {data.shape} instead"
#     668     )
#     669 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     670     # i.e. PandasDtype("O")
#     672     result = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#
# ValueError: Data must be 1-dimensional, got ndarray of shape (0, 0) instead
