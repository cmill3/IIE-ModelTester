# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler

# %%
s3 = boto3.client('s3')

training_bucket = "icarus-research-data"

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

weekly_expiries = ['SPY', 'IVV', 'QQQ', 'GLD', 'IWM', 'EFA', 'XLK', 'XLV', 'TLT', 'LQD', 'XLE', 'TQQQ', 'SQQQ', 'SPXS', 'SPXL', 'SOXL', 'SOXS', 'MMM', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 
                   'AAP', 'AFL', 'ALB', 'ALGN', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMD', 'AAL', 'AXP', 'AIG', 'ABC', 'AMGN', 'ADI', 'APA', 'AAPL', 'AMAT', 'ANET', 'T', 'ADSK', 'BAC', 'BBWI', 'BAX', 'BBY', 'BIIB', 
                   'BLK', 'BA', 'BKNG', 'BMY', 'AVGO', 'CZR', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CAT', 'CBOE', 'CNC', 'CF', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CI', 'CSCO', 'C', 'CLX', 'CME', 'KO', 'CMCSA', 'CMA', 'CAG', 
                   'COP', 'STZ', 'GLW', 'COST', 'CTRA', 'CSX', 'CVS', 'DHI', 'DHR', 'DE', 'DAL', 'DVN', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'DPZ', 'DOW', 'DD', 'EBAY', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'EOG', 'EQT', 
                   'ETSY', 'EXPE', 'XOM', 'FDX', 'FITB', 'FSLR', 'FI', 'F', 'FTNT', 'FOXA', 'FCX', 'GEHC', 'GNRC', 'GD', 'GE', 'GM', 'GILD', 'GS', 'HAL', 'HSY', 'HES', 'HD', 'HON', 'HRL', 'HPQ', 'HUM', 'HBAN', 'IBM', 'ILMN', 
                   'INTC', 'IP', 'INTU', 'ISRG', 'JNJ', 'JPM', 'JNPR', 'KEY', 'KMB', 'KMI', 'KLAC', 'KHC', 'KR', 'LRCX', 'LVS', 'LEN', 'LMT', 'LOW', 'MRO', 'MPC', 'MAR', 'MA', 'MTCH', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 
                   'MGM', 'MU', 'MSFT', 'MRNA', 'MDLZ', 'MS', 'MOS', 'NTAP', 'NFLX', 'NEM', 'NKE', 'NSC', 'NOC', 'NCLH', 'NUE', 'NVDA', 'NXPI', 'OXY', 'ON', 'ORCL', 'PARA', 'PYPL', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PXD', 'PNC', 
                   'PPG', 'PG', 'PHM', 'QCOM', 'RTX', 'REGN', 'ROST', 'RCL', 'SPGI', 'CRM', 'SLB', 'STX', 'NOW', 'SWKS', 'SEDG', 'SO', 'LUV', 'SBUX', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TGT', 'TSLA', 'TXN', 'TMO', 'TJX', 'TSCO', 'TFC', 
                   'TSN', 'USB', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'VLO', 'VZ', 'VRTX', 'VFC', 'V', 'WBA', 'WMT', 'WBD', 'WM', 'WFC', 'WDC', 'WHR', 'WMB', 'WYNN', 'ZION']

# %%
def create_validation_data(key_list, prefix, bucket_name):
    df_list = []
    hours = [10,11,12,13,14,15]
    for key in key_list:
        for hour in hours:
            try:
                data = s3.get_object(Bucket=bucket_name, Key=f'{prefix}{key}/{hour}.csv')
                df = pd.read_csv(data.get("Body")) 
                df_list.append(df)
            except:
                continue

    data = pd.concat(df_list)
    data.reset_index(drop=True, inplace=True)
    # data = full_df.drop(full_df[full_df.third_friday == 'True'].index)
    # data.drop(data[data.third_friday == 'NO RESULTS'].index, inplace=True)
    data['volume_10DDiff'] = data.apply(lambda x: x.v - x.volume_10MA, axis=1)
    data['volume_25DDiff'] = data.apply(lambda x: x.v - x.volume_25MA, axis=1)
    # data['rvi_delta'] = data.apply(lambda x: x.rvi5 - x.rvi10, axis=1)

    data['dt'] = pd.to_datetime(data['date'])
    data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek)
    data['day_of_month'] = data['dt'].apply(lambda x: x.day)
    data['month'] = data['dt'].apply(lambda x: x.month)
    data['year'] = data['dt'].apply(lambda x: x.year)
    data['hour'] = data['dt'].apply(lambda x: x.hour)

    data = data.loc[data['symbol'].isin(weekly_expiries)]

    return data

def create_training_data_v2(key_list, prefix, bucket_name):
    df_list = []
    hours = [10,11,12,13,14,15]
    for key in key_list:
        for hour in hours:
            try:
                data = s3.get_object(Bucket=bucket_name, Key=f'{prefix}{key}/{hour}.csv')
                df = pd.read_csv(data.get("Body")) 
                df_list.append(df)
            except:
                continue

    data = pd.concat(df_list)
    data.reset_index(drop=True, inplace=True)
    # data = full_df.drop(full_df[full_df.third_friday == 'True'].index)
    # data.drop(data[data.third_friday == 'NO RESULTS'].index, inplace=True)
    data['volume_10DDiff'] = data.apply(lambda x: x.v - x.volume_10MA, axis=1)
    data['volume_25DDiff'] = data.apply(lambda x: x.v - x.volume_25MA, axis=1)
    # data['rvi_delta'] = data.apply(lambda x: x.rvi5 - x.rvi10, axis=1)
    data['dt'] = pd.to_datetime(data['date'])
    data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek)
    data['day_of_month'] = data['dt'].apply(lambda x: x.day)
    data['month'] = data['dt'].apply(lambda x: x.month)
    data['year'] = data['dt'].apply(lambda x: x.year)
    data['hour'] = data['dt'].apply(lambda x: x.hour)

    # data = data.loc[data['symbol'].isin(weekly_expiries)]


    return data

# %%
def build_date_list(start_date, end_date):
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    # dataset[["rsi", "cmf", "adx", "roc", "roc3", "roc5","three_max"]] = dataset[["rsi", "cmf", "adx", "roc", "roc3", "roc5","three_max"]].apply(pd.to_numeric)
    # validation_dataset[["rsi", "cmf", "adx", "roc", "roc3", "roc5","three_max"]] = validation_dataset[["rsi", "cmf", "adx", "roc", "roc3", "roc5","three_max"]].apply(pd.to_numeric)
    dataset.loc[:, 'label'] = (dataset['three_max'] > .04).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset['three_max'] > .04).astype(int)

    scaler = StandardScaler()
    
    X = dataset[features]
    y = dataset['label']
    # X = scaler.fit_transform(X)

    # train_len = int(.7*len(dataset))
    # X_train = X.iloc[0:train_len]
    # y_train = y[0:train_len]
    # X_test = X.iloc[train_len:]
    # y_test = y[train_len:]

    print(y.value_counts())
    X_validate = validation_dataset[features]
    y_validate = validation_dataset['label']
    # X_validate = scaler.fit_transform(X_validate)

    # pos_bal_weight = (len(y.loc[y == 0])) / (len(y.loc[y == 1]))
    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],silent=0,objective='binary:logistic')
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, str(fi_list), predictions

# %%
def build_multi_time_dfs(key_list, dataset):
    list30 = key_list[-30:]
    list60 = key_list[-60:]
    list90 = key_list[-90:]
    dataset['key'] = dataset['date'].apply(lambda x: x.split(' ')[0])
    df30 = dataset.loc[dataset['key'].isin(list30)]
    df60 = dataset.loc[dataset['key'].isin(list60)]
    df90 = dataset.loc[dataset['key'].isin(list90)]

    full_dataset = pd.concat([dataset, df30, df60, df90])
    return full_dataset

# %%
def model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,start_date, end_date,deployment_date, feature_str, target_str, hyperparams_str, hyperparams):
    dates = build_date_list(start_date, end_date)
    key_list = build_query_keys(dates)
    validation_keys = build_query_keys_validation(deployment_date)
    # dataset = create_training_data_v2(key_list, 'inv_alerts_with_price/losers/', 'icarus-research-data')
    validation_dataset = create_validation_data(validation_keys, 'vdiff_loss/', 'inv-alerts')
    dataset = create_training_data_v2(key_list, 'vdiff_loss/', 'inv-alerts')
    # full_data = build_multi_time_dfs(key_list, dataset)
    # mod_dataset = pd.concat([dataset, recent_dataset])
    # hyperparams = optimize_model_params(dataset, features)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, target_str, fi_list)

    validation_dataset['predictions'] = predictions
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/standard_dataset/vdiff_lossC/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    return response

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=10)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

# %%
#Need to re-run inv_alerts_vdiffC_weekly:fulltrain_last60_unscaled_tuned
model_name = 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned'
dataset_name = 'inv_alerts_standard'
title = 'most_actives'
hyperparameter_string = "{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"
hyperparams = {'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}

feature_str = "'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"
features = ['rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour']
target_str = 'three_max > 3'
target_label = 'three_max'
target_value = 3.0
dataset_start_date = datetime(2021,1,1) 

dates_list = build_evaluation_period(datetime(2022,10,24), datetime(2023,7,7))
for date in dates_list:
    response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], feature_str, target_str,hyperparameter_string, hyperparams)
    print(response)
# Out:
# label
# 0    105012
# 1     29688
# Name: count, dtype: int64
# [12:03:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 78 12 204 288
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-10-24', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 78, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 204, 'TNpct': Decimal('0'), 'FN': 288, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('6.5'), 'evaluation_timeperiod': '2022-10-24_2022-10-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.046753243}, {'cmf': 0.03995869}, {'adx': 0.041590903}, {'roc': 0.07746198}, {'roc3': 0.06765856}, {'roc5': 0.05763773}, {'PCR': 0.047266047}, {'v': 0.041313525}, {'volume_10MA': 0.041654143}, {'volume_25MA': 0.043465108}, {'volume_10DDiff': 0.040486198}, {'volume_25DDiff': 0.042001385}, {'close_diff': 0.2941406}, {'v_diff_pct': 0.027039446}, {'day_of_week': 0.038737226}, {'hour': 0.05283525}]"}
# {'ResponseMetadata': {'RequestId': 'V6IMLPRQPMO92MQAPBC5GE35J7VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:03:11 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'V6IMLPRQPMO92MQAPBC5GE35J7VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    105930
# 1     30270
# Name: count, dtype: int64
# [12:04:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 54 30 348 114
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-10-31', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 54, 'TPpct': Decimal('0'), 'FP': 30, 'FPpct': Decimal('0'), 'TN': 348, 'TNpct': Decimal('0'), 'FN': 114, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.8'), 'evaluation_timeperiod': '2022-10-31_2022-11-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04678055}, {'cmf': 0.039835975}, {'adx': 0.040959712}, {'roc': 0.073514715}, {'roc3': 0.06306881}, {'roc5': 0.058983933}, {'PCR': 0.04636562}, {'v': 0.04103606}, {'volume_10MA': 0.042008985}, {'volume_25MA': 0.043950267}, {'volume_10DDiff': 0.040362332}, {'volume_25DDiff': 0.042526137}, {'close_diff': 0.2995254}, {'v_diff_pct': 0.02835199}, {'day_of_week': 0.038693924}, {'hour': 0.054035675}]"}
# {'ResponseMetadata': {'RequestId': 'GO6B7JT9ORGA2ETMENGM0LUP2NVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:04:54 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'GO6B7JT9ORGA2ETMENGM0LUP2NVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    106482
# 1     31218
# Name: count, dtype: int64
# [12:06:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 156 6 168 222
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-11-07', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 156, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 168, 'TNpct': Decimal('0'), 'FN': 222, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('26.0'), 'evaluation_timeperiod': '2022-11-07_2022-11-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.046871994}, {'cmf': 0.03962942}, {'adx': 0.042416044}, {'roc': 0.07259029}, {'roc3': 0.06577732}, {'roc5': 0.057016544}, {'PCR': 0.046241134}, {'v': 0.041225303}, {'volume_10MA': 0.041470762}, {'volume_25MA': 0.044207316}, {'volume_10DDiff': 0.040447496}, {'volume_25DDiff': 0.042361032}, {'close_diff': 0.30506495}, {'v_diff_pct': 0.027075332}, {'day_of_week': 0.038997788}, {'hour': 0.048607275}]"}
# {'ResponseMetadata': {'RequestId': '6DV2DVB5EGBQFSHJ18SKC7FEFNVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:06:37 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '6DV2DVB5EGBQFSHJ18SKC7FEFNVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    107580
# 1     31620
# Name: count, dtype: int64
# [12:08:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 48 12 418 72
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-11-14', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 48, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 418, 'TNpct': Decimal('0'), 'FN': 72, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('4.0'), 'evaluation_timeperiod': '2022-11-14_2022-11-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04707668}, {'cmf': 0.039796796}, {'adx': 0.0425754}, {'roc': 0.069398895}, {'roc3': 0.06605039}, {'roc5': 0.059804894}, {'PCR': 0.046335235}, {'v': 0.04150614}, {'volume_10MA': 0.040383022}, {'volume_25MA': 0.040947463}, {'volume_10DDiff': 0.040322904}, {'volume_25DDiff': 0.042317107}, {'close_diff': 0.30668038}, {'v_diff_pct': 0.029470298}, {'day_of_week': 0.038021646}, {'hour': 0.049312808}]"}
# {'ResponseMetadata': {'RequestId': '31255E8V92JQFSB35HQPCIT103VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:08:30 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '31255E8V92JQFSB35HQPCIT103VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    108180
# 1     32520
# Name: count, dtype: int64
# [12:10:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 24 17 341 42
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-11-21', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 24, 'TPpct': Decimal('0'), 'FP': 17, 'FPpct': Decimal('0'), 'TN': 341, 'TNpct': Decimal('0'), 'FN': 42, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.411764705882353'), 'evaluation_timeperiod': '2022-11-21_2022-11-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.046328716}, {'cmf': 0.040489435}, {'adx': 0.04183299}, {'roc': 0.071787834}, {'roc3': 0.064912766}, {'roc5': 0.05662406}, {'PCR': 0.047409773}, {'v': 0.041735645}, {'volume_10MA': 0.040908597}, {'volume_25MA': 0.042730138}, {'volume_10DDiff': 0.040728442}, {'volume_25DDiff': 0.040965926}, {'close_diff': 0.2994138}, {'v_diff_pct': 0.02857152}, {'day_of_week': 0.03899243}, {'hour': 0.056567967}]"}
# {'ResponseMetadata': {'RequestId': 'SD84PIOIPPUFEEK7O8UNMQSV13VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:10:15 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'SD84PIOIPPUFEEK7O8UNMQSV13VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    109248
# 1     32952
# Name: count, dtype: int64
# [12:11:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 42 24 396 162
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-11-28', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 42, 'TPpct': Decimal('0'), 'FP': 24, 'FPpct': Decimal('0'), 'TN': 396, 'TNpct': Decimal('0'), 'FN': 162, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.75'), 'evaluation_timeperiod': '2022-11-28_2022-12-02', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04569613}, {'cmf': 0.0391573}, {'adx': 0.04027476}, {'roc': 0.068413876}, {'roc3': 0.06621043}, {'roc5': 0.0559016}, {'PCR': 0.046787977}, {'v': 0.04085238}, {'volume_10MA': 0.039669592}, {'volume_25MA': 0.04124328}, {'volume_10DDiff': 0.039322887}, {'volume_25DDiff': 0.042181477}, {'close_diff': 0.31573603}, {'v_diff_pct': 0.026064573}, {'day_of_week': 0.0382831}, {'hour': 0.05420463}]"}
# {'ResponseMetadata': {'RequestId': '8638IV3K22HKIABR0PECSVGFF7VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:12:08 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '8638IV3K22HKIABR0PECSVGFF7VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    110214
# 1     33186
# Name: count, dtype: int64
# [12:13:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 12 0 443 138
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-12-05', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 12, 'TPpct': Decimal('0'), 'FP': 0, 'FPpct': Decimal('0'), 'TN': 443, 'TNpct': Decimal('0'), 'FN': 138, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0'), 'evaluation_timeperiod': '2022-12-05_2022-12-09', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.047380377}, {'cmf': 0.039731156}, {'adx': 0.04055802}, {'roc': 0.0711024}, {'roc3': 0.06441967}, {'roc5': 0.05749462}, {'PCR': 0.04788001}, {'v': 0.041335}, {'volume_10MA': 0.04047389}, {'volume_25MA': 0.04229411}, {'volume_10DDiff': 0.039326455}, {'volume_25DDiff': 0.042606775}, {'close_diff': 0.3092053}, {'v_diff_pct': 0.026062027}, {'day_of_week': 0.039113913}, {'hour': 0.05101627}]"}
# {'ResponseMetadata': {'RequestId': 'LN7VKVJ4BL8G14KTK6HOGB2MM3VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:14:04 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'LN7VKVJ4BL8G14KTK6HOGB2MM3VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    111264
# 1     33636
# Name: count, dtype: int64
# [12:15:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 18 0 443 96
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-12-12', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 18, 'TPpct': Decimal('0'), 'FP': 0, 'FPpct': Decimal('0'), 'TN': 443, 'TNpct': Decimal('0'), 'FN': 96, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0'), 'evaluation_timeperiod': '2022-12-12_2022-12-16', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.045730833}, {'cmf': 0.0397785}, {'adx': 0.040865097}, {'roc': 0.06976149}, {'roc3': 0.06386776}, {'roc5': 0.05638748}, {'PCR': 0.04713269}, {'v': 0.040667146}, {'volume_10MA': 0.039994504}, {'volume_25MA': 0.040604707}, {'volume_10DDiff': 0.039955925}, {'volume_25DDiff': 0.042799693}, {'close_diff': 0.31019154}, {'v_diff_pct': 0.026100004}, {'day_of_week': 0.03841854}, {'hour': 0.057744104}]"}
# {'ResponseMetadata': {'RequestId': 'LQ1KF437T7FA0VKJ5FGDMREGUVVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:15:56 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'LQ1KF437T7FA0VKJ5FGDMREGUVVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    112638
# 1     33762
# Name: count, dtype: int64
# [12:17:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 36 18 454 48
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-12-19', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 36, 'TPpct': Decimal('0'), 'FP': 18, 'FPpct': Decimal('0'), 'TN': 454, 'TNpct': Decimal('0'), 'FN': 48, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.0'), 'evaluation_timeperiod': '2022-12-19_2022-12-23', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.047052696}, {'cmf': 0.039959162}, {'adx': 0.041245278}, {'roc': 0.07096856}, {'roc3': 0.06277026}, {'roc5': 0.05750872}, {'PCR': 0.047740214}, {'v': 0.041118186}, {'volume_10MA': 0.040079758}, {'volume_25MA': 0.041567538}, {'volume_10DDiff': 0.040360674}, {'volume_25DDiff': 0.041089896}, {'close_diff': 0.3106168}, {'v_diff_pct': 0.025936874}, {'day_of_week': 0.038112238}, {'hour': 0.053873144}]"}
# {'ResponseMetadata': {'RequestId': 'GSGS7QG24SJ0O4PG7V67MIMQ17VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:17:58 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'GSGS7QG24SJ0O4PG7V67MIMQ17VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    113591
# 1     34309
# Name: count, dtype: int64
# [12:19:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 24 6 486 36
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-12-26', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 24, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 486, 'TNpct': Decimal('0'), 'FN': 36, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('4.0'), 'evaluation_timeperiod': '2022-12-26_2022-12-30', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.044431876}, {'cmf': 0.039863717}, {'adx': 0.040566865}, {'roc': 0.06966036}, {'roc3': 0.06791996}, {'roc5': 0.055897303}, {'PCR': 0.04600838}, {'v': 0.041489556}, {'volume_10MA': 0.03950592}, {'volume_25MA': 0.041541677}, {'volume_10DDiff': 0.03999674}, {'volume_25DDiff': 0.04274898}, {'close_diff': 0.31039444}, {'v_diff_pct': 0.026951272}, {'day_of_week': 0.03802743}, {'hour': 0.05499556}]"}
# {'ResponseMetadata': {'RequestId': 'HHEROC729NOJREPIT7S5J5TK5NVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:19:50 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'HHEROC729NOJREPIT7S5J5TK5NVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    114971
# 1     34429
# Name: count, dtype: int64
# [12:21:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 30 6 240 162
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-01-02', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 30, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 240, 'TNpct': Decimal('0'), 'FN': 162, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('5.0'), 'evaluation_timeperiod': '2023-01-02_2023-01-06', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04795818}, {'cmf': 0.040094517}, {'adx': 0.040880505}, {'roc': 0.068873785}, {'roc3': 0.062879354}, {'roc5': 0.057177536}, {'PCR': 0.047770116}, {'v': 0.03980235}, {'volume_10MA': 0.039817102}, {'volume_25MA': 0.04077363}, {'volume_10DDiff': 0.03903216}, {'volume_25DDiff': 0.042148247}, {'close_diff': 0.3200085}, {'v_diff_pct': 0.022831544}, {'day_of_week': 0.038894527}, {'hour': 0.051057894}]"}
# {'ResponseMetadata': {'RequestId': 'O330LLFDGPVDPC1NU95MGM865FVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:21:41 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'O330LLFDGPVDPC1NU95MGM865FVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    116117
# 1     34483
# Name: count, dtype: int64
# [12:24:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 36 42 383 132
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-01-09', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 36, 'TPpct': Decimal('0'), 'FP': 42, 'FPpct': Decimal('0'), 'TN': 383, 'TNpct': Decimal('0'), 'FN': 132, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8571428571428571'), 'evaluation_timeperiod': '2023-01-09_2023-01-13', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.045455102}, {'cmf': 0.041309495}, {'adx': 0.0417774}, {'roc': 0.06811353}, {'roc3': 0.064906225}, {'roc5': 0.057582285}, {'PCR': 0.045896742}, {'v': 0.040373307}, {'volume_10MA': 0.04162998}, {'volume_25MA': 0.041812014}, {'volume_10DDiff': 0.040623862}, {'volume_25DDiff': 0.041788056}, {'close_diff': 0.31002134}, {'v_diff_pct': 0.028263181}, {'day_of_week': 0.03866651}, {'hour': 0.051780917}]"}
# {'ResponseMetadata': {'RequestId': 'RODJH1PQ8QD2GOBJ9P00LI9I5BVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:24:30 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'RODJH1PQ8QD2GOBJ9P00LI9I5BVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    116999
# 1     34801
# Name: count, dtype: int64
# [12:26:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 24 0 378 84
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-01-16', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 24, 'TPpct': Decimal('0'), 'FP': 0, 'FPpct': Decimal('0'), 'TN': 378, 'TNpct': Decimal('0'), 'FN': 84, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0'), 'evaluation_timeperiod': '2023-01-16_2023-01-20', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.046447996}, {'cmf': 0.0403162}, {'adx': 0.040561296}, {'roc': 0.06937539}, {'roc3': 0.06661221}, {'roc5': 0.057233877}, {'PCR': 0.047399245}, {'v': 0.040971138}, {'volume_10MA': 0.04045692}, {'volume_25MA': 0.041682716}, {'volume_10DDiff': 0.040490426}, {'volume_25DDiff': 0.041615956}, {'close_diff': 0.31417975}, {'v_diff_pct': 0.025736138}, {'day_of_week': 0.03873605}, {'hour': 0.048184674}]"}
# {'ResponseMetadata': {'RequestId': 'KD5B1PC02VVN52KF64O27A49AVVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:26:44 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'KD5B1PC02VVN52KF64O27A49AVVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    117947
# 1     35353
# Name: count, dtype: int64
# [12:28:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 48 6 390 126
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-01-23', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 48, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 390, 'TNpct': Decimal('0'), 'FN': 126, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('8.0'), 'evaluation_timeperiod': '2023-01-23_2023-01-27', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.046697997}, {'cmf': 0.040978093}, {'adx': 0.04151848}, {'roc': 0.07142455}, {'roc3': 0.06638758}, {'roc5': 0.056644734}, {'PCR': 0.047269877}, {'v': 0.039864063}, {'volume_10MA': 0.04122356}, {'volume_25MA': 0.04178659}, {'volume_10DDiff': 0.041605134}, {'volume_25DDiff': 0.041969847}, {'close_diff': 0.30781528}, {'v_diff_pct': 0.022623455}, {'day_of_week': 0.04060758}, {'hour': 0.05158314}]"}
# {'ResponseMetadata': {'RequestId': 'MHUB2NVP4T9L7DLI0P0T59B043VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:28:49 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'MHUB2NVP4T9L7DLI0P0T59B043VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    118985
# 1     35515
# Name: count, dtype: int64
# [12:30:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 30 12 324 222
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-01-30', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 30, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 324, 'TNpct': Decimal('0'), 'FN': 222, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.5'), 'evaluation_timeperiod': '2023-01-30_2023-02-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.046326306}, {'cmf': 0.03929924}, {'adx': 0.040617637}, {'roc': 0.07067273}, {'roc3': 0.06399458}, {'roc5': 0.057414643}, {'PCR': 0.0456039}, {'v': 0.04031095}, {'volume_10MA': 0.03947528}, {'volume_25MA': 0.04185702}, {'volume_10DDiff': 0.039790556}, {'volume_25DDiff': 0.04208575}, {'close_diff': 0.31984785}, {'v_diff_pct': 0.025682414}, {'day_of_week': 0.039048057}, {'hour': 0.047973122}]"}
# {'ResponseMetadata': {'RequestId': '0OI0S6OEE5EB4QL10T8UK1PMRFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:30:51 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '0OI0S6OEE5EB4QL10T8UK1PMRFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    120017
# 1     35983
# Name: count, dtype: int64
# [12:33:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 30 12 518 78
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-02-06', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 30, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 518, 'TNpct': Decimal('0'), 'FN': 78, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.5'), 'evaluation_timeperiod': '2023-02-06_2023-02-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.046073962}, {'cmf': 0.038737748}, {'adx': 0.040664744}, {'roc': 0.070080675}, {'roc3': 0.06486976}, {'roc5': 0.05811872}, {'PCR': 0.044999078}, {'v': 0.04013291}, {'volume_10MA': 0.03901212}, {'volume_25MA': 0.041028883}, {'volume_10DDiff': 0.040550493}, {'volume_25DDiff': 0.040749192}, {'close_diff': 0.31939095}, {'v_diff_pct': 0.028500248}, {'day_of_week': 0.038743034}, {'hour': 0.048347425}]"}
# {'ResponseMetadata': {'RequestId': 'SPBNQQLVT9A85GJIU8QMVPOJRJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:33:31 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'SPBNQQLVT9A85GJIU8QMVPOJRJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    120879
# 1     36621
# Name: count, dtype: int64
# [12:36:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 24 22 452 48
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-02-13', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 24, 'TPpct': Decimal('0'), 'FP': 22, 'FPpct': Decimal('0'), 'TN': 452, 'TNpct': Decimal('0'), 'FN': 48, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0909090909090908'), 'evaluation_timeperiod': '2023-02-13_2023-02-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.046836536}, {'cmf': 0.038899194}, {'adx': 0.04310002}, {'roc': 0.06913277}, {'roc3': 0.06873924}, {'roc5': 0.05602562}, {'PCR': 0.04414839}, {'v': 0.040705618}, {'volume_10MA': 0.039321654}, {'volume_25MA': 0.041153062}, {'volume_10DDiff': 0.03930211}, {'volume_25DDiff': 0.041749477}, {'close_diff': 0.31150976}, {'v_diff_pct': 0.02365085}, {'day_of_week': 0.039963488}, {'hour': 0.055762216}]"}
# {'ResponseMetadata': {'RequestId': 'CC4HQN9U8RC27EVQ1D8TBC0MEJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:36:30 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'CC4HQN9U8RC27EVQ1D8TBC0MEJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    122193
# 1     36807
# Name: count, dtype: int64
# [12:39:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 0 0 408 24
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-02-20', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 0, 'FPpct': Decimal('0'), 'TN': 408, 'TNpct': Decimal('0'), 'FN': 24, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0'), 'evaluation_timeperiod': '2023-02-20_2023-02-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.045321584}, {'cmf': 0.03939852}, {'adx': 0.04136599}, {'roc': 0.07078629}, {'roc3': 0.06491214}, {'roc5': 0.054713916}, {'PCR': 0.0442132}, {'v': 0.04075407}, {'volume_10MA': 0.040248387}, {'volume_25MA': 0.041048434}, {'volume_10DDiff': 0.040427703}, {'volume_25DDiff': 0.041226946}, {'close_diff': 0.31410733}, {'v_diff_pct': 0.027393065}, {'day_of_week': 0.0401073}, {'hour': 0.053975113}]"}
# {'ResponseMetadata': {'RequestId': 'PFKR6L940HJ669K1O8GKCUOIJNVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:39:35 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'PFKR6L940HJ669K1O8GKCUOIJNVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    123453
# 1     37047
# Name: count, dtype: int64
# [12:42:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 31 6 390 125
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-02-27', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 31, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 390, 'TNpct': Decimal('0'), 'FN': 125, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('5.166666666666667'), 'evaluation_timeperiod': '2023-02-27_2023-03-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.047154535}, {'cmf': 0.03980544}, {'adx': 0.042617552}, {'roc': 0.06979221}, {'roc3': 0.06412064}, {'roc5': 0.05607704}, {'PCR': 0.046345156}, {'v': 0.040454134}, {'volume_10MA': 0.039352845}, {'volume_25MA': 0.041241147}, {'volume_10DDiff': 0.039656937}, {'volume_25DDiff': 0.041943256}, {'close_diff': 0.31531417}, {'v_diff_pct': 0.025074508}, {'day_of_week': 0.03942429}, {'hour': 0.051626105}]"}
# {'ResponseMetadata': {'RequestId': 'AC7CVFR9CUOHGDMM79VNVS7VDBVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:42:31 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'AC7CVFR9CUOHGDMM79VNVS7VDBVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    124581
# 1     37119
# Name: count, dtype: int64
# [12:44:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 18 6 565 18
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-03-06', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 18, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 565, 'TNpct': Decimal('0'), 'FN': 18, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.0'), 'evaluation_timeperiod': '2023-03-06_2023-03-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04649205}, {'cmf': 0.04111342}, {'adx': 0.042811453}, {'roc': 0.069524474}, {'roc3': 0.063208774}, {'roc5': 0.058401547}, {'PCR': 0.045855775}, {'v': 0.04107545}, {'volume_10MA': 0.039590653}, {'volume_25MA': 0.04356316}, {'volume_10DDiff': 0.039720587}, {'volume_25DDiff': 0.04143405}, {'close_diff': 0.31609863}, {'v_diff_pct': 0.023886703}, {'day_of_week': 0.04030591}, {'hour': 0.046917308}]"}
# {'ResponseMetadata': {'RequestId': '8MTHBOI7U2I90VPPGT7FD8U8IFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:44:59 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '8MTHBOI7U2I90VPPGT7FD8U8IFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    125841
# 1     37359
# Name: count, dtype: int64
# [12:47:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 42 12 348 126
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-03-13', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 42, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 348, 'TNpct': Decimal('0'), 'FN': 126, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.5'), 'evaluation_timeperiod': '2023-03-13_2023-03-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.045351718}, {'cmf': 0.039877895}, {'adx': 0.042090505}, {'roc': 0.06952178}, {'roc3': 0.06893489}, {'roc5': 0.05644185}, {'PCR': 0.046840623}, {'v': 0.04055817}, {'volume_10MA': 0.039928902}, {'volume_25MA': 0.041231282}, {'volume_10DDiff': 0.0395076}, {'volume_25DDiff': 0.0412552}, {'close_diff': 0.3157937}, {'v_diff_pct': 0.025262216}, {'day_of_week': 0.040505882}, {'hour': 0.046897788}]"}
# {'ResponseMetadata': {'RequestId': 'T4EFIVK692J1I67PGFRM2CR327VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:47:30 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'T4EFIVK692J1I67PGFRM2CR327VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    127197
# 1     37503
# Name: count, dtype: int64
# [12:50:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 25 24 438 101
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-03-20', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 25, 'TPpct': Decimal('0'), 'FP': 24, 'FPpct': Decimal('0'), 'TN': 438, 'TNpct': Decimal('0'), 'FN': 101, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0416666666666667'), 'evaluation_timeperiod': '2023-03-20_2023-03-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04637959}, {'cmf': 0.03987806}, {'adx': 0.042458322}, {'roc': 0.07074144}, {'roc3': 0.063938715}, {'roc5': 0.057280533}, {'PCR': 0.047400806}, {'v': 0.03998569}, {'volume_10MA': 0.03956853}, {'volume_25MA': 0.04141271}, {'volume_10DDiff': 0.04034923}, {'volume_25DDiff': 0.042157263}, {'close_diff': 0.3169103}, {'v_diff_pct': 0.024644202}, {'day_of_week': 0.040315107}, {'hour': 0.046579488}]"}
# {'ResponseMetadata': {'RequestId': 'IKS5RLT53UST9OTJR18R32LBMBVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:50:34 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'IKS5RLT53UST9OTJR18R32LBMBVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    128367
# 1     37833
# Name: count, dtype: int64
# [12:52:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 48 0 290 214
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-03-27', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 48, 'TPpct': Decimal('0'), 'FP': 0, 'FPpct': Decimal('0'), 'TN': 290, 'TNpct': Decimal('0'), 'FN': 214, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0'), 'evaluation_timeperiod': '2023-03-27_2023-03-31', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04490943}, {'cmf': 0.0407508}, {'adx': 0.041901585}, {'roc': 0.06961719}, {'roc3': 0.064495854}, {'roc5': 0.054392017}, {'PCR': 0.04701979}, {'v': 0.039333142}, {'volume_10MA': 0.040428914}, {'volume_25MA': 0.042020787}, {'volume_10DDiff': 0.04016233}, {'volume_25DDiff': 0.042594742}, {'close_diff': 0.32016966}, {'v_diff_pct': 0.02638104}, {'day_of_week': 0.04150481}, {'hour': 0.04431791}]"}
# {'ResponseMetadata': {'RequestId': 'EO555KV3QJHS1TNLMTRH5TDGFVVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:53:02 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'EO555KV3QJHS1TNLMTRH5TDGFVVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    129519
# 1     38181
# Name: count, dtype: int64
# [12:56:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 12 12 420 84
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-04-03', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 12, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 420, 'TNpct': Decimal('0'), 'FN': 84, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0'), 'evaluation_timeperiod': '2023-04-03_2023-04-07', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.046296094}, {'cmf': 0.04002272}, {'adx': 0.042456232}, {'roc': 0.0706058}, {'roc3': 0.062419202}, {'roc5': 0.05602569}, {'PCR': 0.047301095}, {'v': 0.04126864}, {'volume_10MA': 0.039005887}, {'volume_25MA': 0.0416277}, {'volume_10DDiff': 0.038992822}, {'volume_25DDiff': 0.042601004}, {'close_diff': 0.3208748}, {'v_diff_pct': 0.029013773}, {'day_of_week': 0.039085608}, {'hour': 0.042402875}]"}
# {'ResponseMetadata': {'RequestId': 'G59AUQQLJHIUCR6QFLFF36HUEFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 16:56:12 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'G59AUQQLJHIUCR6QFLFF36HUEFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    130479
# 1     38721
# Name: count, dtype: int64
# [13:19:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 18 0 516 90
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-04-10', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 18, 'TPpct': Decimal('0'), 'FP': 0, 'FPpct': Decimal('0'), 'TN': 516, 'TNpct': Decimal('0'), 'FN': 90, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0'), 'evaluation_timeperiod': '2023-04-10_2023-04-14', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.045278396}, {'cmf': 0.039491422}, {'adx': 0.041973732}, {'roc': 0.06917095}, {'roc3': 0.06303758}, {'roc5': 0.05589466}, {'PCR': 0.04554646}, {'v': 0.040011432}, {'volume_10MA': 0.03941374}, {'volume_25MA': 0.04160898}, {'volume_10DDiff': 0.039166737}, {'volume_25DDiff': 0.04113624}, {'close_diff': 0.33405375}, {'v_diff_pct': 0.021342874}, {'day_of_week': 0.040351685}, {'hour': 0.042521343}]"}
# {'ResponseMetadata': {'RequestId': 'DNVSV6F3GL8RR3MJ0CJINLS6FJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 17:19:07 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'DNVSV6F3GL8RR3MJ0CJINLS6FJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    131759
# 1     38941
# Name: count, dtype: int64
# [13:21:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 12 0 518 84
# ...
# {'ResponseMetadata': {'RequestId': 'OD3NCIV5GJSBMHDMGEFOOUOCEJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 17:27:31 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'OD3NCIV5GJSBMHDMGEFOOUOCEJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    136715
# 1     39685
# Name: count, dtype: int64
# [13:29:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 37 6 396 143
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-05-15', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 37, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 396, 'TNpct': Decimal('0'), 'FN': 143, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('6.166666666666667'), 'evaluation_timeperiod': '2023-05-15_2023-05-19', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.044476032}, {'cmf': 0.04059682}, {'adx': 0.042132672}, {'roc': 0.06906323}, {'roc3': 0.061747607}, {'roc5': 0.05792882}, {'PCR': 0.048371617}, {'v': 0.038874608}, {'volume_10MA': 0.039352555}, {'volume_25MA': 0.041425187}, {'volume_10DDiff': 0.040140428}, {'volume_25DDiff': 0.041430663}, {'close_diff': 0.32932356}, {'v_diff_pct': 0.023914203}, {'day_of_week': 0.038226612}, {'hour': 0.042995367}]"}
# {'ResponseMetadata': {'RequestId': 'ET62D3JQUBKIRR1KHS9H7UN0BRVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 17:29:24 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'ET62D3JQUBKIRR1KHS9H7UN0BRVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    137999
# 1     39901
# Name: count, dtype: int64
# [13:31:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 6 6 554 90
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-05-22', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 6, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 554, 'TNpct': Decimal('0'), 'FN': 90, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0'), 'evaluation_timeperiod': '2023-05-22_2023-05-26', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.044531792}, {'cmf': 0.039233774}, {'adx': 0.041388817}, {'roc': 0.065822475}, {'roc3': 0.061630927}, {'roc5': 0.05717277}, {'PCR': 0.0469118}, {'v': 0.039141342}, {'volume_10MA': 0.03783096}, {'volume_25MA': 0.039027333}, {'volume_10DDiff': 0.03898149}, {'volume_25DDiff': 0.041126393}, {'close_diff': 0.3390802}, {'v_diff_pct': 0.026156573}, {'day_of_week': 0.038751196}, {'hour': 0.04321207}]"}
# {'ResponseMetadata': {'RequestId': 'GOOIPFGT42GS8KG2OBIKPOLG3FVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 17:31:23 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'GOOIPFGT42GS8KG2OBIKPOLG3FVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    139205
# 1     40195
# Name: count, dtype: int64
# [13:33:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 18 12 252 168
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-05-29', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 18, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 252, 'TNpct': Decimal('0'), 'FN': 168, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.5'), 'evaluation_timeperiod': '2023-05-29_2023-06-02', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.044481937}, {'cmf': 0.038694836}, {'adx': 0.041775715}, {'roc': 0.06913542}, {'roc3': 0.061752982}, {'roc5': 0.05506438}, {'PCR': 0.04739159}, {'v': 0.038223304}, {'volume_10MA': 0.038896617}, {'volume_25MA': 0.041556407}, {'volume_10DDiff': 0.03879452}, {'volume_25DDiff': 0.03966817}, {'close_diff': 0.3369852}, {'v_diff_pct': 0.02475159}, {'day_of_week': 0.03922531}, {'hour': 0.043602064}]"}
# {'ResponseMetadata': {'RequestId': '8S23KUT3584U3MEB2QMNQL3LV3VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 17:33:18 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '8S23KUT3584U3MEB2QMNQL3LV3VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    140555
# 1     40345
# Name: count, dtype: int64
# [13:35:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 24 18 426 156
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-06-05', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 24, 'TPpct': Decimal('0'), 'FP': 18, 'FPpct': Decimal('0'), 'TN': 426, 'TNpct': Decimal('0'), 'FN': 156, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.3333333333333333'), 'evaluation_timeperiod': '2023-06-05_2023-06-09', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.043555293}, {'cmf': 0.03927374}, {'adx': 0.04043395}, {'roc': 0.068740614}, {'roc3': 0.060117397}, {'roc5': 0.055163216}, {'PCR': 0.048164215}, {'v': 0.039099496}, {'volume_10MA': 0.038082108}, {'volume_25MA': 0.04034829}, {'volume_10DDiff': 0.039194155}, {'volume_25DDiff': 0.043438792}, {'close_diff': 0.33744395}, {'v_diff_pct': 0.022846509}, {'day_of_week': 0.038101364}, {'hour': 0.04599678}]"}
# {'ResponseMetadata': {'RequestId': 'H6C5GEKHUNDG51TDSDMKAO1RFBVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 17:35:22 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'H6C5GEKHUNDG51TDSDMKAO1RFBVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    141473
# 1     40627
# Name: count, dtype: int64
# [13:37:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 25 12 378 101
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-06-12', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 25, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 378, 'TNpct': Decimal('0'), 'FN': 101, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.0833333333333335'), 'evaluation_timeperiod': '2023-06-12_2023-06-16', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.044988737}, {'cmf': 0.03781962}, {'adx': 0.040761713}, {'roc': 0.06742909}, {'roc3': 0.06383547}, {'roc5': 0.055124193}, {'PCR': 0.04672064}, {'v': 0.0372663}, {'volume_10MA': 0.039182924}, {'volume_25MA': 0.04024225}, {'volume_10DDiff': 0.03933235}, {'volume_25DDiff': 0.0401623}, {'close_diff': 0.3385062}, {'v_diff_pct': 0.028546615}, {'day_of_week': 0.038351655}, {'hour': 0.04173003}]"}
# {'ResponseMetadata': {'RequestId': 'T449TDKFJURNB62166P8JCMKSBVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 17:37:22 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'T449TDKFJURNB62166P8JCMKSBVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    142493
# 1     41107
# Name: count, dtype: int64
# [13:39:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 18 6 444 12
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-06-19', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 18, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 444, 'TNpct': Decimal('0'), 'FN': 12, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.0'), 'evaluation_timeperiod': '2023-06-19_2023-06-23', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.045616563}, {'cmf': 0.03794058}, {'adx': 0.04202902}, {'roc': 0.06716037}, {'roc3': 0.06364717}, {'roc5': 0.05280216}, {'PCR': 0.046659403}, {'v': 0.03951082}, {'volume_10MA': 0.03907179}, {'volume_25MA': 0.041739736}, {'volume_10DDiff': 0.03923499}, {'volume_25DDiff': 0.041148975}, {'close_diff': 0.3315223}, {'v_diff_pct': 0.029792093}, {'day_of_week': 0.038129408}, {'hour': 0.04399466}]"}
# {'ResponseMetadata': {'RequestId': 'CP2SB9IKGNAO359779BKDDBHDJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 17:39:24 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'CP2SB9IKGNAO359779BKDDBHDJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    143651
# 1     41449
# Name: count, dtype: int64
# [13:41:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 13 6 446 145
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-06-26', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 13, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 446, 'TNpct': Decimal('0'), 'FN': 145, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.1666666666666665'), 'evaluation_timeperiod': '2023-06-26_2023-06-30', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04399323}, {'cmf': 0.038434956}, {'adx': 0.040677335}, {'roc': 0.06691388}, {'roc3': 0.06150756}, {'roc5': 0.054501716}, {'PCR': 0.04625385}, {'v': 0.039111428}, {'volume_10MA': 0.038627088}, {'volume_25MA': 0.040719416}, {'volume_10DDiff': 0.03797143}, {'volume_25DDiff': 0.040553953}, {'close_diff': 0.34304518}, {'v_diff_pct': 0.02976715}, {'day_of_week': 0.03607921}, {'hour': 0.041842587}]"}
# {'ResponseMetadata': {'RequestId': 'JUF0R7EG0PKRFCVT591B0IDNBVVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 17:41:49 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'JUF0R7EG0PKRFCVT591B0IDNBVVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# label
# 0    144797
# 1     41503
# Name: count, dtype: int64
# [13:45:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 6 6 318 36
# {'model_name': 'inv_alerts_vdiff_lossC_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-07-03', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 6, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 318, 'TNpct': Decimal('0'), 'FN': 36, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0'), 'evaluation_timeperiod': '2023-07-03_2023-07-07', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04358423}, {'cmf': 0.039300755}, {'adx': 0.042071983}, {'roc': 0.067265496}, {'roc3': 0.06319407}, {'roc5': 0.0550241}, {'PCR': 0.04733245}, {'v': 0.03793797}, {'volume_10MA': 0.03859627}, {'volume_25MA': 0.040807802}, {'volume_10DDiff': 0.03955046}, {'volume_25DDiff': 0.041555423}, {'close_diff': 0.32972953}, {'v_diff_pct': 0.03148549}, {'day_of_week': 0.039011315}, {'hour': 0.043552738}]"}
# {'ResponseMetadata': {'RequestId': '6O90D0KT4TCQ7LCHOG05V728RJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Fri, 14 Jul 2023 17:45:26 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '6O90D0KT4TCQ7LCHOG05V728RJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
