# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler
import pytz

# %%
s3 = boto3.client('s3')

training_bucket = "icarus-research-data"
training_prefix = 'training_datasets/expanded_1d_datasets/'

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

# %%
def create_training_data_local(key_list, prefix, bucket_name,title, start_date, end_date):
    df_list = []
    hours = [10,11,12,13,14,15]
    start = start_date.split(' ')[0]
    end = end_date.split(' ')[0]
    # print(file_key)
    for key in key_list:
        for hour in hours:
            try:
                data = s3.get_object(Bucket=bucket_name, Key=f'{prefix}{key}/{hour}.csv')
                df = pd.read_csv(data.get("Body")) 
                df_list.append(df)
                df['hour'] = hour
            except:
                continue

    data = pd.concat(df_list)
    data.reset_index(drop=True, inplace=True)
    data['dt'] = pd.to_datetime(data['date'])
    data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek)
    data = data.round(3)
    data.replace([np.inf, -np.inf], 0, inplace=True)

    data.to_csv(f'/Users/charlesmiller/Documents/INDEX/{start}_{end}.csv', index=False)

    return data

# %%
def pull_training_data_local(end_date,start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/INDEX/2018-01-01_2023-10-28.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data


def pull_validation_data_local(end_date,start_date):
    start_str = start_date.strftime('%Y-%m-%d %H:%M:%S%z').split(' ')[0]
    end_str = end_date.strftime('%Y-%m-%d %H:%M:%S%z').split(' ')[0]
    start_dt = datetime.strptime(start_str, '%Y-%m-%d')
    end_dt = datetime.strptime(end_str, '%Y-%m-%d')
    data = pd.read_csv(f'/Users/charlesmiller/Documents/INDEX/2018-01-01_2023-10-28.csv')
    data['dt'] = pd.to_datetime(data['date'])
    print(data['dt'])
    data = data.loc[data['dt'] <= end_dt]
    data = data.loc[data['dt'] >= start_dt]
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data

# %%
def build_date_list(start_date, end_date):
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_validation_dates_local(deployment_date):
    end_date = deployment_date + timedelta(days=5)
    return end_date

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] < target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] < target_value).astype(int)

    scaler = StandardScaler()
    
    X = dataset[features]
    y = dataset['label']

    print(y.value_counts())
    X_validate = validation_dataset[features]
    y_validate = validation_dataset['label']

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    probabilities = xgb_model.predict_proba(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, str(fi_list), predictions, probabilities

def train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] < target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] < target_value).astype(int)

    dataset = dataset.round(3)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features]
    y = dataset['label']

    X_validate = validation_dataset[features]
    y_validate = validation_dataset['label']

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,"str(fi_list)", predictions, "probabilities"

# %%
def model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
    # dates = build_date_list(start_date, end_date)
    # key_list = build_query_keys(dates)
    validation_end_date = build_validation_dates_local(deployment_date)
    # validation_keys = build_query_keys_validation(deployment_date)
    # validation_dataset = create_validation_data(validation_keys, 'fixed_alerts_full/new_features/big_fish_stable/', 'inv-alerts')
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    # else:
    #     dataset = create_training_data_v2(key_list, 'fixed_alerts_full/new_features/big_fish/', 'inv-alerts')
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
    validation_dataset['probabilities'] = probabilities[:,1]
    validation_dataset['predictions'] = predictions
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    return response

def model_runner_data(model_name, dataset_name, title, features, target_label, target_value,start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams):
    dates = build_date_list(start_date, end_date)
    key_list = build_query_keys(dates)
    dataset = create_training_data_local(key_list, 'fixed_alerts_full/new_features/indexes/', 'inv-alerts', title, start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
    return dataset


def model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,end_date,deployment_date,hyperparams):
    validation_end_date = build_validation_dates_local(deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    return tp, fp, fn, tn

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=10),
            "dataset_start": datetime(2020,1,1)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

# %%
#ma_cont_classifier_EXPvDiff_HistData
#ma_cont_classifier_EXPvDiff_HistData_NOVAL
#ma_cont_classifier_EXPvDiffDYNTUN_HistData_NOVAL
#'ma_cont_classifier_EXPvDiffDYNTUN_HistData_NOVAL

model_name = 'INDEXP:1D_TSSIM1_best231110_custHypP09_2018'
dataset_name = '1D_TSSIM1_best231110_custHypP09_2018'
title = 'INDEXP_1D'
hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
features = ['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']
target_label = 'one_min'
target_value = -.009

dataset_start_date = datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')) 
dates_list = build_evaluation_period(datetime(2022,10,3,tzinfo=pytz.timezone('US/Eastern')), datetime(2023,10,14,tzinfo=pytz.timezone('US/Eastern')))

# date = dates_list[-1]
# response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
for date in dates_list:
    response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])
# Out:
# label
# 0    12734
# 1     8290
# Name: count, dtype: int64
# 10 10 30 22
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2022-10-24', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 10, 'TPpct': Decimal('0'), 'FP': 10, 'FPpct': Decimal('0'), 'TN': 30, 'TNpct': Decimal('0'), 'FN': 22, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0'), 'evaluation_timeperiod': '2022-10-24_2022-10-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08864148}, {'price_25MA': 0.0741965}, {'range_vol5MA': 0.22843315}, {'close_diff_deviation3': 0.0680001}, {'range_vol25MA': 0.08148753}, {'adx': 0.073024936}, {'close_diff5': 0.07693013}, {'threeD_stddev50': 0.08617815}, {'oneD_returns_close': 0.08207291}, {'oneD_stddev50': 0.07478889}, {'range_vol_diff5': 0.06624624}]"}
# label
# 0    12771
# 1     8343
# Name: count, dtype: int64
# 32 27 6 25
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2022-10-31', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 32, 'TPpct': Decimal('0'), 'FP': 27, 'FPpct': Decimal('0'), 'TN': 6, 'TNpct': Decimal('0'), 'FN': 25, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.1851851851851851'), 'evaluation_timeperiod': '2022-10-31_2022-11-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08298227}, {'price_25MA': 0.07312298}, {'range_vol5MA': 0.25253406}, {'close_diff_deviation3': 0.0681752}, {'range_vol25MA': 0.0738937}, {'adx': 0.0719341}, {'close_diff5': 0.0737512}, {'threeD_stddev50': 0.080866076}, {'oneD_returns_close': 0.08157514}, {'oneD_stddev50': 0.07555217}, {'range_vol_diff5': 0.06561307}]"}
# label
# 0    12814
# 1     8372
# Name: count, dtype: int64
# 28 32 19 11
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2022-11-07', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 28, 'TPpct': Decimal('0'), 'FP': 32, 'FPpct': Decimal('0'), 'TN': 19, 'TNpct': Decimal('0'), 'FN': 11, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.875'), 'evaluation_timeperiod': '2022-11-07_2022-11-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.086033545}, {'price_25MA': 0.07651479}, {'range_vol5MA': 0.23317617}, {'close_diff_deviation3': 0.067840286}, {'range_vol25MA': 0.076882884}, {'adx': 0.07543533}, {'close_diff5': 0.07427485}, {'threeD_stddev50': 0.08182136}, {'oneD_returns_close': 0.083336875}, {'oneD_stddev50': 0.08161678}, {'range_vol_diff5': 0.063067116}]"}
# label
# 0    12849
# 1     8427
# Name: count, dtype: int64
# 29 24 13 24
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2022-11-14', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 29, 'TPpct': Decimal('0'), 'FP': 24, 'FPpct': Decimal('0'), 'TN': 13, 'TNpct': Decimal('0'), 'FN': 24, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.2083333333333333'), 'evaluation_timeperiod': '2022-11-14_2022-11-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08345764}, {'price_25MA': 0.07459031}, {'range_vol5MA': 0.24050468}, {'close_diff_deviation3': 0.070173785}, {'range_vol25MA': 0.07293696}, {'adx': 0.073629946}, {'close_diff5': 0.075350024}, {'threeD_stddev50': 0.08306386}, {'oneD_returns_close': 0.08124546}, {'oneD_stddev50': 0.0779522}, {'range_vol_diff5': 0.06709524}]"}
# label
# 0    12901
# 1     8465
# Name: count, dtype: int64
# 9 18 33 6
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2022-11-21', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 9, 'TPpct': Decimal('0'), 'FP': 18, 'FPpct': Decimal('0'), 'TN': 33, 'TNpct': Decimal('0'), 'FN': 6, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5'), 'evaluation_timeperiod': '2022-11-21_2022-11-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08474279}, {'price_25MA': 0.074700385}, {'range_vol5MA': 0.23074698}, {'close_diff_deviation3': 0.06890427}, {'range_vol25MA': 0.08122402}, {'adx': 0.07437014}, {'close_diff5': 0.075235404}, {'threeD_stddev50': 0.079882815}, {'oneD_returns_close': 0.08687255}, {'oneD_stddev50': 0.07964063}, {'range_vol_diff5': 0.06368001}]"}
# label
# 0    12938
# 1     8518
# Name: count, dtype: int64
# 28 11 22 29
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2022-11-28', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 28, 'TPpct': Decimal('0'), 'FP': 11, 'FPpct': Decimal('0'), 'TN': 22, 'TNpct': Decimal('0'), 'FN': 29, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.5454545454545454'), 'evaluation_timeperiod': '2022-11-28_2022-12-02', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08441131}, {'price_25MA': 0.073825985}, {'range_vol5MA': 0.24406843}, {'close_diff_deviation3': 0.069640554}, {'range_vol25MA': 0.0771906}, {'adx': 0.07326168}, {'close_diff5': 0.07486904}, {'threeD_stddev50': 0.08276851}, {'oneD_returns_close': 0.07850495}, {'oneD_stddev50': 0.075595}, {'range_vol_diff5': 0.06586398}]"}
# label
# 0    13000
# 1     8528
# Name: count, dtype: int64
# 34 23 23 10
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2022-12-05', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 34, 'TPpct': Decimal('0'), 'FP': 23, 'FPpct': Decimal('0'), 'TN': 23, 'TNpct': Decimal('0'), 'FN': 10, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.4782608695652173'), 'evaluation_timeperiod': '2022-12-05_2022-12-09', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.089994356}, {'price_25MA': 0.07372889}, {'range_vol5MA': 0.23340374}, {'close_diff_deviation3': 0.070208184}, {'range_vol25MA': 0.07565947}, {'adx': 0.07324916}, {'close_diff5': 0.07520533}, {'threeD_stddev50': 0.082951516}, {'oneD_returns_close': 0.080645315}, {'oneD_stddev50': 0.079102375}, {'range_vol_diff5': 0.065851554}]"}
# label
# 0    13033
# 1     8579
# Name: count, dtype: int64
# 43 23 1 23
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2022-12-12', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 43, 'TPpct': Decimal('0'), 'FP': 23, 'FPpct': Decimal('0'), 'TN': 1, 'TNpct': Decimal('0'), 'FN': 23, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.8695652173913044'), 'evaluation_timeperiod': '2022-12-12_2022-12-16', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08674574}, {'price_25MA': 0.075861536}, {'range_vol5MA': 0.2355781}, {'close_diff_deviation3': 0.067321084}, {'range_vol25MA': 0.07491017}, {'adx': 0.07412268}, {'close_diff5': 0.073254235}, {'threeD_stddev50': 0.08350184}, {'oneD_returns_close': 0.08160563}, {'oneD_stddev50': 0.079971544}, {'range_vol_diff5': 0.067127444}]"}
# label
# 0    13072
# 1     8630
# Name: count, dtype: int64
# 33 49 5 3
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2022-12-19', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 33, 'TPpct': Decimal('0'), 'FP': 49, 'FPpct': Decimal('0'), 'TN': 5, 'TNpct': Decimal('0'), 'FN': 3, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.673469387755102'), 'evaluation_timeperiod': '2022-12-19_2022-12-23', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08691049}, {'price_25MA': 0.07592353}, {'range_vol5MA': 0.23195888}, {'close_diff_deviation3': 0.069435775}, {'range_vol25MA': 0.074409455}, {'adx': 0.075164385}, {'close_diff5': 0.07502952}, {'threeD_stddev50': 0.080021225}, {'oneD_returns_close': 0.08380719}, {'oneD_stddev50': 0.07881024}, {'range_vol_diff5': 0.068529285}]"}
# label
# 0    13098
# 1     8694
# Name: count, dtype: int64
# 15 9 27 21
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2022-12-26', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 15, 'TPpct': Decimal('0'), 'FP': 9, 'FPpct': Decimal('0'), 'TN': 27, 'TNpct': Decimal('0'), 'FN': 21, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.6666666666666667'), 'evaluation_timeperiod': '2022-12-26_2022-12-30', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08447767}, {'price_25MA': 0.073215775}, {'range_vol5MA': 0.24998079}, {'close_diff_deviation3': 0.06561813}, {'range_vol25MA': 0.07561702}, {'adx': 0.07185871}, {'close_diff5': 0.071731955}, {'threeD_stddev50': 0.08139718}, {'oneD_returns_close': 0.084036745}, {'oneD_stddev50': 0.07810907}, {'range_vol_diff5': 0.063956924}]"}
# label
# 0    13139
# 1     8743
# Name: count, dtype: int64
# 7 15 31 19
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-01-02', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 7, 'TPpct': Decimal('0'), 'FP': 15, 'FPpct': Decimal('0'), 'TN': 31, 'TNpct': Decimal('0'), 'FN': 19, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.4666666666666667'), 'evaluation_timeperiod': '2023-01-02_2023-01-06', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.084299855}, {'price_25MA': 0.07424649}, {'range_vol5MA': 0.2543111}, {'close_diff_deviation3': 0.06654152}, {'range_vol25MA': 0.075748235}, {'adx': 0.07387761}, {'close_diff5': 0.07225853}, {'threeD_stddev50': 0.076616876}, {'oneD_returns_close': 0.07946663}, {'oneD_stddev50': 0.0767257}, {'range_vol_diff5': 0.06590741}]"}
# label
# 0    13175
# 1     8779
# Name: count, dtype: int64
# 3 16 54 17
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-01-09', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 3, 'TPpct': Decimal('0'), 'FP': 16, 'FPpct': Decimal('0'), 'TN': 54, 'TNpct': Decimal('0'), 'FN': 17, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.1875'), 'evaluation_timeperiod': '2023-01-09_2023-01-13', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08276714}, {'price_25MA': 0.07418344}, {'range_vol5MA': 0.24126236}, {'close_diff_deviation3': 0.06643241}, {'range_vol25MA': 0.076807104}, {'adx': 0.07361126}, {'close_diff5': 0.073886864}, {'threeD_stddev50': 0.07962508}, {'oneD_returns_close': 0.08302438}, {'oneD_stddev50': 0.08250587}, {'range_vol_diff5': 0.06589409}]"}
# label
# 0    13221
# 1     8805
# Name: count, dtype: int64
# 10 8 28 26
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-01-16', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 10, 'TPpct': Decimal('0'), 'FP': 8, 'FPpct': Decimal('0'), 'TN': 28, 'TNpct': Decimal('0'), 'FN': 26, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.25'), 'evaluation_timeperiod': '2023-01-16_2023-01-20', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08189876}, {'price_25MA': 0.07671944}, {'range_vol5MA': 0.2507669}, {'close_diff_deviation3': 0.06610287}, {'range_vol25MA': 0.07372465}, {'adx': 0.07432395}, {'close_diff5': 0.07466716}, {'threeD_stddev50': 0.07471892}, {'oneD_returns_close': 0.0806598}, {'oneD_stddev50': 0.08139682}, {'range_vol_diff5': 0.06502075}]"}
# label
# 0    13291
# 1     8825
# Name: count, dtype: int64
# 8 12 37 33
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-01-23', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 8, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 37, 'TNpct': Decimal('0'), 'FN': 33, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6666666666666666'), 'evaluation_timeperiod': '2023-01-23_2023-01-27', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.082473226}, {'price_25MA': 0.07416717}, {'range_vol5MA': 0.23825708}, {'close_diff_deviation3': 0.06726541}, {'range_vol25MA': 0.07877625}, {'adx': 0.07481527}, {'close_diff5': 0.074670054}, {'threeD_stddev50': 0.077015616}, {'oneD_returns_close': 0.0810457}, {'oneD_stddev50': 0.08578815}, {'range_vol_diff5': 0.065726094}]"}
# label
# 0    13327
# 1     8861
# Name: count, dtype: int64
# 13 17 38 22
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-01-30', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 13, 'TPpct': Decimal('0'), 'FP': 17, 'FPpct': Decimal('0'), 'TN': 38, 'TNpct': Decimal('0'), 'FN': 22, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.7647058823529411'), 'evaluation_timeperiod': '2023-01-30_2023-02-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08114864}, {'price_25MA': 0.07249682}, {'range_vol5MA': 0.24792635}, {'close_diff_deviation3': 0.06646501}, {'range_vol25MA': 0.07566401}, {'adx': 0.07476195}, {'close_diff5': 0.07224126}, {'threeD_stddev50': 0.077327006}, {'oneD_returns_close': 0.08385345}, {'oneD_stddev50': 0.07956534}, {'range_vol_diff5': 0.068550184}]"}
# label
# 0    13393
# 1     8885
# Name: count, dtype: int64
# 30 20 24 16
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-02-06', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 30, 'TPpct': Decimal('0'), 'FP': 20, 'FPpct': Decimal('0'), 'TN': 24, 'TNpct': Decimal('0'), 'FN': 16, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.5'), 'evaluation_timeperiod': '2023-02-06_2023-02-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08364967}, {'price_25MA': 0.072424516}, {'range_vol5MA': 0.23966114}, {'close_diff_deviation3': 0.07046847}, {'range_vol25MA': 0.07663776}, {'adx': 0.07421285}, {'close_diff5': 0.073013745}, {'threeD_stddev50': 0.079783335}, {'oneD_returns_close': 0.08030783}, {'oneD_stddev50': 0.08115412}, {'range_vol_diff5': 0.06868657}]"}
# label
# 0    13448
# 1     8920
# Name: count, dtype: int64
# 12 13 39 26
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-02-13', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 12, 'TPpct': Decimal('0'), 'FP': 13, 'FPpct': Decimal('0'), 'TN': 39, 'TNpct': Decimal('0'), 'FN': 26, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.9230769230769231'), 'evaluation_timeperiod': '2023-02-13_2023-02-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08451997}, {'price_25MA': 0.07464531}, {'range_vol5MA': 0.23052558}, {'close_diff_deviation3': 0.06878865}, {'range_vol25MA': 0.07522245}, {'adx': 0.07594595}, {'close_diff5': 0.07510675}, {'threeD_stddev50': 0.08270648}, {'oneD_returns_close': 0.08533376}, {'oneD_stddev50': 0.08358732}, {'range_vol_diff5': 0.06361786}]"}
# label
# 0    13475
# 1     8983
# Name: count, dtype: int64
# 12 31 15 14
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-02-20', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 12, 'TPpct': Decimal('0'), 'FP': 31, 'FPpct': Decimal('0'), 'TN': 15, 'TNpct': Decimal('0'), 'FN': 14, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.3870967741935484'), 'evaluation_timeperiod': '2023-02-20_2023-02-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08652316}, {'price_25MA': 0.074129336}, {'range_vol5MA': 0.23320113}, {'close_diff_deviation3': 0.06847646}, {'range_vol25MA': 0.07955698}, {'adx': 0.07521057}, {'close_diff5': 0.07438991}, {'threeD_stddev50': 0.08065801}, {'oneD_returns_close': 0.07922063}, {'oneD_stddev50': 0.08311636}, {'range_vol_diff5': 0.06551741}]"}
# label
# 0    13527
# 1     9021
# Name: count, dtype: int64
# 11 27 28 24
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-02-27', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 11, 'TPpct': Decimal('0'), 'FP': 27, 'FPpct': Decimal('0'), 'TN': 28, 'TNpct': Decimal('0'), 'FN': 24, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.4074074074074074'), 'evaluation_timeperiod': '2023-02-27_2023-03-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08428565}, {'price_25MA': 0.07445851}, {'range_vol5MA': 0.24826987}, {'close_diff_deviation3': 0.067788325}, {'range_vol25MA': 0.07689889}, {'adx': 0.07309866}, {'close_diff5': 0.071142346}, {'threeD_stddev50': 0.07657387}, {'oneD_returns_close': 0.08219292}, {'oneD_stddev50': 0.07951474}, {'range_vol_diff5': 0.065776214}]"}
# label
# 0    13573
# 1     9047
# Name: count, dtype: int64
# 27 7 4 52
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-03-06', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 27, 'TPpct': Decimal('0'), 'FP': 7, 'FPpct': Decimal('0'), 'TN': 4, 'TNpct': Decimal('0'), 'FN': 52, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.857142857142857'), 'evaluation_timeperiod': '2023-03-06_2023-03-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.086421885}, {'price_25MA': 0.07502493}, {'range_vol5MA': 0.2373758}, {'close_diff_deviation3': 0.0678792}, {'range_vol25MA': 0.07594933}, {'adx': 0.07460233}, {'close_diff5': 0.07122167}, {'threeD_stddev50': 0.07952729}, {'oneD_returns_close': 0.08490614}, {'oneD_stddev50': 0.08045912}, {'range_vol_diff5': 0.06663231}]"}
# label
# 0    13632
# 1     9078
# Name: count, dtype: int64
# 25 35 17 13
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-03-13', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 25, 'TPpct': Decimal('0'), 'FP': 35, 'FPpct': Decimal('0'), 'TN': 17, 'TNpct': Decimal('0'), 'FN': 13, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.7142857142857143'), 'evaluation_timeperiod': '2023-03-13_2023-03-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08452414}, {'price_25MA': 0.07413952}, {'range_vol5MA': 0.24744335}, {'close_diff_deviation3': 0.06449704}, {'range_vol25MA': 0.0791448}, {'adx': 0.07593953}, {'close_diff5': 0.07422847}, {'threeD_stddev50': 0.07259928}, {'oneD_returns_close': 0.08200443}, {'oneD_stddev50': 0.08138954}, {'range_vol_diff5': 0.06408991}]"}
# label
# 0    13656
# 1     9144
# Name: count, dtype: int64
# 28 27 15 20
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-03-20', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 28, 'TPpct': Decimal('0'), 'FP': 27, 'FPpct': Decimal('0'), 'TN': 15, 'TNpct': Decimal('0'), 'FN': 20, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.037037037037037'), 'evaluation_timeperiod': '2023-03-20_2023-03-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08282}, {'price_25MA': 0.07406222}, {'range_vol5MA': 0.25830752}, {'close_diff_deviation3': 0.064450145}, {'range_vol25MA': 0.077050656}, {'adx': 0.0737592}, {'close_diff5': 0.073873624}, {'threeD_stddev50': 0.073155314}, {'oneD_returns_close': 0.08151538}, {'oneD_stddev50': 0.079515204}, {'range_vol_diff5': 0.06149083}]"}
# label
# 0    13697
# 1     9193
# Name: count, dtype: int64
# 2 11 64 13
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-03-27', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 2, 'TPpct': Decimal('0'), 'FP': 11, 'FPpct': Decimal('0'), 'TN': 64, 'TNpct': Decimal('0'), 'FN': 13, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.18181818181818182'), 'evaluation_timeperiod': '2023-03-27_2023-03-31', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08342572}, {'price_25MA': 0.07398979}, {'range_vol5MA': 0.23742294}, {'close_diff_deviation3': 0.06688579}, {'range_vol25MA': 0.074598625}, {'adx': 0.074375965}, {'close_diff5': 0.074611865}, {'threeD_stddev50': 0.07745097}, {'oneD_returns_close': 0.081043646}, {'oneD_stddev50': 0.08988341}, {'range_vol_diff5': 0.066311255}]"}
# label
# 0    13733
# 1     9247
# Name: count, dtype: int64
# 16 6 45 5
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-04-03', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 16, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 45, 'TNpct': Decimal('0'), 'FN': 5, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.6666666666666665'), 'evaluation_timeperiod': '2023-04-03_2023-04-07', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.085693225}, {'price_25MA': 0.07503356}, {'range_vol5MA': 0.2415752}, {'close_diff_deviation3': 0.06929798}, {'range_vol25MA': 0.07759711}, {'adx': 0.07460218}, {'close_diff5': 0.07407853}, {'threeD_stddev50': 0.0753038}, {'oneD_returns_close': 0.08357555}, {'oneD_stddev50': 0.0762687}, {'range_vol_diff5': 0.06697417}]"}
# label
# 0    13812
# 1     9258
# Name: count, dtype: int64
# 7 21 43 19
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-04-10', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 7, 'TPpct': Decimal('0'), 'FP': 21, 'FPpct': Decimal('0'), 'TN': 43, 'TNpct': Decimal('0'), 'FN': 19, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.3333333333333333'), 'evaluation_timeperiod': '2023-04-10_2023-04-14', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08268988}, {'price_25MA': 0.07319196}, {'range_vol5MA': 0.24769555}, {'close_diff_deviation3': 0.06558082}, {'range_vol25MA': 0.07756086}, {'adx': 0.07464047}, {'close_diff5': 0.07441227}, {'threeD_stddev50': 0.07927978}, {'oneD_returns_close': 0.08043545}, {'oneD_stddev50': 0.07944431}, {'range_vol_diff5': 0.0650686}]"}
# label
# 0    13877
# 1     9283
# Name: count, dtype: int64
# 6 22 50 12
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-04-17', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 6, 'TPpct': Decimal('0'), 'FP': 22, 'FPpct': Decimal('0'), 'TN': 50, 'TNpct': Decimal('0'), 'FN': 12, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.2727272727272727'), 'evaluation_timeperiod': '2023-04-17_2023-04-21', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.083916634}, {'price_25MA': 0.075393446}, {'range_vol5MA': 0.24355207}, {'close_diff_deviation3': 0.0675125}, {'range_vol25MA': 0.07567657}, {'adx': 0.07487593}, {'close_diff5': 0.075586334}, {'threeD_stddev50': 0.07738913}, {'oneD_returns_close': 0.08014023}, {'oneD_stddev50': 0.078199424}, {'range_vol_diff5': 0.067757726}]"}
# label
# 0    13927
# 1     9305
# Name: count, dtype: int64
# 7 3 51 29
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-04-24', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 7, 'TPpct': Decimal('0'), 'FP': 3, 'FPpct': Decimal('0'), 'TN': 51, 'TNpct': Decimal('0'), 'FN': 29, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.3333333333333335'), 'evaluation_timeperiod': '2023-04-24_2023-04-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.085235074}, {'price_25MA': 0.07614655}, {'range_vol5MA': 0.24485496}, {'close_diff_deviation3': 0.06816035}, {'range_vol25MA': 0.07672773}, {'adx': 0.074507244}, {'close_diff5': 0.073043585}, {'threeD_stddev50': 0.07565367}, {'oneD_returns_close': 0.08154293}, {'oneD_stddev50': 0.07917254}, {'range_vol_diff5': 0.064955406}]"}
# label
# 0    13996
# 1     9326
# Name: count, dtype: int64
# 2 8 37 43
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-05-01', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 2, 'TPpct': Decimal('0'), 'FP': 8, 'FPpct': Decimal('0'), 'TN': 37, 'TNpct': Decimal('0'), 'FN': 43, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.25'), 'evaluation_timeperiod': '2023-05-01_2023-05-05', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.083176374}, {'price_25MA': 0.07603195}, {'range_vol5MA': 0.23795196}, {'close_diff_deviation3': 0.0689046}, {'range_vol25MA': 0.07748899}, {'adx': 0.07440315}, {'close_diff5': 0.07492169}, {'threeD_stddev50': 0.07983254}, {'oneD_returns_close': 0.08177631}, {'oneD_stddev50': 0.07840938}, {'range_vol_diff5': 0.06710302}]"}
# label
# 0    14049
# 1     9363
# Name: count, dtype: int64
# 0 2 74 14
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-05-08', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 2, 'FPpct': Decimal('0'), 'TN': 74, 'TNpct': Decimal('0'), 'FN': 14, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.0'), 'evaluation_timeperiod': '2023-05-08_2023-05-12', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.0837551}, {'price_25MA': 0.07580937}, {'range_vol5MA': 0.24234796}, {'close_diff_deviation3': 0.065954015}, {'range_vol25MA': 0.07467138}, {'adx': 0.07551037}, {'close_diff5': 0.071393296}, {'threeD_stddev50': 0.077256195}, {'oneD_returns_close': 0.08551945}, {'oneD_stddev50': 0.08316994}, {'range_vol_diff5': 0.064612895}]"}
# label
# 0    14100
# 1     9402
# Name: count, dtype: int64
# 0 4 79 7
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-05-15', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 4, 'FPpct': Decimal('0'), 'TN': 79, 'TNpct': Decimal('0'), 'FN': 7, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.0'), 'evaluation_timeperiod': '2023-05-15_2023-05-19', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08621735}, {'price_25MA': 0.07870973}, {'range_vol5MA': 0.23548187}, {'close_diff_deviation3': 0.0677331}, {'range_vol25MA': 0.07644686}, {'adx': 0.07415017}, {'close_diff5': 0.074461885}, {'threeD_stddev50': 0.07787563}, {'oneD_returns_close': 0.08112145}, {'oneD_stddev50': 0.0830725}, {'range_vol_diff5': 0.06472951}]"}
# label
# 0    14172
# 1     9420
# Name: count, dtype: int64
# 0 6 47 37
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-05-22', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 47, 'TNpct': Decimal('0'), 'FN': 37, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.0'), 'evaluation_timeperiod': '2023-05-22_2023-05-26', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08492402}, {'price_25MA': 0.0747746}, {'range_vol5MA': 0.2352765}, {'close_diff_deviation3': 0.06729428}, {'range_vol25MA': 0.07969113}, {'adx': 0.07689907}, {'close_diff5': 0.075584024}, {'threeD_stddev50': 0.07819778}, {'oneD_returns_close': 0.08087204}, {'oneD_stddev50': 0.07913984}, {'range_vol_diff5': 0.0673467}]"}
# label
# 0    14255
# 1     9427
# Name: count, dtype: int64
# 0 10 42 20
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-05-29', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 10, 'FPpct': Decimal('0'), 'TN': 42, 'TNpct': Decimal('0'), 'FN': 20, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.0'), 'evaluation_timeperiod': '2023-05-29_2023-06-02', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08424464}, {'price_25MA': 0.07614583}, {'range_vol5MA': 0.22505534}, {'close_diff_deviation3': 0.06938839}, {'range_vol25MA': 0.077417195}, {'adx': 0.07529248}, {'close_diff5': 0.07554911}, {'threeD_stddev50': 0.08018582}, {'oneD_returns_close': 0.084518105}, {'oneD_stddev50': 0.08363307}, {'range_vol_diff5': 0.06857}]"}
# label
# 0    14306
# 1     9466
# Name: count, dtype: int64
# 14 13 57 6
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-06-05', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 14, 'TPpct': Decimal('0'), 'FP': 13, 'FPpct': Decimal('0'), 'TN': 57, 'TNpct': Decimal('0'), 'FN': 6, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0769230769230769'), 'evaluation_timeperiod': '2023-06-05_2023-06-09', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08176962}, {'price_25MA': 0.07525377}, {'range_vol5MA': 0.25182226}, {'close_diff_deviation3': 0.065118015}, {'range_vol25MA': 0.07710613}, {'adx': 0.07301173}, {'close_diff5': 0.073288776}, {'threeD_stddev50': 0.07960729}, {'oneD_returns_close': 0.07946364}, {'oneD_stddev50': 0.07723899}, {'range_vol_diff5': 0.06631982}]"}
# label
# 0    14361
# 1     9483
# Name: count, dtype: int64
# 1 11 56 22
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-06-12', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 1, 'TPpct': Decimal('0'), 'FP': 11, 'FPpct': Decimal('0'), 'TN': 56, 'TNpct': Decimal('0'), 'FN': 22, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.09090909090909091'), 'evaluation_timeperiod': '2023-06-12_2023-06-16', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08359029}, {'price_25MA': 0.07496272}, {'range_vol5MA': 0.2422002}, {'close_diff_deviation3': 0.06653517}, {'range_vol25MA': 0.07907773}, {'adx': 0.0733426}, {'close_diff5': 0.07509027}, {'threeD_stddev50': 0.07663476}, {'oneD_returns_close': 0.08287598}, {'oneD_stddev50': 0.08169663}, {'range_vol_diff5': 0.063993745}]"}
# label
# 0    14429
# 1     9505
# Name: count, dtype: int64
# 2 6 35 29
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-06-19', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 2, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 35, 'TNpct': Decimal('0'), 'FN': 29, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.3333333333333333'), 'evaluation_timeperiod': '2023-06-19_2023-06-23', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08551182}, {'price_25MA': 0.07568875}, {'range_vol5MA': 0.23132317}, {'close_diff_deviation3': 0.067294866}, {'range_vol25MA': 0.07822123}, {'adx': 0.07509132}, {'close_diff5': 0.07418857}, {'threeD_stddev50': 0.0796938}, {'oneD_returns_close': 0.07941253}, {'oneD_stddev50': 0.088284925}, {'range_vol_diff5': 0.065289}]"}
# label
# 0    14496
# 1     9528
# Name: count, dtype: int64
# 1 2 83 4
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-06-26', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 1, 'TPpct': Decimal('0'), 'FP': 2, 'FPpct': Decimal('0'), 'TN': 83, 'TNpct': Decimal('0'), 'FN': 4, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5'), 'evaluation_timeperiod': '2023-06-26_2023-06-30', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.0867924}, {'price_25MA': 0.07603836}, {'range_vol5MA': 0.22182389}, {'close_diff_deviation3': 0.06815359}, {'range_vol25MA': 0.079145305}, {'adx': 0.07646896}, {'close_diff5': 0.07312145}, {'threeD_stddev50': 0.080195144}, {'oneD_returns_close': 0.081706814}, {'oneD_stddev50': 0.08807891}, {'range_vol_diff5': 0.06847526}]"}
# label
# 0    14544
# 1     9552
# Name: count, dtype: int64
# 6 7 30 23
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-07-03', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 6, 'TPpct': Decimal('0'), 'FP': 7, 'FPpct': Decimal('0'), 'TN': 30, 'TNpct': Decimal('0'), 'FN': 23, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8571428571428571'), 'evaluation_timeperiod': '2023-07-03_2023-07-07', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08475672}, {'price_25MA': 0.0775682}, {'range_vol5MA': 0.22189365}, {'close_diff_deviation3': 0.0692337}, {'range_vol25MA': 0.083931014}, {'adx': 0.07762402}, {'close_diff5': 0.074741684}, {'threeD_stddev50': 0.079789504}, {'oneD_returns_close': 0.08207937}, {'oneD_stddev50': 0.08016777}, {'range_vol_diff5': 0.068214394}]"}
# label
# 0    14621
# 1     9565
# Name: count, dtype: int64
# 0 0 83 7
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-07-10', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 0, 'FPpct': Decimal('0'), 'TN': 83, 'TNpct': Decimal('0'), 'FN': 7, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0'), 'evaluation_timeperiod': '2023-07-10_2023-07-14', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08245805}, {'price_25MA': 0.07568646}, {'range_vol5MA': 0.2394006}, {'close_diff_deviation3': 0.06606182}, {'range_vol25MA': 0.0798927}, {'adx': 0.073837206}, {'close_diff5': 0.07346115}, {'threeD_stddev50': 0.07813621}, {'oneD_returns_close': 0.08417999}, {'oneD_stddev50': 0.079920314}, {'range_vol_diff5': 0.06696542}]"}
# label
# 0    14668
# 1     9584
# Name: count, dtype: int64
# 5 4 65 16
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-07-17', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 5, 'TPpct': Decimal('0'), 'FP': 4, 'FPpct': Decimal('0'), 'TN': 65, 'TNpct': Decimal('0'), 'FN': 16, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.25'), 'evaluation_timeperiod': '2023-07-17_2023-07-21', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.085629426}, {'price_25MA': 0.07700685}, {'range_vol5MA': 0.23985456}, {'close_diff_deviation3': 0.06609854}, {'range_vol25MA': 0.07325776}, {'adx': 0.07498827}, {'close_diff5': 0.07126301}, {'threeD_stddev50': 0.0779759}, {'oneD_returns_close': 0.079516076}, {'oneD_stddev50': 0.08715958}, {'range_vol_diff5': 0.06725008}]"}
# label
# 0    14742
# 1     9600
# Name: count, dtype: int64
# 0 3 58 29
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-07-24', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 3, 'FPpct': Decimal('0'), 'TN': 58, 'TNpct': Decimal('0'), 'FN': 29, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.0'), 'evaluation_timeperiod': '2023-07-24_2023-07-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.084862635}, {'price_25MA': 0.07572063}, {'range_vol5MA': 0.23197687}, {'close_diff_deviation3': 0.06763924}, {'range_vol25MA': 0.081766166}, {'adx': 0.0751749}, {'close_diff5': 0.07366203}, {'threeD_stddev50': 0.081354275}, {'oneD_returns_close': 0.078583494}, {'oneD_stddev50': 0.083877705}, {'range_vol_diff5': 0.0653821}]"}
# label
# 0    14811
# 1     9621
# Name: count, dtype: int64
# 3 7 39 41
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-07-31', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 3, 'TPpct': Decimal('0'), 'FP': 7, 'FPpct': Decimal('0'), 'TN': 39, 'TNpct': Decimal('0'), 'FN': 41, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.42857142857142855'), 'evaluation_timeperiod': '2023-07-31_2023-08-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08672707}, {'price_25MA': 0.075137936}, {'range_vol5MA': 0.22848536}, {'close_diff_deviation3': 0.06790479}, {'range_vol25MA': 0.07939763}, {'adx': 0.0736328}, {'close_diff5': 0.07459868}, {'threeD_stddev50': 0.07828642}, {'oneD_returns_close': 0.07983874}, {'oneD_stddev50': 0.09094345}, {'range_vol_diff5': 0.065047175}]"}
# label
# 0    14874
# 1     9648
# Name: count, dtype: int64
# 17 34 18 21
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-08-07', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 17, 'TPpct': Decimal('0'), 'FP': 34, 'FPpct': Decimal('0'), 'TN': 18, 'TNpct': Decimal('0'), 'FN': 21, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5'), 'evaluation_timeperiod': '2023-08-07_2023-08-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08665119}, {'price_25MA': 0.074672535}, {'range_vol5MA': 0.2374395}, {'close_diff_deviation3': 0.06749168}, {'range_vol25MA': 0.07639648}, {'adx': 0.074086}, {'close_diff5': 0.070390955}, {'threeD_stddev50': 0.08091043}, {'oneD_returns_close': 0.0828634}, {'oneD_stddev50': 0.081897505}, {'range_vol_diff5': 0.06720023}]"}
# label
# 0    14929
# 1     9683
# Name: count, dtype: int64
# 27 8 16 39
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-08-14', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 27, 'TPpct': Decimal('0'), 'FP': 8, 'FPpct': Decimal('0'), 'TN': 16, 'TNpct': Decimal('0'), 'FN': 39, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.375'), 'evaluation_timeperiod': '2023-08-14_2023-08-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.084292844}, {'price_25MA': 0.07449713}, {'range_vol5MA': 0.23514648}, {'close_diff_deviation3': 0.06569548}, {'range_vol25MA': 0.07589786}, {'adx': 0.07402736}, {'close_diff5': 0.07239124}, {'threeD_stddev50': 0.08614752}, {'oneD_returns_close': 0.07946123}, {'oneD_stddev50': 0.08548612}, {'range_vol_diff5': 0.06695673}]"}
# label
# 0    14974
# 1     9728
# Name: count, dtype: int64
# 10 8 47 25
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-08-21', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 10, 'TPpct': Decimal('0'), 'FP': 8, 'FPpct': Decimal('0'), 'TN': 47, 'TNpct': Decimal('0'), 'FN': 25, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.25'), 'evaluation_timeperiod': '2023-08-21_2023-08-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.086733095}, {'price_25MA': 0.07688337}, {'range_vol5MA': 0.22055453}, {'close_diff_deviation3': 0.070233196}, {'range_vol25MA': 0.07937692}, {'adx': 0.07634072}, {'close_diff5': 0.074345715}, {'threeD_stddev50': 0.081666104}, {'oneD_returns_close': 0.08048273}, {'oneD_stddev50': 0.08661829}, {'range_vol_diff5': 0.06676537}]"}
# label
# 0    14995
# 1     9797
# Name: count, dtype: int64
# 0 7 82 1
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-08-28', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 7, 'FPpct': Decimal('0'), 'TN': 82, 'TNpct': Decimal('0'), 'FN': 1, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.0'), 'evaluation_timeperiod': '2023-08-28_2023-09-01', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08572585}, {'price_25MA': 0.07566618}, {'range_vol5MA': 0.23806858}, {'close_diff_deviation3': 0.0676251}, {'range_vol25MA': 0.07857234}, {'adx': 0.07332053}, {'close_diff5': 0.07421802}, {'threeD_stddev50': 0.077887714}, {'oneD_returns_close': 0.08209855}, {'oneD_stddev50': 0.08154675}, {'range_vol_diff5': 0.06527031}]"}
# label
# 0    15050
# 1     9832
# Name: count, dtype: int64
# 8 1 41 22
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-09-04', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 8, 'TPpct': Decimal('0'), 'FP': 1, 'FPpct': Decimal('0'), 'TN': 41, 'TNpct': Decimal('0'), 'FN': 22, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('8.0'), 'evaluation_timeperiod': '2023-09-04_2023-09-08', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08849513}, {'price_25MA': 0.0757299}, {'range_vol5MA': 0.22853504}, {'close_diff_deviation3': 0.06690536}, {'range_vol25MA': 0.080228716}, {'adx': 0.07622925}, {'close_diff5': 0.070639305}, {'threeD_stddev50': 0.08483043}, {'oneD_returns_close': 0.07694534}, {'oneD_stddev50': 0.08340566}, {'range_vol_diff5': 0.06805587}]"}
# label
# 0    15137
# 1     9835
# Name: count, dtype: int64
# 0 2 44 26
# {'model_name': 'IndexP:1D_TSSIM1_custHypP15_2018', 'deployment_date': '2023-09-11', 'algorithm_type': 'xgboost', 'dataset': '1D_TSSIM1_custHypP15_2018', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 2, 'FPpct': Decimal('0'), 'TN': 44, 'TNpct': Decimal('0'), 'FN': 26, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.0'), 'evaluation_timeperiod': '2023-09-11_2023-09-15', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['price7', 'price_25MA', 'range_vol5MA', 'close_diff_deviation3', 'range_vol25MA', 'adx', 'close_diff5', 'threeD_stddev50', 'oneD_returns_close', 'oneD_stddev50', 'range_vol_diff5']"}, 'target': '-0.009+one_min', 'feature_importances': "[{'price7': 0.08549604}, {'price_25MA': 0.07525711}, {'range_vol5MA': 0.24099039}, {'close_diff_deviation3': 0.06577133}, {'range_vol25MA': 0.07678729}, {'adx': 0.075197995}, {'close_diff5': 0.072452694}, {'threeD_stddev50': 0.083113596}, {'oneD_returns_close': 0.079137675}, {'oneD_stddev50': 0.081109874}, {'range_vol_diff5': 0.064685926}]"}
# label
# 0    15179
# 1     9865
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 19
#      16 # date = dates_list[-1]
#      17 # response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
#      18 for date in dates_list:
# ---> 19     response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])
#
# Cell In[9], line 13, in model_runner_v2(model_name, dataset_name, title, features, target_label, target_value, start_date, end_date, deployment_date, feature_str, hyperparams_str, hyperparams, local_data, dataset_start_date)
#      11 dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
#      12 validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
# ---> 13 tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
#      14 response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
#      15 validation_dataset['probabilities'] = probabilities[:,1]
#
# Cell In[8], line 19, in train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
#      17 predictions = xgb_model.predict(X_validate)
#      18 probabilities = xgb_model.predict_proba(X_validate)
# ---> 19 tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)
#      21 fi = xgb_model.feature_importances_
#      22 fi_list = []
#
# Cell In[6], line 4, in model_results_analyzer(predictions, y_validate, target_value)
#       2 result_list = []
#       3 counter = 0
# ----> 4 predictions_series = pd.Series(predictions,name='prediction_values')
#       5 for x in predictions:
#       6     if x == 1:
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/pandas/core/series.py:509, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     507         data = data.copy()
#     508 else:
# --> 509     data = sanitize_array(data, index, dtype, copy)
#     511     manager = get_option("mode.data_manager")
#     512     if manager == "block":
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/pandas/core/construction.py:607, in sanitize_array(data, index, dtype, copy, allow_2d)
#     604             subarr = cast(np.ndarray, subarr)
#     605             subarr = maybe_infer_to_datetimelike(subarr)
# --> 607 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     609 if isinstance(subarr, np.ndarray):
#     610     # at this point we should have dtype be None or subarr.dtype == dtype
#     611     dtype = cast(np.dtype, dtype)
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/pandas/core/construction.py:666, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     664     if allow_2d:
#     665         return result
# --> 666     raise ValueError(
#     667         f"Data must be 1-dimensional, got ndarray of shape {data.shape} instead"
#     668     )
#     669 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     670     # i.e. PandasDtype("O")
#     672     result = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#
# ValueError: Data must be 1-dimensional, got ndarray of shape (0, 0) instead

# %%
# def run_temporal_simulation(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date):
#     tp_avg_list = []
#     gross_accuracy_list = []
#     # fn_list = []
#     # tn_list = []
    
#     hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
#     dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
#     # date = dates_list[-1]
#     # response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
#     for date in dates_list:
#         tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams)
#         tp_avg_list.append(tp)
#         gross_accuracy_list.append((tp-fp))

#     return tp_avg_list, gross_accuracy_list

# %%
# number_of_simulations = 125
# now = datetime.now()
# title = 'INDEXP_1d'
# total_feature_list = ['hour','year','month','day_of_month',
#        'price7', 'price14', 'adjusted_volume', 'vol7', 'vol14',
#        'rsi', 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close',
#        'oneD_returns_close', 'range_vol', 'range_vol5MA', 'range_vol10MA',
#        'range_vol25MA', 'oneD_stddev50', 'threeD_stddev50', 'cmf',
#        'close_diff', 'close_diff3', 'close_diff5', 'v_diff_pct', 'adx',
#        'volume_10MA', 'volume_25MA', 'price_10MA', 'price_25MA',
#        'volume_10DDiff', 'volume_25DDiff', 'price_10DDiff', 'price_25DDiff',
#        'day_of_week','close_diff_deviation3','close_diff_deviation','roc_diff','range_vol_diff5']

# target_label = 'one_min'
# target_value = -.009
# results_array = []

# i = 0
# while i < number_of_simulations:
#        model_name = f"{title}_temporal_simulation_{i}"
#        print(model_name)
#        random_int = random.randint(8, 24)
#        features = random.sample(total_feature_list, random_int)
#        tp_avg_list, gross_accuracy_list = run_temporal_simulation(features, target_label, target_value, dataset_start_date=datetime(2018,10,1), evaluation_start_date=datetime(2022,10,24), evaluation_end_date=datetime(2023,8,11)) 
#        tp_avg = sum(tp_avg_list)/len(tp_avg_list)
#        gross_accuracy = sum(gross_accuracy_list)/len(gross_accuracy_list)
#        print(tp_avg, gross_accuracy)
#        print()
#        results_array.append({"model_name": model_name, "features": features, "tp_avg": tp_avg, "gross_accuracy": gross_accuracy,"num_features": random_int})
#        i += 1

# results_df = pd.DataFrame(results_array)
# results_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
# Out:
# INDEXP_1d_temporal_simulation_0
# 14.452380952380953 -2.0238095238095237
#
# INDEXP_1d_temporal_simulation_1
# 14.666666666666666 -1.0714285714285714
#
# INDEXP_1d_temporal_simulation_2
# 16.80952380952381 -1.619047619047619
#
# INDEXP_1d_temporal_simulation_3
# 15.023809523809524 -1.380952380952381
#
# INDEXP_1d_temporal_simulation_4
# 15.714285714285714 -1.3571428571428572
#
# INDEXP_1d_temporal_simulation_5
# 18.333333333333332 -2.5952380952380953
#
# INDEXP_1d_temporal_simulation_6
# 16.071428571428573 -3.6904761904761907
#
# INDEXP_1d_temporal_simulation_7
# 15.404761904761905 -3.142857142857143
#
# INDEXP_1d_temporal_simulation_8
# 15.261904761904763 -1.880952380952381
#
# INDEXP_1d_temporal_simulation_9
# 14.595238095238095 -4.023809523809524
#
# INDEXP_1d_temporal_simulation_10
# 16.11904761904762 -1.6904761904761905
#
# INDEXP_1d_temporal_simulation_11
# 13.642857142857142 -2.0714285714285716
#
# INDEXP_1d_temporal_simulation_12
# 16.19047619047619 -0.6190476190476191
#
# INDEXP_1d_temporal_simulation_13
# 14.238095238095237 0.35714285714285715
#
# INDEXP_1d_temporal_simulation_14
# 15.476190476190476 0.38095238095238093
#
# INDEXP_1d_temporal_simulation_15
# 15.380952380952381 -2.4761904761904763
#
# INDEXP_1d_temporal_simulation_16
# 15.904761904761905 -0.5714285714285714
#
# INDEXP_1d_temporal_simulation_17
# 14.142857142857142 -2.9285714285714284
#
# INDEXP_1d_temporal_simulation_18
# 15.642857142857142 -0.5238095238095238
#
# INDEXP_1d_temporal_simulation_19
# 14.666666666666666 1.1666666666666667
#
# INDEXP_1d_temporal_simulation_20
# 11.785714285714286 -5.023809523809524
#
# INDEXP_1d_temporal_simulation_21
# 15.642857142857142 -2.4761904761904763
#
# INDEXP_1d_temporal_simulation_22
# 15.119047619047619 -1.380952380952381
#
# INDEXP_1d_temporal_simulation_23
# 16.214285714285715 -0.5
#
# INDEXP_1d_temporal_simulation_24
# 18.0 -3.3095238095238093
#
# INDEXP_1d_temporal_simulation_25
# 15.30952380952381 -4.4523809523809526
#
# INDEXP_1d_temporal_simulation_26
# 14.952380952380953 -1.3333333333333333
#
# INDEXP_1d_temporal_simulation_27
# 16.904761904761905 -0.9523809523809523
#
# INDEXP_1d_temporal_simulation_28
# 14.619047619047619 -1.4523809523809523
#
# INDEXP_1d_temporal_simulation_29
# 16.666666666666668 -0.19047619047619047
#
# INDEXP_1d_temporal_simulation_30
# 16.11904761904762 0.4523809523809524
#
# INDEXP_1d_temporal_simulation_31
# 14.357142857142858 -1.3095238095238095
#
# INDEXP_1d_temporal_simulation_32
# 12.857142857142858 -3.4523809523809526
#
# INDEXP_1d_temporal_simulation_33
# 16.61904761904762 -0.8333333333333334
#
# INDEXP_1d_temporal_simulation_34
# 14.619047619047619 -0.47619047619047616
#
# INDEXP_1d_temporal_simulation_35
# 16.071428571428573 -0.35714285714285715
#
# INDEXP_1d_temporal_simulation_36
# 14.857142857142858 -1.5
#
# INDEXP_1d_temporal_simulation_37
# 16.5 -0.8095238095238095
#
# INDEXP_1d_temporal_simulation_38
# 14.714285714285714 -3.0
#
# INDEXP_1d_temporal_simulation_39
# 16.214285714285715 -3.0714285714285716
#
# INDEXP_1d_temporal_simulation_40
# 14.595238095238095 -1.3571428571428572
#
# INDEXP_1d_temporal_simulation_41
# 14.404761904761905 -1.6428571428571428
#
# INDEXP_1d_temporal_simulation_42
# 15.142857142857142 -1.3095238095238095
#
# INDEXP_1d_temporal_simulation_43
# 16.428571428571427 -2.142857142857143
#
# INDEXP_1d_temporal_simulation_44
# 15.428571428571429 -1.0476190476190477
#
# INDEXP_1d_temporal_simulation_45
# 14.214285714285714 -3.119047619047619
#
# INDEXP_1d_temporal_simulation_46
# 14.547619047619047 -1.1428571428571428
#
# INDEXP_1d_temporal_simulation_47
# 15.880952380952381 0.047619047619047616
#
# INDEXP_1d_temporal_simulation_48
# 16.547619047619047 -2.0952380952380953
#
# INDEXP_1d_temporal_simulation_49
# 14.428571428571429 -2.261904761904762
#
# INDEXP_1d_temporal_simulation_50
# 14.976190476190476 0.047619047619047616
#
# INDEXP_1d_temporal_simulation_51
# 14.928571428571429 -2.619047619047619
#
# INDEXP_1d_temporal_simulation_52
# 14.19047619047619 -2.8095238095238093
#
# INDEXP_1d_temporal_simulation_53
# 13.714285714285714 -2.142857142857143
#
# INDEXP_1d_temporal_simulation_54
# 14.833333333333334 -2.5238095238095237
#
# INDEXP_1d_temporal_simulation_55
# 15.80952380952381 -2.9285714285714284
#
# INDEXP_1d_temporal_simulation_56
# 15.285714285714286 0.38095238095238093
#
# INDEXP_1d_temporal_simulation_57
# 16.261904761904763 -1.5238095238095237
#
# INDEXP_1d_temporal_simulation_58
# 14.547619047619047 -0.42857142857142855
#
# INDEXP_1d_temporal_simulation_59
# 14.452380952380953 -2.5714285714285716
#
# INDEXP_1d_temporal_simulation_60
# 13.380952380952381 -3.2142857142857144
#
# INDEXP_1d_temporal_simulation_61
# 13.595238095238095 -0.4523809523809524
#
# INDEXP_1d_temporal_simulation_62
# 14.285714285714286 -2.142857142857143
#
# INDEXP_1d_temporal_simulation_63
# 14.119047619047619 -3.738095238095238
#
# INDEXP_1d_temporal_simulation_64
# 15.119047619047619 -0.2857142857142857
#
# INDEXP_1d_temporal_simulation_65
# 15.785714285714286 -1.9285714285714286
#
# INDEXP_1d_temporal_simulation_66
# 13.880952380952381 -2.0
#
# INDEXP_1d_temporal_simulation_67
# 15.80952380952381 -1.8095238095238095
#
# INDEXP_1d_temporal_simulation_68
# 15.357142857142858 -2.1904761904761907
#
# INDEXP_1d_temporal_simulation_69
# 14.714285714285714 -1.0476190476190477
#
# INDEXP_1d_temporal_simulation_70
# 16.666666666666668 0.3333333333333333
#
# INDEXP_1d_temporal_simulation_71
# 15.380952380952381 -1.9285714285714286
#
# INDEXP_1d_temporal_simulation_72
# 12.785714285714286 -2.0952380952380953
#
# INDEXP_1d_temporal_simulation_73
# 14.476190476190476 -2.1904761904761907
#
# INDEXP_1d_temporal_simulation_74
# 15.785714285714286 -1.0714285714285714
#
# INDEXP_1d_temporal_simulation_75
# 15.357142857142858 -1.6666666666666667
#
# INDEXP_1d_temporal_simulation_76
# 17.214285714285715 0.5
#
# INDEXP_1d_temporal_simulation_77
# 16.071428571428573 -1.7619047619047619
#
# INDEXP_1d_temporal_simulation_78
# 14.261904761904763 -3.0714285714285716
#
# INDEXP_1d_temporal_simulation_79
# 13.833333333333334 -3.1666666666666665
#
# INDEXP_1d_temporal_simulation_80
# 14.642857142857142 -1.8095238095238095
#
# INDEXP_1d_temporal_simulation_81
# 16.214285714285715 -2.4285714285714284
#
# INDEXP_1d_temporal_simulation_82
# 16.095238095238095 0.6190476190476191
#
# INDEXP_1d_temporal_simulation_83
# 16.404761904761905 -2.1666666666666665
#
# INDEXP_1d_temporal_simulation_84
# 14.952380952380953 -1.0476190476190477
#
# INDEXP_1d_temporal_simulation_85
# 16.404761904761905 -1.5952380952380953
#
# INDEXP_1d_temporal_simulation_86
# 14.833333333333334 -0.07142857142857142
#
# INDEXP_1d_temporal_simulation_87
# 14.428571428571429 -1.4285714285714286
#
# INDEXP_1d_temporal_simulation_88
# 15.0 -0.8333333333333334
#
# INDEXP_1d_temporal_simulation_89
# 13.80952380952381 -2.642857142857143
#
# INDEXP_1d_temporal_simulation_90
# 15.166666666666666 -3.357142857142857
#
# INDEXP_1d_temporal_simulation_91
# 14.880952380952381 1.119047619047619
#
# INDEXP_1d_temporal_simulation_92
# 16.952380952380953 -0.8333333333333334
#
# INDEXP_1d_temporal_simulation_93
# 13.238095238095237 -2.380952380952381
#
# INDEXP_1d_temporal_simulation_94
# 15.738095238095237 -2.0714285714285716
#
# INDEXP_1d_temporal_simulation_95
# 16.404761904761905 -3.357142857142857
#
# INDEXP_1d_temporal_simulation_96
# 14.333333333333334 -1.7857142857142858
#
# INDEXP_1d_temporal_simulation_97
# 14.547619047619047 -2.8333333333333335
#
# INDEXP_1d_temporal_simulation_98
# 15.80952380952381 -1.5238095238095237
#
# INDEXP_1d_temporal_simulation_99
# 15.666666666666666 -0.4523809523809524
#
# INDEXP_1d_temporal_simulation_100
# 14.404761904761905 -2.5476190476190474
#
# INDEXP_1d_temporal_simulation_101
# 14.761904761904763 -1.2857142857142858
#
# INDEXP_1d_temporal_simulation_102
# 14.404761904761905 -3.7142857142857144
#
# INDEXP_1d_temporal_simulation_103
# 14.595238095238095 -1.119047619047619
#
# INDEXP_1d_temporal_simulation_104
# 16.642857142857142 -0.42857142857142855
#
# INDEXP_1d_temporal_simulation_105
# 13.952380952380953 -3.357142857142857
#
# INDEXP_1d_temporal_simulation_106
# 15.523809523809524 -1.5952380952380953
#
# INDEXP_1d_temporal_simulation_107
# 13.30952380952381 -1.2619047619047619
#
# INDEXP_1d_temporal_simulation_108
# 14.357142857142858 -3.1904761904761907
#
# INDEXP_1d_temporal_simulation_109
# 17.357142857142858 -0.23809523809523808
#
# INDEXP_1d_temporal_simulation_110
# 16.642857142857142 -0.5952380952380952
#
# INDEXP_1d_temporal_simulation_111
# 16.023809523809526 -2.357142857142857
#
# INDEXP_1d_temporal_simulation_112
# 16.476190476190474 -1.3571428571428572
#
# INDEXP_1d_temporal_simulation_113
# 14.952380952380953 -1.0
#
# INDEXP_1d_temporal_simulation_114
# 13.761904761904763 -3.357142857142857
#
# INDEXP_1d_temporal_simulation_115
# 15.285714285714286 -2.738095238095238
#
# INDEXP_1d_temporal_simulation_116
# 16.80952380952381 -0.8571428571428571
#
# INDEXP_1d_temporal_simulation_117
# 13.928571428571429 -3.2857142857142856
#
# INDEXP_1d_temporal_simulation_118
# 15.357142857142858 0.5476190476190477
#
# INDEXP_1d_temporal_simulation_119
# 13.666666666666666 -2.119047619047619
#
# INDEXP_1d_temporal_simulation_120
# 16.523809523809526 -0.5476190476190477
#
# INDEXP_1d_temporal_simulation_121
# 15.595238095238095 -2.6904761904761907
#
# INDEXP_1d_temporal_simulation_122
# 15.380952380952381 -0.6190476190476191
#
# INDEXP_1d_temporal_simulation_123
# 14.095238095238095 -0.9523809523809523
#
# INDEXP_1d_temporal_simulation_124
# 13.285714285714286 -2.6666666666666665
