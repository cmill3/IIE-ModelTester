# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler
import pytz

# %%
s3 = boto3.client('s3')

training_bucket = "icarus-research-data"
training_prefix = 'training_datasets/expanded_1d_datasets/'

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

index = ["QQQ","SPY","IWM","TLT"]
test_lag = ["DAL","UAL","VZ","T","AAL","AMC"]
train_lag = ["AMC"]

# %%
def create_training_data_local(key_list, prefix, bucket_name, start_date, end_date):
    df_list = []
    hours = [10,11,12,13,14,15]
    start = start_date.split(' ')[0]
    end = end_date.split(' ')[0]
    # print(file_key)
    for key in key_list:
        print(key)
        for hour in hours:
            try:
                data = s3.get_object(Bucket=bucket_name, Key=f'{prefix}{key}/{hour}.csv')
                df = pd.read_csv(data.get("Body")) 
                df_list.append(df)
                df['hour'] = hour
            except:
                continue

    data = pd.concat(df_list)
    data.reset_index(drop=True, inplace=True)
    data['dt'] = pd.to_datetime(data['date'])
    data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek)
    data = data.round(3)
    data.replace([np.inf, -np.inf], 0, inplace=True)

    data.to_csv(f'/Users/charlesmiller/Documents/BF/{start}_{end}.csv', index=False)

    return data

def pull_training_data_local(end_date,start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/SF/2018-01-01_2023-10-12.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    # data = data.loc[data['dt'] >= start_date]
    data = data.loc[~data['symbol'].isin(index)]
    data = data.loc[~data['symbol'].isin(train_lag)]
    data['roc_diff'] = data['roc'] - data['roc5']
    data['range_vol_diff5'] = (data['range_vol'] - data['range_vol5MA'])
    data['close_diff_deviation3'] = abs(data['close_diff3'])/(data['threeD_stddev50']*100)
    data['close_diff_deviation'] = abs(data['close_diff'])/(data['oneD_stddev50']*100)
    data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek).astype(int)
    data['day_of_month'] = data['dt'].apply(lambda x: x.day).astype(int)
    data['month'] = data['dt'].apply(lambda x: x.month).astype(int)
    data['year'] = data['dt'].apply(lambda x: x.year).astype(int)
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data


def pull_validation_data_local(end_date,start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/SF/2018-01-01_2023-10-12.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data = data.loc[data['dt'] >= start_date]
    data = data.loc[~data['symbol'].isin(index)]
    data = data.loc[~data['symbol'].isin(test_lag)]
    data['roc_diff'] = data['roc'] - data['roc5']
    data['range_vol_diff5'] = (data['range_vol'] - data['range_vol5MA'])
    data['close_diff_deviation3'] = abs(data['close_diff3'])/(data['threeD_stddev50']*100)
    data['close_diff_deviation'] = abs(data['close_diff'])/(data['oneD_stddev50']*100)
    data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek).astype(int)
    data['day_of_month'] = data['dt'].apply(lambda x: x.day).astype(int)
    data['month'] = data['dt'].apply(lambda x: x.month).astype(int)
    data['year'] = data['dt'].apply(lambda x: x.year).astype(int)
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data

# %%
def build_date_list(start_date, end_date):
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_validation_dates_local(deployment_date):
    end_date = deployment_date + timedelta(days=5)
    return end_date

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] < target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] < target_value).astype(int)

    dataset = dataset.round(3)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features]
    y = dataset['label']

    X_validate = validation_dataset[features]
    y_validate = validation_dataset['label']

    print(y.value_counts())
    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    probabilities = xgb_model.predict_proba(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,str(fi_list), predictions, probabilities


def train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] > target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] > target_value).astype(int)

    dataset = dataset.round(3)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features]
    y = dataset['label']

    X_validate = validation_dataset[features]
    y_validate = validation_dataset['label']

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,"str(fi_list)", predictions, "probabilities"

# %%
def model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
    # dates = build_date_list(start_date, end_date)
    # key_list = build_query_keys(dates)
    validation_end_date = build_validation_dates_local(deployment_date)
    # validation_keys = build_query_keys_validation(deployment_date)
    # validation_dataset = create_validation_data(validation_keys, 'fixed_alerts_full/new_features/big_fish_stable/', 'inv-alerts')
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    # else:
    #     dataset = create_training_data_v2(key_list, 'fixed_alerts_full/new_features/big_fish/', 'inv-alerts')
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
    validation_dataset['probabilities'] = probabilities[:,1]
    validation_dataset['predictions'] = predictions
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    return response

def model_runner_data(start_date,end_date,):
    dates = build_date_list(start_date, end_date)
    key_list = build_query_keys(dates)
    print(key_list[-1])
    dataset = create_training_data_local(key_list, 'sf/vol/', 'inv-alerts', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
    return dataset


def model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,end_date,deployment_date,hyperparams):
    validation_end_date = build_validation_dates_local(deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    return tp, fp, fn, tn

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=10),
            "dataset_start": datetime(2020,1,1)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

# %%
#ma_cont_classifier_EXPvDiff_HistData
#ma_cont_classifier_EXPvDiff_HistData_NOVAL
#ma_cont_classifier_EXPvDiffDYNTUN_HistData_NOVAL
#ma_cont_classifier_EXPvDiffDYNTUN_HistData_NOVAL
model_name = 'SFP:3D_TSSIM1_expVol_custHyP15_2018'
dataset_name = '3D_TSSIM1_expVol_custHypP15_2018'
title = 'SFC_3D'
hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
features = ['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 
            'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 
            'volume_10MA',"SPY_diff","SPY_1D"]
target_label = 'three_min'
target_value = -.045
dataset_start_date = datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')) 

dates_list = build_evaluation_period(datetime(2022,10,24,tzinfo=pytz.timezone('US/Eastern')), datetime(2023,10,20,tzinfo=pytz.timezone('US/Eastern')))
# date = dates_list[-1]
# response = model_runner_data(start_date=dataset_start_date,end_date=datetime(2023,10,12,tzinfo=pytz.timezone('US/Eastern')))
for date in dates_list:
    print(date)
    response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,"dataset_start_date",date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])
# Out:
# {'deployment_date': datetime.datetime(2022, 10, 24, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 10, 14, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    218510
# 1    115349
# Name: count, dtype: int64
# 622 712 694 162
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-10-24', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 622, 'TPpct': Decimal('0'), 'FP': 712, 'FPpct': Decimal('0'), 'TN': 694, 'TNpct': Decimal('0'), 'FN': 162, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8735955056179775'), 'evaluation_timeperiod': '2022-10-24_2022-10-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.01658109}, {'vol7': 0.01604195}, {'daily_volume_vol_diff30': 0.022779739}, {'price_10DDiff': 0.02844345}, {'close_diff3': 0.024796259}, {'return_vol_30D': 0.036120586}, {'hour_vol_diff_pct': 0.017956393}, {'v_diff_pct': 0.019258972}, {'month': 0.039024487}, {'hour_volume_vol_diff': 0.01970921}, {'rsi5': 0.026289089}, {'range_vol_diff5': 0.022080166}, {'daily_vol_diff30': 0.026536297}, {'rsi': 0.027069928}, {'roc_diff': 0.026571995}, {'range_vol5MA': 0.31122744}, {'price_25MA': 0.028916799}, {'year': 0.055675652}, {'min_vol_diff': 0.059085988}, {'return_vol_5D': 0.024645818}, {'daily_vol_diff': 0.02495962}, {'price14': 0.026333153}, {'adx': 0.026319873}, {'volume_10MA': 0.020646645}, {'SPY_diff': 0.019176163}, {'SPY_1D': 0.033753216}]"}
# {'deployment_date': datetime.datetime(2022, 10, 31, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 10, 21, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    220004
# 1    116375
# Name: count, dtype: int64
# 1053 259 578 300
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-10-31', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 1053, 'TPpct': Decimal('0'), 'FP': 259, 'FPpct': Decimal('0'), 'TN': 578, 'TNpct': Decimal('0'), 'FN': 300, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('4.065637065637065'), 'evaluation_timeperiod': '2022-10-31_2022-11-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.017514782}, {'vol7': 0.017632024}, {'daily_volume_vol_diff30': 0.023337165}, {'price_10DDiff': 0.029920254}, {'close_diff3': 0.025662918}, {'return_vol_30D': 0.03835327}, {'hour_vol_diff_pct': 0.018050836}, {'v_diff_pct': 0.018470682}, {'month': 0.042128652}, {'hour_volume_vol_diff': 0.019069135}, {'rsi5': 0.026669947}, {'range_vol_diff5': 0.022477495}, {'daily_vol_diff30': 0.025823114}, {'rsi': 0.02735015}, {'roc_diff': 0.027148617}, {'range_vol5MA': 0.3263286}, {'price_25MA': 0.03040978}, {'year': 0.058260504}, {'min_vol_diff': 0.025329245}, {'return_vol_5D': 0.0254742}, {'daily_vol_diff': 0.025367254}, {'price14': 0.0277322}, {'adx': 0.026825072}, {'volume_10MA': 0.020689419}, {'SPY_diff': 0.018601883}, {'SPY_1D': 0.035372764}]"}
# {'deployment_date': datetime.datetime(2022, 11, 7, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 10, 28, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    221878
# 1    117021
# Name: count, dtype: int64
# 565 579 841 205
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-11-07', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 565, 'TPpct': Decimal('0'), 'FP': 579, 'FPpct': Decimal('0'), 'TN': 841, 'TNpct': Decimal('0'), 'FN': 205, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.9758203799654577'), 'evaluation_timeperiod': '2022-11-07_2022-11-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.017196413}, {'vol7': 0.018169086}, {'daily_volume_vol_diff30': 0.023140335}, {'price_10DDiff': 0.03012467}, {'close_diff3': 0.02574814}, {'return_vol_30D': 0.038436476}, {'hour_vol_diff_pct': 0.018882288}, {'v_diff_pct': 0.01900655}, {'month': 0.041409373}, {'hour_volume_vol_diff': 0.02059039}, {'rsi5': 0.027723059}, {'range_vol_diff5': 0.022277286}, {'daily_vol_diff30': 0.027084686}, {'rsi': 0.027410861}, {'roc_diff': 0.027542153}, {'range_vol5MA': 0.3095877}, {'price_25MA': 0.03133712}, {'year': 0.05577026}, {'min_vol_diff': 0.03282036}, {'return_vol_5D': 0.025510222}, {'daily_vol_diff': 0.02532393}, {'price14': 0.028096845}, {'adx': 0.02794672}, {'volume_10MA': 0.021805413}, {'SPY_diff': 0.020262139}, {'SPY_1D': 0.03679748}]"}
# {'deployment_date': datetime.datetime(2022, 11, 14, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 11, 4, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    222937
# 1    118482
# Name: count, dtype: int64
# 1161 419 523 87
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-11-14', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 1161, 'TPpct': Decimal('0'), 'FP': 419, 'FPpct': Decimal('0'), 'TN': 523, 'TNpct': Decimal('0'), 'FN': 87, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.7708830548926016'), 'evaluation_timeperiod': '2022-11-14_2022-11-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.018047892}, {'vol7': 0.017415576}, {'daily_volume_vol_diff30': 0.023669042}, {'price_10DDiff': 0.030089071}, {'close_diff3': 0.026730286}, {'return_vol_30D': 0.03852211}, {'hour_vol_diff_pct': 0.018252715}, {'v_diff_pct': 0.019418532}, {'month': 0.04168661}, {'hour_volume_vol_diff': 0.019994076}, {'rsi5': 0.026557038}, {'range_vol_diff5': 0.02204715}, {'daily_vol_diff30': 0.026851332}, {'rsi': 0.027648628}, {'roc_diff': 0.027715467}, {'range_vol5MA': 0.3148925}, {'price_25MA': 0.030131957}, {'year': 0.05543414}, {'min_vol_diff': 0.032386214}, {'return_vol_5D': 0.025076304}, {'daily_vol_diff': 0.025437418}, {'price14': 0.028309109}, {'adx': 0.028033553}, {'volume_10MA': 0.021618964}, {'SPY_diff': 0.018703846}, {'SPY_1D': 0.035330538}]"}
# {'deployment_date': datetime.datetime(2022, 11, 21, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 11, 11, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    224659
# 1    119280
# Name: count, dtype: int64
# 445 704 868 102
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-11-21', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 445, 'TPpct': Decimal('0'), 'FP': 704, 'FPpct': Decimal('0'), 'TN': 868, 'TNpct': Decimal('0'), 'FN': 102, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6321022727272727'), 'evaluation_timeperiod': '2022-11-21_2022-11-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.016948981}, {'vol7': 0.017450277}, {'daily_volume_vol_diff30': 0.0224625}, {'price_10DDiff': 0.028938567}, {'close_diff3': 0.025128689}, {'return_vol_30D': 0.03761123}, {'hour_vol_diff_pct': 0.017729089}, {'v_diff_pct': 0.019537922}, {'month': 0.039601773}, {'hour_volume_vol_diff': 0.020084472}, {'rsi5': 0.027053135}, {'range_vol_diff5': 0.022545379}, {'daily_vol_diff30': 0.02619016}, {'rsi': 0.026542412}, {'roc_diff': 0.027435452}, {'range_vol5MA': 0.32647943}, {'price_25MA': 0.030702917}, {'year': 0.05457268}, {'min_vol_diff': 0.033329323}, {'return_vol_5D': 0.024058592}, {'daily_vol_diff': 0.025568545}, {'price14': 0.026807908}, {'adx': 0.027267974}, {'volume_10MA': 0.021873282}, {'SPY_diff': 0.018773938}, {'SPY_1D': 0.03530542}]"}
# {'deployment_date': datetime.datetime(2022, 11, 28, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 11, 18, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    225921
# 1    120538
# Name: count, dtype: int64
# 598 614 804 174
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-11-28', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 598, 'TPpct': Decimal('0'), 'FP': 614, 'FPpct': Decimal('0'), 'TN': 804, 'TNpct': Decimal('0'), 'FN': 174, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.9739413680781759'), 'evaluation_timeperiod': '2022-11-28_2022-12-02', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.016223852}, {'vol7': 0.018090913}, {'daily_volume_vol_diff30': 0.02248151}, {'price_10DDiff': 0.02820778}, {'close_diff3': 0.02464202}, {'return_vol_30D': 0.03574697}, {'hour_vol_diff_pct': 0.017479151}, {'v_diff_pct': 0.01932657}, {'month': 0.038910054}, {'hour_volume_vol_diff': 0.02000659}, {'rsi5': 0.026650188}, {'range_vol_diff5': 0.02084594}, {'daily_vol_diff30': 0.025034415}, {'rsi': 0.027709845}, {'roc_diff': 0.026326496}, {'range_vol5MA': 0.3420491}, {'price_25MA': 0.029539865}, {'year': 0.052608825}, {'min_vol_diff': 0.033772208}, {'return_vol_5D': 0.02309869}, {'daily_vol_diff': 0.024920085}, {'price14': 0.02662307}, {'adx': 0.027045643}, {'volume_10MA': 0.019962033}, {'SPY_diff': 0.01797563}, {'SPY_1D': 0.034722462}]"}
# {'deployment_date': datetime.datetime(2022, 12, 5, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 11, 25, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    227514
# 1    120961
# Name: count, dtype: int64
# 578 461 924 227
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-12-05', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 578, 'TPpct': Decimal('0'), 'FP': 461, 'FPpct': Decimal('0'), 'TN': 924, 'TNpct': Decimal('0'), 'FN': 227, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.2537960954446854'), 'evaluation_timeperiod': '2022-12-05_2022-12-09', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.01719683}, {'vol7': 0.017350705}, {'daily_volume_vol_diff30': 0.022503749}, {'price_10DDiff': 0.027959865}, {'close_diff3': 0.023709688}, {'return_vol_30D': 0.033926006}, {'hour_vol_diff_pct': 0.017751068}, {'v_diff_pct': 0.018101985}, {'month': 0.039211232}, {'hour_volume_vol_diff': 0.019411104}, {'rsi5': 0.026875531}, {'range_vol_diff5': 0.021473398}, {'daily_vol_diff30': 0.025447095}, {'rsi': 0.02647712}, {'roc_diff': 0.026236841}, {'range_vol5MA': 0.34029195}, {'price_25MA': 0.028759714}, {'year': 0.05151572}, {'min_vol_diff': 0.043472927}, {'return_vol_5D': 0.02395272}, {'daily_vol_diff': 0.024654295}, {'price14': 0.025743753}, {'adx': 0.026688576}, {'volume_10MA': 0.02053751}, {'SPY_diff': 0.017677601}, {'SPY_1D': 0.033073}]"}
# {'deployment_date': datetime.datetime(2022, 12, 12, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 12, 2, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    229647
# 1    121824
# Name: count, dtype: int64
# 945 181 639 425
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-12-12', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 945, 'TPpct': Decimal('0'), 'FP': 181, 'FPpct': Decimal('0'), 'TN': 639, 'TNpct': Decimal('0'), 'FN': 425, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('5.220994475138122'), 'evaluation_timeperiod': '2022-12-12_2022-12-16', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.015658}, {'vol7': 0.01701452}, {'daily_volume_vol_diff30': 0.022662908}, {'price_10DDiff': 0.027957827}, {'close_diff3': 0.025207238}, {'return_vol_30D': 0.035081185}, {'hour_vol_diff_pct': 0.015844503}, {'v_diff_pct': 0.018560037}, {'month': 0.039431244}, {'hour_volume_vol_diff': 0.02015734}, {'rsi5': 0.026587764}, {'range_vol_diff5': 0.021417271}, {'daily_vol_diff30': 0.026368162}, {'rsi': 0.027649658}, {'roc_diff': 0.025872823}, {'range_vol5MA': 0.33970144}, {'price_25MA': 0.029559514}, {'year': 0.052002456}, {'min_vol_diff': 0.039134655}, {'return_vol_5D': 0.02396927}, {'daily_vol_diff': 0.025243606}, {'price14': 0.026418082}, {'adx': 0.026585689}, {'volume_10MA': 0.019336332}, {'SPY_diff': 0.018955244}, {'SPY_1D': 0.03362321}]"}
# {'deployment_date': datetime.datetime(2022, 12, 19, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 12, 9, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    231210
# 1    122781
# Name: count, dtype: int64
# 358 177 1120 535
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-12-19', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 358, 'TPpct': Decimal('0'), 'FP': 177, 'FPpct': Decimal('0'), 'TN': 1120, 'TNpct': Decimal('0'), 'FN': 535, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.022598870056497'), 'evaluation_timeperiod': '2022-12-19_2022-12-23', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.016828828}, {'vol7': 0.017679209}, {'daily_volume_vol_diff30': 0.021431657}, {'price_10DDiff': 0.027993124}, {'close_diff3': 0.024156729}, {'return_vol_30D': 0.03496144}, {'hour_vol_diff_pct': 0.017230792}, {'v_diff_pct': 0.018783594}, {'month': 0.039542567}, {'hour_volume_vol_diff': 0.02054854}, {'rsi5': 0.026080146}, {'range_vol_diff5': 0.022799203}, {'daily_vol_diff30': 0.02614671}, {'rsi': 0.026057158}, {'roc_diff': 0.025650077}, {'range_vol5MA': 0.33815774}, {'price_25MA': 0.029038217}, {'year': 0.05144188}, {'min_vol_diff': 0.040085893}, {'return_vol_5D': 0.02337362}, {'daily_vol_diff': 0.025100702}, {'price14': 0.026209941}, {'adx': 0.026510376}, {'volume_10MA': 0.021395462}, {'SPY_diff': 0.018257322}, {'SPY_1D': 0.03453909}]"}
# {'deployment_date': datetime.datetime(2022, 12, 26, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 12, 16, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    232228
# 1    124283
# Name: count, dtype: int64
# 204 765 725 58
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2022-12-26', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 204, 'TPpct': Decimal('0'), 'FP': 765, 'FPpct': Decimal('0'), 'TN': 725, 'TNpct': Decimal('0'), 'FN': 58, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.26666666666666666'), 'evaluation_timeperiod': '2022-12-26_2022-12-30', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.016576055}, {'vol7': 0.017021267}, {'daily_volume_vol_diff30': 0.022029221}, {'price_10DDiff': 0.02728523}, {'close_diff3': 0.02463736}, {'return_vol_30D': 0.034239106}, {'hour_vol_diff_pct': 0.016338648}, {'v_diff_pct': 0.018807614}, {'month': 0.039426435}, {'hour_volume_vol_diff': 0.02007643}, {'rsi5': 0.02654109}, {'range_vol_diff5': 0.022252137}, {'daily_vol_diff30': 0.025261445}, {'rsi': 0.026970483}, {'roc_diff': 0.025028467}, {'range_vol5MA': 0.34929514}, {'price_25MA': 0.029232815}, {'year': 0.051513143}, {'min_vol_diff': 0.03441561}, {'return_vol_5D': 0.024334678}, {'daily_vol_diff': 0.02436323}, {'price14': 0.02632807}, {'adx': 0.02581124}, {'volume_10MA': 0.020617813}, {'SPY_diff': 0.018113052}, {'SPY_1D': 0.03348428}]"}
# {'deployment_date': datetime.datetime(2023, 1, 2, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 12, 23, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    233779
# 1    125252
# Name: count, dtype: int64
# 406 612 709 25
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-01-02', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 406, 'TPpct': Decimal('0'), 'FP': 612, 'FPpct': Decimal('0'), 'TN': 709, 'TNpct': Decimal('0'), 'FN': 25, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6633986928104575'), 'evaluation_timeperiod': '2023-01-02_2023-01-06', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.016900197}, {'vol7': 0.01660586}, {'daily_volume_vol_diff30': 0.022545384}, {'price_10DDiff': 0.02819138}, {'close_diff3': 0.023918606}, {'return_vol_30D': 0.035324343}, {'hour_vol_diff_pct': 0.017757421}, {'v_diff_pct': 0.019123057}, {'month': 0.038353134}, {'hour_volume_vol_diff': 0.019422185}, {'rsi5': 0.026507022}, {'range_vol_diff5': 0.02179767}, {'daily_vol_diff30': 0.025008403}, {'rsi': 0.026586078}, {'roc_diff': 0.026157605}, {'range_vol5MA': 0.3437308}, {'price_25MA': 0.029294845}, {'year': 0.053355858}, {'min_vol_diff': 0.03332675}, {'return_vol_5D': 0.023528703}, {'daily_vol_diff': 0.025035338}, {'price14': 0.026525186}, {'adx': 0.026521634}, {'volume_10MA': 0.021646047}, {'SPY_diff': 0.018721499}, {'SPY_1D': 0.034114983}]"}
# {'deployment_date': datetime.datetime(2023, 1, 9, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2022, 12, 30, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    235483
# 1    125564
# Name: count, dtype: int64
# 165 1017 872 113
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-01-09', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 165, 'TPpct': Decimal('0'), 'FP': 1017, 'FPpct': Decimal('0'), 'TN': 872, 'TNpct': Decimal('0'), 'FN': 113, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.16224188790560473'), 'evaluation_timeperiod': '2023-01-09_2023-01-13', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.016212463}, {'vol7': 0.016914044}, {'daily_volume_vol_diff30': 0.021549141}, {'price_10DDiff': 0.028574727}, {'close_diff3': 0.023682373}, {'return_vol_30D': 0.03331043}, {'hour_vol_diff_pct': 0.016881773}, {'v_diff_pct': 0.018291455}, {'month': 0.0397385}, {'hour_volume_vol_diff': 0.020258639}, {'rsi5': 0.02581475}, {'range_vol_diff5': 0.022848938}, {'daily_vol_diff30': 0.02539971}, {'rsi': 0.025932627}, {'roc_diff': 0.025647588}, {'range_vol5MA': 0.3577812}, {'price_25MA': 0.028448438}, {'year': 0.05088241}, {'min_vol_diff': 0.031287506}, {'return_vol_5D': 0.023091234}, {'daily_vol_diff': 0.023485444}, {'price14': 0.02635675}, {'adx': 0.025799742}, {'volume_10MA': 0.020214396}, {'SPY_diff': 0.018323889}, {'SPY_1D': 0.033271804}]"}
# {'deployment_date': datetime.datetime(2023, 1, 16, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 1, 6, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    237006
# 1    126057
# Name: count, dtype: int64
# 244 219 703 333
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-01-16', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 244, 'TPpct': Decimal('0'), 'FP': 219, 'FPpct': Decimal('0'), 'TN': 703, 'TNpct': Decimal('0'), 'FN': 333, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.1141552511415524'), 'evaluation_timeperiod': '2023-01-16_2023-01-20', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.01646983}, {'vol7': 0.01643692}, {'daily_volume_vol_diff30': 0.02202475}, {'price_10DDiff': 0.028118206}, {'close_diff3': 0.02479626}, {'return_vol_30D': 0.03598667}, {'hour_vol_diff_pct': 0.017376324}, {'v_diff_pct': 0.019168558}, {'month': 0.038470358}, {'hour_volume_vol_diff': 0.02014336}, {'rsi5': 0.025925517}, {'range_vol_diff5': 0.021661924}, {'daily_vol_diff30': 0.025423191}, {'rsi': 0.02703693}, {'roc_diff': 0.025948554}, {'range_vol5MA': 0.35334802}, {'price_25MA': 0.029737737}, {'year': 0.051040158}, {'min_vol_diff': 0.027915195}, {'return_vol_5D': 0.024148846}, {'daily_vol_diff': 0.023815429}, {'price14': 0.026615791}, {'adx': 0.026145}, {'volume_10MA': 0.020460762}, {'SPY_diff': 0.018779222}, {'SPY_1D': 0.033006515}]"}
# {'deployment_date': datetime.datetime(2023, 1, 23, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 1, 13, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    239351
# 1    126232
# Name: count, dtype: int64
# 64 76 1147 443
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-01-23', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 64, 'TPpct': Decimal('0'), 'FP': 76, 'FPpct': Decimal('0'), 'TN': 1147, 'TNpct': Decimal('0'), 'FN': 443, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8421052631578947'), 'evaluation_timeperiod': '2023-01-23_2023-01-27', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.016625004}, {'vol7': 0.016573455}, {'daily_volume_vol_diff30': 0.021949124}, {'price_10DDiff': 0.02819868}, {'close_diff3': 0.02416494}, {'return_vol_30D': 0.035835426}, {'hour_vol_diff_pct': 0.017114451}, {'v_diff_pct': 0.017999886}, {'month': 0.03899329}, {'hour_volume_vol_diff': 0.020053947}, {'rsi5': 0.026606683}, {'range_vol_diff5': 0.021827959}, {'daily_vol_diff30': 0.02465327}, {'rsi': 0.026394265}, {'roc_diff': 0.025333036}, {'range_vol5MA': 0.3559267}, {'price_25MA': 0.029768197}, {'year': 0.052690543}, {'min_vol_diff': 0.025759937}, {'return_vol_5D': 0.024341987}, {'daily_vol_diff': 0.02473615}, {'price14': 0.026641065}, {'adx': 0.026079299}, {'volume_10MA': 0.020286903}, {'SPY_diff': 0.018256048}, {'SPY_1D': 0.03318981}]"}
# {'deployment_date': datetime.datetime(2023, 1, 30, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 1, 20, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    240401
# 1    126937
# Name: count, dtype: int64
# 194 111 822 396
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-01-30', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 194, 'TPpct': Decimal('0'), 'FP': 111, 'FPpct': Decimal('0'), 'TN': 822, 'TNpct': Decimal('0'), 'FN': 396, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.7477477477477477'), 'evaluation_timeperiod': '2023-01-30_2023-02-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.016468236}, {'vol7': 0.017734569}, {'daily_volume_vol_diff30': 0.022637436}, {'price_10DDiff': 0.029099997}, {'close_diff3': 0.02430002}, {'return_vol_30D': 0.037551884}, {'hour_vol_diff_pct': 0.018151013}, {'v_diff_pct': 0.019181153}, {'month': 0.039202843}, {'hour_volume_vol_diff': 0.020347323}, {'rsi5': 0.0263463}, {'range_vol_diff5': 0.022404859}, {'daily_vol_diff30': 0.025986584}, {'rsi': 0.027306}, {'roc_diff': 0.026160557}, {'range_vol5MA': 0.34026653}, {'price_25MA': 0.030094078}, {'year': 0.053030998}, {'min_vol_diff': 0.027108556}, {'return_vol_5D': 0.024525981}, {'daily_vol_diff': 0.025273854}, {'price14': 0.02660766}, {'adx': 0.027062202}, {'volume_10MA': 0.020586329}, {'SPY_diff': 0.019048426}, {'SPY_1D': 0.033516537}]"}
# {'deployment_date': datetime.datetime(2023, 2, 6, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 1, 27, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    241915
# 1    127392
# Name: count, dtype: int64
# 90 18 680 712
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-02-06', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 90, 'TPpct': Decimal('0'), 'FP': 18, 'FPpct': Decimal('0'), 'TN': 680, 'TNpct': Decimal('0'), 'FN': 712, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('5.0'), 'evaluation_timeperiod': '2023-02-06_2023-02-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.018291496}, {'vol7': 0.018240985}, {'daily_volume_vol_diff30': 0.022196803}, {'price_10DDiff': 0.028225204}, {'close_diff3': 0.02492504}, {'return_vol_30D': 0.03609219}, {'hour_vol_diff_pct': 0.01734287}, {'v_diff_pct': 0.019044591}, {'month': 0.03975165}, {'hour_volume_vol_diff': 0.020256804}, {'rsi5': 0.026960457}, {'range_vol_diff5': 0.022449719}, {'daily_vol_diff30': 0.026967335}, {'rsi': 0.0273167}, {'roc_diff': 0.026966618}, {'range_vol5MA': 0.33947358}, {'price_25MA': 0.03075459}, {'year': 0.05461264}, {'min_vol_diff': 0.022577763}, {'return_vol_5D': 0.024055915}, {'daily_vol_diff': 0.025907664}, {'price14': 0.026445303}, {'adx': 0.027159188}, {'volume_10MA': 0.02093237}, {'SPY_diff': 0.018849442}, {'SPY_1D': 0.03420303}]"}
# {'deployment_date': datetime.datetime(2023, 2, 13, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 2, 3, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    243118
# 1    127926
# Name: count, dtype: int64
# 217 57 818 546
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-02-13', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 217, 'TPpct': Decimal('0'), 'FP': 57, 'FPpct': Decimal('0'), 'TN': 818, 'TNpct': Decimal('0'), 'FN': 546, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.807017543859649'), 'evaluation_timeperiod': '2023-02-13_2023-02-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.017005065}, {'vol7': 0.017651957}, {'daily_volume_vol_diff30': 0.022034137}, {'price_10DDiff': 0.028860033}, {'close_diff3': 0.023252945}, {'return_vol_30D': 0.03788767}, {'hour_vol_diff_pct': 0.016003009}, {'v_diff_pct': 0.018813515}, {'month': 0.03869294}, {'hour_volume_vol_diff': 0.02068666}, {'rsi5': 0.026692647}, {'range_vol_diff5': 0.022314405}, {'daily_vol_diff30': 0.025548333}, {'rsi': 0.028299829}, {'roc_diff': 0.02564971}, {'range_vol5MA': 0.3527794}, {'price_25MA': 0.029828994}, {'year': 0.051011067}, {'min_vol_diff': 0.023103794}, {'return_vol_5D': 0.023347974}, {'daily_vol_diff': 0.024127873}, {'price14': 0.027299572}, {'adx': 0.026131481}, {'volume_10MA': 0.021748457}, {'SPY_diff': 0.017988311}, {'SPY_1D': 0.033240244}]"}
# {'deployment_date': datetime.datetime(2023, 2, 20, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 2, 10, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    243795
# 1    128899
# Name: count, dtype: int64
# 329 273 420 178
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-02-20', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 329, 'TPpct': Decimal('0'), 'FP': 273, 'FPpct': Decimal('0'), 'TN': 420, 'TNpct': Decimal('0'), 'FN': 178, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.205128205128205'), 'evaluation_timeperiod': '2023-02-20_2023-02-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.016573105}, {'vol7': 0.01706153}, {'daily_volume_vol_diff30': 0.022219231}, {'price_10DDiff': 0.028177984}, {'close_diff3': 0.02373388}, {'return_vol_30D': 0.036026195}, {'hour_vol_diff_pct': 0.01690327}, {'v_diff_pct': 0.018340144}, {'month': 0.03981369}, {'hour_volume_vol_diff': 0.019468518}, {'rsi5': 0.02560726}, {'range_vol_diff5': 0.021000521}, {'daily_vol_diff30': 0.024768969}, {'rsi': 0.026774872}, {'roc_diff': 0.02591698}, {'range_vol5MA': 0.34912032}, {'price_25MA': 0.029367719}, {'year': 0.052056704}, {'min_vol_diff': 0.03397288}, {'return_vol_5D': 0.023269149}, {'daily_vol_diff': 0.025361655}, {'price14': 0.026102232}, {'adx': 0.026320618}, {'volume_10MA': 0.020793738}, {'SPY_diff': 0.017979736}, {'SPY_1D': 0.03326908}]"}
# {'deployment_date': datetime.datetime(2023, 2, 27, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 2, 17, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    244875
# 1    129469
# Name: count, dtype: int64
# 228 187 830 255
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-02-27', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 228, 'TPpct': Decimal('0'), 'FP': 187, 'FPpct': Decimal('0'), 'TN': 830, 'TNpct': Decimal('0'), 'FN': 255, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.2192513368983957'), 'evaluation_timeperiod': '2023-02-27_2023-03-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.017117005}, {'vol7': 0.01699786}, {'daily_volume_vol_diff30': 0.022371428}, {'price_10DDiff': 0.028022718}, {'close_diff3': 0.024954088}, {'return_vol_30D': 0.03709296}, {'hour_vol_diff_pct': 0.0169911}, {'v_diff_pct': 0.018274568}, {'month': 0.039257664}, {'hour_volume_vol_diff': 0.020311896}, {'rsi5': 0.026032079}, {'range_vol_diff5': 0.021683825}, {'daily_vol_diff30': 0.02597196}, {'rsi': 0.026510036}, {'roc_diff': 0.02593521}, {'range_vol5MA': 0.34570432}, {'price_25MA': 0.02956102}, {'year': 0.051745724}, {'min_vol_diff': 0.03330481}, {'return_vol_5D': 0.022722017}, {'daily_vol_diff': 0.024223758}, {'price14': 0.02655155}, {'adx': 0.026360098}, {'volume_10MA': 0.019927392}, {'SPY_diff': 0.017893774}, {'SPY_1D': 0.034481104}]"}
# {'deployment_date': datetime.datetime(2023, 3, 6, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 2, 24, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    245691
# 1    130147
# Name: count, dtype: int64
# 524 90 324 562
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-03-06', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 524, 'TPpct': Decimal('0'), 'FP': 90, 'FPpct': Decimal('0'), 'TN': 324, 'TNpct': Decimal('0'), 'FN': 562, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('5.822222222222222'), 'evaluation_timeperiod': '2023-03-06_2023-03-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.01710517}, {'vol7': 0.017562572}, {'daily_volume_vol_diff30': 0.02171144}, {'price_10DDiff': 0.029167712}, {'close_diff3': 0.02449844}, {'return_vol_30D': 0.037614893}, {'hour_vol_diff_pct': 0.017639209}, {'v_diff_pct': 0.018197864}, {'month': 0.03964099}, {'hour_volume_vol_diff': 0.019867094}, {'rsi5': 0.026151415}, {'range_vol_diff5': 0.022069037}, {'daily_vol_diff30': 0.025578246}, {'rsi': 0.027451472}, {'roc_diff': 0.025916645}, {'range_vol5MA': 0.3515141}, {'price_25MA': 0.029951025}, {'year': 0.050593257}, {'min_vol_diff': 0.023280857}, {'return_vol_5D': 0.023644933}, {'daily_vol_diff': 0.025500562}, {'price14': 0.0265483}, {'adx': 0.026594853}, {'volume_10MA': 0.020196026}, {'SPY_diff': 0.018423438}, {'SPY_1D': 0.03358038}]"}
# {'deployment_date': datetime.datetime(2023, 3, 13, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 3, 3, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    246932
# 1    130556
# Name: count, dtype: int64
# 113 278 897 212
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-03-13', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 113, 'TPpct': Decimal('0'), 'FP': 278, 'FPpct': Decimal('0'), 'TN': 897, 'TNpct': Decimal('0'), 'FN': 212, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.4064748201438849'), 'evaluation_timeperiod': '2023-03-13_2023-03-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.016045803}, {'vol7': 0.018335087}, {'daily_volume_vol_diff30': 0.02257925}, {'price_10DDiff': 0.028439179}, {'close_diff3': 0.024386788}, {'return_vol_30D': 0.03755129}, {'hour_vol_diff_pct': 0.016951729}, {'v_diff_pct': 0.01912277}, {'month': 0.0402442}, {'hour_volume_vol_diff': 0.020078773}, {'rsi5': 0.02758701}, {'range_vol_diff5': 0.022480577}, {'daily_vol_diff30': 0.025548555}, {'rsi': 0.027251614}, {'roc_diff': 0.026275432}, {'range_vol5MA': 0.33899042}, {'price_25MA': 0.030024495}, {'year': 0.05192951}, {'min_vol_diff': 0.030128246}, {'return_vol_5D': 0.023490202}, {'daily_vol_diff': 0.025860026}, {'price14': 0.026510248}, {'adx': 0.027043601}, {'volume_10MA': 0.020867534}, {'SPY_diff': 0.017422201}, {'SPY_1D': 0.03485548}]"}
# {'deployment_date': datetime.datetime(2023, 3, 20, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 3, 10, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    247393
# 1    131745
# Name: count, dtype: int64
# 436 508 443 113
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-03-20', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 436, 'TPpct': Decimal('0'), 'FP': 508, 'FPpct': Decimal('0'), 'TN': 443, 'TNpct': Decimal('0'), 'FN': 113, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8582677165354331'), 'evaluation_timeperiod': '2023-03-20_2023-03-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.017695842}, {'vol7': 0.018894786}, {'daily_volume_vol_diff30': 0.022417907}, {'price_10DDiff': 0.029184306}, {'close_diff3': 0.025003005}, {'return_vol_30D': 0.040374383}, {'hour_vol_diff_pct': 0.016550535}, {'v_diff_pct': 0.01942376}, {'month': 0.041206546}, {'hour_volume_vol_diff': 0.020203715}, {'rsi5': 0.027078485}, {'range_vol_diff5': 0.022579217}, {'daily_vol_diff30': 0.026023887}, {'rsi': 0.027734695}, {'roc_diff': 0.026477797}, {'range_vol5MA': 0.33204654}, {'price_25MA': 0.030239796}, {'year': 0.049325872}, {'min_vol_diff': 0.029720958}, {'return_vol_5D': 0.023159485}, {'daily_vol_diff': 0.026475023}, {'price14': 0.027138608}, {'adx': 0.027459979}, {'volume_10MA': 0.02131334}, {'SPY_diff': 0.019226182}, {'SPY_1D': 0.033045348}]"}
# {'deployment_date': datetime.datetime(2023, 3, 27, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 3, 17, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    248607
# 1    132181
# Name: count, dtype: int64
# 152 299 801 248
# ...
# {'deployment_date': datetime.datetime(2023, 9, 18, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 9, 8, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    276312
# 1    144166
# Name: count, dtype: int64
# 115 33 703 673
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-09-18', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 115, 'TPpct': Decimal('0'), 'FP': 33, 'FPpct': Decimal('0'), 'TN': 703, 'TNpct': Decimal('0'), 'FN': 673, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.484848484848485'), 'evaluation_timeperiod': '2023-09-18_2023-09-22', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.017134668}, {'vol7': 0.018342387}, {'daily_volume_vol_diff30': 0.022338934}, {'price_10DDiff': 0.030281434}, {'close_diff3': 0.025544563}, {'return_vol_30D': 0.04636823}, {'hour_vol_diff_pct': 0.016986106}, {'v_diff_pct': 0.018671457}, {'month': 0.039976895}, {'hour_volume_vol_diff': 0.019310644}, {'rsi5': 0.026342176}, {'range_vol_diff5': 0.021165974}, {'daily_vol_diff30': 0.025262894}, {'rsi': 0.027828872}, {'roc_diff': 0.02661977}, {'range_vol5MA': 0.3337621}, {'price_25MA': 0.030345716}, {'year': 0.04778073}, {'min_vol_diff': 0.025288342}, {'return_vol_5D': 0.025933206}, {'daily_vol_diff': 0.02634419}, {'price14': 0.027028652}, {'adx': 0.027492154}, {'volume_10MA': 0.021473423}, {'SPY_diff': 0.018479055}, {'SPY_1D': 0.033897344}]"}
# {'deployment_date': datetime.datetime(2023, 9, 25, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 9, 15, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    277383
# 1    144745
# Name: count, dtype: int64
# 82 70 1049 329
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-09-25', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 82, 'TPpct': Decimal('0'), 'FP': 70, 'FPpct': Decimal('0'), 'TN': 1049, 'TNpct': Decimal('0'), 'FN': 329, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.1714285714285715'), 'evaluation_timeperiod': '2023-09-25_2023-09-29', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.016704626}, {'vol7': 0.017803162}, {'daily_volume_vol_diff30': 0.022405788}, {'price_10DDiff': 0.02820922}, {'close_diff3': 0.02506019}, {'return_vol_30D': 0.043869913}, {'hour_vol_diff_pct': 0.017083485}, {'v_diff_pct': 0.01816559}, {'month': 0.038660146}, {'hour_volume_vol_diff': 0.019252645}, {'rsi5': 0.026250558}, {'range_vol_diff5': 0.020991096}, {'daily_vol_diff30': 0.024724504}, {'rsi': 0.027420055}, {'roc_diff': 0.025917077}, {'range_vol5MA': 0.33980817}, {'price_25MA': 0.030553538}, {'year': 0.047507238}, {'min_vol_diff': 0.032743588}, {'return_vol_5D': 0.024490878}, {'daily_vol_diff': 0.026661063}, {'price14': 0.027177}, {'adx': 0.027488071}, {'volume_10MA': 0.019826457}, {'SPY_diff': 0.018077468}, {'SPY_1D': 0.03314848}]"}
# {'deployment_date': datetime.datetime(2023, 10, 2, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 9, 22, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    278131
# 1    145665
# Name: count, dtype: int64
# 108 183 977 262
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-10-02', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 108, 'TPpct': Decimal('0'), 'FP': 183, 'FPpct': Decimal('0'), 'TN': 977, 'TNpct': Decimal('0'), 'FN': 262, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5901639344262295'), 'evaluation_timeperiod': '2023-10-02_2023-10-06', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.017470226}, {'vol7': 0.017730786}, {'daily_volume_vol_diff30': 0.022347081}, {'price_10DDiff': 0.028719204}, {'close_diff3': 0.02446881}, {'return_vol_30D': 0.04392853}, {'hour_vol_diff_pct': 0.016889863}, {'v_diff_pct': 0.01958842}, {'month': 0.03924519}, {'hour_volume_vol_diff': 0.019069051}, {'rsi5': 0.026315246}, {'range_vol_diff5': 0.02091477}, {'daily_vol_diff30': 0.026174404}, {'rsi': 0.027272837}, {'roc_diff': 0.026367739}, {'range_vol5MA': 0.3450373}, {'price_25MA': 0.030080458}, {'year': 0.04758726}, {'min_vol_diff': 0.025595823}, {'return_vol_5D': 0.02416312}, {'daily_vol_diff': 0.02508476}, {'price14': 0.027413717}, {'adx': 0.026628705}, {'volume_10MA': 0.02110065}, {'SPY_diff': 0.017866878}, {'SPY_1D': 0.032939196}]"}
# {'deployment_date': datetime.datetime(2023, 10, 9, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 9, 29, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    279491
# 1    145985
# Name: count, dtype: int64
# 108 30 445 335
# {'model_name': 'SFP:3D_TSSIM1_expVol_custHyP15_2018', 'deployment_date': '2023-10-09', 'algorithm_type': 'xgboost', 'dataset': '3D_TSSIM1_expVol_custHypP15_2018', 'TP': 108, 'TPpct': Decimal('0'), 'FP': 30, 'FPpct': Decimal('0'), 'TN': 445, 'TNpct': Decimal('0'), 'FN': 335, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.6'), 'evaluation_timeperiod': '2023-10-09_2023-10-13', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['close_diff_deviation', 'vol7', 'daily_volume_vol_diff30', 'price_10DDiff', 'close_diff3', 'return_vol_30D', 'hour_vol_diff_pct', 'v_diff_pct', 'month', 'hour_volume_vol_diff', 'rsi5', 'range_vol_diff5', 'daily_vol_diff30', 'rsi', 'roc_diff', 'range_vol5MA', 'price_25MA', 'year', 'min_vol_diff', 'return_vol_5D', 'daily_vol_diff', 'price14', 'adx', 'volume_10MA', 'SPY_diff', 'SPY_1D']"}, 'target': '-0.045+three_min', 'feature_importances': "[{'close_diff_deviation': 0.016829867}, {'vol7': 0.018389171}, {'daily_volume_vol_diff30': 0.023301566}, {'price_10DDiff': 0.02882135}, {'close_diff3': 0.024492588}, {'return_vol_30D': 0.05276204}, {'hour_vol_diff_pct': 0.017546436}, {'v_diff_pct': 0.018414807}, {'month': 0.039699156}, {'hour_volume_vol_diff': 0.020173362}, {'rsi5': 0.025807181}, {'range_vol_diff5': 0.02060079}, {'daily_vol_diff30': 0.025469085}, {'rsi': 0.027301647}, {'roc_diff': 0.0260953}, {'range_vol5MA': 0.3359117}, {'price_25MA': 0.030285789}, {'year': 0.04728209}, {'min_vol_diff': 0.025097817}, {'return_vol_5D': 0.023924643}, {'daily_vol_diff': 0.025117384}, {'price14': 0.027326873}, {'adx': 0.027189558}, {'volume_10MA': 0.020964669}, {'SPY_diff': 0.017704371}, {'SPY_1D': 0.033490766}]"}
# {'deployment_date': datetime.datetime(2023, 10, 16, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_end': datetime.datetime(2023, 10, 6, 0, 0, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>), 'dataset_start': datetime.datetime(2020, 1, 1, 0, 0)}
# label
# 0    280604
# 1    146552
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a> for date in dates_list:
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=19'>20</a>     print(date)
# ---> <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=20'>21</a>     response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,"dataset_start_date",date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])
#
# /Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=10'>11</a> dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
# ---> <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=12'>13</a> tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=13'>14</a> response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=14'>15</a> validation_dataset['probabilities'] = probabilities[:,1]
#
# /Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a> predictions = xgb_model.predict(X_validate)
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=19'>20</a> probabilities = xgb_model.predict_proba(X_validate)
# ---> <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=20'>21</a> tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=22'>23</a> fi = xgb_model.feature_importances_
#      <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=23'>24</a> fi_list = []
#
# /Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb Cell 10 line 4
#       <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> result_list = []
#       <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> counter = 0
# ----> <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> predictions_series = pd.Series(predictions,name='prediction_values')
#       <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> for x in predictions:
#       <a href='vscode-notebook-cell:/Users/charlesmiller/Documents/Code/IIE/Icarus/model-tester/xgboost_classifiers/inv_alerts/models/xgb/sfP_3d.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a>     if x == 1:
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/pandas/core/series.py:509, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     507         data = data.copy()
#     508 else:
# --> 509     data = sanitize_array(data, index, dtype, copy)
#     511     manager = get_option("mode.data_manager")
#     512     if manager == "block":
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/pandas/core/construction.py:607, in sanitize_array(data, index, dtype, copy, allow_2d)
#     604             subarr = cast(np.ndarray, subarr)
#     605             subarr = maybe_infer_to_datetimelike(subarr)
# --> 607 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     609 if isinstance(subarr, np.ndarray):
#     610     # at this point we should have dtype be None or subarr.dtype == dtype
#     611     dtype = cast(np.dtype, dtype)
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/pandas/core/construction.py:666, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     664     if allow_2d:
#     665         return result
# --> 666     raise ValueError(
#     667         f"Data must be 1-dimensional, got ndarray of shape {data.shape} instead"
#     668     )
#     669 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     670     # i.e. PandasDtype("O")
#     672     result = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#
# ValueError: Data must be 1-dimensional, got ndarray of shape (0, 0) instead
