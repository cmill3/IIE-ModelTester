# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler
import pytz
import warnings
warnings.filterwarnings('ignore')

# %%
s3 = boto3.client('s3')

training_bucket = "icarus-research-data"
training_prefix = 'training_datasets/expanded_1d_datasets/'

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

weekly_expiries = ['SPY', 'IVV', 'QQQ', 'GLD', 'IWM', 'EFA', 'XLK', 'XLV', 'TLT', 'LQD', 'XLE', 'TQQQ', 'SQQQ', 'SPXS', 'SPXL', 'SOXL', 'SOXS', 'MMM', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 
                   'AAP', 'AFL', 'ALB', 'ALGN', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMD', 'AAL', 'AXP', 'AIG', 'ABC', 'AMGN', 'ADI', 'APA', 'AAPL', 'AMAT', 'ANET', 'T', 'ADSK', 'BAC', 'BBWI', 'BAX', 'BBY', 'BIIB', 
                   'BLK', 'BA', 'BKNG', 'BMY', 'AVGO', 'CZR', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CAT', 'CBOE', 'CNC', 'CF', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CI', 'CSCO', 'C', 'CLX', 'CME', 'KO', 'CMCSA', 'CMA', 'CAG', 
                   'COP', 'STZ', 'GLW', 'COST', 'CTRA', 'CSX', 'CVS', 'DHI', 'DHR', 'DE', 'DAL', 'DVN', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'DPZ', 'DOW', 'DD', 'EBAY', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'EOG', 'EQT', 
                   'ETSY', 'EXPE', 'XOM', 'FDX', 'FITB', 'FSLR', 'FI', 'F', 'FTNT', 'FOXA', 'FCX', 'GEHC', 'GNRC', 'GD', 'GE', 'GM', 'GILD', 'GS', 'HAL', 'HSY', 'HES', 'HD', 'HON', 'HRL', 'HPQ', 'HUM', 'HBAN', 'IBM', 'ILMN', 
                   'INTC', 'IP', 'INTU', 'ISRG', 'JNJ', 'JPM', 'JNPR', 'KEY', 'KMB', 'KMI', 'KLAC', 'KHC', 'KR', 'LRCX', 'LVS', 'LEN', 'LMT', 'LOW', 'MRO', 'MPC', 'MAR', 'MA', 'MTCH', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 
                   'MGM', 'MU', 'MSFT', 'MRNA', 'MDLZ', 'MS', 'MOS', 'NTAP', 'NFLX', 'NEM', 'NKE', 'NSC', 'NOC', 'NCLH', 'NUE', 'NVDA', 'NXPI', 'OXY', 'ON', 'ORCL', 'PARA', 'PYPL', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PXD', 'PNC', 
                   'PPG', 'PG', 'PHM', 'QCOM', 'RTX', 'REGN', 'ROST', 'RCL', 'SPGI', 'CRM', 'SLB', 'STX', 'NOW', 'SWKS', 'SEDG', 'SO', 'LUV', 'SBUX', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TGT', 'TSLA', 'TXN', 'TMO', 'TJX', 'TSCO', 'TFC', 
                   'TSN', 'USB', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'VLO', 'VZ', 'VRTX', 'VFC', 'V', 'WBA', 'WMT', 'WBD', 'WM', 'WFC', 'WDC', 'WHR', 'WMB', 'WYNN', 'ZION']

leveraged_etfs = ["TQQQ","SQQQ","SPXS","SPXL","SOXL","SOXS"]
high_vol = ['COIN','BILI','UPST','CVNA',"TQQQ","SQQQ","SPXS","SPXL","SOXL","SOXS","NIO","BABA","ROKU","RBLX","SE","SNAP","LCID",'RIVN',"BIDU","FUTU","TSLA","JD","HOOD","CHWY"]
expensive = ["CMG","NFLX","AVGO","BKNG","ABNB"]
indexes = ['QQQ','IWM','TLT','VXX','SPY']

# %%
def pull_training_data_local(end_date, start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/BF/2018-01-01_2023-12-23BF3CDVOLP.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data['one_max_vol'] = (data['one_max']/data['return_vol_10D']).round(3)
    data['three_max_vol'] = (data['three_max']/data['return_vol_10D']).round(3)
    data['one_min_vol'] = (data['one_min']/data['return_vol_10D']).round(3)
    data['three_min_vol'] = (data['three_min']/data['return_vol_10D']).round(3)    
    data['one_max_vol30'] = (data['one_max']/data['return_vol_30D']).round(3)
    data['three_max_vol30'] = (data['three_max']/data['return_vol_30D']).round(3)
    data['one_min_vol30'] = (data['one_min']/data['return_vol_30D']).round(3)
    data['three_min_vol30'] = (data['three_min']/data['return_vol_30D']).round(3)    
    data['cd_vol'] = (data['close_diff']/data['return_vol_10D']).round(3)
    data['cd_vol3'] = (data['close_diff3']/data['return_vol_10D']).round(3)
    data['cd_vol30'] = (data['close_diff']/data['return_vol_30D']).round(3)
    data['cd_vol330'] = (data['close_diff3']/data['return_vol_30D']).round(3)
    data['volatility_3D_30D_ratio'] = (data['return_vol_3D']/data['return_vol_30D'])/data['volume_vol_30D']
    data['close_25MA_divergence'] = (data['c'] - data['price_25MA'])/data['price_25MA']
    # data = data.loc[data['symbol'].isin(bf2)]
    data.replace([np.inf, -np.inf], 0, inplace=True)

    return data


def pull_validation_data_local(end_date,start_date):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/BF/2018-01-01_2023-12-23BF3CDVOLP.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data['one_max_vol'] = (data['one_max']/data['return_vol_10D']).round(3)
    data['three_max_vol'] = (data['three_max']/data['return_vol_10D']).round(3)
    data['one_min_vol'] = (data['one_min']/data['return_vol_10D']).round(3)
    data['three_min_vol'] = (data['three_min']/data['return_vol_10D']).round(3)    
    data['one_max_vol30'] = (data['one_max']/data['return_vol_30D']).round(3)
    data['three_max_vol30'] = (data['three_max']/data['return_vol_30D']).round(3)
    data['one_min_vol30'] = (data['one_min']/data['return_vol_30D']).round(3)
    data['three_min_vol30'] = (data['three_min']/data['return_vol_30D']).round(3)    
    data['cd_vol'] = (data['close_diff']/data['return_vol_10D']).round(3)
    data['cd_vol3'] = (data['close_diff3']/data['return_vol_10D']).round(3)
    data['cd_vol30'] = (data['close_diff']/data['return_vol_30D']).round(3)
    data['cd_vol330'] = (data['close_diff3']/data['return_vol_30D']).round(3)
    data = data.loc[data['dt'] <= end_date]
    data = data.loc[data['dt'] >= start_date]
    # data = data.loc[data['symbol'].isin(bf2)]
    data.replace([np.inf, -np.inf], 0, inplace=True)
    return data

# %%
def build_date_list(start_date, end_date):
    print(start_date, end_date)
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_validation_dates_local(deployment_date):
    end_date = deployment_date + timedelta(days=5)
    return end_date

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] <  target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] <  target_value).astype(int)

    # dataset = dataset.round(3)
    # validation_dataset = validation_dataset.round(3)

    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']


    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    print(y.value_counts())
    predictions = xgb_model.predict(X_validate)
    probabilities = xgb_model.predict_proba(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,str(fi_list), predictions, probabilities


def train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] < target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] < target_value).astype(int)

    # dataset = dataset.round(5)
    # validation_dataset = validation_dataset.round(3)


    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']

    

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,"str(fi_list)", predictions, "probabilities"

# %%
def model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile, start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
    validation_end_date = build_validation_dates_local(deployment_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    target_value = dataset[target_label].quantile(target_percentile).round(3)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
    validation_dataset['probabilities'] = probabilities[:,1]
    validation_dataset['predictions'] = predictions
    validation_dataset['target_value'] = target_value
    validation_dataset['target_pct'] = validation_dataset['target_value'] * validation_dataset['return_vol_10D']
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    return response

def model_runner_temporal_simulation(features, target_label, target_vol,dataset_start_date,end_date,deployment_date,hyperparams):
    validation_end_date = build_validation_dates_local(deployment_date)
    dataset = pull_training_data_local(end_date, dataset_start_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
    dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model_TSSim(features, dataset, validation_dataset, target_label, target_vol, hyperparams)
    return tp, fp, fn, tn 

def model_runner_data(start_date,end_date):
    dates = build_date_list(start_date, end_date)
    key_list = build_query_keys(dates)
    print(key_list[-1])
    train_data = create_training_data_local(key_list, 'full_alerts/weekly_exp_alerts/', 'inv-alerts', 'cdvol_losers', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
    val_data = create_validation_data_local(key_list, 'full_alerts/trading_symbols_alerts/', 'inv-alerts', 'cdvol_losers', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
    return "train_data", "val_data"

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=10),
            "dataset_start": datetime(2018,1,1)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

# %%
title = 'CDVOLDIFFP_1D'
target_percentile = 0.5
# target_vol = -.85
model_name = f'{title}:BF3_CDVOL_custHypTP{target_percentile}'
dataset_name = f'BF3_CDVOL_custHypTP{target_percentile}'
hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
features = ['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 
            'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 
            'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 
            'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 
            'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']

target_label = 'one_min_vol'

dataset_start_date = datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')) 
dates_list = build_evaluation_period(datetime(2022,10,3), datetime(2023,12,23))

# date = dates_list[-1]
# print(date)
# response = model_runner_data(start_date=datetime(2018,1,1),end_date=datetime(2023,12,23))

# dataset = pull_training_data_local(start_date=datetime(2018,1,1),end_date=datetime(2023,12,23))
# print(dataset['one_min_vol'].describe())

for date in dates_list:
    print(date)
    response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile, "dataset_start_date",date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])
# Out:
# {'deployment_date': datetime.datetime(2022, 10, 3, 0, 0), 'dataset_end': datetime.datetime(2022, 9, 23, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    28439
# 1    28401
# Name: count, dtype: int64
# 77 40 55 147
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2022-10-03', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 77, 'TPpct': Decimal('0'), 'FP': 40, 'FPpct': Decimal('0'), 'TN': 55, 'TNpct': Decimal('0'), 'FN': 147, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.925'), 'evaluation_timeperiod': '2022-10-03_2022-10-07', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.019+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024189394}, {'day_of_week': 0.029118216}, {'return_vol_5D': 0.025196746}, {'hour_volume_vol_diff': 0.022030436}, {'return_vol_240M': 0.022739526}, {'volume_vol_8H': 0.021138955}, {'range_vol_diff5': 0.025754942}, {'return_vol_30M': 0.02382985}, {'daily_volume_vol_diff30': 0.023299476}, {'close_diff': 0.023571068}, {'volume_vol_15M': 0.019501487}, {'return_vol_10D': 0.030531488}, {'daily_vol_diff_pct': 0.028622437}, {'daily_volume_vol_diff_pct30': 0.022916453}, {'range_vol5MA': 0.026127858}, {'cmf': 0.023837864}, {'return_vol_450M': 0.026958227}, {'hour_volume_vol_diff_pct': 0.022341786}, {'min_vol_diff': 0.020916384}, {'price_25DDiff': 0.025360001}, {'return_vol_3D': 0.02444805}, {'daily_vol_diff_pct30': 0.024242941}, {'volume_vol_3D': 0.0210848}, {'volume_vol_450M': 0.022347925}, {'close_diff_deviation': 0.02380481}, {'return_vol_30D': 0.026872663}, {'close_diff_deviation3': 0.023133162}, {'return_vol_16H': 0.024684278}, {'volume_vol_30M': 0.018450048}, {'rsi': 0.02420461}, {'threeD_stddev50': 0.02508232}, {'close_diff5': 0.028123518}, {'range_vol10MA': 0.02729922}, {'SPY_5D': 0.031312913}, {'daily_vol_diff': 0.048615325}, {'SPY_diff3': 0.024303082}, {'volume_vol_5D': 0.022726566}, {'rsi3': 0.024512077}, {'volume_25DDiff': 0.021683687}, {'price7': 0.025085447}]"}
# {'deployment_date': datetime.datetime(2022, 10, 10, 0, 0), 'dataset_end': datetime.datetime(2022, 9, 30, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    28588
# 1    28559
# Name: count, dtype: int64
# 52 74 158 53
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2022-10-10', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 52, 'TPpct': Decimal('0'), 'FP': 74, 'FPpct': Decimal('0'), 'TN': 158, 'TNpct': Decimal('0'), 'FN': 53, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.7027027027027027'), 'evaluation_timeperiod': '2022-10-10_2022-10-14', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.018+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.02525223}, {'day_of_week': 0.028775271}, {'return_vol_5D': 0.025029043}, {'hour_volume_vol_diff': 0.022114966}, {'return_vol_240M': 0.022888627}, {'volume_vol_8H': 0.021895217}, {'range_vol_diff5': 0.025461873}, {'return_vol_30M': 0.024034664}, {'daily_volume_vol_diff30': 0.02259859}, {'close_diff': 0.02381026}, {'volume_vol_15M': 0.018807946}, {'return_vol_10D': 0.030030442}, {'daily_vol_diff_pct': 0.028915735}, {'daily_volume_vol_diff_pct30': 0.02139103}, {'range_vol5MA': 0.027150141}, {'cmf': 0.024127739}, {'return_vol_450M': 0.027270872}, {'hour_volume_vol_diff_pct': 0.024251318}, {'min_vol_diff': 0.020697273}, {'price_25DDiff': 0.024948537}, {'return_vol_3D': 0.022843456}, {'daily_vol_diff_pct30': 0.02402798}, {'volume_vol_3D': 0.021420846}, {'volume_vol_450M': 0.021645147}, {'close_diff_deviation': 0.024159256}, {'return_vol_30D': 0.02534182}, {'close_diff_deviation3': 0.024775233}, {'return_vol_16H': 0.024058782}, {'volume_vol_30M': 0.019255115}, {'rsi': 0.024911253}, {'threeD_stddev50': 0.024821136}, {'close_diff5': 0.028725944}, {'range_vol10MA': 0.02606397}, {'SPY_5D': 0.031230541}, {'daily_vol_diff': 0.046374865}, {'SPY_diff3': 0.024274873}, {'volume_vol_5D': 0.022719078}, {'rsi3': 0.026449075}, {'volume_25DDiff': 0.02166495}, {'price7': 0.025784882}]"}
# {'deployment_date': datetime.datetime(2022, 10, 17, 0, 0), 'dataset_end': datetime.datetime(2022, 10, 7, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    28744
# 1    28722
# Name: count, dtype: int64
# 5 40 43 15
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2022-10-17', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 5, 'TPpct': Decimal('0'), 'FP': 40, 'FPpct': Decimal('0'), 'TN': 43, 'TNpct': Decimal('0'), 'FN': 15, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.125'), 'evaluation_timeperiod': '2022-10-17_2022-10-21', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.021+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.025187489}, {'day_of_week': 0.030955326}, {'return_vol_5D': 0.025094798}, {'hour_volume_vol_diff': 0.021741677}, {'return_vol_240M': 0.023020778}, {'volume_vol_8H': 0.02151397}, {'range_vol_diff5': 0.025473168}, {'return_vol_30M': 0.02326772}, {'daily_volume_vol_diff30': 0.024029775}, {'close_diff': 0.025081415}, {'volume_vol_15M': 0.017687568}, {'return_vol_10D': 0.03066061}, {'daily_vol_diff_pct': 0.02828304}, {'daily_volume_vol_diff_pct30': 0.020792294}, {'range_vol5MA': 0.026813239}, {'cmf': 0.023676518}, {'return_vol_450M': 0.028064338}, {'hour_volume_vol_diff_pct': 0.023776768}, {'min_vol_diff': 0.020493267}, {'price_25DDiff': 0.023693992}, {'return_vol_3D': 0.023713283}, {'daily_vol_diff_pct30': 0.025220796}, {'volume_vol_3D': 0.019898456}, {'volume_vol_450M': 0.023408588}, {'close_diff_deviation': 0.024628209}, {'return_vol_30D': 0.02666035}, {'close_diff_deviation3': 0.02411007}, {'return_vol_16H': 0.022724599}, {'volume_vol_30M': 0.018773811}, {'rsi': 0.023851788}, {'threeD_stddev50': 0.024873646}, {'close_diff5': 0.02796259}, {'range_vol10MA': 0.025868231}, {'SPY_5D': 0.03184145}, {'daily_vol_diff': 0.04701181}, {'SPY_diff3': 0.02384198}, {'volume_vol_5D': 0.023910398}, {'rsi3': 0.025712568}, {'volume_25DDiff': 0.021569928}, {'price7': 0.025109716}]"}
# {'deployment_date': datetime.datetime(2022, 10, 24, 0, 0), 'dataset_end': datetime.datetime(2022, 10, 14, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    28915
# 1    28888
# Name: count, dtype: int64
# 50 41 49 23
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2022-10-24', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 50, 'TPpct': Decimal('0'), 'FP': 41, 'FPpct': Decimal('0'), 'TN': 49, 'TNpct': Decimal('0'), 'FN': 23, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.2195121951219512'), 'evaluation_timeperiod': '2022-10-24_2022-10-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.018+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024279641}, {'day_of_week': 0.031121835}, {'return_vol_5D': 0.023875048}, {'hour_volume_vol_diff': 0.021088483}, {'return_vol_240M': 0.022791445}, {'volume_vol_8H': 0.021712575}, {'range_vol_diff5': 0.025923863}, {'return_vol_30M': 0.024642589}, {'daily_volume_vol_diff30': 0.02234825}, {'close_diff': 0.02323354}, {'volume_vol_15M': 0.018590493}, {'return_vol_10D': 0.02972838}, {'daily_vol_diff_pct': 0.029295262}, {'daily_volume_vol_diff_pct30': 0.02220106}, {'range_vol5MA': 0.025526486}, {'cmf': 0.024048688}, {'return_vol_450M': 0.027910855}, {'hour_volume_vol_diff_pct': 0.022493051}, {'min_vol_diff': 0.020933788}, {'price_25DDiff': 0.02487423}, {'return_vol_3D': 0.02254046}, {'daily_vol_diff_pct30': 0.024076954}, {'volume_vol_3D': 0.021206083}, {'volume_vol_450M': 0.022634054}, {'close_diff_deviation': 0.025089756}, {'return_vol_30D': 0.026036851}, {'close_diff_deviation3': 0.02467889}, {'return_vol_16H': 0.024358679}, {'volume_vol_30M': 0.01957589}, {'rsi': 0.024684895}, {'threeD_stddev50': 0.025752516}, {'close_diff5': 0.027035847}, {'range_vol10MA': 0.025704838}, {'SPY_5D': 0.032361098}, {'daily_vol_diff': 0.047084067}, {'SPY_diff3': 0.023986803}, {'volume_vol_5D': 0.02220684}, {'rsi3': 0.025847774}, {'volume_25DDiff': 0.022704564}, {'price7': 0.02581358}]"}
# {'deployment_date': datetime.datetime(2022, 10, 31, 0, 0), 'dataset_end': datetime.datetime(2022, 10, 21, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    28970
# 1    28936
# Name: count, dtype: int64
# 93 66 50 73
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2022-10-31', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 93, 'TPpct': Decimal('0'), 'FP': 66, 'FPpct': Decimal('0'), 'TN': 50, 'TNpct': Decimal('0'), 'FN': 73, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.4090909090909092'), 'evaluation_timeperiod': '2022-10-31_2022-11-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.016+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.02538998}, {'day_of_week': 0.030146027}, {'return_vol_5D': 0.02370417}, {'hour_volume_vol_diff': 0.022724286}, {'return_vol_240M': 0.023261677}, {'volume_vol_8H': 0.02134823}, {'range_vol_diff5': 0.026122471}, {'return_vol_30M': 0.023399806}, {'daily_volume_vol_diff30': 0.023297863}, {'close_diff': 0.023411283}, {'volume_vol_15M': 0.018491626}, {'return_vol_10D': 0.028402021}, {'daily_vol_diff_pct': 0.028246092}, {'daily_volume_vol_diff_pct30': 0.021675391}, {'range_vol5MA': 0.026219884}, {'cmf': 0.023676936}, {'return_vol_450M': 0.02743868}, {'hour_volume_vol_diff_pct': 0.022149265}, {'min_vol_diff': 0.020982848}, {'price_25DDiff': 0.025529718}, {'return_vol_3D': 0.022279069}, {'daily_vol_diff_pct30': 0.024474425}, {'volume_vol_3D': 0.022901028}, {'volume_vol_450M': 0.02227541}, {'close_diff_deviation': 0.02377055}, {'return_vol_30D': 0.026345603}, {'close_diff_deviation3': 0.024421535}, {'return_vol_16H': 0.023193248}, {'volume_vol_30M': 0.01890613}, {'rsi': 0.02374532}, {'threeD_stddev50': 0.025537577}, {'close_diff5': 0.027710445}, {'range_vol10MA': 0.025772326}, {'SPY_5D': 0.031796347}, {'daily_vol_diff': 0.048642494}, {'SPY_diff3': 0.024667371}, {'volume_vol_5D': 0.02279417}, {'rsi3': 0.027106788}, {'volume_25DDiff': 0.022354826}, {'price7': 0.025687113}]"}
# {'deployment_date': datetime.datetime(2022, 11, 7, 0, 0), 'dataset_end': datetime.datetime(2022, 10, 28, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    29060
# 1    29009
# Name: count, dtype: int64
# 33 78 64 25
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2022-11-07', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 33, 'TPpct': Decimal('0'), 'FP': 78, 'FPpct': Decimal('0'), 'TN': 64, 'TNpct': Decimal('0'), 'FN': 25, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.4230769230769231'), 'evaluation_timeperiod': '2022-11-07_2022-11-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.016+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024289656}, {'day_of_week': 0.031366374}, {'return_vol_5D': 0.023955164}, {'hour_volume_vol_diff': 0.023299102}, {'return_vol_240M': 0.022579946}, {'volume_vol_8H': 0.020790162}, {'range_vol_diff5': 0.025731858}, {'return_vol_30M': 0.024454933}, {'daily_volume_vol_diff30': 0.023192525}, {'close_diff': 0.023605479}, {'volume_vol_15M': 0.017897189}, {'return_vol_10D': 0.030307425}, {'daily_vol_diff_pct': 0.028259154}, {'daily_volume_vol_diff_pct30': 0.022689387}, {'range_vol5MA': 0.026703188}, {'cmf': 0.023687443}, {'return_vol_450M': 0.027133115}, {'hour_volume_vol_diff_pct': 0.0225133}, {'min_vol_diff': 0.021014465}, {'price_25DDiff': 0.024894457}, {'return_vol_3D': 0.022481555}, {'daily_vol_diff_pct30': 0.023690397}, {'volume_vol_3D': 0.021712884}, {'volume_vol_450M': 0.023378674}, {'close_diff_deviation': 0.024185797}, {'return_vol_30D': 0.025295742}, {'close_diff_deviation3': 0.024807468}, {'return_vol_16H': 0.024332631}, {'volume_vol_30M': 0.018661495}, {'rsi': 0.023778534}, {'threeD_stddev50': 0.025306024}, {'close_diff5': 0.027846942}, {'range_vol10MA': 0.02565396}, {'SPY_5D': 0.032010626}, {'daily_vol_diff': 0.0481614}, {'SPY_diff3': 0.02371181}, {'volume_vol_5D': 0.023584744}, {'rsi3': 0.025332639}, {'volume_25DDiff': 0.021899069}, {'price7': 0.025803268}]"}
# {'deployment_date': datetime.datetime(2022, 11, 14, 0, 0), 'dataset_end': datetime.datetime(2022, 11, 4, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    29176
# 1    29175
# Name: count, dtype: int64
# 32 26 91 89
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2022-11-14', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 32, 'TPpct': Decimal('0'), 'FP': 26, 'FPpct': Decimal('0'), 'TN': 91, 'TNpct': Decimal('0'), 'FN': 89, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.2307692307692308'), 'evaluation_timeperiod': '2022-11-14_2022-11-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.016+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.025164077}, {'day_of_week': 0.030425781}, {'return_vol_5D': 0.025633786}, {'hour_volume_vol_diff': 0.022762166}, {'return_vol_240M': 0.022662308}, {'volume_vol_8H': 0.021107242}, {'range_vol_diff5': 0.025806783}, {'return_vol_30M': 0.023910746}, {'daily_volume_vol_diff30': 0.023941461}, {'close_diff': 0.023569282}, {'volume_vol_15M': 0.018793}, {'return_vol_10D': 0.030843658}, {'daily_vol_diff_pct': 0.028746806}, {'daily_volume_vol_diff_pct30': 0.021193927}, {'range_vol5MA': 0.025399888}, {'cmf': 0.023683138}, {'return_vol_450M': 0.028034769}, {'hour_volume_vol_diff_pct': 0.023162812}, {'min_vol_diff': 0.019850949}, {'price_25DDiff': 0.025300715}, {'return_vol_3D': 0.021659445}, {'daily_vol_diff_pct30': 0.025008684}, {'volume_vol_3D': 0.022524241}, {'volume_vol_450M': 0.022205442}, {'close_diff_deviation': 0.024742665}, {'return_vol_30D': 0.025553886}, {'close_diff_deviation3': 0.024313865}, {'return_vol_16H': 0.024048315}, {'volume_vol_30M': 0.018878758}, {'rsi': 0.024347888}, {'threeD_stddev50': 0.025665006}, {'close_diff5': 0.026732435}, {'range_vol10MA': 0.025274936}, {'SPY_5D': 0.031385202}, {'daily_vol_diff': 0.04614525}, {'SPY_diff3': 0.02565754}, {'volume_vol_5D': 0.022135254}, {'rsi3': 0.026271047}, {'volume_25DDiff': 0.021531098}, {'price7': 0.025925705}]"}
# {'deployment_date': datetime.datetime(2022, 11, 21, 0, 0), 'dataset_end': datetime.datetime(2022, 11, 11, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    29291
# 1    29260
# Name: count, dtype: int64
# 2 16 94 31
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2022-11-21', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 2, 'TPpct': Decimal('0'), 'FP': 16, 'FPpct': Decimal('0'), 'TN': 94, 'TNpct': Decimal('0'), 'FN': 31, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.125'), 'evaluation_timeperiod': '2022-11-21_2022-11-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.015+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024519434}, {'day_of_week': 0.031041887}, {'return_vol_5D': 0.024183394}, {'hour_volume_vol_diff': 0.023181709}, {'return_vol_240M': 0.022553736}, {'volume_vol_8H': 0.021552356}, {'range_vol_diff5': 0.024997456}, {'return_vol_30M': 0.02736304}, {'daily_volume_vol_diff30': 0.022391878}, {'close_diff': 0.023840975}, {'volume_vol_15M': 0.018756688}, {'return_vol_10D': 0.0283276}, {'daily_vol_diff_pct': 0.027898435}, {'daily_volume_vol_diff_pct30': 0.022503503}, {'range_vol5MA': 0.026206046}, {'cmf': 0.023432538}, {'return_vol_450M': 0.027897656}, {'hour_volume_vol_diff_pct': 0.022695437}, {'min_vol_diff': 0.020970583}, {'price_25DDiff': 0.02471488}, {'return_vol_3D': 0.023180941}, {'daily_vol_diff_pct30': 0.023677826}, {'volume_vol_3D': 0.02231312}, {'volume_vol_450M': 0.02247992}, {'close_diff_deviation': 0.025386056}, {'return_vol_30D': 0.02674404}, {'close_diff_deviation3': 0.022942184}, {'return_vol_16H': 0.023772417}, {'volume_vol_30M': 0.018239306}, {'rsi': 0.024322016}, {'threeD_stddev50': 0.02605288}, {'close_diff5': 0.027239826}, {'range_vol10MA': 0.025554668}, {'SPY_5D': 0.030736724}, {'daily_vol_diff': 0.045791693}, {'SPY_diff3': 0.024203837}, {'volume_vol_5D': 0.02270927}, {'rsi3': 0.025999423}, {'volume_25DDiff': 0.023204654}, {'price7': 0.026419934}]"}
# {'deployment_date': datetime.datetime(2022, 11, 28, 0, 0), 'dataset_end': datetime.datetime(2022, 11, 18, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    29408
# 1    29381
# Name: count, dtype: int64
# 101 36 105 143
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2022-11-28', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 101, 'TPpct': Decimal('0'), 'FP': 36, 'FPpct': Decimal('0'), 'TN': 105, 'TNpct': Decimal('0'), 'FN': 143, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.8055555555555554'), 'evaluation_timeperiod': '2022-11-28_2022-12-02', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.015+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.02500379}, {'day_of_week': 0.030953234}, {'return_vol_5D': 0.024707962}, {'hour_volume_vol_diff': 0.021992086}, {'return_vol_240M': 0.022950897}, {'volume_vol_8H': 0.021591302}, {'range_vol_diff5': 0.025462536}, {'return_vol_30M': 0.025182754}, {'daily_volume_vol_diff30': 0.023960793}, {'close_diff': 0.023737708}, {'volume_vol_15M': 0.019128291}, {'return_vol_10D': 0.030308673}, {'daily_vol_diff_pct': 0.028271014}, {'daily_volume_vol_diff_pct30': 0.021363867}, {'range_vol5MA': 0.024526564}, {'cmf': 0.024354525}, {'return_vol_450M': 0.028028265}, {'hour_volume_vol_diff_pct': 0.023247011}, {'min_vol_diff': 0.020187307}, {'price_25DDiff': 0.025346514}, {'return_vol_3D': 0.022808962}, {'daily_vol_diff_pct30': 0.024588272}, {'volume_vol_3D': 0.021576993}, {'volume_vol_450M': 0.022582887}, {'close_diff_deviation': 0.023894535}, {'return_vol_30D': 0.026253428}, {'close_diff_deviation3': 0.024385145}, {'return_vol_16H': 0.023328219}, {'volume_vol_30M': 0.017105548}, {'rsi': 0.024279749}, {'threeD_stddev50': 0.026279816}, {'close_diff5': 0.027733563}, {'range_vol10MA': 0.02525851}, {'SPY_5D': 0.031149369}, {'daily_vol_diff': 0.04915409}, {'SPY_diff3': 0.023708114}, {'volume_vol_5D': 0.022796849}, {'rsi3': 0.025546445}, {'volume_25DDiff': 0.021823552}, {'price7': 0.025440916}]"}
# {'deployment_date': datetime.datetime(2022, 12, 5, 0, 0), 'dataset_end': datetime.datetime(2022, 11, 25, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    29467
# 1    29465
# Name: count, dtype: int64
# 86 77 80 140
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2022-12-05', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 86, 'TPpct': Decimal('0'), 'FP': 77, 'FPpct': Decimal('0'), 'TN': 80, 'TNpct': Decimal('0'), 'FN': 140, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.1168831168831168'), 'evaluation_timeperiod': '2022-12-05_2022-12-09', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.012+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024321606}, {'day_of_week': 0.031330813}, {'return_vol_5D': 0.023012776}, {'hour_volume_vol_diff': 0.022312267}, {'return_vol_240M': 0.022456238}, {'volume_vol_8H': 0.02097924}, {'range_vol_diff5': 0.024961963}, {'return_vol_30M': 0.023530561}, {'daily_volume_vol_diff30': 0.023649115}, {'close_diff': 0.023699665}, {'volume_vol_15M': 0.018260341}, {'return_vol_10D': 0.029789308}, {'daily_vol_diff_pct': 0.027946068}, {'daily_volume_vol_diff_pct30': 0.02174769}, {'range_vol5MA': 0.02541807}, {'cmf': 0.02315879}, {'return_vol_450M': 0.02740832}, {'hour_volume_vol_diff_pct': 0.022524193}, {'min_vol_diff': 0.02020101}, {'price_25DDiff': 0.024686616}, {'return_vol_3D': 0.02387617}, {'daily_vol_diff_pct30': 0.024631701}, {'volume_vol_3D': 0.021747591}, {'volume_vol_450M': 0.022993052}, {'close_diff_deviation': 0.025225587}, {'return_vol_30D': 0.026589328}, {'close_diff_deviation3': 0.02403311}, {'return_vol_16H': 0.024120806}, {'volume_vol_30M': 0.018951505}, {'rsi': 0.024083905}, {'threeD_stddev50': 0.025386639}, {'close_diff5': 0.027829645}, {'range_vol10MA': 0.027277712}, {'SPY_5D': 0.031005375}, {'daily_vol_diff': 0.048342593}, {'SPY_diff3': 0.023934104}, {'volume_vol_5D': 0.022590438}, {'rsi3': 0.027516795}, {'volume_25DDiff': 0.023095455}, {'price7': 0.025373783}]"}
# {'deployment_date': datetime.datetime(2022, 12, 12, 0, 0), 'dataset_end': datetime.datetime(2022, 12, 2, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    29659
# 1    29658
# Name: count, dtype: int64
# 214 88 35 39
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2022-12-12', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 214, 'TPpct': Decimal('0'), 'FP': 88, 'FPpct': Decimal('0'), 'TN': 35, 'TNpct': Decimal('0'), 'FN': 39, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.4318181818181817'), 'evaluation_timeperiod': '2022-12-12_2022-12-16', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.015+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024619736}, {'day_of_week': 0.031284213}, {'return_vol_5D': 0.023787005}, {'hour_volume_vol_diff': 0.022937924}, {'return_vol_240M': 0.022481322}, {'volume_vol_8H': 0.021516867}, {'range_vol_diff5': 0.024433598}, {'return_vol_30M': 0.023864133}, {'daily_volume_vol_diff30': 0.023590948}, {'close_diff': 0.024986282}, {'volume_vol_15M': 0.018458528}, {'return_vol_10D': 0.029577466}, {'daily_vol_diff_pct': 0.027682014}, {'daily_volume_vol_diff_pct30': 0.02166217}, {'range_vol5MA': 0.025874736}, {'cmf': 0.024864923}, {'return_vol_450M': 0.025774648}, {'hour_volume_vol_diff_pct': 0.022142008}, {'min_vol_diff': 0.02124579}, {'price_25DDiff': 0.025633596}, {'return_vol_3D': 0.02314076}, {'daily_vol_diff_pct30': 0.025133053}, {'volume_vol_3D': 0.022562653}, {'volume_vol_450M': 0.022720482}, {'close_diff_deviation': 0.024488095}, {'return_vol_30D': 0.026036803}, {'close_diff_deviation3': 0.024681585}, {'return_vol_16H': 0.023081256}, {'volume_vol_30M': 0.018785192}, {'rsi': 0.02481155}, {'threeD_stddev50': 0.025704702}, {'close_diff5': 0.026799092}, {'range_vol10MA': 0.026885772}, {'SPY_5D': 0.03225693}, {'daily_vol_diff': 0.046314273}, {'SPY_diff3': 0.024556879}, {'volume_vol_5D': 0.022413699}, {'rsi3': 0.02601854}, {'volume_25DDiff': 0.022238392}, {'price7': 0.024952414}]"}
# {'deployment_date': datetime.datetime(2022, 12, 19, 0, 0), 'dataset_end': datetime.datetime(2022, 12, 9, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    29857
# 1    29843
# Name: count, dtype: int64
# 56 170 89 30
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2022-12-19', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 56, 'TPpct': Decimal('0'), 'FP': 170, 'FPpct': Decimal('0'), 'TN': 89, 'TNpct': Decimal('0'), 'FN': 30, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.32941176470588235'), 'evaluation_timeperiod': '2022-12-19_2022-12-23', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.017+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024417097}, {'day_of_week': 0.02992932}, {'return_vol_5D': 0.023387974}, {'hour_volume_vol_diff': 0.022620052}, {'return_vol_240M': 0.023835443}, {'volume_vol_8H': 0.02148841}, {'range_vol_diff5': 0.025340533}, {'return_vol_30M': 0.023774104}, {'daily_volume_vol_diff30': 0.025045795}, {'close_diff': 0.02306097}, {'volume_vol_15M': 0.018283216}, {'return_vol_10D': 0.0314109}, {'daily_vol_diff_pct': 0.028512262}, {'daily_volume_vol_diff_pct30': 0.022416327}, {'range_vol5MA': 0.026664117}, {'cmf': 0.024038093}, {'return_vol_450M': 0.028800758}, {'hour_volume_vol_diff_pct': 0.023113236}, {'min_vol_diff': 0.021562222}, {'price_25DDiff': 0.024415608}, {'return_vol_3D': 0.022447987}, {'daily_vol_diff_pct30': 0.024683507}, {'volume_vol_3D': 0.020975396}, {'volume_vol_450M': 0.02209494}, {'close_diff_deviation': 0.02456853}, {'return_vol_30D': 0.026143212}, {'close_diff_deviation3': 0.024939056}, {'return_vol_16H': 0.02360727}, {'volume_vol_30M': 0.018842375}, {'rsi': 0.024146043}, {'threeD_stddev50': 0.02558472}, {'close_diff5': 0.027394947}, {'range_vol10MA': 0.026232785}, {'SPY_5D': 0.031013576}, {'daily_vol_diff': 0.04465839}, {'SPY_diff3': 0.023686001}, {'volume_vol_5D': 0.023189345}, {'rsi3': 0.026682058}, {'volume_25DDiff': 0.0218916}, {'price7': 0.025101854}]"}
# {'deployment_date': datetime.datetime(2022, 12, 26, 0, 0), 'dataset_end': datetime.datetime(2022, 12, 16, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    30042
# 1    30034
# Name: count, dtype: int64
# 27 143 55 27
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2022-12-26', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 27, 'TPpct': Decimal('0'), 'FP': 143, 'FPpct': Decimal('0'), 'TN': 55, 'TNpct': Decimal('0'), 'FN': 27, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.1888111888111888'), 'evaluation_timeperiod': '2022-12-26_2022-12-30', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.02+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024163054}, {'day_of_week': 0.030950638}, {'return_vol_5D': 0.024330713}, {'hour_volume_vol_diff': 0.0219707}, {'return_vol_240M': 0.023928018}, {'volume_vol_8H': 0.022442795}, {'range_vol_diff5': 0.025115054}, {'return_vol_30M': 0.025088592}, {'daily_volume_vol_diff30': 0.024029775}, {'close_diff': 0.022677835}, {'volume_vol_15M': 0.017438969}, {'return_vol_10D': 0.030850403}, {'daily_vol_diff_pct': 0.028012913}, {'daily_volume_vol_diff_pct30': 0.022606472}, {'range_vol5MA': 0.025808793}, {'cmf': 0.023877153}, {'return_vol_450M': 0.027692707}, {'hour_volume_vol_diff_pct': 0.022501927}, {'min_vol_diff': 0.021419222}, {'price_25DDiff': 0.024941172}, {'return_vol_3D': 0.022035632}, {'daily_vol_diff_pct30': 0.024650667}, {'volume_vol_3D': 0.02179899}, {'volume_vol_450M': 0.02274315}, {'close_diff_deviation': 0.023391495}, {'return_vol_30D': 0.02638882}, {'close_diff_deviation3': 0.023764791}, {'return_vol_16H': 0.024302844}, {'volume_vol_30M': 0.018445179}, {'rsi': 0.023775028}, {'threeD_stddev50': 0.025600698}, {'close_diff5': 0.027694374}, {'range_vol10MA': 0.026336705}, {'SPY_5D': 0.031452976}, {'daily_vol_diff': 0.048844974}, {'SPY_diff3': 0.024192829}, {'volume_vol_5D': 0.02247287}, {'rsi3': 0.025675327}, {'volume_25DDiff': 0.021647984}, {'price7': 0.0249378}]"}
# {'deployment_date': datetime.datetime(2023, 1, 2, 0, 0), 'dataset_end': datetime.datetime(2022, 12, 23, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    30227
# 1    30194
# Name: count, dtype: int64
# 48 111 19 37
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2023-01-02', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 48, 'TPpct': Decimal('0'), 'FP': 111, 'FPpct': Decimal('0'), 'TN': 19, 'TNpct': Decimal('0'), 'FN': 37, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.43243243243243246'), 'evaluation_timeperiod': '2023-01-02_2023-01-06', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.016+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.02510816}, {'day_of_week': 0.030965261}, {'return_vol_5D': 0.02468333}, {'hour_volume_vol_diff': 0.022528445}, {'return_vol_240M': 0.02340234}, {'volume_vol_8H': 0.021160122}, {'range_vol_diff5': 0.024587203}, {'return_vol_30M': 0.023996307}, {'daily_volume_vol_diff30': 0.024131851}, {'close_diff': 0.024664916}, {'volume_vol_15M': 0.017969064}, {'return_vol_10D': 0.031015249}, {'daily_vol_diff_pct': 0.028220009}, {'daily_volume_vol_diff_pct30': 0.022478461}, {'range_vol5MA': 0.026832003}, {'cmf': 0.023511313}, {'return_vol_450M': 0.02665156}, {'hour_volume_vol_diff_pct': 0.022786407}, {'min_vol_diff': 0.020594157}, {'price_25DDiff': 0.025718125}, {'return_vol_3D': 0.021830535}, {'daily_vol_diff_pct30': 0.024919597}, {'volume_vol_3D': 0.021526733}, {'volume_vol_450M': 0.023066422}, {'close_diff_deviation': 0.024266448}, {'return_vol_30D': 0.025910962}, {'close_diff_deviation3': 0.023609562}, {'return_vol_16H': 0.023098333}, {'volume_vol_30M': 0.017963218}, {'rsi': 0.023663707}, {'threeD_stddev50': 0.02574126}, {'close_diff5': 0.027710397}, {'range_vol10MA': 0.026697084}, {'SPY_5D': 0.03080865}, {'daily_vol_diff': 0.04626862}, {'SPY_diff3': 0.024833318}, {'volume_vol_5D': 0.023231816}, {'rsi3': 0.026413525}, {'volume_25DDiff': 0.022519676}, {'price7': 0.024915833}]"}
# {'deployment_date': datetime.datetime(2023, 1, 9, 0, 0), 'dataset_end': datetime.datetime(2022, 12, 30, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    30343
# 1    30330
# Name: count, dtype: int64
# 3 27 54 7
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2023-01-09', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 3, 'TPpct': Decimal('0'), 'FP': 27, 'FPpct': Decimal('0'), 'TN': 54, 'TNpct': Decimal('0'), 'FN': 7, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.1111111111111111'), 'evaluation_timeperiod': '2023-01-09_2023-01-13', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.012+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024545476}, {'day_of_week': 0.029740691}, {'return_vol_5D': 0.02377506}, {'hour_volume_vol_diff': 0.02342337}, {'return_vol_240M': 0.023471953}, {'volume_vol_8H': 0.02097956}, {'range_vol_diff5': 0.025191724}, {'return_vol_30M': 0.02382973}, {'daily_volume_vol_diff30': 0.023940051}, {'close_diff': 0.023195898}, {'volume_vol_15M': 0.018463427}, {'return_vol_10D': 0.030269237}, {'daily_vol_diff_pct': 0.027312348}, {'daily_volume_vol_diff_pct30': 0.02330517}, {'range_vol5MA': 0.027456647}, {'cmf': 0.024805536}, {'return_vol_450M': 0.028063754}, {'hour_volume_vol_diff_pct': 0.023555689}, {'min_vol_diff': 0.021218369}, {'price_25DDiff': 0.024748184}, {'return_vol_3D': 0.02278725}, {'daily_vol_diff_pct30': 0.024311695}, {'volume_vol_3D': 0.02218762}, {'volume_vol_450M': 0.022437578}, {'close_diff_deviation': 0.024004066}, {'return_vol_30D': 0.02565545}, {'close_diff_deviation3': 0.022958007}, {'return_vol_16H': 0.02422429}, {'volume_vol_30M': 0.018703824}, {'rsi': 0.02431087}, {'threeD_stddev50': 0.025203967}, {'close_diff5': 0.02704277}, {'range_vol10MA': 0.026322355}, {'SPY_5D': 0.031435765}, {'daily_vol_diff': 0.04718885}, {'SPY_diff3': 0.023637716}, {'volume_vol_5D': 0.02221152}, {'rsi3': 0.027250225}, {'volume_25DDiff': 0.0222535}, {'price7': 0.024580818}]"}
# {'deployment_date': datetime.datetime(2023, 1, 16, 0, 0), 'dataset_end': datetime.datetime(2023, 1, 6, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    30448
# 1    30440
# Name: count, dtype: int64
# 47 68 64 68
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2023-01-16', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 47, 'TPpct': Decimal('0'), 'FP': 68, 'FPpct': Decimal('0'), 'TN': 64, 'TNpct': Decimal('0'), 'FN': 68, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6911764705882353'), 'evaluation_timeperiod': '2023-01-16_2023-01-20', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-1.011+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024638053}, {'day_of_week': 0.031848468}, {'return_vol_5D': 0.02320132}, {'hour_volume_vol_diff': 0.023394212}, {'return_vol_240M': 0.023744889}, {'volume_vol_8H': 0.021972282}, {'range_vol_diff5': 0.02514989}, {'return_vol_30M': 0.023931671}, {'daily_volume_vol_diff30': 0.022831976}, {'close_diff': 0.02439951}, {'volume_vol_15M': 0.018201958}, {'return_vol_10D': 0.031068247}, {'daily_vol_diff_pct': 0.025781984}, {'daily_volume_vol_diff_pct30': 0.022436222}, {'range_vol5MA': 0.025074603}, {'cmf': 0.02352357}, {'return_vol_450M': 0.0295262}, {'hour_volume_vol_diff_pct': 0.023114622}, {'min_vol_diff': 0.021603672}, {'price_25DDiff': 0.025284564}, {'return_vol_3D': 0.022078024}, {'daily_vol_diff_pct30': 0.024413519}, {'volume_vol_3D': 0.021022826}, {'volume_vol_450M': 0.022396974}, {'close_diff_deviation': 0.023960609}, {'return_vol_30D': 0.026308794}, {'close_diff_deviation3': 0.023579553}, {'return_vol_16H': 0.02410366}, {'volume_vol_30M': 0.019643234}, {'rsi': 0.024756044}, {'threeD_stddev50': 0.024785621}, {'close_diff5': 0.027037447}, {'range_vol10MA': 0.026628874}, {'SPY_5D': 0.03047973}, {'daily_vol_diff': 0.047724117}, {'SPY_diff3': 0.024009855}, {'volume_vol_5D': 0.02312543}, {'rsi3': 0.02564293}, {'volume_25DDiff': 0.02234741}, {'price7': 0.025227427}]"}
# {'deployment_date': datetime.datetime(2023, 1, 23, 0, 0), 'dataset_end': datetime.datetime(2023, 1, 13, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    30496
# 1    30483
# Name: count, dtype: int64
# 31 63 73 28
# ...
# {'deployment_date': datetime.datetime(2023, 11, 20, 0, 0), 'dataset_end': datetime.datetime(2023, 11, 10, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    35977
# 1    35963
# Name: count, dtype: int64
# 15 51 91 3
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2023-11-20', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 15, 'TPpct': Decimal('0'), 'FP': 51, 'FPpct': Decimal('0'), 'TN': 91, 'TNpct': Decimal('0'), 'FN': 3, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.29411764705882354'), 'evaluation_timeperiod': '2023-11-20_2023-11-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-0.993+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024846746}, {'day_of_week': 0.029085375}, {'return_vol_5D': 0.024120543}, {'hour_volume_vol_diff': 0.02362461}, {'return_vol_240M': 0.02331428}, {'volume_vol_8H': 0.021587713}, {'range_vol_diff5': 0.025367988}, {'return_vol_30M': 0.025830073}, {'daily_volume_vol_diff30': 0.02352753}, {'close_diff': 0.023041047}, {'volume_vol_15M': 0.018775407}, {'return_vol_10D': 0.031034628}, {'daily_vol_diff_pct': 0.026724936}, {'daily_volume_vol_diff_pct30': 0.02191221}, {'range_vol5MA': 0.02528692}, {'cmf': 0.024760928}, {'return_vol_450M': 0.027198877}, {'hour_volume_vol_diff_pct': 0.023130363}, {'min_vol_diff': 0.02118475}, {'price_25DDiff': 0.025744427}, {'return_vol_3D': 0.022779396}, {'daily_vol_diff_pct30': 0.024830932}, {'volume_vol_3D': 0.021542288}, {'volume_vol_450M': 0.021943998}, {'close_diff_deviation': 0.024835808}, {'return_vol_30D': 0.025241682}, {'close_diff_deviation3': 0.024051366}, {'return_vol_16H': 0.023099633}, {'volume_vol_30M': 0.019074837}, {'rsi': 0.024833107}, {'threeD_stddev50': 0.024726799}, {'close_diff5': 0.026554689}, {'range_vol10MA': 0.025747065}, {'SPY_5D': 0.030374909}, {'daily_vol_diff': 0.050372377}, {'SPY_diff3': 0.024178674}, {'volume_vol_5D': 0.022995394}, {'rsi3': 0.026437724}, {'volume_25DDiff': 0.022428269}, {'price7': 0.023851616}]"}
# {'deployment_date': datetime.datetime(2023, 11, 27, 0, 0), 'dataset_end': datetime.datetime(2023, 11, 17, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    36070
# 1    36012
# Name: count, dtype: int64
# 87 46 30 48
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2023-11-27', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 87, 'TPpct': Decimal('0'), 'FP': 46, 'FPpct': Decimal('0'), 'TN': 30, 'TNpct': Decimal('0'), 'FN': 48, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.891304347826087'), 'evaluation_timeperiod': '2023-11-27_2023-12-01', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-0.992+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024022613}, {'day_of_week': 0.02975558}, {'return_vol_5D': 0.024251437}, {'hour_volume_vol_diff': 0.023060448}, {'return_vol_240M': 0.023520708}, {'volume_vol_8H': 0.022045078}, {'range_vol_diff5': 0.026647104}, {'return_vol_30M': 0.02424971}, {'daily_volume_vol_diff30': 0.022425331}, {'close_diff': 0.022060258}, {'volume_vol_15M': 0.01959511}, {'return_vol_10D': 0.032740317}, {'daily_vol_diff_pct': 0.026870528}, {'daily_volume_vol_diff_pct30': 0.021804363}, {'range_vol5MA': 0.0271552}, {'cmf': 0.025104944}, {'return_vol_450M': 0.027751435}, {'hour_volume_vol_diff_pct': 0.0239812}, {'min_vol_diff': 0.020714235}, {'price_25DDiff': 0.025415543}, {'return_vol_3D': 0.022702878}, {'daily_vol_diff_pct30': 0.025097992}, {'volume_vol_3D': 0.022959147}, {'volume_vol_450M': 0.022420764}, {'close_diff_deviation': 0.024164239}, {'return_vol_30D': 0.02529456}, {'close_diff_deviation3': 0.024165986}, {'return_vol_16H': 0.023664875}, {'volume_vol_30M': 0.019677145}, {'rsi': 0.02322758}, {'threeD_stddev50': 0.024819233}, {'close_diff5': 0.02706936}, {'range_vol10MA': 0.02658893}, {'SPY_5D': 0.029893776}, {'daily_vol_diff': 0.04624943}, {'SPY_diff3': 0.024931375}, {'volume_vol_5D': 0.021866312}, {'rsi3': 0.025107022}, {'volume_25DDiff': 0.021577561}, {'price7': 0.02535069}]"}
# {'deployment_date': datetime.datetime(2023, 12, 4, 0, 0), 'dataset_end': datetime.datetime(2023, 11, 24, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    36124
# 1    36118
# Name: count, dtype: int64
# 109 113 32 15
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2023-12-04', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 109, 'TPpct': Decimal('0'), 'FP': 113, 'FPpct': Decimal('0'), 'TN': 32, 'TNpct': Decimal('0'), 'FN': 15, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.9646017699115044'), 'evaluation_timeperiod': '2023-12-04_2023-12-08', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-0.989+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024874842}, {'day_of_week': 0.029320696}, {'return_vol_5D': 0.024323348}, {'hour_volume_vol_diff': 0.02363955}, {'return_vol_240M': 0.02253089}, {'volume_vol_8H': 0.021425935}, {'range_vol_diff5': 0.025892945}, {'return_vol_30M': 0.02468097}, {'daily_volume_vol_diff30': 0.022912486}, {'close_diff': 0.024097588}, {'volume_vol_15M': 0.018689144}, {'return_vol_10D': 0.03250088}, {'daily_vol_diff_pct': 0.025558596}, {'daily_volume_vol_diff_pct30': 0.021458492}, {'range_vol5MA': 0.026649881}, {'cmf': 0.024770413}, {'return_vol_450M': 0.02702746}, {'hour_volume_vol_diff_pct': 0.023691915}, {'min_vol_diff': 0.021000672}, {'price_25DDiff': 0.025528561}, {'return_vol_3D': 0.023186186}, {'daily_vol_diff_pct30': 0.024663001}, {'volume_vol_3D': 0.02134602}, {'volume_vol_450M': 0.02272103}, {'close_diff_deviation': 0.025125911}, {'return_vol_30D': 0.025423309}, {'close_diff_deviation3': 0.023575414}, {'return_vol_16H': 0.022926014}, {'volume_vol_30M': 0.018601649}, {'rsi': 0.024349874}, {'threeD_stddev50': 0.024668302}, {'close_diff5': 0.027742893}, {'range_vol10MA': 0.028107677}, {'SPY_5D': 0.02967371}, {'daily_vol_diff': 0.048869222}, {'SPY_diff3': 0.023213891}, {'volume_vol_5D': 0.022361167}, {'rsi3': 0.024930475}, {'volume_25DDiff': 0.022669181}, {'price7': 0.025269836}]"}
# {'deployment_date': datetime.datetime(2023, 12, 11, 0, 0), 'dataset_end': datetime.datetime(2023, 12, 1, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    36233
# 1    36220
# Name: count, dtype: int64
# 35 80 71 14
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2023-12-11', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 35, 'TPpct': Decimal('0'), 'FP': 80, 'FPpct': Decimal('0'), 'TN': 71, 'TNpct': Decimal('0'), 'FN': 14, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.4375'), 'evaluation_timeperiod': '2023-12-11_2023-12-15', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-0.99+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.025019318}, {'day_of_week': 0.02926016}, {'return_vol_5D': 0.023803737}, {'hour_volume_vol_diff': 0.022942204}, {'return_vol_240M': 0.022117391}, {'volume_vol_8H': 0.022181194}, {'range_vol_diff5': 0.025288317}, {'return_vol_30M': 0.024983823}, {'daily_volume_vol_diff30': 0.023210859}, {'close_diff': 0.024180774}, {'volume_vol_15M': 0.018305434}, {'return_vol_10D': 0.032021925}, {'daily_vol_diff_pct': 0.027187768}, {'daily_volume_vol_diff_pct30': 0.021691425}, {'range_vol5MA': 0.026634157}, {'cmf': 0.02438489}, {'return_vol_450M': 0.02642146}, {'hour_volume_vol_diff_pct': 0.023489626}, {'min_vol_diff': 0.020850135}, {'price_25DDiff': 0.025396237}, {'return_vol_3D': 0.023315089}, {'daily_vol_diff_pct30': 0.024527716}, {'volume_vol_3D': 0.021438623}, {'volume_vol_450M': 0.022709752}, {'close_diff_deviation': 0.025335038}, {'return_vol_30D': 0.02590128}, {'close_diff_deviation3': 0.023830855}, {'return_vol_16H': 0.02346113}, {'volume_vol_30M': 0.018581286}, {'rsi': 0.024934756}, {'threeD_stddev50': 0.025524022}, {'close_diff5': 0.027362177}, {'range_vol10MA': 0.026879022}, {'SPY_5D': 0.029768907}, {'daily_vol_diff': 0.048064716}, {'SPY_diff3': 0.024108185}, {'volume_vol_5D': 0.022917135}, {'rsi3': 0.025037756}, {'volume_25DDiff': 0.022290895}, {'price7': 0.024640817}]"}
# {'deployment_date': datetime.datetime(2023, 12, 18, 0, 0), 'dataset_end': datetime.datetime(2023, 12, 8, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    36378
# 1    36344
# Name: count, dtype: int64
# 15 17 18 17
# {'model_name': 'CDVOLDIFFP_1D:BF3_CDVOL_custHypTP0.5', 'deployment_date': '2023-12-18', 'algorithm_type': 'xgboost', 'dataset': 'BF3_CDVOL_custHypTP0.5', 'TP': 15, 'TPpct': Decimal('0'), 'FP': 17, 'FPpct': Decimal('0'), 'TN': 18, 'TNpct': Decimal('0'), 'FN': 17, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8823529411764706'), 'evaluation_timeperiod': '2023-12-18_2023-12-22', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}"}, 'features': {"['SPY_diff', 'day_of_week', 'return_vol_5D', 'hour_volume_vol_diff', 'return_vol_240M', 'volume_vol_8H', 'range_vol_diff5', 'return_vol_30M', 'daily_volume_vol_diff30', 'close_diff', 'volume_vol_15M', 'return_vol_10D', 'daily_vol_diff_pct', 'daily_volume_vol_diff_pct30', 'range_vol5MA', 'cmf', 'return_vol_450M', 'hour_volume_vol_diff_pct', 'min_vol_diff', 'price_25DDiff', 'return_vol_3D', 'daily_vol_diff_pct30', 'volume_vol_3D', 'volume_vol_450M', 'close_diff_deviation', 'return_vol_30D', 'close_diff_deviation3', 'return_vol_16H', 'volume_vol_30M', 'rsi', 'threeD_stddev50', 'close_diff5', 'range_vol10MA', 'SPY_5D', 'daily_vol_diff', 'SPY_diff3', 'volume_vol_5D', 'rsi3', 'volume_25DDiff', 'price7']"}, 'target': '-0.99+one_min_vol', 'feature_importances': "[{'SPY_diff': 0.024403479}, {'day_of_week': 0.028863834}, {'return_vol_5D': 0.023905696}, {'hour_volume_vol_diff': 0.023610434}, {'return_vol_240M': 0.021847365}, {'volume_vol_8H': 0.021603538}, {'range_vol_diff5': 0.025809987}, {'return_vol_30M': 0.024708057}, {'daily_volume_vol_diff30': 0.02288157}, {'close_diff': 0.024666516}, {'volume_vol_15M': 0.018527554}, {'return_vol_10D': 0.03329592}, {'daily_vol_diff_pct': 0.027697215}, {'daily_volume_vol_diff_pct30': 0.021238333}, {'range_vol5MA': 0.02711218}, {'cmf': 0.024143951}, {'return_vol_450M': 0.027121125}, {'hour_volume_vol_diff_pct': 0.022957718}, {'min_vol_diff': 0.0201075}, {'price_25DDiff': 0.025356947}, {'return_vol_3D': 0.023159022}, {'daily_vol_diff_pct30': 0.02486112}, {'volume_vol_3D': 0.021496708}, {'volume_vol_450M': 0.02245788}, {'close_diff_deviation': 0.024970453}, {'return_vol_30D': 0.025156364}, {'close_diff_deviation3': 0.024174621}, {'return_vol_16H': 0.022896377}, {'volume_vol_30M': 0.018926414}, {'rsi': 0.024240864}, {'threeD_stddev50': 0.025086977}, {'close_diff5': 0.02680348}, {'range_vol10MA': 0.025938809}, {'SPY_5D': 0.030218044}, {'daily_vol_diff': 0.050588876}, {'SPY_diff3': 0.024510646}, {'volume_vol_5D': 0.022283193}, {'rsi3': 0.025380176}, {'volume_25DDiff': 0.022417972}, {'price7': 0.024573125}]"}

# %%
# def convert_timestamp_est(timestamp):
#     # Create a naive datetime object from the UNIX timestamp
#     dt_naive = datetime.utcfromtimestamp(timestamp)
#     # Convert the naive datetime object to a timezone-aware one (UTC)
#     dt_utc = pytz.utc.localize(dt_naive)
#     # Convert the UTC datetime to EST
#     dt_est = dt_utc.astimezone(pytz.timezone('US/Eastern'))
    
#     return dt_est


# data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/CDGAIN/2018-01-01_2023-12-23_validationTR15.csv')
# data['date'] = data['date'].astype(str)
# data['date'] = data['date'].apply(lambda x: x.split(" ")[0])
# data = data.drop(data[data['date'] == 'nan'].index)
# # data.drop('date',axis=1,inplace=True)
# # data['date'] = data['t'].apply(lambda x: convert_timestamp_est(x))
# # data.drop(['one_pct','three_pct','Unnamed: 0.2', "Unnamed: 0","Unnamed: 0.1", "date_x","date_y",'vw_x', 'n_x', 'return_vol_240M_x', 'volume_vol_240M_x', 'return_vol_450M_x', 'volume_vol_450M_x', 'min_vol_diff_x', 'min_vol_diff_pct_x', 'min_volume_vol_diff_x', 'min_volume_vol_diff_pct_x', 'return_vol_8H_x', 'return_vol_16H_x', 'volume_vol_8H_x', 'volume_vol_16H_x', 'hour_vol_diff_x', 'hour_vol_diff_pct_x', 'hour_volume_vol_diff_x', 'hour_volume_vol_diff_pct_x', 'return_vol_5D_x', 'return_vol_10D_x', 'return_vol_30D_x', 'volume_vol_5D_x', 'volume_vol_10D_x', 'volume_vol_30D_x', 'daily_vol_diff_x', 'daily_vol_diff_pct_x', 'daily_vol_diff30_x', 'daily_vol_diff_pct30_x', 'daily_volume_vol_diff_x', 'daily_volume_vol_diff_pct_x', 'daily_volume_vol_diff30_x', 'daily_volume_vol_diff_pct30_x', 'vw_y', 'n_y', 'return_vol_240M_y', 'volume_vol_240M_y', 'return_vol_450M_y', 'volume_vol_450M_y', 'min_vol_diff_y', 'min_vol_diff_pct_y', 'min_volume_vol_diff_y', 'min_volume_vol_diff_pct_y', 'return_vol_8H_y', 'return_vol_16H_y', 'volume_vol_8H_y', 'volume_vol_16H_y', 'hour_vol_diff_y', 'hour_vol_diff_pct_y', 'hour_volume_vol_diff_y', 'hour_volume_vol_diff_pct_y', 'return_vol_5D_y', 'return_vol_10D_y', 'return_vol_30D_y', 'volume_vol_5D_y', 'volume_vol_10D_y', 'volume_vol_30D_y', 'daily_vol_diff_y', 'daily_vol_diff_pct_y', 'daily_vol_diff30_y', 'daily_vol_diff_pct30_y', 'daily_volume_vol_diff_y', 'daily_volume_vol_diff_pct_y', 'daily_volume_vol_diff30_y', 'daily_volume_vol_diff_pct30_y'], axis=1, inplace=True)
# data['roc_diff'] = data['roc'] - data['roc5'] 
# data['range_vol_diff5'] = (data['range_vol'] - data['range_vol5MA'])
# data['close_diff_deviation3'] = abs(data['close_diff3'])/(data['threeD_stddev50']*100)
# data['close_diff_deviation'] = abs(data['close_diff'])/(data['oneD_stddev50']*100)
# data.dropna(subset=['date'], inplace=True)
# data['date'] = data['date'].apply(lambda x: datetime.strptime(x,"%Y-%m-%d"))
# data['day_of_week'] = data['date'].apply(lambda x: x.dayofweek).astype(int)
# data['day_of_month'] = data['date'].apply(lambda x: x.day).astype(int)
# data['month'] = data['date'].apply(lambda x: x.month).astype(int)
# data['year'] = data['date'].apply(lambda x: x.year).astype(int)
# data.replace([np.inf, -np.inf], 0, inplace=True)
# data.to_csv(f'/Users/charlesmiller/Documents/model_tester_data/CDGAIN/2018-01-01_2023-12-23_validationTR15.csv', index=False)

# %%
# def run_temporal_simulation(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date):
#     tp_avg_list = []
#     gross_accuracy_list = []
#     # fn_list = []
#     # tn_list = []
    
#     hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
#     dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
#     for date in dates_list:
#         tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams)
#         tp_avg_list.append(tp)
#         gross_accuracy_list.append((tp-fp))

#     return tp_avg_list, gross_accuracy_list

# %%
# number_of_simulations = 300
# now = datetime.now()
# title = 'CDLOSE'
# # total_feature_list = ['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'v', 'o', 'c', 'h', 'l',
# #  'date', 'hour', 'symbol', 't', 'price7', 'price14', 'adjusted_volume', 'vol7', 'vol14', 'rsi', 
# # 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close', 'oneD_returns_close', 'range_vol', 
# # 'range_vol5MA', 'range_vol10MA', 'range_vol25MA', 'oneD_stddev50', 'threeD_stddev50', 'cmf', 'close_diff', 
# # 'close_diff3', 'close_diff5', 'v_diff_pct', 'adx', 'volume_10MA', 'volume_25MA', 'price_10MA', 'price_25MA',
# # 'volume_10DDiff', 'volume_25DDiff', 'price_10DDiff', 'price_25DDiff', 'one_max', 'one_min', 'one_pct', 
# # 'three_max', 'three_min', 'three_pct', 'SPY_diff', 'SPY_diff3', 'SPY_diff5', 'SPY_1D', 'SPY_3D', 'SPY_5D', 
# # 'vw', 'n', 'return_vol_15M', 'volume_vol_15M', 'return_vol_30M', 'volume_vol_30M', 'return_vol_60M', 
# # 'volume_vol_60M', 'return_vol_120M', 'volume_vol_120M', 'return_vol_240M', 'volume_vol_240M', 
# # 'return_vol_450M', 'volume_vol_450M', '15min_vol_diff', '15min_vol_diff_pct', 'min_vol_diff', 
# # 'min_vol_diff_pct', 'min_volume_vol_diff', 'min_volume_vol_diff_pct', 'return_vol_4H', 'return_vol_8H', 
# # 'return_vol_16H', 'volume_vol_4H', 'volume_vol_8H', 'volume_vol_16H', 'hour_vol_diff', 'hour_vol_diff_pct', 
# # 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_3D', 'return_vol_5D', 'return_vol_10D', 
# # 'return_vol_30D', 'volume_vol_3D', 'volume_vol_5D', 'volume_vol_10D', 'volume_vol_30D', 'daily_vol_diff', 
# # 'daily_vol_diff_pct', 'daily_vol_diff30', 'daily_vol_diff_pct30', 'daily_volume_vol_diff', 'daily_volume_vol_diff_pct', 
# # 'daily_volume_vol_diff30', 'daily_volume_vol_diff_pct30', 'cd_vol', 'cd_vol3', 'roc_diff', 'range_vol_diff5', 
# # 'close_diff_deviation3', 'close_diff_deviation', 'day_of_week', 'day_of_month', 'month', 'year', 'dt', 'one_max_vol', 
# # 'three_max_vol', 'one_min_vol', 'three_min_vol']

# testing_features = ['hour', 'price7', 'price14','vol7', 'vol14', 'rsi', 
# 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close', 'oneD_returns_close', 'range_vol', 
# 'range_vol5MA', 'range_vol10MA', 'range_vol25MA', 'oneD_stddev50', 'threeD_stddev50', 'cmf', 'close_diff', 
# 'close_diff3', 'close_diff5','adx',
# 'volume_10DDiff', 'volume_25DDiff', 'price_10DDiff', 'price_25DDiff', 
# 'SPY_diff', 'SPY_diff3', 'SPY_diff5', 'SPY_1D', 'SPY_3D', 'SPY_5D', 
# 'return_vol_15M', 'volume_vol_15M', 'return_vol_30M', 'volume_vol_30M', 'return_vol_60M', 
# 'volume_vol_60M', 'return_vol_120M', 'volume_vol_120M', 'return_vol_240M', 'volume_vol_240M', 
# 'return_vol_450M', 'volume_vol_450M', '15min_vol_diff', '15min_vol_diff_pct', 'min_vol_diff', 
# 'min_vol_diff_pct', 'min_volume_vol_diff', 'min_volume_vol_diff_pct', 'return_vol_4H', 'return_vol_8H', 
# 'return_vol_16H', 'volume_vol_4H', 'volume_vol_8H', 'volume_vol_16H', 'hour_vol_diff', 'hour_vol_diff_pct', 
# 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_3D', 'return_vol_5D', 'return_vol_10D', 
# 'return_vol_30D', 'volume_vol_3D', 'volume_vol_5D', 'volume_vol_10D', 'volume_vol_30D', 'daily_vol_diff', 
# 'daily_vol_diff_pct', 'daily_vol_diff30', 'daily_vol_diff_pct30', 'daily_volume_vol_diff', 'daily_volume_vol_diff_pct', 
# 'daily_volume_vol_diff30', 'daily_volume_vol_diff_pct30', 'cd_vol', 'cd_vol3', 'roc_diff', 'range_vol_diff5', 
# 'close_diff_deviation3', 'close_diff_deviation', 'day_of_week', 'day_of_month', 'month']

# target_label = 'one_min_vol'
# target_value = -0.9
# results_array = []

# i = 0
# while i < number_of_simulations:
#        model_name = f"{title}_temporal_simulation_{i}"
#        print(model_name)
#        random_int = random.randint(15, 40)
#        features = random.sample(testing_features, random_int)
#        print(features)
#        tp_avg_list, gross_accuracy_list = run_temporal_simulation(features, target_label, target_value, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2022,10,3), evaluation_end_date=datetime(2023,12,23))        
#        tp_avg = sum(tp_avg_list)/len(tp_avg_list)
#        gross_accuracy = sum(gross_accuracy_list)/len(gross_accuracy_list)
#        print(tp_avg, gross_accuracy)
#        print()
#        results_array.append({"model_name": model_name, "features": features, "tp_avg": tp_avg, "gross_accuracy": gross_accuracy,"num_features": random_int})
#        i += 1

# results_df = pd.DataFrame(results_array)
# results_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
