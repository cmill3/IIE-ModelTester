# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler

# %%
s3 = boto3.client('s3')

training_bucket = "icarus-research-data"

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

weekly_expiries = ['SPY', 'IVV', 'QQQ', 'GLD', 'IWM', 'EFA', 'XLK', 'XLV', 'TLT', 'LQD', 'XLE', 'TQQQ', 'SQQQ', 'SPXS', 'SPXL', 'SOXL', 'SOXS', 'MMM', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 
                   'AAP', 'AFL', 'ALB', 'ALGN', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMD', 'AAL', 'AXP', 'AIG', 'ABC', 'AMGN', 'ADI', 'APA', 'AAPL', 'AMAT', 'ANET', 'T', 'ADSK', 'BAC', 'BBWI', 'BAX', 'BBY', 'BIIB', 
                   'BLK', 'BA', 'BKNG', 'BMY', 'AVGO', 'CZR', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CAT', 'CBOE', 'CNC', 'CF', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CI', 'CSCO', 'C', 'CLX', 'CME', 'KO', 'CMCSA', 'CMA', 'CAG', 
                   'COP', 'STZ', 'GLW', 'COST', 'CTRA', 'CSX', 'CVS', 'DHI', 'DHR', 'DE', 'DAL', 'DVN', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'DPZ', 'DOW', 'DD', 'EBAY', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'EOG', 'EQT', 
                   'ETSY', 'EXPE', 'XOM', 'FDX', 'FITB', 'FSLR', 'FI', 'F', 'FTNT', 'FOXA', 'FCX', 'GEHC', 'GNRC', 'GD', 'GE', 'GM', 'GILD', 'GS', 'HAL', 'HSY', 'HES', 'HD', 'HON', 'HRL', 'HPQ', 'HUM', 'HBAN', 'IBM', 'ILMN', 
                   'INTC', 'IP', 'INTU', 'ISRG', 'JNJ', 'JPM', 'JNPR', 'KEY', 'KMB', 'KMI', 'KLAC', 'KHC', 'KR', 'LRCX', 'LVS', 'LEN', 'LMT', 'LOW', 'MRO', 'MPC', 'MAR', 'MA', 'MTCH', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 
                   'MGM', 'MU', 'MSFT', 'MRNA', 'MDLZ', 'MS', 'MOS', 'NTAP', 'NFLX', 'NEM', 'NKE', 'NSC', 'NOC', 'NCLH', 'NUE', 'NVDA', 'NXPI', 'OXY', 'ON', 'ORCL', 'PARA', 'PYPL', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PXD', 'PNC', 
                   'PPG', 'PG', 'PHM', 'QCOM', 'RTX', 'REGN', 'ROST', 'RCL', 'SPGI', 'CRM', 'SLB', 'STX', 'NOW', 'SWKS', 'SEDG', 'SO', 'LUV', 'SBUX', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TGT', 'TSLA', 'TXN', 'TMO', 'TJX', 'TSCO', 'TFC', 
                   'TSN', 'USB', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'VLO', 'VZ', 'VRTX', 'VFC', 'V', 'WBA', 'WMT', 'WBD', 'WM', 'WFC', 'WDC', 'WHR', 'WMB', 'WYNN', 'ZION']

# %%
def create_validation_data(key_list, prefix, bucket_name):
    df_list = []
    hours = [10,11,12,13,14,15]
    for key in key_list:
        for hour in hours:
            try:
                data = s3.get_object(Bucket=bucket_name, Key=f'{prefix}{key}/{hour}.csv')
                df = pd.read_csv(data.get("Body")) 
                df_list.append(df)
            except:
                continue

    data = pd.concat(df_list)
    data.reset_index(drop=True, inplace=True)
    # data = full_df.drop(full_df[full_df.third_friday == 'True'].index)
    # data.drop(data[data.third_friday == 'NO RESULTS'].index, inplace=True)
    data['volume_10DDiff'] = data.apply(lambda x: x.v - x.volume_10MA, axis=1)
    data['volume_25DDiff'] = data.apply(lambda x: x.v - x.volume_25MA, axis=1)
    # data['rvi_delta'] = data.apply(lambda x: x.rvi5 - x.rvi10, axis=1)

    data['dt'] = pd.to_datetime(data['date'])
    data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek)
    data['day_of_month'] = data['dt'].apply(lambda x: x.day)
    data['month'] = data['dt'].apply(lambda x: x.month)
    data['year'] = data['dt'].apply(lambda x: x.year)
    data['hour'] = data['dt'].apply(lambda x: x.hour)

    data = data.loc[data['symbol'].isin(weekly_expiries)]

    return data

def create_training_data_v2(key_list, prefix, bucket_name):
    df_list = []
    hours = [10,11,12,13,14,15]
    for key in key_list:
        for hour in hours:
            try:
                data = s3.get_object(Bucket=bucket_name, Key=f'{prefix}{key}/{hour}.csv')
                df = pd.read_csv(data.get("Body")) 
                df_list.append(df)
            except:
                continue

    data = pd.concat(df_list)
    data.reset_index(drop=True, inplace=True)
    # data = full_df.drop(full_df[full_df.third_friday == 'True'].index)
    # data.drop(data[data.third_friday == 'NO RESULTS'].index, inplace=True)
    data['volume_10DDiff'] = data.apply(lambda x: x.v - x.volume_10MA, axis=1)
    data['volume_25DDiff'] = data.apply(lambda x: x.v - x.volume_25MA, axis=1)

    data['dt'] = pd.to_datetime(data['date'])
    data['day_of_week'] = data['dt'].apply(lambda x: x.dayofweek)
    data['day_of_month'] = data['dt'].apply(lambda x: x.day)
    data['month'] = data['dt'].apply(lambda x: x.month)
    data['year'] = data['dt'].apply(lambda x: x.year)
    data['hour'] = data['dt'].apply(lambda x: x.hour)
    # data['rvi_delta'] = data.apply(lambda x: x.rvi5 - x.rvi10, axis=1)

    # data = data.loc[data['symbol'].isin(weekly_expiries)]


    return data

# %%
def build_date_list(start_date, end_date):
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    # dataset[["rsi", "cmf", "adx", "roc", "roc3", "roc5","three_max"]] = dataset[["rsi", "cmf", "adx", "roc", "roc3", "roc5","three_max"]].apply(pd.to_numeric)
    # validation_dataset[["rsi", "cmf", "adx", "roc", "roc3", "roc5","three_max"]] = validation_dataset[["rsi", "cmf", "adx", "roc", "roc3", "roc5","three_max"]].apply(pd.to_numeric)
    dataset.loc[:, 'label'] = (dataset['three_min'] < -.04).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset['three_min'] < -.04).astype(int)

    scaler = StandardScaler()
    
    X = dataset[features]
    y = dataset['label']
    # X = scaler.fit_transform(X)

    # train_len = int(.7*len(dataset))
    # X_train = X.iloc[0:train_len]
    # y_train = y[0:train_len]
    # X_test = X.iloc[train_len:]
    # y_test = y[train_len:]

    print(y.value_counts())
    X_validate = validation_dataset[features]
    y_validate = validation_dataset['label']
    # X_validate = scaler.fit_transform(X_validate)

    # pos_bal_weight = (len(y.loc[y == 0])) / (len(y.loc[y == 1]))
    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],silent=0,objective='binary:logistic')
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, str(fi_list), predictions

# %%
def model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,start_date, end_date,deployment_date, feature_str, target_str, hyperparams_str, hyperparams):
    dates = build_date_list(start_date, end_date)
    key_list = build_query_keys(dates)
    validation_keys = build_query_keys_validation(deployment_date)
    # dataset = create_training_data_v2(key_list, 'inv_alerts_with_price/losers/', 'icarus-research-data')
    # recent_dataset = create_training_data_v2(key_list[-100:], 'inv_alerts_with_price/losers/', 'icarus-research-data')
    validation_dataset = create_validation_data(validation_keys, 'vdiff_loss/', 'inv-alerts')
    dataset = create_training_data_v2(key_list, 'vdiff_loss/', 'inv-alerts')
    # full_data = build_multi_time_dfs(key_list, dataset)
    # mod_dataset = pd.concat([dataset, recent_dataset])
    # hyperparams = optimize_model_params(dataset, features)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    validation_dataset['predictions'] = predictions
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/standard_dataset/vdiff_lossP/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, target_str, fi_list)
    return "response"

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=10)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

# %%
## Need to re-run 'inv_alerts_vdiffP_weekly:fulltrain_last60_unscaled_tuned'
model_name = 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned'
dataset_name = 'inv_alerts_standard'
title = 'most_actives'
hyperparameter_string = "{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"
hyperparams =  {'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}
feature_str = "'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"
features = ['rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour']
target_str = 'three_max > 3'
target_label = 'three_max'
target_value = 3.0
dataset_start_date = datetime(2021,1,1) 

dates_list = build_evaluation_period(datetime(2022,10,24), datetime(2023,7,7))
for date in dates_list:
    response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], feature_str, target_str,hyperparameter_string, hyperparams)
    print(response)
# Out:
# label
# 0    100752
# 1     33948
# Name: count, dtype: int64
# [12:04:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 23 18 486 55
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-10-24', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 23, 'TPpct': Decimal('0'), 'FP': 18, 'FPpct': Decimal('0'), 'TN': 486, 'TNpct': Decimal('0'), 'FN': 55, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.2777777777777777'), 'evaluation_timeperiod': '2022-10-24_2022-10-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.041849725}, {'cmf': 0.036460016}, {'adx': 0.03564944}, {'roc': 0.054686595}, {'roc3': 0.084309764}, {'roc5': 0.057485282}, {'PCR': 0.047765855}, {'v': 0.036248572}, {'volume_10MA': 0.03686393}, {'volume_25MA': 0.036322337}, {'volume_10DDiff': 0.035737216}, {'volume_25DDiff': 0.03767962}, {'close_diff': 0.3166444}, {'v_diff_pct': 0.03457531}, {'day_of_week': 0.039883096}, {'hour': 0.06783886}]"}
# response
# label
# 0    101902
# 1     34298
# Name: count, dtype: int64
# [12:06:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 104 42 282 118
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-10-31', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 104, 'TPpct': Decimal('0'), 'FP': 42, 'FPpct': Decimal('0'), 'TN': 282, 'TNpct': Decimal('0'), 'FN': 118, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.4761904761904763'), 'evaluation_timeperiod': '2022-10-31_2022-11-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.042691957}, {'cmf': 0.03704949}, {'adx': 0.036490142}, {'roc': 0.05557041}, {'roc3': 0.07849014}, {'roc5': 0.06211546}, {'PCR': 0.04740469}, {'v': 0.037020855}, {'volume_10MA': 0.037268844}, {'volume_25MA': 0.03665663}, {'volume_10DDiff': 0.03659483}, {'volume_25DDiff': 0.038885895}, {'close_diff': 0.31309113}, {'v_diff_pct': 0.034645963}, {'day_of_week': 0.0382615}, {'hour': 0.06776213}]"}
# response
# label
# 0    103246
# 1     34454
# Name: count, dtype: int64
# [12:08:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 30 42 402 78
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-11-07', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 30, 'TPpct': Decimal('0'), 'FP': 42, 'FPpct': Decimal('0'), 'TN': 402, 'TNpct': Decimal('0'), 'FN': 78, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.7142857142857143'), 'evaluation_timeperiod': '2022-11-07_2022-11-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.040848803}, {'cmf': 0.036107358}, {'adx': 0.036393553}, {'roc': 0.053952508}, {'roc3': 0.0784145}, {'roc5': 0.058741625}, {'PCR': 0.047583263}, {'v': 0.03686978}, {'volume_10MA': 0.036432207}, {'volume_25MA': 0.03633353}, {'volume_10DDiff': 0.035671372}, {'volume_25DDiff': 0.03701549}, {'close_diff': 0.32729307}, {'v_diff_pct': 0.03068587}, {'day_of_week': 0.03704412}, {'hour': 0.07061297}]"}
# response
# label
# 0    104110
# 1     35090
# Name: count, dtype: int64
# [12:10:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 82 24 378 66
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-11-14', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 82, 'TPpct': Decimal('0'), 'FP': 24, 'FPpct': Decimal('0'), 'TN': 378, 'TNpct': Decimal('0'), 'FN': 66, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.4166666666666665'), 'evaluation_timeperiod': '2022-11-14_2022-11-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.0412835}, {'cmf': 0.03677456}, {'adx': 0.036870956}, {'roc': 0.05306466}, {'roc3': 0.08325876}, {'roc5': 0.065856606}, {'PCR': 0.046206787}, {'v': 0.03722571}, {'volume_10MA': 0.03625712}, {'volume_25MA': 0.036279507}, {'volume_10DDiff': 0.035127044}, {'volume_25DDiff': 0.037458275}, {'close_diff': 0.32394472}, {'v_diff_pct': 0.029950371}, {'day_of_week': 0.03661084}, {'hour': 0.06383058}]"}
# response
# label
# 0    105382
# 1     35318
# Name: count, dtype: int64
# [12:11:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 24 24 352 24
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-11-21', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 24, 'TPpct': Decimal('0'), 'FP': 24, 'FPpct': Decimal('0'), 'TN': 352, 'TNpct': Decimal('0'), 'FN': 24, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0'), 'evaluation_timeperiod': '2022-11-21_2022-11-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.041422717}, {'cmf': 0.03699901}, {'adx': 0.03613794}, {'roc': 0.054451793}, {'roc3': 0.077814296}, {'roc5': 0.059037883}, {'PCR': 0.042971622}, {'v': 0.037785303}, {'volume_10MA': 0.037566207}, {'volume_25MA': 0.03769973}, {'volume_10DDiff': 0.036145255}, {'volume_25DDiff': 0.038569104}, {'close_diff': 0.32297236}, {'v_diff_pct': 0.035287607}, {'day_of_week': 0.03883053}, {'hour': 0.06630864}]"}
# response
# label
# 0    106488
# 1     35712
# Name: count, dtype: int64
# [12:13:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 30 36 432 126
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-11-28', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 30, 'TPpct': Decimal('0'), 'FP': 36, 'FPpct': Decimal('0'), 'TN': 432, 'TNpct': Decimal('0'), 'FN': 126, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8333333333333334'), 'evaluation_timeperiod': '2022-11-28_2022-12-02', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.0407323}, {'cmf': 0.035801772}, {'adx': 0.036718674}, {'roc': 0.05433149}, {'roc3': 0.08115569}, {'roc5': 0.06327109}, {'PCR': 0.04400066}, {'v': 0.037012115}, {'volume_10MA': 0.035871092}, {'volume_25MA': 0.03591329}, {'volume_10DDiff': 0.036341056}, {'volume_25DDiff': 0.037301704}, {'close_diff': 0.32642877}, {'v_diff_pct': 0.03495729}, {'day_of_week': 0.038261734}, {'hour': 0.061901193}]"}
# response
# label
# 0    107622
# 1     35778
# Name: count, dtype: int64
# [12:15:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 72 24 413 84
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-12-05', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 72, 'TPpct': Decimal('0'), 'FP': 24, 'FPpct': Decimal('0'), 'TN': 413, 'TNpct': Decimal('0'), 'FN': 84, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.0'), 'evaluation_timeperiod': '2022-12-05_2022-12-09', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.042709414}, {'cmf': 0.03580502}, {'adx': 0.03676137}, {'roc': 0.05413695}, {'roc3': 0.078573786}, {'roc5': 0.064639695}, {'PCR': 0.043480773}, {'v': 0.037079144}, {'volume_10MA': 0.036952246}, {'volume_25MA': 0.036429044}, {'volume_10DDiff': 0.03552559}, {'volume_25DDiff': 0.0384207}, {'close_diff': 0.3297236}, {'v_diff_pct': 0.032726258}, {'day_of_week': 0.03688761}, {'hour': 0.06014882}]"}
# response
# label
# 0    108907
# 1     35993
# Name: count, dtype: int64
# [12:17:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 53 6 270 228
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-12-12', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 53, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 270, 'TNpct': Decimal('0'), 'FN': 228, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('8.833333333333334'), 'evaluation_timeperiod': '2022-12-12_2022-12-16', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.042023618}, {'cmf': 0.03550571}, {'adx': 0.036777887}, {'roc': 0.05562805}, {'roc3': 0.080510885}, {'roc5': 0.060466938}, {'PCR': 0.04369854}, {'v': 0.03702974}, {'volume_10MA': 0.03714449}, {'volume_25MA': 0.036365308}, {'volume_10DDiff': 0.035836097}, {'volume_25DDiff': 0.03796128}, {'close_diff': 0.33511204}, {'v_diff_pct': 0.03017224}, {'day_of_week': 0.037851196}, {'hour': 0.057916008}]"}
# response
# label
# 0    109950
# 1     36450
# Name: count, dtype: int64
# [12:19:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 78 18 370 90
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-12-19', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 78, 'TPpct': Decimal('0'), 'FP': 18, 'FPpct': Decimal('0'), 'TN': 370, 'TNpct': Decimal('0'), 'FN': 90, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('4.333333333333333'), 'evaluation_timeperiod': '2022-12-19_2022-12-23', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.043889686}, {'cmf': 0.036568474}, {'adx': 0.037535742}, {'roc': 0.056550656}, {'roc3': 0.07969267}, {'roc5': 0.06590673}, {'PCR': 0.043716315}, {'v': 0.03842026}, {'volume_10MA': 0.036378928}, {'volume_25MA': 0.037782863}, {'volume_10DDiff': 0.038082644}, {'volume_25DDiff': 0.03878898}, {'close_diff': 0.32303402}, {'v_diff_pct': 0.031334545}, {'day_of_week': 0.039635282}, {'hour': 0.052682143}]"}
# response
# label
# 0    110892
# 1     37008
# Name: count, dtype: int64
# [12:21:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 13 18 468 53
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2022-12-26', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 13, 'TPpct': Decimal('0'), 'FP': 18, 'FPpct': Decimal('0'), 'TN': 468, 'TNpct': Decimal('0'), 'FN': 53, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.7222222222222222'), 'evaluation_timeperiod': '2022-12-26_2022-12-30', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.041141786}, {'cmf': 0.035579327}, {'adx': 0.036133893}, {'roc': 0.05434063}, {'roc3': 0.08656785}, {'roc5': 0.0580336}, {'PCR': 0.04220881}, {'v': 0.036755465}, {'volume_10MA': 0.03618041}, {'volume_25MA': 0.036840837}, {'volume_10DDiff': 0.03575282}, {'volume_25DDiff': 0.037527144}, {'close_diff': 0.3322886}, {'v_diff_pct': 0.03139504}, {'day_of_week': 0.03871168}, {'hour': 0.060542025}]"}
# response
# label
# 0    112024
# 1     37376
# Name: count, dtype: int64
# [12:24:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 18 6 354 60
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-01-02', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 18, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 354, 'TNpct': Decimal('0'), 'FN': 60, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.0'), 'evaluation_timeperiod': '2023-01-02_2023-01-06', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.040764585}, {'cmf': 0.034701478}, {'adx': 0.03563879}, {'roc': 0.053395938}, {'roc3': 0.077140905}, {'roc5': 0.0641837}, {'PCR': 0.042789694}, {'v': 0.03494503}, {'volume_10MA': 0.03441417}, {'volume_25MA': 0.03666096}, {'volume_10DDiff': 0.0352108}, {'volume_25DDiff': 0.0369946}, {'close_diff': 0.34650898}, {'v_diff_pct': 0.027360206}, {'day_of_week': 0.037500434}, {'hour': 0.061789736}]"}
# response
# label
# 0    113158
# 1     37442
# Name: count, dtype: int64
# [12:26:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 0 12 527 54
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-01-09', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 527, 'TNpct': Decimal('0'), 'FN': 54, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.0'), 'evaluation_timeperiod': '2023-01-09_2023-01-13', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.042038735}, {'cmf': 0.037342798}, {'adx': 0.037856977}, {'roc': 0.054918334}, {'roc3': 0.07784269}, {'roc5': 0.06307377}, {'PCR': 0.04252367}, {'v': 0.038371567}, {'volume_10MA': 0.03833366}, {'volume_25MA': 0.03868826}, {'volume_10DDiff': 0.037718095}, {'volume_25DDiff': 0.039852984}, {'close_diff': 0.33408308}, {'v_diff_pct': 0.027668655}, {'day_of_week': 0.03978981}, {'hour': 0.049896948}]"}
# response
# label
# 0    114232
# 1     37568
# Name: count, dtype: int64
# [12:28:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 24 12 336 114
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-01-16', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 24, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 336, 'TNpct': Decimal('0'), 'FN': 114, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.0'), 'evaluation_timeperiod': '2023-01-16_2023-01-20', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.042230707}, {'cmf': 0.03614154}, {'adx': 0.03645582}, {'roc': 0.052590895}, {'roc3': 0.08588001}, {'roc5': 0.06526946}, {'PCR': 0.04322978}, {'v': 0.03903724}, {'volume_10MA': 0.035987683}, {'volume_25MA': 0.037872244}, {'volume_10DDiff': 0.036750216}, {'volume_25DDiff': 0.038525023}, {'close_diff': 0.3295484}, {'v_diff_pct': 0.030491283}, {'day_of_week': 0.03948896}, {'hour': 0.05050067}]"}
# response
# label
# 0    115642
# 1     37658
# Name: count, dtype: int64
# [12:30:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 12 7 461 90
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-01-23', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 12, 'TPpct': Decimal('0'), 'FP': 7, 'FPpct': Decimal('0'), 'TN': 461, 'TNpct': Decimal('0'), 'FN': 90, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.7142857142857142'), 'evaluation_timeperiod': '2023-01-23_2023-01-27', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.041671533}, {'cmf': 0.03541873}, {'adx': 0.036328357}, {'roc': 0.054309394}, {'roc3': 0.0843047}, {'roc5': 0.059761267}, {'PCR': 0.044688836}, {'v': 0.03749235}, {'volume_10MA': 0.03745716}, {'volume_25MA': 0.036573086}, {'volume_10DDiff': 0.035779756}, {'volume_25DDiff': 0.038620718}, {'close_diff': 0.3400305}, {'v_diff_pct': 0.03115016}, {'day_of_week': 0.036335927}, {'hour': 0.050077584}]"}
# response
# label
# 0    116530
# 1     37970
# Name: count, dtype: int64
# [12:33:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 12 18 456 102
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-01-30', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 12, 'TPpct': Decimal('0'), 'FP': 18, 'FPpct': Decimal('0'), 'TN': 456, 'TNpct': Decimal('0'), 'FN': 102, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6666666666666666'), 'evaluation_timeperiod': '2023-01-30_2023-02-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.040748436}, {'cmf': 0.035254385}, {'adx': 0.036884554}, {'roc': 0.055160154}, {'roc3': 0.07771971}, {'roc5': 0.062106773}, {'PCR': 0.043161802}, {'v': 0.0375301}, {'volume_10MA': 0.037474163}, {'volume_25MA': 0.038124915}, {'volume_10DDiff': 0.035711404}, {'volume_25DDiff': 0.039757494}, {'close_diff': 0.34107515}, {'v_diff_pct': 0.029889226}, {'day_of_week': 0.036956243}, {'hour': 0.05244551}]"}
# response
# label
# 0    117862
# 1     38138
# Name: count, dtype: int64
# [12:36:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 60 12 428 138
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-02-06', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 60, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 428, 'TNpct': Decimal('0'), 'FN': 138, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('5.0'), 'evaluation_timeperiod': '2023-02-06_2023-02-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.041921623}, {'cmf': 0.03472636}, {'adx': 0.03612416}, {'roc': 0.055620346}, {'roc3': 0.083749466}, {'roc5': 0.063364424}, {'PCR': 0.044998083}, {'v': 0.037705638}, {'volume_10MA': 0.036059543}, {'volume_25MA': 0.035979982}, {'volume_10DDiff': 0.03555503}, {'volume_25DDiff': 0.037467416}, {'close_diff': 0.34041917}, {'v_diff_pct': 0.03155695}, {'day_of_week': 0.036800485}, {'hour': 0.0479513}]"}
# response
# label
# 0    119206
# 1     38294
# Name: count, dtype: int64
# [12:39:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 42 11 349 144
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-02-13', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 42, 'TPpct': Decimal('0'), 'FP': 11, 'FPpct': Decimal('0'), 'TN': 349, 'TNpct': Decimal('0'), 'FN': 144, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('3.8181818181818183'), 'evaluation_timeperiod': '2023-02-13_2023-02-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.0414592}, {'cmf': 0.03505135}, {'adx': 0.03558981}, {'roc': 0.055456277}, {'roc3': 0.08875108}, {'roc5': 0.056806114}, {'PCR': 0.046460733}, {'v': 0.03698732}, {'volume_10MA': 0.035785023}, {'volume_25MA': 0.036698073}, {'volume_10DDiff': 0.03522706}, {'volume_25DDiff': 0.03895419}, {'close_diff': 0.34204412}, {'v_diff_pct': 0.030318808}, {'day_of_week': 0.036916457}, {'hour': 0.047494363}]"}
# response
# label
# 0    120274
# 1     38726
# Name: count, dtype: int64
# [12:42:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 24 0 354 54
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-02-20', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 24, 'TPpct': Decimal('0'), 'FP': 0, 'FPpct': Decimal('0'), 'TN': 354, 'TNpct': Decimal('0'), 'FN': 54, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0'), 'evaluation_timeperiod': '2023-02-20_2023-02-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04134978}, {'cmf': 0.036442004}, {'adx': 0.03596432}, {'roc': 0.05803628}, {'roc3': 0.08256397}, {'roc5': 0.05870098}, {'PCR': 0.044079687}, {'v': 0.038316373}, {'volume_10MA': 0.03658511}, {'volume_25MA': 0.036676332}, {'volume_10DDiff': 0.036961038}, {'volume_25DDiff': 0.038594086}, {'close_diff': 0.34573993}, {'v_diff_pct': 0.028983094}, {'day_of_week': 0.037732173}, {'hour': 0.04327487}]"}
# response
# label
# 0    121558
# 1     38942
# Name: count, dtype: int64
# [12:44:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 24 12 438 78
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-02-27', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 24, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 438, 'TNpct': Decimal('0'), 'FN': 78, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.0'), 'evaluation_timeperiod': '2023-02-27_2023-03-03', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04186261}, {'cmf': 0.035963576}, {'adx': 0.036586072}, {'roc': 0.055759992}, {'roc3': 0.0776209}, {'roc5': 0.062872455}, {'PCR': 0.04601195}, {'v': 0.039364878}, {'volume_10MA': 0.036544826}, {'volume_25MA': 0.036344633}, {'volume_10DDiff': 0.036886673}, {'volume_25DDiff': 0.038516264}, {'close_diff': 0.34616393}, {'v_diff_pct': 0.029200343}, {'day_of_week': 0.037217863}, {'hour': 0.043082934}]"}
# response
# label
# 0    122488
# 1     39212
# Name: count, dtype: int64
# [12:47:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 43 1 270 293
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-03-06', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 43, 'TPpct': Decimal('0'), 'FP': 1, 'FPpct': Decimal('0'), 'TN': 270, 'TNpct': Decimal('0'), 'FN': 293, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('43.0'), 'evaluation_timeperiod': '2023-03-06_2023-03-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.043341078}, {'cmf': 0.036104552}, {'adx': 0.037449304}, {'roc': 0.059878893}, {'roc3': 0.07826876}, {'roc5': 0.061920233}, {'PCR': 0.04504203}, {'v': 0.03786931}, {'volume_10MA': 0.038224965}, {'volume_25MA': 0.038145993}, {'volume_10DDiff': 0.03696297}, {'volume_25DDiff': 0.03922542}, {'close_diff': 0.33737978}, {'v_diff_pct': 0.030550724}, {'day_of_week': 0.037948284}, {'hour': 0.041687734}]"}
# response
# label
# 0    123736
# 1     39464
# Name: count, dtype: int64
# [12:50:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 72 6 300 150
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-03-13', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 72, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 300, 'TNpct': Decimal('0'), 'FN': 150, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('12.0'), 'evaluation_timeperiod': '2023-03-13_2023-03-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.041392937}, {'cmf': 0.036336422}, {'adx': 0.03567671}, {'roc': 0.055372518}, {'roc3': 0.08316315}, {'roc5': 0.061721567}, {'PCR': 0.04701349}, {'v': 0.03835759}, {'volume_10MA': 0.037798937}, {'volume_25MA': 0.03717683}, {'volume_10DDiff': 0.03603348}, {'volume_25DDiff': 0.038695324}, {'close_diff': 0.33669242}, {'v_diff_pct': 0.03287209}, {'day_of_week': 0.037972126}, {'hour': 0.04372442}]"}
# response
# label
# 0    124558
# 1     40142
# Name: count, dtype: int64
# [12:52:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 89 12 378 109
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-03-20', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 89, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 378, 'TNpct': Decimal('0'), 'FN': 109, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('7.416666666666667'), 'evaluation_timeperiod': '2023-03-20_2023-03-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.042650174}, {'cmf': 0.034830645}, {'adx': 0.03665642}, {'roc': 0.059423424}, {'roc3': 0.07824136}, {'roc5': 0.06263122}, {'PCR': 0.04472741}, {'v': 0.0374981}, {'volume_10MA': 0.037112113}, {'volume_25MA': 0.0381508}, {'volume_10DDiff': 0.03636877}, {'volume_25DDiff': 0.03893227}, {'close_diff': 0.33855987}, {'v_diff_pct': 0.030210892}, {'day_of_week': 0.03739372}, {'hour': 0.046612877}]"}
# response
# label
# 0    125440
# 1     40760
# Name: count, dtype: int64
# [12:56:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 0 0 522 30
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-03-27', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 0, 'TPpct': Decimal('0'), 'FP': 0, 'FPpct': Decimal('0'), 'TN': 522, 'TNpct': Decimal('0'), 'FN': 30, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0'), 'evaluation_timeperiod': '2023-03-27_2023-03-31', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.041429028}, {'cmf': 0.035664115}, {'adx': 0.037058186}, {'roc': 0.055371717}, {'roc3': 0.07935909}, {'roc5': 0.061128538}, {'PCR': 0.044703227}, {'v': 0.036752246}, {'volume_10MA': 0.03724871}, {'volume_25MA': 0.03805246}, {'volume_10DDiff': 0.036989167}, {'volume_25DDiff': 0.039111383}, {'close_diff': 0.3390639}, {'v_diff_pct': 0.03471817}, {'day_of_week': 0.038523436}, {'hour': 0.044826653}]"}
# response
# label
# 0    126460
# 1     41240
# Name: count, dtype: int64
# [13:18:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 31 12 312 173
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-04-03', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 31, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 312, 'TNpct': Decimal('0'), 'FN': 173, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.5833333333333335'), 'evaluation_timeperiod': '2023-04-03_2023-04-07', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.042016443}, {'cmf': 0.03605708}, {'adx': 0.036839735}, {'roc': 0.057606883}, {'roc3': 0.07988782}, {'roc5': 0.06470014}, {'PCR': 0.042404775}, {'v': 0.037881903}, {'volume_10MA': 0.036600314}, {'volume_25MA': 0.037747953}, {'volume_10DDiff': 0.036068615}, {'volume_25DDiff': 0.038827702}, {'close_diff': 0.33469352}, {'v_diff_pct': 0.03854346}, {'day_of_week': 0.03739303}, {'hour': 0.042730585}]"}
# response
# label
# 0    127882
# 1     41318
# Name: count, dtype: int64
# [13:20:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 24 12 534 54
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-04-10', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 24, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 534, 'TNpct': Decimal('0'), 'FN': 54, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.0'), 'evaluation_timeperiod': '2023-04-10_2023-04-14', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04039375}, {'cmf': 0.034520816}, {'adx': 0.036122877}, {'roc': 0.057175633}, {'roc3': 0.080007136}, {'roc5': 0.06514957}, {'PCR': 0.044112448}, {'v': 0.03749618}, {'volume_10MA': 0.037416425}, {'volume_25MA': 0.03611524}, {'volume_10DDiff': 0.036641017}, {'volume_25DDiff': 0.038321484}, {'close_diff': 0.33916202}, {'v_diff_pct': 0.0342053}, {'day_of_week': 0.03671308}, {'hour': 0.04644707}]"}
# response
# label
# 0    128998
# 1     41702
# Name: count, dtype: int64
# [13:22:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 24 12 512 66
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-04-17', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 24, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 512, 'TNpct': Decimal('0'), 'FN': 66, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.0'), 'evaluation_timeperiod': '2023-04-17_2023-04-21', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.040441073}, {'cmf': 0.034787104}, {'adx': 0.0361199}, {'roc': 0.056553576}, {'roc3': 0.08550445}, {'roc5': 0.061498664}, {'PCR': 0.042024497}, {'v': 0.037220985}, {'volume_10MA': 0.037592664}, {'volume_25MA': 0.03719179}, {'volume_10DDiff': 0.03593113}, {'volume_25DDiff': 0.038262274}, {'close_diff': 0.34053546}, {'v_diff_pct': 0.033483095}, {'day_of_week': 0.036450837}, {'hour': 0.046402413}]"}
# response
# label
# 0    130114
# 1     41786
# Name: count, dtype: int64
# [13:24:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 71 42 342 168
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-04-24', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 71, 'TPpct': Decimal('0'), 'FP': 42, 'FPpct': Decimal('0'), 'TN': 342, 'TNpct': Decimal('0'), 'FN': 168, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.6904761904761905'), 'evaluation_timeperiod': '2023-04-24_2023-04-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04013403}, {'cmf': 0.03650753}, {'adx': 0.03610573}, {'roc': 0.055700764}, {'roc3': 0.07942741}, {'roc5': 0.061701458}, {'PCR': 0.04274013}, {'v': 0.038471688}, {'volume_10MA': 0.035900664}, {'volume_25MA': 0.036598768}, {'volume_10DDiff': 0.036026962}, {'volume_25DDiff': 0.037950817}, {'close_diff': 0.3418471}, {'v_diff_pct': 0.032961085}, {'day_of_week': 0.037406113}, {'hour': 0.05051983}]"}
# response
# label
# 0    131506
# 1     41894
# Name: count, dtype: int64
# [13:26:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 30 12 378 156
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-05-01', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 30, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 378, 'TNpct': Decimal('0'), 'FN': 156, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.5'), 'evaluation_timeperiod': '2023-05-01_2023-05-05', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.041335285}, {'cmf': 0.03498978}, {'adx': 0.037119377}, {'roc': 0.058588818}, {'roc3': 0.07916172}, {'roc5': 0.06365997}, {'PCR': 0.044403695}, {'v': 0.037499662}, {'volume_10MA': 0.03763272}, {'volume_25MA': 0.036724914}, {'volume_10DDiff': 0.0356657}, {'volume_25DDiff': 0.03860021}, {'close_diff': 0.33300275}, {'v_diff_pct': 0.032856155}, {'day_of_week': 0.03638474}, {'hour': 0.0523745}]"}
# response
# label
# 0    132611
# 1     42289
# Name: count, dtype: int64
# [13:28:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 30 6 408 138
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-05-08', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 30, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 408, 'TNpct': Decimal('0'), 'FN': 138, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('5.0'), 'evaluation_timeperiod': '2023-05-08_2023-05-12', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04120753}, {'cmf': 0.035745062}, {'adx': 0.03823938}, {'roc': 0.05717043}, {'roc3': 0.08088471}, {'roc5': 0.0638553}, {'PCR': 0.043639958}, {'v': 0.037999123}, {'volume_10MA': 0.03607385}, {'volume_25MA': 0.038085774}, {'volume_10DDiff': 0.036267504}, {'volume_25DDiff': 0.038385775}, {'close_diff': 0.33823204}, {'v_diff_pct': 0.029718947}, {'day_of_week': 0.03640522}, {'hour': 0.048089355}]"}
# response
# label
# 0    133769
# 1     42631
# Name: count, dtype: int64
# [13:30:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 18 30 468 66
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-05-15', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 18, 'TPpct': Decimal('0'), 'FP': 30, 'FPpct': Decimal('0'), 'TN': 468, 'TNpct': Decimal('0'), 'FN': 66, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.6'), 'evaluation_timeperiod': '2023-05-15_2023-05-19', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.03961824}, {'cmf': 0.034697976}, {'adx': 0.036342632}, {'roc': 0.057041224}, {'roc3': 0.07478474}, {'roc5': 0.063541256}, {'PCR': 0.042537685}, {'v': 0.03582614}, {'volume_10MA': 0.036441304}, {'volume_25MA': 0.036426477}, {'volume_10DDiff': 0.03554942}, {'volume_25DDiff': 0.037826847}, {'close_diff': 0.34882876}, {'v_diff_pct': 0.034129757}, {'day_of_week': 0.035456557}, {'hour': 0.050951045}]"}
# response
# label
# 0    134909
# 1     42991
# Name: count, dtype: int64
# [13:32:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 49 0 440 167
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-05-22', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 49, 'TPpct': Decimal('0'), 'FP': 0, 'FPpct': Decimal('0'), 'TN': 440, 'TNpct': Decimal('0'), 'FN': 167, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0'), 'evaluation_timeperiod': '2023-05-22_2023-05-26', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.040910542}, {'cmf': 0.033614334}, {'adx': 0.035869952}, {'roc': 0.05315287}, {'roc3': 0.08139682}, {'roc5': 0.06608312}, {'PCR': 0.04259794}, {'v': 0.035970904}, {'volume_10MA': 0.034595773}, {'volume_25MA': 0.035667475}, {'volume_10DDiff': 0.03480704}, {'volume_25DDiff': 0.037014306}, {'close_diff': 0.35489962}, {'v_diff_pct': 0.0340714}, {'day_of_week': 0.033645254}, {'hour': 0.04570262}]"}
# response
# label
# 0    136217
# 1     43183
# Name: count, dtype: int64
# [13:34:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 54 6 306 84
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-05-29', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 54, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 306, 'TNpct': Decimal('0'), 'FN': 84, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('9.0'), 'evaluation_timeperiod': '2023-05-29_2023-06-02', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.039790466}, {'cmf': 0.034130007}, {'adx': 0.035533622}, {'roc': 0.058000125}, {'roc3': 0.08036687}, {'roc5': 0.060552046}, {'PCR': 0.043571327}, {'v': 0.03556511}, {'volume_10MA': 0.03629475}, {'volume_25MA': 0.03504954}, {'volume_10DDiff': 0.03464937}, {'volume_25DDiff': 0.0371265}, {'close_diff': 0.34952778}, {'v_diff_pct': 0.032904927}, {'day_of_week': 0.03444113}, {'hour': 0.05249637}]"}
# response
# label
# 0    137201
# 1     43699
# Name: count, dtype: int64
# [13:36:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 31 12 540 41
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-06-05', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 31, 'TPpct': Decimal('0'), 'FP': 12, 'FPpct': Decimal('0'), 'TN': 540, 'TNpct': Decimal('0'), 'FN': 41, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.5833333333333335'), 'evaluation_timeperiod': '2023-06-05_2023-06-09', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04153809}, {'cmf': 0.03438806}, {'adx': 0.03560964}, {'roc': 0.056572575}, {'roc3': 0.080554806}, {'roc5': 0.062492557}, {'PCR': 0.042518646}, {'v': 0.03711761}, {'volume_10MA': 0.035795093}, {'volume_25MA': 0.0354179}, {'volume_10DDiff': 0.035020225}, {'volume_25DDiff': 0.038804494}, {'close_diff': 0.35309434}, {'v_diff_pct': 0.031805076}, {'day_of_week': 0.03459668}, {'hour': 0.044674285}]"}
# response
# label
# 0    138167
# 1     43933
# Name: count, dtype: int64
# [13:38:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 23 30 408 55
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-06-12', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 23, 'TPpct': Decimal('0'), 'FP': 30, 'FPpct': Decimal('0'), 'TN': 408, 'TNpct': Decimal('0'), 'FN': 55, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.7666666666666667'), 'evaluation_timeperiod': '2023-06-12_2023-06-16', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.04186251}, {'cmf': 0.035060447}, {'adx': 0.03550157}, {'roc': 0.056912865}, {'roc3': 0.08714098}, {'roc5': 0.064842716}, {'PCR': 0.043325167}, {'v': 0.03578101}, {'volume_10MA': 0.03612495}, {'volume_25MA': 0.035643324}, {'volume_10DDiff': 0.035434555}, {'volume_25DDiff': 0.03696781}, {'close_diff': 0.34405714}, {'v_diff_pct': 0.03012128}, {'day_of_week': 0.033912458}, {'hour': 0.04731128}]"}
# response
# label
# 0    139553
# 1     44047
# Name: count, dtype: int64
# [13:41:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 66 6 312 96
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-06-19', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 66, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 312, 'TNpct': Decimal('0'), 'FN': 96, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('11.0'), 'evaluation_timeperiod': '2023-06-19_2023-06-23', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.040436853}, {'cmf': 0.035508785}, {'adx': 0.03580083}, {'roc': 0.055703685}, {'roc3': 0.085836396}, {'roc5': 0.056789115}, {'PCR': 0.044315662}, {'v': 0.0369002}, {'volume_10MA': 0.036171712}, {'volume_25MA': 0.03667989}, {'volume_10DDiff': 0.03593946}, {'volume_25DDiff': 0.038329776}, {'close_diff': 0.34839672}, {'v_diff_pct': 0.03161887}, {'day_of_week': 0.03444643}, {'hour': 0.04712556}]"}
# response
# label
# 0    140969
# 1     44131
# Name: count, dtype: int64
# [13:44:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 14 25 543 28
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-06-26', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 14, 'TPpct': Decimal('0'), 'FP': 25, 'FPpct': Decimal('0'), 'TN': 543, 'TNpct': Decimal('0'), 'FN': 28, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.56'), 'evaluation_timeperiod': '2023-06-26_2023-06-30', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.03921453}, {'cmf': 0.033294015}, {'adx': 0.035274513}, {'roc': 0.05428736}, {'roc3': 0.08208102}, {'roc5': 0.06553337}, {'PCR': 0.04306735}, {'v': 0.037486244}, {'volume_10MA': 0.0350835}, {'volume_25MA': 0.034625456}, {'volume_10DDiff': 0.034584433}, {'volume_25DDiff': 0.037619904}, {'close_diff': 0.3490393}, {'v_diff_pct': 0.03463431}, {'day_of_week': 0.03292703}, {'hour': 0.051247638}]"}
# response
# label
# 0    141881
# 1     44419
# Name: count, dtype: int64
# [13:47:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "num_round", "silent" } are not used.
#
# 6 6 282 72
# {'model_name': 'inv_alerts_vdiff_lossP_weekly:fulltrain_fixedvDiff_tuned', 'deployment_date': '2023-07-03', 'algorithm_type': 'xgboost', 'dataset': 'inv_alerts_standard', 'TP': 6, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 282, 'TNpct': Decimal('0'), 'FN': 72, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0'), 'evaluation_timeperiod': '2023-07-03_2023-07-07', 'live': False, 'hyperparameters': {"{'subsample': 0.6, 'num_round': 500, 'min_child_weight': 8, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 8, 'colsample_bytree': 0.6}"}, 'features': {"'rsi','cmf','adx','roc','roc3','roc5','PCR','v','volume_10MA','volume_25MA','volume_10DDiff','volume_25DDiff','close_diff', 'v_diff_pct','day_of_week','hour'"}, 'target': 'three_max > 3', 'feature_importances': "[{'rsi': 0.039470457}, {'cmf': 0.033860855}, {'adx': 0.036843505}, {'roc': 0.056427937}, {'roc3': 0.08138985}, {'roc5': 0.06137081}, {'PCR': 0.04416968}, {'v': 0.035474636}, {'volume_10MA': 0.03532329}, {'volume_25MA': 0.035892226}, {'volume_10DDiff': 0.03538474}, {'volume_25DDiff': 0.03775446}, {'close_diff': 0.34673238}, {'v_diff_pct': 0.034146085}, {'day_of_week': 0.035214227}, {'hour': 0.05054487}]"}
# response
