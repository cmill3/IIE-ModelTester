# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler
import pytz
import warnings
warnings.filterwarnings('ignore')

# %%
s3 = boto3.client('s3')
STRATEGY = 'BFC_1D'
training_bucket = "icarus-research-data"
training_prefix = 'training_datasets/expanded_1d_datasets/'

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

index = ["QQQ","SPY","IWM","TLT"]
test_lag = ["DAL","UAL","VZ","T","AAL","AMC"]
train_lag = ["AMC"]

# big_fish =  [
#             "AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","PLTR","BAC","AAPL","NFLX","ABNB","CRWD","SHOP","FB","CRM",
#             "MSFT","F","V","MA","JNJ","DIS","JPM","INTC","ADBE","BA","CVX","MRNA","PFE","SNOW","SOFI",'META',
#             ]

# bf_plus = ["AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","PLTR","BAC","AAPL","NFLX","ABNB","CRWD","SHOP","FB","CRM",
#             "MSFT","F","V","MA","JNJ","DIS","JPM","INTC","ADBE","BA","CVX","MRNA","PFE","SNOW","NKE",'META',
#             'C','TGT','MMM','SQ','PANW','DAL','CSCO','UBER','SBUX']


all_symbols = ['ZM', 'UBER', 'CMG', 'AXP', 'TDOC', 'UAL', 'DAL', 'MMM', 'PEP', 'GE', 'RCL', 'MRK',
 'HD', 'LOW', 'VZ', 'PG', 'TSM', 'GOOG', 'GOOGL', 'AMZN', 'BAC', 'AAPL', 'ABNB',
 'CRM', 'MSFT', 'F', 'V', 'MA', 'JNJ', 'DIS', 'JPM', 'ADBE', 'BA', 'CVX', 'PFE',
 'META', 'C', 'CAT', 'KO', 'MS', 'GS', 'IBM', 'CSCO','TSLA','LCID','NIO','WFC',
 'TGT', 'COST', 'RIVN', 'COIN', 'SQ', 'SHOP', 'DOCU', 'ROKU', 'TWLO', 'DDOG', 'ZS', 'NET',
 'OKTA', 'UPST', 'ETSY', 'PINS', 'FUTU', 'SE', 'BIDU', 'JD', 'BABA', 'RBLX', 'AMD',
 'NVDA', 'PYPL', 'PLTR', 'NFLX', 'CRWD', 'INTC', 'MRNA', 'SNOW', 'SOFI', 'PANW',
 'ORCL','WBD','ARM','SNAP','BILI','AAL','CCL','NCLH','LYFT','BIDU','JD','BABA','HD','LOW',
 'SBUX','NKE','AFFRM','WMT']

high_vol = ['ZM', 'UBER', 'TDOC', 'UAL', 'RCL', 'AMZN', 'ABNB', 'META', 'TSLA',
       'LCID', 'NIO', 'RIVN', 'SQ', 'SHOP', 'DOCU', 'ROKU',
       'TWLO', 'DDOG', 'ZS', 'NET', 'OKTA', 'ETSY', 'PINS',
       'FUTU', 'SE', 'RBLX', 'AMD', 'NVDA', 'PYPL', 'PLTR', 'NFLX',
       'CRWD', 'MRNA', 'SNOW', 'SOFI', 'WBD', 'ARM', 'SNAP', 'BILI',
       'AAL', 'CCL', 'NCLH', 'LYFT', 'BIDU', 'JD', 'BABA', 'MU', 'AMAT',
       'DKNG', 'CZR', 'VXX']

mid_vol =['CMG', 'AXP', 'DAL', 'GE', 'TSM', 'GOOG', 'GOOGL', 'BAC', 'AAPL',
       'CRM', 'MSFT', 'F', 'DIS', 'ADBE', 'BA', 'CVX', 'C', 'CAT', 'MS',
       'WFC', 'TGT', 'INTC', 'PANW', 'ORCL', 'LOW', 'SBUX', 'NKE', 'QCOM',
       'AVGO', 'TXN', 'MGM', 'XOM']

low_vol = ['MMM', 'MRK', 'HD', 'VZ', 'V', 'MA', 'JPM',
       'PFE', 'GS', 'IBM', 'CSCO', 'WMT', 'COST', 'QQQ', 'SPY',
       'TLT', 'IWM']

bfpidx = ["AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","BAC","AAPL","FB","DIS"
          "MSFT","INTC","PFE","SNOW",'META','C','XOM',"QQQ","SPY","IWM","TLT"]


bf2 = ['QQQ','IWM','AAPL','NVDA','AMD','AMZN','SPY','MSFT','GOOG','GOOGL','C','BAC',
      'JPM','XOM','CVX','CSCO','INTC','DIS','IBM','BA', 'V','AXP','PYPL','ADBE','F','GM']

GE = [
    'QQQ','SPY','IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD','SHOP'
    'AXP', 'AAPL', 'BAC', 'BA', 'CVX', 'CSCO', 'C', 'DIS', 'XOM', 
    'GM', 'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA', 'PYPL','PANW','ADBE'
    'TSLA', 'V', 'SQ', 'TSM', 'QCOM', 'UBER', 'SNOW', 'PLTR', 'ABNB',
    "FB",'META',"TGT","NKE","SBUX","ORCL","DDOG","JNJ","AVGO","COST"
    ]
BF3 = ['QQQ', 'SPY', 'IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD', 'AAPL', 'BAC',
       'BA', 'C', 'DIS', 'XOM', 'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA',
       'TSLA', 'V', 'TSM', 'QCOM', 'SNOW', 'TGT', 'NKE', 'SBUX', 'ORCL',
       'PYPL', 'SQ', 'UBER', 'PLTR', 'ABNB', 
       'META'
       ]
PE = ['SPY', 'TSLA', 'QQQ', 'AMD', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN','TSM','BAC','C','XOM','DIS','SBUX','PYPL','NKE']
PE2 = ['SPY', 'TSLA', 'QQQ', 'AMD', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN','TSM','XOM','DIS','PYPL','BA','NFLX','NVDA','GOOG',
       'META'
       ]
## NVDA,NFLX,GOOG,META,AVGO,COST w/ increased capital

BF3_TRIMMED = [
    'QQQ','SPY','IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD', 
    'AAPL', 'BAC', 'BA', 'C', 'DIS', 'XOM', 
    'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA', 'PYPL',
    'TSLA', 'V', 'SQ', 'TSM', 'QCOM', 'UBER', 'SNOW', 'PLTR', 'ABNB',
    "FB",'META',"TGT","NKE","SBUX","ORCL"
    ]

t11 = ['NVDA', 'SPY', 'TSLA', 'QQQ', 'AMD', 'GOOG', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN']

# %%
def configure_dates(data,strategy):
    if strategy in ["CDBFC","CDBFP"]:
        data = data.loc[data['day_of_week'].isin([0,1,2])] 
    elif strategy in ["CDBFC_1D","CDBFP_1D"]:
        data = data.loc[data['day_of_week'].isin([0,1,2,3])]
    return data

def pull_training_data_local(end_date,strategy):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/BF/2015-01-01_2024-05-03EXP.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data['one_max_vol'] = (data['one_max']/data['return_vol_5D']).round(3)
    data['three_max_vol'] = (data['three_max']/data['return_vol_5D']).round(3)
    data['one_min_vol'] = (data['one_min']/data['return_vol_5D']).round(3)
    data['three_min_vol'] = (data['three_min']/data['return_vol_5D']).round(3)    
    # data['one_max_vol30'] = (data['one_max']/data['return_vol_30D']).round(3)
    # data['three_max_vol30'] = (data['three_max']/data['return_vol_30D']).round(3)
    # data['one_min_vol30'] = (data['one_min']/data['return_vol_30D']).round(3)
    # data['three_min_vol30'] = (data['three_min']/data['return_vol_30D']).round(3)    
    # data['cd_vol'] = (data['close_diff']/data['return_vol_10D']).round(3)
    # data['cd_vol3'] = (data['close_diff3']/data['return_vol_10D']).round(3)
    # data['cd_vol30'] = (data['close_diff']/data['return_vol_30D']).round(3)
    data['cd_vol'] = (data['price_change_D']/data['return_vol_5D']).round(3)
    data['cd_vol3'] = (data['price_3Ddiff']/data['return_vol_5D']).round(3)
    # data['cd_vol330'] = (data['close_diff3']/data['return_vol_30D']).round(3)
    data = data.loc[data['symbol'].isin(PE2)]
    data = configure_dates(data,strategy)
    data.replace([np.inf, -np.inf], 0, inplace=True)
    return data


def pull_validation_data_local(end_date,start_date,strategy):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/BF/2015-01-01_2024-05-03EXP.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data['one_max_vol'] = (data['one_max']/data['return_vol_5D']).round(3)
    data['three_max_vol'] = (data['three_max']/data['return_vol_5D']).round(3)
    data['one_min_vol'] = (data['one_min']/data['return_vol_5D']).round(3)
    data['three_min_vol'] = (data['three_min']/data['return_vol_5D']).round(3)    
    # data['one_max_vol30'] = (data['one_max']/data['return_vol_30D']).round(3)
    # data['three_max_vol30'] = (data['three_max']/data['return_vol_30D']).round(3)
    # data['one_min_vol30'] = (data['one_min']/data['return_vol_30D']).round(3)
    # data['three_min_vol30'] = (data['three_min']/data['return_vol_30D']).round(3)    
    data['cd_vol'] = (data['price_change_D']/data['return_vol_5D']).round(3)
    data['cd_vol3'] = (data['price_3Ddiff']/data['return_vol_5D']).round(3)
    # data['cd_vol30'] = (data['close_diff']/data['return_vol_30D']).round(3)
    # data['cd_vol330'] = (data['close_diff3']/data['return_vol_30D']).round(3)
    data = data.loc[data['dt'] <= end_date]
    data = data.loc[data['dt'] >= start_date]
    data = data.loc[data['symbol'].isin(PE2)]
    data = configure_dates(data,strategy)
    data.replace([np.inf, -np.inf], 0, inplace=True)
    return data

# %%
def build_date_list(start_date, end_date):
    print(start_date, end_date)
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_validation_dates_local(deployment_date):
    end_date = deployment_date + timedelta(days=5)
    return end_date

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] < target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] < target_value).astype(int)

    # dataset = dataset.round(3)
    # validation_dataset = validation_dataset.round(3)

    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']


    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    print(y.value_counts())
    predictions = xgb_model.predict(X_validate)
    probabilities = xgb_model.predict_proba(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,str(fi_list), predictions, probabilities


def train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] < target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] < target_value).astype(int)

    dataset = dataset.round(5)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']
    

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,"str(fi_list)", predictions, "probabilities"

# %%
# def model_runner_v2RM(model_name, dataset_name, title, features, target_label, target_percentile, start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
#     validation_end_date = build_validation_dates_local(deployment_date)
#     validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
#     dataset = pull_training_data_local(end_date, dataset_start_date)
#     dates_list = pull_gmm_labels(deployment_date)
#     rm_dataset = dataset.loc[dataset['dt'].isin(dates_list)]
#     target_value = rm_dataset[target_label].quantile(target_percentile).round(3)
#     print(target_value)
#     print(len(rm_dataset)/len(dataset))
#     tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, rm_dataset, validation_dataset, target_label, target_value, hyperparams)
#     response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
#     validation_dataset['probabilities'] = probabilities[:,1]
#     validation_dataset['predictions'] = predictions
#     validation_dataset['target_value'] = target_value
#     validation_dataset['target_pct'] = validation_dataset['target_value'] * validation_dataset['return_vol_10D']
#     validation_csv = validation_dataset.to_csv()
#     put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
#     return response

def model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile, start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
    validation_end_date = build_validation_dates_local(deployment_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date, title)
    dataset = pull_training_data_local(end_date, title)
    target_value = dataset[target_label].quantile(target_percentile).round(3)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
    validation_dataset['probabilities'] = probabilities[:,1]
    validation_dataset['predictions'] = predictions
    validation_dataset['target_value'] = target_value
    validation_dataset['target_pct'] = validation_dataset['target_value'] * validation_dataset['return_vol_10D']
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    return response

def model_runner_temporal_simulation(features, target_label, target_percentile,dataset_start_date,end_date,deployment_date,hyperparams,strategy):
    validation_end_date = build_validation_dates_local(deployment_date)
    dataset = pull_training_data_local(end_date, strategy)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date, strategy)
    # dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    # validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    # dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    # validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    target_value = dataset[target_label].quantile(target_percentile).round(3)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    return tp, fp, fn, tn 

# def model_runner_data(start_date,end_date):
#     dates = build_date_list(start_date, end_date)
#     key_list = build_query_keys(dates)
#     print(key_list[-1])
#     train_data = create_training_data_local(key_list, 'full_alerts/weekly_exp_alerts/', 'inv-alerts', 'cdvol_gainers', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
#     val_data = create_validation_data_local(key_list, 'full_alerts/trading_symbols_alerts/', 'inv-alerts', 'cdvol_gainers', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
#     return "train_data", "val_data"

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=17),
            "dataset_start": datetime(2018,1,1)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

def pull_gmm_labels(date):
    date_str = date.strftime('%Y-%m-%d')
    data_20d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm20d_labels_RM2/{date_str}.csv')
    data_10d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm10d_labels_RM2/{date_str}.csv')
    data_3d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm3d_labels_RM2/{date_str}.csv')

    data_20d = pd.read_csv(data_20d.get("Body"))
    data_10d = pd.read_csv(data_10d.get("Body"))
    data_3d = pd.read_csv(data_3d.get("Body"))

    data_20d['dt'] = pd.to_datetime(data_20d['date'])
    data_10d['dt'] = pd.to_datetime(data_10d['date'])
    data_3d['dt'] = pd.to_datetime(data_3d['date'])

    label_20d = data_20d['labels'].iloc[-1]
    label_10d = data_10d['labels'].iloc[-1]
    label_3d = data_3d['labels'].iloc[-1]

    dates_20d = data_20d['dt'].loc[data_20d['labels'] == label_20d].tolist()
    dates_10d = data_10d['dt'].loc[data_10d['labels'] == label_10d].tolist()
    dates_3d = data_3d['dt'].loc[data_3d['labels'] == label_3d].tolist()

    # combined_list = list(set(dates_20d  + dates_3d))
    return dates_20d

# %%
target_percentile = 0.4
title = 'CDBFP_1D'
model_name = f'{title}:TSSIM2.4_PE_HYPOPT2_{target_percentile}'
dataset_name = f'TSSIM2.4_PE_HYPOPT2_{target_percentile}'
hyperparams = {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.175450169582592, 'gamma': 0.0, 'colsample_bytree': 0.9977174627230534}
features = ['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 
            'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 
            'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 
            'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']

target_label = 'one_min_vol'


dataset_start_date = datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')) 
dates_list = build_evaluation_period(datetime(2022,8,15), datetime(2024,5,3))
# date = dates_list[-1]
# print(date)
# response = model_runner_data(start_date=datetime(2018,1,1),end_date=datetime(2023,12,23))

# dataset = pull_training_data_local(start_date=datetime(2018,1,1),end_date=datetime(2023,12,23))
# print(dataset.columns.tolist())

for date in dates_list:
    print(date)
    response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile,"dataset_start_date",date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])
# Out:
# {'deployment_date': datetime.datetime(2022, 8, 15, 0, 0), 'dataset_end': datetime.datetime(2022, 7, 29, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    93461
# 1    62233
# Name: count, dtype: int64
# 81 37 174 140
# {'model_name': 'CDBFP_1D:TSSIM2.4_PE_HYPOPT2_0.4', 'deployment_date': '2022-08-15', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_PE_HYPOPT2_0.4', 'TP': 81, 'TPpct': Decimal('0'), 'FP': 37, 'FPpct': Decimal('0'), 'TN': 174, 'TNpct': Decimal('0'), 'FN': 140, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.189189189189189'), 'evaluation_timeperiod': '2022-08-15_2022-08-19', 'live': False, 'hyperparameters': {"{'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.175450169582592, 'gamma': 0.0, 'colsample_bytree': 0.9977174627230534}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-1.013+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.023021229}, {'bb_category': 0.02317009}, {'return_vol_5D_diff': 0.023085587}, {'close_10DMA_diff': 0.019856853}, {'return_vol_5D': 0.084856585}, {'price_range_H': 0.05836169}, {'price_20Ddiff': 0.019256018}, {'roc_vol5': 0.014315753}, {'DIplus': 0.026626593}, {'macd_15MA': 0.016088907}, {'volume_sum15_10DMA_diff': 0.013123066}, {'roc_vol_15MA_diff': 0.020254634}, {'range_vol_stddev20D_diff': 0.015365004}, {'volume_15MA_diff': 0.0162723}, {'volume_sum15': 0.018426962}, {'roc_15MA_diff': 0.016742637}, {'price_10Ddiff': 0.01715824}, {'Low-Close': 0.019525703}, {'roc_vol': 0.022456704}, {'SPY_diff_H': 0.0}, {'roc8H': 0.013288028}, {'DIminus': 0.014744623}, {'day_of_month': 0.023517556}, {'ret_vol_stddev20D_diff': 0.03703667}, {'High-Low': 0.026240017}, {'PrevClose-L': 0.026350692}, {'roc8H_15MA_diff': 0.019224735}, {'High-Close': 0.01572466}, {'cmf_15MA_diff': 0.015439816}, {'roc5': 0.021281727}, {'max_30_diff': 0.022981782}, {'close_20DMA_diff': 0.02274326}, {'return_vol_10D_diff': 0.025659835}, {'roc3': 0.030201996}, {'rsi': 0.020993643}, {'cmf': 0.015668867}, {'day_of_week': 0.025523495}, {'return_vol_8H': 0.038420506}, {'return_vol_8H_diff': 0.010360541}, {'SPY_5d_diff': 0.019386038}, {'H-L': 0.018137466}, {'bb_spread': 0.035011385}, {'SPY_20d_diff': 0.017142892}, {'price_range_8MA_diff': 0.016955279}]"}
# {'deployment_date': datetime.datetime(2022, 8, 22, 0, 0), 'dataset_end': datetime.datetime(2022, 8, 5, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    93733
# 1    62393
# Name: count, dtype: int64
# 8 9 297 118
# {'model_name': 'CDBFP_1D:TSSIM2.4_PE_HYPOPT2_0.4', 'deployment_date': '2022-08-22', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_PE_HYPOPT2_0.4', 'TP': 8, 'TPpct': Decimal('0'), 'FP': 9, 'FPpct': Decimal('0'), 'TN': 297, 'TNpct': Decimal('0'), 'FN': 118, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.8888888888888888'), 'evaluation_timeperiod': '2022-08-22_2022-08-26', 'live': False, 'hyperparameters': {"{'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.175450169582592, 'gamma': 0.0, 'colsample_bytree': 0.9977174627230534}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-1.012+one_min_vol', 'feature_importances': "[{'min_30_diff': 0
one_min_vol', 'feature_importances': "[{'min_30_diff': 0.019126365}, {'bb_category': 0.03436809}, {'return_vol_5D_diff': 0.010438403}, {'close_10DMA_diff': 0.015345041}, {'return_vol_5D': 0.08918582}, {'price_range_H': 0.06514865}, {'price_20Ddiff': 0.020893732}, {'roc_vol5': 0.013382114}, {'DIplus': 0.02810801}, {'macd_15MA': 0.020980487}, {'volume_sum15_10DMA_diff': 0.015058785}, {'roc_vol_15MA_diff': 0.016452055}, {'range_vol_stddev20D_diff': 0.016445244}, {'volume_15MA_diff': 0.015950315}, {'volume_sum15': 0.018623725}, {'roc_15MA_diff': 0.017407259}, {'price_10Ddiff': 0.017762022}, {'Low-Close': 0.016417164}, {'roc_vol': 0.021675833}, {'SPY_diff_H': 0.0}, {'roc8H': 0.018609496}, {'DIminus': 0.017362878}, {'day_of_month': 0.021391459}, {'ret_vol_stddev20D_diff': 0.047812592}, {'High-Low': 0.022552727}, {'PrevClose-L': 0.018176194}, {'roc8H_15MA_diff': 0.013266271}, {'High-Close': 0.021579603}, {'cmf_15MA_diff': 0.015691994}, {'roc5': 0.01985667}, {'max_30_diff': 0.025486032}, {'close_20DMA_diff': 0.009777437}, {'return_vol_10D_diff': 0.017740937}, {'roc3': 0.023252692}, {'rsi': 0.012832867}, {'cmf': 0.015116631}, {'day_of_week': 0.02344538}, {'return_vol_8H': 0.03718002}, {'return_vol_8H_diff': 0.009516293}, {'SPY_5d_diff': 0.020112738}, {'H-L': 0.039467324}, {'bb_spread': 0.041357134}, {'SPY_20d_diff': 0.01856407}, {'price_range_8MA_diff': 0.01708148}]"}

# %%
def run_temporal_simulation(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date,strategy):
    tp_avg_list = []
    gross_accuracy_list = []
    # fn_list = []
    # tn_list = []
    
    hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
    dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
    # date = dates_list[-1]
    # response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
    for date in dates_list:
        tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams,strategy)
        tp_avg_list.append(tp)
        gross_accuracy_list.append((tp-fp))

    return tp_avg_list, gross_accuracy_list

def run_temporal_simulation_hyperparams(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date,strategy,hyperparams):
    tp_avg_list = []
    gross_accuracy_list = []
    
    dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
    for date in dates_list:
        tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams,strategy)
        tp_avg_list.append(tp)
        gross_accuracy_list.append((tp-fp))

    return tp_avg_list, gross_accuracy_list

# %%
# number_of_simulations = 150
# now = datetime.now()
# title = 'CDBFP_1D'
# # total_feature_list = ['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'v', 'o', 'c', 'h', 'l',
# #  'date', 'hour', 'symbol', 't', 'price7', 'price14', 'adjusted_volume', 'vol7', 'vol14', 'rsi', 
# # 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close', 'oneD_returns_close', 'range_vol', 
# # 'range_vol5MA', 'range_vol10MA', 'range_vol25MA', 'oneD_stddev50', 'threeD_stddev50', 'cmf', 'close_diff', 
# # 'close_diff3', 'close_diff5', 'v_diff_pct', 'adx', 'volume_10MA', 'volume_25MA', 'price_10MA', 'price_25MA',
# # 'volume_10DDiff', 'volume_25DDiff', 'price_10DDiff', 'price_25DDiff', 'one_max', 'one_min', 'one_pct', 
# # 'three_max', 'three_min', 'three_pct', 'SPY_diff', 'SPY_diff3', 'SPY_diff5', 'SPY_1D', 'SPY_3D', 'SPY_5D', 
# # 'vw', 'n', 'return_vol_15M', 'volume_vol_15M', 'return_vol_30M', 'volume_vol_30M', 'return_vol_60M', 
# # 'volume_vol_60M', 'return_vol_120M', 'volume_vol_120M', 'return_vol_240M', 'volume_vol_240M', 
# # 'return_vol_450M', 'volume_vol_450M', '15min_vol_diff', '15min_vol_diff_pct', 'min_vol_diff', 
# # 'min_vol_diff_pct', 'min_volume_vol_diff', 'min_volume_vol_diff_pct', 'return_vol_4H', 'return_vol_8H', 
# # 'return_vol_16H', 'volume_vol_4H', 'volume_vol_8H', 'volume_vol_16H', 'hour_vol_diff', 'hour_vol_diff_pct', 
# # 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_3D', 'return_vol_5D', 'return_vol_10D', 
# # 'return_vol_30D', 'volume_vol_3D', 'volume_vol_5D', 'volume_vol_10D', 'volume_vol_30D', 'daily_vol_diff', 
# # 'daily_vol_diff_pct', 'daily_vol_diff30', 'daily_vol_diff_pct30', 'daily_volume_vol_diff', 'daily_volume_vol_diff_pct', 
# # 'daily_volume_vol_diff30', 'daily_volume_vol_diff_pct30', 'cd_vol', 'cd_vol3', 'roc_diff', 'range_vol_diff5', 
# # 'close_diff_deviation3', 'close_diff_deviation', 'day_of_week', 'day_of_month', 'month', 'year', 'dt', 'one_max_vol', 
# # 'three_max_vol', 'one_min_vol', 'three_min_vol']

# testing_features = ['hour', 'price7', 'price14','vol7', 'vol14', 'rsi', 
# 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close', 'oneD_returns_close', 'range_vol', 
# 'range_vol5MA', 'range_vol10MA', 'range_vol25MA', 'oneD_stddev50', 'threeD_stddev50', 'cmf', 'close_diff', 
# 'close_diff3', 'close_diff5','adx',
# 'volume_10DDiff', 'volume_25DDiff', 'price_10DDiff', 'price_25DDiff', 
# 'SPY_diff', 'SPY_diff3', 'SPY_diff5', 'SPY_1D', 'SPY_3D', 'SPY_5D', 
# 'return_vol_15M', 'volume_vol_15M', 'return_vol_30M', 'volume_vol_30M', 'return_vol_60M', 
# 'volume_vol_60M', 'return_vol_120M', 'volume_vol_120M', 'return_vol_240M', 'volume_vol_240M', 
# 'return_vol_450M', 'volume_vol_450M', '15min_vol_diff', '15min_vol_diff_pct', 'min_vol_diff', 
# 'min_vol_diff_pct', 'min_volume_vol_diff', 'min_volume_vol_diff_pct', 'return_vol_4H', 'return_vol_8H', 
# 'return_vol_16H', 'volume_vol_4H', 'volume_vol_8H', 'volume_vol_16H', 'hour_vol_diff', 'hour_vol_diff_pct', 
# 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_3D', 'return_vol_5D', 'return_vol_10D', 
# 'return_vol_30D', 'volume_vol_3D', 'volume_vol_5D', 'volume_vol_10D', 'volume_vol_30D', 'daily_vol_diff', 
# 'daily_vol_diff_pct', 'daily_vol_diff30', 'daily_vol_diff_pct30', 'daily_volume_vol_diff', 'daily_volume_vol_diff_pct', 
# 'daily_volume_vol_diff30', 'daily_volume_vol_diff_pct30', 'roc_diff', 'range_vol_diff5', 
# 'close_diff_deviation3', 'close_diff_deviation', 'day_of_week', 'day_of_month', 'month','bb_spread','bb_trend','macd']

# # testing_features = ['hour_vol_diff', 'range_vol10MA', 'hour_volume_vol_diff_pct','threeD_returns_close', 'volume_10DDiff', 
# #             '15min_vol_diff', 'close_diff', 'month', 'close_diff_deviation', 'volume_vol_8H', 'return_vol_4H', 'roc3', 'range_vol5MA', 'roc_diff', 'volume_25DDiff', 
# #             'rsi5', 'price7', 'adx', 'threeD_stddev50', 'day_of_week', 'return_vol_8H', 'min_volume_vol_diff_pct', 'range_vol25MA', 'oneD_returns_close', 'roc5', 'close_diff3', 
# #             'hour_vol_diff_pct', 'vol14', 'volume_vol_30M', 'return_vol_5D', 'daily_vol_diff_pct', 'daily_vol_diff30', 'return_vol_10D', 
# #             'volume_vol_10D', 'price14', 'hour', 'vol7','cd_vol','cd_vol3','bb_spread','bb_trend','macd']

# target_label = 'one_min_vol'
# target_percentile = 0.45
# results_array = []

# i = 0
# while i < number_of_simulations:
#        model_name = f"{title}_temporal_simulation_{i}"
#        print(model_name)
#        random_int = random.randint(20, 42)
#        features = random.sample(testing_features, random_int)
#        print(features)
#        tp_avg_list, gross_accuracy_list = run_temporal_simulation(features, target_label, target_percentile, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2021,1,4), evaluation_end_date=datetime(2023,12,23))        
#        tp_avg = sum(tp_avg_list)/len(tp_avg_list)
#        gross_accuracy = sum(gross_accuracy_list)/len(gross_accuracy_list)
#        print(tp_avg, gross_accuracy)
#        print()
#        results_array.append({"model_name": model_name, "features": features, "tp_avg": tp_avg, "gross_accuracy": gross_accuracy,"num_features": random_int,"median_tp": np.median(tp_avg_list), "median_gross_accuracy": np.median(gross_accuracy_list)})
#        i += 1

# results_df = pd.DataFrame(results_array)
# results_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)

# %% [markdown]
# ## Genetic Algorithm Feature Selection

# %%
# import random
# import numpy as np
# import pandas as pd
# from datetime import datetime

# # Define the total feature list and other constants
# total_feature_list = ['hour','volume_15MA_diff',  
#                     'volume_sum15_5DMA_diff', 'volume_sum15_10DMA_diff', 'price_change_absolute_H', 
#                       'price_change_H', 'price_range_H', 'price_range_8MA_diff', 'return_vol_8H', 'return_vol_8H_diff', 
#                       'ret_vol_stddev40H_diff','volume_vol_stddev40H_diff', 'range_vol_stddev40H_diff', 'rsiH', 
#                       'rsiH_15MA', 'rsiH_15MA_diff', 'roc8H', 'roc8H_15MA', 'roc8H_15MA_diff', 'price_change_D', 'price_range_D', 
#                       'price_range_5DMA', 'price_range_5DMA_diff', 'return_vol_5D', 'return_vol_5D_diff', 'return_vol_10D', 'return_vol_10D_diff', 'ret_vol_stddev20D', 
#                       'ret_vol_stddev20D_diff', 'range_vol_stddev20D', 'range_vol_stddev20D_diff', 'price_3Ddiff', 'price_5Ddiff', 'price_10Ddiff', 'price_20Ddiff', 
#                       'price_3D20D_diff','close_20DMA_diff', 'close_10DMA', 'close_10DMA_diff', 'rsi', 'rsi_15MA', 'rsi_15MA_diff', 'roc', 'roc3', 'roc5', 
#                       'roc_15MA', 'roc_15MA_diff', 'High-Low', 'High-Close', 'Low-Close', 'TR', 'H-L', 'H-PrevClose', 'PrevClose-L', 'DMplus', 'DMminus', 'DIplus', 'DIminus', 
#                       'DX', 'adx', 'macd', 'macd_15MA', 'macd_15MA_diff', 'bbu', 'bbl', 'bbm', 'bb_spread', 'bb_trend', 'bb_category', 'cmf', 'cmf_15MA', 'cmf_15MA_diff', 
#                       'max_30', 'min_30', 'max_30_diff', 'min_30_diff', 'roc_vol', 'roc_vol3', 'roc_vol5', 'roc_vol_15MA', 'roc_vol_15MA_diff',
#                       'SPY_diff_H', 'SPY_diff_D', 'SPY_5d', 'SPY_20d', 'SPY_5d_diff', 'SPY_20d_diff', 'SPY_range_vol', 
#                       'day_of_week', 'day_of_month', 'cd_vol', 'cd_vol3']
# target_label = 'one_min_vol'
# target_percentile = 0.4
# number_of_generations = 10
# population_size = 10
# mutation_rate = 0.1
# title = 'CDBFP_1D'
# basic_results = []

# # Define your current best feature set
# current_best_features = ['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 
#             'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 
#             'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 
#             'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']

# def evaluate_performance(features):
#     print(features)
#     checked = []
#     for feature in features:
#         if feature not in checked:
#             checked.append(feature)
#         else:
#             print("Duplicate feature found")
#     # tp_avg_list, gross_accuracy_list = run_temporal_simulation(checked, target_label, target_percentile, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2021,1,4), evaluation_end_date=datetime(2024,4,20),strategy=title)
#     tp_avg_list, gross_accuracy_list = run_temporal_simulation(checked, target_label, target_percentile, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2021,1,4), evaluation_end_date=datetime(2021,1,25),strategy=title)
#     acc_median = np.median(gross_accuracy_list)
#     tp_avg = sum(tp_avg_list) / len(tp_avg_list)
#     gross_accuracy = sum(gross_accuracy_list) / len(gross_accuracy_list)
#     print(f"tp_avg: {tp_avg}, gross_accuracy: {gross_accuracy}, acc_median: {acc_median}")
#     print()
#     basic_results.append({"features": features, "tp_avg": tp_avg, "gross_accuracy": gross_accuracy,"num_features": len(features),"median_tp": np.median(tp_avg_list), "median_gross_accuracy": np.median(gross_accuracy_list)})
    # fitness = (1.1 * acc_median) + gross_accuracy
    # print(f"Fitness: {fitness}")
#     return fitness

# def initialize_population(feature_list, population_size, current_best_features):
#     population = [current_best_features]  # Start with the best known feature set
#     for _ in range(population_size - 1):  # Remaining population
#         num_features = random.randint(30, 45)
#         individual = random.sample(feature_list, num_features)
#         population.append(individual)
#     return population

# def select_parents(population, scores, num_parents):
#     parents = random.choices(population, weights=scores, k=num_parents)
#     return parents

# def crossover(parents):
#     crossover_point = random.randint(1, min(len(parents[0]), len(parents[1])) - 1)
#     child = parents[0][:crossover_point] + parents[1][crossover_point:]
#     return child

# def mutate(individual, feature_list, mutation_rate):
#     if random.random() < mutation_rate:
#         if random.random() < 0.5 and len(individual) > 1:  # Remove a feature
#             individual.pop(random.randint(0, len(individual) - 1))
#         else:  # Add a feature
#             possible_features = list(set(feature_list) - set(individual))
#             if possible_features:  # Ensure there are possible features to add
#                 new_feature = random.choice(possible_features)
#                 individual.append(new_feature)
#     return individual

# def genetic_algorithm(feature_list, population_size, generations, mutation_rate, current_best_features):
#     population = initialize_population(feature_list, population_size, current_best_features)
#     results_array = []

#     for generation in range(generations):
#         scores = [evaluate_performance(individual) for individual in population]
#         new_population = []

#         for _ in range(population_size // 2):
#             parents = select_parents(population, scores, 2)
#             child1 = mutate(crossover(parents), feature_list, mutation_rate)
#             child2 = mutate(crossover(parents), feature_list, mutation_rate)
#             new_population.extend([child1, child2])

#         population = new_population
#         print(f"Generation {generation + 1}: Best fitness = {max(scores)}")

#         # Save results of the current generation
#         best_individual = population[np.argmax(scores)]
#         best_score = max(scores)
#         results_array.append({"generation": generation + 1, "best_features": best_individual, "best_score": best_score})
#         print

#     return results_array

# # Run the genetic algorithm
# results = genetic_algorithm(total_feature_list, population_size, number_of_generations, mutation_rate, current_best_features)

# # Save the results
# now = datetime.now()
# results_df = pd.DataFrame(results)
# results_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
# basic_df = pd.DataFrame(basic_results)
# basic_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}_basic.csv', index=False)
# print("Optimization completed and results saved.")

# %% [markdown]
# ## Bayesian Hyperparamter Optimization

# %%
from skopt import gp_minimize
from skopt.space import Real, Integer, Categorical
from skopt.utils import use_named_args

# Define the hyperparameter search space
param_space = [
    Real(0.5, 1.0, name='subsample'),
    Integer(800, 2000, name='num_round'),
    Integer(1, 50, name='min_child_weight'),
    Integer(1, 20, name='max_depth'),
    Real(0.01, 0.3, name='learning_rate'),
    Real(0, 5, name='gamma'),
    Real(0.8, 1.0, name='colsample_bytree')
]

basic_results = []
target_label = 'one_min_vol'
target_percentile = 0.4
title = 'CDBFP_1D'
features = ['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 
            'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 
            'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 
           'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']

# Objective function to minimize (negative cross-validated accuracy)
@use_named_args(param_space)
def objective(**params):
    hyperparams = {
        'subsample': params['subsample'], 
        'num_round': params['num_round'], 
        'min_child_weight': params['min_child_weight'], 
        'max_depth': params['max_depth'], 
        'learning_rate': params['learning_rate'], 
        'gamma': params['gamma'], 
        'colsample_bytree': params['colsample_bytree']
    }
    print(hyperparams)
    tp_avg_list, gross_accuracy_list = run_temporal_simulation_hyperparams(
        features, target_label, target_percentile, 
        dataset_start_date=datetime(2018, 1, 1), 
        evaluation_start_date=datetime(2021, 1, 4), 
        # evaluation_end_date=datetime(2021, 1, 25),
        evaluation_end_date=datetime(2024, 4, 20),
        strategy=title, hyperparams=hyperparams
    )
    
    acc_median = np.median(gross_accuracy_list)
    tp_avg = sum(tp_avg_list) / len(tp_avg_list)
    gross_accuracy = sum(gross_accuracy_list) / len(gross_accuracy_list)
    
    print(f"tp_avg: {tp_avg}, gross_accuracy: {gross_accuracy}, acc_median: {acc_median}")
    print()
    basic_results.append({
        "features": hyperparams, 
        "tp_avg": tp_avg, 
        "gross_accuracy": gross_accuracy,
        "median_tp": np.median(tp_avg_list), 
        "median_gross_accuracy": np.median(gross_accuracy_list)
    })
    
    fitness = (1.3 * acc_median) + gross_accuracy
    print(f"Fitness: {fitness}")
    return -fitness  # Minimize negative fitness



# Perform Bayesian Optimization
result = gp_minimize(
    func=objective,
    dimensions=param_space,
    n_calls=500,
    n_random_starts=10,  # the number of random initialization points
    random_state=None
)

# Best hyperparameters found
best_hyperparameters = {dim.name: result.x[i] for i, dim in enumerate(param_space)}
print("Best Hyperparameters:", best_hyperparameters)

# Save the results to a CSV file
results_df = pd.DataFrame(result.x_iters, columns=[dim.name for dim in param_space])
results_df['Objective'] = result.func_vals
now = datetime.now()
title = 'Hyperparameter_Optimization'
results_df.to_csv(f'/Users/charlesmiller/Documents/hyp_opt_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
basic_df = pd.DataFrame(basic_results)
basic_df.to_csv(f'/Users/charlesmiller/Documents/hyp_opt_results/{title}/{now.year}_{now.month}_{now.day}_basic.csv', index=False)
# Out:
# {'subsample': 0.944647074352998, 'num_round': 1039, 'min_child_weight': 13, 'max_depth': 6, 'learning_rate': 0.08093255478932092, 'gamma': 0.17957073262674986, 'colsample_bytree': 0.8104514919188469}
# tp_avg: 52.27906976744186, gross_accuracy: 14.046511627906977, acc_median: 11.0
#
# Fitness: 25.046511627906977
#
# {'subsample': 0.8467778555296249, 'num_round': 849, 'min_child_weight': 25, 'max_depth': 3, 'learning_rate': 0.2974443068362055, 'gamma': 0.7420918384779658, 'colsample_bytree': 0.9237101036900851}
# tp_avg: 56.075581395348834, gross_accuracy: 13.837209302325581, acc_median: 6.0
#
# Fitness: 19.837209302325583
#
# {'subsample': 0.6243950655454364, 'num_round': 1521, 'min_child_weight': 23, 'max_depth': 2, 'learning_rate': 0.26466086891089324, 'gamma': 3.599835743432335, 'colsample_bytree': 0.996074646518094}
# tp_avg: 49.343023255813954, gross_accuracy: 13.94186046511628, acc_median: 9.0
#
# Fitness: 22.941860465116278
#
# {'subsample': 0.52625672228966, 'num_round': 931, 'min_child_weight': 5, 'max_depth': 12, 'learning_rate': 0.19332138408534266, 'gamma': 4.709912632502534, 'colsample_bytree': 0.872674010617295}
# tp_avg: 65.33720930232558, gross_accuracy: 3.5697674418604652, acc_median: 3.5
#
# Fitness: 7.069767441860465
#
# {'subsample': 0.9806833784556233, 'num_round': 1818, 'min_child_weight': 18, 'max_depth': 9, 'learning_rate': 0.04056933573045933, 'gamma': 1.5569821133105242, 'colsample_bytree': 0.8017017313643559}
# tp_avg: 50.30813953488372, gross_accuracy: 13.540697674418604, acc_median: 9.0
#
# Fitness: 22.540697674418603
#
# {'subsample': 0.7578346038657295, 'num_round': 1145, 'min_child_weight': 24, 'max_depth': 2, 'learning_rate': 0.027659673642674368, 'gamma': 2.178520993499515, 'colsample_bytree': 0.9288385734854246}
# tp_avg: 18.08139534883721, gross_accuracy: 8.36046511627907, acc_median: 2.0
#
# Fitness: 10.36046511627907
#
# {'subsample': 0.8807601580281565, 'num_round': 1278, 'min_child_weight': 47, 'max_depth': 16, 'learning_rate': 0.18108740991745587, 'gamma': 1.8406018467204264, 'colsample_bytree': 0.949937337567546}
# tp_avg: 67.28488372093024, gross_accuracy: 4.383720930232558, acc_median: 3.5
#
# Fitness: 7.883720930232558
#
# {'subsample': 0.9383241179765043, 'num_round': 1306, 'min_child_weight': 5, 'max_depth': 12, 'learning_rate': 0.18197354553601522, 'gamma': 3.3919888961157723, 'colsample_bytree': 0.8819858656461399}
# tp_avg: 63.151162790697676, gross_accuracy: 6.52906976744186, acc_median: 6.5
#
# Fitness: 13.029069767441861
#
# {'subsample': 0.7011752897479044, 'num_round': 1812, 'min_child_weight': 25, 'max_depth': 1, 'learning_rate': 0.22379408194701395, 'gamma': 2.3190491636835753, 'colsample_bytree': 0.9606221500810975}
# tp_avg: 34.97674418604651, gross_accuracy: 12.761627906976743, acc_median: 6.0
#
# Fitness: 18.76162790697674
#
# {'subsample': 0.6565743421120914, 'num_round': 1984, 'min_child_weight': 12, 'max_depth': 8, 'learning_rate': 0.13803482077130344, 'gamma': 1.240541020714714, 'colsample_bytree': 0.9354261920329885}
# tp_avg: 62.383720930232556, gross_accuracy: 8.720930232558139, acc_median: 9.5
#
# Fitness: 18.22093023255814
#
# {'subsample': 1.0, 'num_round': 1824, 'min_child_weight': 33, 'max_depth': 7, 'learning_rate': 0.12239361548176508, 'gamma': 4.682614937329991, 'colsample_bytree': 0.8}
# tp_avg: 57.627906976744185, gross_accuracy: 12.081395348837209, acc_median: 9.5
#
# Fitness: 21.58139534883721
#
# {'subsample': 0.9510087737517505, 'num_round': 826, 'min_child_weight': 32, 'max_depth': 6, 'learning_rate': 0.08091212825143217, 'gamma': 1.2045767869339086, 'colsample_bytree': 0.811478568122406}
# tp_avg: 51.43023255813954, gross_accuracy: 13.686046511627907, acc_median: 10.0
#
# Fitness: 23.686046511627907
#
# {'subsample': 0.9438347500156123, 'num_round': 961, 'min_child_weight': 9, 'max_depth': 6, 'learning_rate': 0.08111098525801756, 'gamma': 0.0, 'colsample_bytree': 0.8100224619146338}
# tp_avg: 51.06395348837209, gross_accuracy: 12.930232558139535, acc_median: 8.0
#
# Fitness: 20.930232558139537
#
# {'subsample': 1.0, 'num_round': 1207, 'min_child_weight': 33, 'max_depth': 7, 'learning_rate': 0.0110903872532269, 'gamma': 0.5808693032876086, 'colsample_bytree': 0.8487041977563832}
# tp_avg: 20.186046511627907, gross_accuracy: 9.162790697674419, acc_median: 5.5
#
# Fitness: 14.662790697674419
#
# {'subsample': 1.0, 'num_round': 1650, 'min_child_weight': 41, 'max_depth': 9, 'learning_rate': 0.07643311478026196, 'gamma': 1.8158026459347651, 'colsample_bytree': 0.8468938470265972}
# tp_avg: 56.36046511627907, gross_accuracy: 11.616279069767442, acc_median: 7.5
#
# Fitness: 19.116279069767444
#
# {'subsample': 1.0, 'num_round': 1721, 'min_child_weight': 6, 'max_depth': 2, 'learning_rate': 0.10446896732728056, 'gamma': 0.8224069069455531, 'colsample_bytree': 0.8}
# tp_avg: 38.03488372093023, gross_accuracy: 13.372093023255815, acc_median: 8.0
#
# Fitness: 21.372093023255815
#
# {'subsample': 0.5, 'num_round': 1872, 'min_child_weight': 27, 'max_depth': 7, 'learning_rate': 0.07984617360890792, 'gamma': 3.755814995352429, 'colsample_bytree': 0.8}
# tp_avg: 55.075581395348834, gross_accuracy: 13.476744186046512, acc_median: 9.0
#
# Fitness: 22.47674418604651
#
# {'subsample': 0.5, 'num_round': 1836, 'min_child_weight': 50, 'max_depth': 1, 'learning_rate': 0.3, 'gamma': 3.1959545451759404, 'colsample_bytree': 1.0}
# tp_avg: 39.622093023255815, gross_accuracy: 13.813953488372093, acc_median: 8.5
#
# Fitness: 22.313953488372093
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 20, 'learning_rate': 0.037497728980100994, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 50.7093023255814, gross_accuracy: 10.726744186046512, acc_median: 5.5
#
# Fitness: 16.22674418604651
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 7, 'learning_rate': 0.3, 'gamma': 1.0854450897374737, 'colsample_bytree': 1.0}
# tp_avg: 65.32558139534883, gross_accuracy: 2.4651162790697674, acc_median: 2.5
#
# Fitness: 4.965116279069767
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 37, 'max_depth': 5, 'learning_rate': 0.1148725094150547, 'gamma': 4.423737825175431, 'colsample_bytree': 0.8069496172884927}
# tp_avg: 51.56976744186046, gross_accuracy: 13.529069767441861, acc_median: 10.5
#
# Fitness: 24.02906976744186
#
# {'subsample': 0.7878983190586906, 'num_round': 1666, 'min_child_weight': 50, 'max_depth': 1, 'learning_rate': 0.09287358239100026, 'gamma': 2.9663444142954805, 'colsample_bytree': 0.8}
# tp_avg: 20.819767441860463, gross_accuracy: 9.290697674418604, acc_median: 3.5
#
# Fitness: 12.790697674418604
#
# {'subsample': 0.5577896708787922, 'num_round': 1056, 'min_child_weight': 5, 'max_depth': 8, 'learning_rate': 0.25727271170748695, 'gamma': 2.59397546143329, 'colsample_bytree': 0.9831875631529257}
# tp_avg: 66.31395348837209, gross_accuracy: 2.6802325581395348, acc_median: 1.5
#
# Fitness: 4.180232558139535
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.11622011849032896, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 52.16279069767442, gross_accuracy: 13.616279069767442, acc_median: 9.5
#
# Fitness: 23.116279069767444
#
# {'subsample': 0.6575856177879881, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.12203079657454605, 'gamma': 2.9417965425292962, 'colsample_bytree': 1.0}
# tp_avg: 53.88953488372093, gross_accuracy: 12.959302325581396, acc_median: 8.0
#
# Fitness: 20.959302325581397
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 1, 'learning_rate': 0.3, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 38.58139534883721, gross_accuracy: 13.511627906976743, acc_median: 8.0
#
# Fitness: 21.51162790697674
#
# {'subsample': 0.8848423060296391, 'num_round': 1878, 'min_child_weight': 2, 'max_depth': 13, 'learning_rate': 0.01, 'gamma': 3.4290244614459393, 'colsample_bytree': 0.8}
# tp_avg: 22.593023255813954, gross_accuracy: 8.366279069767442, acc_median: 4.5
#
# Fitness: 12.866279069767442
#
# {'subsample': 1.0, 'num_round': 973, 'min_child_weight': 49, 'max_depth': 4, 'learning_rate': 0.15132277367504582, 'gamma': 0.20667447912362785, 'colsample_bytree': 0.8}
# tp_avg: 51.75581395348837, gross_accuracy: 13.436046511627907, acc_median: 9.0
#
# Fitness: 22.436046511627907
#
# {'subsample': 0.7336384684509231, 'num_round': 1608, 'min_child_weight': 9, 'max_depth': 20, 'learning_rate': 0.3, 'gamma': 0.315618484015062, 'colsample_bytree': 0.8}
# tp_avg: 66.97674418604652, gross_accuracy: -0.2616279069767442, acc_median: -3.0
#
# Fitness: -3.261627906976744
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 1, 'learning_rate': 0.3, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 39.48837209302326, gross_accuracy: 13.581395348837209, acc_median: 7.5
#
# Fitness: 21.08139534883721
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 6, 'learning_rate': 0.10009791295544727, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 53.343023255813954, gross_accuracy: 12.819767441860465, acc_median: 8.0
#
# Fitness: 20.819767441860463
#
# {'subsample': 0.6593403125800708, 'num_round': 1939, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.12287031401330704, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 53.97093023255814, gross_accuracy: 13.034883720930232, acc_median: 8.0
#
# Fitness: 21.03488372093023
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 1, 'learning_rate': 0.3, 'gamma': 7.459585780167365e-18, 'colsample_bytree': 1.0}
# tp_avg: 38.83139534883721, gross_accuracy: 13.627906976744185, acc_median: 8.0
#
# Fitness: 21.627906976744185
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 1, 'learning_rate': 0.25829090524464887, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 36.33720930232558, gross_accuracy: 13.104651162790697, acc_median: 6.5
#
# Fitness: 19.604651162790695
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.17626407033429398, 'gamma': 1.8514544935971156, 'colsample_bytree': 0.8}
# tp_avg: 49.151162790697676, gross_accuracy: 14.19767441860465, acc_median: 9.0
#
# Fitness: 23.19767441860465
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.17332957999874127, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 52.598837209302324, gross_accuracy: 12.517441860465116, acc_median: 8.0
#
# Fitness: 20.517441860465116
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 6, 'max_depth': 5, 'learning_rate': 0.10831152531236989, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 53.00581395348837, gross_accuracy: 14.540697674418604, acc_median: 8.5
#
# Fitness: 23.040697674418603
#
# {'subsample': 0.5233116927152444, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1486365221111294, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 49.43604651162791, gross_accuracy: 14.593023255813954, acc_median: 10.0
#
# Fitness: 24.593023255813954
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.14017209130979597, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 48.76744186046512, gross_accuracy: 14.5, acc_median: 8.5
#
# Fitness: 23.0
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.11961512433792049, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 50.63953488372093, gross_accuracy: 14.563953488372093, acc_median: 8.5
#
# Fitness: 23.063953488372093
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.1628873492853538, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 43.77906976744186, gross_accuracy: 14.226744186046512, acc_median: 7.5
#
# Fitness: 21.72674418604651
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 4, 'learning_rate': 0.1176635909194888, 'gamma': 5.0, 'colsample_bytree': 0.8752163435417}
# tp_avg: 48.424418604651166, gross_accuracy: 13.383720930232558, acc_median: 8.0
#
# Fitness: 21.383720930232556
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 12, 'learning_rate': 0.08993889300990322, 'gamma': 0.0, 'colsample_bytree': 0.9936488556232317}
# tp_avg: 60.55232558139535, gross_accuracy: 7.866279069767442, acc_median: 5.0
#
# Fitness: 12.866279069767442
#
# {'subsample': 0.5000440834767642, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 18, 'learning_rate': 0.01, 'gamma': 5.0, 'colsample_bytree': 0.9000194396146496}
# tp_avg: 22.86627906976744, gross_accuracy: 10.162790697674419, acc_median: 6.0
#
# Fitness: 16.162790697674417
#
# {'subsample': 0.5, 'num_round': 1646, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.20821511654591424, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 53.01162790697674, gross_accuracy: 14.627906976744185, acc_median: 9.0
#
# Fitness: 23.627906976744185
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.1969667199942046, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 52.145348837209305, gross_accuracy: 14.534883720930232, acc_median: 9.0
#
# Fitness: 23.53488372093023
#
# {'subsample': 0.6064264954597053, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.17550643238740796, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 50.325581395348834, gross_accuracy: 14.151162790697674, acc_median: 10.0
#
# Fitness: 24.151162790697676
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.21685196934698792, 'gamma': 0.16846145746185912, 'colsample_bytree': 1.0}
# tp_avg: 51.48837209302326, gross_accuracy: 13.5, acc_median: 8.0
#
# Fitness: 21.5
#
# {'subsample': 0.5278513184770744, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.1560449256288333, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 50.25581395348837, gross_accuracy: 14.575581395348838, acc_median: 9.0
#
# Fitness: 23.575581395348838
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 10, 'max_depth': 3, 'learning_rate': 0.15241096001449997, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 49.27325581395349, gross_accuracy: 13.976744186046512, acc_median: 9.0
#
# Fitness: 22.97674418604651
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.0921038859551428, 'gamma': 0.0, 'colsample_bytree': 0.9862931723383662}
# tp_avg: 47.7906976744186, gross_accuracy: 14.081395348837209, acc_median: 8.0
#
# Fitness: 22.08139534883721
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.17498837465348954, 'gamma': 5.0, 'colsample_bytree': 0.9967902741739397}
# tp_avg: 50.895348837209305, gross_accuracy: 13.843023255813954, acc_median: 9.0
#
# Fitness: 22.843023255813954
#
# {'subsample': 0.6428163951487336, 'num_round': 1541, 'min_child_weight': 34, 'max_depth': 20, 'learning_rate': 0.12282711955851652, 'gamma': 4.954698629985363, 'colsample_bytree': 0.8218591346969574}
# tp_avg: 62.88953488372093, gross_accuracy: 6.290697674418604, acc_median: 2.0
#
# Fitness: 8.290697674418604
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.1394807985741164, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 47.098837209302324, gross_accuracy: 13.959302325581396, acc_median: 7.5
#
# Fitness: 21.459302325581397
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.234761342260464, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 54.56976744186046, gross_accuracy: 13.69767441860465, acc_median: 9.5
#
# Fitness: 23.19767441860465
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.19650413069261355, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 46.127906976744185, gross_accuracy: 14.44186046511628, acc_median: 8.0
#
# Fitness: 22.441860465116278
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 4, 'max_depth': 10, 'learning_rate': 0.01, 'gamma': 5.0, 'colsample_bytree': 0.9011721118346598}
# tp_avg: 21.28488372093023, gross_accuracy: 9.156976744186046, acc_median: 6.5
#
# Fitness: 15.656976744186046
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 7, 'learning_rate': 0.08084786843672925, 'gamma': 0.39250996162652696, 'colsample_bytree': 0.8}
# tp_avg: 55.47674418604651, gross_accuracy: 12.662790697674419, acc_median: 10.0
#
# Fitness: 22.662790697674417
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.17576920990673112, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 51.383720930232556, gross_accuracy: 14.465116279069768, acc_median: 10.0
#
# Fitness: 24.46511627906977
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.175450169582592, 'gamma': 0.0, 'colsample_bytree': 0.9977174627230534}
# tp_avg: 50.54651162790697, gross_accuracy: 14.517441860465116, acc_median: 12.0
#
# Fitness: 26.517441860465116
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.17626198132447565, 'gamma': 0.16070257724557546, 'colsample_bytree': 0.8}
# tp_avg: 50.88953488372093, gross_accuracy: 14.267441860465116, acc_median: 8.0
#
# Fitness: 22.267441860465116
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1766020821894393, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 51.46511627906977, gross_accuracy: 14.982558139534884, acc_median: 9.5
#
# Fitness: 24.482558139534884
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.17377430563670082, 'gamma': 2.4563445440647085, 'colsample_bytree': 1.0}
# tp_avg: 50.91279069767442, gross_accuracy: 14.162790697674419, acc_median: 8.0
#
# Fitness: 22.162790697674417
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.17239140793592947, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 50.38953488372093, gross_accuracy: 13.86046511627907, acc_median: 9.5
#
# Fitness: 23.36046511627907
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.16205004191268335, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 49.81976744186046, gross_accuracy: 14.209302325581396, acc_median: 9.0
#
# Fitness: 23.209302325581397
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.18999579420008864, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 51.94767441860465, gross_accuracy: 14.220930232558139, acc_median: 8.0
#
# Fitness: 22.22093023255814
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.15942155113606343, 'gamma': 1.1775126345593858, 'colsample_bytree': 1.0}
# tp_avg: 49.46511627906977, gross_accuracy: 14.029069767441861, acc_median: 7.5
#
# Fitness: 21.52906976744186
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.18518928677466068, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 50.0, gross_accuracy: 13.529069767441861, acc_median: 10.5
#
# Fitness: 24.02906976744186
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.18973395820359892, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 49.58720930232558, gross_accuracy: 13.959302325581396, acc_median: 9.0
#
# Fitness: 22.959302325581397
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.18876377362010188, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 51.79651162790697, gross_accuracy: 13.86046511627907, acc_median: 9.0
#
# Fitness: 22.86046511627907
#
# {'subsample': 0.9933676036386938, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1763141708885616, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 49.5406976744186, gross_accuracy: 14.30232558139535, acc_median: 8.5
#
# Fitness: 22.80232558139535
#
# {'subsample': 0.6151582682740844, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19136821365030884, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 51.69186046511628, gross_accuracy: 14.284883720930232, acc_median: 10.0
#
# Fitness: 24.28488372093023
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.19162625810406086, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 52.156976744186046, gross_accuracy: 14.087209302325581, acc_median: 9.0
#
# Fitness: 23.087209302325583
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1899701843494475, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 52.406976744186046, gross_accuracy: 14.796511627906977, acc_median: 9.5
#
# Fitness: 24.296511627906977
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.1893676527190867, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 51.7906976744186, gross_accuracy: 14.587209302325581, acc_median: 9.0
#
# Fitness: 23.587209302325583
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1927418857373342, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 52.33720930232558, gross_accuracy: 15.180232558139535, acc_median: 10.0
#
# Fitness: 25.180232558139537
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.20116575582546128, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 52.151162790697676, gross_accuracy: 13.732558139534884, acc_median: 10.0
#
# Fitness: 23.732558139534884
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.20223003403891812, 'gamma': 0.0, 'colsample_bytree': 0.9227464889260265}
# tp_avg: 53.104651162790695, gross_accuracy: 14.936046511627907, acc_median: 9.5
#
# Fitness: 24.436046511627907
#
# {'subsample': 0.5, 'num_round': 1264, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.20888773376769995, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 52.56976744186046, gross_accuracy: 13.872093023255815, acc_median: 12.0
#
# Fitness: 25.872093023255815
#
# {'subsample': 0.5, 'num_round': 988, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.22219582441586913, 'gamma': 0.7786144639695448, 'colsample_bytree': 1.0}
# tp_avg: 53.906976744186046, gross_accuracy: 14.13953488372093, acc_median: 9.5
#
# Fitness: 23.63953488372093
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.2180646170217923, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 53.343023255813954, gross_accuracy: 13.319767441860465, acc_median: 9.5
#
# Fitness: 22.819767441860463
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.21840652793492193, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 53.18023255813954, gross_accuracy: 12.866279069767442, acc_median: 7.0
#
# Fitness: 19.866279069767444
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1953666517598927, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 52.41279069767442, gross_accuracy: 14.784883720930232, acc_median: 9.0
#
# Fitness: 23.78488372093023
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.18719419935744963, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 51.49418604651163, gross_accuracy: 13.761627906976743, acc_median: 8.5
#
# Fitness: 22.26162790697674
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.1904312637749117, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 52.18023255813954, gross_accuracy: 13.529069767441861, acc_median: 9.0
#
# Fitness: 22.52906976744186
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1885948638236542, 'gamma': 2.9081592066910145, 'colsample_bytree': 0.8}
# tp_avg: 51.48837209302326, gross_accuracy: 14.55813953488372, acc_median: 9.5
#
# Fitness: 24.058139534883722
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.18947815625768716, 'gamma': 0.5646835578395477, 'colsample_bytree': 0.8}
# tp_avg: 51.47674418604651, gross_accuracy: 14.05813953488372, acc_median: 9.0
#
# Fitness: 23.058139534883722
#
# {'subsample': 0.5156065340648831, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19014551830498677, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 51.45348837209303, gross_accuracy: 13.761627906976743, acc_median: 8.0
#
# Fitness: 21.76162790697674
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.18719161937190223, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 51.49418604651163, gross_accuracy: 14.203488372093023, acc_median: 11.0
#
# Fitness: 25.203488372093023
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1866374097551356, 'gamma': 1.9930284664145264, 'colsample_bytree': 1.0}
# tp_avg: 49.83139534883721, gross_accuracy: 13.709302325581396, acc_median: 9.0
#
# Fitness: 22.709302325581397
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.16499403453702144, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 50.13953488372093, gross_accuracy: 13.930232558139535, acc_median: 8.5
#
# Fitness: 22.430232558139537
#
# {'subsample': 0.5, 'num_round': 1877, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1910096763156484, 'gamma': 1.7071428750068915, 'colsample_bytree': 1.0}
# tp_avg: 51.895348837209305, gross_accuracy: 13.848837209302326, acc_median: 9.0
#
# Fitness: 22.848837209302324
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.18915741251058216, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 51.19186046511628, gross_accuracy: 14.087209302325581, acc_median: 9.0
#
# Fitness: 23.087209302325583
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19217244030666497, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 51.96511627906977, gross_accuracy: 12.994186046511627, acc_median: 8.5
#
# Fitness: 21.49418604651163
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19018849238632698, 'gamma': 0.0, 'colsample_bytree': 0.9887525969399247}
# tp_avg: 50.24418604651163, gross_accuracy: 14.261627906976743, acc_median: 11.0
#
# Fitness: 25.26162790697674
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19518200009060457, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 50.50581395348837, gross_accuracy: 13.465116279069768, acc_median: 9.5
#
# Fitness: 22.96511627906977
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19134550167756914, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 51.73255813953488, gross_accuracy: 13.633720930232558, acc_median: 9.0
#
# Fitness: 22.633720930232556
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19028060514135614, 'gamma': 0.0, 'colsample_bytree': 0.9202136412995713}
# tp_avg: 50.33720930232558, gross_accuracy: 13.80232558139535, acc_median: 8.5
#
# Fitness: 22.30232558139535
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.19085120057420163, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 52.122093023255815, gross_accuracy: 14.366279069767442, acc_median: 9.5
#
# Fitness: 23.866279069767444
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1912972090395968, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 52.25581395348837, gross_accuracy: 14.94767441860465, acc_median: 10.0
#
# Fitness: 24.94767441860465
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.19215668568848504, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 51.73837209302326, gross_accuracy: 14.098837209302326, acc_median: 10.0
#
# Fitness: 24.098837209302324
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.18577824438772841, 'gamma': 0.0, 'colsample_bytree': 0.8143054317096767}
# tp_avg: 51.9593023255814, gross_accuracy: 14.529069767441861, acc_median: 10.0
#
# Fitness: 24.52906976744186
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19059206269318305, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 50.43023255813954, gross_accuracy: 14.581395348837209, acc_median: 11.0
#
# Fitness: 25.58139534883721
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19121055761057834, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 50.00581395348837, gross_accuracy: 13.86046511627907, acc_median: 10.5
#
# Fitness: 24.36046511627907
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.18866314888628163, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 49.81395348837209, gross_accuracy: 13.55813953488372, acc_median: 10.0
#
# Fitness: 23.558139534883722
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.19296531797068933, 'gamma': 0.722021936000605, 'colsample_bytree': 0.8}
# tp_avg: 49.7093023255814, gross_accuracy: 13.627906976744185, acc_median: 11.0
#
# Fitness: 24.627906976744185
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.1955806509035171, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 50.7906976744186, gross_accuracy: 14.279069767441861, acc_median: 8.0
#
# Fitness: 22.27906976744186
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1940111192777153, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 52.651162790697676, gross_accuracy: 14.930232558139535, acc_median: 9.0
#
# Fitness: 23.930232558139537
#
# {'subsample': 0.7193024696959729, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19203976115293941, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 51.36046511627907, gross_accuracy: 13.994186046511627, acc_median: 10.0
#
# Fitness: 23.99418604651163
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19234848400282523, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 51.2093023255814, gross_accuracy: 13.959302325581396, acc_median: 11.5
#
# Fitness: 25.459302325581397
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1930762716356454, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 52.16279069767442, gross_accuracy: 15.383720930232558, acc_median: 11.0
#
# Fitness: 26.383720930232556
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19280175373625683, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 50.51744186046512, gross_accuracy: 13.773255813953488, acc_median: 10.0
#
# Fitness: 23.77325581395349
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 3, 'max_depth': 3, 'learning_rate': 0.19181598353311272, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 51.633720930232556, gross_accuracy: 14.075581395348838, acc_median: 9.5
#
# Fitness: 23.575581395348838
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1930645933316743, 'gamma': 1.1528520527351418, 'colsample_bytree': 0.8}
# tp_avg: 50.0, gross_accuracy: 13.55813953488372, acc_median: 10.0
#
# Fitness: 23.558139534883722
#
# {'subsample': 0.8004104469032063, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1938063282588604, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 50.47093023255814, gross_accuracy: 13.482558139534884, acc_median: 12.0
#
# Fitness: 25.482558139534884
#
# {'subsample': 0.7735973734773357, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19053296655559146, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 50.63953488372093, gross_accuracy: 14.017441860465116, acc_median: 9.0
#
# Fitness: 23.017441860465116
#
# {'subsample': 0.5388557952139571, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.19641510966360293, 'gamma': 0.29508425767487306, 'colsample_bytree': 0.8}
# tp_avg: 52.13953488372093, gross_accuracy: 14.040697674418604, acc_median: 8.0
#
# Fitness: 22.040697674418603
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.18697990503728418, 'gamma': 1.4822894694306128, 'colsample_bytree': 0.8}
# tp_avg: 51.104651162790695, gross_accuracy: 13.674418604651162, acc_median: 10.0
#
# Fitness: 23.674418604651162
#
# {'subsample': 0.7588404836459672, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.1942289124906921, 'gamma': 0.0, 'colsample_bytree': 0.8656447716894776}
# tp_avg: 45.41279069767442, gross_accuracy: 13.906976744186046, acc_median: 7.5
#
# Fitness: 21.406976744186046
#
# {'subsample': 0.7271862580436323, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1693324352590881, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 49.79651162790697, gross_accuracy: 13.970930232558139, acc_median: 9.0
#
# Fitness: 22.97093023255814
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.17481977090119838, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 49.401162790697676, gross_accuracy: 13.843023255813954, acc_median: 10.0
#
# Fitness: 23.843023255813954
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1890671571762716, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 49.348837209302324, gross_accuracy: 13.930232558139535, acc_median: 7.5
#
# Fitness: 21.430232558139537
#
# {'subsample': 0.8271333553077337, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1716531327473016, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 49.651162790697676, gross_accuracy: 14.19186046511628, acc_median: 12.0
#
# Fitness: 26.191860465116278
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.16556026711566246, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 49.854651162790695, gross_accuracy: 14.023255813953488, acc_median: 8.0
#
# Fitness: 22.02325581395349
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.1750755277348042, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 49
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.17691701256003872, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 50.877906976744185, gross_accuracy: 14.337209302325581, acc_median: 8.0
#
# Fitness: 22.337209302325583
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.1717918804823924, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 50.22674418604651, gross_accuracy: 14.145348837209303, acc_median: 8.0
#
# Fitness: 22.145348837209305
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.15448863579424862, 'gamma': 0.0, 'colsample_bytree': 0.811227513782592}
# tp_avg: 48.97674418604651, gross_accuracy: 14.05813953488372, acc_median: 9.0
#
# Fitness: 23.058139534883722
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.17274848203004917, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 50.9593023255814, gross_accuracy: 14.540697674418604, acc_median: 11.0
#
# Fitness: 25.540697674418603
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1863108463212941, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 51.75581395348837, gross_accuracy: 14.412790697674419, acc_median: 9.0
#
# Fitness: 23.412790697674417
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.17321383346188896, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 50.71511627906977, gross_accuracy: 14.38953488372093, acc_median: 9.0
#
# Fitness: 23.38953488372093
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 14, 'max_depth': 3, 'learning_rate': 0.18711189241235002, 'gamma': 0.0, 'colsample_bytree': 0.8}
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[14], line 69
#      64     return -fitness  # Minimize negative fitness
#      68 # Perform Bayesian Optimization
# ---> 69 result = gp_minimize(
#      70     func=objective,
#      71     dimensions=param_space,
#      72     n_calls=500,
#      73     n_random_starts=10,  # the number of random initialization points
#      74     random_state=None
#      75 )
#      77 # Best hyperparameters found
#      78 best_hyperparameters = {dim.name: result.x[i] for i, dim in enumerate(param_space)}
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/skopt/optimizer/gp.py:281, in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size, space_constraint)
#     273 if base_estimator is None:
#     274     base_estimator = cook_estimator(
#     275         "GP",
#     276         space=space,
#     277         random_state=rng.randint(0, np.iinfo(np.int32).max),
#     278         noise=noise,
#     279     )
# --> 281 return base_minimize(
#     282     func,
#     283     space,
#     284     base_estimator=base_estimator,
#     285     acq_func=acq_func,
#     286     xi=xi,
#     287     kappa=kappa,
#     288     acq_optimizer=acq_optimizer,
#     289     n_calls=n_calls,
#     290     n_points=n_points,
#     291     n_random_starts=n_random_starts,
#     292     n_initial_points=n_initial_points,
#     293     initial_point_generator=initial_point_generator,
#     294     n_restarts_optimizer=n_restarts_optimizer,
#     295     x0=x0,
#     296     y0=y0,
#     297     random_state=rng,
#     298     verbose=verbose,
#     299     space_constraint=space_constraint,
#     300     callback=callback,
#     301     n_jobs=n_jobs,
#     302     model_queue_size=model_queue_size,
#     303 )
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/skopt/optimizer/base.py:332, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size, space_constraint)
#     330 for _ in range(n_calls):
#     331     next_x = optimizer.ask()
# --> 332     next_y = func(next_x)
#     333     result = optimizer.tell(next_x, next_y)
#     334     result.specs = specs
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/skopt/utils.py:779, in use_named_args.<locals>.decorator.<locals>.wrapper(x)
#     776 arg_dict = {dim.name: value for dim, value in zip(dimensions, x)}
#     778 # Call the wrapped objective function with the named arguments.
# --> 779 objective_value = func(**arg_dict)
#     781 return objective_value
#
# Cell In[14], line 38, in objective(**params)
#      28 hyperparams = {
#      29     'subsample': params['subsample'],
#      30     'num_round': params['num_round'],
#    (...)
#      35     'colsample_bytree': params['colsample_bytree']
#      36 }
#      37 print(hyperparams)
# ---> 38 tp_avg_list, gross_accuracy_list = run_temporal_simulation_hyperparams(
#      39     features, target_label, target_percentile,
#      40     dataset_start_date=datetime(2018, 1, 1),
#      41     evaluation_start_date=datetime(2021, 1, 4),
#      42     # evaluation_end_date=datetime(2021, 1, 25),
#      43     evaluation_end_date=datetime(2024, 4, 20),
#      44     strategy=title, hyperparams=hyperparams
#      45 )
#      47 acc_median = np.median(gross_accuracy_list)
#      48 tp_avg = sum(tp_avg_list) / len(tp_avg_list)
#
# Cell In[11], line 24, in run_temporal_simulation_hyperparams(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date, strategy, hyperparams)
#      22 dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
#      23 for date in dates_list:
# ---> 24     tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams,strategy)
#      25     tp_avg_list.append(tp)
#      26     gross_accuracy_list.append((tp-fp))
#
# Cell In[8], line 38, in model_runner_temporal_simulation(features, target_label, target_percentile, dataset_start_date, end_date, deployment_date, hyperparams, strategy)
#      36 validation_end_date = build_validation_dates_local(deployment_date)
#      37 dataset = pull_training_data_local(end_date, strategy)
# ---> 38 validation_dataset = pull_validation_data_local(validation_end_date,deployment_date, strategy)
#      39 # dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
#      40 # validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
#      41 # dataset.dropna(subset=["close_diff_deviation"],inplace=True)
#      42 # validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
#      43 target_value = dataset[target_label].quantile(target_percentile).round(3)
#
# Cell In[3], line 33, in pull_validation_data_local(end_date, start_date, strategy)
#      32 def pull_validation_data_local(end_date,start_date,strategy):
# ---> 33     data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/BF/2015-01-01_2024-05-03EXP.csv')
#      34     data['dt'] = pd.to_datetime(data['date'])
#      35     data['one_max_vol'] = (data['one_max']/data['return_vol_5D']).round(3)
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.
