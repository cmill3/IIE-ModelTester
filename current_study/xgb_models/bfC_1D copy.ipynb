# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler
import pytz
import warnings
warnings.filterwarnings('ignore')

# %%
s3 = boto3.client('s3')
STRATEGY = 'BFC_1D'
training_bucket = "icarus-research-data"
training_prefix = 'training_datasets/expanded_1d_datasets/'

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

index = ["QQQ","SPY","IWM","TLT"]
test_lag = ["DAL","UAL","VZ","T","AAL","AMC"]
train_lag = ["AMC"]

# big_fish =  [
#             "AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","PLTR","BAC","AAPL","NFLX","ABNB","CRWD","SHOP","FB","CRM",
#             "MSFT","F","V","MA","JNJ","DIS","JPM","INTC","ADBE","BA","CVX","MRNA","PFE","SNOW","SOFI",'META',
#             ]

# bf_plus = ["AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","PLTR","BAC","AAPL","NFLX","ABNB","CRWD","SHOP","FB","CRM",
#             "MSFT","F","V","MA","JNJ","DIS","JPM","INTC","ADBE","BA","CVX","MRNA","PFE","SNOW","NKE",'META',
#             'C','TGT','MMM','SQ','PANW','DAL','CSCO','UBER','SBUX']


all_symbols = ['ZM', 'UBER', 'CMG', 'AXP', 'TDOC', 'UAL', 'DAL', 'MMM', 'PEP', 'GE', 'RCL', 'MRK',
 'HD', 'LOW', 'VZ', 'PG', 'TSM', 'GOOG', 'GOOGL', 'AMZN', 'BAC', 'AAPL', 'ABNB',
 'CRM', 'MSFT', 'F', 'V', 'MA', 'JNJ', 'DIS', 'JPM', 'ADBE', 'BA', 'CVX', 'PFE',
 'META', 'C', 'CAT', 'KO', 'MS', 'GS', 'IBM', 'CSCO','TSLA','LCID','NIO','WFC',
 'TGT', 'COST', 'RIVN', 'COIN', 'SQ', 'SHOP', 'DOCU', 'ROKU', 'TWLO', 'DDOG', 'ZS', 'NET',
 'OKTA', 'UPST', 'ETSY', 'PINS', 'FUTU', 'SE', 'BIDU', 'JD', 'BABA', 'RBLX', 'AMD',
 'NVDA', 'PYPL', 'PLTR', 'NFLX', 'CRWD', 'INTC', 'MRNA', 'SNOW', 'SOFI', 'PANW',
 'ORCL','WBD','ARM','SNAP','BILI','AAL','CCL','NCLH','LYFT','BIDU','JD','BABA','HD','LOW',
 'SBUX','NKE','AFFRM','WMT']

high_vol = ['ZM', 'UBER', 'TDOC', 'UAL', 'RCL', 'AMZN', 'ABNB', 'META', 'TSLA',
       'LCID', 'NIO', 'RIVN', 'SQ', 'SHOP', 'DOCU', 'ROKU',
       'TWLO', 'DDOG', 'ZS', 'NET', 'OKTA', 'ETSY', 'PINS',
       'FUTU', 'SE', 'RBLX', 'AMD', 'NVDA', 'PYPL', 'PLTR', 'NFLX',
       'CRWD', 'MRNA', 'SNOW', 'SOFI', 'WBD', 'ARM', 'SNAP', 'BILI',
       'AAL', 'CCL', 'NCLH', 'LYFT', 'BIDU', 'JD', 'BABA', 'MU', 'AMAT',
       'DKNG', 'CZR', 'VXX']

mid_vol =['CMG', 'AXP', 'DAL', 'GE', 'TSM', 'GOOG', 'GOOGL', 'BAC', 'AAPL',
       'CRM', 'MSFT', 'F', 'DIS', 'ADBE', 'BA', 'CVX', 'C', 'CAT', 'MS',
       'WFC', 'TGT', 'INTC', 'PANW', 'ORCL', 'LOW', 'SBUX', 'NKE', 'QCOM',
       'AVGO', 'TXN', 'MGM', 'XOM']

low_vol = ['MMM', 'MRK', 'HD', 'VZ', 'V', 'MA', 'JPM',
       'PFE', 'GS', 'IBM', 'CSCO', 'WMT', 'COST', 'QQQ', 'SPY',
       'TLT', 'IWM']

bfpidx = ["AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","BAC","AAPL","FB","DIS"
          "MSFT","INTC","PFE","SNOW",'META','C','XOM',"QQQ","SPY","IWM","TLT"]


bf2 = ['QQQ','IWM','AAPL','NVDA','AMD','AMZN','SPY','MSFT','GOOG','GOOGL','C','BAC',
      'JPM','XOM','CVX','CSCO','INTC','DIS','IBM','BA', 'V','AXP','PYPL','ADBE','F','GM']

GE = [
    'QQQ','SPY','IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD','SHOP'
    'AXP', 'AAPL', 'BAC', 'BA', 'CVX', 'CSCO', 'C', 'DIS', 'XOM', 
    'GM', 'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA', 'PYPL','PANW','ADBE'
    'TSLA', 'V', 'SQ', 'TSM', 'QCOM', 'UBER', 'SNOW', 'PLTR', 'ABNB',
    "FB",'META',"TGT","NKE","SBUX","ORCL","DDOG","JNJ","AVGO","COST"
    ]
BF3 = ['QQQ', 'SPY', 'IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD', 'AAPL', 'BAC',
       'BA', 'C', 'DIS', 'XOM', 'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA',
       'TSLA', 'V', 'TSM', 'QCOM', 'SNOW', 'TGT', 'NKE', 'SBUX', 'ORCL',
       'PYPL', 'SQ', 'UBER', 'PLTR', 'ABNB', 
       'META'
       ]
PE = ['SPY', 'TSLA', 'QQQ', 'AMD', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN','TSM','BAC','C','XOM','DIS','SBUX','PYPL','NKE']
PE2 = ['SPY', 'TSLA', 'QQQ', 'AMD', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN','TSM','XOM','DIS','PYPL','BA','NFLX','NVDA','GOOG',
       'META'
       ]
## NVDA,NFLX,GOOG,META,AVGO,COST w/ increased capital

BF3_TRIMMED = [
    'QQQ','SPY','IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD', 
    'AAPL', 'BAC', 'BA', 'C', 'DIS', 'XOM', 
    'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA', 'PYPL',
    'TSLA', 'V', 'SQ', 'TSM', 'QCOM', 'UBER', 'SNOW', 'PLTR', 'ABNB',
    "FB",'META',"TGT","NKE","SBUX","ORCL"
    ]

t11 = ['NVDA', 'SPY', 'TSLA', 'QQQ', 'AMD', 'GOOG', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN']

# %%
def configure_dates(data,strategy):
    if strategy in ["CDBFC","CDBFP"]:
        data = data.loc[data['day_of_week'].isin([0,1,2])] 
    elif strategy in ["CDBFC_1D","CDBFP_1D"]:
        data = data.loc[data['day_of_week'].isin([0,1,2,3])]
    return data

def pull_training_data_local(end_date,strategy):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/BF/2015-01-01_2024-05-03EXP.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data['one_max_vol'] = (data['one_max']/data['return_vol_5D']).round(3)
    data['three_max_vol'] = (data['three_max']/data['return_vol_5D']).round(3)
    data['one_min_vol'] = (data['one_min']/data['return_vol_5D']).round(3)
    data['three_min_vol'] = (data['three_min']/data['return_vol_5D']).round(3)    
    # data['one_max_vol30'] = (data['one_max']/data['return_vol_30D']).round(3)
    # data['three_max_vol30'] = (data['three_max']/data['return_vol_30D']).round(3)
    # data['one_min_vol30'] = (data['one_min']/data['return_vol_30D']).round(3)
    # data['three_min_vol30'] = (data['three_min']/data['return_vol_30D']).round(3)    
    # data['cd_vol'] = (data['close_diff']/data['return_vol_10D']).round(3)
    # data['cd_vol3'] = (data['close_diff3']/data['return_vol_10D']).round(3)
    # data['cd_vol30'] = (data['close_diff']/data['return_vol_30D']).round(3)
    data['cd_vol'] = (data['price_change_D']/data['return_vol_5D']).round(3)
    data['cd_vol3'] = (data['price_3Ddiff']/data['return_vol_5D']).round(3)
    # data['cd_vol330'] = (data['close_diff3']/data['return_vol_30D']).round(3)
    data = data.loc[data['symbol'].isin(PE2)]
    data = configure_dates(data,strategy)
    data.replace([np.inf, -np.inf], 0, inplace=True)
    return data


def pull_validation_data_local(end_date,start_date,strategy):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/BF/2015-01-01_2024-05-03EXP.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data['one_max_vol'] = (data['one_max']/data['return_vol_5D']).round(3)
    data['three_max_vol'] = (data['three_max']/data['return_vol_5D']).round(3)
    data['one_min_vol'] = (data['one_min']/data['return_vol_5D']).round(3)
    data['three_min_vol'] = (data['three_min']/data['return_vol_5D']).round(3)    
    # data['one_max_vol30'] = (data['one_max']/data['return_vol_30D']).round(3)
    # data['three_max_vol30'] = (data['three_max']/data['return_vol_30D']).round(3)
    # data['one_min_vol30'] = (data['one_min']/data['return_vol_30D']).round(3)
    # data['three_min_vol30'] = (data['three_min']/data['return_vol_30D']).round(3)    
    data['cd_vol'] = (data['price_change_D']/data['return_vol_5D']).round(3)
    data['cd_vol3'] = (data['price_3Ddiff']/data['return_vol_5D']).round(3)
    # data['cd_vol30'] = (data['close_diff']/data['return_vol_30D']).round(3)
    # data['cd_vol330'] = (data['close_diff3']/data['return_vol_30D']).round(3)
    data = data.loc[data['dt'] <= end_date]
    data = data.loc[data['dt'] >= start_date]
    data = data.loc[data['symbol'].isin(PE2)]
    data = configure_dates(data,strategy)
    data.replace([np.inf, -np.inf], 0, inplace=True)
    return data

# %%
def build_date_list(start_date, end_date):
    print(start_date, end_date)
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_validation_dates_local(deployment_date):
    end_date = deployment_date + timedelta(days=5)
    return end_date

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    print(target_value)
    dataset.loc[:, 'label'] = (dataset[target_label] > target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] > target_value).astype(int)

    # dataset = dataset.round(3)
    # validation_dataset = validation_dataset.round(3)

    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']


    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    print(y.value_counts())
    predictions = xgb_model.predict(X_validate)
    probabilities = xgb_model.predict_proba(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,str(fi_list), predictions, probabilities


def train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] > target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] > target_value).astype(int)

    dataset = dataset.round(5)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']
    

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,"str(fi_list)", predictions, "probabilities"

# %%
# def model_runner_v2RM(model_name, dataset_name, title, features, target_label, target_percentile, start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
#     validation_end_date = build_validation_dates_local(deployment_date)
#     validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
#     dataset = pull_training_data_local(end_date, dataset_start_date)
#     dates_list = pull_gmm_labels(deployment_date)
#     rm_dataset = dataset.loc[dataset['dt'].isin(dates_list)]
#     target_value = rm_dataset[target_label].quantile(target_percentile).round(3)
#     print(target_value)
#     print(len(rm_dataset)/len(dataset))
#     tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, rm_dataset, validation_dataset, target_label, target_value, hyperparams)
#     response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
#     validation_dataset['probabilities'] = probabilities[:,1]
#     validation_dataset['predictions'] = predictions
#     validation_dataset['target_value'] = target_value
#     validation_dataset['target_pct'] = validation_dataset['target_value'] * validation_dataset['return_vol_10D']
#     validation_csv = validation_dataset.to_csv()
#     put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
#     return response

def model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile, start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
    validation_end_date = build_validation_dates_local(deployment_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date, title)
    dataset = pull_training_data_local(end_date, title)
    target_value = dataset[target_label].quantile(target_percentile).round(3)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
    validation_dataset['probabilities'] = probabilities[:,1]
    validation_dataset['predictions'] = predictions
    validation_dataset['target_value'] = target_value
    validation_dataset['target_pct'] = validation_dataset['target_value'] * validation_dataset['return_vol_10D']
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    return response

def model_runner_temporal_simulation(features, target_label, target_percentile,dataset_start_date,end_date,deployment_date,hyperparams,strategy):
    validation_end_date = build_validation_dates_local(deployment_date)
    dataset = pull_training_data_local(end_date, strategy)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date, strategy)
    # dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    # validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    # dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    # validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    target_value = dataset[target_label].quantile(target_percentile).round(3)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    return tp, fp, fn, tn

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=17),
            "dataset_start": datetime(2018,1,1)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

def pull_gmm_labels(date):
    date_str = date.strftime('%Y-%m-%d')
    data_20d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm20d_labels_RM2/{date_str}.csv')
    data_10d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm10d_labels_RM2/{date_str}.csv')
    data_3d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm3d_labels_RM2/{date_str}.csv')

    data_20d = pd.read_csv(data_20d.get("Body"))
    data_10d = pd.read_csv(data_10d.get("Body"))
    data_3d = pd.read_csv(data_3d.get("Body"))

    data_20d['dt'] = pd.to_datetime(data_20d['date'])
    data_10d['dt'] = pd.to_datetime(data_10d['date'])
    data_3d['dt'] = pd.to_datetime(data_3d['date'])

    label_20d = data_20d['labels'].iloc[-1]
    label_10d = data_10d['labels'].iloc[-1]
    label_3d = data_3d['labels'].iloc[-1]

    dates_20d = data_20d['dt'].loc[data_20d['labels'] == label_20d].tolist()
    dates_10d = data_10d['dt'].loc[data_10d['labels'] == label_10d].tolist()
    dates_3d = data_3d['dt'].loc[data_3d['labels'] == label_3d].tolist()

    combined_list = list(set(dates_20d  + dates_3d))
    return dates_20d

# %%
target_percentile = 0.6
title = 'CDBFC_1D'
model_name = f'{title}:TSSIM2.4_PE_HYPOPT2_{target_percentile}'
dataset_name = f'TSSIM2.4_PE_HYPOPT2_{target_percentile}'
hyperparams = {'subsample': 0.5083158580966601, 'num_round': 1214, 'min_child_weight': 46, 'max_depth': 3, 'learning_rate': 0.2650139173496549, 'gamma': 4.265950587395627, 'colsample_bytree': 0.8659802048508305}
features = ['DIplus', 'cmf_15MA_diff', 'DMplus', 'roc', 'DMminus', 'cd_vol', 'return_vol_5D', 'price_5Ddiff', 'volume_sum15_5DMA_diff', 'H-L', 'cmf_15MA', 'max_30_diff', 'roc5', 'SPY_range_vol', 'Low-Close', 'High-Close', 'rsiH_15MA_diff', 'H-PrevClose', 'hour', 'bb_trend', 'close_10DMA_diff', 'SPY_20d_diff', 'rsiH', 'close_20DMA_diff', 'price_20Ddiff', 'range_vol_stddev40H_diff', 'SPY_5d_diff', 'return_vol_8H_diff', 'price_change_H', 'min_30_diff', 'day_of_week', 'cmf', 'price_range_H', 'rsi', 'roc3', 'bb_category', 'TR', 'roc_vol5', 'bb_spread', 'price_3D20D_diff', 'price_range_D', 'SPY_5d', 'roc_15MA_diff']




target_label = 'one_max_vol'
dataset_start_date = datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')) 
dates_list = build_evaluation_period(datetime(2022,8,15), datetime(2024,5,3))

# date = dates_list[-1]
# print(date)
# response = model_runner_data(start_date=datetime(2018,1,1),end_date=datetime(2023,12,23))

# dataset = pull_training_data_local(start_date=datetime(2018,1,1),end_date=datetime(2023,12,23))
# print(dataset.columns.tolist())

for date in dates_list:
    print(date)
    response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile,"dataset_start_date",date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])
# Out:
# {'deployment_date': datetime.datetime(2022, 8, 15, 0, 0), 'dataset_end': datetime.datetime(2022, 7, 29, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# 1.061
# label
# 0    93458
# 1    62236
# Name: count, dtype: int64
# 26 29 297 80
# {'model_name': 'CDBFC_1D:TSSIM2.4_PE_HYPOPT2_0.6', 'deployment_date': '2022-08-15', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_PE_HYPOPT2_0.6', 'TP': 26, 'TPpct': Decimal('0'), 'FP': 29, 'FPpct': Decimal('0'), 'TN': 297, 'TNpct': Decimal('0'), 'FN': 80, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.896551724137931'), 'evaluation_timeperiod': '2022-08-15_2022-08-19', 'live': False, 'hyperparameters': {"{'subsample': 0.5083158580966601, 'num_round': 1214, 'min_child_weight': 46, 'max_depth': 3, 'learning_rate': 0.2650139173496549, 'gamma': 4.265950587395627, 'colsample_bytree': 0.8659802048508305}"}, 'features': {"['DIplus', 'cmf_15MA_diff', 'DMplus', 'roc', 'DMminus', 'cd_vol', 'return_vol_5D', 'price_5Ddiff', 'volume_sum15_5DMA_diff', 'H-L', 'cmf_15MA', 'max_30_diff', 'roc5', 'SPY_range_vol', 'Low-Close', 'High-Close', 'rsiH_15MA_diff', 'H-PrevClose', 'hour', 'bb_trend', 'close_10DMA_diff', 'SPY_20d_diff', 'rsiH', 'close_20DMA_diff', 'price_20Ddiff', 'range_vol_stddev40H_diff', 'SPY_5d_diff', 'return_vol_8H_diff', 'price_change_H', 'min_30_diff', 'day_of_week', 'cmf', 'price_range_H', 'rsi', 'roc3', 'bb_category', 'TR', 'roc_vol5', 'bb_spread', 'price_3D20D_diff', 'price_range_D', 'SPY_5d', 'roc_15MA_diff']"}, 'target': '1.061+one_max_vol', 'feature_importances': "[{'DIplus': 0.018301273}, {'cmf_15MA_diff': 0.0141406655}, {'DMplus': 0.014476903}, {'roc': 0.013816091}, {'DMminus': 0.0}, {'cd_vol': 0.019829225}, {'return_vol_5D': 0.07057091}, {'price_5Ddiff': 0.08238225}, {'volume_sum15_5DMA_diff': 0.029118057}, {'H-L': 0.014611209}, {'cmf_15MA': 0.012458989}, {'max_30_diff': 0.026347652}, {'roc5': 0.10013471}, {'SPY_range_vol': 0.020196158}, {'Low-Close': 0.015208424}, {'High-Close': 0.018198527}, {'rsiH_15MA_diff': 0.013349731}, {'H-PrevClose': 0.012409984}, {'hour': 0.01929722}, {'bb_trend': 0.01236518}, {'close_10DMA_diff': 0.016860563}, {'SPY_20d_diff': 0.013233668}, {'rsiH': 0.013985724}, {'close_20DMA_diff': 0.0}, {'price_20Ddiff': 0.012989696}, {'range_vol_stddev40H_diff': 0.045331128}, {'SPY_5d_diff': 0.012945687}, {'return_vol_8H_diff': 0.011152003}, {'price_change_H': 0.015542273}, {'min_30_diff': 0.016914904}, {'day_of_week': 0.030396119}, {'cmf': 0.015429683}, {'price_range_H': 0.061171643}, {'rsi': 0.012863291}, {'roc3': 0.02844079}, {'bb_category': 0.020434843}, {'TR': 0.016529199}, {'roc_vol5': 0.017529719}, {'bb_spread': 0.02762926}, {'price_3D20D_diff': 0.017906172}, {'price_range_D': 0.022209631}, {'SPY_5d': 0.026607968}, {'roc_15MA_diff': 0.016682891}]"}
# {'deployment_date': datetime.datetime(2022, 8, 22, 0, 0), 'dataset_end': datetime.datetime(2022, 8, 5, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# 1.061
# label
# 0    93751
# 1    62375
# Name: count, dtype: int64
# 57 106 177 92
# {'model_name': 'CDBFC_1D:TSSIM2.4_PE_HYPOPT2_0.6', 'deployment_date': '2022-08-22', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_PE_HYPOPT2_0.6', 'TP': 57, 'TPpct': Decimal('0'), 'FP': 106, 'FPpct': Decimal('0'), 'TN': 177, 'TNpct': Decimal('0'), 'FN': 92, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5377358490566038'), 'evaluation_timeperiod': '2022-08-22_2022-08-26', 'live': False, 'hyperparameters': {"{'subsample': 0.5083158580966601, 'num_round': 1214, 'min_child_weight': 46, 'max_depth': 3, 'learning_rate': 0.2650139173496549, 'gamma': 4.265950587395627, 'colsample_bytree': 0.8659802048508305}"}, 'features': {"['DIplus', 'cmf_15MA_diff', 'DMplus', 'roc', 'DMminus', 'cd_vol', 'return_vol_5D', 'price_5Ddiff', 'volume_sum15_5DMA_diff', 'H-L', 'cmf_15MA', 'max_30_diff', 'roc5', 'SPY_range_vol', 'Low-Close', 'High-Close', 'rsiH_15MA_diff', 'H-PrevClose', 'hour', 'bb_trend', 'close_10DMA_diff', 'SPY_20d_diff', 'rsiH', 'close_20DMA_diff', 'price_20Ddiff', 'range_vol_stddev40H_diff', 'SPY_5d_diff', 'return_vol_8H_diff', 'price_change_H', 'min_30_diff', 'day_of_week', 'cmf', 'price_range_H', 'rsi', 'roc3', 'bb_category', 'TR', 'roc_vol5', 'bb_spread', 'price_3D20D_diff', 'price_range_D', 'SPY_5d', 'roc_15MA_diff']"}, 'target': '1.061+one_max_vol', 'feature_importances': "[{'DIplus': 0.017095298}, {'cmf_15MA_diff': 0.014445716}, {'DMplus': 0.0}, {'roc': 0.015157369}, {'DMminus': 0.0}, {'cd_vol': 0.018476795}, {'return_vol_5D': 0.07095957}, {'price_5Ddiff': 0.12451348}, {'volume_sum15_5DMA_diff': 0.026002945}, {'H-L': 0.0127879735}, {'cmf_15MA': 0.014980117}, {'max_30_diff': 0.028096799}, {'roc5': 0.032501742}, {'SPY_range_vol': 0.022172248}, {'Low-Close': 0.016615454}, {'High-Close': 0.014901354}, {'rsiH_15MA_diff': 0.014414294}, {'H-PrevClose': 0.015584031}, {'hour': 0.023298174}, {'bb_trend': 0.013609372}, {'close_10DMA_diff': 0.019158857}, {'SPY_20d_diff': 0.012519888}, {'rsiH': 0.019130232}, {'close_20DMA_diff': 0.0}, {'price_20Ddiff': 0
DIplus', 'cmf_15MA_diff', 'DMplus', 'roc', 'DMminus', 'cd_vol', 'return_vol_5D', 'price_5Ddiff', 'volume_sum15_5DMA_diff', 'H-L', 'cmf_15MA', 'max_30_diff', 'roc5', 'SPY_range_vol', 'Low-Close', 'High-Close', 'rsiH_15MA_diff', 'H-PrevClose', 'hour', 'bb_trend', 'close_10DMA_diff', 'SPY_20d_diff', 'rsiH', 'close_20DMA_diff', 'price_20Ddiff', 'range_vol_stddev40H_diff', 'SPY_5d_diff', 'return_vol_8H_diff', 'price_change_H', 'min_30_diff', 'day_of_week', 'cmf', 'price_range_H', 'rsi', 'roc3', 'bb_category', 'TR', 'roc_vol5', 'bb_spread', 'price_3D20D_diff', 'price_range_D', 'SPY_5d', 'roc_15MA_diff']"}, 'target': '1.069+one_max_vol', 'feature_importances': "[{'DIplus': 0.01731062}, {'cmf_15MA_diff': 0.012838695}, {'DMplus': 0.0}, {'roc': 0.012315025}, {'DMminus': 0.0}, {'cd_vol': 0.019275317}, {'return_vol_5D': 0.07499633}, {'price_5Ddiff': 0.103145294}, {'volume_sum15_5DMA_diff': 0.02195563}, {'H-L': 0.016453898}, {'cmf_15MA': 0.012944871}, {'max_30_diff': 0.03041751}, {'roc5': 0.037399117}, {'SPY_range_vol': 0.022246221}, {'Low-Close': 0.013764831}, {'High-Close': 0.012397479}, {'rsiH_15MA_diff': 0.016520329}, {'H-PrevClose': 0.012257283}, {'hour': 0.031831138}, {'bb_trend': 0.012288579}, {'close_10DMA_diff': 0.015293323}, {'SPY_20d_diff': 0.016149778}, {'rsiH': 0.029608283}, {'close_20DMA_diff': 0.0}, {'price_20Ddiff': 0.015053632}, {'range_vol_stddev40H_diff': 0.04111499}, {'SPY_5d_diff': 0.011431042}, {'return_vol_8H_diff': 0.014226927}, {'price_change_H': 0.010822568}, {'min_30_diff': 0.023024807}, {'day_of_week': 0.024285976}, {'cmf': 0.01581}, {'price_range_H': 0.06468167}, {'rsi': 0.012856772}, {'roc3': 0.045518298}, {'bb_category': 0.034131162}, {'TR': 0.018086791}, {'roc_vol5': 0.022172049}, {'bb_spread': 0.025961183}, {'price_3D20D_diff': 0.011791607}, {'price_range_D': 0.020540925}, {'SPY_5d': 0.028790187}, {'roc_15MA_diff': 0.018289765}]"}

# %%
# data.columns.to_list()

# %%
# def convert_timestamp_est(timestamp):
#     # Create a naive datetime object from the UNIX timestamp
#     dt_naive = datetime.utcfromtimestamp(timestamp)
#     # Convert the naive datetime object to a timezone-aware one (UTC)
#     dt_utc = pytz.utc.localize(dt_naive)
#     # Convert the UTC datetime to EST
#     dt_est = dt_utc.astimezone(pytz.timezone('US/Eastern'))
    
#     return dt_est

# data = pd.read_csv(f'/Users/charlesmiller/Documents/ALL_SYM/2018-01-01_2023-10-28.csv')
# # data['date'] = data['date_x'].astype(str)
# # data['date'] = data['date_x'].apply(lambda x: x.split(" ")[0])
# data.drop('date',axis=1,inplace=True)
# data['date'] = data['t'].apply(lambda x: convert_timestamp_est(x))
# # data.drop(['one_pct','three_pct','Unnamed: 0.2', "Unnamed: 0","Unnamed: 0.1", "date_x","date_y",'vw_x', 'n_x', 'return_vol_240M_x', 'volume_vol_240M_x', 'return_vol_450M_x', 'volume_vol_450M_x', 'min_vol_diff_x', 'min_vol_diff_pct_x', 'min_volume_vol_diff_x', 'min_volume_vol_diff_pct_x', 'return_vol_8H_x', 'return_vol_16H_x', 'volume_vol_8H_x', 'volume_vol_16H_x', 'hour_vol_diff_x', 'hour_vol_diff_pct_x', 'hour_volume_vol_diff_x', 'hour_volume_vol_diff_pct_x', 'return_vol_5D_x', 'return_vol_10D_x', 'return_vol_30D_x', 'volume_vol_5D_x', 'volume_vol_10D_x', 'volume_vol_30D_x', 'daily_vol_diff_x', 'daily_vol_diff_pct_x', 'daily_vol_diff30_x', 'daily_vol_diff_pct30_x', 'daily_volume_vol_diff_x', 'daily_volume_vol_diff_pct_x', 'daily_volume_vol_diff30_x', 'daily_volume_vol_diff_pct30_x', 'vw_y', 'n_y', 'return_vol_240M_y', 'volume_vol_240M_y', 'return_vol_450M_y', 'volume_vol_450M_y', 'min_vol_diff_y', 'min_vol_diff_pct_y', 'min_volume_vol_diff_y', 'min_volume_vol_diff_pct_y', 'return_vol_8H_y', 'return_vol_16H_y', 'volume_vol_8H_y', 'volume_vol_16H_y', 'hour_vol_diff_y', 'hour_vol_diff_pct_y', 'hour_volume_vol_diff_y', 'hour_volume_vol_diff_pct_y', 'return_vol_5D_y', 'return_vol_10D_y', 'return_vol_30D_y', 'volume_vol_5D_y', 'volume_vol_10D_y', 'volume_vol_30D_y', 'daily_vol_diff_y', 'daily_vol_diff_pct_y', 'daily_vol_diff30_y', 'daily_vol_diff_pct30_y', 'daily_volume_vol_diff_y', 'daily_volume_vol_diff_pct_y', 'daily_volume_vol_diff30_y', 'daily_volume_vol_diff_pct30_y'], axis=1, inplace=True)
# data['roc_diff'] = data['roc'] - data['roc5']
# data['range_vol_diff5'] = (data['range_vol'] - data['range_vol5MA'])
# data['close_diff_deviation3'] = abs(data['close_diff3'])/(data['threeD_stddev50']*100)
# data['close_diff_deviation'] = abs(data['close_diff'])/(data['oneD_stddev50']*100)
# data.dropna(subset=['date'], inplace=True)
# data['day_of_week'] = data['date'].apply(lambda x: x.dayofweek).astype(int)
# data['day_of_month'] = data['date'].apply(lambda x: x.day).astype(int)
# data['month'] = data['date'].apply(lambda x: x.month).astype(int)
# data['year'] = data['date'].apply(lambda x: x.year).astype(int)
# data.replace([np.inf, -np.inf], 0, inplace=True)
# data.to_csv(f'/Users/charlesmiller/Documents/ALL_SYM/2018-01-01_2023-10-28.csv', index=False)

# %%
# old = pd.read_csv(f'/Users/charlesmiller/Documents/BF/2023-10-11_2023-10-28.csv')
# new = pd.read_csv(f'/Users/charlesmiller/Documents/BF_PLUS/2018-01-01_2023-10-28.csv')
# full = pd.concat([old,new])
# full.reset_index(drop=True, inplace=True)
# full = full.drop_duplicates(subset=['date','symbol'])

# %%
# full.to_csv(f'/Users/charlesmiller/Documents/BF_PLUS/2018-01-01_2023-10-28.csv', index=False)

# %%
def run_temporal_simulation(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date,strategy):
    tp_avg_list = []
    gross_accuracy_list = []
    # fn_list = []
    # tn_list = []
    
    hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
    dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
    # date = dates_list[-1]
    # response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
    for date in dates_list:
        tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams,strategy)
        tp_avg_list.append(tp)
        gross_accuracy_list.append((tp-fp))

    return tp_avg_list, gross_accuracy_list

def run_temporal_simulation_hyperparams(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date,strategy,hyperparams):
    tp_avg_list = []
    gross_accuracy_list = []
    
    dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
    for date in dates_list:
        tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams,strategy)
        tp_avg_list.append(tp)
        gross_accuracy_list.append((tp-fp))

    return tp_avg_list, gross_accuracy_list

# %% [markdown]
# ## Random Feature Selection

# %%
# number_of_simulations = 150
# now = datetime.now()
# title = 'CDBFC_1D'
# total_feature_list = ['Unnamed: 0', 'vw', 'n', 'hour', 'day', 'month', 'symbol', 'volume_15MA', 'volume_15MA_diff', 'volume_sum15', 
#                       'volume_sum15_5DMA', 'volume_sum15_10DMA', 'volume_sum15_5DMA_diff', 'volume_sum15_10DMA_diff', 'price_change_absolute_H', 
#                       'price_change_H', 'price_range_H', 'price_range_8MA', 'price_range_8MA_diff', 'return_vol_8H', 'return_vol_8H_diff', 'ret_vol_stddev40H', 
#                       'ret_vol_stddev40H_diff', 'volume_vol_stddev40H', 'volume_vol_stddev40H_diff', 'range_vol_stddev40H', 'range_vol_stddev40H_diff', 'rsiH', 
#                       'rsiH_15MA', 'rsiH_15MA_diff', 'roc8H', 'roc8H_15MA', 'roc8H_15MA_diff', 'price_change_absolute_D', 'price_change_D', 'price_range_D', 
#                       'price_range_5DMA', 'price_range_5DMA_diff', 'return_vol_5D', 'return_vol_5D_diff', 'return_vol_10D', 'return_vol_10D_diff', 'ret_vol_stddev20D', 
#                       'ret_vol_stddev20D_diff', 'range_vol_stddev20D', 'range_vol_stddev20D_diff', 'price_3Ddiff', 'price_5Ddiff', 'price_10Ddiff', 'price_20Ddiff', 
#                       'price_3D20D_diff', 'close_20DMA', 'close_20DMA_diff', 'close_10DMA', 'close_10DMA_diff', 'rsi', 'rsi_15MA', 'rsi_15MA_diff', 'roc', 'roc3', 'roc5', 
#                       'roc_15MA', 'roc_15MA_diff', 'High-Low', 'High-Close', 'Low-Close', 'TR', 'H-L', 'H-PrevClose', 'PrevClose-L', 'DMplus', 'DMminus', 'DIplus', 'DIminus', 
#                       'DX', 'adx', 'macd', 'macd_15MA', 'macd_15MA_diff', 'bbu', 'bbl', 'bbm', 'bb_spread', 'bb_trend', 'bb_category', 'cmf', 'cmf_15MA', 'cmf_15MA_diff', 
#                       'max_30', 'min_30', 'max_30_diff', 'min_30_diff', 'roc_vol', 'roc_vol3', 'roc_vol5', 'roc_vol_15MA', 'roc_vol_15MA_diff', 'date', 'alert_price', 'one_max', 
#                       'one_min', 'one_pct', 'three_max', 'three_min', 'three_pct', 'SPY_diff_H', 'SPY_diff_D', 'SPY_5d', 'SPY_20d', 'SPY_5d_diff', 'SPY_20d_diff', 'SPY_range_vol', 
#                       'day_of_week', 'day_of_month', 'year', 'dt', 'one_max_vol', 'three_max_vol', 'one_min_vol', 'three_min_vol', 'cd_vol', 'cd_vol3']

# target_label = 'one_max_vol'
# target_percentile = 0.6
# results_array = []

# i = 0
# while i < number_of_simulations:
#        model_name = f"{title}_temporal_simulation_{i}"
#        print(model_name)
#        random_int = random.randint(20,42)
#        features = random.sample(testing_features, random_int)
#        print(features)
#        tp_avg_list, gross_accuracy_list = run_temporal_simulation(features, target_label, target_percentile, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2021,1,4), evaluation_end_date=datetime(2023,12,23))        
#        tp_avg = sum(tp_avg_list)/len(tp_avg_list)
#        gross_accuracy = sum(gross_accuracy_list)/len(gross_accuracy_list)
#        print(tp_avg, gross_accuracy)
#        print()
#        results_array.append({"model_name": model_name, "features": features, "tp_avg": tp_avg, "gross_accuracy": gross_accuracy,"num_features": random_int,"median_tp": np.median(tp_avg_list), "median_gross_accuracy": np.median(gross_accuracy_list)})
#        i += 1

# results_df = pd.DataFrame(results_array)
# results_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)

# %% [markdown]
# ## Genetic Algorithm Feature Selection

# %%
# import random
# import numpy as np
# import pandas as pd
# from datetime import datetime

# # Define the total feature list and other constants
# total_feature_list = ['hour','volume_15MA_diff',  
#                     'volume_sum15_5DMA_diff', 'volume_sum15_10DMA_diff', 'price_change_absolute_H', 
#                       'price_change_H', 'price_range_H', 'price_range_8MA_diff', 'return_vol_8H', 'return_vol_8H_diff', 
#                       'ret_vol_stddev40H_diff','volume_vol_stddev40H_diff', 'range_vol_stddev40H_diff', 'rsiH', 
#                       'rsiH_15MA', 'rsiH_15MA_diff', 'roc8H', 'roc8H_15MA', 'roc8H_15MA_diff', 'price_change_D', 'price_range_D', 
#                       'price_range_5DMA', 'price_range_5DMA_diff', 'return_vol_5D', 'return_vol_5D_diff', 'return_vol_10D', 'return_vol_10D_diff', 'ret_vol_stddev20D', 
#                       'ret_vol_stddev20D_diff', 'range_vol_stddev20D', 'range_vol_stddev20D_diff', 'price_3Ddiff', 'price_5Ddiff', 'price_10Ddiff', 'price_20Ddiff', 
#                       'price_3D20D_diff','close_20DMA_diff', 'close_10DMA', 'close_10DMA_diff', 'rsi', 'rsi_15MA', 'rsi_15MA_diff', 'roc', 'roc3', 'roc5', 
#                       'roc_15MA', 'roc_15MA_diff', 'High-Low', 'High-Close', 'Low-Close', 'TR', 'H-L', 'H-PrevClose', 'PrevClose-L', 'DMplus', 'DMminus', 'DIplus', 'DIminus', 
#                       'DX', 'adx', 'macd', 'macd_15MA', 'macd_15MA_diff', 'bbu', 'bbl', 'bbm', 'bb_spread', 'bb_trend', 'bb_category', 'cmf', 'cmf_15MA', 'cmf_15MA_diff', 
#                       'max_30', 'min_30', 'max_30_diff', 'min_30_diff', 'roc_vol', 'roc_vol3', 'roc_vol5', 'roc_vol_15MA', 'roc_vol_15MA_diff',
#                       'SPY_diff_H', 'SPY_diff_D', 'SPY_5d', 'SPY_20d', 'SPY_5d_diff', 'SPY_20d_diff', 'SPY_range_vol', 
#                       'day_of_week', 'day_of_month','cd_vol', 'cd_vol3']
# target_label = 'one_max_vol'
# target_percentile = 0.6
# number_of_generations = 10
# population_size = 10
# mutation_rate = 0.1
# title = 'CDBFC_1D'
# basic_results = []

# # Define your current best feature set
# current_best_features = ['DIplus', 'cmf_15MA_diff', 'DMplus', 'roc', 'DMminus', 'cd_vol', 'return_vol_5D', 'price_5Ddiff', 'volume_sum15_5DMA_diff', 'H-L', 'cmf_15MA', 'max_30_diff', 'roc5', 'SPY_range_vol', 'Low-Close', 'High-Close', 'rsiH_15MA_diff', 'H-PrevClose', 'hour', 'bb_trend', 'close_10DMA_diff', 'SPY_20d_diff', 'rsiH', 'close_20DMA_diff', 'price_20Ddiff', 'range_vol_stddev40H_diff', 'SPY_5d_diff', 'return_vol_8H_diff', 'price_change_H', 'min_30_diff', 'day_of_week', 'cmf', 'price_range_H', 'rsi', 'roc3', 'bb_category', 'TR', 'roc_vol5', 'bb_spread', 'price_3D20D_diff', 'price_range_D', 'SPY_5d', 'roc_15MA_diff']

# def evaluate_performance(features):
#     print(features)
#     checked = []
#     for feature in features:
#         if feature not in checked:
#             checked.append(feature)
#         else:
#             print("Duplicate feature found")
#     # tp_avg_list, gross_accuracy_list = run_temporal_simulation(checked, target_label, target_percentile, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2021,1,4), evaluation_end_date=datetime(2024,4,20),strategy=title)
#     tp_avg_list, gross_accuracy_list = run_temporal_simulation(checked, target_label, target_percentile, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2021,1,4), evaluation_end_date=datetime(2021,1,25),strategy=title)

#     acc_median = np.median(gross_accuracy_list)
#     tp_avg = sum(tp_avg_list) / len(tp_avg_list)
#     gross_accuracy = sum(gross_accuracy_list) / len(gross_accuracy_list)
#     print(f"tp_avg: {tp_avg}, gross_accuracy: {gross_accuracy}, acc_median: {acc_median}")
#     print()
#     basic_results.append({"features": features, "tp_avg": tp_avg, "gross_accuracy": gross_accuracy,"num_features": len(features),"median_tp": np.median(tp_avg_list), "median_gross_accuracy": np.median(gross_accuracy_list)})
#     fitness = acc_median + gross_accuracy
#     return fitness

# def initialize_population(feature_list, population_size, current_best_features):
#     population = [current_best_features]  # Start with the best known feature set
#     for _ in range(population_size - 1):  # Remaining population
#         num_features = random.randint(30, 45)
#         individual = random.sample(feature_list, num_features)
#         population.append(individual)
#     return population

# def select_parents(population, scores, num_parents):
#     parents = random.choices(population, weights=scores, k=num_parents)
#     return parents

# def crossover(parents):
#     crossover_point = random.randint(1, min(len(parents[0]), len(parents[1])) - 1)
#     child = parents[0][:crossover_point] + parents[1][crossover_point:]
#     return child

# def mutate(individual, feature_list, mutation_rate):
#     if random.random() < mutation_rate:
#         if random.random() < 0.5 and len(individual) > 1:  # Remove a feature
#             individual.pop(random.randint(0, len(individual) - 1))
#         else:  # Add a feature
#             possible_features = list(set(feature_list) - set(individual))
#             if possible_features:  # Ensure there are possible features to add
#                 new_feature = random.choice(possible_features)
#                 individual.append(new_feature)
#     return individual

# def genetic_algorithm(feature_list, population_size, generations, mutation_rate, current_best_features):
#     population = initialize_population(feature_list, population_size, current_best_features)
#     results_array = []

#     for generation in range(generations):
#         scores = [evaluate_performance(individual) for individual in population]
#         new_population = []

#         for _ in range(population_size // 2):
#             parents = select_parents(population, scores, 2)
#             child1 = mutate(crossover(parents), feature_list, mutation_rate)
#             child2 = mutate(crossover(parents), feature_list, mutation_rate)
#             new_population.extend([child1, child2])

#         population = new_population
#         print(f"Generation {generation + 1}: Best fitness = {max(scores)}")

#         # Save results of the current generation
#         best_individual = population[np.argmax(scores)]
#         best_score = max(scores)
#         results_array.append({"generation": generation + 1, "best_features": best_individual, "best_score": best_score})

#     return results_array

# # Run the genetic algorithm
# results = genetic_algorithm(total_feature_list, population_size, number_of_generations, mutation_rate, current_best_features)

# # Save the results
# now = datetime.now()
# results_df = pd.DataFrame(results)
# results_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
# basic_df = pd.DataFrame(basic_results)
# basic_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}_basic.csv', index=False)
# print("Optimization completed and results saved.")

# %% [markdown]
# ## Bayesian Search Hyperparameter Opt

# %%
from skopt import gp_minimize
from skopt.space import Real, Integer, Categorical
from skopt.utils import use_named_args

# Define the hyperparameter search space
param_space = [
    Real(0.5, 1.0, name='subsample'),
    Integer(800, 2000, name='num_round'),
    Integer(1, 50, name='min_child_weight'),
    Integer(1, 20, name='max_depth'),
    Real(0.01, 0.3, name='learning_rate'),
    Real(0, 5, name='gamma'),
    Real(0.8, 1.0, name='colsample_bytree')
]

basic_results = []
target_label = 'one_max_vol'
target_percentile = 0.6
title = 'CDBFC_1D'
features = ['DIplus', 'cmf_15MA_diff', 'DMplus', 'roc', 'DMminus', 'cd_vol', 'return_vol_5D', 'price_5Ddiff', 'volume_sum15_5DMA_diff', 'H-L', 'cmf_15MA', 'max_30_diff', 'roc5', 'SPY_range_vol', 'Low-Close', 'High-Close', 'rsiH_15MA_diff', 'H-PrevClose', 'hour', 'bb_trend', 'close_10DMA_diff', 'SPY_20d_diff', 'rsiH', 'close_20DMA_diff', 'price_20Ddiff', 'range_vol_stddev40H_diff', 'SPY_5d_diff', 'return_vol_8H_diff', 'price_change_H', 'min_30_diff', 'day_of_week', 'cmf', 'price_range_H', 'rsi', 'roc3', 'bb_category', 'TR', 'roc_vol5', 'bb_spread', 'price_3D20D_diff', 'price_range_D', 'SPY_5d', 'roc_15MA_diff']


# Objective function to minimize (negative cross-validated accuracy)
@use_named_args(param_space)
def objective(**params):
    hyperparams = {
        'subsample': params['subsample'], 
        'num_round': params['num_round'], 
        'min_child_weight': params['min_child_weight'], 
        'max_depth': params['max_depth'], 
        'learning_rate': params['learning_rate'], 
        'gamma': params['gamma'], 
        'colsample_bytree': params['colsample_bytree']
    }
    print(hyperparams)
    tp_avg_list, gross_accuracy_list = run_temporal_simulation_hyperparams(
        features, target_label, target_percentile, 
        dataset_start_date=datetime(2018, 1, 1), 
        evaluation_start_date=datetime(2021, 1, 4), 
        # evaluation_end_date=datetime(2021, 1, 25),
        evaluation_end_date=datetime(2024, 4, 20),
        strategy=title, hyperparams=hyperparams
    )
    
    acc_median = np.median(gross_accuracy_list)
    tp_avg = sum(tp_avg_list) / len(tp_avg_list)
    gross_accuracy = sum(gross_accuracy_list) / len(gross_accuracy_list)
    
    print(f"tp_avg: {tp_avg}, gross_accuracy: {gross_accuracy}, acc_median: {acc_median}")
    basic_results.append({
        "features": hyperparams, 
        "tp_avg": tp_avg, 
        "gross_accuracy": gross_accuracy,
        "median_tp": np.median(tp_avg_list), 
        "median_gross_accuracy": np.median(gross_accuracy_list)
    })
    
    fitness = acc_median + gross_accuracy
    print(f"Fitness: {fitness}")
    print()
    return -fitness  # Minimize negative fitness



# Perform Bayesian Optimization
result = gp_minimize(
    func=objective,
    dimensions=param_space,
    n_calls=500,  # Increase if needed
    random_state=None,  # Remove the random seed for different results each run
    n_initial_points=10  # Number of random points before optimization starts
)

# Best hyperparameters found
best_hyperparameters = {dim.name: result.x[i] for i, dim in enumerate(param_space)}
print("Best Hyperparameters:", best_hyperparameters)

# Save the results to a CSV file
results_df = pd.DataFrame(result.x_iters, columns=[dim.name for dim in param_space])
results_df['Objective'] = result.func_vals
now = datetime.now()
title = 'Hyperparameter_Optimization'
results_df.to_csv(f'/Users/charlesmiller/Documents/hyp_opt_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
basic_df = pd.DataFrame(basic_results)
basic_df.to_csv(f'/Users/charlesmiller/Documents/hyp_opt_results/{title}/{now.year}_{now.month}_{now.day}_basic.csv', index=False)
# Out:
# {'subsample': 0.6209810077705786, 'num_round': 935, 'min_child_weight': 32, 'max_depth': 6, 'learning_rate': 0.2725068502503738, 'gamma': 4.660225895978179, 'colsample_bytree': 0.8149955342373723}
# tp_avg: 61.49418604651163, gross_accuracy: 7.5, acc_median: 9.5
# Fitness: 17.0
#
# {'subsample': 0.6982921654659145, 'num_round': 854, 'min_child_weight': 10, 'max_depth': 13, 'learning_rate': 0.05392848467170974, 'gamma': 4.409255023309545, 'colsample_bytree': 0.9937969441142598}
# tp_avg: 57.424418604651166, gross_accuracy: 9.017441860465116, acc_median: 10.0
# Fitness: 19.017441860465116
#
# {'subsample': 0.7368845576237226, 'num_round': 1753, 'min_child_weight': 38, 'max_depth': 20, 'learning_rate': 0.19793875902929486, 'gamma': 2.021884817560199, 'colsample_bytree': 0.9708803420490905}
# tp_avg: 65.06976744186046, gross_accuracy: 1.686046511627907, acc_median: 4.5
# Fitness: 6.186046511627907
#
# {'subsample': 0.6407307552983694, 'num_round': 987, 'min_child_weight': 14, 'max_depth': 5, 'learning_rate': 0.1568110226852732, 'gamma': 2.0549192464394013, 'colsample_bytree': 0.8381671009769555}
# tp_avg: 56.94186046511628, gross_accuracy: 13.168604651162791, acc_median: 14.5
# Fitness: 27.66860465116279
#
# {'subsample': 0.6160413501230189, 'num_round': 1217, 'min_child_weight': 35, 'max_depth': 10, 'learning_rate': 0.2796425580680673, 'gamma': 0.7424869825979925, 'colsample_bytree': 0.8157430976660379}
# tp_avg: 65.81976744186046, gross_accuracy: 1.1337209302325582, acc_median: 5.0
# Fitness: 6.133720930232558
#
# {'subsample': 0.9058489403863199, 'num_round': 1600, 'min_child_weight': 6, 'max_depth': 17, 'learning_rate': 0.1756184229764318, 'gamma': 4.53240754481767, 'colsample_bytree': 0.8669882528785322}
# tp_avg: 60.25, gross_accuracy: 3.313953488372093, acc_median: 4.5
# Fitness: 7.813953488372093
#
# {'subsample': 0.813611440365432, 'num_round': 1104, 'min_child_weight': 25, 'max_depth': 7, 'learning_rate': 0.21539127844825162, 'gamma': 2.7818511861057296, 'colsample_bytree': 0.8536615669106227}
# tp_avg: 59.906976744186046, gross_accuracy: 8.453488372093023, acc_median: 9.5
# Fitness: 17.953488372093023
#
# {'subsample': 0.9737289213161271, 'num_round': 1584, 'min_child_weight': 15, 'max_depth': 18, 'learning_rate': 0.06244047918396958, 'gamma': 1.9557049994246323, 'colsample_bytree': 0.8318348890687631}
# tp_avg: 58.95348837209303, gross_accuracy: 7.825581395348837, acc_median: 9.5
# Fitness: 17.325581395348838
#
# {'subsample': 0.9484822383293612, 'num_round': 1726, 'min_child_weight': 34, 'max_depth': 15, 'learning_rate': 0.26870133905181887, 'gamma': 3.5352918091700913, 'colsample_bytree': 0.8834745402566184}
# tp_avg: 63.825581395348834, gross_accuracy: 2.308139534883721, acc_median: 4.0
# Fitness: 6.308139534883721
#
# {'subsample': 0.5083158580966601, 'num_round': 1214, 'min_child_weight': 46, 'max_depth': 3, 'learning_rate': 0.2650139173496549, 'gamma': 4.265950587395627, 'colsample_bytree': 0.8659802048508305}
# tp_avg: 55.05232558139535, gross_accuracy: 13.180232558139535, acc_median: 17.0
# Fitness: 30.180232558139537
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 1, 'learning_rate': 0.01, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 0.0, gross_accuracy: 0.0, acc_median: 0.0
# Fitness: 0.0
#
# {'subsample': 0.5020228215132313, 'num_round': 1248, 'min_child_weight': 48, 'max_depth': 3, 'learning_rate': 0.26439379742422947, 'gamma': 4.216184305231702, 'colsample_bytree': 0.8711922779998296}
# tp_avg: 54.80232558139535, gross_accuracy: 12.744186046511627, acc_median: 13.0
# Fitness: 25.74418604651163
#
# {'subsample': 0.5, 'num_round': 1112, 'min_child_weight': 39, 'max_depth': 1, 'learning_rate': 0.23540227462525198, 'gamma': 4.065283169033411, 'colsample_bytree': 0.8633356527074652}
# tp_avg: 40.04651162790697, gross_accuracy: 13.220930232558139, acc_median: 11.0
# Fitness: 24.22093023255814
#
# {'subsample': 0.5616386365195588, 'num_round': 1016, 'min_child_weight': 14, 'max_depth': 3, 'learning_rate': 0.1424392067097072, 'gamma': 1.8770199380648291, 'colsample_bytree': 0.8481911441301795}
# tp_avg: 51.78488372093023, gross_accuracy: 14.872093023255815, acc_median: 14.5
# Fitness: 29.372093023255815
#
# {'subsample': 0.9156081848314488, 'num_round': 1227, 'min_child_weight': 2, 'max_depth': 3, 'learning_rate': 0.03927635369568885, 'gamma': 3.9147035798064724, 'colsample_bytree': 0.8477403893182442}
# tp_avg: 35.63953488372093, gross_accuracy: 11.872093023255815, acc_median: 10.0
# Fitness: 21.872093023255815
#
# {'subsample': 0.5, 'num_round': 890, 'min_child_weight': 12, 'max_depth': 4, 'learning_rate': 0.14613213380559248, 'gamma': 0.5834462271987496, 'colsample_bytree': 0.8500443743376135}
# tp_avg: 54.25, gross_accuracy: 13.720930232558139, acc_median: 12.5
# Fitness: 26.22093023255814
#
# {'subsample': 0.5, 'num_round': 1138, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.17675519212388546, 'gamma': 0.0, 'colsample_bytree': 0.9750150337916804}
# tp_avg: 53.854651162790695, gross_accuracy: 14.319767441860465, acc_median: 13.0
# Fitness: 27.319767441860463
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 23, 'max_depth': 5, 'learning_rate': 0.014264525624977473, 'gamma': 3.1869989895404087, 'colsample_bytree': 1.0}
# tp_avg: 30.22093023255814, gross_accuracy: 11.412790697674419, acc_median: 8.0
# Fitness: 19.412790697674417
#
# {'subsample': 0.7312673562211013, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 20, 'learning_rate': 0.01, 'gamma': 2.073912960052185, 'colsample_bytree': 0.8}
# tp_avg: 27.546511627906977, gross_accuracy: 8.05232558139535, acc_median: 6.0
# Fitness: 14.05232558139535
#
# {'subsample': 0.503099771810447, 'num_round': 1169, 'min_child_weight': 50, 'max_depth': 4, 'learning_rate': 0.16773564101926067, 'gamma': 5.0, 'colsample_bytree': 0.8364258998559124}
# tp_avg: 54.593023255813954, gross_accuracy: 13.226744186046512, acc_median: 14.0
# Fitness: 27.22674418604651
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 36, 'max_depth': 1, 'learning_rate': 0.12816846741389956, 'gamma': 5.0, 'colsample_bytree': 0.8030937422725102}
# tp_avg: 28.767441860465116, gross_accuracy: 11.279069767441861, acc_median: 8.0
# Fitness: 19.27906976744186
#
# {'subsample': 0.5367290128582644, 'num_round': 1441, 'min_child_weight': 1, 'max_depth': 1, 'learning_rate': 0.3, 'gamma': 0.0, 'colsample_bytree': 0.8554172295289099}
# tp_avg: 43.51162790697674, gross_accuracy: 14.331395348837209, acc_median: 13.0
# Fitness: 27.33139534883721
#
# {'subsample': 0.6299152212537378, 'num_round': 1609, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.3, 'gamma': 2.6587328640063044, 'colsample_bytree': 0.8}
# tp_avg: 55.79651162790697, gross_accuracy: 13.087209302325581, acc_median: 13.0
# Fitness: 26.087209302325583
#
# {'subsample': 0.6189869113133628, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 1, 'learning_rate': 0.3, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 43.424418604651166, gross_accuracy: 13.872093023255815, acc_median: 13.0
# Fitness: 26.872093023255815
#
# {'subsample': 0.8756732525208601, 'num_round': 1244, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1962077167190428, 'gamma': 0.1464674312859884, 'colsample_bytree': 0.8}
# tp_avg: 51.91279069767442, gross_accuracy: 13.790697674418604, acc_median: 13.5
# Fitness: 27.290697674418603
#
# {'subsample': 0.72439091288994, 'num_round': 1865, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.3, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 51.78488372093023, gross_accuracy: 14.61046511627907, acc_median: 13.0
# Fitness: 27.61046511627907
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 7, 'learning_rate': 0.01, 'gamma': 0.12649491550902167, 'colsample_bytree': 0.8}
# tp_avg: 20.86627906976744, gross_accuracy: 8.633720930232558, acc_median: 7.0
# Fitness: 15.633720930232558
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.3, 'gamma': 5.0, 'colsample_bytree': 0.834143479021924}
# tp_avg: 49.97093023255814, gross_accuracy: 13.616279069767442, acc_median: 13.0
# Fitness: 26.616279069767444
#
# {'subsample': 0.9938836581614594, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.3, 'gamma': 0.14531647908155554, 'colsample_bytree': 0.8260773905551784}
# tp_avg: 50.56395348837209, gross_accuracy: 14.19186046511628, acc_median: 13.0
# Fitness: 27.191860465116278
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.11153663193418424, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 50.622093023255815, gross_accuracy: 13.244186046511627, acc_median: 13.0
# Fitness: 26.24418604651163
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 15, 'learning_rate': 0.01, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 31.988372093023255, gross_accuracy: 9.488372093023257, acc_median: 9.0
# Fitness: 18.48837209302326
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.22006503193421487, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 52.45348837209303, gross_accuracy: 13.081395348837209, acc_median: 14.0
# Fitness: 27.08139534883721
#
# {'subsample': 0.6139541118572792, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 11, 'learning_rate': 0.01, 'gamma': 2.101557025376937, 'colsample_bytree': 1.0}
# tp_avg: 31.098837209302324, gross_accuracy: 10.982558139534884, acc_median: 9.0
# Fitness: 19.982558139534884
#
# {'subsample': 0.9650173331141354, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.207359116863169, 'gamma': 0.0, 'colsample_bytree': 0.8124380366994763}
# tp_avg: 54.76162790697674, gross_accuracy: 12.662790697674419, acc_median: 11.5
# Fitness: 24.162790697674417
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 5, 'learning_rate': 0.10863945999500034, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 54.75, gross_accuracy: 13.069767441860465, acc_median: 13.5
# Fitness: 26.569767441860463
#
# {'subsample': 0.5, 'num_round': 823, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.13049643732531313, 'gamma': 5.0, 'colsample_bytree': 0.8184447671976708}
# tp_avg: 50.95348837209303, gross_accuracy: 13.877906976744185, acc_median: 14.0
# Fitness: 27.877906976744185
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 31, 'max_depth': 2, 'learning_rate': 0.23758203169796568, 'gamma': 0.4536345076191109, 'colsample_bytree': 0.9949498789008795}
# tp_avg: 51.69186046511628, gross_accuracy: 14.651162790697674, acc_median: 15.0
# Fitness: 29.651162790697676
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 11, 'max_depth': 2, 'learning_rate': 0.23096173410659496, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 50.55813953488372, gross_accuracy: 14.662790697674419, acc_median: 14.5
# Fitness: 29.162790697674417
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.23050154242529078, 'gamma': 2.1473956551066045, 'colsample_bytree': 0.8}
# tp_avg: 50.5, gross_accuracy: 14.511627906976743, acc_median: 13.5
# Fitness: 28.01162790697674
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.19632342650713352, 'gamma': 1.439565592914959, 'colsample_bytree': 1.0}
# tp_avg: 49.63953488372093, gross_accuracy: 14.215116279069768, acc_median: 12.5
# Fitness: 26.71511627906977
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.25880951513229056, 'gamma': 3.6628710096900896, 'colsample_bytree': 0.8034855091274586}
# tp_avg: 51.27325581395349, gross_accuracy: 14.017441860465116, acc_median: 12.0
# Fitness: 26.017441860465116
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.13050655861734123, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 51.47093023255814, gross_accuracy: 14.377906976744185, acc_median: 14.0
# Fitness: 28.377906976744185
#
# {'subsample': 0.5, 'num_round': 1214, 'min_child_weight': 14, 'max_depth': 9, 'learning_rate': 0.10688510033430476, 'gamma': 5.0, 'colsample_bytree': 0.8471636894028165}
# tp_avg: 59.03488372093023, gross_accuracy: 9.116279069767442, acc_median: 12.0
# Fitness: 21.116279069767444
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 12, 'max_depth': 4, 'learning_rate': 0.11759895447304869, 'gamma': 0.0, 'colsample_bytree': 0.804849924358362}
# tp_avg: 52.848837209302324, gross_accuracy: 13.133720930232558, acc_median: 12.5
# Fitness: 25.633720930232556
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.17500967049849295, 'gamma': 5.0, 'colsample_bytree': 0.8749402184966908}
# tp_avg: 52.97674418604651, gross_accuracy: 13.970930232558139, acc_median: 15.0
# Fitness: 28.97093023255814
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.18299008423341695, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 53.33720930232558, gross_accuracy: 13.075581395348838, acc_median: 14.0
# Fitness: 27.075581395348838
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.17059356484143673, 'gamma': 2.7978844198944586, 'colsample_bytree': 1.0}
# tp_avg: 51.33139534883721, gross_accuracy: 13.5, acc_median: 13.0
# Fitness: 26.5
#
# {'subsample': 0.5, 'num_round': 1281, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.3, 'gamma': 2.816472682001658, 'colsample_bytree': 1.0}
# tp_avg: 52.36046511627907, gross_accuracy: 14.098837209302326, acc_median: 15.5
# Fitness: 29.598837209302324
#
# {'subsample': 0.5, 'num_round': 1580, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.3, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 52.51162790697674, gross_accuracy: 14.087209302325581, acc_median: 15.5
# Fitness: 29.587209302325583
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.3, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 52.51162790697674, gross_accuracy: 14.087209302325581, acc_median: 15.5
# Fitness: 29.587209302325583
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.3, 'gamma': 5.0, 'colsample_bytree': 0.926452163373662}
# tp_avg: 52.895348837209305, gross_accuracy: 14.633720930232558, acc_median: 15.0
# Fitness: 29.633720930232556
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.3, 'gamma': 1.0051079964856935, 'colsample_bytree': 0.8}
# tp_avg: 52.575581395348834, gross_accuracy: 14.436046511627907, acc_median: 13.5
# Fitness: 27.936046511627907
#
# {'subsample': 0.5, 'num_round': 1981, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.3, 'gamma': 5.0, 'colsample_bytree': 0.9975092062415033}
# tp_avg: 52.76744186046512, gross_accuracy: 14.116279069767442, acc_median: 14.0
# Fitness: 28.116279069767444
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.2699464783892878, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 51.616279069767444, gross_accuracy: 14.122093023255815, acc_median: 14.5
# Fitness: 28.622093023255815
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.3, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 56.377906976744185, gross_accuracy: 13.168604651162791, acc_median: 12.5
# Fitness: 25.66860465116279
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 6, 'learning_rate': 0.12134648826512899, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 57.06976744186046, gross_accuracy: 12.854651162790697, acc_median: 13.0
# Fitness: 25.854651162790695
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 1, 'learning_rate': 0.3, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 43.53488372093023, gross_accuracy: 14.209302325581396, acc_median: 13.0
# Fitness: 27.209302325581397
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.2568236751866514, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 51.53488372093023, gross_accuracy: 14.284883720930232, acc_median: 14.0
# Fitness: 28.28488372093023
#
# {'subsample': 1.0, 'num_round': 1562, 'min_child_weight': 49, 'max_depth': 11, 'learning_rate': 0.12727830673115004, 'gamma': 1.4692795470142996, 'colsample_bytree': 0.9999303540180715}
# tp_avg: 60.13953488372093, gross_accuracy: 8.13953488372093, acc_median: 11.0
# Fitness: 19.13953488372093
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.24275166745231078, 'gamma': 0.14568132117383106, 'colsample_bytree': 0.8}
# tp_avg: 51.41279069767442, gross_accuracy: 14.436046511627907, acc_median: 14.0
# Fitness: 28.436046511627907
#
# {'subsample': 0.5, 'num_round': 937, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.21945531288490164, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 54.383720930232556, gross_accuracy: 13.593023255813954, acc_median: 13.0
# Fitness: 26.593023255813954
#
# {'subsample': 0.8492096024872531, 'num_round': 1159, 'min_child_weight': 5, 'max_depth': 20, 'learning_rate': 0.3, 'gamma': 0.856885829581798, 'colsample_bytree': 0.8223182798616132}
# tp_avg: 62.68604651162791, gross_accuracy: -0.005813953488372093, acc_median: 4.0
# Fitness: 3.994186046511628
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1513340488741486, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 52.00581395348837, gross_accuracy: 14.25, acc_median: 15.5
# Fitness: 29.75
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.15588730109544388, 'gamma': 0.0, 'colsample_bytree': 0.8}
# tp_avg: 52.0, gross_accuracy: 13.279069767441861, acc_median: 12.0
# Fitness: 25.27906976744186
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.2737402344384867, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 52.174418604651166, gross_accuracy: 14.226744186046512, acc_median: 14.0
# Fitness: 28.22674418604651
#
# {'subsample': 1.0, 'num_round': 1163, 'min_child_weight': 48, 'max_depth': 2, 'learning_rate': 0.2682111321932306, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 50.55813953488372, gross_accuracy: 14.482558139534884, acc_median: 13.5
# Fitness: 27.982558139534884
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.3, 'gamma': 5.0, 'colsample_bytree': 0.9014224339101953}
# tp_avg: 52.00581395348837, gross_accuracy: 14.116279069767442, acc_median: 15.0
# Fitness: 29.116279069767444
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.3, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 52.44767441860465, gross_accuracy: 13.94186046511628, acc_median: 15.0
# Fitness: 28.941860465116278
#
# {'subsample': 0.5, 'num_round': 1501, 'min_child_weight': 50, 'max_depth': 1, 'learning_rate': 0.3, 'gamma': 0.08230549272096119, 'colsample_bytree': 1.0}
# tp_avg: 43.53488372093023, gross_accuracy: 14.209302325581396, acc_median: 13.0
# Fitness: 27.209302325581397
#
# {'subsample': 0.559722205159524, 'num_round': 964, 'min_child_weight': 31, 'max_depth': 17, 'learning_rate': 0.01, 'gamma': 1.1158214362118826, 'colsample_bytree': 0.929359132551054}
# tp_avg: 29.523255813953487, gross_accuracy: 10.418604651162791, acc_median: 8.0
# Fitness: 18.41860465116279
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.3, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 52.43604651162791, gross_accuracy: 14.023255813953488, acc_median: 15.0
# Fitness: 29.02325581395349
#
# {'subsample': 0.5058799508722499, 'num_round': 812, 'min_child_weight': 31, 'max_depth': 3, 'learning_rate': 0.1143769144397867, 'gamma': 0.2284704317596029, 'colsample_bytree': 0.9826600609224527}
# tp_avg: 50.924418604651166, gross_accuracy: 14.627906976744185, acc_median: 14.0
# Fitness: 28.627906976744185
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.2667706293148596, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 51.50581395348837, gross_accuracy: 14.255813953488373, acc_median: 15.0
# Fitness: 29.25581395348837
#
# {'subsample': 0.5, 'num_round': 1477, 'min_child_weight': 28, 'max_depth': 3, 'learning_rate': 0.10694798282612204, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 49.99418604651163, gross_accuracy: 14.13953488372093, acc_median: 14.5
# Fitness: 28.63953488372093
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1240034997817919, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 49.343023255813954, gross_accuracy: 14.226744186046512, acc_median: 14.5
# Fitness: 28.72674418604651
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.11060497865146697, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 50.43604651162791, gross_accuracy: 14.36046511627907, acc_median: 15.0
# Fitness: 29.36046511627907
#
# {'subsample': 0.5, 'num_round': 1686, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.14101318427172063, 'gamma': 1.0163415416882013, 'colsample_bytree': 1.0}
# tp_avg: 47.424418604651166, gross_accuracy: 14.465116279069768, acc_median: 14.0
# Fitness: 28.46511627906977
#
# {'subsample': 0.5, 'num_round': 1591, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.13595334518487262, 'gamma': 4.727026349416738, 'colsample_bytree': 1.0}
# tp_avg: 51.27906976744186, gross_accuracy: 13.645348837209303, acc_median: 14.0
# Fitness: 27.645348837209305
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.15517418890799067, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.08720930232558, gross_accuracy: 14.633720930232558, acc_median: 13.0
# Fitness: 27.633720930232556
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 19, 'max_depth': 3, 'learning_rate': 0.12315466441723373, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 50.86046511627907, gross_accuracy: 14.383720930232558, acc_median: 14.0
# Fitness: 28.383720930232556
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.26189563545901556, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 51.53488372093023, gross_accuracy: 14.087209302325581, acc_median: 13.0
# Fitness: 27.087209302325583
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.1354314810426105, 'gamma': 4.637547575545685, 'colsample_bytree': 1.0}
# tp_avg: 51.27906976744186, gross_accuracy: 13.895348837209303, acc_median: 15.0
# Fitness: 28.895348837209305
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 10, 'max_depth': 3, 'learning_rate': 0.1345688384863038, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 49.97093023255814, gross_accuracy: 13.866279069767442, acc_median: 13.5
# Fitness: 27.366279069767444
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.12309766924136127, 'gamma': 1.66279288764837, 'colsample_bytree': 1.0}
# tp_avg: 50.69186046511628, gross_accuracy: 13.848837209302326, acc_median: 14.0
# Fitness: 27.848837209302324
#
# {'subsample': 0.5, 'num_round': 900, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.18680763463388522, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 49.16279069767442, gross_accuracy: 14.44767441860465, acc_median: 15.0
# Fitness: 29.44767441860465
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.1677804464344731, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.604651162790695, gross_accuracy: 14.366279069767442, acc_median: 15.0
# Fitness: 29.366279069767444
#
# {'subsample': 0.5, 'num_round': 980, 'min_child_weight': 48, 'max_depth': 2, 'learning_rate': 0.16030878642532342, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.61046511627907, gross_accuracy: 14.418604651162791, acc_median: 14.5
# Fitness: 28.91860465116279
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.15440321332039145, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 47.47674418604651, gross_accuracy: 13.959302325581396, acc_median: 14.0
# Fitness: 27.959302325581397
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 25, 'max_depth': 2, 'learning_rate': 0.18048681784912537, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 49.25, gross_accuracy: 14.813953488372093, acc_median: 15.0
# Fitness: 29.813953488372093
#
# {'subsample': 0.5, 'num_round': 813, 'min_child_weight': 20, 'max_depth': 2, 'learning_rate': 0.15962582077396545, 'gamma': 0.16927851569920438, 'colsample_bytree': 1.0}
# tp_avg: 48.7906976744186, gross_accuracy: 14.44186046511628, acc_median: 14.0
# Fitness: 28.441860465116278
#
# {'subsample': 0.5, 'num_round': 991, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.19138481399758941, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 49.18023255813954, gross_accuracy: 13.86046511627907, acc_median: 13.0
# Fitness: 26.86046511627907
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 47, 'max_depth': 3, 'learning_rate': 0.14351687572489097, 'gamma': 3.777377341439063, 'colsample_bytree': 1.0}
# tp_avg: 50.73837209302326, gross_accuracy: 14.563953488372093, acc_median: 14.0
# Fitness: 28.563953488372093
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.14540219700093077, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 45.58720930232558, gross_accuracy: 14.662790697674419, acc_median: 14.0
# Fitness: 28.662790697674417
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.14855120227197455, 'gamma': 4.695620029313618, 'colsample_bytree': 1.0}
# tp_avg: 51.06976744186046, gross_accuracy: 14.465116279069768, acc_median: 14.5
# Fitness: 28.96511627906977
#
# {'subsample': 1.0, 'num_round': 1915, 'min_child_weight': 32, 'max_depth': 2, 'learning_rate': 0.147375522664216, 'gamma': 4.808870783685822, 'colsample_bytree': 1.0}
# tp_avg: 45.674418604651166, gross_accuracy: 14.662790697674419, acc_median: 15.0
# Fitness: 29.662790697674417
#
# {'subsample': 1.0, 'num_round': 1411, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.13130623795829222, 'gamma': 4.369607117223878, 'colsample_bytree': 1.0}
# tp_avg: 44.22093023255814, gross_accuracy: 14.267441860465116, acc_median: 13.0
# Fitness: 27.267441860465116
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.14940757240972644, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 45.25581395348837, gross_accuracy: 14.209302325581396, acc_median: 13.0
# Fitness: 27.209302325581397
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.16936744821527408, 'gamma': 0.15265710382632328, 'colsample_bytree': 1.0}
# tp_avg: 47.156976744186046, gross_accuracy: 14.686046511627907, acc_median: 14.0
# Fitness: 28.686046511627907
#
# {'subsample': 0.5, 'num_round': 1994, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.16797202489375476, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 57.18604651162791, gross_accuracy: 10.732558139534884, acc_median: 11.5
# Fitness: 22.232558139534884
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16329531948498588, 'gamma': 3.0996350977862996, 'colsample_bytree': 1.0}
# tp_avg: 49.151162790697676, gross_accuracy: 15.145348837209303, acc_median: 13.5
# Fitness: 28.645348837209305
#
# {'subsample': 1.0, 'num_round': 970, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16344588994439138, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 46.906976744186046, gross_accuracy: 14.581395348837209, acc_median: 15.5
# Fitness: 30.08139534883721
#
# {'subsample': 0.6428712284660179, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16005120850098564, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.33139534883721, gross_accuracy: 14.930232558139535, acc_median: 14.0
# Fitness: 28.930232558139537
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.15678012820964232, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.23837209302326, gross_accuracy: 14.732558139534884, acc_median: 15.0
# Fitness: 29.732558139534884
#
# {'subsample': 1.0, 'num_round': 925, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16316090820003548, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 46.99418604651163, gross_accuracy: 14.837209302325581, acc_median: 15.0
# Fitness: 29.837209302325583
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16706809424872834, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 47.21511627906977, gross_accuracy: 14.872093023255815, acc_median: 15.0
# Fitness: 29.872093023255815
#
# {'subsample': 1.0, 'num_round': 1580, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16446346699101727, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 47.16279069767442, gross_accuracy: 14.965116279069768, acc_median: 14.0
# Fitness: 28.96511627906977
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16614017688323712, 'gamma': 4.951248084493881, 'colsample_bytree': 1.0}
# tp_avg: 46.99418604651163, gross_accuracy: 14.680232558139535, acc_median: 15.0
# Fitness: 29.680232558139537
#
# {'subsample': 0.9682030798988943, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.1501053155815416, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 45.76162790697674, gross_accuracy: 14.44767441860465, acc_median: 13.0
# Fitness: 27.44767441860465
#
# {'subsample': 0.5, 'num_round': 1906, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.1675065355261914, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 49.0, gross_accuracy: 15.087209302325581, acc_median: 15.0
# Fitness: 30.087209302325583
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16576609136204276, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 48.924418604651166, gross_accuracy: 14.313953488372093, acc_median: 14.0
# Fitness: 28.313953488372093
#
# {'subsample': 0.5, 'num_round': 975, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.1698916244941983, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 49.01162790697674, gross_accuracy: 14.133720930232558, acc_median: 14.5
# Fitness: 28.633720930232556
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16859313900736086, 'gamma': 1.2754925251098529e-17, 'colsample_bytree': 1.0}
# tp_avg: 47.33720930232558, gross_accuracy: 14.819767441860465, acc_median: 15.5
# Fitness: 30.319767441860463
#
# {'subsample': 1.0, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.14925424663372544, 'gamma': 0.4003453866072997, 'colsample_bytree': 1.0}
# tp_avg: 50.73255813953488, gross_accuracy: 13.953488372093023, acc_median: 13.0
# Fitness: 26.953488372093023
#
# {'subsample': 0.8489725952806758, 'num_round': 1976, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.1799550557073571, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.30813953488372, gross_accuracy: 14.651162790697674, acc_median: 14.5
# Fitness: 29.151162790697676
#
# {'subsample': 1.0, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.18901151744346173, 'gamma': 2.722952792483126, 'colsample_bytree': 1.0}
# tp_avg: 47.901162790697676, gross_accuracy: 14.319767441860465, acc_median: 14.0
# Fitness: 28.319767441860463
#
# {'subsample': 0.9597575768240865, 'num_round': 800, 'min_child_weight': 33, 'max_depth': 7, 'learning_rate': 0.11310674037859847, 'gamma': 3.999216332733427, 'colsample_bytree': 0.8}
# tp_avg: 56.127906976744185, gross_accuracy: 11.476744186046512, acc_median: 11.0
# Fitness: 22.47674418604651
#
# {'subsample': 0.7939416948532927, 'num_round': 1404, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.16732415218878807, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 47.848837209302324, gross_accuracy: 14.540697674418604, acc_median: 14.0
# Fitness: 28.540697674418603
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16886364585349545, 'gamma': 1.8453906442792927, 'colsample_bytree': 1.0}
# tp_avg: 48.825581395348834, gross_accuracy: 14.412790697674419, acc_median: 14.5
# Fitness: 28.912790697674417
#
# {'subsample': 0.6680688250343438, 'num_round': 1688, 'min_child_weight': 19, 'max_depth': 14, 'learning_rate': 0.14019151429039123, 'gamma': 0.28784773220712107, 'colsample_bytree': 0.8180155825111597}
# tp_avg: 62.424418604651166, gross_accuracy: 4.406976744186046, acc_median: 7.0
# Fitness: 11.406976744186046
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 41, 'max_depth': 2, 'learning_rate': 0.15935048443012903, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.73837209302326, gross_accuracy: 14.38953488372093, acc_median: 15.0
# Fitness: 29.38953488372093
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.15327383172304532, 'gamma': 4.113901114080086, 'colsample_bytree': 0.8}
# tp_avg: 47.73255813953488, gross_accuracy: 14.11046511627907, acc_median: 14.0
# Fitness: 28.11046511627907
#
# {'subsample': 0.981039802064327, 'num_round': 1973, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16497904558306287, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 46.74418604651163, gross_accuracy: 14.267441860465116, acc_median: 13.5
# Fitness: 27.767441860465116
#
# {'subsample': 0.9676952734016102, 'num_round': 1943, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.17187119042525129, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 47.366279069767444, gross_accuracy: 14.767441860465116, acc_median: 14.0
# Fitness: 28.767441860465116
#
# {'subsample': 0.9987978634774797, 'num_round': 1482, 'min_child_weight': 43, 'max_depth': 4, 'learning_rate': 0.08314978848986056, 'gamma': 1.8277226987517206, 'colsample_bytree': 0.9778369284586538}
# tp_avg: 49.83720930232558, gross_accuracy: 13.895348837209303, acc_median: 13.0
# Fitness: 26.895348837209305
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16208565152716145, 'gamma': 5.0, 'colsample_bytree': 0.8}
# tp_avg: 47.906976744186046, gross_accuracy: 14.36046511627907, acc_median: 14.0
# Fitness: 28.36046511627907
#
# {'subsample': 0.9871674621211486, 'num_round': 944, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.15594806432792702, 'gamma': 1.5032575647034017, 'colsample_bytree': 1.0}
# tp_avg: 46.19186046511628, gross_accuracy: 14.587209302325581, acc_median: 14.0
# Fitness: 28.587209302325583
#
# {'subsample': 0.5749511227888424, 'num_round': 958, 'min_child_weight': 49, 'max_depth': 2, 'learning_rate': 0.21796160279707216, 'gamma': 3.4380954879052137, 'colsample_bytree': 0.9795099987493492}
# tp_avg: 50.348837209302324, gross_accuracy: 14.622093023255815, acc_median: 13.0
# Fitness: 27.622093023255815
#
# {'subsample': 0.9472517732232101, 'num_round': 1581, 'min_child_weight': 15, 'max_depth': 5, 'learning_rate': 0.08816194464394245, 'gamma': 3.711786987838688, 'colsample_bytree': 0.8038260075963974}
# tp_avg: 51.872093023255815, gross_accuracy: 13.220930232558139, acc_median: 13.5
# Fitness: 26.72093023255814
#
# {'subsample': 0.5125587458048143, 'num_round': 1584, 'min_child_weight': 50, 'max_depth': 3, 'learning_rate': 0.10074370427528818, 'gamma': 0.3829959990578969, 'colsample_bytree': 0.9942725932757089}
# tp_avg: 49.674418604651166, gross_accuracy: 14.273255813953488, acc_median: 14.5
# Fitness: 28.77325581395349
#
# {'subsample': 0.966999880026159, 'num_round': 1081, 'min_child_weight': 17, 'max_depth': 4, 'learning_rate': 0.2984515918275668, 'gamma': 2.420574625891823, 'colsample_bytree': 0.9835428399168984}
# tp_avg: 56.88953488372093, gross_accuracy: 11.372093023255815, acc_median: 12.0
# Fitness: 23.372093023255815
#
# {'subsample': 0.9939175048281055, 'num_round': 1974, 'min_child_weight': 44, 'max_depth': 3, 'learning_rate': 0.11726110490411482, 'gamma': 1.6271856892432166, 'colsample_bytree': 0.803039397125295}
# tp_avg: 48.348837209302324, gross_accuracy: 13.430232558139535, acc_median: 14.0
# Fitness: 27.430232558139537
#
# {'subsample': 0.9321471609935414, 'num_round': 1837, 'min_child_weight': 47, 'max_depth': 2, 'learning_rate': 0.2987491781754043, 'gamma': 0.4385644907387393, 'colsample_bytree': 0.9905358589538403}
# tp_avg: 50.372093023255815, gross_accuracy: 14.238372093023257, acc_median: 12.5
# Fitness: 26.73837209302326
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.15996925665713357, 'gamma': 0.4321961294990394, 'colsample_bytree': 1.0}
# tp_avg: 48.41860465116279, gross_accuracy: 13.906976744186046, acc_median: 13.0
# Fitness: 26.906976744186046
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 47, 'max_depth': 2, 'learning_rate': 0.16179416087579218, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 49.05232558139535, gross_accuracy: 14.755813953488373, acc_median: 14.5
# Fitness: 29.25581395348837
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16213170680959274, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.94186046511628, gross_accuracy: 14.773255813953488, acc_median: 15.0
# Fitness: 29.77325581395349
#
# {'subsample': 0.5, 'num_round': 1967, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16097755829069058, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.9593023255814, gross_accuracy: 14.69186046511628, acc_median: 15.0
# Fitness: 29.691860465116278
#
# {'subsample': 0.5, 'num_round': 1885, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.1612734004930485, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.424418604651166, gross_accuracy: 14.575581395348838, acc_median: 14.0
# Fitness: 28.575581395348838
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.15454200558705014, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 47.94767441860465, gross_accuracy: 14.627906976744185, acc_median: 15.0
# Fitness: 29.627906976744185
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 17, 'max_depth': 2, 'learning_rate': 0.16072775571590878, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.843023255813954, gross_accuracy: 14.633720930232558, acc_median: 14.5
# Fitness: 29.133720930232556
#
# {'subsample': 0.5, 'num_round': 1617, 'min_child_weight': 45, 'max_depth': 2, 'learning_rate': 0.16438321647140297, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.93023255813954, gross_accuracy: 14.616279069767442, acc_median: 15.0
# Fitness: 29.616279069767444
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16054784293953442, 'gamma': 4.283955195181891, 'colsample_bytree': 1.0}
# tp_avg: 48.901162790697676, gross_accuracy: 14.494186046511627, acc_median: 15.5
# Fitness: 29.99418604651163
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 9, 'max_depth': 2, 'learning_rate': 0.16007352379470843, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.96511627906977, gross_accuracy: 14.546511627906977, acc_median: 16.0
# Fitness: 30.546511627906977
#
# {'subsample': 0.5, 'num_round': 1776, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16358216869091538, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 49.00581395348837, gross_accuracy: 14.75, acc_median: 14.0
# Fitness: 28.75
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.1592878005306258, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.70348837209303, gross_accuracy: 14.482558139534884, acc_median: 15.5
# Fitness: 29.982558139534884
#
# {'subsample': 0.5, 'num_round': 1788, 'min_child_weight': 39, 'max_depth': 2, 'learning_rate': 0.15698745859088184, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.01744186046512, gross_accuracy: 13.86046511627907, acc_median: 13.5
# Fitness: 27.36046511627907
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.1716638142494669, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 49.075581395348834, gross_accuracy: 14.63953488372093, acc_median: 15.0
# Fitness: 29.63953488372093
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.1499710461774926, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 47.94186046511628, gross_accuracy: 14.5, acc_median: 14.0
# Fitness: 28.5
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16167458982962926, 'gamma': 2.9651713963649344, 'colsample_bytree': 1.0}
# tp_avg: 48.51744186046512, gross_accuracy: 14.273255813953488, acc_median: 14.0
# Fitness: 28.27325581395349
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.1611531090291253, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.48837209302326, gross_accuracy: 14.529069767441861, acc_median: 15.0
# Fitness: 29.52906976744186
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16198609923464702, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.81395348837209, gross_accuracy: 14.348837209302326, acc_median: 14.0
# Fitness: 28.348837209302324
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 40, 'max_depth': 2, 'learning_rate': 0.16190668515260923, 'gamma': 0.44865112933369966, 'colsample_bytree': 1.0}
# tp_avg: 48.906976744186046, gross_accuracy: 14.796511627906977, acc_median: 15.0
# Fitness: 29.796511627906977
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.15843570107152874, 'gamma': 4.519579269025416, 'colsample_bytree': 1.0}
# tp_avg: 48.825581395348834, gross_accuracy: 14.883720930232558, acc_median: 14.0
# Fitness: 28.883720930232556
#
# {'subsample': 0.5174683264883566, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.1628360056125939, 'gamma': 4.996526025792742, 'colsample_bytree': 1.0}
# tp_avg: 48.74418604651163, gross_accuracy: 14.366279069767442, acc_median: 14.5
# Fitness: 28.866279069767444
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16169688555406142, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.72093023255814, gross_accuracy: 14.38953488372093, acc_median: 14.0
# Fitness: 28.38953488372093
#
# {'subsample': 0.5, 'num_round': 1269, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.15818295664819643, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.53488372093023, gross_accuracy: 14.284883720930232, acc_median: 13.5
# Fitness: 27.78488372093023
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16160746090533268, 'gamma': 1.8125898411074104, 'colsample_bytree': 1.0}
# tp_avg: 48.616279069767444, gross_accuracy: 14.482558139534884, acc_median: 15.0
# Fitness: 29.482558139534884
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.1605440366992177, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 48.895348837209305, gross_accuracy: 14.459302325581396, acc_median: 15.5
# Fitness: 29.959302325581397
#
# {'subsample': 0.5, 'num_round': 1637, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.15635752590686589, 'gamma': 2.9697936763842, 'colsample_bytree': 1.0}
# tp_avg: 48.25, gross_accuracy: 14.279069767441861, acc_median: 14.0
# Fitness: 28.27906976744186
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.15951991928709258, 'gamma': 0.0, 'colsample_bytree': 1.0}
# tp_avg: 48.66279069767442, gross_accuracy: 14.30813953488372, acc_median: 14.0
# Fitness: 28.308139534883722
#
# {'subsample': 0.5, 'num_round': 1927, 'min_child_weight': 43, 'max_depth': 2, 'learning_rate': 0.1628434455633156, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.96511627906977, gross_accuracy: 14.936046511627907, acc_median: 14.0
# Fitness: 28.936046511627907
#
# {'subsample': 0.5358854858151937, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16666540336536062, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.53488372093023, gross_accuracy: 14.69186046511628, acc_median: 14.5
# Fitness: 29.191860465116278
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.16234259031320109, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.9593023255814, gross_accuracy: 14.651162790697674, acc_median: 14.0
# Fitness: 28.651162790697676
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 23, 'max_depth': 2, 'learning_rate': 0.16257872019746597, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.93604651162791, gross_accuracy: 14.63953488372093, acc_median: 14.5
# Fitness: 29.13953488372093
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.1583629088201851, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 49.08720930232558, gross_accuracy: 14.813953488372093, acc_median: 14.0
# Fitness: 28.813953488372093
#
# {'subsample': 0.5, 'num_round': 952, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16148048508955543, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.4593023255814, gross_accuracy: 14.244186046511627, acc_median: 15.0
# Fitness: 29.24418604651163
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16175569320399488, 'gamma': 0.600696338218289, 'colsample_bytree': 1.0}
# tp_avg: 48.83720930232558, gross_accuracy: 14.470930232558139, acc_median: 14.0
# Fitness: 28.47093023255814
#
# {'subsample': 0.5, 'num_round': 800, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.15999573420498456, 'gamma': 4.704047132668798, 'colsample_bytree': 1.0}
# tp_avg: 48.424418604651166, gross_accuracy: 13.94767441860465, acc_median: 15.0
# Fitness: 28.94767441860465
#
# {'subsample': 0.5, 'num_round': 1692, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16199111237002523, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.825581395348834, gross_accuracy: 14.36046511627907, acc_median: 14.0
# Fitness: 28.36046511627907
#
# {'subsample': 0.7321184505153401, 'num_round': 2000, 'min_child_weight': 49, 'max_depth': 2, 'learning_rate': 0.16468902246199044, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 47.44186046511628, gross_accuracy: 14.19767441860465, acc_median: 15.5
# Fitness: 29.69767441860465
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 47, 'max_depth': 2, 'learning_rate': 0.1535457276379955, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.01162790697674, gross_accuracy: 14.412790697674419, acc_median: 15.5
# Fitness: 29.912790697674417
#
# {'subsample': 0.5, 'num_round': 1786, 'min_child_weight': 11, 'max_depth': 2, 'learning_rate': 0.16019570341862288, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.78488372093023, gross_accuracy: 14.627906976744185, acc_median: 15.0
# Fitness: 29.627906976744185
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.1603722487048855, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.94186046511628, gross_accuracy: 14.61046511627907, acc_median: 15.0
# Fitness: 29.61046511627907
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.16664692227026795, 'gamma': 4.315514076104131, 'colsample_bytree': 1.0}
# tp_avg: 49.21511627906977, gross_accuracy: 14.5, acc_median: 13.5
# Fitness: 28.0
#
# {'subsample': 0.5790803519880524, 'num_round': 2000, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.15805842759385536, 'gamma': 4.6984101929792, 'colsample_bytree': 1.0}
# tp_avg: 48.372093023255815, gross_accuracy: 14.587209302325581, acc_median: 15.0
# Fitness: 29.587209302325583
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 11, 'max_depth': 2, 'learning_rate': 0.15860142663800494, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.78488372093023, gross_accuracy: 14.569767441860465, acc_median: 14.0
# Fitness: 28.569767441860463
#
# {'subsample': 0.5224270761865873, 'num_round': 1907, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.1592436668289271, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.145348837209305, gross_accuracy: 14.5, acc_median: 15.0
# Fitness: 29.5
#
# {'subsample': 0.5, 'num_round': 1784, 'min_child_weight': 50, 'max_depth': 2, 'learning_rate': 0.1656031912673665, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.79651162790697, gross_accuracy: 14.325581395348838, acc_median: 13.0
# Fitness: 27.325581395348838
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.15887216672340193, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.843023255813954, gross_accuracy: 14.540697674418604, acc_median: 13.5
# Fitness: 28.040697674418603
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 38, 'max_depth': 2, 'learning_rate': 0.16097306308892306, 'gamma': 5.0, 'colsample_bytree': 1.0}
# tp_avg: 48.33720930232558, gross_accuracy: 14.13953488372093, acc_median: 14.0
# Fitness: 28.13953488372093
#
# {'subsample': 0.5, 'num_round': 2000, 'min_child_weight': 5, 'max_depth': 2, 'learning_rate': 0.15747534340276745, 'gamma': 0.4916463447949085, 'colsample_bytree': 1.0}
# tp_avg: 48.21511627906977, gross_accuracy: 14.459302325581396, acc_median: 15.0
# Fitness: 29.459302325581397
#
# {'subsample': 0.9299160133288817, 'num_round': 2000, 'min_child_weight': 27, 'max_depth': 2, 'learning_rate': 0.15771647836236524, 'gamma': 5.0, 'colsample_bytree': 1.0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 66
#      61     return -fitness  # Minimize negative fitness
#      65 # Perform Bayesian Optimization
# ---> 66 result = gp_minimize(
#      67     func=objective,
#      68     dimensions=param_space,
#      69     n_calls=500,  # Increase if needed
#      70     random_state=None,  # Remove the random seed for different results each run
#      71     n_initial_points=10  # Number of random points before optimization starts
#      72 )
#      74 # Best hyperparameters found
#      75 best_hyperparameters = {dim.name: result.x[i] for i, dim in enumerate(param_space)}
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/skopt/optimizer/gp.py:281, in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size, space_constraint)
#     273 if base_estimator is None:
#     274     base_estimator = cook_estimator(
#     275         "GP",
#     276         space=space,
#     277         random_state=rng.randint(0, np.iinfo(np.int32).max),
#     278         noise=noise,
#     279     )
# --> 281 return base_minimize(
#     282     func,
#     283     space,
#     284     base_estimator=base_estimator,
#     285     acq_func=acq_func,
#     286     xi=xi,
#     287     kappa=kappa,
#     288     acq_optimizer=acq_optimizer,
#     289     n_calls=n_calls,
#     290     n_points=n_points,
#     291     n_random_starts=n_random_starts,
#     292     n_initial_points=n_initial_points,
#     293     initial_point_generator=initial_point_generator,
#     294     n_restarts_optimizer=n_restarts_optimizer,
#     295     x0=x0,
#     296     y0=y0,
#     297     random_state=rng,
#     298     verbose=verbose,
#     299     space_constraint=space_constraint,
#     300     callback=callback,
#     301     n_jobs=n_jobs,
#     302     model_queue_size=model_queue_size,
#     303 )
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/skopt/optimizer/base.py:332, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size, space_constraint)
#     330 for _ in range(n_calls):
#     331     next_x = optimizer.ask()
# --> 332     next_y = func(next_x)
#     333     result = optimizer.tell(next_x, next_y)
#     334     result.specs = specs
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/skopt/utils.py:779, in use_named_args.<locals>.decorator.<locals>.wrapper(x)
#     776 arg_dict = {dim.name: value for dim, value in zip(dimensions, x)}
#     778 # Call the wrapped objective function with the named arguments.
# --> 779 objective_value = func(**arg_dict)
#     781 return objective_value
#
# Cell In[36], line 36, in objective(**params)
#      26 hyperparams = {
#      27     'subsample': params['subsample'],
#      28     'num_round': params['num_round'],
#    (...)
#      33     'colsample_bytree': params['colsample_bytree']
#      34 }
#      35 print(hyperparams)
# ---> 36 tp_avg_list, gross_accuracy_list = run_temporal_simulation_hyperparams(
#      37     features, target_label, target_percentile,
#      38     dataset_start_date=datetime(2018, 1, 1),
#      39     evaluation_start_date=datetime(2021, 1, 4),
#      40     # evaluation_end_date=datetime(2021, 1, 25),
#      41     evaluation_end_date=datetime(2024, 4, 20),
#      42     strategy=title, hyperparams=hyperparams
#      43 )
#      45 acc_median = np.median(gross_accuracy_list)
#      46 tp_avg = sum(tp_avg_list) / len(tp_avg_list)
#
# Cell In[33], line 24, in run_temporal_simulation_hyperparams(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date, strategy, hyperparams)
#      22 dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
#      23 for date in dates_list:
# ---> 24     tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams,strategy)
#      25     tp_avg_list.append(tp)
#      26     gross_accuracy_list.append((tp-fp))
#
# Cell In[26], line 37, in model_runner_temporal_simulation(features, target_label, target_percentile, dataset_start_date, end_date, deployment_date, hyperparams, strategy)
#      35 def model_runner_temporal_simulation(features, target_label, target_percentile,dataset_start_date,end_date,deployment_date,hyperparams,strategy):
#      36     validation_end_date = build_validation_dates_local(deployment_date)
# ---> 37     dataset = pull_training_data_local(end_date, strategy)
#      38     validation_dataset = pull_validation_data_local(validation_end_date,deployment_date, strategy)
#      39     # dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
#      40     # validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
#      41     # dataset.dropna(subset=["close_diff_deviation"],inplace=True)
#      42     # validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
#
# Cell In[21], line 11, in pull_training_data_local(end_date, strategy)
#       9 data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/BF/2015-01-01_2024-05-03EXP.csv')
#      10 data['dt'] = pd.to_datetime(data['date'])
# ---> 11 data = data.loc[data['dt'] <= end_date]
#      12 data['one_max_vol'] = (data['one_max']/data['return_vol_5D']).round(3)
#      13 data['three_max_vol'] = (data['three_max']/data['return_vol_5D']).round(3)
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/core/indexing.py:1413, in _LocIndexer._getitem_axis(self, key, axis)
#    1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
# -> 1413     return self._getbool_axis(key, axis=axis)
#    1414 elif is_list_like_indexer(key):
#    1415     # an iterable multi-selection
#    1416     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/core/indexing.py:1211, in _LocationIndexer._getbool_axis(self, key, axis)
#    1209 key = check_bool_indexer(labels, key)
#    1210 inds = key.nonzero()[0]
# -> 1211 return self.obj._take_with_is_copy(inds, axis=axis)
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/core/generic.py:4153, in NDFrame._take_with_is_copy(self, indices, axis)
#    4142 @final
#    4143 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4144     """
#    4145     Internal version of the `take` method that sets the `_is_copy`
#    4146     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4151     See the docstring of `take` for full explanation of the parameters.
#    4152     """
# -> 4153     result = self.take(indices=indices, axis=axis)
#    4154     # Maybe set copy if we didn't actually change the index.
#    4155     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/core/generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/core/internals/managers.py:894, in BaseBlockManager.take(self, indexer, axis, verify)
#     891 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     893 new_labels = self.axes[axis].take(indexer)
# --> 894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#     897     axis=axis,
#     898     allow_dups=True,
#     899     copy=None,
#     900 )
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/core/internals/managers.py:687, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
# --> 687     new_blocks = [
#     688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/core/internals/managers.py:688, in <listcomp>(.0)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/core/internals/blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/core/array_algos/take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~/.local/share/virtualenvs/model-tester-tjbixvgX/lib/python3.9/site-packages/pandas/core/array_algos/take.py:162, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
# --> 162 func(arr, indexer, out, fill_value)
#     164 if flip_order:
#     165     out = out.T
#
# KeyboardInterrupt:
