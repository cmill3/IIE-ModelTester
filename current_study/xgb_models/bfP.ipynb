# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler
import pytz
import warnings
warnings.filterwarnings('ignore')

# %%
s3 = boto3.client('s3')
STRATEGY = 'BFC_1D'
training_bucket = "icarus-research-data"
training_prefix = 'training_datasets/expanded_1d_datasets/'

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

index = ["QQQ","SPY","IWM","TLT"]
test_lag = ["DAL","UAL","VZ","T","AAL","AMC"]
train_lag = ["AMC"]

# big_fish =  [
#             "AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","PLTR","BAC","AAPL","NFLX","ABNB","CRWD","SHOP","FB","CRM",
#             "MSFT","F","V","MA","JNJ","DIS","JPM","INTC","ADBE","BA","CVX","MRNA","PFE","SNOW","SOFI",'META',
#             ]

# bf_plus = ["AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","PLTR","BAC","AAPL","NFLX","ABNB","CRWD","SHOP","FB","CRM",
#             "MSFT","F","V","MA","JNJ","DIS","JPM","INTC","ADBE","BA","CVX","MRNA","PFE","SNOW","NKE",'META',
#             'C','TGT','MMM','SQ','PANW','DAL','CSCO','UBER','SBUX']


all_symbols = ['ZM', 'UBER', 'CMG', 'AXP', 'TDOC', 'UAL', 'DAL', 'MMM', 'PEP', 'GE', 'RCL', 'MRK',
 'HD', 'LOW', 'VZ', 'PG', 'TSM', 'GOOG', 'GOOGL', 'AMZN', 'BAC', 'AAPL', 'ABNB',
 'CRM', 'MSFT', 'F', 'V', 'MA', 'JNJ', 'DIS', 'JPM', 'ADBE', 'BA', 'CVX', 'PFE',
 'META', 'C', 'CAT', 'KO', 'MS', 'GS', 'IBM', 'CSCO','TSLA','LCID','NIO','WFC',
 'TGT', 'COST', 'RIVN', 'COIN', 'SQ', 'SHOP', 'DOCU', 'ROKU', 'TWLO', 'DDOG', 'ZS', 'NET',
 'OKTA', 'UPST', 'ETSY', 'PINS', 'FUTU', 'SE', 'BIDU', 'JD', 'BABA', 'RBLX', 'AMD',
 'NVDA', 'PYPL', 'PLTR', 'NFLX', 'CRWD', 'INTC', 'MRNA', 'SNOW', 'SOFI', 'PANW',
 'ORCL','WBD','ARM','SNAP','BILI','AAL','CCL','NCLH','LYFT','BIDU','JD','BABA','HD','LOW',
 'SBUX','NKE','AFFRM','WMT']

high_vol = ['ZM', 'UBER', 'TDOC', 'UAL', 'RCL', 'AMZN', 'ABNB', 'META', 'TSLA',
       'LCID', 'NIO', 'RIVN', 'SQ', 'SHOP', 'DOCU', 'ROKU',
       'TWLO', 'DDOG', 'ZS', 'NET', 'OKTA', 'ETSY', 'PINS',
       'FUTU', 'SE', 'RBLX', 'AMD', 'NVDA', 'PYPL', 'PLTR', 'NFLX',
       'CRWD', 'MRNA', 'SNOW', 'SOFI', 'WBD', 'ARM', 'SNAP', 'BILI',
       'AAL', 'CCL', 'NCLH', 'LYFT', 'BIDU', 'JD', 'BABA', 'MU', 'AMAT',
       'DKNG', 'CZR', 'VXX']

mid_vol =['CMG', 'AXP', 'DAL', 'GE', 'TSM', 'GOOG', 'GOOGL', 'BAC', 'AAPL',
       'CRM', 'MSFT', 'F', 'DIS', 'ADBE', 'BA', 'CVX', 'C', 'CAT', 'MS',
       'WFC', 'TGT', 'INTC', 'PANW', 'ORCL', 'LOW', 'SBUX', 'NKE', 'QCOM',
       'AVGO', 'TXN', 'MGM', 'XOM']

low_vol = ['MMM', 'MRK', 'HD', 'VZ', 'V', 'MA', 'JPM',
       'PFE', 'GS', 'IBM', 'CSCO', 'WMT', 'COST', 'QQQ', 'SPY',
       'TLT', 'IWM']

bfpidx = ["AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","BAC","AAPL","FB","DIS"
          "MSFT","INTC","PFE","SNOW",'META','C','XOM',"QQQ","SPY","IWM","TLT"]


bf2 = ['QQQ','IWM','AAPL','NVDA','AMD','AMZN','SPY','MSFT','GOOG','GOOGL','C','BAC',
      'JPM','XOM','CVX','CSCO','INTC','DIS','IBM','BA', 'V','AXP','PYPL','ADBE','F','GM']

GE = [
    'QQQ','SPY','IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD','SHOP'
    'AXP', 'AAPL', 'BAC', 'BA', 'CVX', 'CSCO', 'C', 'DIS', 'XOM', 
    'GM', 'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA', 'PYPL','PANW','ADBE'
    'TSLA', 'V', 'SQ', 'TSM', 'QCOM', 'UBER', 'SNOW', 'PLTR', 'ABNB',
    "FB",'META',"TGT","NKE","SBUX","ORCL","DDOG","JNJ","AVGO","COST"
    ]
BF3 = ['QQQ', 'SPY', 'IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD', 'AAPL', 'BAC',
       'BA', 'C', 'DIS', 'XOM', 'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA',
       'TSLA', 'V', 'TSM', 'QCOM', 'SNOW', 'TGT', 'NKE', 'SBUX', 'ORCL',
       'PYPL', 'SQ', 'UBER', 'PLTR', 'ABNB', 'META']
PE = ['SPY', 'TSLA', 'QQQ', 'AMD', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN','TSM','BAC','C','XOM','DIS','SBUX','PYPL','NKE']
PE2 = ['SPY', 'TSLA', 'QQQ', 'AMD', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN','TSM','XOM','DIS','PYPL','BA','NFLX','NVDA','GOOG','META']
## NVDA,NFLX,GOOG,META,AVGO,COST w/ increased capital

BF3_TRIMMED = [
    'QQQ','SPY','IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD', 
    'AAPL', 'BAC', 'BA', 'C', 'DIS', 'XOM', 
    'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA', 'PYPL',
    'TSLA', 'V', 'SQ', 'TSM', 'QCOM', 'UBER', 'SNOW', 'PLTR', 'ABNB',
    "FB",'META',"TGT","NKE","SBUX","ORCL"
    ]

t11 = ['NVDA', 'SPY', 'TSLA', 'QQQ', 'AMD', 'GOOG', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN']

# %%
def configure_dates(data,strategy):
    if strategy in ["CDBFC","CDBFP"]:
        data = data.loc[data['day_of_week'].isin([0,1,2])] 
    elif strategy in ["CDBFC_1D","CDBFP_1D"]:
        data = data.loc[data['day_of_week'].isin([0,1,2,3])]
    return data

def pull_training_data_local(end_date,strategy):
    data = pd.read_csv('/Users/charlesmiller/Documents/model_tester_data/BF/2015-01-01_2024-04-20.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data['one_max_vol'] = (data['one_max']/data['return_vol_10D']).round(3)
    data['three_max_vol'] = (data['three_max']/data['return_vol_10D']).round(3)
    data['one_min_vol'] = (data['one_min']/data['return_vol_10D']).round(3)
    data['three_min_vol'] = (data['three_min']/data['return_vol_10D']).round(3)    
    # data['one_max_vol30'] = (data['one_max']/data['return_vol_30D']).round(3)
    # data['three_max_vol30'] = (data['three_max']/data['return_vol_30D']).round(3)
    # data['one_min_vol30'] = (data['one_min']/data['return_vol_30D']).round(3)
    # data['three_min_vol30'] = (data['three_min']/data['return_vol_30D']).round(3)    
    # data['cd_vol'] = (data['close_diff']/data['return_vol_10D']).round(3)
    # data['cd_vol3'] = (data['close_diff3']/data['return_vol_10D']).round(3)
    # data['cd_vol30'] = (data['close_diff']/data['return_vol_30D']).round(3)
    data['cd_vol'] = (data['price_change_D']/data['return_vol_10D']).round(3)
    data['cd_vol3'] = (data['price_3Ddiff']/data['return_vol_10D']).round(3)
    # data['cd_vol330'] = (data['close_diff3']/data['return_vol_30D']).round(3)
    data = data.loc[data['symbol'].isin(BF3)]
    data = configure_dates(data,strategy)
    data.replace([np.inf, -np.inf], 0, inplace=True)
    return data


def pull_validation_data_local(end_date,start_date,strategy):
    data = pd.read_csv('/Users/charlesmiller/Documents/model_tester_data/BF/2015-01-01_2024-04-20.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data['one_max_vol'] = (data['one_max']/data['return_vol_10D']).round(3)
    data['three_max_vol'] = (data['three_max']/data['return_vol_10D']).round(3)
    data['one_min_vol'] = (data['one_min']/data['return_vol_10D']).round(3)
    data['three_min_vol'] = (data['three_min']/data['return_vol_10D']).round(3)    
    # data['one_max_vol30'] = (data['one_max']/data['return_vol_30D']).round(3)
    # data['three_max_vol30'] = (data['three_max']/data['return_vol_30D']).round(3)
    # data['one_min_vol30'] = (data['one_min']/data['return_vol_30D']).round(3)
    # data['three_min_vol30'] = (data['three_min']/data['return_vol_30D']).round(3)    
    data['cd_vol'] = (data['price_change_D']/data['return_vol_10D']).round(3)
    data['cd_vol3'] = (data['price_3Ddiff']/data['return_vol_10D']).round(3)
    # data['cd_vol30'] = (data['close_diff']/data['return_vol_30D']).round(3)
    # data['cd_vol330'] = (data['close_diff3']/data['return_vol_30D']).round(3)
    data = data.loc[data['dt'] <= end_date]
    data = data.loc[data['dt'] >= start_date]
    data = data.loc[data['symbol'].isin(PE2)]
    data = configure_dates(data,strategy)
    data.replace([np.inf, -np.inf], 0, inplace=True)
    return data

# %%
def build_date_list(start_date, end_date):
    print(start_date, end_date)
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_validation_dates_local(deployment_date):
    end_date = deployment_date + timedelta(days=5)
    return end_date

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] < target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] < target_value).astype(int)

    # dataset = dataset.round(3)
    # validation_dataset = validation_dataset.round(3)

    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']


    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],
                                  min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],
                                  learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],
                                  colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',
                                  random_state=42)
    xgb_model.fit(X,y)

    print(y.value_counts())
    predictions = xgb_model.predict(X_validate)
    probabilities = xgb_model.predict_proba(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,str(fi_list), predictions, probabilities


def train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] < target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] < target_value).astype(int)

    dataset = dataset.round(5)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']
    

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,"str(fi_list)", predictions, "probabilities"

# %%
# def model_runner_v2RM(model_name, dataset_name, title, features, target_label, target_percentile, start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
#     validation_end_date = build_validation_dates_local(deployment_date)
#     validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
#     dataset = pull_training_data_local(end_date, dataset_start_date)
#     dates_list = pull_gmm_labels(deployment_date)
#     rm_dataset = dataset.loc[dataset['dt'].isin(dates_list)]
#     target_value = rm_dataset[target_label].quantile(target_percentile).round(3)
#     print(target_value)
#     print(len(rm_dataset)/len(dataset))
#     tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, rm_dataset, validation_dataset, target_label, target_value, hyperparams)
#     response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
#     validation_dataset['probabilities'] = probabilities[:,1]
#     validation_dataset['predictions'] = predictions
#     validation_dataset['target_value'] = target_value
#     validation_dataset['target_pct'] = validation_dataset['target_value'] * validation_dataset['return_vol_10D']
#     validation_csv = validation_dataset.to_csv()
#     put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
#     return response

def model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile, start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
    validation_end_date = build_validation_dates_local(deployment_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date, title)
    dataset = pull_training_data_local(end_date, title)
    target_value = dataset[target_label].quantile(target_percentile).round(3)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
    validation_dataset['probabilities'] = probabilities[:,1]
    validation_dataset['predictions'] = predictions
    validation_dataset['target_value'] = target_value
    validation_dataset['target_pct'] = validation_dataset['target_value'] * validation_dataset['return_vol_10D']
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    return response

def model_runner_temporal_simulation(features, target_label, target_percentile,dataset_start_date,end_date,deployment_date,hyperparams, strategy):
    validation_end_date = build_validation_dates_local(deployment_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date, strategy)
    dataset = pull_training_data_local(end_date, strategy)
    # print(len(dataset))
    # print(len(validation_dataset))
    # dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    # validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    # dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    # validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    # print(len(dataset))
    # print(len(validation_dataset))
    target_value = dataset[target_label].quantile(target_percentile).round(3)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    return tp, fp, fn, tn 

# def model_runner_data(start_date,end_date):
#     dates = build_date_list(start_date, end_date)
#     key_list = build_query_keys(dates)
#     print(key_list[-1])
#     train_data = create_training_data_local(key_list, 'full_alerts/weekly_exp_alerts/', 'inv-alerts', 'cdvol_gainers', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
#     val_data = create_validation_data_local(key_list, 'full_alerts/trading_symbols_alerts/', 'inv-alerts', 'cdvol_gainers', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
#     return "train_data", "val_data"

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=10),
            "dataset_start": datetime(2018,1,1)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

def pull_gmm_labels(date):
    date_str = date.strftime('%Y-%m-%d')
    data_20d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm20d_labels_RM2/{date_str}.csv')
    data_10d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm10d_labels_RM2/{date_str}.csv')
    data_3d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm3d_labels_RM2/{date_str}.csv')

    data_20d = pd.read_csv(data_20d.get("Body"))
    data_10d = pd.read_csv(data_10d.get("Body"))
    data_3d = pd.read_csv(data_3d.get("Body"))

    data_20d['dt'] = pd.to_datetime(data_20d['date'])
    data_10d['dt'] = pd.to_datetime(data_10d['date'])
    data_3d['dt'] = pd.to_datetime(data_3d['date'])

    label_20d = data_20d['labels'].iloc[-1]
    label_10d = data_10d['labels'].iloc[-1]
    label_3d = data_3d['labels'].iloc[-1]

    dates_20d = data_20d['dt'].loc[data_20d['labels'] == label_20d].tolist()
    dates_10d = data_10d['dt'].loc[data_10d['labels'] == label_10d].tolist()
    dates_3d = data_3d['dt'].loc[data_3d['labels'] == label_3d].tolist()

    # combined_list = list(set(dates_20d  + dates_3d))
    return dates_20d

# %%
# target_percentile = 0.4
# title = 'CDBFP'
# model_name = f'{title}:TSSIM2_BF3NFS_custHypTP{target_percentile}'
# dataset_name = f'TSSIM2_BF3NFS_custHypTP{target_percentile}'
# hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
# features = ['cmf', 'return_vol_5D_diff', 'High-Low', 'macd', 'price_range_8MA_diff', 'volume_15MA_diff', 'volume_sum15_10DMA_diff', 'SPY_20d_diff', 
#             'return_vol_10D_diff', 'rsi_15MA', 'price_3Ddiff', 'DIplus', 'PrevClose-L', 'cd_vol3', 'cmf_15MA', 'return_vol_8H_diff', 'price_change_D', 
#             'DIminus', 'day_of_week', 'return_vol_5D', 'rsi_15MA_diff', 'roc_15MA_diff', 'bb_trend', 'price_change_H', 'price_10Ddiff', 'price_range', 
#             'DMplus', 'volume_sum15_5DMA_diff', 'H-L', 'roc', 'return_vol_10D', 'macd_15MA_diff', 'month', 'DX', 'cd_vol', 'volume_sum15', 'SPY_5d_diff', 
#             'H-PrevClose', 'adx', 'Low-Close', 'return_vol_8H', 'bb_spread', 'roc5', 'hour', 'bb_category']

# target_label = 'one_min_vol'


# dataset_start_date = datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')) 
# dates_list = build_evaluation_period(datetime(2020,1,6), datetime(2024,4,20))
# # date = dates_list[-1]
# # print(date)
# # response = model_runner_data(start_date=datetime(2018,1,1),end_date=datetime(2023,12,23))

# # dataset = pull_training_data_local(start_date=datetime(2018,1,1),end_date=datetime(2023,12,23))

# for date in dates_list:
#     print(date)
#     response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile,"dataset_start_date",date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])

# %%
# data = pull_training_data_local(datetime(2023,9,23,tzinfo=pytz.timezone('US/Eastern')), datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')))

# %%
# list = ['date', 'hour', 'symbol', 't', 'price7', 'price14', 'adjusted_volume', 'vol7', 'vol14', 'rsi', 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close', 'oneD_returns_close', 'range_vol', 'range_vol5MA', 'range_vol10MA', 
#         'range_vol25MA', 'oneD_stddev50', 'threeD_stddev50', 'cmf', 'close_diff', 'close_diff3', 'close_diff5', 'v_diff_pct', 'adx', 'volume_10MA', 'volume_25MA', 'price_10MA', 'price_25MA', 'volume_10DDiff', 'volume_25DDiff', 'price_10DDiff', 
#         'price_25DDiff', 'one_max', 'one_min', 'one_pct', 'three_max', 'three_min', 'three_pct', 'SPY_diff', 'SPY_diff3', 'SPY_diff5', 'SPY_1D', 'SPY_3D', 'SPY_5D', 'return_vol_15M', 'volume_vol_15M', 'return_vol_30M', 'volume_vol_30M', 
#         'return_vol_60M', 'volume_vol_60M', 'return_vol_120M', 'volume_vol_120M', 'return_vol_240M', 'volume_vol_240M', 'return_vol_450M', 'volume_vol_450M', '15min_vol_diff', '15min_vol_diff_pct', 'min_vol_diff', 'min_vol_diff_pct', 'min_volume_vol_diff', 
#         'min_volume_vol_diff_pct', 'return_vol_4H', 'return_vol_8H', 'return_vol_16H', 'volume_vol_4H', 'volume_vol_8H', 'volume_vol_16H', 'hour_vol_diff', 'hour_vol_diff_pct', 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_3D', 'return_vol_5D', 
#         'return_vol_10D', 'return_vol_30D', 'volume_vol_3D', 'volume_vol_5D', 'volume_vol_10D', 'volume_vol_30D', 'daily_vol_diff', 'daily_vol_diff_pct', 'daily_vol_diff30', 'daily_vol_diff_pct30', 'daily_volume_vol_diff', 'daily_volume_vol_diff_pct', 'daily_volume_vol_diff30',
#         'daily_volume_vol_diff_pct30', 'roc_diff', 'range_vol_diff5', 'close_diff_deviation3', 'close_diff_deviation', 'day_of_week', 'day_of_month', 'month', 'year', 'dt']

# %%
def run_temporal_simulation(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date,strategy):
    tp_avg_list = []
    gross_accuracy_list = []
    # fn_list = []
    # tn_list = []
    
    hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
    dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
    # date = dates_list[-1]
    # response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
    for date in dates_list:
        tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams,strategy)
        tp_avg_list.append(tp)
        gross_accuracy_list.append((tp-fp))

    return tp_avg_list, gross_accuracy_list

# %%
number_of_simulations = 75
now = datetime.now()
title = 'CDBFP'
# total_feature_list = ['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'v', 'o', 'c', 'h', 'l',
#  'date', 'hour', 'symbol', 't', 'price7', 'price14', 'adjusted_volume', 'vol7', 'vol14', 'rsi', 
# 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close', 'oneD_returns_close', 'range_vol', 
# 'range_vol5MA', 'range_vol10MA', 'range_vol25MA', 'oneD_stddev50', 'threeD_stddev50', 'cmf', 'close_diff', 
# 'close_diff3', 'close_diff5', 'v_diff_pct', 'adx', 'volume_10MA', 'volume_25MA', 'price_10MA', 'price_25MA',
# 'volume_10DDiff', 'volume_25DDiff', 'price_10DDiff', 'price_25DDiff', 'one_max', 'one_min', 'one_pct', 
# 'three_max', 'three_min', 'three_pct', 'SPY_diff', 'SPY_diff3', 'SPY_diff5', 'SPY_1D', 'SPY_3D', 'SPY_5D', 
# 'vw', 'n', 'return_vol_15M', 'volume_vol_15M', 'return_vol_30M', 'volume_vol_30M', 'return_vol_60M', 
# 'volume_vol_60M', 'return_vol_120M', 'volume_vol_120M', 'return_vol_240M', 'volume_vol_240M', 
# 'return_vol_450M', 'volume_vol_450M', '15min_vol_diff', '15min_vol_diff_pct', 'min_vol_diff', 
# 'min_vol_diff_pct', 'min_volume_vol_diff', 'min_volume_vol_diff_pct', 'return_vol_4H', 'return_vol_8H', 
# 'return_vol_16H', 'volume_vol_4H', 'volume_vol_8H', 'volume_vol_16H', 'hour_vol_diff', 'hour_vol_diff_pct', 
# 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_3D', 'return_vol_5D', 'return_vol_10D', 
# 'return_vol_30D', 'volume_vol_3D', 'volume_vol_5D', 'volume_vol_10D', 'volume_vol_30D', 'daily_vol_diff', 
# 'daily_vol_diff_pct', 'daily_vol_diff30', 'daily_vol_diff_pct30', 'daily_volume_vol_diff', 'daily_volume_vol_diff_pct', 
# 'daily_volume_vol_diff30', 'daily_volume_vol_diff_pct30', 'cd_vol', 'cd_vol3', 'roc_diff', 'range_vol_diff5', 
# 'close_diff_deviation3', 'close_diff_deviation', 'day_of_week', 'day_of_month', 'month', 'year', 'dt', 'one_max_vol', 
# 'three_max_vol', 'one_min_vol', 'three_min_vol']

testing_features = ['price_change_H', 'cd_vol', 'price_range', 'bb_trend', 'price_range_5DMA_diff', 'roc', 'bb_category', 'bb_spread', 'volume_15MA_diff', 'price_change_D', 'month', 'return_vol_10D', 'PrevClose-L', 'roc3', 'H-L', 'TR', 'volume_sum15', 'return_vol_5D_diff', 'price_3Ddiff', 'roc_15MA', 'macd_15MA_diff', 'rsi_15MA', 'SPY_5d_diff', 'return_vol_8H_diff', 'High-Close', 'DMminus', 'hour', 'return_vol_10D_diff', 'H-PrevClose', 'DMplus', 'DX', 'SPY_range_vol', 'Low-Close', 'price_5Ddiff', 'volume_sum15_10DMA_diff', 'rsi', 'cmf_15MA_diff', 'return_vol_5D', 'price_10Ddiff', 'day_of_week', 'High-Low', 'roc_15MA_diff', 'cmf', 'volume_sum15_5DMA_diff', 'SPY_20d', 'macd_15MA', 'day_of_month', 'adx', 'price_range_8MA_diff', 'cd_vol3', 'DIplus', 'return_vol_8H', 'price_20Ddiff', 'cmf_15MA', 'price_3D20D_diff', 'SPY_5d', 'SPY_20d_diff', 'rsi_15MA_diff', 'macd', 'roc5', 'DIminus']

# testing_features = ['bb_spread','bb_trend','macd','return_vol_8H', 'SPY_diff5', 'volume_vol_8H', 'return_vol_10D', 'range_vol_diff5', 'min_vol_diff_pct', 'range_vol10MA', 
#             'vol7', 'daily_volume_vol_diff30', 'day_of_week', 'SPY_1D', 'oneD_returns_close', 'daily_vol_diff', 'roc_diff', 'volume_vol_5D',
#             'rsi', 'volume_vol_15M', 'threeD_stddev50', 'range_vol25MA', 'month','cd_vol','cd_vol3']

target_label = 'three_min_vol'
target_percentile = 0.45
results_array = []

i = 0
while i < number_of_simulations:
       model_name = f"{title}_temporal_simulation_{i}"
       print(model_name)
       random_int = random.randint(36, 48)
       features = random.sample(testing_features, random_int)
       print(features)
       tp_avg_list, gross_accuracy_list = run_temporal_simulation(features, target_label, target_percentile, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2020,1,6), evaluation_end_date=datetime(2024,4,6),strategy=title)        
       tp_avg = sum(tp_avg_list)/len(tp_avg_list)
       gross_accuracy = sum(gross_accuracy_list)/len(gross_accuracy_list)
       print(tp_avg, gross_accuracy)
       print()
       results_array.append({"model_name": model_name, "features": features, "tp_avg": tp_avg, "gross_accuracy": gross_accuracy,"num_features": random_int,"median_tp": np.median(tp_avg_list), "median_gross_accuracy": np.median(gross_accuracy_list)})
       i += 1

results_df = pd.DataFrame(results_array)
results_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
# Out:
# CDBFP_temporal_simulation_0
# ['price_range_8MA_diff', 'macd', 'price_change_D', 'cd_vol3', 'SPY_range_vol', 'adx', 'High-Low', 'price_3D20D_diff', 'H-L', 'volume_sum15_5DMA_diff', 'rsi', 'SPY_5d_diff', 'price_range', 'DMplus', 'price_3Ddiff', 'roc3', 'Low-Close', 'SPY_5d', 'hour', 'SPY_20d_diff', 'TR', 'volume_sum15_10DMA_diff', 'DIplus', 'cmf', 'PrevClose-L', 'cmf_15MA', 'roc_15MA', 'return_vol_8H', 'macd_15MA', 'roc_15MA_diff', 'month', 'cd_vol', 'price_5Ddiff', 'cmf_15MA_diff', 'roc5', 'H-PrevClose']
# 46.03603603603604 -1.4414414414414414
#
# CDBFP_temporal_simulation_1
# ['bb_category', 'macd_15MA', 'price_change_H', 'day_of_week', 'DMplus', 'bb_spread', 'PrevClose-L', 'price_change_D', 'High-Low', 'SPY_range_vol', 'SPY_20d', 'return_vol_10D_diff', 'price_3D20D_diff', 'DIminus', 'High-Close', 'price_20Ddiff', 'TR', 'H-PrevClose', 'price_range', 'roc', 'price_5Ddiff', 'cd_vol3', 'roc5', 'return_vol_8H', 'Low-Close', 'SPY_5d', 'roc_15MA_diff', 'macd_15MA_diff', 'return_vol_5D', 'DX', 'DIplus', 'macd', 'H-L', 'cd_vol', 'roc3', 'cmf_15MA', 'volume_sum15', 'SPY_20d_diff', 'volume_sum15_10DMA_diff', 'rsi_15MA_diff', 'roc_15MA', 'adx', 'hour', 'rsi', 'return_vol_8H_diff', 'DMminus', 'price_3Ddiff']
# 49.73873873873874 -0.018018018018018018
#
# CDBFP_temporal_simulation_2
# ['price_range_8MA_diff', 'SPY_20d', 'roc5', 'High-Low', 'price_range', 'bb_category', 'DMminus', 'price_3D20D_diff', 'roc_15MA_diff', 'volume_15MA_diff', 'SPY_5d_diff', 'rsi_15MA_diff', 'macd_15MA', 'price_10Ddiff', 'return_vol_10D', 'month', 'price_20Ddiff', 'return_vol_8H', 'rsi_15MA', 'cmf_15MA_diff', 'DMplus', 'cmf', 'adx', 'SPY_20d_diff', 'Low-Close', 'roc_15MA', 'volume_sum15_10DMA_diff', 'hour', 'H-L', 'DIminus', 'volume_sum15_5DMA_diff', 'TR', 'price_range_5DMA_diff', 'roc', 'return_vol_10D_diff', 'DX', 'SPY_range_vol', 'return_vol_5D_diff', 'cd_vol3', 'DIplus', 'macd', 'cmf_15MA', 'price_change_D']
# 45.585585585585584 -1.990990990990991
#
# CDBFP_temporal_simulation_3
# ['day_of_month', 'price_range_8MA_diff', 'Low-Close', 'High-Close', 'hour', 'price_3Ddiff', 'volume_15MA_diff', 'bb_category', 'volume_sum15', 'price_5Ddiff', 'roc', 'price_3D20D_diff', 'roc_15MA_diff', 'PrevClose-L', 'return_vol_10D_diff', 'rsi_15MA_diff', 'cmf_15MA', 'cmf', 'H-PrevClose', 'DIplus', 'return_vol_5D', 'TR', 'roc5', 'return_vol_10D', 'return_vol_5D_diff', 'price_range', 'price_10Ddiff', 'price_20Ddiff', 'adx', 'SPY_5d', 'bb_spread', 'DMplus', 'macd_15MA_diff', 'rsi_15MA', 'day_of_week', 'cd_vol3', 'roc3', 'macd']
# 49.729729729729726 0.6216216216216216
#
# CDBFP_temporal_simulation_4
# ['price_3Ddiff', 'roc', 'volume_15MA_diff', 'rsi_15MA_diff', 'DX', 'volume_sum15_5DMA_diff', 'SPY_range_vol', 'price_range', 'bb_spread', 'volume_sum15_10DMA_diff', 'price_range_5DMA_diff', 'macd_15MA_diff', 'SPY_20d_diff', 'cmf_15MA', 'SPY_20d', 'TR', 'price_5Ddiff', 'day_of_month', 'volume_sum15', 'SPY_5d_diff', 'month', 'cmf_15MA_diff', 'H-PrevClose', 'return_vol_8H', 'price_range_8MA_diff', 'macd_15MA', 'DMplus', 'adx', 'roc3', 'bb_category', 'price_20Ddiff', 'DIminus', 'return_vol_10D_diff', 'price_change_D', 'hour', 'DMminus', 'price_3D20D_diff', 'price_change_H', 'return_vol_8H_diff', 'price_10Ddiff', 'H-L', 'return_vol_5D_diff', 'macd', 'day_of_week', 'High-Low']
# 44.171171171171174 -4.662162162162162
#
# CDBFP_temporal_simulation_5
# ['SPY_20d_diff', 'macd', 'bb_trend', 'month', 'price_3D20D_diff', 'day_of_week', 'rsi_15MA', 'TR', 'cd_vol3', 'roc3', 'volume_sum15_10DMA_diff', 'hour', 'H-PrevClose', 'rsi_15MA_diff', 'price_5Ddiff', 'price_10Ddiff', 'SPY_5d_diff', 'macd_15MA_diff', 'cmf', 'cmf_15MA_diff', 'DMplus', 'bb_category', 'cmf_15MA', 'adx', 'return_vol_8H', 'cd_vol', 'H-L', 'macd_15MA', 'SPY_5d', 'price_change_D', 'DX', 'roc_15MA_diff', 'return_vol_5D', 'return_vol_5D_diff', 'High-Close', 'price_20Ddiff', 'SPY_20d', 'volume_sum15', 'PrevClose-L', 'price_range', 'SPY_range_vol', 'volume_sum15_5DMA_diff']
# 46.734234234234236 -1.8558558558558558
#
# CDBFP_temporal_simulation_6
# ['macd', 'H-PrevClose', 'DMplus', 'DMminus', 'High-Close', 'High-Low', 'SPY_20d', 'roc5', 'cmf', 'price_3D20D_diff', 'SPY_5d_diff', 'price_change_H', 'roc_15MA_diff', 'price_change_D', 'cmf_15MA_diff', 'day_of_week', 'price_range', 'price_5Ddiff', 'rsi', 'price_10Ddiff', 'DX', 'volume_sum15_10DMA_diff', 'DIplus', 'DIminus', 'volume_15MA_diff', 'SPY_5d', 'day_of_month', 'SPY_20d_diff', 'price_3Ddiff', 'cmf_15MA', 'return_vol_10D', 'return_vol_5D', 'bb_spread', 'roc3', 'bb_category', 'Low-Close', 'volume_sum15']
# 51.78378378378378 0.17567567567567569
#
# CDBFP_temporal_simulation_7
# ['bb_category', 'price_range', 'DMplus', 'DIplus', 'macd_15MA_diff', 'return_vol_10D', 'rsi', 'return_vol_5D_diff', 'SPY_20d_diff', 'cd_vol', 'roc3', 'price_change_D', 'Low-Close', 'day_of_week', 'High-Low', 'volume_sum15_10DMA_diff', 'roc', 'price_change_H', 'roc_15MA_diff', 'volume_sum15_5DMA_diff', 'PrevClose-L', 'return_vol_8H', 'macd', 'price_range_5DMA_diff', 'rsi_15MA_diff', 'H-L', 'cmf_15MA_diff', 'DMminus', 'roc_15MA', 'adx', 'cmf', 'rsi_15MA', 'SPY_range_vol', 'SPY_5d', 'High-Close', 'TR']
# 51.52252252252252 2.1126126126126126
#
# CDBFP_temporal_simulation_8
# ['bb_trend', 'roc3', 'TR', 'H-L', 'SPY_20d_diff', 'hour', 'roc', 'SPY_5d', 'SPY_20d', 'volume_sum15_10DMA_diff', 'PrevClose-L', 'price_range_8MA_diff', 'macd', 'roc5', 'Low-Close', 'rsi_15MA', 'adx', 'price_5Ddiff', 'bb_category', 'price_range_5DMA_diff', 'bb_spread', 'cmf_15MA_diff', 'SPY_5d_diff', 'price_3Ddiff', 'rsi_15MA_diff', 'month', 'DIplus', 'DIminus', 'price_3D20D_diff', 'return_vol_8H', 'macd_15MA_diff', 'price_range', 'cd_vol3', 'High-Close', 'return_vol_8H_diff', 'price_10Ddiff', 'DX', 'roc_15MA_diff', 'return_vol_10D_diff', 'return_vol_5D', 'volume_sum15_5DMA_diff']
# 44.26126126126126 -2.8513513513513513
#
# CDBFP_temporal_simulation_9
# ['return_vol_5D_diff', 'roc3', 'rsi_15MA_diff', 'return_vol_8H', 'price_range', 'roc5', 'price_change_H', 'return_vol_8H_diff', 'High-Close', 'price_20Ddiff', 'hour', 'price_10Ddiff', 'cmf', 'SPY_range_vol', 'return_vol_10D_diff', 'DMminus', 'return_vol_5D', 'adx', 'bb_category', 'cd_vol', 'High-Low', 'PrevClose-L', 'return_vol_10D', 'cd_vol3', 'price_5Ddiff', 'H-L', 'roc', 'volume_sum15_10DMA_diff', 'cmf_15MA_diff', 'price_range_5DMA_diff', 'TR', 'DX', 'rsi', 'roc_15MA_diff', 'bb_spread', 'DIminus', 'DMplus', 'month', 'SPY_20d_diff', 'DIplus', 'Low-Close']
# 44.56306306306306 -0.13513513513513514
#
# CDBFP_temporal_simulation_10
# ['return_vol_5D_diff', 'return_vol_10D', 'price_change_D', 'return_vol_8H_diff', 'DIminus', 'High-Low', 'price_range_8MA_diff', 'SPY_5d_diff', 'roc3', 'rsi', 'return_vol_8H', 'price_3D20D_diff', 'H-L', 'adx', 'cmf_15MA', 'DX', 'PrevClose-L', 'cmf_15MA_diff', 'volume_sum15_10DMA_diff', 'High-Close', 'SPY_5d', 'H-PrevClose', 'bb_category', 'macd_15MA', 'return_vol_5D', 'macd', 'roc_15MA_diff', 'roc', 'volume_sum15_5DMA_diff', 'price_range', 'price_range_5DMA_diff', 'DIplus', 'SPY_20d', 'cmf', 'cd_vol', 'price_10Ddiff', 'rsi_15MA', 'roc_15MA', 'hour', 'macd_15MA_diff', 'volume_15MA_diff', 'SPY_20d_diff', 'DMminus', 'price_20Ddiff', 'TR', 'price_5Ddiff', 'day_of_month']
# 50.265765765765764 -0.3918918918918919
#
# CDBFP_temporal_simulation_11
# ['DMminus', 'macd_15MA_diff', 'High-Low', 'H-L', 'cmf_15MA', 'roc_15MA_diff', 'return_vol_5D_diff', 'SPY_20d', 'SPY_20d_diff', 'price_20Ddiff', 'Low-Close', 'price_range_5DMA_diff', 'DX', 'volume_sum15_5DMA_diff', 'price_5Ddiff', 'return_vol_8H_diff', 'price_10Ddiff', 'rsi_15MA_diff', 'SPY_5d', 'macd_15MA', 'day_of_month', 'return_vol_10D_diff', 'return_vol_5D', 'bb_spread', 'cmf_15MA_diff', 'DIminus', 'return_vol_8H', 'bb_category', 'month', 'price_change_D', 'return_vol_10D', 'DMplus', 'DIplus', 'SPY_range_vol', 'hour', 'volume_sum15']
# 46.8018018018018 -3.027027027027027
#
# CDBFP_temporal_simulation_12
# ['H-PrevClose', 'SPY_5d_diff', 'price_20Ddiff', 'TR', 'month', 'SPY_20d', 'Low-Close', 'High-Close', 'return_vol_8H', 'macd_15MA', 'rsi', 'price_change_H', 'cmf', 'DIminus', 'rsi_15MA', 'roc5', 'return_vol_10D_diff', 'price_change_D', 'return_vol_8H_diff', 'SPY_range_vol', 'DX', 'price_10Ddiff', 'price_range_8MA_diff', 'H-L', 'cmf_15MA', 'macd_15MA_diff', 'bb_spread', 'hour', 'High-Low', 'DMplus', 'roc3', 'volume_15MA_diff', 'DMminus', 'day_of_month', 'return_vol_5D_diff', 'DIplus', 'price_3D20D_diff', 'price_range', 'volume_sum15_10DMA_diff', 'bb_category', 'return_vol_5D', 'macd', 'cd_vol3', 'cd_vol']
# 44.968468468468465 -2.990990990990991
#
# CDBFP_temporal_simulation_13
# ['cmf_15MA_diff', 'cmf_15MA', 'return_vol_5D', 'SPY_20d', 'day_of_week', 'roc_15MA', 'DMminus', 'rsi', 'DX', 'volume_15MA_diff', 'rsi_15MA_diff', 'bb_category', 'day_of_month', 'return_vol_10D_diff', 'price_5Ddiff', 'price_range_8MA_diff', 'rsi_15MA', 'return_vol_5D_diff', 'roc', 'macd_15MA', 'SPY_20d_diff', 'roc3', 'price_3D20D_diff', 'TR', 'price_change_D', 'roc5', 'bb_spread', 'volume_sum15', 'DIminus', 'H-PrevClose', 'price_range_5DMA_diff', 'month', 'return_vol_8H_diff', 'DMplus', 'PrevClose-L', 'price_20Ddiff', 'price_range', 'roc_15MA_diff', 'High-Low', 'cd_vol', 'hour', 'DIplus']
# 45.171171171171174 -3.130630630630631
#
# CDBFP_temporal_simulation_14
# ['return_vol_10D', 'month', 'macd', 'SPY_20d', 'return_vol_10D_diff', 'H-PrevClose', 'price_10Ddiff', 'adx', 'TR', 'Low-Close', 'cmf', 'bb_category', 'price_range', 'cd_vol', 'price_change_H', 'return_vol_5D', 'H-L', 'DMminus', 'High-Close', 'bb_spread', 'macd_15MA', 'volume_sum15', 'SPY_5d', 'DIminus', 'price_range_5DMA_diff', 'SPY_5d_diff', 'DX', 'roc_15MA_diff', 'day_of_week', 'price_3D20D_diff', 'price_change_D', 'cd_vol3', 'volume_sum15_5DMA_diff', 'volume_15MA_diff', 'price_range_8MA_diff', 'roc3', 'rsi_15MA', 'rsi', 'SPY_range_vol', 'roc_15MA', 'PrevClose-L']
# 47.734234234234236 0.43243243243243246
#
# CDBFP_temporal_simulation_15
# ['price_range_8MA_diff', 'SPY_range_vol', 'cmf_15MA_diff', 'macd_15MA_diff', 'cmf', 'hour', 'bb_trend', 'price_change_H', 'roc', 'cd_vol3', 'macd', 'rsi', 'return_vol_10D', 'price_3Ddiff', 'price_20Ddiff', 'H-L', 'PrevClose-L', 'adx', 'price_3D20D_diff', 'return_vol_5D', 'volume_15MA_diff', 'SPY_20d', 'DIplus', 'DIminus', 'DMminus', 'day_of_week', 'return_vol_8H', 'Low-Close', 'DMplus', 'bb_spread', 'price_5Ddiff', 'price_10Ddiff', 'volume_sum15_10DMA_diff', 'cd_vol', 'roc_15MA_diff', 'SPY_20d_diff', 'return_vol_5D_diff', 'roc3', 'DX', 'volume_sum15', 'volume_sum15_5DMA_diff', 'day_of_month', 'High-Low', 'rsi_15MA_diff', 'TR', 'rsi_15MA']
# 48.810810810810814 -0.9099099099099099
#
# CDBFP_temporal_simulation_16
# ['SPY_5d', 'roc3', 'bb_trend', 'rsi', 'price_3Ddiff', 'roc_15MA_diff', 'SPY_range_vol', 'High-Low', 'macd', 'price_10Ddiff', 'roc5', 'price_change_H', 'cmf_15MA_diff', 'day_of_month', 'return_vol_5D', 'PrevClose-L', 'DIplus', 'return_vol_5D_diff', 'return_vol_10D_diff', 'month', 'price_range_5DMA_diff', 'return_vol_8H', 'DMminus', 'price_range_8MA_diff', 'roc_15MA', 'bb_category', 'DX', 'bb_spread', 'macd_15MA_diff', 'price_range', 'adx', 'volume_sum15_10DMA_diff', 'return_vol_10D', 'roc', 'volume_sum15', 'price_change_D', 'price_20Ddiff', 'day_of_week', 'H-L', 'cmf', 'SPY_5d_diff', 'DMplus']
# 49.54054054054054 0.9774774774774775
#
# CDBFP_temporal_simulation_17
# ['rsi', 'DIminus', 'cmf_15MA', 'cd_vol', 'roc5', 'price_range', 'return_vol_10D', 'roc', 'rsi_15MA', 'price_10Ddiff', 'volume_sum15_10DMA_diff', 'High-Low', 'DX', 'macd', 'SPY_20d', 'roc_15MA_diff', 'High-Close', 'price_3D20D_diff', 'Low-Close', 'day_of_month', 'price_range_8MA_diff', 'return_vol_8H_diff', 'cmf_15MA_diff', 'macd_15MA', 'price_5Ddiff', 'return_vol_5D_diff', 'price_change_D', 'roc_15MA', 'adx', 'cd_vol3', 'day_of_week', 'return_vol_10D_diff', 'rsi_15MA_diff', 'roc3', 'SPY_5d_diff', 'volume_sum15', 'return_vol_8H', 'bb_trend', 'H-L', 'hour', 'month', 'SPY_5d']
# 46.06306306306306 -3.184684684684685
#
# CDBFP_temporal_simulation_18
# ['PrevClose-L', 'volume_15MA_diff', 'price_range_8MA_diff', 'adx', 'cmf', 'day_of_week', 'hour', 'price_20Ddiff', 'SPY_5d_diff', 'DIplus', 'price_3D20D_diff', 'rsi', 'roc5', 'macd_15MA_diff', 'return_vol_10D_diff', 'DX', 'return_vol_8H', 'price_range', 'month', 'return_vol_5D_diff', 'DMplus', 'price_5Ddiff', 'volume_sum15_5DMA_diff', 'H-L', 'cmf_15MA', 'cd_vol', 'roc_15MA', 'return_vol_8H_diff', 'bb_trend', 'volume_sum15', 'DIminus', 'High-Low', 'bb_category', 'cd_vol3', 'SPY_20d', 'roc', 'cmf_15MA_diff', 'SPY_20d_diff', 'price_10Ddiff', 'day_of_month', 'price_range_5DMA_diff', 'volume_sum15_10DMA_diff']
# 43.409909909909906 -4.400900900900901
#
# CDBFP_temporal_simulation_19
# ['SPY_20d_diff', 'volume_15MA_diff', 'day_of_week', 'rsi_15MA_diff', 'High-Close', 'price_range_5DMA_diff', 'DMplus', 'cd_vol3', 'price_change_H', 'hour', 'DIminus', 'macd_15MA', 'cmf_15MA_diff', 'SPY_5d_diff', 'month', 'price_20Ddiff', 'day_of_month', 'return_vol_10D', 'bb_spread', 'return_vol_8H', 'PrevClose-L', 'DIplus', 'return_vol_8H_diff', 'price_3D20D_diff', 'H-PrevClose', 'TR', 'price_range', 'volume_sum15', 'macd_15MA_diff', 'volume_sum15_5DMA_diff', 'roc', 'bb_trend', 'SPY_5d', 'roc_15MA', 'volume_sum15_10DMA_diff', 'roc5', 'price_change_D', 'return_vol_5D', 'bb_category', 'rsi_15MA', 'return_vol_10D_diff', 'High-Low', 'roc_15MA_diff', 'macd', 'DX', 'adx', 'DMminus']
# 47.833333333333336 0.17117117117117117
#
# CDBFP_temporal_simulation_20
# ['roc3', 'cmf_15MA_diff', 'rsi_15MA_diff', 'price_range', 'macd_15MA', 'return_vol_5D', 'volume_sum15_5DMA_diff', 'High-Low', 'High-Close', 'SPY_5d_diff', 'day_of_week', 'rsi', 'SPY_20d_diff', 'DIminus', 'cd_vol3', 'price_3D20D_diff', 'DIplus', 'DMminus', 'return_vol_8H', 'cmf', 'bb_trend', 'price_change_D', 'volume_15MA_diff', 'hour', 'return_vol_10D', 'day_of_month', 'price_change_H', 'return_vol_8H_diff', 'adx', 'cmf_15MA', 'macd', 'price_3Ddiff', 'rsi_15MA', 'roc_15MA', 'Low-Close', 'H-L']
# 48.88288288288288 -0.481981981981982
#
# CDBFP_temporal_simulation_21
# ['cmf_15MA', 'return_vol_5D_diff', 'return_vol_8H_diff', 'macd', 'rsi', 'adx', 'price_5Ddiff', 'cmf', 'roc5', 'SPY_5d_diff', 'return_vol_5D', 'DX', 'day_of_month', 'SPY_20d_diff', 'H-L', 'bb_spread', 'roc_15MA_diff', 'TR', 'SPY_20d', 'roc', 'price_3Ddiff', 'hour', 'H-PrevClose', 'bb_category', 'price_change_H', 'PrevClose-L', 'DMminus', 'bb_trend', 'macd_15MA', 'Low-Close', 'month', 'rsi_15MA_diff', 'price_10Ddiff', 'volume_sum15', 'macd_15MA_diff', 'cd_vol', 'return_vol_10D_diff']
# 45.43693693693694 -5.2657657657657655
#
# CDBFP_temporal_simulation_22
# ['DMplus', 'hour', 'SPY_range_vol', 'roc5', 'rsi', 'H-L', 'volume_sum15_10DMA_diff', 'month', 'price_range_8MA_diff', 'macd_15MA', 'PrevClose-L', 'DX', 'day_of_month', 'roc', 'rsi_15MA_diff', 'price_20Ddiff', 'cmf', 'roc_15MA_diff', 'volume_15MA_diff', 'bb_spread', 'rsi_15MA', 'SPY_20d', 'DMminus', 'cmf_15MA_diff', 'price_3Ddiff', 'price_change_H', 'price_5Ddiff', 'price_10Ddiff', 'DIplus', 'volume_sum15', 'return_vol_10D', 'High-Low', 'return_vol_8H_diff', 'SPY_20d_diff', 'cmf_15MA', 'Low-Close', 'return_vol_10D_diff', 'price_range_5DMA_diff', 'return_vol_5D', 'return_vol_8H', 'cd_vol', 'price_range', 'price_3D20D_diff', 'SPY_5d_diff']
# 45.554054054054056 -2.536036036036036
#
# CDBFP_temporal_simulation_23
# ['volume_sum15', 'return_vol_10D', 'price_20Ddiff', 'price_10Ddiff', 'roc_15MA', 'price_3Ddiff', 'DMminus', 'TR', 'price_range_5DMA_diff', 'SPY_5d', 'volume_sum15_10DMA_diff', 'cmf_15MA', 'cmf', 'cmf_15MA_diff', 'price_3D20D_diff', 'price_range_8MA_diff', 'return_vol_10D_diff', 'rsi_15MA', 'price_change_H', 'rsi_15MA_diff', 'High-Close', 'adx', 'return_vol_5D', 'price_5Ddiff', 'day_of_week', 'price_range', 'cd_vol', 'SPY_20d', 'bb_category', 'return_vol_8H', 'macd_15MA_diff', 'roc_15MA_diff', 'roc', 'volume_15MA_diff', 'bb_spread', 'price_change_D']
# 51.27477477477478 4.031531531531532
#
# CDBFP_temporal_simulation_24
# ['return_vol_10D_diff', 'bb_category', 'return_vol_8H_diff', 'roc3', 'volume_sum15', 'SPY_5d_diff', 'return_vol_5D_diff', 'price_3Ddiff', 'rsi_15MA', 'macd_15MA', 'roc5', 'High-Low', 'roc_15MA_diff', 'High-Close', 'roc', 'price_range_8MA_diff', 'roc_15MA', 'day_of_month', 'volume_sum15_5DMA_diff', 'PrevClose-L', 'cmf_15MA_diff', 'macd', 'volume_sum15_10DMA_diff', 'price_range', 'return_vol_10D', 'macd_15MA_diff', 'rsi', 'bb_trend', 'H-L', 'DIplus', 'return_vol_8H', 'price_5Ddiff', 'volume_15MA_diff', 'hour', 'price_3D20D_diff', 'rsi_15MA_diff']
# 49.7027027027027 -0.2972972972972973
#
# CDBFP_temporal_simulation_25
# ['month', 'High-Close', 'price_20Ddiff', 'H-PrevClose', 'DIplus', 'rsi', 'DIminus', 'price_range_5DMA_diff', 'cd_vol', 'volume_sum15_10DMA_diff', 'price_range_8MA_diff', 'roc5', 'rsi_15MA_diff', 'rsi_15MA', 'Low-Close', 'volume_15MA_diff', 'price_3Ddiff', 'macd_15MA', 'volume_sum15_5DMA_diff', 'bb_category', 'price_range', 'macd', 'DMminus', 'return_vol_10D', 'SPY_range_vol', 'PrevClose-L', 'roc_15MA', 'H-L', 'DX', 'cmf', 'price_3D20D_diff', 'day_of_week', 'SPY_5d', 'price_change_H', 'hour', 'price_change_D', 'return_vol_8H_diff', 'cmf_15MA', 'bb_trend', 'bb_spread', 'price_5Ddiff']
# 48.01801801801802 -0.009009009009009009
#
# CDBFP_temporal_simulation_26
# ['rsi_15MA', 'rsi_15MA_diff', 'roc3', 'return_vol_5D_diff', 'return_vol_10D_diff', 'cd_vol3', 'SPY_20d', 'adx', 'price_10Ddiff', 'volume_sum15_5DMA_diff', 'price_change_H', 'roc5', 'bb_spread', 'SPY_5d', 'TR', 'DIplus', 'hour', 'SPY_range_vol', 'Low-Close', 'cmf', 'macd', 'DX', 'return_vol_8H_diff', 'volume_sum15_10DMA_diff', 'volume_sum15', 'High-Low', 'cmf_15MA', 'return_vol_10D', 'return_vol_8H', 'price_3D20D_diff', 'price_5Ddiff', 'bb_category', 'macd_15MA_diff', 'cd_vol', 'price_3Ddiff', 'roc_15MA_diff', 'month', 'SPY_20d_diff', 'DIminus', 'price_change_D']
# 44.96396396396396 -3.0720720720720722
#
# CDBFP_temporal_simulation_27
# ['SPY_range_vol', 'price_range', 'price_3Ddiff', 'volume_sum15_10DMA_diff', 'DIminus', 'price_5Ddiff', 'roc5', 'price_change_D', 'H-L', 'High-Close', 'TR', 'price_range_8MA_diff', 'volume_15MA_diff', 'adx', 'return_vol_8H_diff', 'cd_vol3', 'bb_spread', 'High-Low', 'DMplus', 'SPY_5d', 'return_vol_8H', 'SPY_5d_diff', 'DX', 'bb_category', 'cmf_15MA_diff', 'return_vol_5D_diff', 'day_of_week', 'rsi', 'price_3D20D_diff', 'SPY_20d_diff', 'rsi_15MA', 'SPY_20d', 'cmf', 'volume_sum15_5DMA_diff', 'price_range_5DMA_diff', 'price_change_H', 'DIplus', 'cmf_15MA', 'price_20Ddiff', 'roc3', 'macd_15MA_diff', 'roc_15MA', 'H-PrevClose']
# 48.770270270270274 1.0765765765765767
#
# CDBFP_temporal_simulation_28
# ['volume_sum15_5DMA_diff', 'macd', 'price_range', 'volume_sum15_10DMA_diff', 'DMplus', 'return_vol_10D', 'SPY_5d', 'month', 'High-Close', 'Low-Close', 'rsi', 'High-Low', 'price_change_D', 'price_5Ddiff', 'DX', 'price_3D20D_diff', 'roc5', 'roc', 'macd_15MA_diff', 'price_3Ddiff', 'roc_15MA', 'volume_sum15', 'roc_15MA_diff', 'cmf_15MA_diff', 'macd_15MA', 'cmf_15MA', 'price_change_H', 'return_vol_8H', 'return_vol_10D_diff', 'DMminus', 'volume_15MA_diff', 'cd_vol', 'cmf', 'SPY_20d_diff', 'DIplus', 'price_10Ddiff', 'SPY_range_vol', 'bb_category']
# 47.4054054054054 -2.099099099099099
#
# CDBFP_temporal_simulation_29
# ['Low-Close', 'roc_15MA', 'DMminus', 'cmf_15MA_diff', 'SPY_range_vol', 'return_vol_10D_diff', 'DX', 'volume_sum15_5DMA_diff', 'macd_15MA', 'rsi_15MA', 'SPY_5d_diff', 'bb_spread', 'H-PrevClose', 'price_3D20D_diff', 'cmf', 'day_of_week', 'price_range_8MA_diff', 'volume_15MA_diff', 'bb_trend', 'price_20Ddiff', 'price_change_D', 'adx', 'roc_15MA_diff', 'volume_sum15', 'H-L', 'rsi', 'volume_sum15_10DMA_diff', 'cd_vol', 'DIminus', 'SPY_5d', 'cmf_15MA', 'TR', 'price_10Ddiff', 'roc', 'roc5', 'return_vol_8H_diff', 'PrevClose-L', 'High-Close', 'SPY_20d', 'SPY_20d_diff', 'return_vol_5D', 'DMplus']
# 51.3963963963964 -0.35135135135135137
#
# CDBFP_temporal_simulation_30
# ['DIminus', 'day_of_week', 'SPY_range_vol', 'price_5Ddiff', 'macd_15MA', 'volume_sum15', 'return_vol_10D', 'hour', 'bb_trend', 'return_vol_5D_diff', 'H-PrevClose', 'price_range_8MA_diff', 'SPY_5d_diff', 'H-L', 'DMminus', 'TR', 'return_vol_5D', 'roc_15MA_diff', 'SPY_20d', 'macd', 'rsi', 'price_range_5DMA_diff', 'High-Close', 'month', 'cmf_15MA_diff', 'price_change_D', 'cmf_15MA', 'bb_category', 'day_of_month', 'price_range', 'roc', 'volume_15MA_diff', 'rsi_15MA', 'adx', 'Low-Close', 'price_20Ddiff', 'cd_vol3', 'return_vol_10D_diff', 'DX', 'roc3', 'roc_15MA', 'volume_sum15_5DMA_diff', 'cd_vol', 'macd_15MA_diff']
# 44.792792792792795 -3.873873873873874
#
# CDBFP_temporal_simulation_31
# ['price_change_H', 'rsi_15MA', 'DX', 'rsi', 'day_of_month', 'cd_vol3', 'volume_sum15_5DMA_diff', 'H-PrevClose', 'SPY_5d_diff', 'macd', 'SPY_range_vol', 'return_vol_10D', 'price_5Ddiff', 'SPY_20d', 'Low-Close', 'return_vol_10D_diff', 'TR', 'return_vol_5D', 'return_vol_8H_diff', 'DMminus', 'hour', 'cmf_15MA_diff', 'cmf_15MA', 'SPY_5d', 'High-Low', 'macd_15MA_diff', 'cmf', 'return_vol_8H', 'return_vol_5D_diff', 'day_of_week', 'roc3', 'High-Close', 'price_3D20D_diff', 'volume_15MA_diff', 'volume_sum15_10DMA_diff', 'SPY_20d_diff', 'adx', 'macd_15MA', 'PrevClose-L', 'month', 'price_range_5DMA_diff', 'roc_15MA', 'volume_sum15', 'bb_trend']
# 48.693693693693696 -3.369369369369369
#
# CDBFP_temporal_simulation_32
# ['price_range_8MA_diff', 'price_10Ddiff', 'rsi', 'return_vol_10D', 'macd', 'cd_vol', 'Low-Close', 'roc_15MA', 'macd_15MA_diff', 'High-Low', 'cmf', 'volume_sum15_10DMA_diff', 'adx', 'price_change_D', 'SPY_20d_diff', 'return_vol_8H', 'cmf_15MA_diff', 'price_range', 'DMminus', 'bb_trend', 'hour', 'bb_category', 'SPY_range_vol', 'DIminus', 'return_vol_8H_diff', 'price_3D20D_diff', 'bb_spread', 'cmf_15MA', 'roc', 'return_vol_5D_diff', 'rsi_15MA', 'DIplus', 'H-L', 'rsi_15MA_diff', 'roc3', 'return_vol_5D', 'price_3Ddiff', 'roc_15MA_diff', 'month']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 40
#      38 features = random.sample(testing_features, random_int)
#      39 print(features)
# ---> 40 tp_avg_list, gross_accuracy_list = run_temporal_simulation(features, target_label, target_percentile, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2020,1,6), evaluation_end_date=datetime(2024,4,6),strategy=title)
#      41 tp_avg = sum(tp_avg_list)/len(tp_avg_list)
#      42 gross_accuracy = sum(gross_accuracy_list)/len(gross_accuracy_list)
#
# Cell In[27], line 12, in run_temporal_simulation(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date, strategy)
#       9 # date = dates_list[-1]
#      10 # response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
#      11 for date in dates_list:
# ---> 12     tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams,strategy)
#      13     tp_avg_list.append(tp)
#      14     gross_accuracy_list.append((tp-fp))
#
# Cell In[22], line 48, in model_runner_temporal_simulation(features, target_label, target_percentile, dataset_start_date, end_date, deployment_date, hyperparams, strategy)
#      39 # print(len(dataset))
#      40 # print(len(validation_dataset))
#      41 # dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
#    (...)
#      45 # print(len(dataset))
#      46 # print(len(validation_dataset))
#      47 target_value = dataset[target_label].quantile(target_percentile).round(3)
# ---> 48 tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams)
#      49 return tp, fp, fn, tn
#
# Cell In[21], line 53, in train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams)
#      49 y_validate = validation_dataset['label']
#      52 xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
# ---> 53 xgb_model.fit(X,y)
#      55 predictions = xgb_model.predict(X_validate)
#      56 tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/xgboost/sklearn.py:1515, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1487 (
#    1488     model,
#    1489     metric,
#    (...)
#    1494     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1495 )
#    1496 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1497     missing=self.missing,
#    1498     X=X,
#    (...)
#    1512     feature_types=self.feature_types,
#    1513 )
# -> 1515 self._Booster = train(
#    1516     params,
#    1517     train_dmatrix,
#    1518     self.get_num_boosting_rounds(),
#    1519     evals=evals,
#    1520     early_stopping_rounds=early_stopping_rounds,
#    1521     evals_result=evals_result,
#    1522     obj=obj,
#    1523     custom_metric=metric,
#    1524     verbose_eval=verbose,
#    1525     xgb_model=model,
#    1526     callbacks=callbacks,
#    1527 )
#    1529 if not callable(self.objective):
#    1530     self.objective = params["objective"]
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/xgboost/core.py:2050, in Booster.update(self, dtrain, iteration, fobj)
#    2046 self._assign_dmatrix_features(dtrain)
#    2048 if fobj is None:
#    2049     _check_call(
# -> 2050         _LIB.XGBoosterUpdateOneIter(
#    2051             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2052         )
#    2053     )
#    2054 else:
#    2055     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
