# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler
import pytz
import warnings
warnings.filterwarnings('ignore')

# %%
s3 = boto3.client('s3')
STRATEGY = 'BFC_1D'
training_bucket = "icarus-research-data"
training_prefix = 'training_datasets/expanded_1d_datasets/'

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

index = ["QQQ","SPY","IWM","TLT"]
test_lag = ["DAL","UAL","VZ","T","AAL","AMC"]
train_lag = ["AMC"]

# big_fish =  [
#             "AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","PLTR","BAC","AAPL","NFLX","ABNB","CRWD","SHOP","FB","CRM",
#             "MSFT","F","V","MA","JNJ","DIS","JPM","INTC","ADBE","BA","CVX","MRNA","PFE","SNOW","SOFI",'META',
#             ]

# bf_plus = ["AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","PLTR","BAC","AAPL","NFLX","ABNB","CRWD","SHOP","FB","CRM",
#             "MSFT","F","V","MA","JNJ","DIS","JPM","INTC","ADBE","BA","CVX","MRNA","PFE","SNOW","NKE",'META',
#             'C','TGT','MMM','SQ','PANW','DAL','CSCO','UBER','SBUX']


all_symbols = ['ZM', 'UBER', 'CMG', 'AXP', 'TDOC', 'UAL', 'DAL', 'MMM', 'PEP', 'GE', 'RCL', 'MRK',
 'HD', 'LOW', 'VZ', 'PG', 'TSM', 'GOOG', 'GOOGL', 'AMZN', 'BAC', 'AAPL', 'ABNB',
 'CRM', 'MSFT', 'F', 'V', 'MA', 'JNJ', 'DIS', 'JPM', 'ADBE', 'BA', 'CVX', 'PFE',
 'META', 'C', 'CAT', 'KO', 'MS', 'GS', 'IBM', 'CSCO','TSLA','LCID','NIO','WFC',
 'TGT', 'COST', 'RIVN', 'COIN', 'SQ', 'SHOP', 'DOCU', 'ROKU', 'TWLO', 'DDOG', 'ZS', 'NET',
 'OKTA', 'UPST', 'ETSY', 'PINS', 'FUTU', 'SE', 'BIDU', 'JD', 'BABA', 'RBLX', 'AMD',
 'NVDA', 'PYPL', 'PLTR', 'NFLX', 'CRWD', 'INTC', 'MRNA', 'SNOW', 'SOFI', 'PANW',
 'ORCL','WBD','ARM','SNAP','BILI','AAL','CCL','NCLH','LYFT','BIDU','JD','BABA','HD','LOW',
 'SBUX','NKE','AFFRM','WMT']

high_vol = ['ZM', 'UBER', 'TDOC', 'UAL', 'RCL', 'AMZN', 'ABNB', 'META', 'TSLA',
       'LCID', 'NIO', 'RIVN', 'SQ', 'SHOP', 'DOCU', 'ROKU',
       'TWLO', 'DDOG', 'ZS', 'NET', 'OKTA', 'ETSY', 'PINS',
       'FUTU', 'SE', 'RBLX', 'AMD', 'NVDA', 'PYPL', 'PLTR', 'NFLX',
       'CRWD', 'MRNA', 'SNOW', 'SOFI', 'WBD', 'ARM', 'SNAP', 'BILI',
       'AAL', 'CCL', 'NCLH', 'LYFT', 'BIDU', 'JD', 'BABA', 'MU', 'AMAT',
       'DKNG', 'CZR', 'VXX']

mid_vol =['CMG', 'AXP', 'DAL', 'GE', 'TSM', 'GOOG', 'GOOGL', 'BAC', 'AAPL',
       'CRM', 'MSFT', 'F', 'DIS', 'ADBE', 'BA', 'CVX', 'C', 'CAT', 'MS',
       'WFC', 'TGT', 'INTC', 'PANW', 'ORCL', 'LOW', 'SBUX', 'NKE', 'QCOM',
       'AVGO', 'TXN', 'MGM', 'XOM']

low_vol = ['MMM', 'MRK', 'HD', 'VZ', 'V', 'MA', 'JPM',
       'PFE', 'GS', 'IBM', 'CSCO', 'WMT', 'COST', 'QQQ', 'SPY',
       'TLT', 'IWM']

bfpidx = ["AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","BAC","AAPL","FB","DIS"
          "MSFT","INTC","PFE","SNOW",'META','C','XOM',"QQQ","SPY","IWM","TLT"]


bf2 = ['QQQ','IWM','AAPL','NVDA','AMD','AMZN','SPY','MSFT','GOOG','GOOGL','C','BAC',
      'JPM','XOM','CVX','CSCO','INTC','DIS','IBM','BA', 'V','AXP','PYPL','ADBE','F','GM']

GE = [
    'QQQ','SPY','IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD','SHOP'
    'AXP', 'AAPL', 'BAC', 'BA', 'CVX', 'CSCO', 'C', 'DIS', 'XOM', 
    'GM', 'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA', 'PYPL','PANW','ADBE'
    'TSLA', 'V', 'SQ', 'TSM', 'QCOM', 'UBER', 'SNOW', 'PLTR', 'ABNB',
    "FB",'META',"TGT","NKE","SBUX","ORCL","DDOG","JNJ","AVGO","COST"
    ]
BF3 = ['QQQ', 'SPY', 'IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD', 'AAPL', 'BAC',
       'BA', 'C', 'DIS', 'XOM', 'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA',
       'TSLA', 'V', 'TSM', 'QCOM', 'SNOW', 'TGT', 'NKE', 'SBUX', 'ORCL',
       'PYPL', 'SQ', 'UBER', 'PLTR', 'ABNB','ADBE'
       'META'
       ]
PE = ['SPY', 'TSLA', 'QQQ', 'AMD', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN','TSM','BAC','C','XOM','DIS','SBUX','PYPL','NKE']
PE2 = ['SPY', 'TSLA', 'QQQ', 'AMD', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN','TSM','XOM','DIS','PYPL','BA','NFLX','NVDA','GOOG',
       'META'
       ]
PE3 = ['SPY', 'TSLA', 'QQQ', 'AMD', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN','TSM','XOM','PYPL','BA',
'NFLX','NVDA','GOOG','META','COST','SNOW','CRWD','AVGO','ADBE'
       ]## GOOG,AVGO,COST w/ increased capital

BF3_TRIMMED = [
    'QQQ','SPY','IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD', 
    'AAPL', 'BAC', 'BA', 'C', 'DIS', 'XOM', 
    'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA', 'PYPL',
    'TSLA', 'V', 'SQ', 'TSM', 'QCOM', 'UBER', 'SNOW', 'PLTR', 'ABNB',
    "FB",'META',"TGT","NKE","SBUX","ORCL"
    ]

TOP = [
       'NVDA', 'SPY', 'TSLA', 'QQQ', 'AMD', 'TSM', 'NFLX',
       'AAPL', 'MSFT', 'IWM', 'AMZN','AVGO','META','COST']

# %%
def configure_dates(data,strategy):
    if strategy in ["CDBFC","CDBFP"]:
        data = data.loc[data['day_of_week'].isin([0,1,2])] 
    elif strategy in ["CDBFC_1D","CDBFP_1D"]:
        data = data.loc[data['day_of_week'].isin([0,1,2,3])]
    return data

def pull_training_data_local(end_date,strategy,volatility_measure):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/BF/2015-01-01_2024-06-08GE.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data['one_max_vol'] = (data['one_max']/data[volatility_measure]).round(3)
    data['three_max_vol'] = (data['three_max']/data[volatility_measure]).round(3)
    data['one_min_vol'] = (data['one_min']/data[volatility_measure]).round(3)
    data['three_min_vol'] = (data['three_min']/data[volatility_measure]).round(3)    
    # data['one_max_vol30'] = (data['one_max']/data['return_vol_30D']).round(3)
    # data['three_max_vol30'] = (data['three_max']/data['return_vol_30D']).round(3)
    # data['one_min_vol30'] = (data['one_min']/data['return_vol_30D']).round(3)
    # data['three_min_vol30'] = (data['three_min']/data['return_vol_30D']).round(3)    
    # data['cd_vol'] = (data['close_diff']/data['return_vol_10D']).round(3)
    # data['cd_vol3'] = (data['close_diff3']/data['return_vol_10D']).round(3)
    # data['cd_vol30'] = (data['close_diff']/data['return_vol_30D']).round(3)
    data['cd_vol'] = (data['price_change_D']/data[volatility_measure]).round(3)
    data['cd_vol3'] = (data['price_3Ddiff']/data[volatility_measure]).round(3)
    # data['cd_vol330'] = (data['close_diff3']/data['return_vol_30D']).round(3)
    data = data.loc[data['symbol'].isin(TOP)]
    data = configure_dates(data,strategy)
    data.replace([np.inf, -np.inf], 0, inplace=True)
    return data


def pull_validation_data_local(end_date,start_date,strategy,volatility_measure):
    data = pd.read_csv(f'/Users/charlesmiller/Documents/model_tester_data/BF/2015-01-01_2024-06-08GE.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data['one_max_vol'] = (data['one_max']/data[volatility_measure]).round(3)
    data['three_max_vol'] = (data['three_max']/data[volatility_measure]).round(3)
    data['one_min_vol'] = (data['one_min']/data[volatility_measure]).round(3)
    data['three_min_vol'] = (data['three_min']/data[volatility_measure]).round(3)    
    # data['one_max_vol30'] = (data['one_max']/data['return_vol_30D']).round(3)
    # data['three_max_vol30'] = (data['three_max']/data['return_vol_30D']).round(3)
    # data['one_min_vol30'] = (data['one_min']/data['return_vol_30D']).round(3)
    # data['three_min_vol30'] = (data['three_min']/data['return_vol_30D']).round(3)    
    data['cd_vol'] = (data['price_change_D']/data[volatility_measure]).round(3)
    data['cd_vol3'] = (data['price_3Ddiff']/data[volatility_measure]).round(3)
    # data['cd_vol30'] = (data['close_diff']/data['return_vol_30D']).round(3)
    # data['cd_vol330'] = (data['close_diff3']/data['return_vol_30D']).round(3)
    data = data.loc[data['dt'] <= end_date]
    data = data.loc[data['dt'] >= start_date]
    data = data.loc[data['symbol'].isin(TOP)]
    data = configure_dates(data,strategy)
    # data = data.loc[data['day_of_week'].isin([2,3])]
    data.replace([np.inf, -np.inf], 0, inplace=True)
    return data

# %%
def build_date_list(start_date, end_date):
    print(start_date, end_date)
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_validation_dates_local(deployment_date):
    end_date = deployment_date + timedelta(days=5)
    return end_date

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] < target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] < target_value).astype(int)

    # dataset = dataset.round(3)
    # validation_dataset = validation_dataset.round(3)

    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']


    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    print(y.value_counts())
    predictions = xgb_model.predict(X_validate)
    probabilities = xgb_model.predict_proba(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,str(fi_list), predictions, probabilities


def train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] < target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] < target_value).astype(int)

    dataset = dataset.round(5)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']
    

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,"str(fi_list)", predictions, "probabilities"

# %%
# def model_runner_v2RM(model_name, dataset_name, title, features, target_label, target_percentile, start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
#     validation_end_date = build_validation_dates_local(deployment_date)
#     validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
#     dataset = pull_training_data_local(end_date, dataset_start_date)
#     dates_list = pull_gmm_labels(deployment_date)
#     rm_dataset = dataset.loc[dataset['dt'].isin(dates_list)]
#     target_value = rm_dataset[target_label].quantile(target_percentile).round(3)
#     print(target_value)
#     print(len(rm_dataset)/len(dataset))
#     tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, rm_dataset, validation_dataset, target_label, target_value, hyperparams)
#     response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
#     validation_dataset['probabilities'] = probabilities[:,1]
#     validation_dataset['predictions'] = predictions
#     validation_dataset['target_value'] = target_value
#     validation_dataset['target_pct'] = validation_dataset['target_value'] * validation_dataset['return_vol_10D']
#     validation_csv = validation_dataset.to_csv()
#     put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
#     return response

def model_runner_v2(
    model_name, dataset_name, title, features, target_label, 
    target_percentile, start_date, end_date,deployment_date, feature_str, hyperparams_str, 
    hyperparams,local_data, dataset_start_date,volatility_measure
    ):

    validation_end_date = build_validation_dates_local(deployment_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date, title,volatility_measure)
    dataset = pull_training_data_local(end_date, title,volatility_measure)
    target_value = dataset[target_label].quantile(target_percentile).round(3)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
    validation_dataset['probabilities'] = probabilities[:,1]
    validation_dataset['predictions'] = predictions
    validation_dataset['target_value'] = target_value
    validation_dataset['target_pct'] = validation_dataset['target_value'] * validation_dataset['return_vol_10D']
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    return response

def model_runner_temporal_simulation(features, target_label, target_percentile,dataset_start_date,end_date,deployment_date,hyperparams,strategy):
    validation_end_date = build_validation_dates_local(deployment_date)
    dataset = pull_training_data_local(end_date, strategy)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date, strategy)
    # dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    # validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    # dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    # validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    target_value = dataset[target_label].quantile(target_percentile).round(3)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    return tp, fp, fn, tn 

# def model_runner_data(start_date,end_date):
#     dates = build_date_list(start_date, end_date)
#     key_list = build_query_keys(dates)
#     print(key_list[-1])
#     train_data = create_training_data_local(key_list, 'full_alerts/weekly_exp_alerts/', 'inv-alerts', 'cdvol_gainers', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
#     val_data = create_validation_data_local(key_list, 'full_alerts/trading_symbols_alerts/', 'inv-alerts', 'cdvol_gainers', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
#     return "train_data", "val_data"

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=17),
            "dataset_start": datetime(2018,1,1)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

def pull_gmm_labels(date):
    date_str = date.strftime('%Y-%m-%d')
    data_20d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm20d_labels_RM2/{date_str}.csv')
    data_10d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm10d_labels_RM2/{date_str}.csv')
    data_3d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm3d_labels_RM2/{date_str}.csv')

    data_20d = pd.read_csv(data_20d.get("Body"))
    data_10d = pd.read_csv(data_10d.get("Body"))
    data_3d = pd.read_csv(data_3d.get("Body"))

    data_20d['dt'] = pd.to_datetime(data_20d['date'])
    data_10d['dt'] = pd.to_datetime(data_10d['date'])
    data_3d['dt'] = pd.to_datetime(data_3d['date'])

    label_20d = data_20d['labels'].iloc[-1]
    label_10d = data_10d['labels'].iloc[-1]
    label_3d = data_3d['labels'].iloc[-1]

    dates_20d = data_20d['dt'].loc[data_20d['labels'] == label_20d].tolist()
    dates_10d = data_10d['dt'].loc[data_10d['labels'] == label_10d].tolist()
    dates_3d = data_3d['dt'].loc[data_3d['labels'] == label_3d].tolist()

    # combined_list = list(set(dates_20d  + dates_3d))
    return dates_20d

# %%
target_percentile = 0.45
title = 'CDBFP_1D'
model_name = f'{title}:TSSIM2.4_TOP_HYPOPT2_TP{target_percentile}'
dataset_name = f'TSSIM2.4_TOP_HYPOPT2_TP{target_percentile}'
hyperparams = {'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}
features = ['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']
volatility_measure = 'return_vol_5D'


target_label = 'one_min_vol'


dataset_start_date = datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')) 
dates_list = build_evaluation_period(datetime(2022,1,3), datetime(2024,6,8))
# date = dates_list[-1]
# print(date)
# response = model_runner_data(start_date=datetime(2018,1,1),end_date=datetime(2023,12,23))

# dataset = pull_training_data_local(start_date=datetime(2018,1,1),end_date=datetime(2023,12,23))
# print(dataset.columns.tolist())

for date in dates_list:
    print(date)
    response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile,"dataset_start_date",date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'],volatility_measure=volatility_measure)
# Out:
# {'deployment_date': datetime.datetime(2022, 1, 3, 0, 0), 'dataset_end': datetime.datetime(2021, 12, 17, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    55758
# 1    45528
# Name: count, dtype: int64
# 162 14 17 119
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-01-03', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 162, 'TPpct': Decimal('0'), 'FP': 14, 'FPpct': Decimal('0'), 'TN': 17, 'TNpct': Decimal('0'), 'FN': 119, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('11.571428571428571'), 'evaluation_timeperiod': '2022-01-03_2022-01-07', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.868+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.02409181}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.014564437}, {'close_10DMA_diff': 0.013556806}, {'return_vol_5D': 0.10636974}, {'price_range_H': 0.06905621}, {'price_20Ddiff': 0.019523358}, {'roc_vol5': 0.016697858}, {'DIplus': 0.031391207}, {'macd_15MA': 0.02023682}, {'volume_sum15_10DMA_diff': 0.0}, {'roc_vol_15MA_diff': 0.016444271}, {'range_vol_stddev20D_diff': 0.014053444}, {'volume_15MA_diff': 0.037297744}, {'volume_sum15': 0.010351143}, {'roc_15MA_diff': 0.025860723}, {'price_10Ddiff': 0.01539895}, {'Low-Close': 0.02231727}, {'roc_vol': 0.016546035}, {'SPY_diff_H': 0.0}, {'roc8H': 0.012137075}, {'DIminus': 0.01919581}, {'day_of_month': 0.023938928}, {'ret_vol_stddev20D_diff': 0.058579847}, {'High-Low': 0.018119046}, {'PrevClose-L': 0.02386288}, {'roc8H_15MA_diff': 0.01702357}, {'High-Close': 0.013426888}, {'cmf_15MA_diff': 0.021312194}, {'roc5': 0.031858224}, {'max_30_diff': 0.018641837}, {'close_20DMA_diff': 0.02301756}, {'return_vol_10D_diff': 0.0}, {'roc3': 0.029275836}, {'rsi': 0.014696726}, {'cmf': 0.02392994}, {'day_of_week': 0.02615838}, {'return_vol_8H': 0.04493937}, {'return_vol_8H_diff': 0.01095085}, {'SPY_5d_diff': 0.020853816}, {'H-L': 0.0}, {'bb_spread': 0.037997216}, {'SPY_20d_diff': 0.022627082}, {'price_range_8MA_diff': 0.013699107}]"}
# {'deployment_date': datetime.datetime(2022, 1, 10, 0, 0), 'dataset_end': datetime.datetime(2021, 12, 24, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    55932
# 1    45666
# Name: count, dtype: int64
# 121 53 106 32
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-01-10', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 121, 'TPpct': Decimal('0'), 'FP': 53, 'FPpct': Decimal('0'), 'TN': 106, 'TNpct': Decimal('0'), 'FN': 32, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.2830188679245285'), 'evaluation_timeperiod': '2022-01-10_2022-01-14', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.865+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.023251742}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.012607596}, {'close_10DMA_diff': 0.022418188}, {'return_vol_5D': 0.1069402}, {'price_range_H': 0.06331739}, {'price_20Ddiff': 0.016836943}, {'roc_vol5': 0.018766196}, {'DIplus': 0.023753753}, {'macd_15MA': 0.015051589}, {'volume_sum15_10DMA_diff': 0.009198556}, {'roc_vol_15MA_diff': 0.014145527}, {'range_vol_stddev20D_diff': 0.013776296}, {'volume_15MA_diff': 0.029088818}, {'volume_sum15': 0.01606133}, {'roc_15MA_diff': 0.016091192}, {'price_10Ddiff': 0.012423142}, {'Low-Close': 0.01442471}, {'roc_vol': 0.017557206}, {'SPY_diff_H': 0.0}, {'roc8H': 0.0}, {'DIminus': 0.021983797}, {'day_of_month': 0.027664395}, {'ret_vol_stddev20D_diff': 0.054547112}, {'High-Low': 0.016546825}, {'PrevClose-L': 0.019573946}, {'roc8H_15MA_diff': 0.013901602}, {'High-Close': 0.014127833}, {'cmf_15MA_diff': 0.01981596}, {'roc5': 0.043522056}, {'max_30_diff': 0.023136703}, {'close_20DMA_diff': 0.02301434}, {'return_vol_10D_diff': 0.014554481}, {'roc3': 0.021496408}, {'rsi': 0.02017875}, {'cmf': 0.020445133}, {'day_of_week': 0.023569226}, {'return_vol_8H': 0.04396717}, {'return_vol_8H_diff': 0.018662225}, {'SPY_5d_diff': 0.025898824}, {'H-L': 0.022755817}, {'bb_spread': 0.032118622}, {'SPY_20d_diff': 0.019152641}, {'price_range_8MA_diff': 0.013655755}]"}
# {'deployment_date': datetime.datetime(2022, 1, 17, 0, 0), 'dataset_end': datetime.datetime(2021, 12, 31, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    56085
# 1    45825
# Name: count, dtype: int64
# 52 6 20 156
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-01-17', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 52, 'TPpct': Decimal('0'), 'FP': 6, 'FPpct': Decimal('0'), 'TN': 20, 'TNpct': Decimal('0'), 'FN': 156, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('8.666666666666666'), 'evaluation_timeperiod': '2022-01-17_2022-01-21', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.865+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.026830746}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.007012339}, {'close_10DMA_diff': 0.019049276}, {'return_vol_5D': 0.103902265}, {'price_range_H': 0.059101023}, {'price_20Ddiff': 0.01163051}, {'roc_vol5': 0.0150150005}, {'DIplus': 0.031497777}, {'macd_15MA': 0.017300537}, {'volume_sum15_10DMA_diff': 0.0}, {'roc_vol_15MA_diff': 0.020917384}, {'range_vol_stddev20D_diff': 0.01703253}, {'volume_15MA_diff': 0.03339067}, {'volume_sum15': 0.01756865}, {'roc_15MA_diff': 0.019618668}, {'price_10Ddiff': 0.0}, {'Low-Close': 0.01809745}, {'roc_vol': 0.022058366}, {'SPY_diff_H': 0.0}, {'roc8H': 0.023089444}, {'DIminus': 0.02251747}, {'day_of_month': 0.024232028}, {'ret_vol_stddev20D_diff': 0.08672902}, {'High-Low': 0.017727492}, {'PrevClose-L': 0.025804708}, {'roc8H_15MA_diff': 0.013754451}, {'High-Close': 0.0143216895}, {'cmf_15MA_diff': 0.017511277}, {'roc5': 0.039382577}, {'max_30_diff': 0.01611111}, {'close_20DMA_diff': 0.028239964}, {'return_vol_10D_diff': 0.012029246}, {'roc3': 0.02560992}, {'rsi': 0.01829326}, {'cmf': 0.014277748}, {'day_of_week': 0.024569033}, {'return_vol_8H': 0.04311275}, {'return_vol_8H_diff': 0.0}, {'SPY_5d_diff': 0.01817971}, {'H-L': 0.0}, {'bb_spread': 0.043887936}, {'SPY_20d_diff': 0.016470032}, {'price_range_8MA_diff': 0.014125945}]"}
# {'deployment_date': datetime.datetime(2022, 1, 24, 0, 0), 'dataset_end': datetime.datetime(2022, 1, 7, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    56247
# 1    45975
# Name: count, dtype: int64
# 98 42 75 97
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-01-24', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 98, 'TPpct': Decimal('0'), 'FP': 42, 'FPpct': Decimal('0'), 'TN': 75, 'TNpct': Decimal('0'), 'FN': 97, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.3333333333333335'), 'evaluation_timeperiod': '2022-01-24_2022-01-28', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.868+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.02208842}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.012681889}, {'close_10DMA_diff': 0.017898241}, {'return_vol_5D': 0.1009722}, {'price_range_H': 0.05953791}, {'price_20Ddiff': 0.017661616}, {'roc_vol5': 0.018053433}, {'DIplus': 0.027869087}, {'macd_15MA': 0.018830696}, {'volume_sum15_10DMA_diff': 0.0}, {'roc_vol_15MA_diff': 0.01845178}, {'range_vol_stddev20D_diff': 0.01379175}, {'volume_15MA_diff': 0.04684437}, {'volume_sum15': 0.012345692}, {'roc_15MA_diff': 0.021323228}, {'price_10Ddiff': 0.011187538}, {'Low-Close': 0.018469853}, {'roc_vol': 0.015750691}, {'SPY_diff_H': 0.0}, {'roc8H': 0.010900091}, {'DIminus': 0.020510128}, {'day_of_month': 0.02695402}, {'ret_vol_stddev20D_diff': 0.056818243}, {'High-Low': 0.013757751}, {'PrevClose-L': 0.024956396}, {'roc8H_15MA_diff': 0.016394908}, {'High-Close': 0.013649862}, {'cmf_15MA_diff': 0.020862605}, {'roc5': 0.03674557}, {'max_30_diff': 0.016047081}, {'close_20DMA_diff': 0.032267496}, {'return_vol_10D_diff': 0.0}, {'roc3': 0.031509273}, {'rsi': 0.023236329}, {'cmf': 0.019141588}, {'day_of_week': 0.020023843}, {'return_vol_8H': 0.04175247}, {'return_vol_8H_diff': 0.0}, {'SPY_5d_diff': 0.02763543}, {'H-L': 0.023237163}, {'bb_spread': 0.041613687}, {'SPY_20d_diff': 0.013196001}, {'price_range_8MA_diff': 0.015031661}]"}
# {'deployment_date': datetime.datetime(2022, 1, 31, 0, 0), 'dataset_end': datetime.datetime(2022, 1, 14, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    56406
# 1    46128
# Name: count, dtype: int64
# 13 35 180 84
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-01-31', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 13, 'TPpct': Decimal('0'), 'FP': 35, 'FPpct': Decimal('0'), 'TN': 180, 'TNpct': Decimal('0'), 'FN': 84, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.37142857142857144'), 'evaluation_timeperiod': '2022-01-31_2022-02-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.868+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.02624471}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.021371473}, {'close_10DMA_diff': 0.018922525}, {'return_vol_5D': 0.10012143}, {'price_range_H': 0.05952754}, {'price_20Ddiff': 0.020133123}, {'roc_vol5': 0.012602944}, {'DIplus': 0.026498945}, {'macd_15MA': 0.01816831}, {'volume_sum15_10DMA_diff': 0.0}, {'roc_vol_15MA_diff': 0.019866167}, {'range_vol_stddev20D_diff': 0.013897002}, {'volume_15MA_diff': 0.025097594}, {'volume_sum15': 0.010634349}, {'roc_15MA_diff': 0.017943285}, {'price_10Ddiff': 0.016205357}, {'Low-Close': 0.015910413}, {'roc_vol': 0.015166242}, {'SPY_diff_H': 0.0}, {'roc8H': 0.008134995}, {'DIminus': 0.01944794}, {'day_of_month': 0.024874022}, {'ret_vol_stddev20D_diff': 0.044899255}, {'High-Low': 0.016945133}, {'PrevClose-L': 0.02491025}, {'roc8H_15MA_diff': 0.015047613}, {'High-Close': 0.014386906}, {'cmf_15MA_diff': 0.022083037}, {'roc5': 0.034814008}, {'max_30_diff': 0.02617944}, {'close_20DMA_diff': 0.040844467}, {'return_vol_10D_diff': 0.010658831}, {'roc3': 0.0376458}, {'rsi': 0.014698463}, {'cmf': 0.018491434}, {'day_of_week': 0.023826659}, {'return_vol_8H': 0.045544103}, {'return_vol_8H_diff': 0.010838087}, {'SPY_5d_diff': 0.027610365}, {'H-L': 0.012343896}, {'bb_spread': 0.035300255}, {'SPY_20d_diff': 0.017201686}, {'price_range_8MA_diff': 0.014962031}]"}
# {'deployment_date': datetime.datetime(2022, 2, 7, 0, 0), 'dataset_end': datetime.datetime(2022, 1, 21, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    56553
# 1    46215
# Name: count, dtype: int64
# 80 40 108 84
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-02-07', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 80, 'TPpct': Decimal('0'), 'FP': 40, 'FPpct': Decimal('0'), 'TN': 108, 'TNpct': Decimal('0'), 'FN': 84, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.0'), 'evaluation_timeperiod': '2022-02-07_2022-02-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.871+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.020883337}, {'bb_category': 0.027560174}, {'return_vol_5D_diff': 0.010597877}, {'close_10DMA_diff': 0.018853897}, {'return_vol_5D': 0.100290716}, {'price_range_H': 0.06136086}, {'price_20Ddiff': 0.017128147}, {'roc_vol5': 0.011002592}, {'DIplus': 0.025856702}, {'macd_15MA': 0.013506386}, {'volume_sum15_10DMA_diff': 0.0055829044}, {'roc_vol_15MA_diff': 0.013447678}, {'range_vol_stddev20D_diff': 0.015994351}, {'volume_15MA_diff': 0.029780168}, {'volume_sum15': 0.009254761}, {'roc_15MA_diff': 0.01871824}, {'price_10Ddiff': 0.008435584}, {'Low-Close': 0.01797335}, {'roc_vol': 0.020303482}, {'SPY_diff_H': 0.0}, {'roc8H': 0.0}, {'DIminus': 0.024123266}, {'day_of_month': 0.023887295}, {'ret_vol_stddev20D_diff': 0.054169744}, {'High-Low': 0.014341584}, {'PrevClose-L': 0.021397298}, {'roc8H_15MA_diff': 0.012448986}, {'High-Close': 0.015442085}, {'cmf_15MA_diff': 0.015864076}, {'roc5': 0.030161083}, {'max_30_diff': 0.022260431}, {'close_20DMA_diff': 0.03423632}, {'return_vol_10D_diff': 0.013226126}, {'roc3': 0.027955197}, {'rsi': 0.0161997}, {'cmf': 0.010622714}, {'day_of_week': 0.025290905}, {'return_vol_8H': 0.04114786}, {'return_vol_8H_diff': 0.01115758}, {'SPY_5d_diff': 0.027556403}, {'H-L': 0.02397785}, {'bb_spread': 0.042291567}, {'SPY_20d_diff': 0.031217152}, {'price_range_8MA_diff': 0.014493566}]"}
# {'deployment_date': datetime.datetime(2022, 2, 14, 0, 0), 'dataset_end': datetime.datetime(2022, 1, 28, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    56735
# 1    46345
# Name: count, dtype: int64
# 10 18 143 141
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-02-14', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 10, 'TPpct': Decimal('0'), 'FP': 18, 'FPpct': Decimal('0'), 'TN': 143, 'TNpct': Decimal('0'), 'FN': 141, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5555555555555556'), 'evaluation_timeperiod': '2022-02-14_2022-02-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.873+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.0215301}, {'bb_category': 0.03223536}, {'return_vol_5D_diff': 0.0}, {'close_10DMA_diff': 0.015953345}, {'return_vol_5D': 0.10228097}, {'price_range_H': 0.054109983}, {'price_20Ddiff': 0.015226182}, {'roc_vol5': 0.011673224}, {'DIplus': 0.029818667}, {'macd_15MA': 0.018221194}, {'volume_sum15_10DMA_diff': 0.0}, {'roc_vol_15MA_diff': 0.019934209}, {'range_vol_stddev20D_diff': 0.016614797}, {'volume_15MA_diff': 0.026948892}, {'volume_sum15': 0.015698211}, {'roc_15MA_diff': 0.0126882475}, {'price_10Ddiff': 0.0}, {'Low-Close': 0.016298072}, {'roc_vol': 0.018092247}, {'SPY_diff_H': 0.0}, {'roc8H': 0.009894794}, {'DIminus': 0.018890813}, {'day_of_month': 0.02577458}, {'ret_vol_stddev20D_diff': 0.062955104}, {'High-Low': 0.016154997}, {'PrevClose-L': 0.02943593}, {'roc8H_15MA_diff': 0.015187981}, {'High-Close': 0.013199999}, {'cmf_15MA_diff': 0.01880432}, {'roc5': 0.0449413}, {'max_30_diff': 0.022495748}, {'close_20DMA_diff': 0.025801692}, {'return_vol_10D_diff': 0.012903238}, {'roc3': 0.026423434}, {'rsi': 0.017612362}, {'cmf': 0.017884571}, {'day_of_week': 0.023734042}, {'return_vol_8H': 0.041480698}, {'return_vol_8H_diff': 0.015484824}, {'SPY_5d_diff': 0.02139621}, {'H-L': 0.015438538}, {'bb_spread': 0.044215653}, {'SPY_20d_diff': 0.018882189}, {'price_range_8MA_diff': 0.0136833275}]"}
# {'deployment_date': datetime.datetime(2022, 2, 21, 0, 0), 'dataset_end': datetime.datetime(2022, 2, 4, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    56886
# 1    46506
# Name: count, dtype: int64
# 67 41 55 71
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-02-21', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 67, 'TPpct': Decimal('0'), 'FP': 41, 'FPpct': Decimal('0'), 'TN': 55, 'TNpct': Decimal('0'), 'FN': 71, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.6341463414634145'), 'evaluation_timeperiod': '2022-02-21_2022-02-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.871+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.016721519}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.0}, {'close_10DMA_diff': 0.014752461}, {'return_vol_5D': 0.10233198}, {'price_range_H': 0.06536304}, {'price_20Ddiff': 0.014018064}, {'roc_vol5': 0.011200993}, {'DIplus': 0.024745228}, {'macd_15MA': 0.016387627}, {'volume_sum15_10DMA_diff': 0.0063630985}, {'roc_vol_15MA_diff': 0.017204829}, {'range_vol_stddev20D_diff': 0.016759142}, {'volume_15MA_diff': 0.02896164}, {'volume_sum15': 0.018681334}, {'roc_15MA_diff': 0.015362939}, {'price_10Ddiff': 0.018161872}, {'Low-Close': 0.017903319}, {'roc_vol': 0.017451527}, {'SPY_diff_H': 0.0}, {'roc8H': 0.014356932}, {'DIminus': 0.019604094}, {'day_of_month': 0.02817249}, {'ret_vol_stddev20D_diff': 0.04509339}, {'High-Low': 0.023126865}, {'PrevClose-L': 0.02393425}, {'roc8H_15MA_diff': 0.019060783}, {'High-Close': 0.015111934}, {'cmf_15MA_diff': 0.022417454}, {'roc5': 0.0409791}, {'max_30_diff': 0.020153083}, {'close_20DMA_diff': 0.020722685}, {'return_vol_10D_diff': 0.01336315}, {'roc3': 0.035318963}, {'rsi': 0.025169192}, {'cmf': 0.018105054}, {'day_of_week': 0.030842846}, {'return_vol_8H': 0.04056178}, {'return_vol_8H_diff': 0.010434819}, {'SPY_5d_diff': 0.014655402}, {'H-L': 0.023730801}, {'bb_spread': 0.038458455}, {'SPY_20d_diff': 0.017355938}, {'price_range_8MA_diff': 0.01689998}]"}
# {'deployment_date': datetime.datetime(2022, 2, 28, 0, 0), 'dataset_end': datetime.datetime(2022, 2, 11, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    57068
# 1    46636
# Name: count, dtype: int64
# 36 8 126 142
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-02-28', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 36, 'TPpct': Decimal('0'), 'FP': 8, 'FPpct': Decimal('0'), 'TN': 126, 'TNpct': Decimal('0'), 'FN': 142, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('4.5'), 'evaluation_timeperiod': '2022-02-28_2022-03-04', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.872+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.020287598}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.016271655}, {'close_10DMA_diff': 0.017069051}, {'return_vol_5D': 0.098932356}, {'price_range_H': 0.06019929}, {'price_20Ddiff': 0.029299036}, {'roc_vol5': 0.011633592}, {'DIplus': 0.022722805}, {'macd_15MA': 0.017676111}, {'volume_sum15_10DMA_diff': 0.0}, {'roc_vol_15MA_diff': 0.019281939}, {'range_vol_stddev20D_diff': 0.018529987}, {'volume_15MA_diff': 0.03307324}, {'volume_sum15': 0.018705798}, {'roc_15MA_diff': 0.009073278}, {'price_10Ddiff': 0.020091107}, {'Low-Close': 0.016646136}, {'roc_vol': 0.019456333}, {'SPY_diff_H': 0.0}, {'roc8H': 0.014968097}, {'DIminus': 0.017225642}, {'day_of_month': 0.024810473}, {'ret_vol_stddev20D_diff': 0.03658564}, {'High-Low': 0.014588505}, {'PrevClose-L': 0.02794422}, {'roc8H_15MA_diff': 0.012369588}, {'High-Close': 0.0199983}, {'cmf_15MA_diff': 0.014830036}, {'roc5': 0.042727463}, {'max_30_diff': 0.017229281}, {'close_20DMA_diff': 0.01834918}, {'return_vol_10D_diff': 0.012825908}, {'roc3': 0.02800178}, {'rsi': 0.022478042}, {'cmf': 0.014553287}, {'day_of_week': 0.025419706}, {'return_vol_8H': 0.04173575}, {'return_vol_8H_diff': 0.01096936}, {'SPY_5d_diff': 0.025369251}, {'H-L': 0.017796608}, {'bb_spread': 0.04998054}, {'SPY_20d_diff': 0.025826901}, {'price_range_8MA_diff': 0.01446717}]"}
# {'deployment_date': datetime.datetime(2022, 3, 7, 0, 0), 'dataset_end': datetime.datetime(2022, 2, 18, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    57229
# 1    46787
# Name: count, dtype: int64
# 44 29 132 107
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-03-07', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 44, 'TPpct': Decimal('0'), 'FP': 29, 'FPpct': Decimal('0'), 'TN': 132, 'TNpct': Decimal('0'), 'FN': 107, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.5172413793103448'), 'evaluation_timeperiod': '2022-03-07_2022-03-11', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.872+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.02200452}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.0}, {'close_10DMA_diff': 0.020058151}, {'return_vol_5D': 0.10423162}, {'price_range_H': 0.06505158}, {'price_20Ddiff': 0.021581562}, {'roc_vol5': 0.017174182}, {'DIplus': 0.025153777}, {'macd_15MA': 0.01730672}, {'volume_sum15_10DMA_diff': 0.0}, {'roc_vol_15MA_diff': 0.0167355}, {'range_vol_stddev20D_diff': 0.011381349}, {'volume_15MA_diff': 0.030055642}, {'volume_sum15': 0.016180847}, {'roc_15MA_diff': 0.010350738}, {'price_10Ddiff': 0.00983878}, {'Low-Close': 0.020630758}, {'roc_vol': 0.021342328}, {'SPY_diff_H': 0.0}, {'roc8H': 0.010023076}, {'DIminus': 0.021884816}, {'day_of_month': 0.02641248}, {'ret_vol_stddev20D_diff': 0.08685852}, {'High-Low': 0.015380293}, {'PrevClose-L': 0.02074151}, {'roc8H_15MA_diff': 0.015110248}, {'High-Close': 0.016548328}, {'cmf_15MA_diff': 0.017799318}, {'roc5': 0.049476054}, {'max_30_diff': 0.020466141}, {'close_20DMA_diff': 0.0}, {'return_vol_10D_diff': 0.013657591}, {'roc3': 0.030528435}, {'rsi': 0.017567847}, {'cmf': 0.016348837}, {'day_of_week': 0.033533715}, {'return_vol_8H': 0.03986602}, {'return_vol_8H_diff': 0.009904077}, {'SPY_5d_diff': 0.019797552}, {'H-L': 0.015385258}, {'bb_spread': 0.041741252}, {'SPY_20d_diff': 0.019671863}, {'price_range_8MA_diff': 0.0122187985}]"}
# {'deployment_date': datetime.datetime(2022, 3, 14, 0, 0), 'dataset_end': datetime.datetime(2022, 2, 25, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    57356
# 1    46894
# Name: count, dtype: int64
# 5 8 233 66
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-03-14', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 5, 'TPpct': Decimal('0'), 'FP': 8, 'FPpct': Decimal('0'), 'TN': 233, 'TNpct': Decimal('0'), 'FN': 66, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.625'), 'evaluation_timeperiod': '2022-03-14_2022-03-18', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.873+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.01810179}, {'bb_category': 0.007246439}, {'return_vol_5D_diff': 0.0}, {'close_10DMA_diff': 0.014268177}, {'return_vol_5D': 0.09048275}, {'price_range_H': 0.048664052}, {'price_20Ddiff': 0.016105527}, {'roc_vol5': 0.0102007175}, {'DIplus': 0.028348463}, {'macd_15MA': 0.013848412}, {'volume_sum15_10DMA_diff': 0.0}, {'roc_vol_15MA_diff': 0.0129559515}, {'range_vol_stddev20D_diff': 0.0142012555}, {'volume_15MA_diff': 0.03009063}, {'volume_sum15': 0.014194256}, {'roc_15MA_diff': 0.016829742}, {'price_10Ddiff': 0.019171342}, {'Low-Close': 0.02190625}, {'roc_vol': 0.025779283}, {'SPY_diff_H': 0.01838293}, {'roc8H': 0.06390302}, {'DIminus': 0.015208533}, {'day_of_month': 0.022250926}, {'ret_vol_stddev20D_diff': 0.06951491}, {'High-Low': 0.012899184}, {'PrevClose-L': 0.026873026}, {'roc8H_15MA_diff': 0.014798129}, {'High-Close': 0.016763058}, {'cmf_15MA_diff': 0.012203584}, {'roc5': 0.04520704}, {'max_30_diff': 0.0169668}, {'close_20DMA_diff': 0.016203523}, {'return_vol_10D_diff': 0.013607795}, {'roc3': 0.020540072}, {'rsi': 0.027782584}, {'cmf': 0.013752036}, {'day_of_week': 0.024595607}, {'return_vol_8H': 0.039961714}, {'return_vol_8H_diff': 0.0}, {'SPY_5d_diff': 0.018920422}, {'H-L': 0.020753792}, {'bb_spread': 0.03295813}, {'SPY_20d_diff': 0.021517253}, {'price_range_8MA_diff': 0.012040857}]"}
# {'deployment_date': datetime.datetime(2022, 3, 21, 0, 0), 'dataset_end': datetime.datetime(2022, 3, 4, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    57533
# 1    47029
# Name: count, dtype: int64
# 43 36 167 66
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-03-21', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 43, 'TPpct': Decimal('0'), 'FP': 36, 'FPpct': Decimal('0'), 'TN': 167, 'TNpct': Decimal('0'), 'FN': 66, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.1944444444444444'), 'evaluation_timeperiod': '2022-03-21_2022-03-25', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.874+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.020473659}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.0}, {'close_10DMA_diff': 0.01511758}, {'return_vol_5D': 0.09596892}, {'price_range_H': 0.057674844}, {'price_20Ddiff': 0.028551806}, {'roc_vol5': 0.014554935}, {'DIplus': 0.028702632}, {'macd_15MA': 0.013164407}, {'volume_sum15_10DMA_diff': 0.0}, {'roc_vol_15MA_diff': 0.017884817}, {'range_vol_stddev20D_diff': 0.012784144}, {'volume_15MA_diff': 0.03136356}, {'volume_sum15': 0.015299975}, {'roc_15MA_diff': 0.014897848}, {'price_10Ddiff': 0.01585079}, {'Low-Close': 0.017954912}, {'roc_vol': 0.021566315}, {'SPY_diff_H': 0.0}, {'roc8H': 0.010560453}, {'DIminus': 0.019529182}, {'day_of_month': 0.021078149}, {'ret_vol_stddev20D_diff': 0.07565155}, {'High-Low': 0.01757397}, {'PrevClose-L': 0.025208492}, {'roc8H_15MA_diff': 0.016362568}, {'High-Close': 0.017064381}, {'cmf_15MA_diff': 0.01531976}, {'roc5': 0.052079126}, {'max_30_diff': 0.019774409}, {'close_20DMA_diff': 0.014300991}, {'return_vol_10D_diff': 0.022683403}, {'roc3': 0.025472652}, {'rsi': 0.0}, {'cmf': 0.024290297}, {'day_of_week': 0.027982248}, {'return_vol_8H': 0.041906565}, {'return_vol_8H_diff': 0.0136584435}, {'SPY_5d_diff': 0.031371802}, {'H-L': 0.016077535}, {'bb_spread': 0.041529868}, {'SPY_20d_diff': 0.014779413}, {'price_range_8MA_diff': 0.013933648}]"}
# {'deployment_date': datetime.datetime(2022, 3, 28, 0, 0), 'dataset_end': datetime.datetime(2022, 3, 11, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    57696
# 1    47178
# Name: count, dtype: int64
# 87 37 85 103
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-03-28', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 87, 'TPpct': Decimal('0'), 'FP': 37, 'FPpct': Decimal('0'), 'TN': 85, 'TNpct': Decimal('0'), 'FN': 103, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.3513513513513513'), 'evaluation_timeperiod': '2022-03-28_2022-04-01', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.874+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.018444663}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.0}, {'close_10DMA_diff': 0.018607246}, {'return_vol_5D': 0.09735499}, {'price_range_H': 0.054879755}, {'price_20Ddiff': 0.012457668}, {'roc_vol5': 0.0147944465}, {'DIplus': 0.026724426}, {'macd_15MA': 0.01724565}, {'volume_sum15_10DMA_diff': 0.0}, {'roc_vol_15MA_diff': 0.019391598}, {'range_vol_stddev20D_diff': 0.013728904}, {'volume_15MA_diff': 0.031229319}, {'volume_sum15': 0.019869028}, {'roc_15MA_diff': 0.011524219}, {'price_10Ddiff': 0.0149502}, {'Low-Close': 0.020691305}, {'roc_vol': 0.025060855}, {'SPY_diff_H': 0.0}, {'roc8H': 0.011173842}, {'DIminus': 0.023076108}, {'day_of_month': 0.02594193}, {'ret_vol_stddev20D_diff': 0.058618296}, {'High-Low': 0.016219946}, {'PrevClose-L': 0.022810087}, {'roc8H_15MA_diff': 0.0140245855}, {'High-Close': 0.014758112}, {'cmf_15MA_diff': 0.01817789}, {'roc5': 0.061178528}, {'max_30_diff': 0.021774663}, {'close_20DMA_diff': 0.015920347}, {'return_vol_10D_diff': 0.014039786}, {'roc3': 0.029300936}, {'rsi': 0.02048764}, {'cmf': 0.016909832}, {'day_of_week': 0.030407807}, {'return_vol_8H': 0.038485996}, {'return_vol_8H_diff': 0.0}, {'SPY_5d_diff': 0.020384364}, {'H-L': 0.03495349}, {'bb_spread': 0.038154453}, {'SPY_20d_diff': 0.018555034}, {'price_range_8MA_diff': 0.01769218}]"}
# {'deployment_date': datetime.datetime(2022, 4, 4, 0, 0), 'dataset_end': datetime.datetime(2022, 3, 18, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    57894
# 1    47292
# Name: count, dtype: int64
# 67 28 67 150
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-04-04', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 67, 'TPpct': Decimal('0'), 'FP': 28, 'FPpct': Decimal('0'), 'TN': 67, 'TNpct': Decimal('0'), 'FN': 150, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.392857142857143'), 'evaluation_timeperiod': '2022-04-04_2022-04-08', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.873+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.020462764}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.009126738}, {'close_10DMA_diff': 0.012078286}, {'return_vol_5D': 0.10084208}, {'price_range_H': 0.06383299}, {'price_20Ddiff': 0.019563362}, {'roc_vol5': 0.018766513}, {'DIplus': 0.02017376}, {'macd_15MA': 0.01625163}, {'volume_sum15_10DMA_diff': 0.0}, {'roc_vol_15MA_diff': 0.014936761}, {'range_vol_stddev20D_diff': 0.011382341}, {'volume_15MA_diff': 0.034880616}, {'volume_sum15': 0.019414738}, {'roc_15MA_diff': 0.01933439}, {'price_10Ddiff': 0.009844693}, {'Low-Close': 0.016663898}, {'roc_vol': 0.018457133}, {'SPY_diff_H': 0.0}, {'roc8H': 0.030262593}, {'DIminus': 0.019974474}, {'day_of_month': 0.023633258}, {'ret_vol_stddev20D_diff': 0.067438625}, {'High-Low': 0.018741664}, {'PrevClose-L': 0.025064712}, {'roc8H_15MA_diff': 0.014186208}, {'High-Close': 0.013629342}, {'cmf_15MA_diff': 0.014596336}, {'roc5': 0.052114226}, {'max_30_diff': 0.016026806}, {'close_20DMA_diff': 0.019844042}, {'return_vol_10D_diff': 0.010631759}, {'roc3': 0.033188857}, {'rsi': 0.016708346}, {'cmf': 0.013467638}, {'day_of_week': 0.022989612}, {'return_vol_8H': 0.040497515}, {'return_vol_8H_diff': 0.0}, {'SPY_5d_diff': 0.02131889}, {'H-L': 0.021607708}, {'bb_spread': 0.044080388}, {'SPY_20d_diff': 0.018094296}, {'price_range_8MA_diff': 0.015890088}]"}
# {'deployment_date': datetime.datetime(2022, 4, 11, 0, 0), 'dataset_end': datetime.datetime(2022, 3, 25, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    58063
# 1    47435
# Name: count, dtype: int64
# 47 20 120 101
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-04-11', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 47, 'TPpct': Decimal('0'), 'FP': 20, 'FPpct': Decimal('0'), 'TN': 120, 'TNpct': Decimal('0'), 'FN': 101, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.35'), 'evaluation_timeperiod': '2022-04-11_2022-04-15', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.872+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.019860096}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.0}, {'close_10DMA_diff': 0.021550763}, {'return_vol_5D': 0.10115159}, {'price_range_H': 0.062202286}, {'price_20Ddiff': 0.01631276}, {'roc_vol5': 0.011689091}, {'DIplus': 0.027215665}, {'macd_15MA': 0.013915468}, {'volume_sum15_10DMA_diff': 0.0}, {'roc_vol_15MA_diff': 0.017397229}, {'range_vol_stddev20D_diff': 0.01735834}, {'volume_15MA_diff': 0.051692028}, {'volume_sum15': 0.023400234}, {'roc_15MA_diff': 0.012103598}, {'price_10Ddiff': 0.008544793}, {'Low-Close': 0.021670746}, {'roc_vol': 0.01729163}, {'SPY_diff_H': 0.0}, {'roc8H': 0.022541558}, {'DIminus': 0.016396698}, {'day_of_month': 0.025437033}, {'ret_vol_stddev20D_diff': 0.053864047}, {'High-Low': 0.018734876}, {'PrevClose-L': 0.02346056}, {'roc8H_15MA_diff': 0.016700802}, {'High-Close': 0.017793303}, {'cmf_15MA_diff': 0.01812391}, {'roc5': 0.05431184}, {'max_30_diff': 0.01863534}, {'close_20DMA_diff': 0.015766783}, {'return_vol_10D_diff': 0.0}, {'roc3': 0.022520546}, {'rsi': 0.020841576}, {'cmf': 0.018136438}, {'day_of_week': 0.02429769}, {'return_vol_8H': 0.034759693}, {'return_vol_8H_diff': 0.0}, {'SPY_5d_diff': 0.032973547}, {'H-L': 0.025742726}, {'bb_spread': 0.04246157}, {'SPY_20d_diff': 0.015723748}, {'price_range_8MA_diff': 0.017419428}]"}
# {'deployment_date': datetime.datetime(2022, 4, 18, 0, 0), 'dataset_end': datetime.datetime(2022, 4, 1, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    58217
# 1    47593
# Name: count, dtype: int64
# 48 18 115 107
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2022-04-18', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 48, 'TPpct': Decimal('0'), 'FP': 18, 'FPpct': Decimal('0'), 'TN': 115, 'TNpct': Decimal('0'), 'FN': 107, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.6666666666666665'), 'evaluation_timeperiod': '2022-04-18_2022-04-22', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.873+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.020144852}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.01319957}, {'close_10DMA_diff': 0.012410116}, {'return_vol_5D': 0.096263714}, {'price_range_H': 0.057430115}, {'price_20Ddiff': 0.0176287}, {'roc_vol5': 0.009821182}, {'DIplus': 0.023027964}, {'macd_15MA': 0.013264799}, {'volume_sum15_10DMA_diff': 0.0}, {'roc_vol_15MA_diff': 0.017383663}, {'range_vol_stddev20D_diff': 0.014207394}, {'volume_15MA_diff': 0.036327288}, {'volume_sum15': 0.01765118}, {'roc_15MA_diff': 0.014398462}, {'price_10Ddiff': 0.010476954}, {'Low-Close': 0.024359658}, {'roc_vol': 0.01701598}, {'SPY_diff_H': 0.0}, {'roc8H': 0.024323357}, {'DIminus': 0.031467326}, {'day_of_month': 0.024039587}, {'ret_vol_stddev20D_diff': 0.079314075}, {'High-Low': 0.017110702}, {'PrevClose-L': 0.025531448}, {'roc8H_15MA_diff': 0.012201712}, {'High-Close': 0.016109735}, {'cmf_15MA_diff': 0.014699544}, {'roc5': 0.052881163}, {'max_30_diff': 0.018317305}, {'close_20DMA_diff': 0.02433273}, {'return_vol_10D_diff': 0.0105273165}, {'roc3': 0.026833724}, {'rsi': 0.016233461}, {'cmf': 0.01231192}, {'day_of_week': 0.02688617}, {'return_vol_8H': 0.043133304}, {'return_vol_8H_diff': 0.0}, {'SPY_5d_diff': 0.015051091}, {'H-L': 0.022647478}, {'bb_spread': 0.039456997}, {'SPY_20d_diff': 0.01853189}, {'price_range_8MA_diff': 0.013046433}]"}
# {'deployment_date': datetime.datetime(2022, 4, 25, 0, 0), 'dataset_end': datetime.datetime(2022, 4, 8, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    58389
# 1    47733
# Name: count, dtype: int64
# 53 21 91 123
# ...
# {'deployment_date': datetime.datetime(2024, 5, 6, 0, 0), 'dataset_end': datetime.datetime(2024, 4, 19, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    75716
# 1    61870
# Name: count, dtype: int64
# 8 15 264 25
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2024-05-06', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 8, 'TPpct': Decimal('0'), 'FP': 15, 'FPpct': Decimal('0'), 'TN': 264, 'TNpct': Decimal('0'), 'FN': 25, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5333333333333333'), 'evaluation_timeperiod': '2024-05-06_2024-05-10', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.879+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.018499646}, {'bb_category': 0.016009722}, {'return_vol_5D_diff': 0.019067356}, {'close_10DMA_diff': 0.020798426}, {'return_vol_5D': 0.10383095}, {'price_range_H': 0.052123997}, {'price_20Ddiff': 0.018603541}, {'roc_vol5': 0.0131611405}, {'DIplus': 0.037954118}, {'macd_15MA': 0.024397334}, {'volume_sum15_10DMA_diff': 0.007378102}, {'roc_vol_15MA_diff': 0.014115162}, {'range_vol_stddev20D_diff': 0.016121127}, {'volume_15MA_diff': 0.028429102}, {'volume_sum15': 0.015078501}, {'roc_15MA_diff': 0.014862757}, {'price_10Ddiff': 0.010617777}, {'Low-Close': 0.024192134}, {'roc_vol': 0.018171422}, {'SPY_diff_H': 0.020111708}, {'roc8H': 0.0}, {'DIminus': 0.022045633}, {'day_of_month': 0.020040628}, {'ret_vol_stddev20D_diff': 0.048165325}, {'High-Low': 0.013562989}, {'PrevClose-L': 0.013770754}, {'roc8H_15MA_diff': 0.010725401}, {'High-Close': 0.013078488}, {'cmf_15MA_diff': 0.019950444}, {'roc5': 0.042122096}, {'max_30_diff': 0.01650495}, {'close_20DMA_diff': 0.034188103}, {'return_vol_10D_diff': 0.015119469}, {'roc3': 0.015210664}, {'rsi': 0.0}, {'cmf': 0.016483495}, {'day_of_week': 0.023298742}, {'return_vol_8H': 0.036070418}, {'return_vol_8H_diff': 0.014254292}, {'SPY_5d_diff': 0.020716673}, {'H-L': 0.036380876}, {'bb_spread': 0.039662562}, {'SPY_20d_diff': 0.021704612}, {'price_range_8MA_diff': 0.013419363}]"}
# {'deployment_date': datetime.datetime(2024, 5, 13, 0, 0), 'dataset_end': datetime.datetime(2024, 4, 26, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    75877
# 1    62021
# Name: count, dtype: int64
# 82 77 115 38
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2024-05-13', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 82, 'TPpct': Decimal('0'), 'FP': 77, 'FPpct': Decimal('0'), 'TN': 115, 'TNpct': Decimal('0'), 'FN': 38, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('1.0649350649350648'), 'evaluation_timeperiod': '2024-05-13_2024-05-17', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.878+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.018195122}, {'bb_category': 0.017143514}, {'return_vol_5D_diff': 0.0}, {'close_10DMA_diff': 0.02534481}, {'return_vol_5D': 0.11021878}, {'price_range_H': 0.053640682}, {'price_20Ddiff': 0.02436563}, {'roc_vol5': 0.01261225}, {'DIplus': 0.04283019}, {'macd_15MA': 0.018107284}, {'volume_sum15_10DMA_diff': 0.010362874}, {'roc_vol_15MA_diff': 0.016319023}, {'range_vol_stddev20D_diff': 0.017696708}, {'volume_15MA_diff': 0.02168683}, {'volume_sum15': 0.016929463}, {'roc_15MA_diff': 0.013441694}, {'price_10Ddiff': 0.032328997}, {'Low-Close': 0.016936895}, {'roc_vol': 0.019759566}, {'SPY_diff_H': 0.0}, {'roc8H': 0.0}, {'DIminus': 0.020616427}, {'day_of_month': 0.020240303}, {'ret_vol_stddev20D_diff': 0.033604853}, {'High-Low': 0.017708763}, {'PrevClose-L': 0.02335403}, {'roc8H_15MA_diff': 0.012783981}, {'High-Close': 0.014263147}, {'cmf_15MA_diff': 0.017545743}, {'roc5': 0.034366507}, {'max_30_diff': 0.016904954}, {'close_20DMA_diff': 0.02890444}, {'return_vol_10D_diff': 0.017059013}, {'roc3': 0.019867273}, {'rsi': 0.013781397}, {'cmf': 0.0148941325}, {'day_of_week': 0.026352257}, {'return_vol_8H': 0.03929224}, {'return_vol_8H_diff': 0.010990805}, {'SPY_5d_diff': 0.024368847}, {'H-L': 0.023315897}, {'bb_spread': 0.051143143}, {'SPY_20d_diff': 0.016039578}, {'price_range_8MA_diff': 0.01468193}]"}
# {'deployment_date': datetime.datetime(2024, 5, 20, 0, 0), 'dataset_end': datetime.datetime(2024, 5, 3, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    76112
# 1    62098
# Name: count, dtype: int64
# 146 52 73 41
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2024-05-20', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 146, 'TPpct': Decimal('0'), 'FP': 52, 'FPpct': Decimal('0'), 'TN': 73, 'TNpct': Decimal('0'), 'FN': 41, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('2.8076923076923075'), 'evaluation_timeperiod': '2024-05-20_2024-05-24', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.879+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.019941308}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.01072094}, {'close_10DMA_diff': 0.025907455}, {'return_vol_5D': 0.1077767}, {'price_range_H': 0.057061657}, {'price_20Ddiff': 0.015796766}, {'roc_vol5': 0.017788086}, {'DIplus': 0.040975794}, {'macd_15MA': 0.022985434}, {'volume_sum15_10DMA_diff': 0.008897428}, {'roc_vol_15MA_diff': 0.014938867}, {'range_vol_stddev20D_diff': 0.01450697}, {'volume_15MA_diff': 0.021889891}, {'volume_sum15': 0.021631802}, {'roc_15MA_diff': 0.019249849}, {'price_10Ddiff': 0.018040774}, {'Low-Close': 0.016468644}, {'roc_vol': 0.022159059}, {'SPY_diff_H': 0.0}, {'roc8H': 0.0}, {'DIminus': 0.024138298}, {'day_of_month': 0.021790123}, {'ret_vol_stddev20D_diff': 0.047347687}, {'High-Low': 0.014564583}, {'PrevClose-L': 0.016036956}, {'roc8H_15MA_diff': 0.012739815}, {'High-Close': 0.014832855}, {'cmf_15MA_diff': 0.017050354}, {'roc5': 0.03390134}, {'max_30_diff': 0.028881386}, {'close_20DMA_diff': 0.026022853}, {'return_vol_10D_diff': 0.012140647}, {'roc3': 0.017055273}, {'rsi': 0.013560241}, {'cmf': 0.016352292}, {'day_of_week': 0.026333628}, {'return_vol_8H': 0.041376125}, {'return_vol_8H_diff': 0.011934501}, {'SPY_5d_diff': 0.021181496}, {'H-L': 0.029136984}, {'bb_spread': 0.045087058}, {'SPY_20d_diff': 0.015108524}, {'price_range_8MA_diff': 0.016689476}]"}
# {'deployment_date': datetime.datetime(2024, 5, 27, 0, 0), 'dataset_end': datetime.datetime(2024, 5, 10, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    76222
# 1    62300
# Name: count, dtype: int64
# 96 19 44 75
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2024-05-27', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 96, 'TPpct': Decimal('0'), 'FP': 19, 'FPpct': Decimal('0'), 'TN': 44, 'TNpct': Decimal('0'), 'FN': 75, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('5.052631578947368'), 'evaluation_timeperiod': '2024-05-27_2024-05-31', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.876+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.023238372}, {'bb_category': 0.0}, {'return_vol_5D_diff': 0.0}, {'close_10DMA_diff': 0.013584061}, {'return_vol_5D': 0.10933098}, {'price_range_H': 0.054589238}, {'price_20Ddiff': 0.02180886}, {'roc_vol5': 0.013116071}, {'DIplus': 0.047854744}, {'macd_15MA': 0.026362734}, {'volume_sum15_10DMA_diff': 0.0088269375}, {'roc_vol_15MA_diff': 0.015521166}, {'range_vol_stddev20D_diff': 0.017210832}, {'volume_15MA_diff': 0.023778535}, {'volume_sum15': 0.015749846}, {'roc_15MA_diff': 0.015881006}, {'price_10Ddiff': 0.012875421}, {'Low-Close': 0.017663052}, {'roc_vol': 0.021095177}, {'SPY_diff_H': 0.0}, {'roc8H': 0.0}, {'DIminus': 0.023183448}, {'day_of_month': 0.020712756}, {'ret_vol_stddev20D_diff': 0.058785286}, {'High-Low': 0.017208219}, {'PrevClose-L': 0.011687135}, {'roc8H_15MA_diff': 0.017464418}, {'High-Close': 0.015391892}, {'cmf_15MA_diff': 0.0119408}, {'roc5': 0.031976875}, {'max_30_diff': 0.019239398}, {'close_20DMA_diff': 0.035310317}, {'return_vol_10D_diff': 0.015945392}, {'roc3': 0.019679248}, {'rsi': 0.016577968}, {'cmf': 0.017182028}, {'day_of_week': 0.028507445}, {'return_vol_8H': 0.03926799}, {'return_vol_8H_diff': 0.012292445}, {'SPY_5d_diff': 0.02309425}, {'H-L': 0.024240859}, {'bb_spread': 0.05062625}, {'SPY_20d_diff': 0.018014627}, {'price_range_8MA_diff': 0.013183902}]"}
# {'deployment_date': datetime.datetime(2024, 6, 3, 0, 0), 'dataset_end': datetime.datetime(2024, 5, 17, 0, 0), 'dataset_start': datetime.datetime(2018, 1, 1, 0, 0)}
# label
# 0    76414
# 1    62420
# Name: count, dtype: int64
# 47 89 146 30
# {'model_name': 'CDBFP_1D:TSSIM2.4_TOP_HYPOPT2_TP0.45', 'deployment_date': '2024-06-03', 'algorithm_type': 'xgboost', 'dataset': 'TSSIM2.4_TOP_HYPOPT2_TP0.45', 'TP': 47, 'TPpct': Decimal('0'), 'FP': 89, 'FPpct': Decimal('0'), 'TN': 146, 'TNpct': Decimal('0'), 'FN': 30, 'FNpct': Decimal('0'), 'precision_ratio': Decimal('0.5280898876404494'), 'evaluation_timeperiod': '2024-06-03_2024-06-07', 'live': False, 'hyperparameters': {"{'subsample': 0.6943714742283909, 'num_round': 800, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.28333880183497623, 'gamma': 0.0, 'colsample_bytree': 0.8}"}, 'features': {"['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']"}, 'target': '-0.876+one_min_vol', 'feature_importances': "[{'min_30_diff': 0.018861473}, {'bb_category': 0.015401761}, {'return_vol_5D_diff': 0.0}, {'close_10DMA_diff': 0.023764264}, {'return_vol_5D': 0.103629485}, {'price_range_H': 0.05219234}, {'price_20Ddiff': 0.016476015}, {'roc_vol5': 0.011366381}, {'DIplus': 0.038650364}, {'macd_15MA': 0.024540618}, {'volume_sum15_10DMA_diff': 0.016960623}, {'roc_vol_15MA_diff': 0.014615127}, {'range_vol_stddev20D_diff': 0.020135922}, {'volume_15MA_diff': 0.03127753}, {'volume_sum15': 0.020290725}, {'roc_15MA_diff': 0.011660322}, {'price_10Ddiff': 0.018454786}, {'Low-Close': 0.023243995}, {'roc_vol': 0.01753676}, {'SPY_diff_H': 0.0}, {'roc8H': 0.015274677}, {'DIminus': 0.022241527}, {'day_of_month': 0.019359188}, {'ret_vol_stddev20D_diff': 0.059385072}, {'High-Low': 0.018436413}, {'PrevClose-L': 0.012156625}, {'roc8H_15MA_diff': 0.013979082}, {'High-Close': 0.012849953}, {'cmf_15MA_diff': 0.013529251}, {'roc5': 0.036276568}, {'max_30_diff': 0.02443825}, {'close_20DMA_diff': 0.024342766}, {'return_vol_10D_diff': 0.013288512}, {'roc3': 0.015598691}, {'rsi': 0.0}, {'cmf': 0.017787987}, {'day_of_week': 0.02925264}, {'return_vol_8H': 0.038631797}, {'return_vol_8H_diff': 0.0130499685}, {'SPY_5d_diff': 0.022316167}, {'H-L': 0.028782504}, {'bb_spread': 0.045289267}, {'SPY_20d_diff': 0.010861316}, {'price_range_8MA_diff': 0.013813351}]"}

# %%
def run_temporal_simulation(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date,strategy):
    tp_avg_list = []
    gross_accuracy_list = []
    # fn_list = []
    # tn_list = []
    
    hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
    dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
    # date = dates_list[-1]
    # response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
    for date in dates_list:
        tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams,strategy)
        tp_avg_list.append(tp)
        gross_accuracy_list.append((tp-fp))

    return tp_avg_list, gross_accuracy_list

def run_temporal_simulation_hyperparams(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date,strategy,hyperparams):
    tp_avg_list = []
    gross_accuracy_list = []
    
    dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
    for date in dates_list:
        tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams,strategy)
        tp_avg_list.append(tp)
        gross_accuracy_list.append((tp-fp))

    return tp_avg_list, gross_accuracy_list

# %%
# number_of_simulations = 150
# now = datetime.now()
# title = 'CDBFP_1D'
# # total_feature_list = ['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'v', 'o', 'c', 'h', 'l',
# #  'date', 'hour', 'symbol', 't', 'price7', 'price14', 'adjusted_volume', 'vol7', 'vol14', 'rsi', 
# # 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close', 'oneD_returns_close', 'range_vol', 
# # 'range_vol5MA', 'range_vol10MA', 'range_vol25MA', 'oneD_stddev50', 'threeD_stddev50', 'cmf', 'close_diff', 
# # 'close_diff3', 'close_diff5', 'v_diff_pct', 'adx', 'volume_10MA', 'volume_25MA', 'price_10MA', 'price_25MA',
# # 'volume_10DDiff', 'volume_25DDiff', 'price_10DDiff', 'price_25DDiff', 'one_max', 'one_min', 'one_pct', 
# # 'three_max', 'three_min', 'three_pct', 'SPY_diff', 'SPY_diff3', 'SPY_diff5', 'SPY_1D', 'SPY_3D', 'SPY_5D', 
# # 'vw', 'n', 'return_vol_15M', 'volume_vol_15M', 'return_vol_30M', 'volume_vol_30M', 'return_vol_60M', 
# # 'volume_vol_60M', 'return_vol_120M', 'volume_vol_120M', 'return_vol_240M', 'volume_vol_240M', 
# # 'return_vol_450M', 'volume_vol_450M', '15min_vol_diff', '15min_vol_diff_pct', 'min_vol_diff', 
# # 'min_vol_diff_pct', 'min_volume_vol_diff', 'min_volume_vol_diff_pct', 'return_vol_4H', 'return_vol_8H', 
# # 'return_vol_16H', 'volume_vol_4H', 'volume_vol_8H', 'volume_vol_16H', 'hour_vol_diff', 'hour_vol_diff_pct', 
# # 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_3D', 'return_vol_5D', 'return_vol_10D', 
# # 'return_vol_30D', 'volume_vol_3D', 'volume_vol_5D', 'volume_vol_10D', 'volume_vol_30D', 'daily_vol_diff', 
# # 'daily_vol_diff_pct', 'daily_vol_diff30', 'daily_vol_diff_pct30', 'daily_volume_vol_diff', 'daily_volume_vol_diff_pct', 
# # 'daily_volume_vol_diff30', 'daily_volume_vol_diff_pct30', 'cd_vol', 'cd_vol3', 'roc_diff', 'range_vol_diff5', 
# # 'close_diff_deviation3', 'close_diff_deviation', 'day_of_week', 'day_of_month', 'month', 'year', 'dt', 'one_max_vol', 
# # 'three_max_vol', 'one_min_vol', 'three_min_vol']

# CDBFC_1D_temporal_simulation_26
# ['min_30_diff', 'bb_category', 'day_of_week', 'max_30_diff', 'return_vol_10D_diff', 'SPY_5d_diff', 'SPY_range_vol', 'volume_vol_stddev40H_diff', 'range_vol_stddev40H_diff', 'cmf', 'roc_vol', 'DIminus', 'bb_trend', 'close_20DMA_diff', 'macd_15MA', 'price_change_D', 'rsi_15MA_diff', 'roc_vol5', 'ret_vol_stddev40H_diff', 'DIplus', 'range_vol_stddev20D_diff', 'bb_spread', 'price_range_8MA_diff', 'PrevClose-L', 'TR', 'return_vol_10D', 'roc_vol3', 'roc', 'volume_sum15', 'roc_vol_15MA_diff', 'roc5', 'rsi_15MA', 'close_10DMA_diff', 'macd', 'rsi', 'High-Close', 'cd_vol', 'month', 'DMminus', 'High-Low', 'hour', 'cd_vol3']
# 71.86936936936937 9.468468468468469 11.0

# %% [markdown]
# ## Genetic Algorithm Feature Selection

# %%
# import random
# import numpy as np
# import pandas as pd
# from datetime import datetime

# # Define the total feature list and other constants
# total_feature_list = ['hour','volume_15MA_diff',  
#                     'volume_sum15_5DMA_diff', 'volume_sum15_10DMA_diff', 'price_change_absolute_H', 
#                       'price_change_H', 'price_range_H', 'price_range_8MA_diff', 'return_vol_8H', 'return_vol_8H_diff', 
#                       'ret_vol_stddev40H_diff','volume_vol_stddev40H_diff', 'range_vol_stddev40H_diff', 'rsiH', 
#                       'rsiH_15MA', 'rsiH_15MA_diff', 'roc8H', 'roc8H_15MA', 'roc8H_15MA_diff', 'price_change_D', 'price_range_D', 
#                       'price_range_5DMA', 'price_range_5DMA_diff', 'return_vol_5D', 'return_vol_5D_diff', 'return_vol_10D', 'return_vol_10D_diff', 'ret_vol_stddev20D', 
#                       'ret_vol_stddev20D_diff', 'range_vol_stddev20D', 'range_vol_stddev20D_diff', 'price_3Ddiff', 'price_5Ddiff', 'price_10Ddiff', 'price_20Ddiff', 
#                       'price_3D20D_diff','close_20DMA_diff', 'close_10DMA', 'close_10DMA_diff', 'rsi', 'rsi_15MA', 'rsi_15MA_diff', 'roc', 'roc3', 'roc5', 
#                       'roc_15MA', 'roc_15MA_diff', 'High-Low', 'High-Close', 'Low-Close', 'TR', 'H-L', 'H-PrevClose', 'PrevClose-L', 'DMplus', 'DMminus', 'DIplus', 'DIminus', 
#                       'DX', 'adx', 'macd', 'macd_15MA', 'macd_15MA_diff', 'bbu', 'bbl', 'bbm', 'bb_spread', 'bb_trend', 'bb_category', 'cmf', 'cmf_15MA', 'cmf_15MA_diff', 
#                       'max_30', 'min_30', 'max_30_diff', 'min_30_diff', 'roc_vol', 'roc_vol3', 'roc_vol5', 'roc_vol_15MA', 'roc_vol_15MA_diff',
#                       'SPY_diff_H', 'SPY_diff_D', 'SPY_5d', 'SPY_20d', 'SPY_5d_diff', 'SPY_20d_diff', 'SPY_range_vol', 
#                       'day_of_week', 'day_of_month', 'cd_vol', 'cd_vol3']
# target_label = 'one_min_vol'
# target_percentile = 0.4
# number_of_generations = 10
# population_size = 10
# mutation_rate = 0.1
# title = 'CDBFP_1D'
# basic_results = []

# # Define your current best feature set
# current_best_features = ['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 
#             'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 
#             'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 
#             'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']

# def evaluate_performance(features):
#     print(features)
#     checked = []
#     for feature in features:
#         if feature not in checked:
#             checked.append(feature)
#         else:
#             print("Duplicate feature found")
#     # tp_avg_list, gross_accuracy_list = run_temporal_simulation(checked, target_label, target_percentile, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2021,1,4), evaluation_end_date=datetime(2024,4,20),strategy=title)
#     tp_avg_list, gross_accuracy_list = run_temporal_simulation(checked, target_label, target_percentile, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2021,1,4), evaluation_end_date=datetime(2021,1,25),strategy=title)
#     acc_median = np.median(gross_accuracy_list)
#     tp_avg = sum(tp_avg_list) / len(tp_avg_list)
#     gross_accuracy = sum(gross_accuracy_list) / len(gross_accuracy_list)
#     print(f"tp_avg: {tp_avg}, gross_accuracy: {gross_accuracy}, acc_median: {acc_median}")
#     print()
#     basic_results.append({"features": features, "tp_avg": tp_avg, "gross_accuracy": gross_accuracy,"num_features": len(features),"median_tp": np.median(tp_avg_list), "median_gross_accuracy": np.median(gross_accuracy_list)})
#     fitness = acc_median + gross_accuracy
#     return fitness

# def initialize_population(feature_list, population_size, current_best_features):
#     population = [current_best_features]  # Start with the best known feature set
#     for _ in range(population_size - 1):  # Remaining population
#         num_features = random.randint(30, 45)
#         individual = random.sample(feature_list, num_features)
#         population.append(individual)
#     return population

# def select_parents(population, scores, num_parents):
#     parents = random.choices(population, weights=scores, k=num_parents)
#     return parents

# def crossover(parents):
#     crossover_point = random.randint(1, min(len(parents[0]), len(parents[1])) - 1)
#     child = parents[0][:crossover_point] + parents[1][crossover_point:]
#     return child

# def mutate(individual, feature_list, mutation_rate):
#     if random.random() < mutation_rate:
#         if random.random() < 0.5 and len(individual) > 1:  # Remove a feature
#             individual.pop(random.randint(0, len(individual) - 1))
#         else:  # Add a feature
#             possible_features = list(set(feature_list) - set(individual))
#             if possible_features:  # Ensure there are possible features to add
#                 new_feature = random.choice(possible_features)
#                 individual.append(new_feature)
#     return individual

# def genetic_algorithm(feature_list, population_size, generations, mutation_rate, current_best_features):
#     population = initialize_population(feature_list, population_size, current_best_features)
#     results_array = []

#     for generation in range(generations):
#         scores = [evaluate_performance(individual) for individual in population]
#         new_population = []

#         for _ in range(population_size // 2):
#             parents = select_parents(population, scores, 2)
#             child1 = mutate(crossover(parents), feature_list, mutation_rate)
#             child2 = mutate(crossover(parents), feature_list, mutation_rate)
#             new_population.extend([child1, child2])

#         population = new_population
#         print(f"Generation {generation + 1}: Best fitness = {max(scores)}")

#         # Save results of the current generation
#         best_individual = population[np.argmax(scores)]
#         best_score = max(scores)
#         results_array.append({"generation": generation + 1, "best_features": best_individual, "best_score": best_score})
#         print

#     return results_array

# # Run the genetic algorithm
# results = genetic_algorithm(total_feature_list, population_size, number_of_generations, mutation_rate, current_best_features)

# # Save the results
# now = datetime.now()
# results_df = pd.DataFrame(results)
# results_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
# basic_df = pd.DataFrame(basic_results)
# basic_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}_basic.csv', index=False)
# print("Optimization completed and results saved.")

# %% [markdown]
# ## Bayesian Hyperparamter Optimization

# %%
# from skopt import gp_minimize
# from skopt.space import Real, Integer, Categorical
# from skopt.utils import use_named_args

# # Define the hyperparameter search space
# param_space = [
#     Real(0.5, 1.0, name='subsample'),
#     Integer(800, 2000, name='num_round'),
#     Integer(1, 50, name='min_child_weight'),
#     Integer(1, 20, name='max_depth'),
#     Real(0.01, 0.3, name='learning_rate'),
#     Real(0, 5, name='gamma'),
#     Real(0.8, 1.0, name='colsample_bytree')
# ]

# basic_results = []
# target_label = 'one_min_vol'
# target_percentile = 0.45
# title = 'CDBFP_1D'
# features = ['min_30_diff', 'bb_category', 'return_vol_5D_diff', 'close_10DMA_diff', 'return_vol_5D', 'price_range_H', 'price_20Ddiff', 'roc_vol5', 'DIplus', 
#             'macd_15MA', 'volume_sum15_10DMA_diff', 'roc_vol_15MA_diff', 'range_vol_stddev20D_diff', 'volume_15MA_diff', 'volume_sum15', 'roc_15MA_diff', 'price_10Ddiff', 
#             'Low-Close', 'roc_vol', 'SPY_diff_H', 'roc8H', 'DIminus', 'day_of_month', 'ret_vol_stddev20D_diff', 'High-Low', 'PrevClose-L', 'roc8H_15MA_diff', 'High-Close', 
#            'cmf_15MA_diff', 'roc5', 'max_30_diff', 'close_20DMA_diff', 'return_vol_10D_diff', 'roc3', 'rsi', 'cmf', 'day_of_week', 'return_vol_8H', 'return_vol_8H_diff', 'SPY_5d_diff', 'H-L', 'bb_spread', 'SPY_20d_diff', 'price_range_8MA_diff']

# # Objective function to minimize (negative cross-validated accuracy)
# @use_named_args(param_space)
# def objective(**params):
#     hyperparams = {
#         'subsample': params['subsample'], 
#         'num_round': params['num_round'], 
#         'min_child_weight': params['min_child_weight'], 
#         'max_depth': params['max_depth'], 
#         'learning_rate': params['learning_rate'], 
#         'gamma': params['gamma'], 
#         'colsample_bytree': params['colsample_bytree']
#     }
#     print(hyperparams)
#     tp_avg_list, gross_accuracy_list = run_temporal_simulation_hyperparams(
#         features, target_label, target_percentile, 
#         dataset_start_date=datetime(2018, 1, 1), 
#         evaluation_start_date=datetime(2021, 1, 4), 
#         # evaluation_end_date=datetime(2021, 1, 25),
#         evaluation_end_date=datetime(2024, 4, 20),
#         strategy=title, hyperparams=hyperparams
#     )
    
#     acc_median = np.median(gross_accuracy_list)
#     tp_avg = sum(tp_avg_list) / len(tp_avg_list)
#     gross_accuracy = sum(gross_accuracy_list) / len(gross_accuracy_list)
    
#     print(f"tp_avg: {tp_avg}, gross_accuracy: {gross_accuracy}, acc_median: {acc_median}")
#     print()
#     basic_results.append({
#         "features": hyperparams, 
#         "tp_avg": tp_avg, 
#         "gross_accuracy": gross_accuracy,
#         "median_tp": np.median(tp_avg_list), 
#         "median_gross_accuracy": np.median(gross_accuracy_list)
#     })
    
    # fitness = (1.1 * acc_median) + gross_accuracy
    # print(f"Fitness: {fitness}")
#     print()
#     return -fitness  # Minimize negative fitness



# # Perform Bayesian Optimization
# result = gp_minimize(
#     func=objective,
#     dimensions=param_space,
#     n_calls=500,
#     n_random_starts=10,  # the number of random initialization points
#     random_state=0
# )

# # Best hyperparameters found
# best_hyperparameters = {dim.name: result.x[i] for i, dim in enumerate(param_space)}
# print("Best Hyperparameters:", best_hyperparameters)

# # Save the results to a CSV file
# results_df = pd.DataFrame(result.x_iters, columns=[dim.name for dim in param_space])
# results_df['Objective'] = result.func_vals
# now = datetime.now()
# title = 'Hyperparameter_Optimization'
# results_df.to_csv(f'/Users/charlesmiller/Documents/hyp_opt_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
# basic_df = pd.DataFrame(basic_results)
# basic_df.to_csv(f'/Users/charlesmiller/Documents/hyp_opt_results/{title}/{now.year}_{now.month}_{now.day}_basic.csv', index=False)

# %% [markdown]
# ## Bayesian Search Features

# %%
# # Example feature list
# testing_features = ['price_change_H', 'cd_vol', 'price_range_D','price_range_H', 'bb_trend', 'price_range_5DMA_diff', 
#                     'roc', 'bb_category', 'bb_spread', 'volume_15MA_diff', 'price_change_D', 'month', 
#                     'return_vol_10D', 'PrevClose-L', 'roc3', 'H-L', 'TR', 'volume_sum15', 
#                     'return_vol_5D_diff', 'price_3Ddiff', 'roc_15MA', 'macd_15MA_diff', 'rsi_15MA', 
#                     'SPY_5d_diff', 'return_vol_8H_diff', 'High-Close', 'DMminus', 'hour', 
#                     'return_vol_10D_diff', 'H-PrevClose', 'DMplus', 'DX', 'SPY_range_vol', 
#                     'Low-Close', 'price_5Ddiff', 'volume_sum15_10DMA_diff', 'rsi', 'cmf_15MA_diff', 
#                     'return_vol_5D', 'price_10Ddiff', 'day_of_week', 'High-Low', 'roc_15MA_diff', 
#                     'cmf', 'volume_sum15_5DMA_diff', 'SPY_20d', 'macd_15MA', 'day_of_month', 'adx', 
#                     'price_range_8MA_diff', 'cd_vol3', 'DIplus', 'return_vol_8H', 'price_20Ddiff', 
#                     'cmf_15MA', 'price_3D20D_diff', 'SPY_5d', 'SPY_20d_diff', 'rsi_15MA_diff', 'macd', 
#                     'roc5', 'DIminus','ret_vol_stddev40H_diff', 
#                     'volume_vol_stddev40H_diff', 'ret_vol_stddev20D_diff', 
#                     'range_vol_stddev40H_diff', 'range_vol_stddev20D_diff', 
#                     'close_20DMA_diff', 'close_10DMA_diff', 'max_30_diff', 'min_30_diff', 
#                     'roc_vol_15MA_diff','roc_vol','roc_vol3','roc_vol5','roc8H', 'roc8H_15MA_diff','rsiH',
#                     'rsiH_15MA_diff','SPY_diff_H','SPY_diff_D',
#                     # 'PCR_H', 'PCR_D', 'PCR_HD_diff', 'PCR_H_change', 'PCR_H_change_10std_diff', 
#                     # 'PCR_H_change8', 'PCR_H_10MA_diff', 'total_volume_H_change', 'total_volume_H_change8', 'total_volume_H_8MA_diff', 'total_volume_change_10std_diff', 
#                     # 'PCR_D_change', 'PCR_D_change_10std_diff', 'PCR_D_change5', 'PCR_D_10MA_diff'
#                     ]

# target_label = 'one_min_vol'
# target_percentile = 0.45
# title = 'CDBFP_1D'

# # Define the feature selection space as binary variables (0 or 1 for each feature)
# param_space = [Integer(0, 1, name=feature) for feature in testing_features]

# # Placeholder for results
# basic_results = []

# # Objective function to maximize
# @use_named_args(param_space)
# def objective(**params):
#     # Convert the binary mask to a list of selected features
#     selected_features = [feature for feature, include in params.items() if include == 1]
#     print(selected_features)
    
#     if not selected_features:
#         return 0  # If no features are selected, return a low fitness score
    
#     tp_avg_list, gross_accuracy_list = run_temporal_simulation(
#         selected_features, target_label, target_percentile, 
#         dataset_start_date=datetime(2018, 1, 1), 
#         evaluation_start_date=datetime(2021, 1, 4), 
#         # evaluation_end_date=datetime(2021, 1, 25),
#         evaluation_end_date=datetime.datetime(2024, 4, 20),
#         strategy=title
#     )
    
#     acc_median = np.median(gross_accuracy_list)
#     tp_avg = sum(tp_avg_list) / len(tp_avg_list)
#     gross_accuracy = sum(gross_accuracy_list) / len(gross_accuracy_list)
#     print(f"tp_avg: {tp_avg}, gross_accuracy: {gross_accuracy}, acc_median: {acc_median}, length: {len(selected_features)}")
#     print()
    
#     basic_results.append({
#         "features": selected_features, 
#         "tp_avg": tp_avg, 
#         "gross_accuracy": gross_accuracy,
#         "num_features": len(selected_features),
#         "median_tp": np.median(tp_avg_list), 
#         "median_gross_accuracy": np.median(gross_accuracy_list)
#     })
    
#     # Maximize fitness, so return negative value to minimize
#     fitness = (1.1 * acc_median) + gross_accuracy
#     print(f"Fitness: {fitness}")
#     return -fitness

# # Perform Bayesian Optimization
# result = gp_minimize(
#     func=objective,
#     dimensions=param_space,
#     n_calls=500,  # Increase if needed
#     random_state=None,  # Remove the random seed for different results each run
#     n_initial_points=10  # Number of random points before optimization starts
# )

# # Best feature set found
# best_feature_mask = result.x
# best_features = [testing_features[i] for i in range(len(testing_features)) if best_feature_mask[i] == 1]
# print("Best Features:", best_features)

# # Save the results to a CSV file
# results_df = pd.DataFrame(result.x_iters, columns=[dim.name for dim in param_space])
# results_df['Objective'] = result.func_vals
# now = datetime.now()
# results_df.to_csv(f'./{title}_{now.year}_{now.month}_{now.day}.csv', index=False)
# print("Optimization completed and results saved.")
