# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import math
import random
from decimal import Decimal, getcontext
import pandas_market_calendars as mcal
import ast
from sklearn.preprocessing import StandardScaler
import pytz
import warnings
warnings.filterwarnings('ignore')

# %%
s3 = boto3.client('s3')
STRATEGY = 'BFC_1D'
training_bucket = "icarus-research-data"
training_prefix = 'training_datasets/expanded_1d_datasets/'

# Create a calendar
nyse = mcal.get_calendar('NYSE')
holidays = nyse.regular_holidays
market_holidays = holidays.holidays()

index = ["QQQ","SPY","IWM","TLT"]
test_lag = ["DAL","UAL","VZ","T","AAL","AMC"]
train_lag = ["AMC"]

# big_fish =  [
#             "AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","PLTR","BAC","AAPL","NFLX","ABNB","CRWD","SHOP","FB","CRM",
#             "MSFT","F","V","MA","JNJ","DIS","JPM","INTC","ADBE","BA","CVX","MRNA","PFE","SNOW","SOFI",'META',
#             ]

# bf_plus = ["AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","PLTR","BAC","AAPL","NFLX","ABNB","CRWD","SHOP","FB","CRM",
#             "MSFT","F","V","MA","JNJ","DIS","JPM","INTC","ADBE","BA","CVX","MRNA","PFE","SNOW","NKE",'META',
#             'C','TGT','MMM','SQ','PANW','DAL','CSCO','UBER','SBUX']


all_symbols = ['ZM', 'UBER', 'CMG', 'AXP', 'TDOC', 'UAL', 'DAL', 'MMM', 'PEP', 'GE', 'RCL', 'MRK',
 'HD', 'LOW', 'VZ', 'PG', 'TSM', 'GOOG', 'GOOGL', 'AMZN', 'BAC', 'AAPL', 'ABNB',
 'CRM', 'MSFT', 'F', 'V', 'MA', 'JNJ', 'DIS', 'JPM', 'ADBE', 'BA', 'CVX', 'PFE',
 'META', 'C', 'CAT', 'KO', 'MS', 'GS', 'IBM', 'CSCO','TSLA','LCID','NIO','WFC',
 'TGT', 'COST', 'RIVN', 'COIN', 'SQ', 'SHOP', 'DOCU', 'ROKU', 'TWLO', 'DDOG', 'ZS', 'NET',
 'OKTA', 'UPST', 'ETSY', 'PINS', 'FUTU', 'SE', 'BIDU', 'JD', 'BABA', 'RBLX', 'AMD',
 'NVDA', 'PYPL', 'PLTR', 'NFLX', 'CRWD', 'INTC', 'MRNA', 'SNOW', 'SOFI', 'PANW',
 'ORCL','WBD','ARM','SNAP','BILI','AAL','CCL','NCLH','LYFT','BIDU','JD','BABA','HD','LOW',
 'SBUX','NKE','AFFRM','WMT']

high_vol = ['ZM', 'UBER', 'TDOC', 'UAL', 'RCL', 'AMZN', 'ABNB', 'META', 'TSLA',
       'LCID', 'NIO', 'RIVN', 'SQ', 'SHOP', 'DOCU', 'ROKU',
       'TWLO', 'DDOG', 'ZS', 'NET', 'OKTA', 'ETSY', 'PINS',
       'FUTU', 'SE', 'RBLX', 'AMD', 'NVDA', 'PYPL', 'PLTR', 'NFLX',
       'CRWD', 'MRNA', 'SNOW', 'SOFI', 'WBD', 'ARM', 'SNAP', 'BILI',
       'AAL', 'CCL', 'NCLH', 'LYFT', 'BIDU', 'JD', 'BABA', 'MU', 'AMAT',
       'DKNG', 'CZR', 'VXX']

mid_vol =['CMG', 'AXP', 'DAL', 'GE', 'TSM', 'GOOG', 'GOOGL', 'BAC', 'AAPL',
       'CRM', 'MSFT', 'F', 'DIS', 'ADBE', 'BA', 'CVX', 'C', 'CAT', 'MS',
       'WFC', 'TGT', 'INTC', 'PANW', 'ORCL', 'LOW', 'SBUX', 'NKE', 'QCOM',
       'AVGO', 'TXN', 'MGM', 'XOM']

low_vol = ['MMM', 'MRK', 'HD', 'VZ', 'V', 'MA', 'JPM',
       'PFE', 'GS', 'IBM', 'CSCO', 'WMT', 'COST', 'QQQ', 'SPY',
       'TLT', 'IWM']

bfpidx = ["AMD","NVDA","PYPL","GOOG","GOOGL","AMZN","BAC","AAPL","FB","DIS"
          "MSFT","INTC","PFE","SNOW",'META','C','XOM',"QQQ","SPY","IWM","TLT"]


bf2 = ['QQQ','IWM','AAPL','NVDA','AMD','AMZN','SPY','MSFT','GOOG','GOOGL','C','BAC',
      'JPM','XOM','CVX','CSCO','INTC','DIS','IBM','BA', 'V','AXP','PYPL','ADBE','F','GM']

GE = [
    'QQQ','SPY','IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD','SHOP'
    'AXP', 'AAPL', 'BAC', 'BA', 'CVX', 'CSCO', 'C', 'DIS', 'XOM', 
    'GM', 'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA', 'PYPL','PANW','ADBE'
    'TSLA', 'V', 'SQ', 'TSM', 'QCOM', 'UBER', 'SNOW', 'PLTR', 'ABNB',
    "FB",'META',"TGT","NKE","SBUX","ORCL","DDOG","JNJ","AVGO","COST"
    ]
BF3 = ['QQQ', 'SPY', 'IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD', 'AAPL', 'BAC',
       'BA', 'C', 'DIS', 'XOM', 'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA',
       'TSLA', 'V', 'TSM', 'QCOM', 'SNOW', 'TGT', 'NKE', 'SBUX', 'ORCL',
       'PYPL', 'SQ', 'UBER', 'PLTR', 'ABNB', 'META']
PE = ['SPY', 'TSLA', 'QQQ', 'AMD', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN','TSM','BAC','C','XOM','DIS','SBUX','PYPL','NKE']
PE2 = ['SPY', 'TSLA', 'QQQ', 'AMD', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN','TSM','XOM','DIS','PYPL','BA','NFLX','NVDA','GOOG','META']
## NVDA,NFLX,GOOG,META,AVGO,COST w/ increased capital

BF3_TRIMMED = [
    'QQQ','SPY','IWM', 'GOOGL', 'GOOG', 'AMZN', 'AMD', 
    'AAPL', 'BAC', 'BA', 'C', 'DIS', 'XOM', 
    'INTC', 'JPM', 'MSFT', 'NFLX', 'NVDA', 'PYPL',
    'TSLA', 'V', 'SQ', 'TSM', 'QCOM', 'UBER', 'SNOW', 'PLTR', 'ABNB',
    "FB",'META',"TGT","NKE","SBUX","ORCL"
    ]

t11 = ['NVDA', 'SPY', 'TSLA', 'QQQ', 'AMD', 'GOOG', 'GOOGL','AAPL', 'MSFT', 'IWM', 'AMZN']

# %%
def configure_dates(data,strategy):
    if strategy in ["CDBFC","CDBFP"]:
        data = data.loc[data['day_of_week'].isin([0,1,2])] 
    elif strategy in ["CDBFC_1D","CDBFP_1D"]:
        data = data.loc[data['day_of_week'].isin([0,1,2,3])]
    return data

def pull_training_data_local(end_date,strategy):
    data = pd.read_csv('/Users/charlesmiller/Documents/model_tester_data/BF/2015-01-01_2024-04-20.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data = data.loc[data['dt'] <= end_date]
    data['one_max_vol'] = (data['one_max']/data['return_vol_10D']).round(3)
    data['three_max_vol'] = (data['three_max']/data['return_vol_10D']).round(3)
    data['one_min_vol'] = (data['one_min']/data['return_vol_10D']).round(3)
    data['three_min_vol'] = (data['three_min']/data['return_vol_10D']).round(3)    
    # data['one_max_vol30'] = (data['one_max']/data['return_vol_30D']).round(3)
    # data['three_max_vol30'] = (data['three_max']/data['return_vol_30D']).round(3)
    # data['one_min_vol30'] = (data['one_min']/data['return_vol_30D']).round(3)
    # data['three_min_vol30'] = (data['three_min']/data['return_vol_30D']).round(3)    
    # data['cd_vol'] = (data['close_diff']/data['return_vol_10D']).round(3)
    # data['cd_vol3'] = (data['close_diff3']/data['return_vol_10D']).round(3)
    # data['cd_vol30'] = (data['close_diff']/data['return_vol_30D']).round(3)
    data['cd_vol'] = (data['price_change_D']/data['return_vol_10D']).round(3)
    data['cd_vol3'] = (data['price_3Ddiff']/data['return_vol_10D']).round(3)
    # data['cd_vol330'] = (data['close_diff3']/data['return_vol_30D']).round(3)
    data = data.loc[data['symbol'].isin(BF3)]
    data = configure_dates(data,strategy)
    data.replace([np.inf, -np.inf], 0, inplace=True)
    return data


def pull_validation_data_local(end_date,start_date,strategy):
    data = pd.read_csv('/Users/charlesmiller/Documents/model_tester_data/BF/2015-01-01_2024-04-20.csv')
    data['dt'] = pd.to_datetime(data['date'])
    data['one_max_vol'] = (data['one_max']/data['return_vol_10D']).round(3)
    data['three_max_vol'] = (data['three_max']/data['return_vol_10D']).round(3)
    data['one_min_vol'] = (data['one_min']/data['return_vol_10D']).round(3)
    data['three_min_vol'] = (data['three_min']/data['return_vol_10D']).round(3)    
    # data['one_max_vol30'] = (data['one_max']/data['return_vol_30D']).round(3)
    # data['three_max_vol30'] = (data['three_max']/data['return_vol_30D']).round(3)
    # data['one_min_vol30'] = (data['one_min']/data['return_vol_30D']).round(3)
    # data['three_min_vol30'] = (data['three_min']/data['return_vol_30D']).round(3)    
    data['cd_vol'] = (data['price_change_D']/data['return_vol_10D']).round(3)
    data['cd_vol3'] = (data['price_3Ddiff']/data['return_vol_10D']).round(3)
    # data['cd_vol30'] = (data['close_diff']/data['return_vol_30D']).round(3)
    # data['cd_vol330'] = (data['close_diff3']/data['return_vol_30D']).round(3)
    data = data.loc[data['dt'] <= end_date]
    data = data.loc[data['dt'] >= start_date]
    data = data.loc[data['symbol'].isin(PE2)]
    data = configure_dates(data,strategy)
    data.replace([np.inf, -np.inf], 0, inplace=True)
    return data

# %%
def build_date_list(start_date, end_date):
    print(start_date, end_date)
    date_diff = end_date - start_date
    numdays = date_diff.days 
    dateList = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            dateList.append(temp_date)
    return dateList

def build_query_keys_hist():
    start_date = datetime(2021,1,5)
    date_diff = datetime(2022,7,29) - start_date
    numdays = date_diff.days 
    key_list = []
    for x in range (0, numdays):
        temp_date = start_date + timedelta(days = x)
        if temp_date.weekday() > 4:
            continue
        else:
            date_str = temp_date.strftime('%Y-%m-%d')
            if date_str in market_holidays:
                continue
            else:
                date_str = date_str.replace("-","/")
                key_list.append(date_str)
        
    return key_list
    
def build_query_keys(dates):
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_query_keys_validation(end_date):
    validation_end_date = end_date + timedelta(days=7)
    dates = build_date_list(end_date, validation_end_date)
    key_list = []
    for date in dates:
        date_str = date.strftime('%Y-%m-%d')
        if date_str in market_holidays:
            continue
        else:
            year, month, day = date_str.split('-')
            temp = f'{year}/{month}/{day}'
            key_list.append(temp)

    return key_list

def build_validation_dates_local(deployment_date):
    end_date = deployment_date + timedelta(days=5)
    return end_date

# %%
def model_results_analyzer(predictions, y_validate, target_value):
    result_list = []
    counter = 0
    predictions_series = pd.Series(predictions,name='prediction_values')
    for x in predictions:
        if x == 1:
            if y_validate.iloc[counter] == 1:
                classification_result = 0
            else:
                classification_result = 1
        elif x == 0:
            if y_validate.iloc[counter] == 0:
                classification_result = 2
            else: 
                classification_result = 3
        result_list.append(classification_result)
        counter += 1
    three_max = pd.Series(y_validate,name='three_max')
    df = pd.concat([pd.Series(result_list,name='classifier_performance'),predictions_series,three_max],axis=1)
    df.reset_index(drop=True, inplace=True)
    # df = pd.DataFrame([result_list, y_validate], columns=['classifier_performance', 'prediction_score'])

    tp = df.loc[df['classifier_performance'] == 0]
    fp = df.loc[df['classifier_performance'] == 1]
    tn = df.loc[df['classifier_performance'] == 2]
    fn = df.loc[df['classifier_performance'] == 3]

    # tp_scr = tp["prediction_score"].mean()
    # fp_scr = fp["prediction_score"].mean()
    # tn_scr = tn["prediction_score"].mean()
    # fn_scr = fn["prediction_score"].mean()

    return len(tp), "0", len(fp), "0", len(tn), "0", len(fn), "0"

# %%
def create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name, hyperparam_str, feature_str, target_str, fi_list):    
    ddb = boto3.resource('dynamodb','us-east-1')
    table = ddb.Table('icarus-models-results-table')
    eval_start = deployment_date
    eval_end = deployment_date + timedelta(days=4)
    try:
        precision = (tp/fp)
    except:
        precision = 0

    ## FILL IN
    item={
        'model_name': model_name,
        'deployment_date': deployment_date.strftime("%Y-%m-%d"),
        'algorithm_type': 'xgboost',
        'dataset': dataset_name,
        'TP': tp,
        'TPpct': Decimal("0"),
        'FP': fp,
        'FPpct': Decimal("0"),
        'TN': tn,
        'TNpct': Decimal("0"),
        'FN': fn,
        'FNpct': Decimal("0"),
        'precision_ratio': Decimal(str(precision)),
        'evaluation_timeperiod': f'{eval_start.strftime("%Y-%m-%d")}_{eval_end.strftime("%Y-%m-%d")}',
        'live': False,
        'hyperparameters': {hyperparam_str},
        'features' : {feature_str},
        'target' : target_str,
        'feature_importances': fi_list

    }

    print(item)
    response = table.put_item(
            Item=item
        )

    return response

# %%
def train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] > target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] > target_value).astype(int)

    # dataset = dataset.round(3)
    # validation_dataset = validation_dataset.round(3)

    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']


    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],
                                  min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],
                                  learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],
                                  colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',
                                  random_state=42)
    xgb_model.fit(X,y)

    print(y.value_counts())
    predictions = xgb_model.predict(X_validate)
    probabilities = xgb_model.predict_proba(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    fi = xgb_model.feature_importances_
    fi_list = []
    counter = 0
    for x in features:
        fi_list.append({x:fi[counter]})
        counter += 1
    print(tp,fp,tn,fn)
    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,str(fi_list), predictions, probabilities


def train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams):
    dataset.loc[:, 'label'] = (dataset[target_label] > target_value).astype(int)
    validation_dataset.loc[:, 'label'] = (validation_dataset[target_label] > target_value).astype(int)

    dataset = dataset.round(5)
    validation_dataset = validation_dataset.round(3)


    X = dataset[features].astype(float)
    y = dataset['label']

    X_validate = validation_dataset[features].astype(float)
    y_validate = validation_dataset['label']
    

    xgb_model = xgb.XGBClassifier(subsample=hyperparams['subsample'],num_round=hyperparams['num_round'],min_child_weight=hyperparams['min_child_weight'],max_depth=hyperparams['max_depth'],learning_rate=hyperparams['learning_rate'],gamma=hyperparams['gamma'],colsample_bytree=hyperparams['colsample_bytree'],verbosity=0,objective='binary:logistic',random_state=42)
    xgb_model.fit(X,y)

    predictions = xgb_model.predict(X_validate)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr = model_results_analyzer(predictions, y_validate, target_value)

    return tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr,"str(fi_list)", predictions, "probabilities"

# %%
# def model_runner_v2RM(model_name, dataset_name, title, features, target_label, target_percentile, start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
#     validation_end_date = build_validation_dates_local(deployment_date)
#     validation_dataset = pull_validation_data_local(validation_end_date,deployment_date)
#     dataset = pull_training_data_local(end_date, dataset_start_date)
#     dates_list = pull_gmm_labels(deployment_date)
#     rm_dataset = dataset.loc[dataset['dt'].isin(dates_list)]
#     target_value = rm_dataset[target_label].quantile(target_percentile).round(3)
#     print(target_value)
#     print(len(rm_dataset)/len(dataset))
#     tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, rm_dataset, validation_dataset, target_label, target_value, hyperparams)
#     response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
#     validation_dataset['probabilities'] = probabilities[:,1]
#     validation_dataset['predictions'] = predictions
#     validation_dataset['target_value'] = target_value
#     validation_dataset['target_pct'] = validation_dataset['target_value'] * validation_dataset['return_vol_10D']
#     validation_csv = validation_dataset.to_csv()
#     put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
#     return response

def model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile, start_date, end_date,deployment_date, feature_str, hyperparams_str, hyperparams,local_data, dataset_start_date):
    validation_end_date = build_validation_dates_local(deployment_date)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date, title)
    dataset = pull_training_data_local(end_date, title)
    target_value = dataset[target_label].quantile(target_percentile).round(3)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    response = create_dynamo_record(tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, model_name, deployment_date, dataset_name,hyperparams_str,feature_str, f"{target_value}+{target_label}", fi_list)
    validation_dataset['probabilities'] = probabilities[:,1]
    validation_dataset['predictions'] = predictions
    validation_dataset['target_value'] = target_value
    validation_dataset['target_pct'] = validation_dataset['target_value'] * validation_dataset['return_vol_10D']
    validation_csv = validation_dataset.to_csv()
    put_response = s3.put_object(Bucket="icarus-research-data", Key=f"backtesting_data/inv_alerts/{dataset_name}/{title}/{deployment_date.strftime('%Y-%m-%d')}.csv", Body=validation_csv)
    return response

def model_runner_temporal_simulation(features, target_label, target_percentile,dataset_start_date,end_date,deployment_date,hyperparams,strategy):
    validation_end_date = build_validation_dates_local(deployment_date)
    dataset = pull_training_data_local(end_date, strategy)
    validation_dataset = pull_validation_data_local(validation_end_date,deployment_date,strategy)
    # dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    # validation_dataset.dropna(subset=["close_diff_deviation3"],inplace=True)
    # dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    # validation_dataset.dropna(subset=["close_diff_deviation"],inplace=True)
    target_value = dataset[target_label].quantile(target_percentile).round(3)
    tp, tp_scr, fp, fp_scr, tn, tn_scr, fn, fn_scr, fi_list, predictions, probabilities = train_model_TSSim(features, dataset, validation_dataset, target_label, target_value, hyperparams)
    return tp, fp, fn, tn 

# def model_runner_data(start_date,end_date):
#     dates = build_date_list(start_date, end_date)
#     key_list = build_query_keys(dates)
#     print(key_list[-1])
#     train_data = create_training_data_local(key_list, 'full_alerts/weekly_exp_alerts/', 'inv-alerts', 'cdvol_gainers', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
#     val_data = create_validation_data_local(key_list, 'full_alerts/trading_symbols_alerts/', 'inv-alerts', 'cdvol_gainers', start_date.strftime('%Y-%m-%d %H:%M:%S'),end_date.strftime('%Y-%m-%d %H:%M:%S'))
#     return "train_data", "val_data"

# %%
def build_evaluation_period(eval_start, eval_end):
    dates_list = []
    while eval_start <= eval_end:
        date_object = {
            "deployment_date": eval_start,
            "dataset_end": eval_start - timedelta(days=10),
            "dataset_start": datetime(2018,1,1)
        }
        dates_list.append(date_object)
        eval_start += timedelta(days=7)
    return dates_list

def pull_gmm_labels(date):
    date_str = date.strftime('%Y-%m-%d')
    data_20d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm20d_labels_RM2/{date_str}.csv')
    data_10d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm10d_labels_RM2/{date_str}.csv')
    data_3d = s3.get_object(Bucket="icarus-research-data", Key=f'regime_modeling_data/gmm3d_labels_RM2/{date_str}.csv')

    data_20d = pd.read_csv(data_20d.get("Body"))
    data_10d = pd.read_csv(data_10d.get("Body"))
    data_3d = pd.read_csv(data_3d.get("Body"))

    data_20d['dt'] = pd.to_datetime(data_20d['date'])
    data_10d['dt'] = pd.to_datetime(data_10d['date'])
    data_3d['dt'] = pd.to_datetime(data_3d['date'])

    label_20d = data_20d['labels'].iloc[-1]
    label_10d = data_10d['labels'].iloc[-1]
    label_3d = data_3d['labels'].iloc[-1]

    dates_20d = data_20d['dt'].loc[data_20d['labels'] == label_20d].tolist()
    dates_10d = data_10d['dt'].loc[data_10d['labels'] == label_10d].tolist()
    dates_3d = data_3d['dt'].loc[data_3d['labels'] == label_3d].tolist()

    combined_list = list(set(dates_20d  + dates_3d))
    return dates_20d

# %%
# target_percentile = 0.6
# title = 'CDBFC'
# model_name = f'{title}:TSSIM2S_PE_custHypTP{target_percentile}'
# dataset_name = f'TSSIM2S_PE_custHypTP{target_percentile}'
# hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
# features = ['price_change_H', 'hour', 'Low-Close', 'rsi_15MA_diff', 'price_change_D', 'volume_sum15_10DMA_diff', 'PrevClose-L', 'return_vol_8H', 
#             'return_vol_10D_diff', 'return_vol_10D', 'rsi_15MA', 'TR', 'DX', 'price_10Ddiff', 'volume_sum15_5DMA_diff', 'High-Close', 'cd_vol3', 
#             'DIminus', 'rsi', 'return_vol_5D_diff', 'bb_spread', 'macd', 'return_vol_8H_diff', 'DMplus', 'volume_15MA_diff', 'day_of_week', 'cmf', 
#             'month', 'H-L', 'SPY_20d_diff', 'cd_vol', 'cmf_15MA', 'High-Low', 'roc5', 'bb_category', 'price_range', 'price_range_8MA_diff', 'macd_15MA', 
#             'macd_15MA_diff', 'price_range_5DMA_diff', 'SPY_5d_diff']

# # target_label = 'one_max_vol'


# # dataset_start_date = datetime(2018,1,1,tzinfo=pytz.timezone('US/Eastern')) 
# # dates_list = build_evaluation_period(datetime(2020,1,6), datetime(2024,4,20))

# # # date = dates_list[-1]
# # # print(date)
# # # response = model_runner_data(start_date=datetime(2018,1,1),end_date=datetime(2023,12,23))

# # # dataset = pull_training_data_local(start_date=datetime(2018,1,1),end_date=datetime(2023,12,23))
# # # print(dataset.columns.tolist())

# # for date in dates_list:
# #     print(date)
# #     response = model_runner_v2(model_name, dataset_name, title, features, target_label, target_percentile,"dataset_start_date",date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams, local_data=True, dataset_start_date=date['dataset_start'])

# %%
def run_temporal_simulation(features, target_label, target_value, dataset_start_date, evaluation_start_date, evaluation_end_date,strategy):
    tp_avg_list = []
    gross_accuracy_list = []
    # fn_list = []
    # tn_list = []
    
    hyperparams = {'subsample': 0.6, 'num_round': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 2, 'colsample_bytree': 1}
    dates_list = build_evaluation_period(evaluation_start_date, evaluation_end_date)
    # date = dates_list[-1]
    # response = model_runner_data(model_name, dataset_name, title, features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], str(features),str(hyperparams), hyperparams)
    for date in dates_list:
        tp, fp, fn, tn = model_runner_temporal_simulation(features, target_label, target_value,dataset_start_date,date['dataset_end'],date['deployment_date'], hyperparams,strategy)
        tp_avg_list.append(tp)
        gross_accuracy_list.append((tp-fp))

    return tp_avg_list, gross_accuracy_list

# %%
number_of_simulations = 75
now = datetime.now()
title = 'CDBFC'
# total_feature_list = ['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'v', 'o', 'c', 'h', 'l',
#  'date', 'hour', 'symbol', 't', 'price7', 'price14', 'adjusted_volume', 'vol7', 'vol14', 'rsi', 
# 'rsi3', 'rsi5', 'roc', 'roc3', 'roc5', 'threeD_returns_close', 'oneD_returns_close', 'range_vol', 
# 'range_vol5MA', 'range_vol10MA', 'range_vol25MA', 'oneD_stddev50', 'threeD_stddev50', 'cmf', 'close_diff', 
# 'close_diff3', 'close_diff5', 'v_diff_pct', 'adx', 'volume_10MA', 'volume_25MA', 'price_10MA', 'price_25MA',
# 'volume_10DDiff', 'volume_25DDiff', 'price_10DDiff', 'price_25DDiff', 'one_max', 'one_min', 'one_pct', 
# 'three_max', 'three_min', 'three_pct', 'SPY_diff', 'SPY_diff3', 'SPY_diff5', 'SPY_1D', 'SPY_3D', 'SPY_5D', 
# 'vw', 'n', 'return_vol_15M', 'volume_vol_15M', 'return_vol_30M', 'volume_vol_30M', 'return_vol_60M', 
# 'volume_vol_60M', 'return_vol_120M', 'volume_vol_120M', 'return_vol_240M', 'volume_vol_240M', 
# 'return_vol_450M', 'volume_vol_450M', '15min_vol_diff', '15min_vol_diff_pct', 'min_vol_diff', 
# 'min_vol_diff_pct', 'min_volume_vol_diff', 'min_volume_vol_diff_pct', 'return_vol_4H', 'return_vol_8H', 
# 'return_vol_16H', 'volume_vol_4H', 'volume_vol_8H', 'volume_vol_16H', 'hour_vol_diff', 'hour_vol_diff_pct', 
# 'hour_volume_vol_diff', 'hour_volume_vol_diff_pct', 'return_vol_3D', 'return_vol_5D', 'return_vol_10D', 
# 'return_vol_30D', 'volume_vol_3D', 'volume_vol_5D', 'volume_vol_10D', 'volume_vol_30D', 'daily_vol_diff', 
# 'daily_vol_diff_pct', 'daily_vol_diff30', 'daily_vol_diff_pct30', 'daily_volume_vol_diff', 'daily_volume_vol_diff_pct', 
# 'daily_volume_vol_diff30', 'daily_volume_vol_diff_pct30', 'cd_vol', 'cd_vol3', 'roc_diff', 'range_vol_diff5', 
# 'close_diff_deviation3', 'close_diff_deviation', 'day_of_week', 'day_of_month', 'month', 'year', 'dt', 'one_max_vol', 
# 'three_max_vol', 'one_min_vol', 'three_min_vol']
testing_features = ['price_change_H', 'cd_vol', 'price_range', 'bb_trend', 'price_range_5DMA_diff', 'roc', 'bb_category', 'bb_spread', 'volume_15MA_diff', 'price_change_D', 'month', 'return_vol_10D', 'PrevClose-L', 'roc3', 'H-L', 'TR', 'volume_sum15', 'return_vol_5D_diff', 'price_3Ddiff', 'roc_15MA', 'macd_15MA_diff', 'rsi_15MA', 'SPY_5d_diff', 'return_vol_8H_diff', 'High-Close', 'DMminus', 'hour', 'return_vol_10D_diff', 'H-PrevClose', 'DMplus', 'DX', 'SPY_range_vol', 'Low-Close', 'price_5Ddiff', 'volume_sum15_10DMA_diff', 'rsi', 'cmf_15MA_diff', 'return_vol_5D', 'price_10Ddiff', 'day_of_week', 'High-Low', 'roc_15MA_diff', 'cmf', 'volume_sum15_5DMA_diff', 'SPY_20d', 'macd_15MA', 'day_of_month', 'adx', 'price_range_8MA_diff', 'cd_vol3', 'DIplus', 'return_vol_8H', 'price_20Ddiff', 'cmf_15MA', 'price_3D20D_diff', 'SPY_5d', 'SPY_20d_diff', 'rsi_15MA_diff', 'macd', 'roc5', 'DIminus']

target_label = 'three_max_vol'
target_percentile = 0.55
results_array = []

i = 0
while i < number_of_simulations:
       model_name = f"{title}_temporal_simulation_{i}"
       print(model_name)
       random_int = random.randint(36, 48)
       features = random.sample(testing_features, random_int)
       print(features)
       tp_avg_list, gross_accuracy_list = run_temporal_simulation(features, target_label, target_percentile, dataset_start_date=datetime(2018,1,1), evaluation_start_date=datetime(2021,1,4), evaluation_end_date=datetime(2024,4,6),strategy=title)        
       tp_avg = sum(tp_avg_list)/len(tp_avg_list)
       gross_accuracy = sum(gross_accuracy_list)/len(gross_accuracy_list)
       print(tp_avg, gross_accuracy)
       print()
       results_array.append({"model_name": model_name, "features": features, "tp_avg": tp_avg, "gross_accuracy": gross_accuracy,"num_features": random_int,"median_tp": np.median(tp_avg_list), "median_gross_accuracy": np.median(gross_accuracy_list)})
       i += 1

results_df = pd.DataFrame(results_array)
results_df.to_csv(f'/Users/charlesmiller/Documents/temporal_simulation_results/{title}/{now.year}_{now.month}_{now.day}.csv', index=False)
# Out:
# CDBFC_temporal_simulation_0
# ['Low-Close', 'DIminus', 'price_3D20D_diff', 'DIplus', 'return_vol_8H', 'DX', 'DMplus', 'price_range_8MA_diff', 'SPY_20d', 'day_of_month', 'hour', 'roc5', 'day_of_week', 'H-L', 'price_3Ddiff', 'SPY_5d', 'DMminus', 'adx', 'PrevClose-L', 'return_vol_5D', 'price_10Ddiff', 'return_vol_10D_diff', 'price_range', 'return_vol_5D_diff', 'return_vol_8H_diff', 'rsi_15MA', 'volume_sum15_5DMA_diff', 'macd', 'volume_15MA_diff', 'roc', 'macd_15MA', 'High-Close', 'price_20Ddiff', 'High-Low', 'roc_15MA_diff', 'price_5Ddiff', 'price_range_5DMA_diff', 'TR', 'rsi_15MA_diff', 'price_change_H', 'SPY_5d_diff', 'cmf', 'macd_15MA_diff', 'cd_vol', 'cd_vol3', 'price_change_D']
# 51.12352941176471 2.135294117647059
#
# CDBFC_temporal_simulation_1
# ['price_10Ddiff', 'rsi_15MA_diff', 'volume_sum15', 'cmf_15MA', 'cmf', 'return_vol_8H_diff', 'roc_15MA', 'Low-Close', 'SPY_5d', 'DIplus', 'price_change_D', 'High-Close', 'rsi', 'H-L', 'price_3D20D_diff', 'bb_spread', 'TR', 'day_of_week', 'SPY_range_vol', 'return_vol_10D', 'month', 'adx', 'roc5', 'volume_sum15_5DMA_diff', 'DMminus', 'SPY_5d_diff', 'DMplus', 'hour', 'price_change_H', 'price_range_5DMA_diff', 'return_vol_10D_diff', 'High-Low', 'price_3Ddiff', 'price_20Ddiff', 'return_vol_8H', 'volume_sum15_10DMA_diff', 'cmf_15MA_diff', 'return_vol_5D_diff', 'roc_15MA_diff', 'DIminus', 'rsi_15MA']
# 52.56470588235294 4.205882352941177
#
# CDBFC_temporal_simulation_2
# ['return_vol_8H_diff', 'roc_15MA', 'SPY_20d', 'cmf', 'SPY_5d_diff', 'day_of_week', 'price_change_H', 'rsi_15MA_diff', 'price_3D20D_diff', 'price_range_5DMA_diff', 'price_10Ddiff', 'return_vol_5D_diff', 'month', 'cmf_15MA_diff', 'PrevClose-L', 'macd_15MA_diff', 'H-L', 'High-Close', 'roc3', 'roc', 'price_5Ddiff', 'High-Low', 'volume_sum15_5DMA_diff', 'H-PrevClose', 'SPY_5d', 'DIplus', 'return_vol_10D_diff', 'price_range_8MA_diff', 'DMplus', 'day_of_month', 'macd', 'SPY_20d_diff', 'DIminus', 'TR', 'SPY_range_vol', 'cd_vol3', 'DMminus', 'macd_15MA', 'price_20Ddiff', 'bb_spread']
# 51.417647058823526 0.8235294117647058
#
# CDBFC_temporal_simulation_3
# ['High-Low', 'cd_vol', 'volume_sum15_10DMA_diff', 'DIminus', 'cd_vol3', 'roc', 'return_vol_10D', 'H-L', 'return_vol_8H', 'return_vol_5D_diff', 'return_vol_5D', 'price_change_H', 'High-Close', 'price_5Ddiff', 'price_3Ddiff', 'day_of_month', 'macd_15MA_diff', 'price_range', 'macd_15MA', 'bb_spread', 'roc5', 'price_change_D', 'adx', 'return_vol_10D_diff', 'Low-Close', 'roc_15MA_diff', 'cmf_15MA', 'month', 'DMplus', 'volume_sum15_5DMA_diff', 'DX', 'macd', 'SPY_5d_diff', 'DMminus', 'volume_sum15', 'price_20Ddiff', 'hour', 'H-PrevClose', 'volume_15MA_diff', 'cmf', 'rsi_15MA_diff', 'DIplus', 'day_of_week']
# 54.03529411764706 5.0588235294117645
#
# CDBFC_temporal_simulation_4
# ['SPY_5d', 'SPY_range_vol', 'volume_sum15_10DMA_diff', 'bb_spread', 'cmf_15MA', 'PrevClose-L', 'High-Close', 'macd_15MA', 'rsi_15MA', 'day_of_week', 'H-PrevClose', 'price_5Ddiff', 'price_range_8MA_diff', 'cd_vol3', 'roc', 'DIminus', 'price_change_H', 'return_vol_8H', 'return_vol_10D_diff', 'return_vol_5D_diff', 'SPY_20d_diff', 'DMplus', 'TR', 'bb_category', 'price_20Ddiff', 'roc5', 'price_3D20D_diff', 'price_3Ddiff', 'macd', 'DX', 'price_change_D', 'roc_15MA', 'volume_15MA_diff', 'month', 'volume_sum15_5DMA_diff', 'Low-Close', 'price_range_5DMA_diff', 'cd_vol', 'roc3', 'DMminus', 'return_vol_8H_diff', 'SPY_5d_diff', 'adx', 'cmf_15MA_diff', 'volume_sum15', 'cmf', 'return_vol_10D']
# 54.411764705882355 3.5470588235294116
#
# CDBFC_temporal_simulation_5
# ['DIminus', 'H-L', 'bb_trend', 'price_5Ddiff', 'DMminus', 'H-PrevClose', 'Low-Close', 'macd', 'High-Close', 'price_20Ddiff', 'TR', 'macd_15MA_diff', 'macd_15MA', 'SPY_20d_diff', 'month', 'rsi', 'PrevClose-L', 'return_vol_8H', 'DX', 'DIplus', 'roc_15MA', 'cmf_15MA', 'return_vol_8H_diff', 'bb_category', 'bb_spread', 'SPY_5d_diff', 'cmf', 'price_range_8MA_diff', 'price_change_D', 'price_3Ddiff', 'day_of_month', 'cd_vol', 'price_change_H', 'price_3D20D_diff', 'SPY_range_vol', 'day_of_week', 'High-Low', 'SPY_5d', 'return_vol_10D', 'roc5', 'SPY_20d', 'return_vol_5D_diff']
# 52.27058823529412 5.176470588235294
#
# CDBFC_temporal_simulation_6
# ['DMminus', 'return_vol_8H', 'bb_category', 'return_vol_5D', 'cmf_15MA', 'cmf_15MA_diff', 'bb_spread', 'month', 'volume_sum15', 'High-Close', 'DIplus', 'adx', 'High-Low', 'return_vol_5D_diff', 'hour', 'price_change_H', 'roc3', 'volume_15MA_diff', 'rsi', 'SPY_20d', 'volume_sum15_10DMA_diff', 'return_vol_10D', 'price_3D20D_diff', 'return_vol_10D_diff', 'price_5Ddiff', 'price_range', 'SPY_20d_diff', 'price_range_8MA_diff', 'rsi_15MA', 'cd_vol', 'cmf', 'DMplus', 'H-L', 'PrevClose-L', 'roc_15MA', 'SPY_range_vol', 'cd_vol3', 'Low-Close', 'macd_15MA_diff']
# 50.04705882352941 1.3470588235294119
#
# CDBFC_temporal_simulation_7
# ['bb_spread', 'macd_15MA', 'DIplus', 'adx', 'price_range_5DMA_diff', 'price_20Ddiff', 'macd_15MA_diff', 'day_of_month', 'roc_15MA', 'DIminus', 'roc_15MA_diff', 'SPY_20d', 'macd', 'cmf_15MA', 'return_vol_5D', 'cd_vol', 'price_3D20D_diff', 'price_change_D', 'month', 'cmf', 'SPY_range_vol', 'hour', 'SPY_5d_diff', 'High-Close', 'DMminus', 'volume_sum15_10DMA_diff', 'Low-Close', 'H-L', 'price_change_H', 'PrevClose-L', 'rsi_15MA_diff', 'price_5Ddiff', 'price_range', 'return_vol_5D_diff', 'day_of_week', 'High-Low']
# 50.36470588235294 0.28823529411764703
#
# CDBFC_temporal_simulation_8
# ['bb_category', 'volume_sum15_10DMA_diff', 'High-Close', 'High-Low', 'macd', 'day_of_month', 'SPY_20d', 'roc3', 'return_vol_10D', 'DX', 'H-PrevClose', 'roc_15MA_diff', 'Low-Close', 'cd_vol3', 'DMminus', 'macd_15MA', 'price_range_8MA_diff', 'adx', 'cmf_15MA_diff', 'price_3Ddiff', 'SPY_5d', 'H-L', 'macd_15MA_diff', 'month', 'volume_sum15', 'return_vol_8H_diff', 'rsi_15MA', 'price_range_5DMA_diff', 'price_change_H', 'price_5Ddiff', 'cmf', 'day_of_week', 'return_vol_8H', 'price_10Ddiff', 'rsi', 'price_range', 'roc_15MA', 'cd_vol', 'SPY_range_vol', 'TR', 'bb_trend', 'bb_spread', 'PrevClose-L']
# 51.68235294117647 3.211764705882353
#
# CDBFC_temporal_simulation_9
# ['cd_vol3', 'rsi_15MA', 'DIminus', 'DX', 'return_vol_8H_diff', 'return_vol_8H', 'DMplus', 'adx', 'SPY_20d', 'roc5', 'bb_spread', 'volume_sum15_10DMA_diff', 'macd_15MA', 'Low-Close', 'roc', 'day_of_month', 'macd', 'roc_15MA', 'macd_15MA_diff', 'H-PrevClose', 'return_vol_5D_diff', 'return_vol_10D_diff', 'bb_category', 'price_range_8MA_diff', 'price_5Ddiff', 'rsi', 'bb_trend', 'price_range', 'TR', 'return_vol_5D', 'H-L', 'price_20Ddiff', 'SPY_5d_diff', 'price_range_5DMA_diff', 'price_change_H', 'SPY_20d_diff', 'price_10Ddiff', 'day_of_week', 'DMminus', 'cd_vol', 'hour', 'SPY_range_vol', 'cmf', 'price_3D20D_diff', 'return_vol_10D', 'volume_15MA_diff']
# 53.81764705882353 6.364705882352941
#
# CDBFC_temporal_simulation_10
# ['macd_15MA_diff', 'return_vol_5D_diff', 'price_range_5DMA_diff', 'price_3Ddiff', 'rsi', 'cmf_15MA', 'return_vol_8H', 'SPY_5d', 'price_10Ddiff', 'roc_15MA', 'macd', 'price_change_H', 'cmf', 'DIminus', 'Low-Close', 'volume_sum15_5DMA_diff', 'price_range_8MA_diff', 'bb_category', 'month', 'volume_15MA_diff', 'roc5', 'return_vol_5D', 'cmf_15MA_diff', 'DMplus', 'rsi_15MA', 'day_of_month', 'SPY_5d_diff', 'roc3', 'cd_vol3', 'return_vol_10D', 'price_range', 'SPY_range_vol', 'DX', 'return_vol_10D_diff', 'H-PrevClose', 'High-Close', 'volume_sum15', 'price_3D20D_diff', 'DIplus', 'bb_spread', 'TR', 'SPY_20d', 'price_5Ddiff', 'bb_trend']
# 52.741176470588236 4.035294117647059
#
# CDBFC_temporal_simulation_11
# ['DMplus', 'price_3Ddiff', 'return_vol_5D', 'Low-Close', 'High-Close', 'return_vol_8H', 'SPY_20d_diff', 'roc3', 'adx', 'return_vol_10D', 'volume_sum15', 'price_range_8MA_diff', 'hour', 'volume_sum15_5DMA_diff', 'macd_15MA_diff', 'macd_15MA', 'cmf_15MA', 'cd_vol3', 'SPY_20d', 'return_vol_5D_diff', 'SPY_range_vol', 'DX', 'volume_15MA_diff', 'rsi', 'macd', 'price_range', 'roc5', 'volume_sum15_10DMA_diff', 'price_change_H', 'month', 'price_3D20D_diff', 'PrevClose-L', 'price_20Ddiff', 'DIminus', 'DMminus', 'bb_trend', 'roc', 'roc_15MA_diff', 'SPY_5d', 'bb_spread', 'rsi_15MA']
# 51.64705882352941 0.47058823529411764
#
# CDBFC_temporal_simulation_12
# ['High-Close', 'price_change_H', 'Low-Close', 'roc3', 'volume_sum15_10DMA_diff', 'H-PrevClose', 'volume_sum15_5DMA_diff', 'cd_vol3', 'price_5Ddiff', 'volume_sum15', 'DIminus', 'DMplus', 'macd_15MA_diff', 'roc5', 'bb_spread', 'return_vol_5D_diff', 'price_20Ddiff', 'roc', 'SPY_range_vol', 'H-L', 'cmf_15MA_diff', 'volume_15MA_diff', 'hour', 'bb_category', 'price_range_8MA_diff', 'macd_15MA', 'roc_15MA', 'DX', 'price_3D20D_diff', 'return_vol_8H_diff', 'cmf_15MA', 'price_10Ddiff', 'return_vol_10D', 'SPY_20d', 'PrevClose-L', 'day_of_month', 'return_vol_10D_diff', 'SPY_5d_diff', 'price_range', 'return_vol_5D', 'roc_15MA_diff']
# 52.63529411764706 5.594117647058823
#
# CDBFC_temporal_simulation_13
# ['roc_15MA_diff', 'High-Close', 'price_change_D', 'SPY_5d', 'bb_spread', 'cmf_15MA_diff', 'rsi_15MA_diff', 'DIminus', 'roc', 'bb_trend', 'roc5', 'return_vol_8H', 'roc_15MA', 'Low-Close', 'rsi', 'return_vol_5D', 'macd_15MA', 'SPY_range_vol', 'price_5Ddiff', 'price_3D20D_diff', 'H-L', 'SPY_20d_diff', 'cd_vol3', 'volume_sum15_5DMA_diff', 'bb_category', 'roc3', 'volume_sum15_10DMA_diff', 'return_vol_5D_diff', 'TR', 'price_range', 'DMminus', 'cmf', 'price_3Ddiff', 'DMplus', 'day_of_week', 'volume_sum15', 'rsi_15MA', 'volume_15MA_diff', 'DX', 'return_vol_10D_diff', 'month', 'High-Low', 'return_vol_10D', 'PrevClose-L', 'SPY_5d_diff', 'return_vol_8H_diff']
# 54.023529411764706 3.3294117647058825
#
# CDBFC_temporal_simulation_14
# ['SPY_20d_diff', 'hour', 'month', 'volume_15MA_diff', 'return_vol_8H', 'price_10Ddiff', 'roc_15MA', 'cmf', 'volume_sum15_10DMA_diff', 'volume_sum15_5DMA_diff', 'volume_sum15', 'return_vol_10D', 'price_3D20D_diff', 'rsi_15MA', 'adx', 'macd', 'TR', 'return_vol_10D_diff', 'bb_category', 'H-L', 'price_5Ddiff', 'SPY_20d', 'return_vol_5D_diff', 'price_change_H', 'DMplus', 'return_vol_5D', 'DMminus', 'cd_vol3', 'price_change_D', 'macd_15MA', 'roc_15MA_diff', 'day_of_month', 'macd_15MA_diff', 'SPY_5d', 'DIplus', 'rsi_15MA_diff', 'bb_trend', 'roc3', 'cd_vol', 'High-Low', 'price_range_8MA_diff', 'rsi']
# 53.46470588235294 3.8705882352941177
#
# CDBFC_temporal_simulation_15
# ['price_5Ddiff', 'DMplus', 'High-Close', 'macd', 'price_3D20D_diff', 'price_range_5DMA_diff', 'price_change_H', 'DIminus', 'roc5', 'rsi', 'SPY_5d', 'PrevClose-L', 'SPY_range_vol', 'bb_trend', 'return_vol_8H', 'rsi_15MA', 'price_change_D', 'DMminus', 'hour', 'price_20Ddiff', 'return_vol_10D_diff', 'cd_vol3', 'High-Low', 'cmf', 'DX', 'volume_15MA_diff', 'roc_15MA_diff', 'roc', 'day_of_month', 'month', 'TR', 'Low-Close', 'price_3Ddiff', 'roc3', 'DIplus', 'return_vol_8H_diff', 'price_range_8MA_diff']
# 54.63529411764706 3.8
#
# CDBFC_temporal_simulation_16
# ['DIminus', 'bb_trend', 'roc5', 'adx', 'price_range_5DMA_diff', 'rsi_15MA_diff', 'H-PrevClose', 'SPY_5d_diff', 'return_vol_5D', 'roc_15MA', 'H-L', 'cmf', 'price_range', 'day_of_month', 'bb_spread', 'hour', 'rsi_15MA', 'price_10Ddiff', 'macd_15MA_diff', 'volume_15MA_diff', 'cd_vol3', 'return_vol_5D_diff', 'roc3', 'price_range_8MA_diff', 'SPY_range_vol', 'SPY_20d_diff', 'macd', 'return_vol_8H_diff', 'month', 'High-Close', 'price_20Ddiff', 'DX', 'day_of_week', 'DMminus', 'price_3D20D_diff', 'SPY_5d', 'return_vol_10D', 'volume_sum15_10DMA_diff', 'TR', 'price_5Ddiff', 'volume_sum15_5DMA_diff', 'roc', 'DIplus', 'cmf_15MA_diff', 'rsi', 'cd_vol', 'volume_sum15']
# 56.082352941176474 6.017647058823529
#
# CDBFC_temporal_simulation_17
# ['TR', 'SPY_20d_diff', 'price_3D20D_diff', 'rsi', 'roc_15MA_diff', 'return_vol_10D', 'price_change_H', 'volume_sum15', 'price_range', 'adx', 'SPY_5d', 'DMminus', 'DIminus', 'day_of_month', 'macd_15MA_diff', 'DMplus', 'rsi_15MA_diff', 'DX', 'roc5', 'return_vol_10D_diff', 'bb_spread', 'price_range_8MA_diff', 'roc3', 'cmf_15MA', 'price_3Ddiff', 'H-PrevClose', 'day_of_week', 'volume_15MA_diff', 'Low-Close', 'cd_vol', 'SPY_range_vol', 'cmf_15MA_diff', 'volume_sum15_10DMA_diff', 'roc_15MA', 'price_change_D', 'High-Low', 'price_10Ddiff', 'bb_trend', 'macd', 'bb_category', 'PrevClose-L']
# 52.10588235294118 5.017647058823529
#
# CDBFC_temporal_simulation_18
# ['roc_15MA_diff', 'roc', 'price_range_5DMA_diff', 'PrevClose-L', 'SPY_5d_diff', 'price_3Ddiff', 'price_3D20D_diff', 'DMplus', 'TR', 'rsi', 'return_vol_5D', 'return_vol_5D_diff', 'hour', 'rsi_15MA_diff', 'roc5', 'return_vol_8H_diff', 'adx', 'H-PrevClose', 'cmf_15MA', 'cd_vol3', 'price_10Ddiff', 'price_change_D', 'price_20Ddiff', 'roc_15MA', 'volume_sum15_5DMA_diff', 'return_vol_8H', 'price_change_H', 'bb_category', 'rsi_15MA', 'volume_sum15', 'return_vol_10D_diff', 'macd_15MA_diff', 'SPY_5d', 'SPY_20d', 'day_of_week', 'day_of_month', 'High-Close', 'macd_15MA', 'DMminus', 'Low-Close', 'DIplus', 'cmf_15MA_diff', 'price_range_8MA_diff', 'roc3', 'DIminus', 'bb_spread', 'price_5Ddiff', 'SPY_20d_diff']
# 49.188235294117646 3.6058823529411765
#
# CDBFC_temporal_simulation_19
# ['price_range_5DMA_diff', 'cmf', 'DIminus', 'roc_15MA_diff', 'DMminus', 'return_vol_5D_diff', 'return_vol_8H', 'price_3Ddiff', 'return_vol_10D', 'rsi_15MA_diff', 'hour', 'return_vol_8H_diff', 'bb_trend', 'price_change_D', 'roc_15MA', 'H-L', 'price_10Ddiff', 'cmf_15MA_diff', 'cmf_15MA', 'day_of_month', 'SPY_5d', 'bb_spread', 'price_change_H', 'day_of_week', 'cd_vol', 'month', 'Low-Close', 'roc', 'price_range', 'DX', 'SPY_range_vol', 'SPY_20d', 'price_5Ddiff', 'macd_15MA_diff', 'volume_15MA_diff', 'DMplus', 'return_vol_10D_diff', 'rsi']
# 52.14705882352941 2.2705882352941176
#
# CDBFC_temporal_simulation_20
# ['volume_15MA_diff', 'volume_sum15_5DMA_diff', 'return_vol_10D', 'High-Low', 'DX', 'DIplus', 'macd', 'day_of_month', 'SPY_5d', 'cd_vol3', 'cd_vol', 'price_3Ddiff', 'PrevClose-L', 'price_range', 'return_vol_5D', 'volume_sum15_10DMA_diff', 'roc5', 'price_3D20D_diff', 'H-PrevClose', 'DIminus', 'return_vol_8H', 'Low-Close', 'price_range_5DMA_diff', 'DMplus', 'month', 'rsi_15MA', 'TR', 'price_10Ddiff', 'rsi', 'return_vol_8H_diff', 'cmf_15MA', 'H-L', 'DMminus', 'SPY_5d_diff', 'cmf_15MA_diff', 'SPY_20d_diff', 'roc3', 'roc_15MA', 'price_change_D', 'macd_15MA', 'price_5Ddiff', 'price_change_H', 'SPY_20d']
# 53.46470588235294 2.411764705882353
#
# CDBFC_temporal_simulation_21
# ['month', 'Low-Close', 'price_range_5DMA_diff', 'bb_spread', 'roc3', 'High-Close', 'return_vol_10D_diff', 'SPY_20d', 'SPY_5d', 'roc', 'cmf_15MA_diff', 'price_3Ddiff', 'price_range', 'roc_15MA', 'price_3D20D_diff', 'DIplus', 'SPY_20d_diff', 'SPY_5d_diff', 'cmf', 'day_of_week', 'return_vol_8H_diff', 'H-PrevClose', 'DX', 'rsi_15MA_diff', 'price_5Ddiff', 'price_change_H', 'volume_sum15_5DMA_diff', 'day_of_month', 'High-Low', 'DMminus', 'volume_sum15_10DMA_diff', 'price_change_D', 'PrevClose-L', 'bb_category', 'H-L', 'return_vol_5D_diff']
# 51.35294117647059 1.7176470588235293
#
# CDBFC_temporal_simulation_22
# ['price_3Ddiff', 'adx', 'H-PrevClose', 'DX', 'bb_trend', 'cd_vol3', 'rsi_15MA', 'return_vol_10D_diff', 'TR', 'DMminus', 'roc5', 'volume_sum15_5DMA_diff', 'SPY_5d_diff', 'day_of_week', 'volume_sum15_10DMA_diff', 'month', 'volume_15MA_diff', 'High-Low', 'macd_15MA_diff', 'volume_sum15', 'DIplus', 'price_20Ddiff', 'roc_15MA', 'H-L', 'Low-Close', 'roc', 'SPY_range_vol', 'return_vol_5D_diff', 'roc_15MA_diff', 'PrevClose-L', 'return_vol_10D', 'return_vol_8H', 'macd_15MA', 'price_change_H', 'SPY_20d', 'cmf_15MA', 'DIminus', 'bb_spread', 'DMplus']
# 51.476470588235294 1.6470588235294117
#
# CDBFC_temporal_simulation_23
# ['DIplus', 'volume_15MA_diff', 'day_of_week', 'H-PrevClose', 'SPY_5d', 'price_range_5DMA_diff', 'SPY_20d_diff', 'High-Close', 'roc3', 'volume_sum15_5DMA_diff', 'DMplus', 'return_vol_8H', 'bb_spread', 'cmf', 'DX', 'macd', 'SPY_20d', 'volume_sum15_10DMA_diff', 'SPY_range_vol', 'price_10Ddiff', 'bb_category', 'hour', 'H-L', 'DIminus', 'adx', 'month', 'price_change_H', 'TR', 'return_vol_10D', 'SPY_5d_diff', 'price_5Ddiff', 'DMminus', 'PrevClose-L', 'roc_15MA', 'rsi', 'day_of_month', 'cmf_15MA_diff', 'price_20Ddiff', 'volume_sum15', 'return_vol_8H_diff', 'roc_15MA_diff', 'bb_trend', 'cd_vol', 'cmf_15MA', 'cd_vol3', 'High-Low', 'rsi_15MA_diff', 'macd_15MA_diff']
# 52.78823529411765 2.8294117647058825
#
# CDBFC_temporal_simulation_24
# ['SPY_20d_diff', 'volume_sum15_5DMA_diff', 'roc3', 'day_of_month', 'volume_sum15_10DMA_diff', 'bb_category', 'price_change_H', 'return_vol_8H', 'price_range_5DMA_diff', 'day_of_week', 'DMminus', 'DMplus', 'rsi_15MA', 'volume_15MA_diff', 'Low-Close', 'High-Close', 'macd_15MA_diff', 'price_20Ddiff', 'macd_15MA', 'rsi', 'cmf_15MA', 'roc_15MA', 'adx', 'TR', 'DIminus', 'return_vol_5D_diff', 'price_change_D', 'roc', 'return_vol_8H_diff', 'price_3D20D_diff', 'price_10Ddiff', 'SPY_5d_diff', 'DIplus', 'bb_trend', 'roc_15MA_diff', 'DX', 'bb_spread', 'H-PrevClose', 'H-L', 'price_range_8MA_diff', 'PrevClose-L', 'cmf', 'roc5', 'volume_sum15', 'price_5Ddiff', 'hour']
# 50.88823529411765 4.5588235294117645
#
# CDBFC_temporal_simulation_25
# ['Low-Close', 'DX', 'H-L', 'price_change_H', 'volume_sum15', 'price_20Ddiff', 'return_vol_5D_diff', 'cd_vol3', 'bb_spread', 'macd', 'cmf_15MA', 'macd_15MA_diff', 'return_vol_8H', 'volume_sum15_5DMA_diff', 'High-Close', 'price_range', 'volume_15MA_diff', 'price_3D20D_diff', 'DIplus', 'bb_trend', 'day_of_week', 'TR', 'price_range_5DMA_diff', 'volume_sum15_10DMA_diff', 'roc', 'SPY_20d_diff', 'price_change_D', 'price_10Ddiff', 'rsi_15MA_diff', 'DIminus', 'High-Low', 'rsi', 'SPY_5d_diff', 'SPY_20d', 'return_vol_10D_diff', 'roc5', 'DMminus', 'return_vol_8H_diff']
# 49.6 2.0
#
# CDBFC_temporal_simulation_26
# ['SPY_range_vol', 'price_10Ddiff', 'Low-Close', 'return_vol_8H', 'return_vol_8H_diff', 'bb_category', 'DIminus', 'roc5', 'cmf_15MA_diff', 'hour', 'SPY_5d', 'price_change_H', 'price_change_D', 'rsi_15MA_diff', 'cd_vol', 'roc3', 'price_range_5DMA_diff', 'DX', 'rsi', 'High-Close', 'macd_15MA', 'day_of_month', 'DIplus', 'H-PrevClose', 'cmf_15MA', 'price_20Ddiff', 'price_5Ddiff', 'volume_sum15', 'rsi_15MA', 'month', 'bb_spread', 'PrevClose-L', 'DMplus', 'H-L', 'day_of_week', 'roc_15MA', 'price_range', 'SPY_20d_diff', 'roc_15MA_diff', 'High-Low', 'volume_sum15_5DMA_diff', 'return_vol_10D_diff', 'return_vol_5D', 'macd', 'return_vol_5D_diff', 'volume_15MA_diff', 'price_3D20D_diff', 'TR']
# 52.8235294117647 2.3
#
# CDBFC_temporal_simulation_27
# ['price_change_D', 'day_of_week', 'return_vol_5D', 'DMplus', 'price_5Ddiff', 'roc5', 'volume_sum15_5DMA_diff', 'H-L', 'return_vol_8H', 'cmf', 'cmf_15MA_diff', 'DIplus', 'SPY_5d', 'DIminus', 'return_vol_8H_diff', 'bb_spread', 'price_3D20D_diff', 'price_10Ddiff', 'DX', 'day_of_month', 'rsi_15MA_diff', 'month', 'roc_15MA_diff', 'cd_vol3', 'roc3', 'price_range', 'cd_vol', 'macd_15MA', 'price_20Ddiff', 'volume_sum15', 'TR', 'bb_trend', 'price_change_H', 'price_range_5DMA_diff', 'hour', 'macd', 'roc_15MA', 'SPY_range_vol', 'PrevClose-L', 'Low-Close', 'DMminus', 'return_vol_10D_diff', 'adx', 'High-Close', 'rsi_15MA', 'price_range_8MA_diff']
# 51.85294117647059 2.4235294117647057
#
# CDBFC_temporal_simulation_28
# ['rsi_15MA', 'return_vol_10D', 'rsi_15MA_diff', 'SPY_5d', 'SPY_20d_diff', 'bb_category', 'TR', 'price_5Ddiff', 'price_10Ddiff', 'return_vol_8H', 'price_range_5DMA_diff', 'roc_15MA_diff', 'bb_trend', 'DIplus', 'volume_sum15_10DMA_diff', 'volume_sum15_5DMA_diff', 'H-L', 'price_change_H', 'price_range', 'PrevClose-L', 'High-Low', 'Low-Close', 'price_change_D', 'SPY_range_vol', 'DMminus', 'bb_spread', 'SPY_20d', 'SPY_5d_diff', 'High-Close', 'return_vol_10D_diff', 'return_vol_8H_diff', 'price_3Ddiff', 'H-PrevClose', 'return_vol_5D', 'price_3D20D_diff', 'volume_15MA_diff', 'cmf_15MA', 'DIminus', 'cmf', 'month', 'price_range_8MA_diff', 'day_of_week', 'hour', 'volume_sum15', 'adx']
# 53.59411764705882 2.9352941176470586
#
# CDBFC_temporal_simulation_29
# ['day_of_week', 'volume_15MA_diff', 'macd_15MA', 'adx', 'price_range', 'macd_15MA_diff', 'H-L', 'price_3D20D_diff', 'bb_category', 'price_change_D', 'cd_vol', 'roc_15MA_diff', 'SPY_5d_diff', 'volume_sum15_10DMA_diff', 'roc3', 'SPY_5d', 'rsi', 'return_vol_8H', 'TR', 'return_vol_10D', 'roc5', 'volume_sum15', 'DIminus', 'volume_sum15_5DMA_diff', 'cmf_15MA', 'price_range_5DMA_diff', 'SPY_20d', 'price_change_H', 'price_5Ddiff', 'Low-Close', 'return_vol_8H_diff', 'bb_trend', 'H-PrevClose', 'High-Close', 'rsi_15MA_diff', 'price_10Ddiff', 'High-Low', 'roc', 'DMminus', 'DX']
# 51.747058823529414 1.9941176470588236
#
# CDBFC_temporal_simulation_30
# ['SPY_20d', 'volume_sum15_10DMA_diff', 'return_vol_5D_diff', 'day_of_month', 'roc', 'return_vol_8H_diff', 'High-Low', 'macd', 'rsi', 'price_10Ddiff', 'volume_15MA_diff', 'rsi_15MA', 'volume_sum15_5DMA_diff', 'adx', 'price_range', 'roc_15MA_diff', 'price_5Ddiff', 'SPY_20d_diff', 'volume_sum15', 'price_3Ddiff', 'roc5', 'DIplus', 'bb_spread', 'bb_category', 'Low-Close', 'price_3D20D_diff', 'SPY_5d', 'price_range_8MA_diff', 'day_of_week', 'return_vol_10D_diff', 'High-Close', 'cmf_15MA_diff', 'SPY_range_vol', 'TR', 'DMminus', 'rsi_15MA_diff', 'PrevClose-L', 'bb_trend', 'hour', 'cmf_15MA', 'cmf', 'H-PrevClose', 'price_20Ddiff', 'cd_vol', 'macd_15MA_diff']
# 48.12352941176471 2.3588235294117648
#
# CDBFC_temporal_simulation_31
# ['roc3', 'volume_15MA_diff', 'price_5Ddiff', 'DMminus', 'return_vol_5D_diff', 'SPY_range_vol', 'SPY_20d', 'rsi_15MA_diff', 'roc_15MA', 'month', 'price_range_8MA_diff', 'bb_category', 'H-L', 'High-Low', 'price_change_D', 'DIplus', 'PrevClose-L', 'macd_15MA', 'rsi_15MA', 'cd_vol', 'volume_sum15_10DMA_diff', 'return_vol_8H_diff', 'DIminus', 'price_range_5DMA_diff', 'price_change_H', 'TR', 'return_vol_10D', 'bb_spread', 'SPY_5d_diff', 'hour', 'price_range', 'price_3Ddiff', 'adx', 'SPY_20d_diff', 'volume_sum15_5DMA_diff', 'price_3D20D_diff', 'Low-Close', 'price_10Ddiff', 'macd', 'bb_trend', 'roc', 'return_vol_5D']
# 53.93529411764706 1.9352941176470588
#
# CDBFC_temporal_simulation_32
# ['price_10Ddiff', 'price_range_5DMA_diff', 'return_vol_8H_diff', 'High-Close', 'TR', 'macd_15MA', 'roc_15MA', 'DX', 'price_20Ddiff', 'roc', 'return_vol_5D_diff', 'H-PrevClose', 'price_change_H', 'SPY_range_vol', 'volume_15MA_diff', 'price_range_8MA_diff', 'adx', 'DMminus', 'rsi', 'roc5', 'SPY_5d_diff', 'price_5Ddiff', 'H-L', 'day_of_month', 'macd', 'cmf_15MA', 'SPY_20d_diff', 'month', 'day_of_week', 'roc3', 'cd_vol', 'DIminus', 'return_vol_8H', 'cmf', 'price_3D20D_diff', 'volume_sum15_5DMA_diff', 'bb_category', 'cd_vol3', 'SPY_20d', 'bb_spread', 'macd_15MA_diff', 'return_vol_5D', 'DIplus', 'price_range', 'hour', 'roc_15MA_diff', 'return_vol_10D']
# 52.84117647058824 3.7941176470588234
#
# CDBFC_temporal_simulation_33
# ['price_3D20D_diff', 'macd_15MA_diff', 'rsi_15MA_diff', 'return_vol_10D', 'SPY_5d', 'DIplus', 'return_vol_8H_diff', 'price_change_H', 'return_vol_5D_diff', 'volume_sum15_5DMA_diff', 'SPY_20d_diff', 'price_range_5DMA_diff', 'return_vol_5D', 'price_change_D', 'adx', 'rsi', 'price_5Ddiff', 'H-PrevClose', 'price_3Ddiff', 'cd_vol', 'High-Low', 'rsi_15MA', 'volume_sum15', 'SPY_20d', 'price_range', 'roc3', 'day_of_month', 'roc', 'price_20Ddiff', 'TR', 'SPY_5d_diff', 'month', 'H-L', 'DMminus', 'return_vol_10D_diff', 'roc_15MA', 'volume_sum15_10DMA_diff', 'bb_trend', 'bb_spread']
# 51.970588235294116 1.6941176470588235
#
# CDBFC_temporal_simulation_34
# ['price_5Ddiff', 'price_3D20D_diff', 'price_range', 'volume_sum15_10DMA_diff', 'return_vol_8H', 'return_vol_10D_diff', 'day_of_month', 'price_20Ddiff', 'SPY_20d', 'bb_category', 'price_change_D', 'price_range_5DMA_diff', 'return_vol_10D', 'cd_vol', 'macd', 'volume_sum15_5DMA_diff', 'adx', 'rsi', 'roc_15MA', 'DIminus', 'return_vol_5D_diff', 'SPY_20d_diff', 'cmf', 'month', 'DMminus', 'SPY_range_vol', 'SPY_5d', 'price_range_8MA_diff', 'return_vol_8H_diff', 'hour', 'price_3Ddiff', 'volume_15MA_diff', 'return_vol_5D', 'H-PrevClose', 'macd_15MA', 'cmf_15MA', 'Low-Close']
# 51.76470588235294 3.7823529411764705
#
# CDBFC_temporal_simulation_35
# ['return_vol_10D', 'SPY_range_vol', 'DX', 'volume_sum15_10DMA_diff', 'price_3Ddiff', 'TR', 'bb_category', 'DIplus', 'High-Close', 'cmf_15MA_diff', 'roc_15MA_diff', 'bb_spread', 'rsi_15MA', 'cd_vol', 'rsi', 'price_change_H', 'SPY_5d_diff', 'return_vol_10D_diff', 'macd_15MA_diff', 'month', 'return_vol_8H', 'roc3', 'cd_vol3', 'price_20Ddiff', 'price_3D20D_diff', 'price_5Ddiff', 'H-L', 'DMplus', 'roc_15MA', 'price_range_8MA_diff', 'volume_15MA_diff', 'SPY_20d', 'price_range', 'High-Low', 'rsi_15MA_diff', 'cmf', 'volume_sum15', 'roc5', 'price_range_5DMA_diff']
# 52.04117647058823 3.0294117647058822
#
# CDBFC_temporal_simulation_36
# ['day_of_week', 'SPY_5d_diff', 'price_20Ddiff', 'SPY_20d_diff', 'price_change_H', 'volume_sum15', 'High-Low', 'cmf', 'Low-Close', 'return_vol_5D', 'return_vol_8H_diff', 'SPY_range_vol', 'volume_sum15_5DMA_diff', 'price_range_8MA_diff', 'adx', 'macd_15MA', 'price_change_D', 'volume_sum15_10DMA_diff', 'cd_vol3', 'roc_15MA', 'price_3Ddiff', 'price_3D20D_diff', 'roc', 'bb_trend', 'cmf_15MA', 'rsi_15MA', 'cd_vol', 'SPY_20d', 'return_vol_10D', 'DIplus', 'TR', 'price_range', 'return_vol_5D_diff', 'return_vol_8H', 'rsi', 'DMminus', 'PrevClose-L', 'SPY_5d', 'price_10Ddiff', 'cmf_15MA_diff', 'return_vol_10D_diff', 'DIminus', 'volume_15MA_diff', 'bb_category', 'day_of_month', 'High-Close', 'DX', 'month']
# 51.86470588235294 5.052941176470588
#
# CDBFC_temporal_simulation_37
# ['month', 'return_vol_8H', 'return_vol_5D', 'macd_15MA', 'SPY_5d', 'DIplus', 'DMplus', 'SPY_20d_diff', 'return_vol_10D_diff', 'bb_trend', 'volume_sum15_10DMA_diff', 'price_range', 'roc3', 'return_vol_5D_diff', 'price_20Ddiff', 'PrevClose-L', 'TR', 'volume_15MA_diff', 'return_vol_10D', 'roc_15MA_diff', 'price_5Ddiff', 'cmf_15MA_diff', 'volume_sum15_5DMA_diff', 'return_vol_8H_diff', 'hour', 'H-PrevClose', 'day_of_month', 'High-Low', 'rsi_15MA', 'cd_vol3', 'High-Close', 'price_3D20D_diff', 'cmf_15MA', 'bb_spread', 'cd_vol', 'price_10Ddiff', 'roc', 'adx', 'price_change_H', 'cmf', 'DX', 'price_range_8MA_diff', 'rsi', 'H-L', 'DIminus', 'day_of_week', 'bb_category', 'volume_sum15']
# 52.8235294117647 4.788235294117647
#
# CDBFC_temporal_simulation_38
# ['volume_15MA_diff', 'bb_trend', 'bb_spread', 'price_change_D', 'roc_15MA_diff', 'DX', 'cmf_15MA', 'cmf', 'TR', 'return_vol_10D_diff', 'SPY_20d', 'macd_15MA', 'price_range', 'month', 'price_10Ddiff', 'SPY_5d', 'Low-Close', 'H-L', 'rsi_15MA', 'SPY_20d_diff', 'price_range_5DMA_diff', 'price_3Ddiff', 'return_vol_5D', 'High-Close', 'rsi_15MA_diff', 'roc5', 'DIplus', 'price_change_H', 'SPY_range_vol', 'volume_sum15_10DMA_diff', 'roc', 'price_3D20D_diff', 'DMminus', 'return_vol_8H_diff', 'day_of_week', 'price_range_8MA_diff', 'return_vol_10D', 'cd_vol', 'DMplus', 'volume_sum15']
# 54.40588235294118 3.4352941176470586
#
# CDBFC_temporal_simulation_39
# ['month', 'price_range', 'rsi', 'day_of_week', 'macd_15MA', 'return_vol_8H_diff', 'rsi_15MA_diff', 'roc_15MA', 'roc', 'return_vol_10D_diff', 'price_change_H', 'price_3Ddiff', 'volume_sum15', 'bb_category', 'Low-Close', 'day_of_month', 'cd_vol3', 'volume_sum15_5DMA_diff', 'price_range_5DMA_diff', 'DIplus', 'SPY_5d_diff', 'DMminus', 'price_range_8MA_diff', 'High-Close', 'return_vol_5D', 'return_vol_8H', 'roc5', 'hour', 'roc3', 'macd', 'DMplus', 'price_10Ddiff', 'macd_15MA_diff', 'price_3D20D_diff', 'SPY_20d_diff', 'TR', 'cmf_15MA', 'cmf', 'H-PrevClose', 'return_vol_10D', 'SPY_5d', 'bb_spread', 'price_change_D', 'bb_trend', 'cd_vol', 'DX', 'roc_15MA_diff', 'High-Low']
# 55.11176470588235 5.2823529411764705
#
# CDBFC_temporal_simulation_40
# ['roc_15MA_diff', 'macd', 'price_5Ddiff', 'roc', 'TR', 'volume_15MA_diff', 'price_3D20D_diff', 'volume_sum15_5DMA_diff', 'DMplus', 'price_10Ddiff', 'H-L', 'High-Low', 'cd_vol3', 'roc_15MA', 'cd_vol', 'volume_sum15', 'price_3Ddiff', 'macd_15MA', 'macd_15MA_diff', 'bb_trend', 'return_vol_5D_diff', 'rsi', 'DX', 'bb_category', 'rsi_15MA_diff', 'price_20Ddiff', 'H-PrevClose', 'return_vol_10D_diff', 'adx', 'day_of_week', 'day_of_month', 'month', 'SPY_range_vol', 'return_vol_5D', 'return_vol_10D', 'SPY_5d', 'price_change_H', 'SPY_20d', 'price_range_5DMA_diff', 'return_vol_8H', 'return_vol_8H_diff', 'hour', 'price_range', 'rsi_15MA', 'DIplus', 'price_change_D']
# 52.39411764705882 2.8705882352941177
#
# CDBFC_temporal_simulation_41
# ['price_change_H', 'price_range_5DMA_diff', 'return_vol_8H_diff', 'SPY_20d_diff', 'SPY_range_vol', 'return_vol_10D_diff', 'return_vol_5D', 'cmf_15MA_diff', 'bb_category', 'roc', 'cd_vol', 'DIplus', 'DIminus', 'price_20Ddiff', 'macd_15MA', 'price_range', 'SPY_5d', 'adx', 'H-PrevClose', 'price_10Ddiff', 'price_5Ddiff', 'High-Close', 'High-Low', 'macd', 'rsi_15MA', 'price_3D20D_diff', 'price_3Ddiff', 'volume_sum15_10DMA_diff', 'day_of_week', 'month', 'day_of_month', 'rsi_15MA_diff', 'return_vol_10D', 'roc_15MA', 'volume_sum15', 'cd_vol3', 'volume_sum15_5DMA_diff', 'roc5', 'SPY_20d', 'Low-Close', 'roc3', 'roc_15MA_diff', 'return_vol_5D_diff']
# Exception ignored on calling ctypes callback function: <bound method DataIter._next_wrapper of <xgboost.data.SingleBatchInternalIter object at 0x2b5703fd0>>
# Traceback (most recent call last):
#   File "/Users/charlesmiller/.local/share/virtualenvs/model-tester-d0oOM2ve/lib/python3.11/site-packages/xgboost/core.py", line 588, in _next_wrapper
#     def _next_wrapper(self, this: None) -> int:  # pylint: disable=unused-argument
#
# KeyboardInterrupt:
